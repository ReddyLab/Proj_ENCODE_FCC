# %% [markdown]
# **Set environment**

# %%
suppressWarnings(suppressMessages(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## Import data

# %%
fdiry = file.path(FD_RES, "results", "region", "KS91_K562_ASTARRseq_peak_macs_input")
fname = "KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz"
fpath = file.path(fdiry, fname)

cnames = c("Chrom", "Start", "End")
dat = read_tsv(fpath, col_names = cnames, show_col_types = FALSE)
dat = dat %>% dplyr::mutate(Name = paste0(Chrom, ":", Start, "-", End))

dat_peak_ocr = dat
print(dim(dat))
head(dat)
# Out:
# [1] 247520      4
#   Chrom Start End   Name
# 1 chr1  10015 10442 chr1:10015-10442
# 2 chr1  14253 14645 chr1:14253-14645
# 3 chr1  16015 16477 chr1:16015-16477
# 4 chr1  17237 17772 chr1:17237-17772
# 5 chr1  28903 29613 chr1:28903-29613
# 6 chr1  30803 31072 chr1:30803-31072

# %%
fdiry = file.path(FD_RES, "results", "region")
fname = "region_screened_selected.bed.gz"
fpath = file.path(fdiry, fname)

cnames = c("Chrom", "Start", "End", "Name")
dat = read_tsv(fpath, col_names = cnames, show_col_types = FALSE)

dat_region_subset = dat
print(dim(dat))
dat
# Out:
# [1] 16  4
#    Chrom Start     End       Name
# 1  chr11   4000000   6600000 chr11:4091884-6505900
# 2  chr11  32800000  35000000 chr11:32869701-34870100
# 3  chr11  61700000  62000000 chr11:61787329-61898348
# 4  chr12  54290000  54310000 chr12:54300766-54301042
# 5  chr12 110000000 113000000 chr12:110726151-112325737
# 6  chr16         0   1300000 chr16:10001-1173100
# 7  chr19  12880000  12900000 chr19:12887110-12887237
# 8  chr2   59000000  62000000 chr2:59553301-61553700
# 9  chr20  55500000  59000000 chr20:56391301-58391700
# 10 chr3  128475000 128512000 chr3:128487571-128487937
# 11 chr4   55000000  56500000 chr4:55237590-56068531
# 12 chr5   86000000  91600000 chr5:87611207-89911163
# 13 chr6  108000000 111000000 chr6:108840570-109828800
# 14 chr6  133000000 138000000 chr6:134253831-136927585
# 15 chr8  122000000 136000000 chr8:126735901-128736550
# 16 chrX   47000000  51000000 chrX:47785501-49880650

# %%
dat = dat_region_subset
vec = dat$Chrom
vec_chrom = sort(unique(vec))
print(vec_chrom)
# Out:
#  [1] "chr11" "chr12" "chr16" "chr19" "chr2"  "chr20" "chr3"  "chr4"  "chr5"
# [10] "chr6"  "chr8"  "chrX"

# %% [markdown]
# ## Create combinations of OCRs for selected chromosomes

# %%
dat = dat_peak_ocr
lst = split(dat$Name, dat$Chrom)

vec = vec_chrom
lst = lst[vec]

lst = lapply(lst, function(vec){
    ### Show progress
    cat(vec[1], "\n", length(vec), "\n\n")
    flush.console()
    
    ### create combinations without permutation
    dat_comb2_self  = data.frame(V1 = vec, V2 = vec)
    dat_comb2_pair  = combn(vec, 2) %>% t %>% as.data.frame    
    dat_comb2_total = dplyr::bind_rows(
        dat_comb2_self, 
        dat_comb2_pair) %>% 
        dplyr::arrange(V1, V2)
    return(dat_comb2_total)
})

lst_peak_comb2 = lst
print(names(lst))
head(lst[[1]])
# Out:
# chr11:113408-113701
#  12010
#
# chr12:10606-11448
#  10725
#
# chr16:10131-11496
#  8999
#
# chr19:70732-71295
#  8447
#
# chr2:11292-11934
#  19379
#
# chr20:129971-130487
#  6046
#
# chr3:10230-10640
#  14422
#
# chr4:11715-12387
#  10120
#
# chr5:10627-11783
#  13453
#
# chr6:126583-127039
#  18166
#
# chr8:191891-192124
#  10120
#
# chrX:19079-20855
#  4214
#
#  [1] "chr11" "chr12" "chr16" "chr19" "chr2"  "chr20" "chr3"  "chr4"  "chr5"
# [10] "chr6"  "chr8"  "chrX"
#   V1                    V2
# 1 chr11:1002205-1002620 chr11:1002205-1002620
# 2 chr11:1002205-1002620 chr11:100285883-100286264
# 3 chr11:1002205-1002620 chr11:100451963-100452380
# 4 chr11:1002205-1002620 chr11:100547023-100547250
# 5 chr11:1002205-1002620 chr11:100563051-100563718
# 6 chr11:1002205-1002620 chr11:100602670-100604359

# %%
lst = lst_peak_comb2
for (idn in names(lst)){
    dat = lst[[idn]]
    cat(idn, "|", nrow(dat)/10^6, "\n")
}
# Out:
# chr11 | 72.12605
# chr12 | 57.51817
# chr16 | 40.4955
# chr19 | 35.68013
# chr2 | 187.7825
# chr20 | 18.28008
# chr3 | 104.0043
# chr4 | 51.21226
# chr5 | 90.49833
# chr6 | 165.0109
# chr8 | 51.21226
# chrX | 8.881005

# %% [markdown]
# ## Split each dataset into subset and save results

# %%
lst_dat = lst_peak_comb2
for (idn in names(lst)){

    ### set file directory
    fdiry = file.path(
        FD_RES, "results", "region", 
        "KS91_K562_ASTARRseq_peak_macs_input", 
        "region_pair",
        paste("region_pair", idn, sep="_"))
    
    txt = paste("mkdir", "-p", fdiry)
    system(txt)
    
    ### extract data and split
    dat = lst_dat[[idn]]
    lst_tmp = split(dat, (seq(nrow(dat))-1) %/% 10^6)
    
    ### show progress
    cat("==========================\n")
    cat(idn, "|", nrow(dat)/10^6, "\n")
    cat("Splitted into", length(lst_tmp), "pieces", "\n")
    cat("\n")
    flush.console()
    
    ### 
    for (idx in seq_along(lst_tmp)){
        ### extract data
        dat   = lst_tmp[[idx]]
        txt   = paste0("SUBSET", idx)
        
        ### set file directory
        fname = paste("region_pair", idn, txt, "tsv.gz", sep=".")
        fpath = file.path(fdiry, fname)
        
        ### save the results
        write_tsv(dat, fpath, col_names=FALSE)
        
        ### show progress
        cat("File name: ", fname,    "\n")
        cat("Data shape:", dim(dat), "\n")
        cat("\n")
        flush.console()
    }
}
# Out:
# ==========================
# chr11 | 72.12605
# Splitted into 73 pieces
#
# File name:  region_pair.chr11.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET52.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET53.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET54.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET55.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET56.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET57.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET58.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET59.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET60.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET61.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET62.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET63.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET64.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET65.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET66.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET67.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET68.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET69.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET70.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET71.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET72.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr11.SUBSET73.tsv.gz
# Data shape: 126055 2
#
# ==========================
# chr12 | 57.51817
# Splitted into 58 pieces
#
# File name:  region_pair.chr12.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET52.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET53.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET54.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET55.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET56.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET57.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr12.SUBSET58.tsv.gz
# Data shape: 518175 2
#
# ==========================
# chr16 | 40.4955
# Splitted into 41 pieces
#
# File name:  region_pair.chr16.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr16.SUBSET41.tsv.gz
# Data shape: 495500 2
#
# ==========================
# chr19 | 35.68013
# Splitted into 36 pieces
#
# File name:  region_pair.chr19.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr19.SUBSET36.tsv.gz
# Data shape: 680128 2
#
# ==========================
# chr2 | 187.7825
# Splitted into 188 pieces
#
# File name:  region_pair.chr2.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET52.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET53.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET54.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET55.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET56.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET57.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET58.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET59.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET60.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET61.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET62.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET63.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET64.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET65.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET66.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET67.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET68.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET69.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET70.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET71.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET72.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET73.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET74.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET75.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET76.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET77.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET78.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET79.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET80.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET81.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET82.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET83.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET84.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET85.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET86.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET87.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET88.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET89.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET90.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET91.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET92.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET93.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET94.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET95.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET96.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET97.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET98.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET99.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET100.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET101.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET102.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET103.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET104.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET105.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET106.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET107.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET108.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET109.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET110.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET111.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET112.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET113.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET114.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET115.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET116.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET117.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET118.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET119.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET120.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET121.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET122.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET123.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET124.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET125.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET126.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET127.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET128.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET129.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET130.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET131.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET132.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET133.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET134.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET135.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET136.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET137.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET138.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET139.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET140.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET141.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET142.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET143.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET144.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET145.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET146.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET147.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET148.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET149.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET150.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET151.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET152.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET153.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET154.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET155.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET156.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET157.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET158.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET159.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET160.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET161.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET162.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET163.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET164.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET165.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET166.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET167.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET168.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET169.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET170.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET171.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET172.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET173.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET174.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET175.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET176.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET177.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET178.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET179.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET180.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET181.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET182.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET183.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET184.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET185.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET186.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET187.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr2.SUBSET188.tsv.gz
# Data shape: 782510 2
#
# ==========================
# chr20 | 18.28008
# Splitted into 19 pieces
#
# File name:  region_pair.chr20.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr20.SUBSET19.tsv.gz
# Data shape: 280081 2
#
# ==========================
# chr3 | 104.0043
# Splitted into 105 pieces
#
# File name:  region_pair.chr3.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET52.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET53.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET54.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET55.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET56.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET57.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET58.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET59.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET60.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET61.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET62.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET63.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET64.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET65.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET66.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET67.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET68.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET69.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET70.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET71.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET72.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET73.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET74.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET75.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET76.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET77.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET78.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET79.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET80.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET81.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET82.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET83.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET84.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET85.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET86.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET87.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET88.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET89.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET90.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET91.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET92.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET93.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET94.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET95.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET96.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET97.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET98.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET99.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET100.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET101.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET102.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET103.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET104.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr3.SUBSET105.tsv.gz
# Data shape: 4253 2
#
# ==========================
# chr4 | 51.21226
# Splitted into 52 pieces
#
# File name:  region_pair.chr4.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr4.SUBSET52.tsv.gz
# Data shape: 212260 2
#
# ==========================
# chr5 | 90.49833
# Splitted into 91 pieces
#
# File name:  region_pair.chr5.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET52.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET53.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET54.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET55.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET56.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET57.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET58.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET59.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET60.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET61.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET62.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET63.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET64.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET65.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET66.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET67.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET68.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET69.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET70.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET71.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET72.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET73.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET74.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET75.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET76.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET77.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET78.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET79.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET80.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET81.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET82.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET83.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET84.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET85.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET86.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET87.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET88.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET89.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET90.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr5.SUBSET91.tsv.gz
# Data shape: 498331 2
#
# ==========================
# chr6 | 165.0109
# Splitted into 166 pieces
#
# File name:  region_pair.chr6.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET52.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET53.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET54.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET55.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET56.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET57.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET58.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET59.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET60.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET61.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET62.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET63.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET64.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET65.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET66.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET67.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET68.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET69.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET70.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET71.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET72.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET73.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET74.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET75.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET76.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET77.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET78.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET79.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET80.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET81.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET82.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET83.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET84.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET85.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET86.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET87.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET88.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET89.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET90.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET91.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET92.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET93.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET94.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET95.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET96.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET97.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET98.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET99.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET100.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET101.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET102.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET103.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET104.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET105.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET106.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET107.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET108.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET109.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET110.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET111.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET112.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET113.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET114.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET115.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET116.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET117.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET118.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET119.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET120.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET121.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET122.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET123.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET124.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET125.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET126.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET127.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET128.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET129.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET130.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET131.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET132.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET133.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET134.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET135.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET136.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET137.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET138.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET139.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET140.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET141.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET142.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET143.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET144.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET145.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET146.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET147.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET148.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET149.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET150.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET151.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET152.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET153.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET154.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET155.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET156.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET157.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET158.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET159.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET160.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET161.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET162.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET163.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET164.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET165.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr6.SUBSET166.tsv.gz
# Data shape: 10861 2
#
# ==========================
# chr8 | 51.21226
# Splitted into 52 pieces
#
# File name:  region_pair.chr8.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET9.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET10.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET11.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET12.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET13.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET14.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET15.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET16.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET17.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET18.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET19.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET20.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET21.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET22.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET23.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET24.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET25.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET26.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET27.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET28.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET29.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET30.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET31.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET32.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET33.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET34.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET35.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET36.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET37.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET38.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET39.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET40.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET41.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET42.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET43.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET44.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET45.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET46.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET47.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET48.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET49.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET50.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET51.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chr8.SUBSET52.tsv.gz
# Data shape: 212260 2
#
# ==========================
# chrX | 8.881005
# Splitted into 9 pieces
#
# File name:  region_pair.chrX.SUBSET1.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET2.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET3.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET4.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET5.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET6.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET7.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET8.tsv.gz
# Data shape: 1000000 2
#
# File name:  region_pair.chrX.SUBSET9.tsv.gz
# Data shape: 881005 2
