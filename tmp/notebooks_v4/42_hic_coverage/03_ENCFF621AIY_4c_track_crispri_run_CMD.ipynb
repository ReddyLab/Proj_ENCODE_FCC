# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **check data**

# %%
FDIRY=${FD_RES}/source/hic_intact_K562_ENCSR479XDG
ls ${FDIRY}
# Out:
# ENCFF621AIY.hic
# K562.ENCSR479XDG.ENCFF126GED.contact_domains.bedpe.gz
# K562.ENCSR479XDG.ENCFF256ZMD.loops.bedpe.gz

# %%
ls ./*tsv
# Out:
# ./hic_intact_K562_deep_virtual4c_track_crispri_hcrff_1K.tsv
# ./hic_intact_K562_deep_virtual4c_track_crispri_hcrff_3K.tsv
# ./hic_intact_K562_ENCSR479XDG_virtual4c_track_crispri_hcrff_1K.tsv
# ./hic_intact_K562_ENCSR479XDG_virtual4c_track_crispri_hcrff_3K.tsv

# %%
FD_INP=.
FN_INP=hic_intact_K562_ENCSR479XDG_virtual4c_track_crispri_hcrff_3K.tsv
FP_INP=${FD_INP}/${FN_INP}

FD_OUT=.
FN_OUT=run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_3K.sh
FP_OUT=${FD_OUT}/${FN_OUT}

cat  /dev/null     >  ${FP_OUT}
echo '#!/bin/bash' >> ${FP_OUT}

FP_AWK=/data/reddylab/software/bin/print_tab_cols.awk
cat ${FP_INP} \
| awk -f ${FP_AWK} -v cols=CMD \
>> ${FP_OUT}

chmod +x ${FP_OUT}

# %%
FD_INP=.
FN_INP=hic_intact_K562_ENCSR479XDG_virtual4c_track_crispri_hcrff_1K.tsv
FP_INP=${FD_INP}/${FN_INP}

FD_OUT=.
FN_OUT=run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_1K.sh
FP_OUT=${FD_OUT}/${FN_OUT}

cat  /dev/null     >  ${FP_OUT}
echo '#!/bin/bash' >> ${FP_OUT}

FP_AWK=/data/reddylab/software/bin/print_tab_cols.awk
cat ${FP_INP} \
| awk -f ${FP_AWK} -v cols=CMD \
>> ${FP_OUT}

chmod +x ${FP_OUT}

# %%
cat run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_3K.sh
# Out:
# #!/bin/bash
# python /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC/notebooks/42_hic_coverage/gen_virtual4c_track.py --fpath_hic /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_ENCSR479XDG/ENCFF621AIY.hic --fpath_out /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/virtual4C.K562.ENCFF621AIY.HBE1.TSS.3K.bg --normalization SCALE --resolution 100 --chrom chr11 --x1 4091884 --y1 6419310 --x2 5266945 --y2 5272945 --verbose
# ...

# %%
cat run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_1K.sh
# Out:
# #!/bin/bash
# python /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC/notebooks/42_hic_coverage/gen_virtual4c_track.py --fpath_hic /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_ENCSR479XDG/ENCFF621AIY.hic --fpath_out /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/virtual4C.K562.ENCFF621AIY.HBE1.TSS.1K.bg --normalization SCALE --resolution 100 --chrom chr11 --x1 4091884 --y1 6419310 --x2 5268945 --y2 5270945 --verbose
# ...

# %% [markdown]
# **Run**

# %%
cat ${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh
# Out:
# #!/bin/bash
#
# ### get file path
# ### Stackoverflow: how-can-i-get-the-source-directory-of-a-bash-script-from-within-the-script-itself
# SCRIPT_DIR="$( cd "$( dirname "${BASH_SOURCE[0]}" )" &> /dev/null && pwd )"
# source ${SCRIPT_DIR}/config/config_duke.sh
#
# ### execute
# singularity exec \
#     -H ${PWD}:/home \
#     -B ${FD_WORK}:/mount/work \
#     -B ${FD_CODE}:/mount/code \
#     -B ${FD_RLAB}:/mount/reddylab \
#     -B /data:/data \
#     ${FD_SING}/singularity_proj_encode_fcc.sif \
#     "$@"

# %%
FDIRY=/data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC/notebooks/42_hic_coverage
FNAME=gen_virtual4c_track.py
FPATH=${FDIRY}/${FNAME}

${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh python ${FPATH} -h
# Out:
# usage: gen_virtual4c_track.py [-h] [--chrom CHROM] [--x1 X1] [--y1 Y1]
#                               [--x2 X2] [--y2 Y2] [--fpath_out FPATH_OUT]
#                               [--fpath_hic FPATH_HIC]
#                               [--normalization NORMALIZATION]
#                               [--resolution RESOLUTION] [-v]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --chrom CHROM
#   --x1 X1
#   --y1 Y1
#   --x2 X2
#   --y2 Y2
#   --fpath_out FPATH_OUT
#   --fpath_hic FPATH_HIC
#   --normalization NORMALIZATION
#   --resolution RESOLUTION
#   -v, --verbose

# %%
ls ./*ENCSR479XDG*sh
# Out:
# ./run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_1K.sh
# ./run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_3K.sh

# %%
sbatch -p ${NODE} \
    --exclude=dl-01 \
    --cpus-per-task 8 \
    --mem 20G \
    --output ${FD_LOG}/coverage_hic_intact_K562_ENCFF621AIY_virtual4c_track_crispri_hcrff_TSS_3k.%a.txt \
    --array 0 \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config/config_duke.sh

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### execute
FDIRY=${FD_PRJ}/notebooks/42_hic_coverage
FNAME=run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_3K.sh
FPATH=${FDIRY}/${FNAME}

chmod +x ${FPATH}
${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh ${FPATH}

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"
EOF
# Out:
# Submitted batch job 29916160

# %%
sbatch -p ${NODE} \
    --exclude=dl-01 \
    --cpus-per-task 8 \
    --mem 20G \
    --output ${FD_LOG}/coverage_hic_intact_K562_ENCFF621AIY_virtual4c_track_crispri_hcrff_TSS_1k.%a.txt \
    --array 0 \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config/config_duke.sh

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### execute
FDIRY=${FD_PRJ}/notebooks/42_hic_coverage
FNAME=run_gen_virtual4c_track_K562_ENCSR479XDG_TSS_1K.sh
FPATH=${FDIRY}/${FNAME}

chmod +x ${FPATH}
${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh ${FPATH}

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"
EOF
# Out:
# Submitted batch job 29916161

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/coverage_hic_intact_K562_ENCFF621AIY_virtual4c_track_crispri_hcrff_TSS_3k.0.txt
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         05-29-23+15:03:43
#
# Arguments:
# -  chrom : chr11
# -  x1 : 4091884
# -  y1 : 6419310
# -  x2 : 5266945
# -  y2 : 5272945
# -  fpath_out : /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/virtual4C.K562.ENCFF621AIY.HBE1.TSS.3K.bg
# -  fpath_hic : /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_ENCSR479XDG/ENCFF621AIY.hic
# -  normalization : SCALE
# -  resolution : 100
# -  verbose : True
#
# Matrix generated.
# - Shape: (23276, 61)
#
# DataFrame generated.
# - Shape: (23276, 4)
#
# Arguments:
# -  chrom : chr11
# -  x1 : 4091884
# -  y1 : 6419310
# -  x2 : 5246857
# -  y2 : 5252857
# -  fpath_out : /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/virtual4C.K562.ENCFF621AIY.HBG1.TSS.3K.bg
# ...

# %%
cat ${FD_LOG}/coverage_hic_intact_K562_ENCFF621AIY_virtual4c_track_crispri_hcrff_TSS_1k.0.txt
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         05-29-23+15:03:47
#
# Arguments:
# -  chrom : chr11
# -  x1 : 4091884
# -  y1 : 6419310
# -  x2 : 5268945
# -  y2 : 5270945
# -  fpath_out : /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/virtual4C.K562.ENCFF621AIY.HBE1.TSS.1K.bg
# -  fpath_hic : /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_ENCSR479XDG/ENCFF621AIY.hic
# -  normalization : SCALE
# -  resolution : 100
# -  verbose : True
#
# Matrix generated.
# - Shape: (23276, 21)
#
# DataFrame generated.
# - Shape: (23276, 4)
#
# Arguments:
# -  chrom : chr11
# -  x1 : 4091884
# -  y1 : 6419310
# -  x2 : 5248857
# -  y2 : 5250857
# -  fpath_out : /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/virtual4C.K562.ENCFF621AIY.HBG1.TSS.1K.bg
# ...

# %% [markdown]
# ## Convert bedgraph to bigwig

# %%
FP_INPS=($(ls ${FD_RES}/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/*.bg))
basename -a ${FP_INPS[@]}
# Out:
# virtual4C.K562.ENCFF621AIY.CAPRIN1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.CAPRIN1.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.CAT.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.CAT.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.CD164.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.CD164.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.ERP29.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.ERP29.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.FADS1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.FADS1.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.FADS2.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.FADS2.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.FADS3.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.FADS3.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.FEN1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.FEN1.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.GATA1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.GATA1.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.HBE1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.HBE1.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.HBG1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.HBG1.TSS.3K.bg
# ...

# %%
### init
FD_UCSC=/data/common/shared_conda_envs/ucsc/bin
FP_CHR=${FD_RES}/source/chrom.sizes.hg38
FP_INPS=($(ls ${FD_RES}/results/hic_intact_K562_ENCSR479XDG/coverage_virtual4c_track_crispri_hcrff/*.bg))

### loop through each bed file and convert to bigwig file
for FP_INP in ${FP_INPS[@]}; do

    ### set input and output
    FD_OUT=$(dirname  ${FP_INP})
    FN_INP=$(basename ${FP_INP})
    PREFIX=${FN_INP%.bg}
    FN_OUT=${PREFIX}.bw
    FP_OUT=${FD_OUT}/${FN_OUT}
    echo ${FN_INP}
    echo ${FN_OUT}
    
    ### bedgraph2bigwig
    ${FD_UCSC}/bedGraphToBigWig ${FP_INP} ${FP_CHR} ${FP_OUT}
done
# Out:
# virtual4C.K562.ENCFF621AIY.CAPRIN1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.CAPRIN1.TSS.1K.bw
# virtual4C.K562.ENCFF621AIY.CAPRIN1.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.CAPRIN1.TSS.3K.bw
# virtual4C.K562.ENCFF621AIY.CAT.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.CAT.TSS.1K.bw
# virtual4C.K562.ENCFF621AIY.CAT.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.CAT.TSS.3K.bw
# virtual4C.K562.ENCFF621AIY.CD164.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.CD164.TSS.1K.bw
# virtual4C.K562.ENCFF621AIY.CD164.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.CD164.TSS.3K.bw
# virtual4C.K562.ENCFF621AIY.ERP29.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.ERP29.TSS.1K.bw
# virtual4C.K562.ENCFF621AIY.ERP29.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.ERP29.TSS.3K.bw
# virtual4C.K562.ENCFF621AIY.FADS1.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.FADS1.TSS.1K.bw
# virtual4C.K562.ENCFF621AIY.FADS1.TSS.3K.bg
# virtual4C.K562.ENCFF621AIY.FADS1.TSS.3K.bw
# virtual4C.K562.ENCFF621AIY.FADS2.TSS.1K.bg
# virtual4C.K562.ENCFF621AIY.FADS2.TSS.1K.bw
# ...
