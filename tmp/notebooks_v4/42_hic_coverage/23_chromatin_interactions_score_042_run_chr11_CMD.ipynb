# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loops**

# %%
TXT_CHROMOSOME=chr11

FOLDER_LOOP=hic_intact_K562_deep
FOLDER_REG=region_pair_${TXT_CHROMOSOME}

FP_HIC=${FD_RES}/source/${FOLDER_LOOP}/inter.hic
FD_INP=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/${FOLDER_REG}
FD_OUT=${FD_RES}/results/${FOLDER_LOOP}/coverage_astarrseq_peak_macs_input/${FOLDER_REG}

FP_INPS=($(ls ${FD_INP}/region_pair*chr*.SUBSET*.tsv.gz))
for FP_INP in ${FP_INPS[@]}; do

    ### set I/O file
    FN_INP=$(basename ${FP_INP})
    IFS='.' read -r -a ARRAY <<< ${FN_INP}
    FN_OUT=${FN_INP}
    FN_LOG=coverage.${FOLDER_LOOP}.region_pair.${ARRAY[1]}.${ARRAY[2]}.%a.txt
    
    FP_INP=${FD_INP}/${FN_INP}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "Chromosome:" ${TXT_CHROMOSOME}
    echo
    echo "FP_HIC:"  ${FP_HIC}
    echo "FP_INP:"  ${FP_INP}
    echo "FP_OUT:"  ${FP_OUT}
    echo
    echo "FN_INP:"  ${FN_INP}
    echo "FN_OUT:"  ${FN_OUT}
    echo "FP_LOG:" '${FD_LOG}'/${FN_LOG/\%a/0}
    echo
done
# Out:
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET10.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET10.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET10.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET10.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET10.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET11.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET11.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET11.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET11.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET11.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET12.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET12.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET12.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET12.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET12.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET13.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET13.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET13.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET13.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET13.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET14.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET14.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET14.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET14.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET14.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET15.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET15.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET15.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET15.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET15.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET16.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET16.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET16.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET16.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET16.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET17.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET17.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET17.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET17.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET17.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET18.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET18.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET18.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET18.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET18.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET19.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET19.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET19.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET19.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET19.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET1.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET1.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET1.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET1.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET1.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET20.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET20.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET20.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET20.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET20.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET21.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET21.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET21.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET21.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET21.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET22.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET22.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET22.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET22.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET22.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET23.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET23.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET23.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET23.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET23.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET24.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET24.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET24.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET24.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET24.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET25.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET25.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET25.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET25.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET25.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET26.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET26.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET26.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET26.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET26.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET27.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET27.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET27.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET27.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET27.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET28.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET28.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET28.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET28.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET28.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET29.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET29.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET29.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET29.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET29.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET2.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET2.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET2.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET2.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET2.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET30.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET30.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET30.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET30.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET30.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET31.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET31.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET31.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET31.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET31.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET32.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET32.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET32.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET32.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET32.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET33.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET33.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET33.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET33.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET33.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET34.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET34.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET34.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET34.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET34.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET35.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET35.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET35.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET35.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET35.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET36.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET36.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET36.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET36.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET36.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET37.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET37.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET37.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET37.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET37.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET38.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET38.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET38.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET38.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET38.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET39.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET39.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET39.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET39.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET39.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET3.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET3.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET3.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET3.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET3.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET40.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET40.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET40.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET40.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET40.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET41.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET41.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET41.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET41.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET41.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET42.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET42.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET42.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET42.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET42.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET43.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET43.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET43.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET43.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET43.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET44.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET44.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET44.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET44.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET44.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET45.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET45.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET45.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET45.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET45.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET46.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET46.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET46.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET46.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET46.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET47.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET47.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET47.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET47.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET47.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET48.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET48.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET48.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET48.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET48.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET49.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET49.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET49.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET49.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET49.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET4.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET4.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET4.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET4.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET4.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET50.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET50.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET50.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET50.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET50.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET51.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET51.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET51.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET51.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET51.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET52.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET52.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET52.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET52.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET52.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET53.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET53.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET53.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET53.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET53.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET54.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET54.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET54.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET54.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET54.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET55.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET55.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET55.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET55.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET55.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET56.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET56.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET56.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET56.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET56.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET57.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET57.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET57.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET57.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET57.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET58.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET58.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET58.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET58.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET58.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET59.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET59.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET59.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET59.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET59.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET5.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET5.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET5.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET5.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET5.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET60.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET60.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET60.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET60.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET60.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET61.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET61.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET61.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET61.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET61.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET62.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET62.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET62.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET62.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET62.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET63.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET63.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET63.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET63.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET63.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET64.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET64.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET64.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET64.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET64.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET65.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET65.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET65.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET65.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET65.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET66.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET66.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET66.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET66.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET66.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET67.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET67.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET67.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET67.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET67.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET68.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET68.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET68.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET68.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET68.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET69.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET69.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET69.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET69.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET69.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET6.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET6.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET6.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET6.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET6.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET70.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET70.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET70.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET70.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET70.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET71.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET71.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET71.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET71.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET71.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET72.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET72.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET72.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET72.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET72.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET73.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET73.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET73.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET73.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET73.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET7.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET7.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET7.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET7.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET7.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET8.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET8.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET8.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET8.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET8.0.txt
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET9.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET9.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET9.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET9.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET9.0.txt

# %% [markdown]
# **Execute**

# %%
### init: choosing regions
TXT_CHROMOSOME=chr11
FOLDER_LOOP=hic_intact_K562_deep
FOLDER_REG=region_pair_${TXT_CHROMOSOME}

### init: set I/O file directory
FP_HIC=${FD_RES}/source/${FOLDER_LOOP}/inter.hic
FD_INP=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/${FOLDER_REG}
FD_OUT=${FD_RES}/results/${FOLDER_LOOP}/coverage_astarrseq_peak_macs_input/${FOLDER_REG}

### init: arguments
TXT_NORMALIZATION='RU'
VAL_RESOLUTION=100
VAL_NUM_LINE_SHOW=10_000

### execute: get input and set output file directory
mkdir -p ${FD_OUT} 
FP_INPS=($(ls ${FD_INP}/region_pair*chr*.SUBSET*.tsv.gz))

### execute: loop and process each input file
for FP_INP in ${FP_INPS[@]}; do

    ### set I/O file
    FN_INP=$(basename ${FP_INP})
    IFS='.' read -r -a ARRAY <<< ${FN_INP}
    FN_OUT=${FN_INP}
    FN_LOG=coverage.${FOLDER_LOOP}.region_pair.${ARRAY[1]}.${ARRAY[2]}.%a.txt
    
    FP_INP=${FD_INP}/${FN_INP}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "Chromosome:" ${TXT_CHROMOSOME}
    echo
    echo "FP_HIC:"  ${FP_HIC}
    echo "FP_INP:"  ${FP_INP}
    echo "FP_OUT:"  ${FP_OUT}
    echo
    echo "FN_INP:"  ${FN_INP}
    echo "FN_OUT:"  ${FN_OUT}
    echo "FP_LOG:" '${FD_LOG}'/${FN_LOG/\%a/0}
    echo
    sbatch -p ${NODE} \
        --exclude dl-01 \
        --cpus-per-task 8 \
        --mem 30G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        run_converage_region_pair_score_subset.sh \
            ${FP_HIC} \
            ${FP_INP} \
            ${FP_OUT} \
            ${TXT_CHROMOSOME} \
            ${TXT_NORMALIZATION} \
            ${VAL_RESOLUTION} \
            ${VAL_NUM_LINE_SHOW}
    echo
done
# Out:
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBS
tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET47.0.txt
#
# Submitted batch job 30034103
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET48.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET48.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET48.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET48.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET48.0.txt
#
# Submitted batch job 30034104
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET49.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET49.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET49.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET49.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET49.0.txt
#
# Submitted batch job 30034105
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET4.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET4.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET4.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET4.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET4.0.txt
#
# Submitted batch job 30034106
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET50.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET50.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET50.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET50.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET50.0.txt
#
# Submitted batch job 30034107
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET51.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET51.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET51.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET51.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET51.0.txt
#
# Submitted batch job 30034108
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET52.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET52.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET52.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET52.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET52.0.txt
#
# Submitted batch job 30034109
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET53.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET53.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET53.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET53.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET53.0.txt
#
# Submitted batch job 30034110
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET54.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET54.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET54.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET54.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET54.0.txt
#
# Submitted batch job 30034111
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET55.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET55.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET55.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET55.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET55.0.txt
#
# Submitted batch job 30034112
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET56.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET56.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET56.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET56.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET56.0.txt
#
# Submitted batch job 30034113
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET57.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET57.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET57.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET57.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET57.0.txt
#
# Submitted batch job 30034114
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET58.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET58.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET58.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET58.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET58.0.txt
#
# Submitted batch job 30034115
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET59.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET59.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET59.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET59.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET59.0.txt
#
# Submitted batch job 30034116
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET5.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET5.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET5.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET5.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET5.0.txt
#
# Submitted batch job 30034117
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET60.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET60.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET60.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET60.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET60.0.txt
#
# Submitted batch job 30034118
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET61.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET61.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET61.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET61.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET61.0.txt
#
# Submitted batch job 30034119
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET62.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET62.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET62.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET62.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET62.0.txt
#
# Submitted batch job 30034120
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET63.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET63.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET63.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET63.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET63.0.txt
#
# Submitted batch job 30034121
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET64.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET64.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET64.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET64.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET64.0.txt
#
# Submitted batch job 30034122
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET65.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET65.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET65.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET65.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET65.0.txt
#
# Submitted batch job 30034123
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET66.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET66.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET66.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET66.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET66.0.txt
#
# Submitted batch job 30034124
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET67.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET67.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET67.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET67.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET67.0.txt
#
# Submitted batch job 30034125
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET68.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET68.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET68.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET68.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET68.0.txt
#
# Submitted batch job 30034126
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET69.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET69.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET69.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET69.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET69.0.txt
#
# Submitted batch job 30034127
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET6.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET6.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET6.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET6.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET6.0.txt
#
# Submitted batch job 30034128
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET70.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET70.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET70.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET70.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET70.0.txt
#
# Submitted batch job 30034129
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET71.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET71.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET71.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET71.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET71.0.txt
#
# Submitted batch job 30034130
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET72.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET72.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET72.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET72.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET72.0.txt
#
# Submitted batch job 30034131
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET73.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET73.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET73.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET73.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET73.0.txt
#
# Submitted batch job 30034132
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET7.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET7.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET7.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET7.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET7.0.txt
#
# Submitted batch job 30034133
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET8.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET8.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET8.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET8.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET8.0.txt
#
# Submitted batch job 30034134
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair_chr11/region_pair.chr11.SUBSET9.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair_chr11/region_pair.chr11.SUBSET9.tsv.gz
#
# FN_INP: region_pair.chr11.SUBSET9.tsv.gz
# FN_OUT: region_pair.chr11.SUBSET9.tsv.gz
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET9.0.txt
#
# Submitted batch job 30034135

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.SUBSET69.0.txt
# Out:
# Hostname:           x2-05-2
# Slurm Array Index:  0
# Time Stamp:         07-04-23+11:18:13
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results