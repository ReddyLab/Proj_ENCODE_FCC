# %% [markdown]
# **Set environment**

# %%
suppressWarnings(suppressMessages(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## Import data

# %%
fdiry = file.path(FD_RES, "results", "region", "KS91_K562_ASTARRseq_peak_macs_input")
fname = "KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz"
fpath = file.path(fdiry, fname)

cnames = c("Chrom", "Start", "End")
dat = read_tsv(fpath, col_names = cnames, show_col_types = FALSE)
dat = dat %>% dplyr::mutate(Name = paste0(Chrom, ":", Start, "-", End))

dat_peak_ocr = dat
print(dim(dat))
head(dat)
# Out:
# [1] 247520      4
#   Chrom Start End   Name
# 1 chr1  10015 10442 chr1:10015-10442
# 2 chr1  14253 14645 chr1:14253-14645
# 3 chr1  16015 16477 chr1:16015-16477
# 4 chr1  17237 17772 chr1:17237-17772
# 5 chr1  28903 29613 chr1:28903-29613
# 6 chr1  30803 31072 chr1:30803-31072

# %% [markdown]
# ## Create combinations of OCRs for each chromosome

# %%
dat = dat_peak_ocr

vec = paste0("chr", c(1:22, "X"))
dat = dat %>% dplyr::filter(Chrom %in% vec)

lst = split(dat$Name, dat$Chrom)
lst = lapply(lst, function(vec){
    ### Show progress
    cat(vec[1], "\n", length(vec), "\n\n")
    flush.console()
    
    ### create combinations without permutation
    dat_comb2_self  = data.frame(V1 = vec, V2 = vec)
    dat_comb2_pair  = combn(vec, 2) %>% t %>% as.data.frame    
    dat_comb2_total = dplyr::bind_rows(
        dat_comb2_self, 
        dat_comb2_pair) %>% 
        dplyr::arrange(V1, V2)
    return(dat_comb2_total)
})

lst_peak_comb2 = lst
print(names(lst))
head(lst[[1]])
# Out:
# chr1:10015-10442
#  30534
#
# chr10:11333-11817
#  11398
#
# chr11:113408-113701
#  12010
#
# chr12:10606-11448
#  10725
#
# chr13:16008265-16008631
#  3675
#
# chr14:18655043-18655786
#  4386
#
# chr15:19987541-19987935
#  7965
#
# chr16:10131-11496
#  8999
#
# chr17:134079-134681
#  10104
#
# chr18:45971-46669
#  5088
#
# chr19:70732-71295
#  8447
#
# chr2:11292-11934
#  19379
#
# chr20:129971-130487
#  6046
#
# chr21:5065292-5066109
#  4241
#
# chr22:10687272-10687556
#  4946
#
# chr3:10230-10640
#  14422
#
# chr4:11715-12387
#  10120
#
# chr5:10627-11783
#  13453
#
# chr6:126583-127039
#  18166
#
# chr7:30662-31595
#  20036
#
# chr8:191891-192124
#  10120
#
# chr9:10454-11824
#  8378
#
# chrX:19079-20855
#  4214
#
#  [1] "chr1"  "chr10" "chr11" "chr12" "chr13" "chr14" "chr15" "chr16" "chr17"
# [10] "chr18" "chr19" "chr2"  "chr20" "chr21" "chr22" "chr3"  "chr4"  "chr5"
# [19] "chr6"  "chr7"  "chr8"  "chr9"  "chrX"
#   V1                       V2
# 1 chr1:100006256-100006880 chr1:100006256-100006880
# 2 chr1:100006256-100006880 chr1:100010437-100010915
# 3 chr1:100006256-100006880 chr1:100021298-100021629
# 4 chr1:100006256-100006880 chr1:100023727-100023976
# 5 chr1:100006256-100006880 chr1:100027983-100029702
# 6 chr1:100006256-100006880 chr1:100036871-100039191

# %%
lst = lst_peak_comb2
for (idn in names(lst)){
    dat = lst[[idn]]
    cat(idn, "|", nrow(dat)/10^6, "\n")
}
# Out:
# chr1 | 466.1778
# chr10 | 64.9629
# chr11 | 72.12605
# chr12 | 57.51817
# chr13 | 6.75465
# chr14 | 9.620691
# chr15 | 31.7246
# chr16 | 40.4955
# chr17 | 51.05046
# chr18 | 12.94642
# chr19 | 35.68013
# chr2 | 187.7825
# chr20 | 18.28008
# chr21 | 8.995161
# chr22 | 12.23393
# chr3 | 104.0043
# chr4 | 51.21226
# chr5 | 90.49833
# chr6 | 165.0109
# chr7 | 200.7307
# chr8 | 51.21226
# chr9 | 35.09963
# chrX | 8.881005

# %% [markdown]
# ## Save the results into tsv and bedpe format

# %%
lst = lst_peak_comb2
for (idn in names(lst)){
    ### Show progress
    cat("Chromosome:", idn, "\n")
    flush.console()
    
    ### extract table
    dat = lst[[idn]]
    
    ### save in table format
    fdiry = file.path(FD_RES, "results", "region", "KS91_K562_ASTARRseq_peak_macs_input", "region_pair")
    fname = paste("region_pair", idn, "tsv.gz", sep=".")
    fpath = file.path(fdiry, fname)
    write_tsv(dat, fpath, col_names=FALSE)

    ### Show progress
    cat("Save results:\n", fpath,    "\n")
    cat("Data shape:\n",   dim(dat), "\n")
    print(head(dat))
    cat("\n")
    flush.console()
}
# Out:
# Chromosome: chr1
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr1.tsv.gz
# Data shape:
#  466177845 2
#                         V1                       V2
# 1 chr1:100006256-100006880 chr1:100006256-100006880
# 2 chr1:100006256-100006880 chr1:100010437-100010915
# 3 chr1:100006256-100006880 chr1:100021298-100021629
# 4 chr1:100006256-100006880 chr1:100023727-100023976
# 5 chr1:100006256-100006880 chr1:100027983-100029702
# 6 chr1:100006256-100006880 chr1:100036871-100039191
#
# Chromosome: chr10
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr10.tsv.gz
# Data shape:
#  64962901 2
#                          V1                        V2
# 1 chr10:100009096-100010466 chr10:100009096-100010466
# 2 chr10:100009096-100010466 chr10:100020710-100021134
# 3 chr10:100009096-100010466 chr10:100045961-100046653
# 4 chr10:100009096-100010466 chr10:100065094-100065486
# 5 chr10:100009096-100010466 chr10:100081317-100081607
# 6 chr10:100009096-100010466 chr10:100095324-100095660
#
# Chromosome: chr11
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.ch
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr5.tsv.gz
# Data shape:
#  90498331 2
#                       V1                       V2
# 1 chr5:10002440-10002945   chr5:10002440-10002945
# 2 chr5:10002440-10002945   chr5:10016307-10017092
# 3 chr5:10002440-10002945   chr5:10029973-10031379
# 4 chr5:10002440-10002945   chr5:10033952-10034403
# 5 chr5:10002440-10002945 chr5:100379363-100380149
# 6 chr5:10002440-10002945 chr5:100389505-100389846
#
# Chromosome: chr6
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr6.tsv.gz
# Data shape:
#  165010861 2
#                         V1                       V2
# 1 chr6:100001763-100002390 chr6:100001763-100002390
# 2 chr6:100001763-100002390 chr6:100065270-100065656
# 3 chr6:100001763-100002390 chr6:100078483-100079108
# 4 chr6:100001763-100002390 chr6:100092797-100093517
# 5 chr6:100001763-100002390 chr6:100097012-100097404
# 6 chr6:100001763-100002390 chr6:100099405-100099868
#
# Chromosome: chr7
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr7.tsv.gz
# Data shape:
#  200730666 2
#                         V1                       V2
# 1 chr7:100003749-100004855 chr7:100003749-100004855
# 2 chr7:100003749-100004855 chr7:100015117-100016484
# 3 chr7:100003749-100004855 chr7:100025722-100026708
# 4 chr7:100003749-100004855 chr7:100027394-100028542
# 5 chr7:100003749-100004855 chr7:100038436-100039235
# 6 chr7:100003749-100004855 chr7:100041644-100042549
#
# Chromosome: chr8
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr8.tsv.gz
# Data shape:
#  51212260 2
#                         V1                       V2
# 1 chr8:100054972-100055592 chr8:100054972-100055592
# 2 chr8:100054972-100055592 chr8:100103870-100104273
# 3 chr8:100054972-100055592 chr8:100105753-100106594
# 4 chr8:100054972-100055592 chr8:100108604-100109329
# 5 chr8:100054972-100055592 chr8:100129973-100130492
# 6 chr8:100054972-100055592 chr8:100136632-100137321
#
# Chromosome: chr9
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr9.tsv.gz
# Data shape:
#  35099631 2
#                         V1                       V2
# 1 chr9:100003623-100004574 chr9:100003623-100004574
# 2 chr9:100003623-100004574 chr9:100011219-100011457
# 3 chr9:100003623-100004574 chr9:100027836-100028736
# 4 chr9:100003623-100004574 chr9:100029702-100031045
# 5 chr9:100003623-100004574 chr9:100033889-100034489
# 6 chr9:100003623-100004574 chr9:100036624-100037747
#
# Chromosome: chrX
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chrX.tsv.gz
# Data shape:
#  8881005 2
#                       V1                       V2
# 1 chrX:10014456-10015536   chrX:10014456-10015536
# 2 chrX:10014456-10015536   chrX:10047006-10047716
# 3 chrX:10014456-10015536 chrX:100649726-100650005
# 4 chrX:10014456-10015536 chrX:100670968-100671799
# 5 chrX:10014456-10015536 chrX:100674743-100675253
# 6 chrX:10014456-10015536 chrX:100685652-100686154

# %%
folders = c(
    "hic_intact_K562_ENCSR479XDG",
    "hic_intact_K562_deep"
)

lst = lst_peak_comb2
for (idn in names(lst)){
    ### Show progress
    cat("Chromosome:", idn, "\n")
    flush.console()
    
    ### change column name
    dat = lst[[idn]]
    colnames(dat) = c("Region1", "Region2")
    dat_peak_pair_tsv = dat
    
    ### Show progress
    print(head(dat))
    cat(dim(dat), "\n")
    cat("\n")
    flush.console()
    
    ### Save results
    for (folder in folders){
        ### set file direcotyr
        fdiry = file.path(FD_RES, "results", folder, "coverage_astarrseq_peak_macs_input")
        
        ### save in table format
        fname = paste("region_pair", idn, "tsv.gz", sep=".")
        fpath = file.path(fdiry, fname)
        write_tsv(dat_peak_pair_tsv, fpath)
        
        cat("Save results:\n", fpath, "\n")
        cat("\n")
    }
}
# Out:
# Chromosome: chr1
#                    Region1                  Region2
# 1 chr1:100006256-100006880 chr1:100006256-100006880
# 2 chr1:100006256-100006880 chr1:100010437-100010915
# 3 chr1:100006256-100006880 chr1:100021298-100021629
# 4 chr1:100006256-100006880 chr1:100023727-100023976
# 5 chr1:100006256-100006880 chr1:100027983-100029702
# 6 chr1:100006256-100006880 chr1:100036871-100039191
# 466177845 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chr1.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr1.tsv.gz
#
# Chromosome: chr10
#                     Region1                   Region2
# 1 chr10:100009096-100010466 chr10:100009096-100010466
# 2 chr10:100009096-100010466 chr10:100020710-100021134
# 3 chr10:100009096-100010466 chr10:100045961-100046653
# 4 chr10:100009096-100010466 chr10:100065094-100065486
# 5 chr10:100009096-100010466 chr10:100081317-100081607
# 6 chr10:100009096-100010466 chr10:100095324-100095660
# 64962901 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chr10.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr10.tsv.gz
#
# Chromosome: chr11
#                 Region1                   Region2
# 1 chr11:1002205-1002620     chr11:1002205-1002620
# 2 chr11:1002205-1002620 chr11:100285883-100286264
# 3 chr11:1002205-1002620 chr11:100451963-100452380
# 4 chr11:1002205-1002620 chr11:100547023-100547250
# 5 chr11:1002205-1002620 chr11:100563051-100563718
# 6 chr11:1002205-1002620 chr11:100602670-100604359
# 72126055 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chr11.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr11.tsv.gz
#
# Chromosome: chr12
#                     Region1                   Region2
# 1 chr12:100010891-100011499 chr12:100010891-100011499
# 2 chr12:100010891-100011499 chr12:100020522-100021180
# 3 chr12:100010891-100011499 chr12:100024779-100025313
# 4 chr12:100010891-100011499 chr12:100042691-100043104
# 5 chr12:100010891-100011499 chr12:100043417-100045340
# 6 chr12:100010891-100011499 chr12:100058602-100058961
# 57518175 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chr12.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr12.tsv.gz
#
# Chromosome: chr13
#                     Region1                   Region2
# 1 chr13:100001853-100002103 chr13:100001853-100002103
# 2 chr13:100001853-100002103 chr13:100020062-100020336
# 3 chr13:100001853-100002103 chr13:100088363-100089884
# 4 chr13:100001853-100002103 chr13:100098363-100098772
# 5 chr13:100001853-100002103 chr13:100132067-100132392
# 6 chr13:100001853-100002103 chr13:100223737-100224595
# 6754650 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chr13.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr13.tsv.gz
#
# Chromosome: chr14
#                     Region1                   Region2
# 1 chr14:100009223-100010688 chr14:100009223-100010688
# 2 chr14:100009223-100010688 chr14:100015169-100016031
# 3 chr14:100009223-100010688 chr14:100017586-100019888
# 4 chr14:100009223-100010688 chr14:100022743-100023106
# 5 chr14:100009223-100010688 chr14:100024408-100025872
# 6 chr14:100009223-100010688 chr14:100044478-100045787
# 9620691 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.ch
tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr7.tsv.gz
#
# Chromosome: chr8
#                    Region1                  Region2
# 1 chr8:100054972-100055592 chr8:100054972-100055592
# 2 chr8:100054972-100055592 chr8:100103870-100104273
# 3 chr8:100054972-100055592 chr8:100105753-100106594
# 4 chr8:100054972-100055592 chr8:100108604-100109329
# 5 chr8:100054972-100055592 chr8:100129973-100130492
# 6 chr8:100054972-100055592 chr8:100136632-100137321
# 51212260 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chr8.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr8.tsv.gz
#
# Chromosome: chr9
#                    Region1                  Region2
# 1 chr9:100003623-100004574 chr9:100003623-100004574
# 2 chr9:100003623-100004574 chr9:100011219-100011457
# 3 chr9:100003623-100004574 chr9:100027836-100028736
# 4 chr9:100003623-100004574 chr9:100029702-100031045
# 5 chr9:100003623-100004574 chr9:100033889-100034489
# 6 chr9:100003623-100004574 chr9:100036624-100037747
# 35099631 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chr9.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr9.tsv.gz
#
# Chromosome: chrX
#                  Region1                  Region2
# 1 chrX:10014456-10015536   chrX:10014456-10015536
# 2 chrX:10014456-10015536   chrX:10047006-10047716
# 3 chrX:10014456-10015536 chrX:100649726-100650005
# 4 chrX:10014456-10015536 chrX:100670968-100671799
# 5 chrX:10014456-10015536 chrX:100674743-100675253
# 6 chrX:10014456-10015536 chrX:100685652-100686154
# 8881005 2
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_ENCSR479XDG/coverage_astarrseq_peak_macs_input/region_pair.chrX.tsv.gz
#
# Save results:
#  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chrX.tsv.gz

# %% [markdown]
# ```
# folders = c(
#     "hic_intact_K562_ENCSR479XDG",
#     "hic_intact_K562_deep"
# )
#
# lst = lst_peak_comb2
# for (idn in names(lst)){
#     ### Show progress
#     cat("Chromosome:", idn, "\n")
#     flush.console()
#
#     ### change column name
#     dat = lst[[idn]]
#     colnames(dat) = c("Region1", "Region2")
#     dat_peak_pair_tsv = dat
#
#     ### Show progress
#     print(head(dat))
#     cat(dim(dat), "\n")
#     cat("\n")
#     flush.console()
#
#     ### split the regions into bedpe format
#     dat = dat %>%
#         dplyr::mutate(Name = paste(Region1, Region2, sep="|")) %>%
#         tidyr::separate(Region1, c("Chrom1", "Start1", "End1"), sep = "[:-]") %>%
#         tidyr::separate(Region2, c("Chrom2", "Start2", "End2"), sep = "[:-]") %>%
#         dplyr::select(Chrom1, Start1, End1, Chrom2, Start2, End2, Name)
#     dat_peak_pair_bedpe = dat
#
#     ### Show progress
#     print(head(dat))
#     cat(dim(dat), "\n")
#     cat("\n")
#     flush.console()
#
#     ### Save results
#     for (folder in folders){
#         ### set file direcotyr
#         fdiry = file.path(FD_RES, "results", folder, "coverage_astarrseq_peak_macs_input")
#
#         ### save in table format
#         fname = paste("region_pair", idn, "tsv", sep=".")
#         fpath = file.path(fdiry, fname)
#         write_tsv(dat_peak_pair_tsv, fpath)
#
#         cat("Save results:\n", fpath, "\n")
#         cat("\n")
#
#         ### save in bedpe format
#         fname = paste("region_pair", idn, "bedpe.gz", sep=".")
#         fpath = file.path(fdiry, fname)
#         write_tsv(dat_peak_pair_bedpe, fpath, col_names=FALSE)
#
#         cat("Save results:\n", fpath, "\n")
#         cat("\n")
#     }
# }
# ```
