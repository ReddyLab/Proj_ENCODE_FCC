# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## Set script

# %%
cat > run_converage_region_pair_score.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### set I/O
source ../config/config_duke.sh
FP_HIC=$1
FP_INP=$2
FP_OUT=$3

TXT_CHROMOSOME=$4    # chr11
TXT_NORMALIZATION=$5 # 'RU'
VAL_RESOLUTION=$6    # 100

### show I/O file
echo "Input: " ${FP_INP}
echo
echo "show first few lines of input"
zcat ${FP_INP} | head -5
echo

### execute
RUN_SING=${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh

${RUN_SING} python run_coverage_region_pair_score.py \
    --fpath_hic ${FP_HIC} \
    --fpath_inp ${FP_INP} \
    --fpath_out ${FP_OUT} \
    --chromosome    ${TXT_CHROMOSOME}    \
    --normalization ${TXT_NORMALIZATION} \
    --resolution    ${VAL_RESOLUTION}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
zcat ${FP_OUT} | head -5
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"
EOF

chmod +x run_converage_region_pair_score.sh

# %%
cat > run_coverage_region_pair_score.py << 'EOF'
### Set environment
import numpy as np
import itertools as it
import functools
import os, sys, gzip
import argparse
import hicstraw
import re

print = functools.partial(print, flush=True)

### Parse arguments and set global variables
parser = argparse.ArgumentParser()
parser.add_argument('--fpath_hic',     type=str, required=True)
parser.add_argument('--fpath_inp',     type=str, required=True)
parser.add_argument('--fpath_out',     type=str, required=True)
parser.add_argument('--normalization', type=str, required=True)
parser.add_argument('--resolution',    type=int, required=True)
parser.add_argument('--chromosome',    type=str, required=True)

args = parser.parse_args()
FP_HIC=args.fpath_hic
FP_INP=args.fpath_inp
FP_OUT=args.fpath_out

TXT_CHROMOSOME    = args.chromosome
TXT_NORMALIZATION = args.normalization
VAL_RESOLUTION    = args.resolution

### Import data: Hi-C
hic = hicstraw.HiCFile(FP_HIC)
mat_object = hic.getMatrixZoomData(
    TXT_CHROMOSOME, 
    TXT_CHROMOSOME, 
    "observed", 
    TXT_NORMALIZATION, 
    "BP", 
    VAL_RESOLUTION)

### Read data and write results to output file
with gzip.open(FP_INP,'rt') as finp, gzip.open(FP_OUT,'wt') as fout:
    
    ### set read lines
    #lines_inp = it.islice(finp, 30)
    lines_inp = finp
    
    ### progress each line
    for line_idx, line_inp in enumerate(lines_inp):
    
        ### parse info
        line_inp = line_inp.strip()
        txt_chrom1, val_start1, val_end1, txt_chrom2, val_start2, val_end2 = re.split(":|-|\t", line_inp)
        
        ### show progress
        if (line_idx % 1_000_000) == 0:
            print("Process Line:", line_idx)
        
        ### get hic matrix
        mat_numpy = mat_object.getRecordsAsMatrix(
            int(val_start1),
            int(val_end1),
            int(val_start2),
            int(val_end2)
        )
        
        ### get nonzero submatrix of hic
        idx_nonzero  = np.nonzero(mat_numpy)
        mat_nonzero  = mat_numpy[idx_nonzero]
        is_not_empty = np.any(mat_nonzero)
        
        ### calculate descriptive stats on nonzero values
        if(is_not_empty):
            ### calculate values
            lst = [
                np.mean(mat_nonzero),
                np.std(mat_nonzero),
                np.quantile(mat_nonzero, 0.25),
                np.quantile(mat_nonzero, 0.5),
                np.quantile(mat_nonzero, 0.75),
                np.min(mat_nonzero),
                np.max(mat_nonzero),
                mat_nonzero.flatten().shape[0]/mat_numpy.flatten().shape[0]
            ]
            ### round values
            fun = lambda x: np.round(x, decimals = 5)
            lst = list(map(fun, lst))
            
            ### concatenate results into line for output file
            txt_scores = "\t".join(map(str, lst))
            txt_name   = "|".join( map(str, line_inp.split()))
            txt_loc    = "\t".join([
                txt_chrom1, val_start1, val_end1, 
                txt_chrom2, val_start2, val_end2])
            
            line_out = "\t".join([txt_loc, txt_name, txt_scores])
            line_out = line_out + "\n"
            fout.write(line_out)
EOF

# %% [markdown]
# ```
# TXT_CHROM=chr1
# TXT_NORMALIZATION='RU'
# VAL_RESOLUTION=100
#
# FP_HIC=${FD_RES}/source/hic_intact_K562_deep/inter.hic
# FD_INP=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair
# FN_INP=region_pair.${TXT_CHROM}.tsv.gz
# FP_INP=${FD_INP}/${FN_INP}
#
# FD_OUT=${FD_RES}/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input
# FN_OUT=${FN_INP}
# FP_OUT=${FD_OUT}/${FN_OUT}
#
# RUN_SING=${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh
# ${RUN_SING} python run_coverage_region_pair_score.py \
#     --fpath_hic ${FP_HIC} \
#     --fpath_inp ${FP_INP} \
#     --fpath_out ${FP_OUT} \
#     --chromosome    ${TXT_CHROM} \
#     --normalization ${TXT_NORMALIZATION}  \
#     --resolution    ${VAL_RESOLUTION}
#
# Process Line: 0
# Process Line: 10
# Process Line: 20
# ```

# %%
FD_INP=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair
FP_INPS=($(ls ${FD_INP}/region_pair*chr*tsv.gz))
basename -a ${FP_INPS[@]}
# Out:
# region_pair.chr10.tsv.gz
# region_pair.chr11.tsv.gz
# region_pair.chr12.tsv.gz
# region_pair.chr13.tsv.gz
# region_pair.chr14.tsv.gz
# region_pair.chr15.tsv.gz
# region_pair.chr16.tsv.gz
# region_pair.chr17.tsv.gz
# region_pair.chr18.tsv.gz
# region_pair.chr19.tsv.gz
# region_pair.chr1.tsv.gz
# region_pair.chr20.tsv.gz
# region_pair.chr21.tsv.gz
# region_pair.chr22.tsv.gz
# region_pair.chr2.tsv.gz
# region_pair.chr3.tsv.gz
# region_pair.chr4.tsv.gz
# region_pair.chr5.tsv.gz
# region_pair.chr6.tsv.gz
# region_pair.chr7.tsv.gz
# region_pair.chr8.tsv.gz
# region_pair.chr9.tsv.gz
# region_pair.chrX.tsv.gz

# %%
FOLDER=hic_intact_K562_deep
FP_HIC=${FD_RES}/source/${FOLDER}/inter.hic
FD_INP=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair
FD_OUT=${FD_RES}/results/${FOLDER}/coverage_astarrseq_peak_macs_input

TXT_NORMALIZATION='RU'
VAL_RESOLUTION=100

VAL_CHROMS=($(seq 1 22) X)
for VAL_CHROM in ${VAL_CHROMS[@]}; do
    TXT_CHROMOSOME="chr${VAL_CHROM}"
    
    FN_INP=region_pair.${TXT_CHROMOSOME}.tsv.gz
    FN_OUT=${FN_INP}
    FN_LOG=coverage.${FOLDER}.region_pair.${TXT_CHROMOSOME}.%a.txt
    
    FP_INP=${FD_INP}/${FN_INP}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "Chromosome:" ${TXT_CHROMOSOME}
    echo
    echo "FP_HIC:"  ${FP_HIC}
    echo "FP_INP:"  ${FP_INP}
    echo "FP_OUT:"  ${FP_OUT}
    echo
    echo "FP_LOG:" '${FD_LOG}'/${FN_LOG/\%a/0}
    echo
    
    sbatch -p ${NODE} \
        --exclude dl-01 \
        --cpus-per-task 8 \
        --mem 30G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        run_converage_region_pair_score.sh \
            ${FP_HIC} ${FP_INP} ${FP_OUT} \
            ${TXT_CHROMOSOME} \
            ${TXT_NORMALIZATION} \
            ${VAL_RESOLUTION}
    echo
done
# Out:
# Chromosome: chr1
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr1.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr1.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr1.0.txt
#
# Submitted batch job 30033010
#
# Chromosome: chr2
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr2.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr2.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr2.0.txt
#
# Submitted batch job 30033011
#
# Chromosome: chr3
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr3.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr3.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr3.0.txt
#
# Submitted batch job 30033012
#
# Chromosome: chr4
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr4.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr4.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr4.0.txt
#
# Submitted batch job 30033013
#
# Chromosome: chr5
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr5.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr5.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr5.0.txt
#
# Submitted batch job 30033014
#
# Chromosome: chr6
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr6.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr6.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr6.0.txt
#
# Submitted batch job 30033015
#
# Chromosome: chr7
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr7.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr7.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr7.0.txt
#
# Submitted batch job 30033016
#
# Chromosome: chr8
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr8.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr8.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr8.0.txt
#
# Submitted batch job 30033017
#
# Chromosome: chr9
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr9.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr9.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr9.0.txt
#
# Submitted batch job 30033018
#
# Chromosome: chr10
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr10.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr10.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr10.0.txt
#
# Submitted batch job 30033019
#
# Chromosome: chr11
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr11.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr11.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr11.0.txt
#
# Submitted batch job 30033020
#
# Chromosome: chr12
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr12.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr12.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr12.0.txt
#
# Submitted batch job 30033021
#
# Chromosome: chr13
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr13.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr13.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr13.0.txt
#
# Submitted batch job 30033022
#
# Chromosome: chr14
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr14.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr14.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr14.0.txt
#
# Submitted batch job 30033023
#
# Chromosome: chr15
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr15.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr15.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr15.0.txt
#
# Submitted batch job 30033024
#
# Chromosome: chr16
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr16.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr16.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr16.0.txt
#
# Submitted batch job 30033025
#
# Chromosome: chr17
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr17.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr17.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr17.0.txt
#
# Submitted batch job 30033026
#
# Chromosome: chr18
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr18.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr18.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr18.0.txt
#
# Submitted batch job 30033027
#
# Chromosome: chr19
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr19.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr19.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr19.0.txt
#
# Submitted batch job 30033028
#
# Chromosome: chr20
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr20.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr20.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr20.0.txt
#
# Submitted batch job 30033029
#
# Chromosome: chr21
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr21.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr21.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr21.0.txt
#
# Submitted batch job 30033030
#
# Chromosome: chr22
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr22.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr22.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr22.0.txt
#
# Submitted batch job 30033031
#
# Chromosome: chrX
#
# FP_HIC: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/hic_intact_K562_deep/inter.hic
# FP_INP: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chrX.tsv.gz
# FP_OUT: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chrX.tsv.gz
#
# FP_LOG: ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chrX.0.txt
#
# Submitted batch job 30033032

# %% [markdown]
# **Check results**

# %%
echo ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr1.0.txt
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage.hic_intact_K562_deep.region_pair.chr1.0.txt

# %%
cat ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr1.0.txt
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-30-23+12:58:21
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr1.tsv.gz
#
# show first few lines of input
# chr1:100006256-100006880	chr1:100006256-100006880
# chr1:100006256-100006880	chr1:100010437-100010915
# chr1:100006256-100006880	chr1:100021298-100021629
# chr1:100006256-100006880	chr1:100023727-100023976
# chr1:100006256-100006880	chr1:100027983-100029702
#
# Process Line: 0
# Process Line: 10
# Process Line: 20
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr1.tsv.gz
#
# show first few lines of output:
# chr1	100006256	100006880	chr1	100006256	100006880	chr1:100006256-100006880|chr1:100006256-100006880	31.159	21.927	14.695	23.761	49.848	6.932	82.802	0.735
# chr1	100006256	100006880	chr1	100010437	100010915	chr1:100006256-100006880|chr1:100010437-100010915	1.595	0.785	1.077	1.318	1.591	0.862	3.851	0.405
# chr1	100006256	100006880	chr1	100021298	100021629	chr1:100006256-100006880|chr1:100021298-100021629	1.659	0.0	1.659	1.659	1.659	1.659	1.659	0.029
# chr1	100006256	100006880	chr1	100023727	100023976	chr1:100006256-100006880|chr1:100023727-100023976	3.951	0.0	3.951	3.951	3.951	3.951	3.951	0.048
# chr1	100006256	100006880	chr1	100027983	100029702	chr1:100006256-100006880|chr1:100027983-100029702	1.301	0.305	1.102	1.284	1.526	0.828	1.788	0.075
#
#
# Done!
# Run Time: 7 seconds

# %%
cat ${FD_LOG}/coverage.hic_intact_K562_deep.region_pair.chr2.0.txt
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-30-23+12:58:21
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/region_pair/region_pair.chr2.tsv.gz
#
# show first few lines of input
# chr2:100047054-100047450	chr2:100047054-100047450
# chr2:100047054-100047450	chr2:100104939-100105313
# chr2:100047054-100047450	chr2:100177831-100178695
# chr2:100047054-100047450	chr2:100179842-100180130
# chr2:100047054-100047450	chr2:100197644-100198321
#
# Process Line: 0
# Process Line: 10
# Process Line: 20
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/hic_intact_K562_deep/coverage_astarrseq_peak_macs_input/region_pair.chr2.tsv.gz
#
# show first few lines of output:
# chr2	100047054	100047450	chr2	100047054	100047450	chr2:100047054-100047450|chr2:100047054-100047450	13.416	5.405	8.732	13.341	15.215	5.83	23.01	0.64
# chr2	100047054	100047450	chr2	100177831	100178695	chr2:100047054-100047450|chr2:100177831-100178695	0.564	0.344	0.392	0.564	0.736	0.219	0.908	0.044
# chr2	100047054	100047450	chr2	100197644	100198321	chr2:100047054-100047450|chr2:100197644-100198321	0.6	0.0	0.6	0.6	0.6	0.6	0.6	0.025
# chr2	100047054	100047450	chr2	100235155	100235718	chr2:100047054-100047450|chr2:100235155-100235718	1.275	0.194	1.177	1.275	1.372	1.08	1.469	0.057
# chr2	100047054	100047450	chr2	100238605	100239024	chr2:100047054-100047450|chr2:100238605-100239024	0.866	0.0	0.866	0.866	0.866	0.866	0.866	0.04
#
#
# Done!
# Run Time: 6 seconds
