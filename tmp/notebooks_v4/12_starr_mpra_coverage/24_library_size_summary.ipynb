# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## Helper function

# %%
get_group  = function(fpath){return(str_extract(fpath, "Input|Output"))}
get_sample = function(fpath){return(str_extract(fpath, "Input.rep\\d|Input.mean|Output.rep\\d|Output.mean"))}
get_prefix = function(fpath){return(str_extract(fpath, "^[^\\.]*"))}

get_type   = function(fpath){
    res = ifelse(
        str_detect(fpath, "norm"),
        "norm",
        "raw"
    )
    return(res)
}

get_genome   = function(fpath){
    res = ifelse(
        str_detect(fpath, "hg19"),
        "hg19",
        "hg38"
    )
    return(res)
}

# %% [markdown]
# ## Summarize information of library size for each assay

# %%
### init
ASSAYS=c("KS91_K562_ASTARRseq", "A001_K562_WSTARRseq", "Tewhey_K562_TileMPRA")
cnames = c("FName", "Size")
ctypes = c(col_character(), col_double())

### loop through each assay
for (assay in ASSAYS) {
    
    ### set file path
    fdiry = file.path(FD_RES, "results", assay, "coverage", "summary")
    fname = "library_size_count.csv"
    fpath = file.path(fdiry, fname)
    
    ### import and add additional information
    dat_lib = read_csv(fpath, col_names = cnames, col_types = ctypes)
    dat_lib = dat_lib %>% 
        dplyr::mutate(
            Prefix = get_prefix(FName),
            Group  = get_group(FName),
            Sample = get_sample(FName),
            Type   = get_type(FName),
            Genome = get_genome(FName)
        ) %>%
        dplyr::select(FName, Size, Prefix, Sample, Group, Type, Genome)
    
    ### store table
    fname = "library_size_summary.tsv"
    fpath = file.path(fdiry, fname)
    write_tsv(dat_lib, fpath)
    
    ### create sorted version without header for bash join command
    dat_lib = dat_lib %>% arrange(FName)
    
    fname = "library_size_summary_sorted_no_cnames.tsv"
    fpath = file.path(fdiry, fname)
    write_tsv(dat_lib, fpath, col_names = FALSE)
    
    ### show progress
    print(assay)
    print(dat_lib)
    cat("++++++++++++++++++++++++++\n")

}
# Out:
# [1] "KS91_K562_ASTARRseq"
# # A tibble: 10 × 7
#    FName                                   Size Prefix Sample Group Type  Genome
#    <chr>                                  <dbl> <chr>  <chr>  <chr> <chr> <chr>
#  1 KS91_K562_ASTARRseq.Input.rep1.WGS.u… 3.49e8 KS91_… Input… Input raw   hg38
#  2 KS91_K562_ASTARRseq.Input.rep2.WGS.u… 4.51e8 KS91_… Input… Input raw   hg38
#  3 KS91_K562_ASTARRseq.Input.rep3.WGS.u… 4.88e8 KS91_… Input… Input raw   hg38
#  4 KS91_K562_ASTARRseq.Input.rep4.WGS.u… 4.56e8 KS91_… Input… Input raw   hg38
#  5 KS91_K562_ASTARRseq.Input.rep5.WGS.u… 4.44e8 KS91_… Input… Input raw   hg38
#  6 KS91_K562_ASTARRseq.Input.rep6.WGS.u… 3.97e8 KS91_… Input… Input raw   hg38
#  7 KS91_K562_ASTARRseq.Output.rep1.WGS.… 4.41e7 KS91_… Outpu… Outp… raw   hg38
#  8 KS91_K562_ASTARRseq.Output.rep2.WGS.… 9.75e7 KS91_… Outpu… Outp… raw   hg38
#  9 KS91_K562_ASTARRseq.Output.rep3.WGS.… 8.41e7 KS91_… Outpu… Outp… raw   hg38
# 10 KS91_K562_ASTARRseq.Output.rep4.WGS.… 1.83e8 KS91_… Outpu… Outp… raw   hg38
# ++++++++++++++++++++++++++
# [1] "A001_K562_WSTARRseq"
# # A tibble: 7 × 7
#   FName                                    Size Prefix Sample Group Type  Genome
#   <chr>                                   <dbl> <chr>  <chr>  <chr> <chr> <chr>
# 1 A001_K562_WSTARRseq.Input.rep1.WGS.un… 2.69e7 A001_… Input… Input raw   hg38
# 2 A001_K562_WSTARRseq.Input.rep2.WGS.un… 9.99e7 A001_… Input… Input raw   hg38
# 3 A001_K562_WSTARRseq.Input.rep3.WGS.un… 1.06e8 A001_… Input… Input raw   hg38
# 4 A001_K562_WSTARRseq.Input.rep4.WGS.un… 1.09e8 A001_… Input… Input raw   hg38
# 5 A001_K562_WSTARRseq.Output.rep1.WGS.u… 1.60e8 A001_… Outpu… Outp… raw   hg38
# 6 A001_K562_WSTARRseq.Output.rep2.WGS.u… 1.57e8 A001_… Outpu… Outp… raw   hg38
# 7 A001_K562_WSTARRseq.Output.rep3.WGS.u… 3.28e8 A001_… Outpu… Outp… raw   hg38
# ++++++++++++++++++++++++++
# [1] "Tewhey_K562_TileMPRA"
# # A tibble: 70 × 7
#    FName                                   Size Prefix Sample Group Type  Genome
#    <chr>                                  <dbl> <chr>  <chr>  <chr> <chr> <chr>
#  1 OL13_20220512.hg19.norm.Input.rep1.s… 6.42e6 OL13_… Input… Input norm  hg19
#  2 OL13_20220512.hg19.norm.Input.rep2.s… 6.41e6 OL13_… Input… Input norm  hg19
#  3 OL13_20220512.hg19.norm.Input.rep3.s… 6.41e6 OL13_… Input… Input norm  hg19
#  4 OL13_20220512.hg19.norm.Input.rep4.s… 6.41e6 OL13_… Input… Input norm  hg19
#  5 OL13_20220512.hg19.norm.Output.rep1.… 2.42e7 OL13_… Outpu… Outp… norm  hg19
#  6 OL13_20220512.hg19.norm.Output.rep2.… 2.20e7 OL13_… Outpu… Outp… norm  hg19
#  7 OL13_20220512.hg19.norm.Output.rep3.… 2.08e7 OL13_… Outpu… Outp… norm  hg19
#  8 OL13_20220512.hg19.norm.Output.rep4.… 1.92e7 OL13_… Outpu… Outp… norm  hg19
#  9 OL13_20220512.hg19.raw.Input.rep1.st… 1.17e7 OL13_… Input… Input raw   hg19
# 10 OL13_20220512.hg19.raw.Input.rep2.st… 6.54e6 OL13_… Input… Input raw   hg19
# # … with 60 more rows
# ++++++++++++++++++++++++++

# %%
dat_lib
# Out:
#    FName                                                Size      Prefix
# 1  OL13_20220512.hg19.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 2  OL13_20220512.hg19.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 3  OL13_20220512.hg19.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 4  OL13_20220512.hg19.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 5  OL13_20220512.hg19.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 6  OL13_20220512.hg19.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 7  OL13_20220512.hg19.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 8  OL13_20220512.hg19.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 9  OL13_20220512.hg19.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 10 OL13_20220512.hg19.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 11 OL13_20220512.hg19.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 12 OL13_20220512.hg19.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 13 OL13_20220512.hg19.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 14 OL13_20220512.hg19.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# 15 OL13_20220512.hg19.raw.Output.rep3.stranded_pos.bed  16323839  OL13_20220512
# 16 OL13_20220512.hg19.raw.Output.rep4.stranded_pos.bed  15755240  OL13_20220512
# 17 OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 18 OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 19 OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 20 OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 21 OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 22 OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 23 OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 24 OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 25 OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 26 OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 27 OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 28 OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 29 OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 30 OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# ⋮  ⋮                                                    ⋮         ⋮
# 41 OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed 114646887 OL43_20221003
# 42 OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed 130086009 OL43_20221003
# 43 OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed 120461487 OL43_20221003
# 44 OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed    67808075 OL43_20221003
# 45 OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed    76561739 OL43_20221003
# 46 OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed    71168558 OL43_20221003
# 47 OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed    72593861 OL43_20221003
# 48 OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed    35160045 OL43_20221003
# 49 OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed    35230272 OL43_20221003
# 50 OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed   85916775 OL43_20221003
# 51 OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed   64383745 OL43_20221003
# 52 OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed  106218676 OL43_20221003
# 53 OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed   75440322 OL43_20221003
# 54 OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed   85257860 OL43_20221003
# 55 OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed   42577629 OL45_20220927
# 56 OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed   42657457 OL45_20220927
# 57 OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed   42746400 OL45_20220927
# 58 OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed   42740318 OL45_20220927
# 59 OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed  94286600 OL45_20220927
# 60 OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed  96442408 OL45_20220927
# 61 OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed  99043384 OL45_20220927
# 62 OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed  96478668 OL45_20220927
# 63 OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed    57835964 OL45_20220927
# 64 OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed    49098092 OL45_20220927
# 65 OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed    50494539 OL45_20220927
# 66 OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed    49646312 OL45_20220927
# 67 OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed   76571038 OL45_20220927
# 68 OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed   64193541 OL45_20220927
# 69 OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed   58531500 OL45_20220927
# 70 OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed   86396781 OL45_20220927
#    Sample      Group  Type Genome
# 1  Input.rep1  Input  norm hg19
# 2  Input.rep2  Input  norm hg19
# 3  Input.rep3  Input  norm hg19
# 4  Input.rep4  Input  norm hg19
# 5  Output.rep1 Output norm hg19
# 6  Output.rep2 Output norm hg19
# 7  Output.rep3 Output norm hg19
# 8  Output.rep4 Output norm hg19
# 9  Input.rep1  Input  raw  hg19
# 10 Input.rep2  Input  raw  hg19
# 11 Input.rep3  Input  raw  hg19
# 12 Input.rep4  Input  raw  hg19
# 13 Output.rep1 Output raw  hg19
# 14 Output.rep2 Output raw  hg19
# 15 Output.rep3 Output raw  hg19
# 16 Output.rep4 Output raw  hg19
# 17 Input.rep1  Input  norm hg38
# 18 Input.rep2  Input  norm hg38
# 19 Input.rep3  Input  norm hg38
# 20 Input.rep4  Input  norm hg38
# 21 Output.rep1 Output norm hg38
# 22 Output.rep2 Output norm hg38
# 23 Output.rep3 Output norm hg38
# 24 Output.rep4 Output norm hg38
# 25 Input.rep1  Input  raw  hg38
# 26 Input.rep2  Input  raw  hg38
# 27 Input.rep3  Input  raw  hg38
# 28 Input.rep4  Input  raw  hg38
# 29 Output.rep1 Output raw  hg38
# 30 Output.rep2 Output raw  hg38
# ⋮  ⋮           ⋮      ⋮    ⋮
# 41 Output.rep3 Output norm hg38
# 42 Output.rep4 Output norm hg38
# 43 Output.rep5 Output norm hg38
# 44 Input.rep1  Input  raw  hg38
# 45 Input.rep2  Input  raw  hg38
# 46 Input.rep3  Input  raw  hg38
# 47 Input.rep4  Input  raw  hg38
# 48 Input.rep5  Input  raw  hg38
# 49 Input.rep6  Input  raw  hg38
# 50 Output.rep1 Output raw  hg38
# 51 Output.rep2 Output raw  hg38
# 52 Output.rep3 Output raw  hg38
# 53 Output.rep4 Output raw  hg38
# 54 Output.rep5 Output raw  hg38
# 55 Input.rep1  Input  norm hg38
# 56 Input.rep2  Input  norm hg38
# 57 Input.rep3  Input  norm hg38
# 58 Input.rep4  Input  norm hg38
# 59 Output.rep1 Output norm hg38
# 60 Output.rep2 Output norm hg38
# 61 Output.rep3 Output norm hg38
# 62 Output.rep4 Output norm hg38
# 63 Input.rep1  Input  raw  hg38
# 64 Input.rep2  Input  raw  hg38
# 65 Input.rep3  Input  raw  hg38
# 66 Input.rep4  Input  raw  hg38
# 67 Output.rep1 Output raw  hg38
# 68 Output.rep2 Output raw  hg38
# 69 Output.rep3 Output raw  hg38
# 70 Output.rep4 Output raw  hg38

# %%
### set file path
fdiry = file.path(FD_RES, "results", assay, "coverage", "summary")
fname = "library_size_count.csv"
fpath = file.path(fdiry, fname)

### import and add additional information
cnames = c("FName", "Size")
ctypes = c(col_character(), col_double())
dat_lib = read_csv(fpath, col_names = cnames, col_types = ctypes)

dat_lib = dat_lib %>% 
    dplyr::mutate(
        Prefix = get_prefix(FName),
        Group  = get_group(FName),
        Sample = get_sample(FName),
        Type   = get_type(FName),
        Genome = get_genome(FName)
    )
dat_lib
# Out:
#    FName                                                 Size
# 1  KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz  348695063
# 2  KS91_K562_ASTARRseq.Input.rep2.WGS.unstranded.bed.gz  451369741
# 3  KS91_K562_ASTARRseq.Input.rep3.WGS.unstranded.bed.gz  487579055
# 4  KS91_K562_ASTARRseq.Input.rep4.WGS.unstranded.bed.gz  456246254
# 5  KS91_K562_ASTARRseq.Input.rep5.WGS.unstranded.bed.gz  444268950
# 6  KS91_K562_ASTARRseq.Input.rep6.WGS.unstranded.bed.gz  397333562
# 7  KS91_K562_ASTARRseq.Output.rep1.WGS.unstranded.bed.gz  44103844
# 8  KS91_K562_ASTARRseq.Output.rep2.WGS.unstranded.bed.gz  97471282
# 9  KS91_K562_ASTARRseq.Output.rep3.WGS.unstranded.bed.gz  84103298
# 10 KS91_K562_ASTARRseq.Output.rep4.WGS.unstranded.bed.gz 183115379
#    Prefix              Group  Sample      Type Genome
# 1  KS91_K562_ASTARRseq Input  Input.rep1  raw  hg38
# 2  KS91_K562_ASTARRseq Input  Input.rep2  raw  hg38
# 3  KS91_K562_ASTARRseq Input  Input.rep3  raw  hg38
# 4  KS91_K562_ASTARRseq Input  Input.rep4  raw  hg38
# 5  KS91_K562_ASTARRseq Input  Input.rep5  raw  hg38
# 6  KS91_K562_ASTARRseq Input  Input.rep6  raw  hg38
# 7  KS91_K562_ASTARRseq Output Output.rep1 raw  hg38
# 8  KS91_K562_ASTARRseq Output Output.rep2 raw  hg38
# 9  KS91_K562_ASTARRseq Output Output.rep3 raw  hg38
# 10 KS91_K562_ASTARRseq Output Output.rep4 raw  hg38

# %%
dat_lib %>% arrange(FName)
# Out:
#    FName                                                 Size
# 1  KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz  348695063
# 2  KS91_K562_ASTARRseq.Input.rep2.WGS.unstranded.bed.gz  451369741
# 3  KS91_K562_ASTARRseq.Input.rep3.WGS.unstranded.bed.gz  487579055
# 4  KS91_K562_ASTARRseq.Input.rep4.WGS.unstranded.bed.gz  456246254
# 5  KS91_K562_ASTARRseq.Input.rep5.WGS.unstranded.bed.gz  444268950
# 6  KS91_K562_ASTARRseq.Input.rep6.WGS.unstranded.bed.gz  397333562
# 7  KS91_K562_ASTARRseq.Output.rep1.WGS.unstranded.bed.gz  44103844
# 8  KS91_K562_ASTARRseq.Output.rep2.WGS.unstranded.bed.gz  97471282
# 9  KS91_K562_ASTARRseq.Output.rep3.WGS.unstranded.bed.gz  84103298
# 10 KS91_K562_ASTARRseq.Output.rep4.WGS.unstranded.bed.gz 183115379
#    Prefix              Group  Sample      Type Genome
# 1  KS91_K562_ASTARRseq Input  Input.rep1  raw  hg38
# 2  KS91_K562_ASTARRseq Input  Input.rep2  raw  hg38
# 3  KS91_K562_ASTARRseq Input  Input.rep3  raw  hg38
# 4  KS91_K562_ASTARRseq Input  Input.rep4  raw  hg38
# 5  KS91_K562_ASTARRseq Input  Input.rep5  raw  hg38
# 6  KS91_K562_ASTARRseq Input  Input.rep6  raw  hg38
# 7  KS91_K562_ASTARRseq Output Output.rep1 raw  hg38
# 8  KS91_K562_ASTARRseq Output Output.rep2 raw  hg38
# 9  KS91_K562_ASTARRseq Output Output.rep3 raw  hg38
# 10 KS91_K562_ASTARRseq Output Output.rep4 raw  hg38

# %%
assay = "A001_K562_WSTARRseq"

# %%
### set file path
fdiry = file.path(FD_RES, "results", assay, "coverage", "summary")
fname = "library_size_count.csv"
fpath = file.path(fdiry, fname)

### import and add additional information
cnames = c("FName", "Size")
ctypes = c(col_character(), col_double())
dat_lib = read_csv(fpath, col_names = cnames, col_types = ctypes)

dat_lib = dat_lib %>% 
    dplyr::mutate(
        Prefix = get_prefix(FName),
        Group  = get_group(FName),
        Sample = get_sample(FName),
        Type   = get_type(FName),
        Genome = get_genome(FName)
    )
dat_lib
# Out:
#   FName                                                 Size
# 1 A001_K562_WSTARRseq.Input.rep1.WGS.unstranded.bed.gz   26908970
# 2 A001_K562_WSTARRseq.Input.rep2.WGS.unstranded.bed.gz   99899775
# 3 A001_K562_WSTARRseq.Input.rep3.WGS.unstranded.bed.gz  105623984
# 4 A001_K562_WSTARRseq.Input.rep4.WGS.unstranded.bed.gz  108635002
# 5 A001_K562_WSTARRseq.Output.rep1.WGS.unstranded.bed.gz 160349140
# 6 A001_K562_WSTARRseq.Output.rep2.WGS.unstranded.bed.gz 157326312
# 7 A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz 328185275
#   Prefix              Group  Sample      Type Genome
# 1 A001_K562_WSTARRseq Input  Input.rep1  raw  hg38
# 2 A001_K562_WSTARRseq Input  Input.rep2  raw  hg38
# 3 A001_K562_WSTARRseq Input  Input.rep3  raw  hg38
# 4 A001_K562_WSTARRseq Input  Input.rep4  raw  hg38
# 5 A001_K562_WSTARRseq Output Output.rep1 raw  hg38
# 6 A001_K562_WSTARRseq Output Output.rep2 raw  hg38
# 7 A001_K562_WSTARRseq Output Output.rep3 raw  hg38

# %%
assay = "A001_K562_WSTARRseq"

# %%
### set file path
fdiry = file.path(FD_RES, "results", assay, "coverage", "summary")
fname = "library_size_count.csv"
fpath = file.path(fdiry, fname)

### import and add additional information
cnames = c("FName", "Size")
ctypes = c(col_character(), col_double())
dat_lib = read_csv(fpath, col_names = cnames, col_types = ctypes)

dat_lib = dat_lib %>% 
    dplyr::mutate(
        Prefix = get_prefix(FName),
        Group  = get_group(FName),
        Sample = get_sample(FName),
        Type   = get_type(FName),
        Genome = get_genome(FName)
    )
dat_lib
# Out:
#   FName                                                 Size
# 1 A001_K562_WSTARRseq.Input.rep1.WGS.unstranded.bed.gz   26908970
# 2 A001_K562_WSTARRseq.Input.rep2.WGS.unstranded.bed.gz   99899775
# 3 A001_K562_WSTARRseq.Input.rep3.WGS.unstranded.bed.gz  105623984
# 4 A001_K562_WSTARRseq.Input.rep4.WGS.unstranded.bed.gz  108635002
# 5 A001_K562_WSTARRseq.Output.rep1.WGS.unstranded.bed.gz 160349140
# 6 A001_K562_WSTARRseq.Output.rep2.WGS.unstranded.bed.gz 157326312
# 7 A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz  38522888
#   Prefix              Group  Sample      Type Genome
# 1 A001_K562_WSTARRseq Input  Input.rep1  raw  hg38
# 2 A001_K562_WSTARRseq Input  Input.rep2  raw  hg38
# 3 A001_K562_WSTARRseq Input  Input.rep3  raw  hg38
# 4 A001_K562_WSTARRseq Input  Input.rep4  raw  hg38
# 5 A001_K562_WSTARRseq Output Output.rep1 raw  hg38
# 6 A001_K562_WSTARRseq Output Output.rep2 raw  hg38
# 7 A001_K562_WSTARRseq Output Output.rep3 raw  hg38

# %%
assay = "Tewhey_K562_TileMPRA"

# %%
### set file path
fdiry = file.path(FD_RES, "results", assay, "coverage", "summary")
fname = "library_size_count.csv"
fpath = file.path(fdiry, fname)

### import and add additional information
cnames = c("FName", "Size")
ctypes = c(col_character(), col_double())
dat_lib = read_csv(fpath, col_names = cnames, col_types = ctypes)

dat_lib = dat_lib %>% 
    dplyr::mutate(
        Prefix = get_prefix(FName),
        Group  = get_group(FName),
        Sample = get_sample(FName),
        Type   = get_type(FName),
        Genome = get_genome(FName)
    )
dat_lib
# Out:
#    FName                                                Size      Prefix
# 1  OL13_20220512.hg19.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 2  OL13_20220512.hg19.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 3  OL13_20220512.hg19.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 4  OL13_20220512.hg19.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 5  OL13_20220512.hg19.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 6  OL13_20220512.hg19.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 7  OL13_20220512.hg19.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 8  OL13_20220512.hg19.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 9  OL13_20220512.hg19.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 10 OL13_20220512.hg19.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 11 OL13_20220512.hg19.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 12 OL13_20220512.hg19.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 13 OL13_20220512.hg19.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 14 OL13_20220512.hg19.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# 15 OL13_20220512.hg19.raw.Output.rep3.stranded_pos.bed  16323839  OL13_20220512
# 16 OL13_20220512.hg19.raw.Output.rep4.stranded_pos.bed  15755240  OL13_20220512
# 17 OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 18 OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 19 OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 20 OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 21 OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 22 OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 23 OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 24 OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 25 OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 26 OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 27 OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 28 OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 29 OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 30 OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# ⋮  ⋮                                                    ⋮         ⋮
# 41 OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed 114646887 OL13_20220512
# 42 OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed 130086009 OL13_20220512
# 43 OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed 120461487 OL13_20220512
# 44 OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed    67808075 OL13_20220512
# 45 OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed    76561739 OL13_20220512
# 46 OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed    71168558 OL13_20220512
# 47 OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed    72593861 OL13_20220512
# 48 OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed    35160045 OL13_20220512
# 49 OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed    35230272 OL13_20220512
# 50 OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed   85916775 OL13_20220512
# 51 OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed   64383745 OL13_20220512
# 52 OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed  106218676 OL13_20220512
# 53 OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed   75440322 OL13_20220512
# 54 OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed   85257860 OL13_20220512
# 55 OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed   42577629 OL13_20220512
# 56 OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed   42657457 OL13_20220512
# 57 OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed   42746400 OL13_20220512
# 58 OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed   42740318 OL13_20220512
# 59 OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed  94286600 OL13_20220512
# 60 OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed  96442408 OL13_20220512
# 61 OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed  99043384 OL13_20220512
# 62 OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed  96478668 OL13_20220512
# 63 OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed    57835964 OL13_20220512
# 64 OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed    49098092 OL13_20220512
# 65 OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed    50494539 OL13_20220512
# 66 OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed    49646312 OL13_20220512
# 67 OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed   76571038 OL13_20220512
# 68 OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed   64193541 OL13_20220512
# 69 OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed   58531500 OL13_20220512
# 70 OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed   86396781 OL13_20220512
#    Group  Sample      Type Genome
# 1  Input  Input.rep1  norm hg19
# 2  Input  Input.rep2  norm hg19
# 3  Input  Input.rep3  norm hg19
# 4  Input  Input.rep4  norm hg19
# 5  Output Output.rep1 norm hg19
# 6  Output Output.rep2 norm hg19
# 7  Output Output.rep3 norm hg19
# 8  Output Output.rep4 norm hg19
# 9  Input  Input.rep1  raw  hg19
# 10 Input  Input.rep2  raw  hg19
# 11 Input  Input.rep3  raw  hg19
# 12 Input  Input.rep4  raw  hg19
# 13 Output Output.rep1 raw  hg19
# 14 Output Output.rep2 raw  hg19
# 15 Output Output.rep3 raw  hg19
# 16 Output Output.rep4 raw  hg19
# 17 Input  Input.rep1  norm hg38
# 18 Input  Input.rep2  norm hg38
# 19 Input  Input.rep3  norm hg38
# 20 Input  Input.rep4  norm hg38
# 21 Output Output.rep1 norm hg38
# 22 Output Output.rep2 norm hg38
# 23 Output Output.rep3 norm hg38
# 24 Output Output.rep4 norm hg38
# 25 Input  Input.rep1  raw  hg38
# 26 Input  Input.rep2  raw  hg38
# 27 Input  Input.rep3  raw  hg38
# 28 Input  Input.rep4  raw  hg38
# 29 Output Output.rep1 raw  hg38
# 30 Output Output.rep2 raw  hg38
# ⋮  ⋮      ⋮           ⋮    ⋮
# 41 Output Output.rep3 norm hg38
# 42 Output Output.rep4 norm hg38
# 43 Output Output.rep5 norm hg38
# 44 Input  Input.rep1  raw  hg38
# 45 Input  Input.rep2  raw  hg38
# 46 Input  Input.rep3  raw  hg38
# 47 Input  Input.rep4  raw  hg38
# 48 Input  Input.rep5  raw  hg38
# 49 Input  Input.rep6  raw  hg38
# 50 Output Output.rep1 raw  hg38
# 51 Output Output.rep2 raw  hg38
# 52 Output Output.rep3 raw  hg38
# 53 Output Output.rep4 raw  hg38
# 54 Output Output.rep5 raw  hg38
# 55 Input  Input.rep1  norm hg38
# 56 Input  Input.rep2  norm hg38
# 57 Input  Input.rep3  norm hg38
# 58 Input  Input.rep4  norm hg38
# 59 Output Output.rep1 norm hg38
# 60 Output Output.rep2 norm hg38
# 61 Output Output.rep3 norm hg38
# 62 Output Output.rep4 norm hg38
# 63 Input  Input.rep1  raw  hg38
# 64 Input  Input.rep2  raw  hg38
# 65 Input  Input.rep3  raw  hg38
# 66 Input  Input.rep4  raw  hg38
# 67 Output Output.rep1 raw  hg38
# 68 Output Output.rep2 raw  hg38
# 69 Output Output.rep3 raw  hg38
# 70 Output Output.rep4 raw  hg38

# %%
dat_lib %>% arrange(FName)
# Out:
#    FName                                                Size      Prefix
# 1  OL13_20220512.hg19.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 2  OL13_20220512.hg19.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 3  OL13_20220512.hg19.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 4  OL13_20220512.hg19.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 5  OL13_20220512.hg19.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 6  OL13_20220512.hg19.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 7  OL13_20220512.hg19.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 8  OL13_20220512.hg19.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 9  OL13_20220512.hg19.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 10 OL13_20220512.hg19.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 11 OL13_20220512.hg19.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 12 OL13_20220512.hg19.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 13 OL13_20220512.hg19.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 14 OL13_20220512.hg19.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# 15 OL13_20220512.hg19.raw.Output.rep3.stranded_pos.bed  16323839  OL13_20220512
# 16 OL13_20220512.hg19.raw.Output.rep4.stranded_pos.bed  15755240  OL13_20220512
# 17 OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 18 OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 19 OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 20 OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 21 OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 22 OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 23 OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 24 OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 25 OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 26 OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 27 OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 28 OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 29 OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 30 OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# ⋮  ⋮                                                    ⋮         ⋮
# 41 OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed 114646887 OL13_20220512
# 42 OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed 130086009 OL13_20220512
# 43 OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed 120461487 OL13_20220512
# 44 OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed    67808075 OL13_20220512
# 45 OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed    76561739 OL13_20220512
# 46 OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed    71168558 OL13_20220512
# 47 OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed    72593861 OL13_20220512
# 48 OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed    35160045 OL13_20220512
# 49 OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed    35230272 OL13_20220512
# 50 OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed   85916775 OL13_20220512
# 51 OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed   64383745 OL13_20220512
# 52 OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed  106218676 OL13_20220512
# 53 OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed   75440322 OL13_20220512
# 54 OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed   85257860 OL13_20220512
# 55 OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed   42577629 OL13_20220512
# 56 OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed   42657457 OL13_20220512
# 57 OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed   42746400 OL13_20220512
# 58 OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed   42740318 OL13_20220512
# 59 OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed  94286600 OL13_20220512
# 60 OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed  96442408 OL13_20220512
# 61 OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed  99043384 OL13_20220512
# 62 OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed  96478668 OL13_20220512
# 63 OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed    57835964 OL13_20220512
# 64 OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed    49098092 OL13_20220512
# 65 OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed    50494539 OL13_20220512
# 66 OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed    49646312 OL13_20220512
# 67 OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed   76571038 OL13_20220512
# 68 OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed   64193541 OL13_20220512
# 69 OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed   58531500 OL13_20220512
# 70 OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed   86396781 OL13_20220512
#    Group  Sample      Type Genome
# 1  Input  Input.rep1  norm hg19
# 2  Input  Input.rep2  norm hg19
# 3  Input  Input.rep3  norm hg19
# 4  Input  Input.rep4  norm hg19
# 5  Output Output.rep1 norm hg19
# 6  Output Output.rep2 norm hg19
# 7  Output Output.rep3 norm hg19
# 8  Output Output.rep4 norm hg19
# 9  Input  Input.rep1  raw  hg19
# 10 Input  Input.rep2  raw  hg19
# 11 Input  Input.rep3  raw  hg19
# 12 Input  Input.rep4  raw  hg19
# 13 Output Output.rep1 raw  hg19
# 14 Output Output.rep2 raw  hg19
# 15 Output Output.rep3 raw  hg19
# 16 Output Output.rep4 raw  hg19
# 17 Input  Input.rep1  norm hg38
# 18 Input  Input.rep2  norm hg38
# 19 Input  Input.rep3  norm hg38
# 20 Input  Input.rep4  norm hg38
# 21 Output Output.rep1 norm hg38
# 22 Output Output.rep2 norm hg38
# 23 Output Output.rep3 norm hg38
# 24 Output Output.rep4 norm hg38
# 25 Input  Input.rep1  raw  hg38
# 26 Input  Input.rep2  raw  hg38
# 27 Input  Input.rep3  raw  hg38
# 28 Input  Input.rep4  raw  hg38
# 29 Output Output.rep1 raw  hg38
# 30 Output Output.rep2 raw  hg38
# ⋮  ⋮      ⋮           ⋮    ⋮
# 41 Output Output.rep3 norm hg38
# 42 Output Output.rep4 norm hg38
# 43 Output Output.rep5 norm hg38
# 44 Input  Input.rep1  raw  hg38
# 45 Input  Input.rep2  raw  hg38
# 46 Input  Input.rep3  raw  hg38
# 47 Input  Input.rep4  raw  hg38
# 48 Input  Input.rep5  raw  hg38
# 49 Input  Input.rep6  raw  hg38
# 50 Output Output.rep1 raw  hg38
# 51 Output Output.rep2 raw  hg38
# 52 Output Output.rep3 raw  hg38
# 53 Output Output.rep4 raw  hg38
# 54 Output Output.rep5 raw  hg38
# 55 Input  Input.rep1  norm hg38
# 56 Input  Input.rep2  norm hg38
# 57 Input  Input.rep3  norm hg38
# 58 Input  Input.rep4  norm hg38
# 59 Output Output.rep1 norm hg38
# 60 Output Output.rep2 norm hg38
# 61 Output Output.rep3 norm hg38
# 62 Output Output.rep4 norm hg38
# 63 Input  Input.rep1  raw  hg38
# 64 Input  Input.rep2  raw  hg38
# 65 Input  Input.rep3  raw  hg38
# 66 Input  Input.rep4  raw  hg38
# 67 Output Output.rep1 raw  hg38
# 68 Output Output.rep2 raw  hg38
# 69 Output Output.rep3 raw  hg38
# 70 Output Output.rep4 raw  hg38

# %%
fpath = "OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed"
unlist(str_split(fpath, "\\."))[1]
# Out:
# [1] "OL45_20220927"
