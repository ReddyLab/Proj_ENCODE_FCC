# %% [markdown]
# **Set environment**

# %%
suppressWarnings(suppressMessages(source("../config/config_sing.R")))
library(UpSetR)
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **Check data files**

# %%
fdiry = file.path(FD_RES, "results", "region", "annotation_enhancer_merge")
for (txt in dir(fdiry)){cat(txt, "\n")}
# Out:
# annotation_ccre
# description.tsv
# enhancer_merge.concat.starrmpra_crispr_atac.active.bed.gz
# enhancer_merge.concat.starrmpra_crispr_atac.active.merge.bed.gz
# enhancer_merge.concat.starrmpra_crispr_atac.active.merge.merge.bed.gz
# enhancer_merge.concat.starrmpra_crispr_atac.total.bed.gz
# enhancer_merge.concat.starrmpra_crispr_atac.total.merge.bed.gz
# enhancer_merge.concat.starrmpra_crispr_atac.total.merge.merge.bed.gz
# summary_starrmpra_crispri_atac
# tmp

# %% [markdown]
# ## Import data

# %%
fdiry = file.path(FD_RES, "results", "region", "annotation_enhancer_merge")
fname = "enhancer_merge.concat.starrmpra_crispr_atac.active.merge.bed.gz"
fpath = file.path(fdiry, fname)

cnames = c("Chrom", "Start", "End", "Assay_Type", "Assay_Label")
dat = read_tsv(fpath, col_names=cnames, show_col_types=FALSE)
dat = dat %>% 
    dplyr::mutate(Region = paste0(Chrom, ":", Start, "-", End)) %>%
    dplyr::select(Chrom, Start, End, Region, Assay_Type, Assay_Label)

dat_region_merge_import = dat
print(dim(dat))
head(dat)
# Out:
# [1] 303293      6
#   Chrom Start End   Region           Assay_Type Assay_Label
# 1 chr1  10015 10442 chr1:10015-10442 ATAC       ATAC
# 2 chr1  14253 14645 chr1:14253-14645 ATAC       ATAC
# 3 chr1  16015 16477 chr1:16015-16477 ATAC       ATAC
# 4 chr1  17237 17772 chr1:17237-17772 ATAC       ATAC
# 5 chr1  28903 29613 chr1:28903-29613 ATAC       ATAC
# 6 chr1  30803 31072 chr1:30803-31072 ATAC       ATAC

# %%
dat = dat_region_merge_import
txt = "ASTARR"
dat = dat %>% dplyr::filter(Assay_Type == txt)
table(dat$Assay_Label)
# Out:
#           ASTARR_A ASTARR_A,ASTARR_AB
#                239                 27

# %% [markdown]
# ## Arrange and summary

# %%
dat = dat_region_merge_import
for (x in unique(dat$Assay_Type))
    print(x)
# Out:
# [1] "ATAC"
# [1] "ATAC,ENCODE-E2G_Prediction"
# [1] "ATAC,WSTARR"
# [1] "LMPRA"
# [1] "ATAC,CRISPRi-Growth"
# [1] "ENCODE-E2G_Prediction"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Prediction,LMPRA"
# [1] "WSTARR"
# [1] "ATAC,ENCODE-E2G_Prediction,WSTARR"
# [1] "ATAC,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "CRISPRi-Growth"
# [1] "ATAC,LMPRA"
# [1] "ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,LMPRA,WSTARR"
# [1] "ENCODE-E2G_Prediction,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction,WSTARR"
# [1] "ASTARR,ATAC,WSTARR"
# [1] "CRISPRi-Growth,WSTARR"
# [1] "ASTARR,ATAC,LMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,WSTARR"
# [1] "LMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,LMPRA"
# [1] "ASTARR,WSTARR"
# [1] "ASTARR,ATAC"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction,LMPRA"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,LMPRA"
# [1] "ATAC,CRISPRi-Growth,LMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Benchmark,LMPRA"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction"
# [1] "ASTARR,LMPRA,WSTARR"
# [1] "ASTARR"
# [1] "ASTARR,ENCODE-E2G_Prediction"
# [1] "CRISPRi-Growth,ENCODE-E2G_Prediction"
# [1] "ASTARR,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,WSTARR"
# [1] "ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth,LMPRA,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,LMPRA"
# [1] "ASTARR,CRISPRi-Growth,ENCODE-E2G_Prediction"
# [1] "ASTARR,LMPRA"
# [1] "CRISPRi-Growth,ENCODE-E2G_Prediction,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,WSTARR"
# [1] "CRISPRi-Growth,LMPRA"
# [1] "ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,WSTARR"
# [1] "ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction"
# [1] "ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ENCODE-E2G_Prediction,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth"
# [1] "ENCODE-E2G_Benchmark,LMPRA"
# [1] "CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction"
# [1] "ASTARR,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Benchmark,LMPRA,WSTARR"
# [1] "TMPRA"
# [1] "LMPRA,TMPRA,WSTARR"
# [1] "LMPRA,TMPRA"
# [1] "TMPRA,WSTARR"
# [1] "ATAC,TMPRA"
# [1] "ATAC,LMPRA,TMPRA"
# [1] "ATAC,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ATAC,ENCODE-E2G_Prediction,TMPRA"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction,TMPRA"
# [1] "ENCODE-E2G_Prediction,TMPRA"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ATAC,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,TMPRA"
# [1] "CRISPRi-HCRFF"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ENCODE-E2G_Benchmark,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction"
# [1] "ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ATAC,TMPRA,WSTARR"
# [1] "ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ASTARR,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ENCODE-E2G_Benchmark"
# [1] "ASTARR,ATAC,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,TMPRA"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "CRISPRi-HCRFF,ENCODE-E2G_Prediction"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction"
# [1] "ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA"
# [1] "ATAC,ENCODE-E2G_Benchmark,WSTARR"
# [1] "ASTARR,CRISPRi-Growth,ENCODE-E2G_Prediction,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,LMPRA"
# [1] "ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,TMPRA"
# [1] "ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "CRISPRi-Growth,TMPRA"
# [1] "ASTARR,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ATAC,CRISPRi-Growth,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction"
# [1] "ATAC,ENCODE-E2G_Benchmark"
# [1] "CRISPRi-Growth,LMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Benchmark,LMPRA,WSTARR"
# [1] "ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,TMPRA"
# [1] "ATAC,CRISPRi-Growth,LMPRA,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,TMPRA,WSTARR"
# [1] "ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Benchmark,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction"
# [1] "ASTARR,ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction,WSTARR"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA"
# [1] "CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA,WSTARR"
# [1] "ASTARR,CRISPRi-Growth,LMPRA"
# [1] "ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,CRISPRi-HCRFF,ENCODE-E2G_Prediction,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction"
# [1] "ATAC,ENCODE-E2G_Benchmark,LMPRA,TMPRA"
# [1] "ATAC,ENCODE-E2G_Benchmark,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Prediction,TMPRA"
# [1] "CRISPRi-Growth,ENCODE-E2G_Prediction,LMPRA,TMPRA"
# [1] "ASTARR,ATAC,CRISPRi-Growth,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ASTARR,ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,TMPRA,WSTARR"
# [1] "ATAC,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR"

# %%
dat = dat_region_merge_import
dat = dat %>% tidyr::separate_longer_delim(Assay_Type, ",")

dat_region_merge_arrange = dat
print(dim(dat))
head(dat)
# Out:
# [1] 424511      6
#   Chrom Start End   Region           Assay_Type Assay_Label
# 1 chr1  10015 10442 chr1:10015-10442 ATAC       ATAC
# 2 chr1  14253 14645 chr1:14253-14645 ATAC       ATAC
# 3 chr1  16015 16477 chr1:16015-16477 ATAC       ATAC
# 4 chr1  17237 17772 chr1:17237-17772 ATAC       ATAC
# 5 chr1  28903 29613 chr1:28903-29613 ATAC       ATAC
# 6 chr1  30803 31072 chr1:30803-31072 ATAC       ATAC

# %% [markdown]
# **Check results**

# %%
vec = paste0("chr", c(1:22, "X"))
dat = dat_region_merge_arrange
dat = dat %>% dplyr::filter(Chrom %in% vec, Assay_Type == "TMPRA")
table(dat$Chrom)
# Out:
# chr11 chr16  chr2 chr20  chr8  chrX
#  2045   777   945  1125  1301  1345

# %% [markdown]
# ## Upset plot by Assay Type

# %%
dat = dat_region_merge_arrange
lst = split(dat$Region, dat$Assay_Type)

lst_region = lst
lst = lapply(lst, length)
print(lst)
# Out:
# $ASTARR
# [1] 8539
#
# $ATAC
# [1] 247249
#
# $`CRISPRi-Growth`
# [1] 6169
#
# $`CRISPRi-HCRFF`
# [1] 75
#
# $`ENCODE-E2G_Benchmark`
# [1] 381
#
# $`ENCODE-E2G_Prediction`
# [1] 45429
#
# $LMPRA
# [1] 37633
#
# $TMPRA
# [1] 7538
#
# $WSTARR
# [1] 71498

# %%
lst = lst_region

options(repr.plot.height=10, repr.plot.width=30)
upset(fromList(lst), 
      order.by = "freq", 
      nsets = 8,
      nintersects = NA,
      number.angles = 0,
      point.size = 3, 
      line.size  = 2,
      mb.ratio = c(0.6, 0.4),
      mainbar.y.label = "Regulatory regions identified", 
      sets.x.label    = "Assay Type", 
      text.scale = c(
          3, # upper barplot y axis title
          2, # upper barplot y axis text
          3, # left  barplot y axis title
          2, # left  barplot y axis text
          3, # set title
          2  # upper barplot count number
      )
)
# Out:
# plot without title

# %% [markdown]
# ## Upset plot by Assay Group (STARR / MPRA / CRISPRi / ENCODE-E2G / ATAC)

# %%
dat = dat_region_merge_arrange
dat = dat %>% 
    dplyr::mutate(
        Assay_Type = ifelse(
            str_detect(Assay_Type, "CRISPRi"),
            "CRISPRi",
            Assay_Type
        )
    ) %>%
    dplyr::mutate(
        Assay_Type = ifelse(
            str_detect(Assay_Type, "STARR"),
            "STARR",
            Assay_Type
        )
    ) %>%
    dplyr::mutate(
        Assay_Type = ifelse(
            str_detect(Assay_Type, "MPRA"),
            "MPRA",
            Assay_Type
        )
    ) %>%
    dplyr::mutate(
        Assay_Type = ifelse(
            str_detect(Assay_Type, "ENCODE-E2G"),
            "ENCODE-E2G",
            Assay_Type
        )
    )

dat_region_merge_summary = dat
table(dat$Assay_Type)
# Out:
#       ATAC    CRISPRi ENCODE-E2G       MPRA      STARR
#     247249       6244      45810      45171      80037

# %%
dat = dat_region_merge_summary
lst = split(dat$Region, dat$Assay_Type)

lst_region = lst
lst = lapply(lst, length)
print(lst)
# Out:
# $ATAC
# [1] 247249
#
# $CRISPRi
# [1] 6244
#
# $`ENCODE-E2G`
# [1] 45810
#
# $MPRA
# [1] 45171
#
# $STARR
# [1] 80037

# %%
lst = lst_region

options(repr.plot.height=10, repr.plot.width=15)
upset(fromList(lst), 
      order.by = "freq", 
      nsets = 8,
      nintersects = NA,
      number.angles = 0,
      point.size = 3, 
      line.size  = 2,
      #mb.ratio = c(0.8, 0.2),
      mainbar.y.label = "Regulatory regions identified", 
      sets.x.label    = "Assay Type", 
      text.scale = c(
          2.5, # upper barplot y axis title
          2, # upper barplot y axis text
          2, # left  barplot y axis title
          1.4, # left  barplot y axis text
          2.5, # set title
          1.2  # upper barplot count number
      )
)
# Out:
# plot without title

# %% [markdown]
# ## Percentage of ATAC in each assay

# %%
dat = dat_region_merge_arrange
lst = split(dat$Region, dat$Assay_Type)
vec = lst[["ATAC"]]

vec_txt_region_atac = vec
lst_vec_txt_region  = lst
print(names(lst))
print(length(vec))
# Out:
# [1] "ASTARR"                "ATAC"                  "CRISPRi-Growth"
# [4] "CRISPRi-HCRFF"         "ENCODE-E2G_Benchmark"  "ENCODE-E2G_Prediction"
# [7] "LMPRA"                 "TMPRA"                 "WSTARR"
# [1] 247249

# %%
lst = lst_vec_txt_region

lst = lapply(lst, function(vec_txt_region){
    vec = vec_txt_region %in% vec_txt_region_atac
    num_atac  = sum(vec)
    num_total = length(vec_txt_region)
    
    vec = c(num_atac, num_total)
    names(vec) = c("Count_ATAC", "Count_Total")
    return(vec)
})

dat = bind_rows(lst, .id = "Assay")
dat = dat %>% 
    dplyr::mutate(
        Freq_ATAC   = Count_ATAC / Count_Total,
        Count_Label = ifelse(
            Count_Total > 1000, 
            paste0(round(Count_Total / 1000), "K"),
            Count_Total
        )
    ) %>%
    dplyr::mutate(
        Assay_Label = paste0(Assay, " (", Count_Label, ")")
    )

dat_region_merge_isATAC = dat
dat
# Out:
#   Assay                 Count_ATAC Count_Total Freq_ATAC Count_Label
# 1 ASTARR                  7827       8539      0.9166179 9K
# 2 ATAC                  247249     247249      1.0000000 247K
# 3 CRISPRi-Growth          4890       6169      0.7926730 6K
# 4 CRISPRi-HCRFF             55         75      0.7333333 75
# 5 ENCODE-E2G_Benchmark     357        381      0.9370079 381
# 6 ENCODE-E2G_Prediction  37393      45429      0.8231086 45K
# 7 LMPRA                  32900      37633      0.8742327 38K
# 8 TMPRA                   1258       7538      0.1668878 8K
# 9 WSTARR                 33408      71498      0.4672578 71K
#   Assay_Label
# 1 ASTARR (9K)
# 2 ATAC (247K)
# 3 CRISPRi-Growth (6K)
# 4 CRISPRi-HCRFF (75)
# 5 ENCODE-E2G_Benchmark (381)
# 6 ENCODE-E2G_Prediction (45K)
# 7 LMPRA (38K)
# 8 TMPRA (8K)
# 9 WSTARR (71K)

# %%
dat = dat_region_merge_isATAC
dat = dat %>% 
    dplyr::arrange(Freq_ATAC) %>%
    dplyr::mutate(Assay_Label = factor(Assay_Label, levels=Assay_Label))

gpt = ggplot(dat, aes(x=Freq_ATAC, y=Assay_Label)) + 
    geom_col() + 
    labs(x="Frequency of ATAC peaks", y="Assays") +
    theme_cowplot()

options(repr.plot.height=6, repr.plot.width=10)
print(gpt)
# Out:
# plot without title
