# %% [markdown]
# **Set environment**

# %%
suppressWarnings(suppressMessages(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %%
fdiry = file.path(FD_RES, "results", "region", "annotation_enhancer_merge")
fname = "enhancer_merge.region.starrmpra_crispri_atac.bed.gz"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, col_names=c("Chrom", "Start", "End", "Assay_Type", "Assay_Label"))
dat_peak_merge_starrmpra_crispri_atac_import = dat
print(dim(dat))
head(dat)
# Out:
# Rows: 350813 Columns: 5
# ── Column specification ─────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): Chrom, Assay_Type, Assay_Label
# dbl (2): Start, End
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 350813      5
#   Chrom Start End   Assay_Type Assay_Label
# 1 chr1  10015 10442 ATAC       ATAC
# 2 chr1  14253 14645 ATAC       ATAC
# 3 chr1  16015 16477 ATAC       ATAC
# 4 chr1  17237 17772 ATAC       ATAC
# 5 chr1  28903 29613 ATAC       ATAC
# 6 chr1  30803 31072 ATAC       ATAC

# %%
fdiry = file.path(FD_RES, "results", "region", "annotation_enhancer_merge")
fname = "enhancer_merge.region.starrmpra_crispri.bed.gz"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, col_names=c("Chrom", "Start", "End", "Assay_Type", "Assay_Label"))
dat_peak_merge_starrmpra_crispri_import = dat
print(dim(dat))
head(dat)
# Out:
# Rows: 186745 Columns: 5
# ── Column specification ─────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): Chrom, Assay_Type, Assay_Label
# dbl (2): Start, End
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 186745      5
#   Chrom Start  End    Assay_Type     Assay_Label
# 1 chr1  136520 136950 ASTARR         ASTARR_R
# 2 chr1  137050 137150 ASTARR         ASTARR_R
# 3 chr1  181600 181790 ASTARR         ASTARR_R
# 4 chr1  184330 184480 WSTARR         WSTARR_A
# 5 chr1  203225 203425 LMPRA          LMPRA_A
# 6 chr1  605550 605627 CRISPRi-Growth CRISPRi-Growth

# %%
dat = dat_peak_merge_starrmpra_crispri_atac_import
dat[1:100,]
# Out:
#     Chrom Start   End     Assay_Type
# 1   chr1   10015   10442  ATAC
# 2   chr1   14253   14645  ATAC
# 3   chr1   16015   16477  ATAC
# 4   chr1   17237   17772  ATAC
# 5   chr1   28903   29613  ATAC
# 6   chr1   30803   31072  ATAC
# 7   chr1  101603  101849  ATAC
# 8   chr1  115411  115986  ATAC
# 9   chr1  118518  118743  ATAC
# 10  chr1  136071  137429  ASTARR,ATAC
# 11  chr1  137737  139544  ATAC
# 12  chr1  180982  182087  ASTARR,ATAC
# 13  chr1  183239  184602  ATAC,WSTARR
# 14  chr1  186238  187159  ATAC
# 15  chr1  191188  191739  ATAC
# 16  chr1  202111  202447  ATAC
# 17  chr1  203225  203425  LMPRA
# 18  chr1  267853  268603  ATAC
# 19  chr1  605090  605823  ATAC,CRISPRi-Growth
# 20  chr1  727124  727516  ATAC
# 21  chr1  770944  771343  ATAC
# 22  chr1  777949  779437  ASTARR,ATAC,LMPRA,WSTARR
# 23  chr1  794279  794597  ATAC
# 24  chr1  795895  796356  ATAC
# 25  chr1  802390  802820  ATAC
# 26  chr1  804729  804964  ATAC
# 27  chr1  806348  806649  ATAC
# ...

# %%
dat = dat_peak_merge_starrmpra_crispri_import
dat[1:100,]
# Out:
#     Chrom Start   End     Assay_Type
# 1   chr1  136520  136950  ASTARR
# 2   chr1  137050  137150  ASTARR
# 3   chr1  181600  181790  ASTARR
# 4   chr1  184330  184480  WSTARR
# 5   chr1  203225  203425  LMPRA
# 6   chr1  605550  605627  CRISPRi-Growth
# 7   chr1  778400  779100  ASTARR,LMPRA,WSTARR
# 8   chr1  818780  818990  WSTARR
# 9   chr1  822090  822250  WSTARR
# 10  chr1  826642  828050  ASTARR,CRISPRi-Growth,LMPRA,WSTARR
# 11  chr1  842870  843070  LMPRA
# 12  chr1  844050  844190  WSTARR
# 13  chr1  851650  851750  WSTARR
# 14  chr1  869810  870100  ASTARR
# 15  chr1  904160  904260  ASTARR
# 16  chr1  904280  904550  ASTARR,LMPRA
# 17  chr1  904740  905140  ASTARR
# 18  chr1  913020  913330  WSTARR
# 19  chr1  918350  918500  WSTARR
# 20  chr1  921010  921400  LMPRA,WSTARR
# 21  chr1  923460  923690  ASTARR
# 22  chr1  923740  924810  ASTARR
# 23  chr1  924890  925130  ASTARR
# 24  chr1  925430  925650  ASTARR
# 25  chr1  925690  925890  ASTARR
# ...

# %%
fdiry = file.path(FD_RES, "results", "region", "annotation_enhancer_merge")
fname = "enhancer_merge.region.starrmpra_crispri_atac.tsv"
fpath = file.path(fdiry, fname)

dat = dat_peak_merge_starrmpra_crispri_atac_import
write_tsv(dat, fpath)

# %%
fdiry = file.path(FD_RES, "results", "region", "annotation_enhancer_merge")
fname = "enhancer_merge.region.starrmpra_crispri.tsv"
fpath = file.path(fdiry, fname)

dat = dat_peak_merge_starrmpra_crispri_import
write_tsv(dat, fpath)
