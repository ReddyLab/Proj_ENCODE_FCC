# %% [markdown]
# **Set environment**

# %%
suppressWarnings(suppressMessages(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **Check data files**

# %%
fdiry  = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname  = "*bed.gz"
fglob  = file.path(fdiry, fname)
fpaths = Sys.glob(fglob)
fnames = basename(fpaths)

for (txt in fnames){cat(txt, "\n")}
# Out:
# fcc_table.starrmpra.crispri.atac.concat.bed.gz
# fcc_table.starrmpra.crispri.atac.e2g_benchmark.concat.bed.gz
# fcc_table.starrmpra.crispri.atac.e2g_benchmark.e2g_prediction.concat.bed.gz
# fcc_table.starrmpra.crispri.atac.e2g_benchmark.e2g_prediction.merge.bed.gz
# fcc_table.starrmpra.crispri.atac.e2g_benchmark.merge.bed.gz
# fcc_table.starrmpra.crispri.atac.merge.bed.gz

# %% [markdown]
# ## Import data

# %%
fdiry = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname = "description.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, show_col_types = FALSE)

dat_cnames = dat
IRdisplay::display(dat)
# Out:
#   Name        Description
# 1 Chrom       Chromosome
# 2 Start       Start
# 3 End         End
# 4 Assay_Type  Assay type
# 5 Assay_Label Assay label

# %%
### set file paths
fdiry = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname = "fcc_table.starrmpra.crispri.atac.e2g_benchmark.e2g_prediction.merge.bed.gz"
fpath = file.path(fdiry, fname)

### read table
vec_txt_cnames = dat_cnames$Name
dat = read_tsv(fpath, col_names = vec_txt_cnames, show_col_types = FALSE)

### assign and show
dat_enhancer_merge_total = dat
print(dim(dat))
head(dat, 10)
# Out:
# [1] 354603      5
#    Chrom Start  End    Assay_Type
# 1  chr1   10015  10442 ATAC
# 2  chr1   14253  14645 ATAC
# 3  chr1   16015  16477 ATAC
# 4  chr1   17237  17772 ATAC
# 5  chr1   28903  29613 ATAC
# 6  chr1   30803  31072 ATAC
# 7  chr1  101603 101849 ATAC
# 8  chr1  115411 115986 ATAC,ENCODE-E2G_Prediction
# 9  chr1  118518 118743 ATAC
# 10 chr1  136071 137429 ASTARR,ATAC
#    Assay_Label
# 1  ATAC
# 2  ATAC
# 3  ATAC
# 4  ATAC
# 5  ATAC
# 6  ATAC
# 7  ATAC
# 8  ATAC,ENCODE-E2G_Prediction:SAMD11
# 9  ATAC
# 10 ASTARR_R,ATAC

# %%
### set file paths
fdiry = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname = "fcc_table.starrmpra.crispri.atac.e2g_benchmark.merge.bed.gz"
fpath = file.path(fdiry, fname)

### read table
vec_txt_cnames = dat_cnames$Name
dat = read_tsv(fpath, col_names = vec_txt_cnames, show_col_types = FALSE)

### assign and show
dat_enhancer_merge_benchmark = dat
print(dim(dat))
head(dat, 10)
# Out:
# [1] 348966      5
#    Chrom Start  End    Assay_Type  Assay_Label
# 1  chr1   10015  10442 ATAC        ATAC
# 2  chr1   14253  14645 ATAC        ATAC
# 3  chr1   16015  16477 ATAC        ATAC
# 4  chr1   17237  17772 ATAC        ATAC
# 5  chr1   28903  29613 ATAC        ATAC
# 6  chr1   30803  31072 ATAC        ATAC
# 7  chr1  101603 101849 ATAC        ATAC
# 8  chr1  115411 115986 ATAC        ATAC
# 9  chr1  118518 118743 ATAC        ATAC
# 10 chr1  136071 137429 ASTARR,ATAC ASTARR_R,ATAC

# %%
### set file paths
fdiry = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname = "fcc_table.starrmpra.crispri.atac.merge.bed.gz"
fpath = file.path(fdiry, fname)

### read table
vec_txt_cnames = dat_cnames$Name
dat = read_tsv(fpath, col_names = vec_txt_cnames, show_col_types = FALSE)

### assign and show
dat_enhancer_merge_fcc = dat
print(dim(dat))
head(dat, 10)
# Out:
# [1] 348956      5
#    Chrom Start  End    Assay_Type  Assay_Label
# 1  chr1   10015  10442 ATAC        ATAC
# 2  chr1   14253  14645 ATAC        ATAC
# 3  chr1   16015  16477 ATAC        ATAC
# 4  chr1   17237  17772 ATAC        ATAC
# 5  chr1   28903  29613 ATAC        ATAC
# 6  chr1   30803  31072 ATAC        ATAC
# 7  chr1  101603 101849 ATAC        ATAC
# 8  chr1  115411 115986 ATAC        ATAC
# 9  chr1  118518 118743 ATAC        ATAC
# 10 chr1  136071 137429 ASTARR,ATAC ASTARR_R,ATAC

# %% [markdown]
# ## Quick explore

# %%
dat = dat_enhancer_merge_total
res = table(dat$Assay_Type)
print(length(res))
print(res)
# Out:
# [1] 176
#
#                                                                                                 ASTARR
#                                                                                                    828
#                                                                                            ASTARR,ATAC
#                                                                                                   2132
#                                                                             ASTARR,ATAC,CRISPRi-Growth
#                                                                                                     73
# ASTARR,ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,LMPRA,TMPRA,WSTARR
#                                                                                                      4
#       ASTARR,ATAC,CRISPRi-Growth,CRISPRi-HCRFF,ENCODE-E2G_Benchmark,ENCODE-E2G_Prediction,TMPRA,WSTARR
# ...

# %% [markdown]
# ## Store results

# %%
### set file paths
fdiry = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname = "fcc_table.starrmpra.crispri.atac.e2g_benchmark.e2g_prediction.merge.tsv"
fpath = file.path(fdiry, fname)

dat = dat_enhancer_merge_total
write_tsv(dat, fpath)

# %%
### set file paths
fdiry = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname = "fcc_table.starrmpra.crispri.atac.e2g_benchmark.merge.tsv"
fpath = file.path(fdiry, fname)

dat = dat_enhancer_merge_benchmark
write_tsv(dat, fpath)

# %%
### set file paths
fdiry = file.path(FD_RES, "results", "region", "annotation_fcc_table")
fname = "fcc_table.starrmpra.crispri.atac.merge.tsv"
fpath = file.path(fdiry, fname)

dat = dat_enhancer_merge_fcc
write_tsv(dat, fpath)
