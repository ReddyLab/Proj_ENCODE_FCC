# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %%
FDIRY=${FD_RES}/results/region/annotation_chipseq_histone/accession_info_peaks.tsv
ls ${FDIRY}
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_chipseq_histone/accession_info_peaks.tsv

# %%
FDIRY=${FD_RES}/results/region/annotation_chipseq_histone
FNAME=accession_info_peaks.tsv
FPATH=${FDIRY}/${FNAME}

head ${FPATH}
# Out:
# Experiment_Accession	File_Accession	Target	Output	Assay	Biosample	File_Analysis_Title	File_Assembly	Experiment_Data_Released	md5sum	URL	FN_OUT	CMD
# ENCSR000EWA	ENCFF122CSI	H3K4me3	pseudoreplicated peaks	Histone ChIP-seq	K562	ENCODE4 v1.5.1 GRCh38	GRCh38	2011-05-19	e5694050796ccb5eeace1e6a4efec34d	https://www.encodeproject.org/files/ENCFF122CSI/@@download/ENCFF122CSI.bed.gz	K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz	wget https://www.encodeproject.org/files/ENCFF122CSI/@@download/ENCFF122CSI.bed.gz -O K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# ENCSR000EWB	ENCFF801AHF	H3K27me3	pseudoreplicated peaks	Histone ChIP-seq	K562	ENCODE4 v1.6.0 GRCh38	GRCh38	2011-05-19	e2bef555c66ac7cb95dd56dc3339420f	https://www.encodeproject.org/files/ENCFF801AHF/@@download/ENCFF801AHF.bed.gz	K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz	wget https://www.encodeproject.org/files/ENCFF801AHF/@@download/ENCFF801AHF.bed.gz -O K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# ...

# %%
FD_INP=${FD_RES}/results/region/annotation_chipseq_histone
FN_INP=accession_info_peaks.tsv
FP_INP=${FD_INP}/${FN_INP}

FD_OUT=${FD_RES}/results/region/annotation_chipseq_histone
FN_OUT=download.sh
FP_OUT=${FD_OUT}/${FN_OUT}

cat  /dev/null     >  ${FP_OUT}
echo '#!/bin/bash' >> ${FP_OUT}

FP_AWK=/data/reddylab/software/bin/print_tab_cols.awk
cat ${FP_INP} \
| awk -f ${FP_AWK} -v cols=CMD \
>> ${FP_OUT}

# %%
cat ${FP_OUT}
# Out:
# #!/bin/bash
# wget https://www.encodeproject.org/files/ENCFF122CSI/@@download/ENCFF122CSI.bed.gz -O K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# wget https://www.encodeproject.org/files/ENCFF801AHF/@@download/ENCFF801AHF.bed.gz -O K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# wget https://www.encodeproject.org/files/ENCFF193ERO/@@download/ENCFF193ERO.bed.gz -O K562.ENCSR000AKR.ENCFF193ERO.H3K36me3.bed.gz
# wget https://www.encodeproject.org/files/ENCFF963GZJ/@@download/ENCFF963GZJ.bed.gz -O K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.bed.gz
# wget https://www.encodeproject.org/files/ENCFF540NGG/@@download/ENCFF540NGG.bed.gz -O K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.bed.gz
# wget https://www.encodeproject.org/files/ENCFF148UQI/@@download/ENCFF148UQI.bed.gz -O K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.bed.gz
# wget https://www.encodeproject.org/files/ENCFF885FQN/@@download/ENCFF885FQN.bed.gz -O K562.ENCSR668LDD.ENCFF885FQN.H3K4me3.bed.gz
# ...

# %%
chmod +x ${FP_OUT}
cd   ${FD_OUT}
bash ${FP_OUT}
# Out:
# --2023-04-13 11:15:18--  https://www.encodeproject.org/files/ENCFF122CSI/@@download/ENCFF122CSI.bed.gz
# Resolving www.encodeproject.org (www.encodeproject.org)... 34.211.244.144
# Connecting to www.encodeproject.org (www.encodeproject.org)|34.211.244.144|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# ...

# %% [markdown]
# ## Sort the file

# %%
ls
# Out:
# accession_info_peaks.tsv
# download.sh
# K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz
# K562.ENCSR000AKQ.ENCFF323WOT.H3K27me3.bed.gz
# K562.ENCSR000AKR.ENCFF193ERO.H3K36me3.bed.gz
# K562.ENCSR000AKS.ENCFF135ZLM.H3K4me1.bed.gz
# K562.ENCSR000AKT.ENCFF749KLQ.H3K4me2.bed.gz
# K562.ENCSR000AKU.ENCFF689QIJ.H3K4me3.bed.gz
# K562.ENCSR000AKV.ENCFF891CHI.H3K9ac.bed.gz
# K562.ENCSR000AKW.ENCFF462AVD.H3K9me1.bed.gz
# K562.ENCSR000AKX.ENCFF909RKY.H4K20me1.bed.gz
# K562.ENCSR000APC.ENCFF213OTI.H2AFZ.bed.gz
# K562.ENCSR000APD.ENCFF209OQD.H3K79me2.bed.gz
# K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.bed.gz
# K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3.bed.gz
# K562.ENCSR000DWD.ENCFF706WUF.H3K4me3.bed.gz
# K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.bed.gz
# K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.bed.gz
# K562.ENCSR668LDD.ENCFF885FQN.H3K4me3.bed.gz

# %%
zcat K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz | head
# Out:
# chr1	100028600	100028930	Peak_47835	54	.	2.76831	5.42882	3.51807	159
# chr1	100036704	100039952	Peak_1354	1000	.	25.73648	216.21426	212.19016	1075
# chr1	100049282	100049759	Peak_40225	69	.	3.43177	6.91015	4.94452	331
# chr1	100050055	100050522	Peak_53510	47	.	2.44126	4.75251	2.87542	319
# chr1	100061449	100061694	Peak_49711	52	.	3.02405	5.23828	3.33907	115
# chr1	100090387	100090929	Peak_41569	65	.	3.34388	6.56285	4.60720	144
# chr1	100129975	100134105	Peak_5627	1000	.	10.20206	106.07190	102.91519	2814
# chr1	100244086	100244356	Peak_50570	50	.	2.94687	5.05628	3.16241	121
# chr1	100244551	100245189	Peak_55989	44	.	2.48105	4.47616	2.61285	488
# chr1	100246265	100247485	Peak_20752	205	.	5.07687	20.59566	18.32800	522

# %%
zcat K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz | sort -k 1,1 -k2,2n -C || echo -n "not " ; echo "sorted"
# Out:
# not sorted

# %%
FPATH=K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz
zcat ${FPATH} | sort -k 1,1 -k2,2n | gzip -c > tmp.bed.gz
mv tmp.bed.gz ${FPATH}

#sort -k 1,1 -k2,2n -o ${FPATH} ${FPATH}

# %%
zcat K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz | head
# Out:
# chr1	118751	119101	Peak_29282	111	.	5.05870	11.17124	9.08295	187
# chr1	120082	120287	Peak_29283	111	.	4.92747	11.17124	9.08295	171
# chr1	137650	138169	Peak_16228	317	.	9.24885	31.74444	29.32013	338
# chr1	138356	139236	Peak_19531	228	.	7.55215	22.82356	20.52066	178
# chr1	139285	139490	Peak_33716	88	.	4.27130	8.85756	6.82864	172
# chr1	777712	778823	Peak_6597	939	.	19.33186	93.91751	90.86520	823
# chr1	778887	779412	Peak_16912	296	.	8.99031	29.63080	27.23310	306
# chr1	826565	827901	Peak_8064	783	.	17.13224	78.32069	75.40894	869
# chr1	904427	905189	Peak_20746	205	.	6.90387	20.59898	18.33118	515
# chr1	958526	959284	Peak_18429	254	.	5.37920	25.40607	23.06551	348

# %%
zcat K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz | sort -k 1,1 -k2,2n -C || echo -n "not " ; echo "sorted"
# Out:
# sorted

# %%
FD_INP=${FD_RES}/results/region/annotation_chipseq_histone
FP_INPS=($(ls ${FD_INP}/K562.*.bed.gz))

echo ${#FP_INPS[@]}
basename -a ${FP_INPS[@]}
# Out:
# 19
# K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz
# K562.ENCSR000AKQ.ENCFF323WOT.H3K27me3.bed.gz
# K562.ENCSR000AKR.ENCFF193ERO.H3K36me3.bed.gz
# K562.ENCSR000AKS.ENCFF135ZLM.H3K4me1.bed.gz
# K562.ENCSR000AKT.ENCFF749KLQ.H3K4me2.bed.gz
# K562.ENCSR000AKU.ENCFF689QIJ.H3K4me3.bed.gz
# K562.ENCSR000AKV.ENCFF891CHI.H3K9ac.bed.gz
# K562.ENCSR000AKW.ENCFF462AVD.H3K9me1.bed.gz
# K562.ENCSR000AKX.ENCFF909RKY.H4K20me1.bed.gz
# K562.ENCSR000APC.ENCFF213OTI.H2AFZ.bed.gz
# K562.ENCSR000APD.ENCFF209OQD.H3K79me2.bed.gz
# K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.bed.gz
# K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3.bed.gz
# K562.ENCSR000DWD.ENCFF706WUF.H3K4me3.bed.gz
# K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.bed.gz
# K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.bed.gz
# K562.ENCSR668LDD.ENCFF885FQN.H3K4me3.bed.gz

# %%
FD_INP=${FD_RES}/results/region/annotation_chipseq_histone
FP_INPS=($(ls ${FD_INP}/K562.*.bed.gz))
FP_TMP=${FD_INP}/tmp.bed.gz

for FP_INP in ${FP_INPS[@]}; do
    FN_INP=$(basename ${FP_INP})
    echo ${FN_INP}
    
    zcat ${FP_INP} | sort -k 1,1 -k2,2n | gzip -c > ${FP_TMP}
    mv ${FP_TMP} ${FP_INP}
    
    zcat ${FP_INP} | sort -k 1,1 -k2,2n -C || echo -n "not" ; echo "sorted"
done
# Out:
# K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz
# sorted
# K562.ENCSR000AKQ.ENCFF323WOT.H3K27me3.bed.gz
# sorted
# K562.ENCSR000AKR.ENCFF193ERO.H3K36me3.bed.gz
# sorted
# K562.ENCSR000AKS.ENCFF135ZLM.H3K4me1.bed.gz
# sorted
# K562.ENCSR000AKT.ENCFF749KLQ.H3K4me2.bed.gz
# sorted
# K562.ENCSR000AKU.ENCFF689QIJ.H3K4me3.bed.gz
# sorted
# K562.ENCSR000AKV.ENCFF891CHI.H3K9ac.bed.gz
# sorted
# K562.ENCSR000AKW.ENCFF462AVD.H3K9me1.bed.gz
# sorted
# K562.ENCSR000AKX.ENCFF909RKY.H4K20me1.bed.gz
# sorted
# K562.ENCSR000APC.ENCFF213OTI.H2AFZ.bed.gz
# sorted
# K562.ENCSR000APD.ENCFF209OQD.H3K79me2.bed.gz
# sorted
# K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.bed.gz
# sorted
# K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3.bed.gz
# sorted
# K562.ENCSR000DWD.ENCFF706WUF.H3K4me3.bed.gz
# sorted
# K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.bed.gz
# sorted
# K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# sorted
# K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# sorted
# K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.bed.gz
# sorted
# ...
