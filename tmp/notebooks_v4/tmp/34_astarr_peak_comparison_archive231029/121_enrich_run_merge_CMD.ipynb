# %% [markdown]
# **Set environment**

# %%
### set env
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **Check environment**

# %%
${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh which R
# Out:
# /usr/bin/R

# %%
${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh Rscript -e 'R.Version()$version.string'
# Out:
# [1] "R version 4.3.0 (2023-04-21)"

# %% [markdown]
# ## Script for running enrichment

# %%
cat > run_fgsea.R << 'EOF'
library(tidyverse)
library(fgsea)

### parse arguemnts
myargs = commandArgs(trailingOnly=TRUE)
FP_INP_SCORE = myargs[1]
FP_INP_ANNOT = myargs[2]
FP_OUT       = myargs[3]

### show
cat("\n")
cat("Input score:", FP_INP_SCORE, "\n\n")
cat("Input annot:", FP_INP_ANNOT, "\n\n")
cat("Output file:", FP_OUT,       "\n\n")
flush.console()

### import data
vec_score = readRDS(FP_INP_SCORE)
lst_annot = readRDS(FP_INP_ANNOT)

### run GSEA
cat("RUN GSEA: Start.\n")
set.seed(123)
fgseaRes = fgsea(
    pathways  = lst_annot, 
    stats     = vec_score,
    eps       = 0.0,
    scoreType = "pos"
)
cat("RUN GSEA: Done!\n\n")

### show results
cat("Show results:\n")
print(fgseaRes)
cat("\n")

### Save the results
cat("Save results.\n")
saveRDS(fgseaRes, FP_OUT)

EOF

# %%
cat > run_fgsea.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP_SCORE=$1
FP_INP_ANNOT=$2
FP_OUT=$3

#FP_INP_ANNOTS=($(ls ${FD_INP_ANNOT}/*rds))
#FP_INP_ANNOT=${FP_INP_ANNOTS[${SLURM_ARRAY_TASK_ID}]}

### execute
${FD_PRJ}/notebooks/sing_proj_encode_fcc.sh Rscript ./run_fgsea.R ${FP_INP_SCORE} ${FP_INP_ANNOT} ${FP_OUT}

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x run_fgsea.sh

# %% [markdown]
# ## Check data

# %% [markdown]
# **Score**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge

ls -1 ${FD_INP_SCORE}
# Out:
# score_merge.astarr.rds
# score_merge.atac.rds
# score_merge.crispri_growth_tot.rds
# score_merge.crispri_hcrff_tot.rds
# score_merge.lmpra_tot.rds
# score_merge.overall.rds
# score_merge.tmpra.rds
# score_merge.wstarr.rds

# %% [markdown]
# **Annotation**

# %%
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation

ls -1 ${FD_INP_ANNOT}
echo
ls -1 ${FD_INP_ANNOT}/annotation_chipseq_histone
# Out:
# annotation_chipseq_histone
# annotation_chipseq_tf
# annotation_chipseq_tf_subset
# annotation_genomic
#
# annot.ChIPseq_Histone.H2AFZ_ENCFF213OTI.rds
# annot.ChIPseq_Histone.H3K27ac_ENCFF544LXB.rds
# annot.ChIPseq_Histone.H3K27me3_ENCFF323WOT.rds
# annot.ChIPseq_Histone.H3K27me3_ENCFF801AHF.rds
# annot.ChIPseq_Histone.H3K36me3_ENCFF193ERO.rds
# annot.ChIPseq_Histone.H3K36me3_ENCFF561OUZ.rds
# annot.ChIPseq_Histone.H3K4me1_ENCFF135ZLM.rds
# annot.ChIPseq_Histone.H3K4me1_ENCFF540NGG.rds
# annot.ChIPseq_Histone.H3K4me2_ENCFF749KLQ.rds
# annot.ChIPseq_Histone.H3K4me3_ENCFF122CSI.rds
# annot.ChIPseq_Histone.H3K4me3_ENCFF689QIJ.rds
# annot.ChIPseq_Histone.H3K4me3_ENCFF706WUF.rds
# annot.ChIPseq_Histone.H3K4me3_ENCFF885FQN.rds
# annot.ChIPseq_Histone.H3K79me2_ENCFF209OQD.rds
# annot.ChIPseq_Histone.H3K9ac_ENCFF148UQI.rds
# annot.ChIPseq_Histone.H3K9ac_ENCFF891CHI.rds
# annot.ChIPseq_Histone.H3K9me1_ENCFF462AVD.rds
# annot.ChIPseq_Histone.H3K9me3_ENCFF963GZJ.rds
# annot.ChIPseq_Histone.H4K20me1_ENCFF909RKY.rds

# %%
FOLDERS=(annotation_genomic annotation_chipseq_histone annotation_chipseq_tf_subset annotation_chipseq_tf)
for FOLDER in ${FOLDERS[@]}; do
    FP_INPS_ANNOT=($(ls ${FD_INP_ANNOT}/${FOLDER}/annot*rds))
    echo ${FOLDER}
    echo ${#FP_INPS_ANNOT[@]}
    echo
done
# Out:
# annotation_genomic
# 49
#
# annotation_chipseq_histone
# 19
#
# annotation_chipseq_tf_subset
# 16
#
# annotation_chipseq_tf
# 733

# %% [markdown]
# ## Run enrichment

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge

FOLDERS=(annotation_genomic annotation_chipseq_histone annotation_chipseq_tf_subset annotation_chipseq_tf)
for FOLDER in ${FOLDERS[@]}; do
    FP_INPS_SCORE=($(ls ${FD_INP_SCORE}/score*rds))
    FP_INPS_ANNOT=($(ls ${FD_INP_ANNOT}/${FOLDER}/annot*rds))
    echo ${FOLDER}
    echo ${#FP_INPS_ANNOT[@]}
    echo
    
    for FP_INP_SCORE in ${FP_INPS_SCORE[@]}; do
        for FP_INP_ANNOT in ${FP_INPS_ANNOT[@]}; do
            FN_INP_SCORE=$(basename ${FP_INP_SCORE})
            FN_INP_ANNOT=$(basename ${FP_INP_ANNOT})
            
            ID_INP_SCORE=${FN_INP_SCORE%.rds}
            ID_INP_ANNOT=${FN_INP_ANNOT%.rds}
            
            FDIRY=${FD_OUT}/${FOLDER}
            FN_OUT=${ID_INP_SCORE}.${ID_INP_ANNOT}.rds
            FP_OUT=${FDIRY}/${FN_OUT}
            mkdir -p ${FDIRY}
            
            FN_LOG=run_fgsea.${ID_INP_SCORE}.${ID_INP_ANNOT}.%a.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            echo "FPATH  (INPUT; SCORE):" ${FP_INP_SCORE}
            echo "FPATH  (INPUT; ANNOT):" ${FP_INP_ANNOT}
            echo "FPATH  (OUTPUT):      " ${FP_OUT}
            echo "PREFIX (INPUT; SCORE):" ${ID_INP_SCORE}
            echo "PREFIX (INPUT; ANNOT):" ${ID_INP_ANNOT}
            echo "FNAME  (OUTPUT):      " ${FN_OUT}
            echo "FPATH  (LOG):         " '${FD_LOG}'/run_fgsea.${ID_INP_SCORE}.${ID_INP_ANNOT}.0.txt
            echo
            
            sbatch -p ${NODE} \
                --exclude=dl-01 \
                --cpus-per-task 8 \
                --mem 4G \
                --output ${FP_LOG} \
                --array 0 \
                ./run_fgsea.sh ${FP_INP_SCORE} ${FP_INP_ANNOT} ${FP_OUT}
            echo
        done
    done
    echo
done
# Out:
# annotation_genomic
# 49
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.CTCF_only_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.CTCF_only_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.CTCF_only_CTCF_bound
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.CTCF_only_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.CTCF_only_CTCF_bound.0.txt
#
# Submitted batch job 30022339
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.dELS_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.dELS_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.dELS_CTCF_bound
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.dELS_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.dELS_CTCF_bound.0.txt
#
# Submitted batch job 30022340
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.dELS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.dELS.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.dELS
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.dELS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.dELS.0.txt
#
# Submitted batch job 30022341
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.DNase_H3K4me3_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.DNase_H3K4me3_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.DNase_H3K4me3_CTCF_bound
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.DNase_H3K4me3_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.DNase_H3K4me3_CTCF_bound.0.txt
#
# Submitted batch job 30022342
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.DNase_H3K4me3.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.DNase_H3K4me3.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.DNase_H3K4me3
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.DNase_H3K4me3.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.DNase_H3K4me3.0.txt
#
# Submitted batch job 30022343
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.DNase_only.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.DNase_only.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.DNase_only
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.DNase_only.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.DNase_only.0.txt
#
# Submitted batch job 30022344
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.Low_DNase.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.Low_DNase.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.Low_DNase
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.Low_DNase.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.Low_DNase.0.txt
#
# Submitted batch job 30022345
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.pELS_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.pELS_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.pELS_CTCF_bound
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.pELS_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.pELS_CTCF_bound.0.txt
#
# Submitted batch job 30022346
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.pELS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.pELS.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.pELS
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.pELS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.pELS.0.txt
#
# Submitted batch job 30022347
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.PLS_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.PLS_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.PLS_CTCF_bound
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.PLS_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.PLS_CTCF_bound.0.txt
#
# Submitted batch job 30022348
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.PLS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.PLS.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v3.PLS
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v3.PLS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.PLS.0.txt
#
# Submitted batch job 30022349
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.CA_CTCF.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.CA_CTCF.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.CA_CTCF
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.CA_CTCF.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.CA_CTCF.0.txt
#
# Submitted batch job 30022350
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.CA_H3K4me3.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.CA_H3K4me3.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.CA_H3K4me3
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.CA_H3K4me3.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.CA_H3K4me3.0.txt
#
# Submitted batch job 30022351
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.CA_only.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.CA_only.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.CA_only
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.CA_only.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.CA_only.0.txt
#
# Submitted batch job 30022352
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.CA_TF.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.CA_TF.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.CA_TF
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.CA_TF.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.CA_TF.0.txt
#
# Submitted batch job 30022353
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.dELS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.dELS.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.dELS
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.dELS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.dELS.0.txt
#
# Submitted batch job 30022354
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.Low_DNase.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.Low_DNase.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.Low_DNase
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.Low_DNase.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.Low_DNase.0.txt
#
# Submitted batch job 30022355
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.pELS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.pELS.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.pELS
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.pELS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.pELS.0.txt
#
# Submitted batch job 30022356
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v4.PLS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v4.PLS.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ccre_v4.PLS
# FNAME  (OUTPUT):       score_merge.astarr.annot.ccre_v4.PLS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v4.PLS.0.txt
#
# Submitted batch job 30022357
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.Biv.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.Biv.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.Biv
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.Biv.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.Biv.0.txt
#
# Submitted batch job 30022358
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.Enh1.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.Enh1.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.Enh1
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.Enh1.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.Enh1.0.txt
#
# Submitted batch job 30022359
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.Enh2.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.Enh2.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.Enh2
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.Enh2.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.Enh2.0.txt
#
# Submitted batch job 30022360
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.EnhG1.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.EnhG1.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.EnhG1
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.EnhG1.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.EnhG1.0.txt
#
# Submitted batch job 30022361
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.EnhG2.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.EnhG2.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.EnhG2
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.EnhG2.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.EnhG2.0.txt
#
# Submitted batch job 30022362
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.Het.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.Het.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.Het
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.Het.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.Het.0.txt
#
# Submitted batch job 30022363
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.Quies.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.Quies.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.Quies
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.Quies.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.Quies.0.txt
#
# Submitted batch job 30022364
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.ReprPC.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.ReprPC.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.ReprPC
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.ReprPC.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.ReprPC.0.txt
#
# Submitted batch job 30022365
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.TssFlnkD.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.TssFlnkD.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.TssFlnkD
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.TssFlnkD.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.TssFlnkD.0.txt
#
# Submitted batch job 30022366
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.TssFlnk.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.TssFlnk.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.TssFlnk
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.TssFlnk.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.TssFlnk.0.txt
#
# Submitted batch job 30022367
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.TssFlnkU.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.TssFlnkU.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.TssFlnkU
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.TssFlnkU.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.TssFlnkU.0.txt
#
# Submitted batch job 30022368
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.Tss.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.Tss.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.Tss
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.Tss.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.Tss.0.txt
#
# Submitted batch job 30022369
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.Tx.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.Tx.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.Tx
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.Tx.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.Tx.0.txt
#
# Submitted batch job 30022370
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.TxWk.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.TxWk.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.TxWk
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.TxWk.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.TxWk.0.txt
#
# Submitted batch job 30022371
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.ZNF_Rpts.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.ZNF_Rpts.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.ChromHMM.ZNF_Rpts
# FNAME  (OUTPUT):       score_merge.astarr.annot.ChromHMM.ZNF_Rpts.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.ZNF_Rpts.0.txt
#
# Submitted batch job 30022372
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.CRISPRi.CRISPRi_E2G.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.CRISPRi.CRISPRi_E2G.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.CRISPRi.CRISPRi_E2G
# FNAME  (OUTPUT):       score_merge.astarr.annot.CRISPRi.CRISPRi_E2G.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.CRISPRi.CRISPRi_E2G.0.txt
#
# Submitted batch job 30022373
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.CRISPRi.CRISPRi_Growth.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.CRISPRi.CRISPRi_Growth.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.CRISPRi.CRISPRi_Growth
# FNAME  (OUTPUT):       score_merge.astarr.annot.CRISPRi.CRISPRi_Growth.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.CRISPRi.CRISPRi_Growth.0.txt
#
# Submitted batch job 30022374
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.CRISPRi.CRISPRi_HCRFF.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.CRISPRi.CRISPRi_HCRFF.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.CRISPRi.CRISPRi_HCRFF
# FNAME  (OUTPUT):       score_merge.astarr.annot.CRISPRi.CRISPRi_HCRFF.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.CRISPRi.CRISPRi_HCRFF.0.txt
#
# Submitted batch job 30022375
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.ASTARR_AB.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.ASTARR_AB.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.ASTARR_AB
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.ASTARR_AB.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.ASTARR_AB.0.txt
#
# Submitted batch job 30022376
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.ASTARR_A.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.ASTARR_A.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.ASTARR_A
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.ASTARR_A.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.ASTARR_A.0.txt
#
# Submitted batch job 30022377
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.ASTARR_R.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.ASTARR_R.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.ASTARR_R
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.ASTARR_R.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.ASTARR_R.0.txt
#
# Submitted batch job 30022378
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.LMPRA_AB.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.LMPRA_AB.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.LMPRA_AB
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.LMPRA_AB.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.LMPRA_AB.0.txt
#
# Submitted batch job 30022379
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.LMPRA_A.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.LMPRA_A.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.LMPRA_A
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.LMPRA_A.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.LMPRA_A.0.txt
#
# Submitted batch job 30022380
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.LMPRA_R.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.LMPRA_R.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.LMPRA_R
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.LMPRA_R.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.LMPRA_R.0.txt
#
# Submitted batch job 30022381
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.TMPRA_A.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.TMPRA_A.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.TMPRA_A
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.TMPRA_A.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.TMPRA_A.0.txt
#
# Submitted batch job 30022382
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.TMPRA_R.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.TMPRA_R.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.TMPRA_R
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.TMPRA_R.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.TMPRA_R.0.txt
#
# Submitted batch job 30022383
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.WSTARR_AB.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.WSTARR_AB.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.WSTARR_AB
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.WSTARR_AB.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.WSTARR_AB.0.txt
#
# Submitted batch job 30022384
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.WSTARR_A.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.WSTARR_A.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.WSTARR_A
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.WSTARR_A.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.WSTARR_A.0.txt
#
# Submitted batch job 30022385
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.Enhancer_ZScore.WSTARR_R.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.Enhancer_ZScore.WSTARR_R.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.Enhancer_ZScore.WSTARR_R
# FNAME  (OUTPUT):       score_merge.astarr.annot.Enhancer_ZScore.WSTARR_R.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.Enhancer_ZScore.WSTARR_R.0.txt
#
# Submitted batch job 30022386
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.TSS_POL2.TSS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.TSS_POL2.TSS.rds
# PREFIX (INPUT; SCORE): score_merge.astarr
# PREFIX (INPUT; ANNOT): annot.TSS_POL2.TSS
# FNAME  (OUTPUT):       score_merge.astarr.annot.TSS_POL2.TSS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.astarr.annot.TSS_POL2.TSS.0.txt
#
# Submitted batch job 30022387
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.CTCF_only_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.atac.annot.ccre_v3.CTCF_only_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ccre_v3.CTCF_only_CTCF_bound
# FNAME  (OUTPUT):       score_merge.atac.annot.ccre_v3.CTCF_only_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ccre_v3.CTCF_only_CTCF_bound.0.txt
#
# Submitted batch job 30022388
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.dELS_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.atac.annot.ccre_v3.dELS_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ccre_v3.dELS_CTCF_bound
# FNAME  (OUTPUT):       score_merge.atac.annot.ccre_v3.dELS_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ccre_v3.dELS_CTCF_bound.0.txt
#
# Submitted batch job 30022389
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.dELS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.atac.annot.ccre_v3.dELS.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ccre_v3.dELS
# FNAME  (OUTPUT):       score_merge.atac.annot.ccre_v3.dELS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ccre_v3.dELS.0.txt
#
# Submitted batch job 30022390
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.DNase_H3K4me3_CTCF_bound.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.atac.annot.ccre_v3.DNase_H3K4me3_CTCF_bound.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ccre_v3.DNase_H3K4me3_CTCF_bound
# FNAME  (OUTPUT):       score_merge.atac.annot.ccre_v3.DNase_H3K4me3_CTCF_bound.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ccre_v3.DNase_H3K4me3_CTCF_bound.0.txt
#
# Submitted batch job 30022391
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.DNase_H3K4me3.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.atac.annot.ccre_v3.DNase_H3K4me3.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ccre_v3.DNase_H3K4me3
# FNAME  (OUTPUT):       score_merge.atac.annot.ccre_v3.DNase_H3K4me3.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ccre_v3.DNase_H3K4me3.0.txt
#
# Submitted batch job 30022392
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# ...
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MITF_ENCFF605XYC
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MITF_ENCFF605XYC.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MITF_ENCFF605XYC.0.txt
#
# Submitted batch job 30024040
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MLLT1_ENCFF355OYM.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MLLT1_ENCFF355OYM.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MLLT1_ENCFF355OYM
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MLLT1_ENCFF355OYM.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MLLT1_ENCFF355OYM.0.txt
#
# Submitted batch job 30024041
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MLLT1_ENCFF556MUV.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MLLT1_ENCFF556MUV.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MLLT1_ENCFF556MUV
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MLLT1_ENCFF556MUV.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MLLT1_ENCFF556MUV.0.txt
#
# Submitted batch job 30024042
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MLX_ENCFF128YWS.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MLX_ENCFF128YWS.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MLX_ENCFF128YWS
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MLX_ENCFF128YWS.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MLX_ENCFF128YWS.0.txt
#
# Submitted batch job 30024043
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MLX_ENCFF171ZNN.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MLX_ENCFF171ZNN.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MLX_ENCFF171ZNN
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MLX_ENCFF171ZNN.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MLX_ENCFF171ZNN.0.txt
#
# Submitted batch job 30024044
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MNT_ENCFF440AQF.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF440AQF.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MNT_ENCFF440AQF
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF440AQF.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF440AQF.0.txt
#
# Submitted batch job 30024045
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MNT_ENCFF461QQT.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF461QQT.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MNT_ENCFF461QQT
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF461QQT.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF461QQT.0.txt
#
# Submitted batch job 30024046
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MNT_ENCFF986SXD.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF986SXD.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MNT_ENCFF986SXD
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF986SXD.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MNT_ENCFF986SXD.0.txt
#
# Submitted batch job 30024047
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MTA1_ENCFF058ZHN.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MTA1_ENCFF058ZHN.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MTA1_ENCFF058ZHN
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MTA1_ENCFF058ZHN.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MTA1_ENCFF058ZHN.0.txt
#
# Submitted batch job 30024048
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MTA2_ENCFF080IBW.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MTA2_ENCFF080IBW.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MTA2_ENCFF080IBW
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MTA2_ENCFF080IBW.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MTA2_ENCFF080IBW.0.txt
#
# Submitted batch job 30024049
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MTA2_ENCFF478LQC.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MTA2_ENCFF478LQC.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MTA2_ENCFF478LQC
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MTA2_ENCFF478LQC.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MTA2_ENCFF478LQC.0.txt
#
# Submitted batch job 30024050
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MTA3_ENCFF280AIK.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MTA3_ENCFF280AIK.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MTA3_ENCFF280AIK
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MTA3_ENCFF280AIK.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MTA3_ENCFF280AIK.0.txt
#
# Submitted batch job 30024051
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MTF1_ENCFF478MAJ.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MTF1_ENCFF478MAJ.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MTF1_ENCFF478MAJ
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MTF1_ENCFF478MAJ.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MTF1_ENCFF478MAJ.0.txt
#
# Submitted batch job 30024052
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MXD1_ENCFF559MTF.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MXD1_ENCFF559MTF.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MXD1_ENCFF559MTF
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MXD1_ENCFF559MTF.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MXD1_ENCFF559MTF.0.txt
#
# Submitted batch job 30024053
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MXI1_ENCFF068IGH.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MXI1_ENCFF068IGH.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MXI1_ENCFF068IGH
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MXI1_ENCFF068IGH.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MXI1_ENCFF068IGH.0.txt
#
# Submitted batch job 30024054
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MYBL2_ENCFF227LKX.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MYBL2_ENCFF227LKX.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MYBL2_ENCFF227LKX
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MYBL2_ENCFF227LKX.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MYBL2_ENCFF227LKX.0.txt
#
# Submitted batch job 30024055
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MYBL2_ENCFF637PFI.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MYBL2_ENCFF637PFI.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MYBL2_ENCFF637PFI
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MYBL2_ENCFF637PFI.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MYBL2_ENCFF637PFI.0.txt
#
# Submitted batch job 30024056
#
# FPATH  (INPUT; SCORE): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.atac.rds
# FPATH  (INPUT; ANNOT): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_chipseq_tf/annot.ChIPseq_TF.MYC_ENCFF114VAI.rds
# FPATH  (OUTPUT):       /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_chipseq_tf/score_merge.atac.annot.ChIPseq_TF.MYC_ENCFF114VAI.rds
# PREFIX (INPUT; SCORE): score_merge.atac
# PREFIX (INPUT; ANNOT): annot.ChIPseq_TF.MYC_ENCFF114VAI
# FNAME  (OUTPUT):       score_merge.atac.annot.ChIPseq_TF.MYC_ENCFF114VAI.rds
# FPATH  (LOG):          ${FD_LOG}/run_fgsea.score_merge.atac.annot.ChIPseq_TF.MYC_ENCFF114VAI.0.txt
#
# Submitted batch job 30024057

# %%
cat ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ccre_v3.CTCF_only_CTCF_bound.0.txt
# Out:
# Hostname:           x1-01-2.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-24-23+18:45:25
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ccre_v3.CTCF_only_CTCF_bound.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ccre_v3.CTCF_only_CTCF_bound.rds
#
# RUN GSEA: Start.
# RUN GSEA: Done!
#
# Show results:
#                         pathway      pval      padj    log2err        ES
# 1: ccre_v3:CTCF-only,CTCF-bound 0.7462537 0.7462537 0.02660528 0.2575266
#          NES size
# 1: 0.8925704   78
#                                                                                                                                       leadingEdge
# 1: chr2:60674341-60675636,chr11:5600369-5600825,chrX:49840468-49841285,chr20:58233920-58234495,chr2:61425472-61427136,chr11:34791840-34792579,...
#
# Save results.
#
# Done!
# Run Time: 7 seconds

# %%
cat ${FD_LOG}/run_fgsea.score_merge.astarr.annot.ChromHMM.TssFlnkU.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-24-23+18:45:25
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge.astarr.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation/annotation_genomic/annot.ChromHMM.TssFlnkU.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/annotation_genomic/score_merge.astarr.annot.ChromHMM.TssFlnkU.rds
#
# RUN GSEA: Start.
# RUN GSEA: Done!
#
# Show results:
#              pathway         pval         padj   log2err        ES      NES
# 1: ChromHMM:TssFlnkU 9.870551e-05 9.870551e-05 0.5384341 0.4223621 1.505539
#    size
# 1:  119
#                                                                                                                                    leadingEdge
# 1: chr20:56411580-56412866,chr2:60755774-60757171,chrX:49147328-49149698,chr2:61016793-61018539,chrX:49039728-49040229,chr16:807054-808186,...
#
# Save results.
#
# Done!
# Run Time: 10 seconds

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annotation

FP_INPS_SCORE=($(ls ${FD_INP_SCORE}/score*rds))

FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge

FOLDERS=(annotation_genomic annotation_chipseq_histone annotation_chipseq_tf)
for FOLDER in ${FOLDERS[@]}; do
    FP_INPS_ANNOT=($(ls ${FD_INP_SCORE}/score*rds))
    echo ${FOLDER}
    FDIRY=${FD_OUT}/${FOLDER}
    
done
# Out:
# annotation_genomic
# annotation_chipseq_histone
# annotation_chipseq_tf

# %% [markdown]
# ## Run enrichment: All annotations besides ChIP-seq

# %% [markdown]
# **Check data**

# %%
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_others
ls ${FD_INP_ANNOT}
# Out:
# annot.ccre_v3.CTCF_only_CTCF_bound.rds      annot.ChromHMM.Het.rds
# annot.ccre_v3.dELS_CTCF_bound.rds           annot.ChromHMM.Quies.rds
# annot.ccre_v3.dELS.rds                      annot.ChromHMM.ReprPC.rds
# annot.ccre_v3.DNase_H3K4me3_CTCF_bound.rds  annot.ChromHMM.TssFlnkD.rds
# annot.ccre_v3.DNase_H3K4me3.rds             annot.ChromHMM.TssFlnk.rds
# annot.ccre_v3.DNase_only.rds                annot.ChromHMM.TssFlnkU.rds
# annot.ccre_v3.Low_DNase.rds                 annot.ChromHMM.Tss.rds
# annot.ccre_v3.pELS_CTCF_bound.rds           annot.ChromHMM.Tx.rds
# annot.ccre_v3.pELS.rds                      annot.ChromHMM.TxWk.rds
# annot.ccre_v3.PLS_CTCF_bound.rds            annot.ChromHMM.ZNF_Rpts.rds
# annot.ccre_v3.PLS.rds                       annot.CRISPRi.CRISPRi_Growth.rds
# annot.ccre_v4.CA_CTCF.rds                   annot.CRISPRi.CRISPRi_HCRFF.rds
# annot.ccre_v4.CA_H3K4me3.rds                annot.Enhancer_ZScore.ASTARR_AB.rds
# annot.ccre_v4.CA_only.rds                   annot.Enhancer_ZScore.ASTARR_A.rds
# annot.ccre_v4.CA_TF.rds                     annot.Enhancer_ZScore.ASTARR_R.rds
# annot.ccre_v4.dELS.rds                      annot.Enhancer_ZScore.LMPRA_AB.rds
# annot.ccre_v4.Low_DNase.rds                 annot.Enhancer_ZScore.LMPRA_A.rds
# annot.ccre_v4.pELS.rds                      annot.Enhancer_ZScore.LMPRA_R.rds
# annot.ccre_v4.PLS.rds                       annot.Enhancer_ZScore.TMPRA_A.rds
# annot.ChromHMM.Biv.rds                      annot.Enhancer_ZScore.TMPRA_R.rds
# annot.ChromHMM.Enh1.rds                     annot.Enhancer_ZScore.WSTARR_AB.rds
# annot.ChromHMM.Enh2.rds                     annot.Enhancer_ZScore.WSTARR_A.rds
# annot.ChromHMM.EnhG1.rds                    annot.Enhancer_ZScore.WSTARR_R.rds
# annot.ChromHMM.EnhG2.rds                    annot.TSS_POL2.TSS.rds

# %%
FP_INP_ANNOTS=($(ls ${FD_INP_ANNOT}))
echo ${#FP_INP_ANNOTS[@]}
# Out:
# 48

# %% [markdown]
# **Test loop**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_others
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
echo ${FD_OUT}
echo

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    echo ${FP_INP_SCORE}
    echo ${FN_INP_SCORE}
    echo ${ID_INP_SCORE}
    echo
done
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_astarr.rds
# score_merge_astarr.rds
# score_merge_astarr
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_lmpra_tot.rds
# score_merge_lmpra_tot.rds
# score_merge_lmpra_tot
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
# score_merge_overall.rds
# score_merge_overall
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_tmpra.rds
# score_merge_tmpra.rds
# score_merge_tmpra
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_wstarr.rds
# score_merge_wstarr.rds
# score_merge_wstarr

# %% [markdown]
# **RUN**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_others
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    
    echo ${ID_INP_SCORE}
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 8 \
        --mem 4G \
        --output ${FD_LOG}/run_fgsea_${ID_INP_SCORE}_annot_others.%a.txt \
        --array 0-37 \
        ./run_fgsea.sh ${FP_INP_SCORE} ${FD_INP_ANNOT} ${FD_OUT}
done
# Out:
# score_merge_astarr
# Submitted batch job 29983194
# score_merge_crispri_growth_tot
# Submitted batch job 29983195
# score_merge_crispri_hcrff_tot
# Submitted batch job 29983196
# score_merge_lmpra_tot
# Submitted batch job 29983197
# score_merge_overall
# Submitted batch job 29983198
# score_merge_tmpra
# Submitted batch job 29983199
# score_merge_wstarr
# Submitted batch job 29983200

# %% [markdown]
# **Check results**

# %%
cat /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/run_fgsea_score_merge_overall_annot_others.0.txt
# Out:
# Hostname:           x3-03-4.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-12-23+15:43:14
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_others/annot.ccre_v3.CTCF_only_CTCF_bound.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/score_merge_overall_annot.ccre_v3.CTCF_only_CTCF_bound.rds
#
# RUN GSEA: Start.
# Warning message:
# In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (13.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# RUN GSEA: Done!
#
# Show results:
#                         pathway       pval       padj   log2err        ES
# 1: ccre_v3:CTCF-only,CTCF-bound 0.02897103 0.02897103 0.2663507 0.3094418
#         NES size
# 1: 1.414557   78
#                                                                                                                                   leadingEdge
# 1: chr16:785365-786016,chr20:56626306-56626978,chr16:1150597-1150980,chrX:48025602-48027305,chr20:58233920-58234495,chr11:5600369-5600825,...
#
# Save results.
#
# Done!
# Run Time: 8 seconds

# %%
cat /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/run_fgsea_score_merge_astarr_annot_others.0.txt
# Out:
# Hostname:           x1-01-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         05-10-23+15:52:03
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.4.1
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_astarr.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_others/annot_ccre_v3_CTCF_only_CTCF_bound.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/score_merge_astarr_annot_ccre_v3_CTCF_only_CTCF_bound.rds
#
# RUN GSEA: Start.
# RUN GSEA: Done!
#
# Show results:
#                         pathway      pval      padj    log2err        ES
# 1: ccre_v3:CTCF-only,CTCF-bound 0.7382617 0.7382617 0.02716698 0.2597125
#          NES size
# 1: 0.8998583   80
#                                                                                                                                       leadingEdge
# 1: chr2_60674341_60675636,chr11_5600369_5600825,chrX_49840468_49841285,chr20_58233920_58234495,chr2_61425472_61427136,chr11_34791840_34792579,...
#
# Save results.
#
# Done!
# Run Time: 6 seconds

# %%
cat /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/run_fgsea_score_merge_astarr_annot_others.37.txt
# Out:
# Hostname:           x2-03-3.genome.duke.edu
# Slurm Array Index:  37
# Time Stamp:         06-12-23+06:05:17
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_astarr.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_others/annot_TSS_POL2_TSS.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/score_merge_astarr_annot_TSS_POL2_TSS.rds
#
# RUN GSEA: Start.
# RUN GSEA: Done!
#
# Show results:
# Empty data.table (0 rows and 8 cols): pathway,pval,padj,log2err,ES,NES...
#
# Save results.
#
# Done!
# Run Time: 7 seconds

# %% [markdown]
# ## Run enrichment: ChIP-seq Histone modifications

# %% [markdown]
# **Check data**

# %%
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_histone
ls ${FD_INP_ANNOT}
# Out:
# annot_ChIPseq_Histone_H2AFZ.rds     annot_ChIPseq_Histone_H3K4me3.rds
# annot_ChIPseq_Histone_H3K27ac.rds   annot_ChIPseq_Histone_H3K79me2.rds
# annot_ChIPseq_Histone_H3K27me3.rds  annot_ChIPseq_Histone_H3K9ac.rds
# annot_ChIPseq_Histone_H3K36me3.rds  annot_ChIPseq_Histone_H3K9me1.rds
# annot_ChIPseq_Histone_H3K4me1.rds   annot_ChIPseq_Histone_H3K9me3.rds
# annot_ChIPseq_Histone_H3K4me2.rds   annot_ChIPseq_Histone_H4K20me1.rds

# %%
FP_INP_ANNOTS=($(ls ${FD_INP_ANNOT}))
echo ${#FP_INP_ANNOTS[@]}
# Out:
# 12

# %% [markdown]
# **Test loop**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_histone
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    echo ${FP_INP_SCORE}
    echo ${FN_INP_SCORE}
    echo ${ID_INP_SCORE}
    echo ${FD_OUT}
    echo
done
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_astarr.rds
# score_merge_astarr.rds
# score_merge_astarr
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_lmpra_tot.rds
# score_merge_lmpra_tot.rds
# score_merge_lmpra_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
# score_merge_overall.rds
# score_merge_overall
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_tmpra.rds
# score_merge_tmpra.rds
# score_merge_tmpra
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_wstarr.rds
# score_merge_wstarr.rds
# score_merge_wstarr
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge

# %% [markdown]
# **RUN**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_histone
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 8 \
        --mem 4G \
        --output ${FD_LOG}/run_fgsea_${ID_INP_SCORE}_annot_chipseq_histone.%a.txt \
        --array 0-11 \
        ./run_fgsea.sh ${FP_INP_SCORE} ${FD_INP_ANNOT} ${FD_OUT}
done
# Out:
# Submitted batch job 29960580
# Submitted batch job 29960581
# Submitted batch job 29960582
# Submitted batch job 29960583
# Submitted batch job 29960584
# Submitted batch job 29960585
# Submitted batch job 29960586

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/run_fgsea_score_merge_overall_annot_chipseq_histone.0.txt
# Out:
# Hostname:           x2-04-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-12-23+06:06:51
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_histone/annot_ChIPseq_Histone_H2AFZ.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/score_merge_overall_annot_ChIPseq_Histone_H2AFZ.rds
#
# RUN GSEA: Start.
# Warning message:
# In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (13.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# RUN GSEA: Done!
#
# Show results:
# Empty data.table (0 rows and 8 cols): pathway,pval,padj,log2err,ES,NES...
#
# Save results.
#
# Done!
# Run Time: 5 seconds

# %%
cat ${FD_LOG}/run_fgsea_score_merge_overall_annot_chipseq_histone.11.txt
# Out:
# Hostname:           x2-04-3.genome.duke.edu
# Slurm Array Index:  11
# Time Stamp:         06-12-23+06:06:51
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_histone/annot_ChIPseq_Histone_H4K20me1.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge/score_merge_overall_annot_ChIPseq_Histone_H4K20me1.rds
#
# RUN GSEA: Start.
# Warning message:
# In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (13.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# RUN GSEA: Done!
#
# Show results:
# Empty data.table (0 rows and 8 cols): pathway,pval,padj,log2err,ES,NES...
#
# Save results.
#
# Done!
# Run Time: 5 seconds

# %% [markdown]
# ## Run enrichment: ChIP-seq TF Subset

# %% [markdown]
# **Check data**

# %%
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf_subset
ls ${FD_INP_ANNOT}
# Out:
# annot_ChIPseq_TF_ATF1_ENCFF627RSK.rds   annot_ChIPseq_TF_NFE2_ENCFF023IFO.rds
# annot_ChIPseq_TF_CTCF_ENCFF660GHM.rds   annot_ChIPseq_TF_NRF1_ENCFF777PKJ.rds
# annot_ChIPseq_TF_ELK1_ENCFF715WGN.rds   annot_ChIPseq_TF_POLR2A_ENCFF355MNE.rds
# annot_ChIPseq_TF_EP300_ENCFF702XPO.rds  annot_ChIPseq_TF_REST_ENCFF707MDI.rds
# annot_ChIPseq_TF_GATA1_ENCFF657CTC.rds  annot_ChIPseq_TF_SP1_ENCFF553GPK.rds
# annot_ChIPseq_TF_JUN_ENCFF190CGV.rds    annot_ChIPseq_TF_TAL1_ENCFF852ZRK.rds
# annot_ChIPseq_TF_KLF10_ENCFF142ZTD.rds  annot_ChIPseq_TF_YY1_ENCFF398UQZ.rds
# annot_ChIPseq_TF_KLF16_ENCFF488OTN.rds  annot_ChIPseq_TF_ZEB2_ENCFF242AOL.rds

# %%
FP_INP_ANNOTS=($(ls ${FD_INP_ANNOT}))
echo ${#FP_INP_ANNOTS[@]}
# Out:
# 16

# %% [markdown]
# **Test loop**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf_subset
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    echo ${FP_INP_SCORE}
    echo ${FN_INP_SCORE}
    echo ${ID_INP_SCORE}
    echo ${FD_OUT}
    echo
done
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_astarr.rds
# score_merge_astarr.rds
# score_merge_astarr
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_lmpra_tot.rds
# score_merge_lmpra_tot.rds
# score_merge_lmpra_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
# score_merge_overall.rds
# score_merge_overall
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_tmpra.rds
# score_merge_tmpra.rds
# score_merge_tmpra
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_wstarr.rds
# score_merge_wstarr.rds
# score_merge_wstarr
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset

# %% [markdown]
# **RUN**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf_subset
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    echo ${ID_INP_SCORE}
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 8 \
        --mem 4G \
        --output ${FD_LOG}/run_fgsea_${ID_INP_SCORE}_annot_chipseq_tf_subset.%a.txt \
        --array 0-15 \
        ./run_fgsea.sh ${FP_INP_SCORE} ${FD_INP_ANNOT} ${FD_OUT}
done
# Out:
# score_merge_astarr
# Submitted batch job 29960664
# score_merge_crispri_growth_tot
# Submitted batch job 29960665
# score_merge_crispri_hcrff_tot
# Submitted batch job 29960666
# score_merge_lmpra_tot
# Submitted batch job 29960667
# score_merge_overall
# Submitted batch job 29960668
# score_merge_tmpra
# Submitted batch job 29960669
# score_merge_wstarr
# Submitted batch job 29960670

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/run_fgsea_score_merge_overall_annot_chipseq_tf_subset.0.txt
# Out:
# Hostname:           x1-03-4.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         05-11-23+13:28:06
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.4.1
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf_subset/annot_ChIPseq_TF_ATF1_ENCFF627RSK.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset/score_merge_overall_annot_ChIPseq_TF_ATF1_ENCFF627RSK.rds
#
# RUN GSEA: Start.
# Warning message:
# In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (13.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# RUN GSEA: Done!
#
# Show results:
#                        pathway         pval         padj  log2err       ES
# 1: ChIPseq_TF:ATF1_ENCFF627RSK 6.068028e-49 6.068028e-49 1.825919 0.642985
#         NES size
# 1: 3.211689  216
#                                                                                                                                     leadingEdge
# 1: chr11_5280584_5281311,chr16_807054_808186,chrX_48573742_48575194,chr11_33161035_33162032,chr11_34809279_34810196,chr11_34104842_34106372,...
#
# Save results.
#
# Done!
# Run Time: 9 seconds

# %%
cat ${FD_LOG}/run_fgsea_score_merge_overall_annot_chipseq_tf_subset.15.txt
# Out:
# Hostname:           x2-03-2.genome.duke.edu
# Slurm Array Index:  15
# Time Stamp:         05-11-23+13:28:06
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.4.1
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf_subset/annot_ChIPseq_TF_ZEB2_ENCFF242AOL.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf_subset/score_merge_overall_annot_ChIPseq_TF_ZEB2_ENCFF242AOL.rds
#
# RUN GSEA: Start.
# Warning message:
# In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (13.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# RUN GSEA: Done!
#
# Show results:
#                        pathway         pval         padj  log2err        ES
# 1: ChIPseq_TF:ZEB2_ENCFF242AOL 1.002386e-22 1.002386e-22 1.237897 0.5651548
#         NES size
# 1: 2.727009  139
#                                                                                                                                leadingEdge
# 1: chr11_5280584_5281311,chr16_807054_808186,chrX_48573742_48575194,chr11_34809279_34810196,chrX_49039728_49040229,chr16_112817_114269,...
#
# Save results.
#
# Done!
# Run Time: 7 seconds

# %% [markdown]
# ## Run enrichment: ChIP-seq TF

# %% [markdown]
# **Check data**

# %%
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf
ls ${FD_INP_ANNOT} | head
# Out:
# annot_ChIPseq_TF_ADNP_ENCFF739AJO.rds
# annot_ChIPseq_TF_AFF1_ENCFF195YGC.rds
# annot_ChIPseq_TF_AFF1_ENCFF674XTY.rds
# annot_ChIPseq_TF_AGO1_ENCFF794IRP.rds
# annot_ChIPseq_TF_ARHGAP35_ENCFF952WKN.rds
# annot_ChIPseq_TF_ARID1B_ENCFF879NTL.rds
# annot_ChIPseq_TF_ARID2_ENCFF913WRW.rds
# annot_ChIPseq_TF_ARID3A_ENCFF891OQP.rds
# annot_ChIPseq_TF_ARID3B_ENCFF270TSN.rds
# annot_ChIPseq_TF_ARID4B_ENCFF086FAZ.rds

# %%
FP_INP_ANNOTS=($(ls ${FD_INP_ANNOT}))
echo ${#FP_INP_ANNOTS[@]}
# Out:
# 733

# %% [markdown]
# **Test loop**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    echo ${FP_INP_SCORE}
    echo ${FN_INP_SCORE}
    echo ${ID_INP_SCORE}
    echo ${FD_OUT}
    echo
done
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_astarr.rds
# score_merge_astarr.rds
# score_merge_astarr
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot.rds
# score_merge_crispri_growth_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot.rds
# score_merge_crispri_hcrff_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_lmpra_tot.rds
# score_merge_lmpra_tot.rds
# score_merge_lmpra_tot
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
# score_merge_overall.rds
# score_merge_overall
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_tmpra.rds
# score_merge_tmpra.rds
# score_merge_tmpra
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_wstarr.rds
# score_merge_wstarr.rds
# score_merge_wstarr
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf

# %% [markdown]
# **RUN**

# %%
FD_INP_SCORE=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge
FD_INP_ANNOT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf
FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf

FP_INP_SCORES=($(ls ${FD_INP_SCORE}/*.rds))
for FP_INP_SCORE in ${FP_INP_SCORES[@]}; do
    FN_INP_SCORE=$(basename ${FP_INP_SCORE})
    ID_INP_SCORE=${FN_INP_SCORE%.rds}
    echo ${ID_INP_SCORE}
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 8 \
        --mem 4G \
        --output ${FD_LOG}/run_fgsea_${ID_INP_SCORE}_annot_chipseq_tf.%a.txt \
        --array 0-732 \
        ./run_fgsea.sh ${FP_INP_SCORE} ${FD_INP_ANNOT} ${FD_OUT}
done
# Out:
# score_merge_astarr
# Submitted batch job 29960776
# score_merge_crispri_growth_tot
# Submitted batch job 29960878
# score_merge_crispri_hcrff_tot
# Submitted batch job 29960879
# score_merge_lmpra_tot
# Submitted batch job 29960880
# score_merge_overall
# Submitted batch job 29960881
# score_merge_tmpra
# Submitted batch job 29960882
# score_merge_wstarr
# Submitted batch job 29960883

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/run_fgsea_score_merge_overall_annot_chipseq_tf.0.txt
# Out:
# Hostname:           x3-02-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         05-10-23+15:56:16
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.4.1
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf/annot_ChIPseq_TF_ADNP_ENCFF739AJO.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf/score_merge_overall_annot_ChIPseq_TF_ADNP_ENCFF739AJO.rds
#
# RUN GSEA: Start.
# Warning message:
# In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (13.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# RUN GSEA: Done!
#
# Show results:
#                        pathway        pval        padj   log2err        ES
# 1: ChIPseq_TF:ADNP_ENCFF739AJO 0.002534382 0.002534382 0.4317077 0.4075296
#         NES size
# 1: 1.708821   44
#                                                                                                                                          leadingEdge
# 1: chr11_34809279_34810196,chr16_112817_114269,chr8_127898363_127899746,chr8_127959623_127961065,chrX_48736825_48738095,chr8_128176331_128177858,...
#
# Save results.
#
# Done!
# Run Time: 5 seconds

# %%
cat ${FD_LOG}/run_fgsea_score_merge_overall_annot_chipseq_tf.732.txt
# Out:
# Hostname:           x1-03-4.genome.duke.edu
# Slurm Array Index:  732
# Time Stamp:         05-10-23+15:56:31
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.4.1
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Input score: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_score_merge/score_merge_overall.rds
#
# Input annot: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_prepare_annot_chipseq_tf/annot_ChIPseq_TF_ZZZ3_ENCFF797VEK.rds
#
# Output file: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_results_merge_chipseq_tf/score_merge_overall_annot_ChIPseq_TF_ZZZ3_ENCFF797VEK.rds
#
# RUN GSEA: Start.
# Warning message:
# In preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam,  :
#   There are ties in the preranked stats (13.94% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.
# RUN GSEA: Done!
#
# Show results:
#                        pathway         pval         padj   log2err        ES
# 1: ChIPseq_TF:ZZZ3_ENCFF797VEK 0.0001825152 0.0001825152 0.5188481 0.7216629
#         NES size
# 1: 2.254505    9
#                                                                                                                                         leadingEdge
# 1: chrX_48573742_48575194,chr11_34104842_34106372,chr20_56391751_56392958,chrX_49079517_49080656,chr11_61792068_61793464,chr2_61016793_61018539,...
#
# Save results.
#
# Done!
# Run Time: 6 seconds
