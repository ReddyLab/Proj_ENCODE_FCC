# %% [markdown]
# **Set environment**

# %%
### set env
source ../config/config_duke.sh
source ../config/config_load_module_bedtools.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **Check data**

# %%
ls -1 ${FD_RES}/results/region/annotation_tss_pol2_span | head
# Out:
# description.tsv
# K562.TSS.highest_Pol2.0_1K.bed.gz
# K562.TSS.highest_Pol2.100_101K.bed.gz
# K562.TSS.highest_Pol2.101_102K.bed.gz
# K562.TSS.highest_Pol2.10_11K.bed.gz
# K562.TSS.highest_Pol2.102_103K.bed.gz
# K562.TSS.highest_Pol2.103_104K.bed.gz
# K562.TSS.highest_Pol2.104_105K.bed.gz
# K562.TSS.highest_Pol2.105_106K.bed.gz
# K562.TSS.highest_Pol2.106_107K.bed.gz

# %%
FD_INP=${FD_RES}/results/region/annotation_tss_pol2_span
FP_INPS=($(ls ${FD_INP}/K562.*.bed.gz))

echo ${#FP_INPS[@]}
basename -a ${FP_INPS[@]}
# Out:
# 500
# K562.TSS.highest_Pol2.0_1K.bed.gz
# K562.TSS.highest_Pol2.100_101K.bed.gz
# K562.TSS.highest_Pol2.101_102K.bed.gz
# K562.TSS.highest_Pol2.10_11K.bed.gz
# K562.TSS.highest_Pol2.102_103K.bed.gz
# K562.TSS.highest_Pol2.103_104K.bed.gz
# K562.TSS.highest_Pol2.104_105K.bed.gz
# K562.TSS.highest_Pol2.105_106K.bed.gz
# K562.TSS.highest_Pol2.106_107K.bed.gz
# K562.TSS.highest_Pol2.107_108K.bed.gz
# K562.TSS.highest_Pol2.108_109K.bed.gz
# K562.TSS.highest_Pol2.109_110K.bed.gz
# K562.TSS.highest_Pol2.110_111K.bed.gz
# K562.TSS.highest_Pol2.111_112K.bed.gz
# K562.TSS.highest_Pol2.11_12K.bed.gz
# K562.TSS.highest_Pol2.112_113K.bed.gz
# K562.TSS.highest_Pol2.113_114K.bed.gz
# K562.TSS.highest_Pol2.114_115K.bed.gz
# K562.TSS.highest_Pol2.115_116K.bed.gz
# K562.TSS.highest_Pol2.116_117K.bed.gz
# K562.TSS.highest_Pol2.117_118K.bed.gz
# K562.TSS.highest_Pol2.118_119K.bed.gz
# K562.TSS.highest_Pol2.119_120K.bed.gz
# K562.TSS.highest_Pol2.120_121K.bed.gz
# K562.TSS.highest_Pol2.121_122K.bed.gz
# ...

# %%
FD_INP=${FD_RES}/results/region/annotation_tss_pol2_span
FN_INP=K562.TSS.highest_Pol2.99_100K.bed.gz
FP_INP=${FD_INP}/${FN_INP}

zcat ${FP_INP} | head
# Out:
# chr1	40566	41566	chr1:140566-140567:99-100K:-	2.3e-4	LOC729737
# chr1	82387	83387	chr1:182387-182388:99-100K:-	0.00779966	DDX11L17
# chr1	110873	111873	chr1:11873-11874:99-100K:+	2.3e-4	DDX11L1
# chr1	116436	117436	chr1:17436-17437:99-100K:+	9.43812	MIR6859-1
# chr1	116436	117436	chr1:17436-17437:99-100K:+	9.43812	MIR6859-2
# chr1	116436	117436	chr1:17436-17437:99-100K:+	9.43812	MIR6859-3
# chr1	116436	117436	chr1:17436-17437:99-100K:+	9.43812	MIR6859-4
# chr1	128370	129370	chr1:29370-29371:99-100K:+	2.3e-4	WASH7P
# chr1	129365	130365	chr1:30365-30366:99-100K:+	0.562995	MIR1302-10
# chr1	129365	130365	chr1:30365-30366:99-100K:+	0.562995	MIR1302-11

# %% [markdown]
# **RUN**

# %%
sbatch -p ${NODE} \
    --exclude=dl-01 \
    --cpus-per-task 8 \
    --mem 4G \
    --output ${FD_LOG}/annotation_astarr_peak_macs_input_tss_pol2_span.%a.txt \
    --array 0-499 \
    <<'EOF'
#!/bin/bash
### set directories
source ../config/config_duke.sh

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### set input and output
FD_INP=${FD_RES}/results/region/annotation_tss_pol2_span
FP_INPS=($(ls ${FD_INP}/K562.*.bed.gz))
FP_INP=${FP_INPS[SLURM_ARRAY_TASK_ID]}
FN_INP=$(basename ${FP_INP})

FD_REG=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input
FN_REG=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed
FP_REG=${FD_REG}/${FN_REG}

FD_OUT=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_tss_pol2_span
FN_OUT=peak.annotation.${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

### show I/O file
echo "Input: " ${FP_REG}
echo
echo "show first few lines of input"
cat ${FP_REG} | head -5
echo
echo "Input: " ${FP_INP}
echo
echo "show first few lines of input"
zcat ${FP_INP} | head -5
echo

### init: create output folder if not exist
mkdir -p ${FD_OUT}

### annotation using intersect
bedtools intersect \
    -a ${FP_REG} \
    -b ${FP_INP} \
    -wo \
    -f 0.7 \
    -F 0.7 \
    -e \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
zcat ${FP_OUT} | head -5
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 29825294

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/annotation_astarr_peak_macs_input_tss_pol2_span.0.txt
# Out:
# Hostname:           x1-02-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         05-17-23+09:16:27
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_tss_pol2_span/K562.TSS.highest_Pol2.0_1K.bed.gz
#
# show first few lines of input
# chr1	10873	11873	chr1:11873-11874:0-1K:-	2.3e-4	DDX11L1
# chr1	11873	12873	chr1:11873-11874:0-1K:+	2.3e-4	DDX11L1
# chr1	16436	17436	chr1:17436-17437:0-1K:-	9.43812	MIR6859-1
# chr1	16436	17436	chr1:17436-17437:0-1K:-	9.43812	MIR6859-2
# chr1	16436	17436	chr1:17436-17437:0-1K:-	9.43812	MIR6859-3
#
#
# ...

# %%
cat ${FD_LOG}/annotation_astarr_peak_macs_input_tss_pol2_span.92.txt
# Out:
# Hostname:           x2-05-2
# Slurm Array Index:  92
# Time Stamp:         05-17-23+09:16:27
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_tss_pol2_span/K562.TSS.highest_Pol2.99_100K.bed.gz
#
# show first few lines of input
# chr1	40566	41566	chr1:140566-140567:99-100K:-	2.3e-4	LOC729737
# chr1	82387	83387	chr1:182387-182388:99-100K:-	0.00779966	DDX11L17
# chr1	110873	111873	chr1:11873-11874:99-100K:+	2.3e-4	DDX11L1
# chr1	116436	117436	chr1:17436-17437:99-100K:+	9.43812	MIR6859-1
# chr1	116436	117436	chr1:17436-17437:99-100K:+	9.43812	MIR6859-2
#
#
# ...
