# %% [markdown]
# **Set environment**

# %%
suppressWarnings(suppressMessages(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## Import data

# %%
fdiry = file.path(FD_RES, "results", "region", "KS91_K562_ASTARRseq_peak_macs_input", "summary")
fname = "peak.screened.fcc.total.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, show_col_types=FALSE)

dat_peak_atac_fcc_total = dat
print(dim(dat))
head(dat)
# Out:
# [1] 740280      6
#   Chrom Start     End       Peak                     Assay_Type Assay_Label
# 1 chr1  100006256 100006880 chr1:100006256-100006880 ASTARR     ASTARR_T
# 2 chr1  100010437 100010915 chr1:100010437-100010915 ASTARR     ASTARR_T
# 3 chr1   10002087  10003910 chr1:10002087-10003910   ASTARR     ASTARR_T
# 4 chr1  100021298 100021629 chr1:100021298-100021629 ASTARR     ASTARR_T
# 5 chr1  100023727 100023976 chr1:100023727-100023976 ASTARR     ASTARR_T
# 6 chr1  100027983 100029702 chr1:100027983-100029702 ASTARR     ASTARR_T

# %%
fdiry = file.path(FD_RES, "results", "region", "KS91_K562_ASTARRseq_peak_macs_input", "summary")
fname = "peak.screened.fcc.active.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, show_col_types=FALSE)

dat_peak_atac_fcc_active = dat
print(dim(dat))
head(dat)
# Out:
# [1] 167127      6
#   Chrom Start     End       Peak                     Assay_Type Assay_Label
# 1 chr1  101198203 101199537 chr1:101198203-101199537 ASTARR     ASTARR_AB
# 2 chr1    1012902   1014502 chr1:1012902-1014502     ASTARR     ASTARR_AB
# 3 chr1  109213422 109215054 chr1:109213422-109215054 ASTARR     ASTARR_AB
# 4 chr1  109218538 109219133 chr1:109218538-109219133 ASTARR     ASTARR_AB
# 5 chr1  109388963 109390708 chr1:109388963-109390708 ASTARR     ASTARR_AB
# 6 chr1  109476546 109477209 chr1:109476546-109477209 ASTARR     ASTARR_AB

# %%
fdiry = file.path(FD_RES, "results", "region", "KS91_K562_ASTARRseq_peak_macs_input", "summary")
fname = "peak.screened.fcc.inactive.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, show_col_types=FALSE)

dat_peak_atac_fcc_inactive = dat
print(dim(dat))
head(dat)
# Out:
# [1] 293262      6
#   Chrom Start   End     Peak                 Assay_Type Assay_Label
# 1 chr1   938228  938505 chr1:938228-938505   ASTARR     ASTARR_I
# 2 chr1   965936  967556 chr1:965936-967556   ASTARR     ASTARR_I
# 3 chr1  1005089 1005593 chr1:1005089-1005593 ASTARR     ASTARR_I
# 4 chr1  1024158 1024602 chr1:1024158-1024602 ASTARR     ASTARR_I
# 5 chr1  1062264 1062778 chr1:1062264-1062778 ASTARR     ASTARR_I
# 6 chr1  1067955 1068196 chr1:1067955-1068196 ASTARR     ASTARR_I

# %%
fdiry = file.path(FD_RES, "results", "region", "KS91_K562_ASTARRseq_peak_macs_input", "summary")
fname = "peak.screened.atac.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, show_col_types=FALSE)

dat_peak_atac_total = dat
print(dim(dat))
head(dat)
# Out:
# [1] 495040      6
#   Chrom Start End   Peak             Assay_Type Assay_Label
# 1 chr1  10015 10442 chr1:10015-10442 ATAC       ATAC_I
# 2 chr1  14253 14645 chr1:14253-14645 ATAC       ATAC_I
# 3 chr1  16015 16477 chr1:16015-16477 ATAC       ATAC_I
# 4 chr1  17237 17772 chr1:17237-17772 ATAC       ATAC_I
# 5 chr1  28903 29613 chr1:28903-29613 ATAC       ATAC_I
# 6 chr1  30803 31072 chr1:30803-31072 ATAC       ATAC_I

# %% [markdown]
# **Merge**

# %%
lst = list(
    dat_peak_atac_fcc_total,
    dat_peak_atac_fcc_active,
    dat_peak_atac_fcc_inactive,
    dat_peak_atac_total)

dat = bind_rows(lst)

dat_peak_atac_merge = dat
print(dim(dat))
head(dat)
# Out:
# [1] 1695709       6
#   Chrom Start     End       Peak                     Assay_Type Assay_Label
# 1 chr1  100006256 100006880 chr1:100006256-100006880 ASTARR     ASTARR_T
# 2 chr1  100010437 100010915 chr1:100010437-100010915 ASTARR     ASTARR_T
# 3 chr1   10002087  10003910 chr1:10002087-10003910   ASTARR     ASTARR_T
# 4 chr1  100021298 100021629 chr1:100021298-100021629 ASTARR     ASTARR_T
# 5 chr1  100023727 100023976 chr1:100023727-100023976 ASTARR     ASTARR_T
# 6 chr1  100027983 100029702 chr1:100027983-100029702 ASTARR     ASTARR_T

# %%
dat = dat_peak_atac_merge
dat = dat %>% 
    dplyr::select(Assay_Type, Assay_Label) %>% 
    dplyr::arrange(Assay_Type) %>%
    dplyr::distinct()
dat
# Out:
#    Assay_Type            Assay_Label
# 1  ASTARR                ASTARR_T
# 2  ASTARR                ASTARR_AB
# 3  ASTARR                ASTARR_A
# 4  ASTARR                ASTARR_R
# 5  ASTARR                ASTARR_I
# 6  ATAC                  ATAC_I
# 7  ATAC                  ATAC_A
# 8  ATAC                  ATAC_T
# 9  CRISPRi_Growth        CRISPRi_Growth_T
# 10 CRISPRi_Growth        CRISPRi_Growth_A
# 11 CRISPRi_Growth        CRISPRi_Growth_I
# 12 CRISPRi_HCRFF         CRISPRi_HCRFF_T
# 13 CRISPRi_HCRFF         CRISPRi_HCRFF_A
# 14 CRISPRi_HCRFF         CRISPRi_HCRFF_I
# 15 ENCODE-E2G_Benchmark  ENCODE-E2G_Benchmark_T
# 16 ENCODE-E2G_Benchmark  ENCODE-E2G_Benchmark_A
# 17 ENCODE-E2G_Benchmark  ENCODE-E2G_Benchmark_I
# 18 ENCODE-E2G_Prediction ENCODE-E2G_Prediction_T
# 19 ENCODE-E2G_Prediction ENCODE-E2G_Prediction_A
# 20 ENCODE-E2G_Prediction ENCODE-E2G_Prediction_I
# 21 LMPRA                 LMPRA_T
# 22 LMPRA                 LMPRA_AB
# 23 LMPRA                 LMPRA_A
# 24 LMPRA                 LMPRA_R
# 25 LMPRA                 LMPRA_I
# 26 TMPRA                 TMPRA_T
# 27 TMPRA                 TMPRA_A
# 28 TMPRA                 TMPRA_R
# 29 TMPRA                 TMPRA_I
# 30 WSTARR                WSTARR_T
# 31 WSTARR                WSTARR_AB
# 32 WSTARR                WSTARR_A
# 33 WSTARR                WSTARR_R
# 34 WSTARR                WSTARR_I

# %%
dat = dat_peak_atac_merge
head(dat$Peak)
# Out:
# [1] "chr1:100006256-100006880" "chr1:100010437-100010915"
# [3] "chr1:10002087-10003910"   "chr1:100021298-100021629"
# [5] "chr1:100023727-100023976" "chr1:100027983-100029702"

# %% [markdown]
# ## Import data

# %% [markdown]
# **Check data files**

# %%
FOLDER_REG = "hic_intact_deep"

fdiry = file.path(FD_RES, "results", "region", FOLDER_REG, "summary")
for (fname in dir(fdiry)){cat(fname, "\n")}
# Out:
# peak.looped.astarr_a.bed.gz
# peak.looped.astarr_ab.bed.gz
# peak.looped.astarr_r.bed.gz
# peak.looped.atac.bed.gz
# peak.looped.crispri_growth.bed.gz
# peak.looped.crispri_hcrff.bed.gz
# peak.looped.encode_e2g_benchmark.bed.gz
# peak.looped.encode_e2g_prediction.bed.gz
# peak.looped.lmpra_a.bed.gz
# peak.looped.lmpra_ab.bed.gz
# peak.looped.lmpra_r.bed.gz
# peak.looped.tmpra_a.bed.gz
# peak.looped.tmpra_r.bed.gz
# peak.looped.wstarr_a.bed.gz
# peak.looped.wstarr_ab.bed.gz
# peak.looped.wstarr_r.bed.gz
# peak.summary.crispri_growth.dhs.active.tsv
# peak.summary.crispri_hcrff.casa.merge.tsv
# peak.summary.encode_e2g_benchmark.active.merge.tsv
# peak.summary.encode_e2g_prediction.active.merge.tsv
# peak.summary.enhancer_zscore_junke.concat.tsv
# peak.summary.KS91_K562_ASTARRseq_peak_macs_input.tsv

# %% [markdown]
# **Import data**

# %%
FOLDER_REG = "hic_intact_deep"

### get file paths
fdiry = file.path(FD_RES, "results", "region", FOLDER_REG, "summary")
fname = "peak.summary.KS91_K562_ASTARRseq_peak_macs_input.tsv"
fpath = file.path(fdiry, fname)

### read tables
dat = read_tsv(fpath, show_col_types = FALSE)

### assign and show
dat_peak_atac_loop_summary = dat
print(dim(dat))
head(dat)
# Out:
# [1] 569206      6
#   Peak             Loop               Distance Annotation Label_Peak Label_Loop
# 1 chr1:10015-10442 chr1:778000-779000 767559   ATAC       ATAC       Loop_A
# 2 chr1:14253-14645 chr1:778000-779000 763356   ATAC       ATAC       Loop_A
# 3 chr1:16015-16477 chr1:778000-779000 761524   ATAC       ATAC       Loop_A
# 4 chr1:17237-17772 chr1:778000-779000 760229   ATAC       ATAC       Loop_A
# 5 chr1:28903-29613 chr1:778000-779000 748388   ATAC       ATAC       Loop_A
# 6 chr1:30803-31072 chr1:778000-779000 746929   ATAC       ATAC       Loop_A

# %% [markdown]
# **Get distance and overlap**

# %%
dat = dat_peak_atac_loop_summary

dat = dat %>%
    dplyr::group_by(Peak) %>%
    dplyr::summarise(Distance = min(Distance), .groups = "drop")

dat_peak_atac_loop_distance = dat
print(dim(dat))
head(dat)
# Out:
# [1] 230509      2
#   Peak                      Distance
# 1 chr10:100009096-100010466     0
# 2 chr10:100020710-100021134  5711
# 3 chr10:1000372-1000820      7181
# 4 chr10:100045961-100046653     0
# 5 chr10:100065094-100065486 15095
# 6 chr10:100081317-100081607 18394

# %%
dat = dat_peak_atac_loop_distance

dat = dat %>% dplyr::filter(Distance == 0)
vec = dat$Peak

dat_peak_atac_loop_overlap = dat
vec_peak_atac_loop_overlap = vec
print(dim(dat))
print(head(vec))
head(dat)
# Out:
# [1] 65084     2
# [1] "chr10:100009096-100010466" "chr10:100045961-100046653"
# [3] "chr10:100185017-100187275" "chr10:100228452-100230090"
# [5] "chr10:100240591-100241246" "chr10:100267066-100268374"
#   Peak                      Distance
# 1 chr10:100009096-100010466 0
# 2 chr10:100045961-100046653 0
# 3 chr10:100185017-100187275 0
# 4 chr10:100228452-100230090 0
# 5 chr10:100240591-100241246 0
# 6 chr10:100267066-100268374 0

# %% [markdown]
# ## Frequency

# %%
### init
vec_peak_feature = vec_peak_atac_loop_overlap

### init
dat = dat_peak_atac_merge
lst = split(dat, dat$Assay_Type)
print(names(lst))

### example
txt_assay = "ATAC"
dat_assay = lst[[txt_assay]]

print(table(dat_assay$Assay_Label))
head(dat_assay)
# Out:
# [1] "ASTARR"                "ATAC"                  "CRISPRi_Growth"
# [4] "CRISPRi_HCRFF"         "ENCODE-E2G_Benchmark"  "ENCODE-E2G_Prediction"
# [7] "LMPRA"                 "TMPRA"                 "WSTARR"
#
# ATAC_A ATAC_I ATAC_T
#  24752 222768 247520
#   Chrom Start End   Peak             Assay_Type Assay_Label
# 1 chr1  10015 10442 chr1:10015-10442 ATAC       ATAC_I
# 2 chr1  14253 14645 chr1:14253-14645 ATAC       ATAC_I
# 3 chr1  16015 16477 chr1:16015-16477 ATAC       ATAC_I
# 4 chr1  17237 17772 chr1:17237-17772 ATAC       ATAC_I
# 5 chr1  28903 29613 chr1:28903-29613 ATAC       ATAC_I
# 6 chr1  30803 31072 chr1:30803-31072 ATAC       ATAC_I

# %%
lst = split(dat_assay$Peak, dat_assay$Assay_Label)
txt = paste(txt_assay, "T", sep="_")

vec_peak_total  = lst[[txt]]
num_peak_total  = length(vec_peak_total)
vec_peak_sample = sample(vec_peak_total, size = as.integer(num_peak_total * 0.9))

lst = lapply(lst, function(vec_peak_group){
    vec = intersect(vec_peak_sample, vec_peak_group)
    vec = vec %in% vec_peak_feature
    num = mean(vec)
    return(num)
})

# %%
### init
vec_peak_feature = vec_peak_atac_loop_overlap

### init
dat_merge = dat_peak_atac_merge
lst_merge = split(dat_merge, dat_merge$Assay_Type)

for (txt_assay in names(lst_merge)) {
    print(txt_assay)
    dat_assay = lst_merge[[txt_assay]]
    
    lst = split(dat_assay$Peak, dat_assay$Assay_Label)
    txt = paste(txt_assay, "T", sep="_")
    
    vec_peak_total  = lst[[txt]]
    num_peak_total  = length(vec_peak_total)
    vec_peak_sample = sample(vec_peak_total, size = as.integer(num_peak_total * 0.9))
    
    lst = lapply(lst, function(vec_peak_group){
        vec = intersect(vec_peak_sample, vec_peak_group)
        vec = vec %in% vec_peak_feature
        num = mean(vec)
        return(num)
    })
    print(lst)
}
# Out:
# [1] "ASTARR"
# $ASTARR_A
# [1] 0.6830036
#
# $ASTARR_AB
# [1] 0.6970179
#
# $ASTARR_I
# [1] 0.7453573
#
# $ASTARR_R
# [1] 0.7399682
#
# $ASTARR_T
# [1] 0.2639435
#
# [1] "ATAC"
# $ATAC_A
# [1] 0.7764849
#
# $ATAC_I
# [1] 0.2072266
#
# $ATAC_T
# [1] 0.2641044
#
# [1] "CRISPRi_Growth"
# $CRISPRi_Growth_A
# [1] 0.6138114
#
# $CRISPRi_Growth_I
# [1] 0.559328
#
# $CRISPRi_Growth_T
# [1] 0.5619092
#
# [1] "CRISPRi_HCRFF"
# $CRISPRi_HCRFF_A
# [1] 0.787234
#
# $CRISPRi_HCRFF_I
# [1] 0.3795812
#
# $CRISPRi_HCRFF_T
# [1] 0.3968254
#
# [1] "ENCODE-E2G_Benchmark"
# $`ENCODE-E2G_Benchmark_A`
# [1] 0.8375
#
# $`ENCODE-E2G_Benchmark_I`
# [1] 0.6697209
#
# $`ENCODE-E2G_Benchmark_T`
# [1] 0.6896805
#
# [1] "ENCODE-E2G_Prediction"
# $`ENCODE-E2G_Prediction_A`
# [1] 0.6733501
#
# $`ENCODE-E2G_Prediction_I`
# [1] 0.4517597
#
# $`ENCODE-E2G_Prediction_T`
# [1] 0.5462526
#
# [1] "LMPRA"
# $LMPRA_A
# [1] 0.5871261
#
# $LMPRA_AB
# [1] 0.5935571
#
# $LMPRA_I
# [1] 0.3069909
#
# $LMPRA_R
# [1] 0.5919118
#
# $LMPRA_T
# [1] 0.56223
#
# [1] "TMPRA"
# $TMPRA_A
# [1] 0.4096257
#
# $TMPRA_I
# [1] 0.1994382
#
# $TMPRA_R
# [1] 0.375
#
# $TMPRA_T
# [1] 0.315042
#
# [1] "WSTARR"
# $WSTARR_A
# [1] 0.4876806
#
# $WSTARR_AB
# [1] 0.5938451
#
# $WSTARR_I
# [1] 0.2191714
#
# $WSTARR_R
# [1] 0.3299455
#
# $WSTARR_T
# [1] 0.2636531

# %%
### init
vec_peak_feature = vec_peak_atac_loop_overlap

### init
dat_merge = dat_peak_atac_merge
lst_merge = split(dat_merge, dat_merge$Assay_Type)

lst = lapply(names(lst_merge), function(txt_assay){
    
    dat_assay = lst_merge[[txt_assay]]
    
    lst = split(dat_assay$Peak, dat_assay$Assay_Label)
    txt = paste(txt_assay, "T", sep="_")
    
    vec_peak_total  = lst[[txt]]
    vec_peak_sample = vec_peak_total
    #num_peak_total  = length(vec_peak_total)
    #vec_peak_sample = sample(vec_peak_total, size = as.integer(num_peak_total * 0.9))
    
    lst = lapply(lst, function(vec_peak_group){
        vec = intersect(vec_peak_sample, vec_peak_group)
        vec = vec %in% vec_peak_feature
        num = mean(vec)
        return(num)
    })
    return(lst)
})

# %%
vec = unlist(lst)
vec_txt_assay_label = names(vec)

dat = data.frame(
    "Assay_Label" = names(vec),
    "Freq"        = vec
)

dat = dat %>% 
    dplyr::mutate(Assay_Type = Assay_Label) %>%
    dplyr::mutate(Assay_Type = str_remove(Assay_Type, pattern = "_AB|_R|_I|_T")) %>%
    dplyr::mutate(Assay_Type = str_remove(Assay_Type, pattern = "_A"))
    

dat = dat %>%
    dplyr::arrange(Assay_Type, Assay_Label) %>%
    dplyr::mutate(Assay_Label = factor(Assay_Label, levels=Assay_Label))

dat_freq = dat
dat
# Out:
#                         Assay_Label             Freq      Assay_Type
# ASTARR_A                ASTARR_A                0.6850680 ASTARR
# ASTARR_AB               ASTARR_AB               0.6981065 ASTARR
# ASTARR_I                ASTARR_I                0.7459247 ASTARR
# ASTARR_R                ASTARR_R                0.7405888 ASTARR
# ASTARR_T                ASTARR_T                0.2636581 ASTARR
# ATAC_A                  ATAC_A                  0.7777553 ATAC
# ATAC_I                  ATAC_I                  0.2057432 ATAC
# ATAC_T                  ATAC_T                  0.2629444 ATAC
# CRISPRi_Growth_A        CRISPRi_Growth_A        0.6149500 CRISPRi_Growth
# CRISPRi_Growth_I        CRISPRi_Growth_I        0.5586734 CRISPRi_Growth
# CRISPRi_Growth_T        CRISPRi_Growth_T        0.5612918 CRISPRi_Growth
# CRISPRi_HCRFF_A         CRISPRi_HCRFF_A         0.7777778 CRISPRi_HCRFF
# CRISPRi_HCRFF_I         CRISPRi_HCRFF_I         0.3789308 CRISPRi_HCRFF
# CRISPRi_HCRFF_T         CRISPRi_HCRFF_T         0.3962406 CRISPRi_HCRFF
# ENCODE-E2G_Benchmark_A  ENCODE-E2G_Benchmark_A  0.8385269 ENCODE-E2G_Benchmark
# ENCODE-E2G_Benchmark_I  ENCODE-E2G_Benchmark_I  0.6650321 ENCODE-E2G_Benchmark
# ENCODE-E2G_Benchmark_T  ENCODE-E2G_Benchmark_T  0.6856287 ENCODE-E2G_Benchmark
# ENCODE-E2G_Prediction_A ENCODE-E2G_Prediction_A 0.6721518 ENCODE-E2G_Prediction
# ENCODE-E2G_Prediction_I ENCODE-E2G_Prediction_I 0.4507587 ENCODE-E2G_Prediction
# ENCODE-E2G_Prediction_T ENCODE-E2G_Prediction_T 0.5447230 ENCODE-E2G_Prediction
# LMPRA_A                 LMPRA_A                 0.5875000 LMPRA
# LMPRA_AB                LMPRA_AB                0.5942952 LMPRA
# LMPRA_I                 LMPRA_I                 0.3005464 LMPRA
# LMPRA_R                 LMPRA_R                 0.5959821 LMPRA
# LMPRA_T                 LMPRA_T                 0.5627448 LMPRA
# TMPRA_A                 TMPRA_A                 0.4093067 TMPRA
# TMPRA_I                 TMPRA_I                 0.1928021 TMPRA
# TMPRA_R                 TMPRA_R                 0.3529412 TMPRA
# TMPRA_T                 TMPRA_T                 0.3170732 TMPRA
# WSTARR_A                WSTARR_A                0.4882210 WSTARR
# WSTARR_AB               WSTARR_AB               0.5921962 WSTARR
# WSTARR_I                WSTARR_I                0.2196201 WSTARR
# WSTARR_R                WSTARR_R                0.3281528 WSTARR
# WSTARR_T                WSTARR_T                0.2637907 WSTARR

# %%
dat = dat_freq
gpt = ggplot(dat, aes(x=Assay_Label, y=Freq, fill=Assay_Type)) + 
    geom_col() + 
    coord_flip() +
    theme_cowplot() 
print(gpt)
# Out:
# plot without title

# %%
dat = dat_freq
dat = dat %>% dplyr::filter(!(str_detect(Assay_Label, pattern = "_AB")))
gpt = ggplot(dat, aes(x=Assay_Label, y=Freq, fill=Assay_Type)) +
    geom_col() + 
    labs(x="Assay", y="Proportion of Loop") +
    coord_flip() +
    theme_cowplot() 

options(repr.plot.width=10, repr.plot.height=7)
print(gpt)
# Out:
# plot without title

# %%
fun_get_label = function(txt){
    vec_pattern = c("_A", "_T", "_R", "_I")
    vec_label   = c("Active", "Total", "Repress", "Inactive")
    idx = str_detect(string = txt, pattern = vec_pattern)
    res = vec_label[idx]
    return(res)
}

# %%
for (x in dat_freq$Assay_Label)

# %%
dat = dat_freq
dat = dat %>% dplyr::filter(!(str_detect(Assay_Label, pattern = "_AB")))
dat = dat %>% 
    dplyr::rowwise() %>%
    dplyr::mutate(Label = fun_get_label(Assay_Label)) %>%
    dplyr::ungroup()

dat = dat %>% 
    dplyr::filter(Label %in% c("Active", "Inactive")) %>%
    dplyr::select(Assay_Type, Label, Freq) %>%
    tidyr::spread(Label, Freq) %>%
    dplyr::mutate(Ratio = log10(Active / Inactive))

gpt = ggplot(dat, aes(x=Assay_Type, y=Ratio, fill=Assay_Type)) +
    geom_col() + 
    labs(x="Assay", y="Log10(Active vs Inactive)") +
    coord_flip() +
    theme_cowplot() 

options(repr.plot.width=10, repr.plot.height=5)
print(gpt)
# Out:
# plot without title
