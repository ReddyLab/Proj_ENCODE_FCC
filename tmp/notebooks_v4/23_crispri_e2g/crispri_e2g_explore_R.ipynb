# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %%
fdiry = file.path(FD_RES, "source")
dir(fdiry)
# Out:
#  [1] "A001_K562_wstarrseq_fragments"
#  [2] "A001_K562_wstarrseq_fragments_wgs"
#  [3] "annotation_cCREs"
#  [4] "annotation_chipseq_histone"
#  [5] "annotation_chipseq_tf"
#  [6] "annotation_chromHMM"
#  [7] "annotation_enhancer_junke"
#  [8] "annotation_enhancer_junke_zscore_230420"
#  [9] "annotation_enhancer_junke_zscore_prev"
# [10] "annotation_gencode"
# [11] "annotation_gene"
# [12] "annotation_remap2022"
# [13] "chrom.sizes.hg19"
# [14] "chrom.sizes.hg38"
# [15] "CRISPR_E2G"
# [16] "CRISPRi_FlowFISH"
# [17] "CRISPRi_growth"
# [18] "hic_intact_K562_deep"
# [19] "hic_intact_K562_ENCSR479XDG"
# [20] "KS91_K562_astarrseq_fragments_220510"
# [21] "KS91_K562_astarrseq_fragments_wgs"
# [22] "KS91_K562_astarrseq_peak_macs"
# [23] "MPRA"
# [24] "negative_control_junke"
# [25] "Readme.md"
# [26] "TF_modules"
# [27] "tmp"

# %%
fdiry = file.path(FD_RES, "source", "CRISPR_E2G")
fname = "EPCrisprBenchmark_ensemble_data_GRCh38.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath, show_col_types = FALSE)

dat_crispr_e2g = dat
print(dim(dat))
head(dat)
# Out:
# [1] 10412    25
#   dataset       chrom chromStart chromEnd name
# 1 FlowFISH_K562 chr1  3774714    3775214  CEP104|chr1:3691278-3691778:*
# 2 FlowFISH_K562 chr1  3774714    3775214  LRRC47|chr1:3691278-3691778:*
# 3 Gasperini2019 chr1  3803570    3805848  LRRC47|chr1:3720134-3722412:.
# 4 FlowFISH_K562 chr1  3774714    3775214  SMIM1|chr1:3691278-3691778:*
# 5 Gasperini2019 chr1  3803570    3805848  SMIM1|chr1:3720134-3722412:.
# 6 Gasperini2019 chr1  4126791    4127291  SMIM1|chr1:4186851-4187351:.
#   EffectSize   chrTSS startTSS endTSS  measuredGeneSymbol ⋯
# 1 -0.293431866 chr1   3857213  3857214 CEP104             ⋯
# 2 -0.331178093 chr1   3796503  3796504 LRRC47             ⋯
# 3 -0.001471265 chr1   3796503  3796504 LRRC47             ⋯
# 4 -0.472019217 chr1   3772761  3772762 SMIM1              ⋯
# 5  0.025676924 chr1   3772788  3772789 SMIM1              ⋯
# 6  0.023383787 chr1   3772788  3772789 SMIM1              ⋯
# ...

# %%
dat = dat_crispr_e2g
dat = dat %>% dplyr::select(dataset, CellType, Reference) %>% distinct
dat
# Out:
#    dataset       CellType Reference
# 1  FlowFISH_K562 K562     Ulirsch2016
# 2  Gasperini2019 K562     Gasperini et al., 2019
# 3  FlowFISH_K562 K562     Wakabayashi2016
# 4  TAPseq        K562     Schraivogel et al., 2020
# 5  FlowFISH_K562 K562     Klann2017
# 6  FlowFISH_K562 K562     Thakore2015
# 7  FlowFISH_K562 K562     Xie2017
# 8  FlowFISH_K562 K562     Fulco2019
# 9  FlowFISH_K562 K562     Qi2018
# 10 FlowFISH_K562 K562     Huang2018
# 11 FlowFISH_K562 K562     Xu2015
# 12 FlowFISH_K562 K562     Fulco2016

# %%
knitr::kable(dat, "html") %>% as.character() %>% IRdisplay::display_html()
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> dataset </th>
#    <th style="text-align:left;"> CellType </th>
#    <th style="text-align:left;"> Reference </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> FlowFISH_K562 </td>
#    <td style="text-align:left;"> K562 </td>
#    <td style="text-align:left;"> Ulirsch2016 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Gasperini2019 </td>
#    <td style="text-align:left;"> K562 </td>
#    <td style="text-align:left;"> Gasperini et al., 2019 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> FlowFISH_K562 </td>
#    <td style="text-align:left;"> K562 </td>
#    <td style="text-align:left;"> Wakabayashi2016 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> TAPseq </td>
#    <td style="text-align:left;"> K562 </td>
#    <td style="text-align:left;"> Schraivogel et al., 2020 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> FlowFISH_K562 </td>
# ...

# %%
dat = dat_crispr_e2g
dat = table(dat$Reference) %>% as.data.frame 
colnames(dat) = c("Reference", "Count")

dat = dat %>% dplyr::arrange(-Count)
head(dat)
# Out:
#   Reference                Count
# 1 Gasperini et al., 2019   5355
# 2 Fulco2019                3501
# 3 Schraivogel et al., 2020 1306
# 4 Klann2017                 122
# 5 Fulco2016                 103
# 6 Huang2018                   7

# %%
knitr::kable(dat, "html") %>% as.character() %>% IRdisplay::display_html()
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Reference </th>
#    <th style="text-align:right;"> Count </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> Gasperini et al., 2019 </td>
#    <td style="text-align:right;"> 5355 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Fulco2019 </td>
#    <td style="text-align:right;"> 3501 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Schraivogel et al., 2020 </td>
#    <td style="text-align:right;"> 1306 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Klann2017 </td>
#    <td style="text-align:right;"> 122 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Fulco2016 </td>
#    <td style="text-align:right;"> 103 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Huang2018 </td>
#    <td style="text-align:right;"> 7 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Xie2017 </td>
#    <td style="text-align:right;"> 6 </td>
#   </tr>
# ...

# %%
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Reference </th>
#    <th style="text-align:right;"> Count </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> Fulco2016 </td>
#    <td style="text-align:right;"> 103 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Fulco2019 </td>
#    <td style="text-align:right;"> 3501 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Gasperini et al., 2019 </td>
#    <td style="text-align:right;"> 5355 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Huang2018 </td>
#    <td style="text-align:right;"> 7 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Klann2017 </td>
#    <td style="text-align:right;"> 122 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Qi2018 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Schraivogel et al., 2020 </td>
#    <td style="text-align:right;"> 1306 </td>
#   </tr>
# ...
