# %% [markdown]
# **Set environment**

# %%
### set env
source ../config/config_duke.sh
source ../config/config_load_module_bedtools.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## CRISPRi-HCRFF

# %%
FD_REG=${FD_RES}/results/region

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz 
FP_BED_INP1=${FDIRY}/${FNAME}

FDIRY=${FD_REG}
FNAME=region_screened_crispri_flowfish.bed
FP_BED_INP2=${FDIRY}/${FNAME}

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.screened.crispri_hcrff.bed.gz 
FP_BED_OUT=${FDIRY}/${FNAME}

./run_bed_intersect_test.sh ${FP_BED_INP1} ${FP_BED_INP2} ${FP_BED_OUT}
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         08-15-23+10:12:36
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/region_screened_crispri_flowfish.bed
#
# show first few lines of input
# chr11	4091884	6419310	HBE1,HBG1,HBG2,HBS1L,MYB
# chr11	33064196	34664117	CAPRIN1,CAT,LMO2
# chr11	61788524	61897153	FADS1,FADS2,FADS3,FEN1
# chr12	54300766	54301042	GATA1,HDAC6
# chr12	110726151	112325737	ERP29
# chr19	12887110	12887237	GATA1,HDAC6
# chr3	128487571	128487937	GATA1,HDAC6
# chr4	55237590	56068531	NMU
# ...

# %%
FD_REG=${FD_RES}/results/region

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz 
FP_BED_INP1=${FDIRY}/${FNAME}

FDIRY=${FD_REG}
FNAME=region_screened_crispri_flowfish.bed
FP_BED_INP2=${FDIRY}/${FNAME}

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.screened.crispri_hcrff.bed.gz 
FP_BED_OUT=${FDIRY}/${FNAME}

./run_bed_intersect.sh ${FP_BED_INP1} ${FP_BED_INP2} ${FP_BED_OUT}
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         08-15-23+10:12:38
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/region_screened_crispri_flowfish.bed
#
# show first few lines of input
# chr11	4091884	6419310	HBE1,HBG1,HBG2,HBS1L,MYB
# chr11	33064196	34664117	CAPRIN1,CAT,LMO2
# chr11	61788524	61897153	FADS1,FADS2,FADS3,FEN1
# chr12	54300766	54301042	GATA1,HDAC6
# chr12	110726151	112325737	ERP29
# chr19	12887110	12887237	GATA1,HDAC6
# chr3	128487571	128487937	GATA1,HDAC6
# chr4	55237590	56068531	NMU
# ...

# %% [markdown]
# ## TMPRA

# %%
FD_REG=${FD_RES}/results/region

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz 
FP_BED_INP1=${FDIRY}/${FNAME}

FDIRY=${FD_REG}
FNAME=region_screened_tmpra.bed
FP_BED_INP2=${FDIRY}/${FNAME}

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.screened.tmpra.bed.gz 
FP_BED_OUT=${FDIRY}/${FNAME}

./run_bed_intersect_test.sh ${FP_BED_INP1} ${FP_BED_INP2} ${FP_BED_OUT}
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         08-15-23+10:12:58
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/region_screened_tmpra.bed
#
# show first few lines of input
# chr11	4505501	6505900	HBE1	OL45
# chr11	32869701	34870100	LMO2	OL45
# chr11	61787329	61898348	FADS	OL13
# chr16	10001	1173100	HBA2	OL45
# chr2	59553301	61553700	BCL11A	OL45
# chr20	56391301	58391700	RBM38	OL45
# chr8	126735901	128736550	MYC	OL43
# chrX	47785501	49880650	GATA1	OL43
#
#
# ...

# %%
FD_REG=${FD_RES}/results/region

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz 
FP_BED_INP1=${FDIRY}/${FNAME}

FDIRY=${FD_REG}
FNAME=region_screened_tmpra.bed
FP_BED_INP2=${FDIRY}/${FNAME}

FDIRY=${FD_REG}/KS91_K562_ASTARRseq_peak_macs_input
FNAME=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.screened.tmpra.bed.gz 
FP_BED_OUT=${FDIRY}/${FNAME}

./run_bed_intersect.sh ${FP_BED_INP1} ${FP_BED_INP2} ${FP_BED_OUT}
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         08-15-23+10:13:12
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/region_screened_tmpra.bed
#
# show first few lines of input
# chr11	4505501	6505900	HBE1	OL45
# chr11	32869701	34870100	LMO2	OL45
# chr11	61787329	61898348	FADS	OL13
# chr16	10001	1173100	HBA2	OL45
# chr2	59553301	61553700	BCL11A	OL45
# chr20	56391301	58391700	RBM38	OL45
# chr8	126735901	128736550	MYC	OL43
# chrX	47785501	49880650	GATA1	OL43
#
#
# ...
