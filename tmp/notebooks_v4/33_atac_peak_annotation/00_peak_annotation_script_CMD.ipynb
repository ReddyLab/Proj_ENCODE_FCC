# %% [markdown]
# **Set environment**

# %%
### set env
source ../config/config_duke.sh
source ../config/config_load_module_bedtools.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## **Script**

# %% [markdown]
# ### Test script

# %%
cat > run_bedtools_test.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute
bedtools -h

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x run_bedtools_test.sh

# %% [markdown]
# ### Annotation with requirement on A and B

# %%
cat > run_bedtools_annot.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_REG=$1
FP_ANT=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_REG}
echo
echo "show first few lines of input"
zcat ${FP_REG} | head -5
echo
echo "Input: " ${FP_ANT}
echo
echo "show first few lines of input"
zcat ${FP_ANT} | head -5
echo

### execute: annotation using intersect
bedtools intersect \
    -a ${FP_REG} \
    -b ${FP_ANT} \
    -wo \
    -f 0.7 \
    -F 0.7 \
    -e \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
zcat ${FP_OUT} | head -5
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x run_annot.sh

# %% [markdown]
# ### Annotate with requirement only on A

# %%
cat > run_bedtools_annot_A.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_BED_INP1=$1
FP_BED_INP2=$2
FP_BED_OUT=$3

### show I/O file
echo "Input: " ${FP_BED_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_BED_INP1}
echo
echo "Input: " ${FP_BED_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_BED_INP2}
echo

### execute: annotation using intersect
bedtools intersect \
    -a ${FP_BED_INP1} \
    -b ${FP_BED_INP2} \
    -wo \
    -f 0.7 \
| gzip -c \
> ${FP_BED_OUT}

### show output file
echo
echo "Output: " ${FP_BED_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_BED_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x run_bed_annot_A.sh

# %% [markdown]
# ### Intersect and inverse

# %%
cat > run_bedtools_intersect.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_BED_INP1=$1
FP_BED_INP2=$2
FP_BED_OUT=$3

### show I/O file
echo "Input: " ${FP_BED_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_BED_INP1}
echo
echo "Input: " ${FP_BED_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_BED_INP2}
echo

### execute: annotation using intersect
bedtools intersect \
    -a ${FP_BED_INP1} \
    -b ${FP_BED_INP2} \
    -wo \
| gzip -c \
> ${FP_BED_OUT}

### show output file
echo
echo "Output: " ${FP_BED_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_BED_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x run_bed_intersect.sh

# %%
cat > run_bedtools_intersect_inv.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_BED_INP1=$1
FP_BED_INP2=$2
FP_BED_OUT=$3

### show I/O file
echo "Input: " ${FP_BED_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_BED_INP1}
echo
echo "Input: " ${FP_BED_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_BED_INP2}
echo

### execute: annotation using intersect
bedtools intersect \
    -a ${FP_BED_INP1} \
    -b ${FP_BED_INP2} \
    -v    \
| gzip -c \
> ${FP_BED_OUT}

### show output file
echo
echo "Output: " ${FP_BED_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_BED_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x run_bed_intersect_inv.sh

# %% [markdown]
# ### Closest
# Similar to intersect, closest searches for overlapping features in A and B.

# %%
cat > run_bedtools_closest.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute
bedtools closest \
    -a ${FP_INP1} \
    -b ${FP_INP2} \
    -d    \
| awk '{ if($4 != ".") { print }}' \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x run_bedtools_closest.sh

# %%
FD_REG=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input
FN_REG=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
FP_REG=${FD_REG}/${FN_REG}
ls   ${FP_REG}
zcat ${FP_REG} | head
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429

# %%
FOLDER=annotation_enhancer_zscore_junke
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# enhancer_zscore_junke.peak.ASTARR.bed.gz
# enhancer_zscore_junke.peak.LMPRA.bed.gz
# enhancer_zscore_junke.peak.TMPRA.bed.gz
# enhancer_zscore_junke.peak.WSTARR.bed.gz

# %%
FD_REG=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input
FN_REG=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
FP_REG=${FD_REG}/${FN_REG}

FOLDER=annotation_enhancer_zscore_junke
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo ${FD_OUT}

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG=${FD_LOG}/peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo ${PREFIX}
    echo ${FN_ANT}
    echo ${FN_OUT}
    echo ${FN_LOG}
    echo ${FP_LOG}
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot_test.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_enhancer_zscore_junke
# enhancer_zscore_junke.peak.ASTARR
# enhancer_zscore_junke.peak.ASTARR.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.ASTARR.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.ASTARR.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.enhancer_zscore_junke.peak.ASTARR.0.txt
# Submitted batch job 29918998
#
# enhancer_zscore_junke.peak.LMPRA
# enhancer_zscore_junke.peak.LMPRA.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.LMPRA.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.LMPRA.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.enhancer_zscore_junke.peak.LMPRA.0.txt
# Submitted batch job 29918999
#
# enhancer_zscore_junke.peak.TMPRA
# enhancer_zscore_junke.peak.TMPRA.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.TMPRA.bed.gz
# ...

# %%
cat /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.enhancer_zscore_junke.peak.ASTARR.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-06-23+13:11:23
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_enhancer_zscore_junke/enhancer_zscore_junke.peak.ASTARR.bed.gz
#
# show first few lines of input
# chr1	136520	136950	peak1	-1.603467695889237	.	ASTARR	ASTARR_R
# chr1	137050	137150	peak2	-1.4084640632794576	.	ASTARR	ASTARR_R
# chr1	181600	181790	peak3	-1.9131552198942965	.	ASTARR	ASTARR_R
# chr1	778720	778830	peak1	2.0095770203893415	.	ASTARR	ASTARR_A
# chr1	827060	827160	peak4	-1.383606425443357	.	ASTARR	ASTARR_R
#
#
# ...

# %%
FD_REG=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input
FN_REG=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
FP_REG=${FD_REG}/${FN_REG}

FOLDER=annotation_enhancer_zscore_junke
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo ${FD_OUT}

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG=${FD_LOG}/peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo ${PREFIX}
    echo ${FN_ANT}
    echo ${FN_OUT}
    echo ${FN_LOG}
    echo ${FP_LOG}
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_enhancer_zscore_junke
# enhancer_zscore_junke.peak.ASTARR
# enhancer_zscore_junke.peak.ASTARR.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.ASTARR.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.ASTARR.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.enhancer_zscore_junke.peak.ASTARR.0.txt
# Submitted batch job 29919002
#
# enhancer_zscore_junke.peak.LMPRA
# enhancer_zscore_junke.peak.LMPRA.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.LMPRA.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.LMPRA.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.enhancer_zscore_junke.peak.LMPRA.0.txt
# Submitted batch job 29919003
#
# enhancer_zscore_junke.peak.TMPRA
# enhancer_zscore_junke.peak.TMPRA.bed.gz
# peak.annotation.enhancer_zscore_junke.peak.TMPRA.bed.gz
# ...

# %%
cat /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.enhancer_zscore_junke.peak.ASTARR.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-06-23+13:11:29
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_enhancer_zscore_junke/enhancer_zscore_junke.peak.ASTARR.bed.gz
#
# show first few lines of input
# chr1	136520	136950	peak1	-1.603467695889237	.	ASTARR	ASTARR_R
# chr1	137050	137150	peak2	-1.4084640632794576	.	ASTARR	ASTARR_R
# chr1	181600	181790	peak3	-1.9131552198942965	.	ASTARR	ASTARR_R
# chr1	778720	778830	peak1	2.0095770203893415	.	ASTARR	ASTARR_A
# chr1	827060	827160	peak4	-1.383606425443357	.	ASTARR	ASTARR_R
#
#
# ...
