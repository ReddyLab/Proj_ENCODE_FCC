# %% [markdown]
# **Set environment**

# %%
### set env
source ../config/config_duke.sh
source ../config/config_load_module_bedtools.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## Region to annotation: ATAC peaks

# %%
FD_REG=${FD_RES}/results/region/KS91_K562_ASTARRseq_peak_macs_input
FN_REG=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
FP_REG=${FD_REG}/${FN_REG}
ls   ${FP_REG}
zcat ${FP_REG} | head
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429

# %% [markdown]
# ## Annotation: Enhancer calls from Junke

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_enhancer_zscore_junke
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# enhancer_zscore_junke.peak.ASTARR_AB.bed.gz
# enhancer_zscore_junke.peak.ASTARR_A.bed.gz
# enhancer_zscore_junke.peak.ASTARR.bed.gz
# enhancer_zscore_junke.peak.ASTARR_R.bed.gz
# enhancer_zscore_junke.peak.LMPRA_AB.bed.gz
# enhancer_zscore_junke.peak.LMPRA_A.bed.gz
# enhancer_zscore_junke.peak.LMPRA.bed.gz
# enhancer_zscore_junke.peak.LMPRA_R.bed.gz
# enhancer_zscore_junke.peak.STARRMPRA.bed.gz
# enhancer_zscore_junke.peak.TMPRA_A.bed.gz
# enhancer_zscore_junke.peak.TMPRA.bed.gz
# enhancer_zscore_junke.peak.TMPRA_R.bed.gz
# enhancer_zscore_junke.peak.WSTARR_AB.bed.gz
# enhancer_zscore_junke.peak.WSTARR_A.bed.gz
# enhancer_zscore_junke.peak.WSTARR.bed.gz
# enhancer_zscore_junke.peak.WSTARR_R.bed.gz

# %% [markdown]
# **Annotatoin**

# %%
FOLDER=annotation_enhancer_zscore_junke
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_enhancer_zscore_junke
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.ASTARR_AB
# File Name   (Annotation): enhancer_zscore_junke.peak.ASTARR_AB.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.ASTARR_AB.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.ASTARR_AB.0.txt
#
# Submitted batch job 29960067
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.ASTARR_A
# File Name   (Annotation): enhancer_zscore_junke.peak.ASTARR_A.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.ASTARR_A.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.ASTARR_A.0.txt
#
# Submitted batch job 29960068
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.ASTARR
# File Name   (Annotation): enhancer_zscore_junke.peak.ASTARR.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.ASTARR.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.ASTARR.0.txt
#
# Submitted batch job 29960069
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.ASTARR_R
# File Name   (Annotation): enhancer_zscore_junke.peak.ASTARR_R.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.ASTARR_R.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.ASTARR_R.0.txt
#
# Submitted batch job 29960070
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.LMPRA_AB
# File Name   (Annotation): enhancer_zscore_junke.peak.LMPRA_AB.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.LMPRA_AB.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.LMPRA_AB.0.txt
#
# Submitted batch job 29960071
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.LMPRA_A
# File Name   (Annotation): enhancer_zscore_junke.peak.LMPRA_A.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.LMPRA_A.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.LMPRA_A.0.txt
#
# Submitted batch job 29960072
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.LMPRA
# File Name   (Annotation): enhancer_zscore_junke.peak.LMPRA.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.LMPRA.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.LMPRA.0.txt
#
# Submitted batch job 29960073
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.LMPRA_R
# File Name   (Annotation): enhancer_zscore_junke.peak.LMPRA_R.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.LMPRA_R.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.LMPRA_R.0.txt
#
# Submitted batch job 29960074
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.STARRMPRA
# File Name   (Annotation): enhancer_zscore_junke.peak.STARRMPRA.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.STARRMPRA.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.STARRMPRA.0.txt
#
# Submitted batch job 29960075
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.TMPRA_A
# File Name   (Annotation): enhancer_zscore_junke.peak.TMPRA_A.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.TMPRA_A.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.TMPRA_A.0.txt
#
# Submitted batch job 29960076
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.TMPRA
# File Name   (Annotation): enhancer_zscore_junke.peak.TMPRA.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.TMPRA.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.TMPRA.0.txt
#
# Submitted batch job 29960077
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.TMPRA_R
# File Name   (Annotation): enhancer_zscore_junke.peak.TMPRA_R.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.TMPRA_R.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.TMPRA_R.0.txt
#
# Submitted batch job 29960078
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.WSTARR_AB
# File Name   (Annotation): enhancer_zscore_junke.peak.WSTARR_AB.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.WSTARR_AB.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.WSTARR_AB.0.txt
#
# Submitted batch job 29960079
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.WSTARR_A
# File Name   (Annotation): enhancer_zscore_junke.peak.WSTARR_A.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.WSTARR_A.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.WSTARR_A.0.txt
#
# Submitted batch job 29960080
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.WSTARR
# File Name   (Annotation): enhancer_zscore_junke.peak.WSTARR.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.WSTARR.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.WSTARR.0.txt
#
# Submitted batch job 29960081
#
# File Prefix (Annotation): enhancer_zscore_junke.peak.WSTARR_R
# File Name   (Annotation): enhancer_zscore_junke.peak.WSTARR_R.bed.gz
# File Name (Output): peak.annotation.enhancer_zscore_junke.peak.WSTARR_R.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.WSTARR_R.0.txt
#
# Submitted batch job 29960082

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.enhancer_zscore_junke.peak.ASTARR_AB.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:08:41
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_enhancer_zscore_junke/enhancer_zscore_junke.peak.ASTARR_AB.bed.gz
#
# show first few lines of input
# chr1	1013020	1013470	peak_both_1	2.1815960444053615	.	ASTARR	ASTARR_AB
# chr1	1724540	1724700	peak_both_2	2.15437368509707	.	ASTARR	ASTARR_AB
# chr1	2290700	2291030	peak_both_3	2.388581751849955	.	ASTARR	ASTARR_AB
# chr1	3313260	3313400	peak_both_4	2.179445521958002	.	ASTARR	ASTARR_AB
# chr1	5856530	5856630	peak_both_5	1.9965321443474449	.	ASTARR	ASTARR_AB
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_enhancer_zscore_junke/peak.annotation.enhancer_zscore_junke.peak.ASTARR_AB.bed.gz
#
# show first few lines of output:
# chr1	1012902	1014502	chr1	1013020	1013470	peak_both_1	2.1815960444053615	.	ASTARR	ASTARR_AB	450
# chr1	1723926	1724986	chr1	1724540	1724700	peak_both_2	2.15437368509707	.	ASTARR	ASTARR_AB	160
# chr1	2289710	2291474	chr1	2290700	2291030	peak_both_3	2.388581751849955	.	ASTARR	ASTARR_AB	330
# chr1	3312817	3313807	chr1	3313260	3313400	peak_both_4	2.179445521958002	.	ASTARR	ASTARR_AB	140
# chr1	5855596	5857313	chr1	5856530	5856630	peak_both_5	1.9965321443474449	.	ASTARR	ASTARR_AB	100
#
#
# Done!
# Run Time: 0 seconds

# %% [markdown]
# ## Annotation: CRISPRi-HCRFF

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_crispri_hcrff
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# crispri_hcrff_casa.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_crispri_hcrff
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_crispri_hcrff
#
# File Prefix (Annotation): crispri_hcrff_casa
# File Name   (Annotation): crispri_hcrff_casa.bed.gz
# File Name (Output): peak.annotation.crispri_hcrff_casa.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.crispri_hcrff_casa.0.txt
#
# Submitted batch job 29960083

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.crispri_hcrff_casa.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:08:57
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_crispri_hcrff/crispri_hcrff_casa.bed.gz
#
# show first few lines of input
# chr11	33944871	33945471	chr11:33944871-33945471	0.803764617	.	CAPRIN1	ENSG00000135387	CRISPRi-HCRFF	CRISPRi-HCRFF:CAPRIN1
# chr11	34050971	34051471	chr11:34050971-34051471	0.973987294	.	CAPRIN1	ENSG00000135387	CRISPRi-HCRFF	CRISPRi-HCRFF:CAPRIN1
# chr11	34051571	34054171	chr11:34051571-34054171	2.06429067	.	CAPRIN1	ENSG00000135387	CRISPRi-HCRFF	CRISPRi-HCRFF:CAPRIN1
# chr11	34085871	34086871	chr11:34085871-34086871	1.009272431	.	CAPRIN1	ENSG00000135387	CRISPRi-HCRFF	CRISPRi-HCRFF:CAPRIN1
# chr11	33944868	33945268	chr11:33944868-33945268	1.214675507	.	CAT	ENSG00000121691	CRISPRi-HCRFF	CRISPRi-HCRFF:CAT
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_crispri_hcrff/peak.annotation.crispri_hcrff_casa.bed.gz
#
# show first few lines of output:
# chr11	5249943	5250880	chr11	5249847	5250847	chr11:5249847-5250847	1.8908898984108689	.	HBG1	ENST00000330597.5	CRISPRi-HCRFF	CRISPRi-HCRFF:HBG1	904
# chr11	5249943	5250880	chr11	5249847	5250847	chr11:5249847-5250847	1.9229557946824665	.	HBG2	ENST00000336906.6	CRISPRi-HCRFF	CRISPRi-HCRFF:HBG2	904
# chr11	5254190	5254453	chr11	5253647	5254647	chr11:5253647-5254647	1.5044043629848811	.	HBG1	ENST00000330597.5	CRISPRi-HCRFF	CRISPRi-HCRFF:HBG1	263
# chr11	5254190	5254453	chr11	5253647	5254647	chr11:5253647-5254647	1.430535293771277	.	HBG2	ENST00000336906.6	CRISPRi-HCRFF	CRISPRi-HCRFF:HBG2	263
# chr11	5269440	5270695	chr11	5269147	5271147	chr11:5269147-5271147	1.906478008877551	.	HBE1	ENST00000336906.6	CRISPRi-HCRFF	CRISPRi-HCRFF:HBE1	1255
#
#
# Done!
# Run Time: 0 seconds

# %% [markdown]
# ## Annotation: CRISPRi-Growth

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_crispri_growth
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# crispri_growth_dhs.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_crispri_growth
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
mkdir -p ${FD_OUT}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_crispri_growth
#
# File Prefix (Annotation): crispri_growth_dhs
# File Name   (Annotation): crispri_growth_dhs.bed.gz
# File Name (Output): peak.annotation.crispri_growth_dhs.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.crispri_growth_dhs.0.txt
#
# Submitted batch job 29960161

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.crispri_growth_dhs.0.txt
# Out:
# Hostname:           x1-02-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+17:50:40
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_crispri_growth/crispri_growth_dhs.bed.gz
#
# show first few lines of input
# chr1	605550	605627	chr1.1.1	-0.985933797051245	3.24578658189092e-11	CRISPRi-Growth	CRISPRi-Growth
# chr1	826642	827902	chr1.4.8	0.185507412283124	0.0325051212861127	CRISPRi-Growth	CRISPRi-Growth
# chr1	964946	965136	chr1.41.7	-1.1466792071519	1.46465391074394e-26	CRISPRi-Growth	CRISPRi-Growth
# chr1	995761	996190	chr1.53.2	0.21410749393477305	0.0187408911746605	CRISPRi-Growth	CRISPRi-Growth
# chr1	1067929	1070953	chr1.74.8	-0.338370170783949	0.0337196418434639	CRISPRi-Growth	CRISPRi-Growth
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_crispri_growth/peak.annotation.crispri_growth_dhs.bed.gz
#
# show first few lines of output:
# chr1	605090	605823	chr1	605550	605627	chr1.1.1	-0.985933797051245	3.24578658189092e-11	CRISPRi-Growth	CRISPRi-Growth	77
# chr1	826754	828040	chr1	826642	827902	chr1.4.8	0.185507412283124	0.0325051212861127	CRISPRi-Growth	CRISPRi-Growth	1148
# chr1	1067955	1068196	chr1	1067929	1070953	chr1.74.8	-0.338370170783949	0.0337196418434639	CRISPRi-Growth	CRISPRi-Growth	241
# chr1	1068570	1070643	chr1	1067929	1070953	chr1.74.8	-0.338370170783949	0.0337196418434639	CRISPRi-Growth	CRISPRi-Growth	2073
# chr1	1298873	1300608	chr1	1300037	1300357	chr1.170.3	-1.05531374805495	2.46224280386627e-12	CRISPRi-Growth	CRISPRi-Growth	320
#
#
# Done!
# Run Time: 1 seconds

# %% [markdown]
# ## Annotation: CRISPRi-E2G

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_crispri_e2g
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# crispri_e2g_region.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_crispri_e2g
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
mkdir -p ${FD_OUT}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_crispri_e2g
#
# File Prefix (Annotation): crispri_e2g_region
# File Name   (Annotation): crispri_e2g_region.bed.gz
# File Name (Output): peak.annotation.crispri_e2g_region.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.crispri_e2g_region.0.txt
#
# Submitted batch job 30021843

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.crispri_e2g_region.0.txt
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-22-23+14:43:53
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_crispri_e2g/crispri_e2g_region.bed.gz
#
# show first few lines of input
# chr1	8858063	8858563	ENO1|chr1:8918122-8918622:.	-0.10741	ENO1	chr1:8879248-8879249	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:ENO1
# chr1	17441310	17441810	SDHB|chr1:17767806-17768306:.	-0.08968	SDHB	chr1:17054169-17054170	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:SDHB
# chr1	25933351	25933954	NUDC|chr1:26259842-26260445:.	-0.08462	NUDC	chr1:26900238-26900239	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:NUDC
# chr1	25933351	25933954	STMN1|chr1:26259842-26260445:.	-0.12223	STMN1	chr1:25906990-25906991	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:STMN1
# chr1	26377523	26378866	LIN28A|chr1:26704014-26705357:.	-0.05172	LIN28A	chr1:26410778-26410779	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:LIN28A
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_crispri_e2g/peak.annotation.crispri_e2g_region.bed.gz
#
# show first few lines of output:
# chr1	8857749	8858710	chr1	8858063	8858563	ENO1|chr1:8918122-8918622:.	-0.10741	ENO1	chr1:8879248-8879249	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:ENO1	500
# chr1	25932957	25934403	chr1	25933351	25933954	NUDC|chr1:26259842-26260445:.	-0.08462	NUDC	chr1:26900238-26900239	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:NUDC	603
# chr1	25932957	25934403	chr1	25933351	25933954	STMN1|chr1:26259842-26260445:.	-0.12223	STMN1	chr1:25906990-25906991	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:STMN1	603
# chr1	26378063	26379023	chr1	26377523	26378866	LIN28A|chr1:26704014-26705357:.	-0.05172	LIN28A	chr1:26410778-26410779	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:LIN28A	803
# chr1	28883554	28885530	chr1	28883765	28884265	EPB41|chr1:29210277-29210777:.	-0.26521	EPB41	chr1:28887091-28887092	Gasperini et al., 2019	CRISPRi-E2G	CRISPRi-E2G:EPB41	500
#
#
# Done!
# Run Time: 0 seconds

# %% [markdown]
# ## Annotation: TSS

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_tss_pol2
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# K562.TSS.selected_by_highest_Pol2_signal.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_tss_pol2
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_tss_pol2
#
# File Prefix (Annotation): K562.TSS.selected_by_highest_Pol2_signal
# File Name   (Annotation): K562.TSS.selected_by_highest_Pol2_signal.bed.gz
# File Name (Output): peak.annotation.K562.TSS.selected_by_highest_Pol2_signal.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.TSS.selected_by_highest_Pol2_signal.0.txt
#
# Submitted batch job 29960085

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.K562.TSS.selected_by_highest_Pol2_signal.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:09:22
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_tss_pol2/K562.TSS.selected_by_highest_Pol2_signal.bed.gz
#
# show first few lines of input
# chr1	11873	11874	DDX11L1	2.3e-4
# chr1	17436	17437	MIR6859-1	9.43812
# chr1	17436	17437	MIR6859-2	9.43812
# chr1	17436	17437	MIR6859-3	9.43812
# chr1	17436	17437	MIR6859-4	9.43812
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_tss_pol2/peak.annotation.K562.TSS.selected_by_highest_Pol2_signal.bed.gz
#
# show first few lines of output:
# chr1	17237	17772	chr1	17436	17437	MIR6859-1	9.43812	1
# chr1	17237	17772	chr1	17436	17437	MIR6859-2	9.43812	1
# chr1	17237	17772	chr1	17436	17437	MIR6859-3	9.43812	1
# chr1	17237	17772	chr1	17436	17437	MIR6859-4	9.43812	1
# chr1	28903	29613	chr1	29370	29371	WASH7P	2.3e-4	1
#
#
# Done!
# Run Time: 0 seconds

# %% [markdown]
# ## Annotation: cCREs

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_ccre
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# ccre_v3.bed.gz
# ccre_v4.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_ccre
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
mkdir -p ${FD_OUT}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_ccre
#
# File Prefix (Annotation): ccre_v3
# File Name   (Annotation): ccre_v3.bed.gz
# File Name (Output): peak.annotation.ccre_v3.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.ccre_v3.0.txt
#
# Submitted batch job 29960125
#
# File Prefix (Annotation): ccre_v4
# File Name   (Annotation): ccre_v4.bed.gz
# File Name (Output): peak.annotation.ccre_v4.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.ccre_v4.0.txt
#
# Submitted batch job 29960126

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.ccre_v3.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:26:34
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_ccre/ccre_v3.bed.gz
#
# show first few lines of input
# chr1	181251	181601	EH38E1310153	0	.	181251	181601	6,218,147	DNase-only	All-data/Full-classification
# chr1	190865	191071	EH38E1310154	0	.	190865	191071	225,225,225	Low-DNase	All-data/Full-classification
# chr1	778562	778912	EH38E1310158	0	.	778562	778912	255,0,0	PLS,CTCF-bound	All-data/Full-classification
# chr1	779086	779355	EH38E1310159	0	.	779086	779355	255,0,0	PLS	All-data/Full-classification
# chr1	779727	780060	EH38E1310160	0	.	779727	780060	225,225,225	Low-DNase	All-data/Full-classification
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_ccre/peak.annotation.ccre_v3.bed.gz
#
# show first few lines of output:
# chr1	180982	182087	chr1	181251	181601	EH38E1310153	0	.	181251	181601	6,218,147	DNase-only	All-data/Full-classification	350
# chr1	777949	779437	chr1	778562	778912	EH38E1310158	0	.	778562	778912	255,0,0	PLS,CTCF-bound	All-data/Full-classification	350
# chr1	777949	779437	chr1	779086	779355	EH38E1310159	0	.	779086	779355	255,0,0	PLS	All-data/Full-classification	269
# chr1	816774	817547	chr1	817080	817403	EH38E1310166	0	.	817080	817403	225,225,225	Low-DNase	All-data/Full-classification	323
# chr1	817905	818348	chr1	817903	818252	EH38E1310167	0	.	817903	818252	225,225,225	Low-DNase	All-data/Full-classification	347
#
#
# Done!
# Run Time: 4 seconds

# %%
cat ${FD_LOG}/peak.annotation.ccre_v4.0.txt
# Out:
# Hostname:           x1-03-2.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:26:34
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_ccre/ccre_v4.bed.gz
#
# show first few lines of input
# chr1	10033	10250	EH38E2776516	0	.	10033	10250	225,225,225	Low-DNase	All-data/Full-classification
# chr1	10385	10713	EH38E2776517	0	.	10385	10713	225,225,225	Low-DNase	All-data/Full-classification
# chr1	16097	16381	EH38E3951272	0	.	16097	16381	225,225,225	Low-DNase	All-data/Full-classification
# chr1	17343	17642	EH38E3951273	0	.	17343	17642	225,225,225	Low-DNase	All-data/Full-classification
# chr1	29320	29517	EH38E3951274	0	.	29320	29517	225,225,225	Low-DNase	All-data/Full-classification
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_ccre/peak.annotation.ccre_v4.bed.gz
#
# show first few lines of output:
# chr1	10015	10442	chr1	10033	10250	EH38E2776516	0	.	10033	10250	225,225,225	Low-DNase	All-data/Full-classification	217
# chr1	16015	16477	chr1	16097	16381	EH38E3951272	0	.	16097	16381	225,225,225	Low-DNase	All-data/Full-classification	284
# chr1	17237	17772	chr1	17343	17642	EH38E3951273	0	.	17343	17642	225,225,225	Low-DNase	All-data/Full-classification	299
# chr1	28903	29613	chr1	29320	29517	EH38E3951274	0	.	29320	29517	225,225,225	Low-DNase	All-data/Full-classification	197
# chr1	115411	115986	chr1	115562	115912	EH38E3951280	0	.	115562	115912	0,176,240	CA-CTCF	All-data/Full-classification	350
#
#
# Done!
# Run Time: 11 seconds

# %% [markdown]
# ## Annotation: ChromHMM

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_chromHMM
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# K562.ENCSR365YNI.ENCFF106BGJ.ChromHMM.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_chromHMM
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_chromHMM
#
# File Prefix (Annotation): K562.ENCSR365YNI.ENCFF106BGJ.ChromHMM
# File Name   (Annotation): K562.ENCSR365YNI.ENCFF106BGJ.ChromHMM.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR365YNI.ENCFF106BGJ.ChromHMM.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR365YNI.ENCFF106BGJ.ChromHMM.0.txt
#
# Submitted batch job 29966139

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.K562.ENCSR365YNI.ENCFF106BGJ.ChromHMM.0.txt
# Out:
# Hostname:           x2-04-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-12-23+14:31:22
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_chromHMM/K562.ENCSR365YNI.ENCFF106BGJ.ChromHMM.bed.gz
#
# show first few lines of input
# chr1	0	16000	Quies	1	.	0	16000	220,220,220
# chr1	16000	16200	TxWk	1	.	16000	16200	63,154,80
# chr1	16200	17400	Quies	1	.	16200	17400	220,220,220
# chr1	17400	17600	TxWk	1	.	17400	17600	63,154,80
# chr1	17600	118400	Quies	1	.	17600	118400	220,220,220

# %% [markdown]
# ## Annotation: ChIP-seq Histone modification

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_chipseq_histone
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz
# K562.ENCSR000AKQ.ENCFF323WOT.H3K27me3.bed.gz
# K562.ENCSR000AKR.ENCFF193ERO.H3K36me3.bed.gz
# K562.ENCSR000AKS.ENCFF135ZLM.H3K4me1.bed.gz
# K562.ENCSR000AKT.ENCFF749KLQ.H3K4me2.bed.gz
# K562.ENCSR000AKU.ENCFF689QIJ.H3K4me3.bed.gz
# K562.ENCSR000AKV.ENCFF891CHI.H3K9ac.bed.gz
# K562.ENCSR000AKW.ENCFF462AVD.H3K9me1.bed.gz
# K562.ENCSR000AKX.ENCFF909RKY.H4K20me1.bed.gz
# K562.ENCSR000APC.ENCFF213OTI.H2AFZ.bed.gz
# K562.ENCSR000APD.ENCFF209OQD.H3K79me2.bed.gz
# K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.bed.gz
# K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3.bed.gz
# K562.ENCSR000DWD.ENCFF706WUF.H3K4me3.bed.gz
# K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.bed.gz
# K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.bed.gz
# K562.ENCSR668LDD.ENCFF885FQN.H3K4me3.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_chipseq_histone
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    echo "File Name   (Annotation):" ${FN_ANT}
    echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation
bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AKX.ENCFF909RKY.H4K20me1.0.txt
#
# Submitted batch job 29960096
#
# File Prefix (Annotation): K562.ENCSR000APC.ENCFF213OTI.H2AFZ
# File Name   (Annotation): K562.ENCSR000APC.ENCFF213OTI.H2AFZ.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000APC.ENCFF213OTI.H2AFZ.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000APC.ENCFF213OTI.H2AFZ.0.txt
#
# Submitted batch job 29960097
#
# File Prefix (Annotation): K562.ENCSR000APD.ENCFF209OQD.H3K79me2
# File Name   (Annotation): K562.ENCSR000APD.ENCFF209OQD.H3K79me2.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000APD.ENCFF209OQD.H3K79me2.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000APD.ENCFF209OQD.H3K79me2.0.txt
#
# Submitted batch job 29960098
#
# File Prefix (Annotation): K562.ENCSR000APE.ENCFF963GZJ.H3K9me3
# File Name   (Annotation): K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000APE.ENCFF963GZJ.H3K9me3.0.txt
#
# Submitted batch job 29960099
#
# File Prefix (Annotation): K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3
# File Name   (Annotation): K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DWB.ENCFF561OUZ.H3K36me3.0.txt
#
# Submitted batch job 29960100
#
# File Prefix (Annotation): K562.ENCSR000DWD.ENCFF706WUF.H3K4me3
# File Name   (Annotation): K562.ENCSR000DWD.ENCFF706WUF.H3K4me3.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000DWD.ENCFF706WUF.H3K4me3.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DWD.ENCFF706WUF.H3K4me3.0.txt
#
# Submitted batch job 29960101
#
# File Prefix (Annotation): K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac
# File Name   (Annotation): K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EVZ.ENCFF148UQI.H3K9ac.0.txt
#
# Submitted batch job 29960102
#
# File Prefix (Annotation): K562.ENCSR000EWA.ENCFF122CSI.H3K4me3
# File Name   (Annotation): K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWA.ENCFF122CSI.H3K4me3.0.txt
#
# Submitted batch job 29960103
#
# File Prefix (Annotation): K562.ENCSR000EWB.ENCFF801AHF.H3K27me3
# File Name   (Annotation): K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWB.ENCFF801AHF.H3K27me3.0.txt
#
# Submitted batch job 29960104
#
# File Prefix (Annotation): K562.ENCSR000EWC.ENCFF540NGG.H3K4me1
# File Name   (Annotation): K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWC.ENCFF540NGG.H3K4me1.0.txt
#
# Submitted batch job 29960105
#
# File Prefix (Annotation): K562.ENCSR668LDD.ENCFF885FQN.H3K4me3
# File Name   (Annotation): K562.ENCSR668LDD.ENCFF885FQN.H3K4me3.bed.gz
# File Name (Output): peak.annotation.K562.ENCSR668LDD.ENCFF885FQN.H3K4me3.bed.gz
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR668LDD.ENCFF885FQN.H3K4me3.0.txt
#
# Submitted batch job 29960106

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:09:57
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_chipseq_histone/K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz
#
# show first few lines of input
# chr1	118751	119101	Peak_29282	111	.	5.05870	11.17124	9.08295	187
# chr1	120082	120287	Peak_29283	111	.	4.92747	11.17124	9.08295	171
# chr1	137650	138169	Peak_16228	317	.	9.24885	31.74444	29.32013	338
# chr1	138356	139236	Peak_19531	228	.	7.55215	22.82356	20.52066	178
# chr1	139285	139490	Peak_33716	88	.	4.27130	8.85756	6.82864	172
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_chipseq_histone/peak.annotation.K562.ENCSR000AKP.ENCFF544LXB.H3K27ac.bed.gz
#
# show first few lines of output:
# chr1	137737	139544	chr1	137650	138169	Peak_16228	317	.	9.24885	31.74444	29.32013	338	432
# chr1	137737	139544	chr1	138356	139236	Peak_19531	228	.	7.55215	22.82356	20.52066	178	880
# chr1	137737	139544	chr1	139285	139490	Peak_33716	88	.	4.27130	8.85756	6.82864	172	205
# chr1	777949	779437	chr1	777712	778823	Peak_6597	939	.	19.33186	93.91751	90.86520	823	874
# chr1	777949	779437	chr1	778887	779412	Peak_16912	296	.	8.99031	29.63080	27.23310	306	525
#
#
# Done!
# Run Time: 1 seconds

# %% [markdown]
# ## Annotation: ChIP-seq TF (Subset)

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_chipseq_tf_subset
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# K562.ENCSR000BMH.ENCFF398UQZ.YY1.bed.gz
# K562.ENCSR000BMW.ENCFF707MDI.REST.bed.gz
# K562.ENCSR000EFS.ENCFF190CGV.JUN.bed.gz
# K562.ENCSR000EFT.ENCFF657CTC.GATA1.bed.gz
# K562.ENCSR000EFU.ENCFF715WGN.ELK1.bed.gz
# K562.ENCSR000EGE.ENCFF702XPO.EP300.bed.gz
# K562.ENCSR000EGM.ENCFF660GHM.CTCF.bed.gz
# K562.ENCSR000EHB.ENCFF852ZRK.TAL1.bed.gz
# K562.ENCSR004GKA.ENCFF242AOL.ZEB2.bed.gz
# K562.ENCSR091GVJ.ENCFF627RSK.ATF1.bed.gz
# K562.ENCSR121SPB.ENCFF142ZTD.KLF10.bed.gz
# K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz
# K562.ENCSR552YGL.ENCFF023IFO.NFE2.bed.gz
# K562.ENCSR760UVO.ENCFF488OTN.KLF16.bed.gz
# K562.ENCSR991ELG.ENCFF553GPK.SP1.bed.gz
# K562.ENCSR998AJK.ENCFF777PKJ.NRF1.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_chipseq_tf_subset
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG=${FD_LOG}/peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo ${PREFIX}
    echo ${FN_ANT}
    echo ${FN_OUT}
    echo ${FN_LOG}
    echo ${FP_LOG}
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_chipseq_tf_subset
#
# K562.ENCSR000BMH.ENCFF398UQZ.YY1
# K562.ENCSR000BMH.ENCFF398UQZ.YY1.bed.gz
# peak.annotation.K562.ENCSR000BMH.ENCFF398UQZ.YY1.bed.gz
# peak.annotation.K562.ENCSR000BMH.ENCFF398UQZ.YY1.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000BMH.ENCFF398UQZ.YY1.0.txt
# Submitted batch job 29960107
#
# K562.ENCSR000BMW.ENCFF707MDI.REST
# K562.ENCSR000BMW.ENCFF707MDI.REST.bed.gz
# peak.annotation.K562.ENCSR000BMW.ENCFF707MDI.REST.bed.gz
# peak.annotation.K562.ENCSR000BMW.ENCFF707MDI.REST.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000BMW.ENCFF707MDI.REST.0.txt
# Submitted batch job 29960108
#
# K562.ENCSR000EFS.ENCFF190CGV.JUN
# K562.ENCSR000EFS.ENCFF190CGV.JUN.bed.gz
# peak.annotation.K562.ENCSR000EFS.ENCFF190CGV.JUN.bed.gz
# peak.annotation.K562.ENCSR000EFS.ENCFF190CGV.JUN.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000EFS.ENCFF190CGV.JUN.0.txt
# Submitted batch job 29960109
#
# K562.ENCSR000EFT.ENCFF657CTC.GATA1
# K562.ENCSR000EFT.ENCFF657CTC.GATA1.bed.gz
# peak.annotation.K562.ENCSR000EFT.ENCFF657CTC.GATA1.bed.gz
# peak.annotation.K562.ENCSR000EFT.ENCFF657CTC.GATA1.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000EFT.ENCFF657CTC.GATA1.0.txt
# Submitted batch job 29960110
#
# K562.ENCSR000EFU.ENCFF715WGN.ELK1
# K562.ENCSR000EFU.ENCFF715WGN.ELK1.bed.gz
# peak.annotation.K562.ENCSR000EFU.ENCFF715WGN.ELK1.bed.gz
# peak.annotation.K562.ENCSR000EFU.ENCFF715WGN.ELK1.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000EFU.ENCFF715WGN.ELK1.0.txt
# Submitted batch job 29960111
#
# K562.ENCSR000EGE.ENCFF702XPO.EP300
# K562.ENCSR000EGE.ENCFF702XPO.EP300.bed.gz
# peak.annotation.K562.ENCSR000EGE.ENCFF702XPO.EP300.bed.gz
# peak.annotation.K562.ENCSR000EGE.ENCFF702XPO.EP300.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000EGE.ENCFF702XPO.EP300.0.txt
# Submitted batch job 29960112
#
# K562.ENCSR000EGM.ENCFF660GHM.CTCF
# K562.ENCSR000EGM.ENCFF660GHM.CTCF.bed.gz
# peak.annotation.K562.ENCSR000EGM.ENCFF660GHM.CTCF.bed.gz
# peak.annotation.K562.ENCSR000EGM.ENCFF660GHM.CTCF.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000EGM.ENCFF660GHM.CTCF.0.txt
# Submitted batch job 29960113
#
# K562.ENCSR000EHB.ENCFF852ZRK.TAL1
# K562.ENCSR000EHB.ENCFF852ZRK.TAL1.bed.gz
# peak.annotation.K562.ENCSR000EHB.ENCFF852ZRK.TAL1.bed.gz
# peak.annotation.K562.ENCSR000EHB.ENCFF852ZRK.TAL1.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR000EHB.ENCFF852ZRK.TAL1.0.txt
# Submitted batch job 29960114
#
# K562.ENCSR004GKA.ENCFF242AOL.ZEB2
# K562.ENCSR004GKA.ENCFF242AOL.ZEB2.bed.gz
# peak.annotation.K562.ENCSR004GKA.ENCFF242AOL.ZEB2.bed.gz
# peak.annotation.K562.ENCSR004GKA.ENCFF242AOL.ZEB2.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR004GKA.ENCFF242AOL.ZEB2.0.txt
# Submitted batch job 29960115
#
# K562.ENCSR091GVJ.ENCFF627RSK.ATF1
# K562.ENCSR091GVJ.ENCFF627RSK.ATF1.bed.gz
# peak.annotation.K562.ENCSR091GVJ.ENCFF627RSK.ATF1.bed.gz
# peak.annotation.K562.ENCSR091GVJ.ENCFF627RSK.ATF1.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR091GVJ.ENCFF627RSK.ATF1.0.txt
# Submitted batch job 29960116
#
# K562.ENCSR121SPB.ENCFF142ZTD.KLF10
# K562.ENCSR121SPB.ENCFF142ZTD.KLF10.bed.gz
# peak.annotation.K562.ENCSR121SPB.ENCFF142ZTD.KLF10.bed.gz
# peak.annotation.K562.ENCSR121SPB.ENCFF142ZTD.KLF10.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR121SPB.ENCFF142ZTD.KLF10.0.txt
# Submitted batch job 29960117
#
# K562.ENCSR388QZF.ENCFF355MNE.POLR2A
# K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz
# peak.annotation.K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz
# peak.annotation.K562.ENCSR388QZF.ENCFF355MNE.POLR2A.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR388QZF.ENCFF355MNE.POLR2A.0.txt
# Submitted batch job 29960118
#
# K562.ENCSR552YGL.ENCFF023IFO.NFE2
# K562.ENCSR552YGL.ENCFF023IFO.NFE2.bed.gz
# peak.annotation.K562.ENCSR552YGL.ENCFF023IFO.NFE2.bed.gz
# peak.annotation.K562.ENCSR552YGL.ENCFF023IFO.NFE2.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR552YGL.ENCFF023IFO.NFE2.0.txt
# Submitted batch job 29960119
#
# K562.ENCSR760UVO.ENCFF488OTN.KLF16
# K562.ENCSR760UVO.ENCFF488OTN.KLF16.bed.gz
# peak.annotation.K562.ENCSR760UVO.ENCFF488OTN.KLF16.bed.gz
# peak.annotation.K562.ENCSR760UVO.ENCFF488OTN.KLF16.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR760UVO.ENCFF488OTN.KLF16.0.txt
# Submitted batch job 29960120
#
# K562.ENCSR991ELG.ENCFF553GPK.SP1
# K562.ENCSR991ELG.ENCFF553GPK.SP1.bed.gz
# peak.annotation.K562.ENCSR991ELG.ENCFF553GPK.SP1.bed.gz
# peak.annotation.K562.ENCSR991ELG.ENCFF553GPK.SP1.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR991ELG.ENCFF553GPK.SP1.0.txt
# Submitted batch job 29960121
#
# K562.ENCSR998AJK.ENCFF777PKJ.NRF1
# K562.ENCSR998AJK.ENCFF777PKJ.NRF1.bed.gz
# peak.annotation.K562.ENCSR998AJK.ENCFF777PKJ.NRF1.bed.gz
# peak.annotation.K562.ENCSR998AJK.ENCFF777PKJ.NRF1.%a.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR998AJK.ENCFF777PKJ.NRF1.0.txt
# Submitted batch job 29960122

# %% [markdown]
# **Check results**

# %%
cat /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/peak.annotation.K562.ENCSR388QZF.ENCFF355MNE.POLR2A.0.txt
# Out:
# Hostname:           x1-03-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:10:06
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_chipseq_tf_subset/K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz
#
# show first few lines of input
# chr1	17333	17518	.	1000	.	79.27235	-1.00000	4.75617	151
# chr1	115625	115913	.	1000	.	113.27279	-1.00000	4.75617	123
# chr1	184346	184650	.	927	.	72.17743	-1.00000	4.75617	143
# chr1	605043	605719	.	1000	.	82.60300	-1.00000	4.75617	338
# chr1	778259	779068	.	1000	.	889.18667	-1.00000	4.75617	331
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_chipseq_tf_subset/peak.annotation.K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz
#
# show first few lines of output:
# chr1	17237	17772	chr1	17333	17518	.	1000	.	79.27235	-1.00000	4.75617	151	185
# chr1	115411	115986	chr1	115625	115913	.	1000	.	113.27279	-1.00000	4.75617	123	288
# chr1	183239	184602	chr1	184346	184650	.	927	.	72.17743	-1.00000	4.75617	143	256
# chr1	605090	605823	chr1	605043	605719	.	1000	.	82.60300	-1.00000	4.75617	338	629
# chr1	777949	779437	chr1	778259	779068	.	1000	.	889.18667	-1.00000	4.75617	331	809
#
#
# Done!
# Run Time: 1 seconds

# %% [markdown]
# ## Annotation: ChIP-seq TF (FULL)

# %% [markdown]
# **Check data**

# %%
FOLDER=annotation_chipseq_tf
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

basename -a ${FP_ANTS[@]}
# Out:
# K562.ENCSR000AKO.ENCFF769AUF.CTCF.bed.gz
# K562.ENCSR000AQA.ENCFF807FNB.KDM5B.bed.gz
# K562.ENCSR000AQD.ENCFF408NUX.CHD1.bed.gz
# K562.ENCSR000AQE.ENCFF804RVA.EZH2.bed.gz
# K562.ENCSR000AQF.ENCFF669MJX.HDAC1.bed.gz
# K562.ENCSR000AQG.ENCFF182MPT.HDAC2.bed.gz
# K562.ENCSR931HNY.ENCFF660DEP.NCOA1.bed.gz
# K562.ENCSR934RJP.ENCFF798AFV.ZNF3.bed.gz
# K562.ENCSR935PEA.ENCFF875JMR.CREB5.bed.gz
# K562.ENCSR935UQL.ENCFF188PLS.MECOM.bed.gz
# K562.ENCSR939CDD.ENCFF086FAZ.ARID4B.bed.gz
# K562.ENCSR942XQI.ENCFF330SHG.RAD21.bed.gz
# K562.ENCSR946BXO.ENCFF620FIH.BRCA1.bed.gz
# K562.ENCSR946WBN.ENCFF865UPM.JUN.bed.gz
# K562.ENCSR947PJZ.ENCFF449JMB.HIVEP1.bed.gz
# K562.ENCSR948JND.ENCFF380KJB.ZNF398.bed.gz
# K562.ENCSR948KMB.ENCFF835NOD.PTBP1.bed.gz
# K562.ENCSR948QLZ.ENCFF470CSE.CBX1.bed.gz
# K562.ENCSR948VFL.ENCFF637SIR.IKZF1.bed.gz
# K562.ENCSR949NVY.ENCFF669VJB.ZNF639.bed.gz
# K562.ENCSR953DVM.ENCFF925GLW.E2F8.bed.gz
# K562.ENCSR953KEY.ENCFF592NJN.TFE3.bed.gz
# K562.ENCSR957LDM.ENCFF597YMB.TRIM24.bed.gz
# K562.ENCSR958JPH.ENCFF144ZLB.TSHZ1.bed.gz
# K562.ENCSR959BQO.ENCFF208OME.ZNF700.bed.gz
# K562.ENCSR968GIB.ENCFF768VRG.RFX1.bed.gz
# K562.ENCSR970NKQ.ENCFF746GDG.NR2F1.bed.gz
# K562.ENCSR970OJY.ENCFF773RNU.TCF3.bed.gz
# K562.ENCSR971EWR.ENCFF604LXR.ETV5.bed.gz
# K562.ENCSR972CVS.ENCFF198NGY.ELK3.bed.gz
# K562.ENCSR972ZBV.ENCFF951BFN.ATF7.bed.gz
# K562.ENCSR975SSR.ENCFF133TSU.ELF1.bed.gz
# K562.ENCSR979QYJ.ENCFF986SXD.MNT.bed.gz
# K562.ENCSR980ZWE.ENCFF201BGD.NR3C1.bed.gz
# K562.ENCSR985OYK.ENCFF227HVU.ZBTB11.bed.gz
# K562.ENCSR986CDX.ENCFF625QHR.NEUROD1.bed.gz
# K562.ENCSR987KYK.ENCFF159END.ZNF717.bed.gz
# K562.ENCSR987PBI.ENCFF412WOK.DNMT1.bed.gz
# K562.ENCSR990AZC.ENCFF583XAW.MCM3.bed.gz
# K562.ENCSR991ELG.ENCFF553GPK.SP1.bed.gz
# K562.ENCSR992KLV.ENCFF749GMT.MYNN.bed.gz
# K562.ENCSR995FUM.ENCFF670RLH.ZNF79.bed.gz
# K562.ENCSR996ESX.ENCFF321LMQ.NFRKB.bed.gz
# K562.ENCSR996SKD.ENCFF798LLI.CXXC5.bed.gz
# K562.ENCSR997NGQ.ENCFF137OGC.XRCC3.bed.gz
# K562.ENCSR998AJK.ENCFF777PKJ.NRF1.bed.gz
# K562.ENCSR998OMC.ENCFF392MAR.TFCP2.bed.gz

# %% [markdown]
# **Execute**

# %%
FOLDER=annotation_chipseq_tf
FD_ANT=${FD_RES}/results/region/${FOLDER}
FP_ANTS=($(ls ${FD_ANT}/*bed.gz))

FD_OUT=${FD_REG}/${FOLDER}
echo "File Folder (Output):"
echo ${FD_OUT}
echo 

for FP_ANT in ${FP_ANTS[@]}; do
    FN_ANT=$(basename ${FP_ANT})
    PREFIX=${FN_ANT%.bed.gz}
    
    FN_LOG=peak.annotation.${PREFIX}.%a.txt
    FP_LOG='${FD_LOG}/'peak.annotation.${PREFIX}.0.txt
    
    FD_OUT=${FD_REG}/${FOLDER}
    FN_OUT=peak.annotation.${FN_ANT}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    echo "File Prefix (Annotation):" ${PREFIX}
    #echo "File Name   (Annotation):" ${FN_ANT}
    #echo "File Name (Output):" ${FN_OUT}
    echo "File Path (Log):   " ${FP_LOG}
    #echo
    sbatch -p ${NODE} \
        --exclude=dl-01 \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FD_LOG}/${FN_LOG} \
        --array 0 \
        ./run_annot.sh ${FP_REG} ${FP_ANT} ${FP_OUT}
    echo
done
# Out:
# File Folder (Output):
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_chipseq_tf
#
# File Prefix (Annotation): K562.ENCSR000AKO.ENCFF769AUF.CTCF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AKO.ENCFF769AUF.CTCF.0.txt
# Submitted batch job 29959332
#
# File Prefix (Annotation): K562.ENCSR000AQA.ENCFF807FNB.KDM5B
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQA.ENCFF807FNB.KDM5B.0.txt
# Submitted batch job 29959333
#
# File Prefix (Annotation): K562.ENCSR000AQD.ENCFF408NUX.CHD1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQD.ENCFF408NUX.CHD1.0.txt
# Submitted batch job 29959334
#
# File Prefix (Annotation): K562.ENCSR000AQE.ENCFF804RVA.EZH2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQE.ENCFF804RVA.EZH2.0.txt
# Submitted batch job 29959335
#
# File Prefix (Annotation): K562.ENCSR000AQF.ENCFF669MJX.HDAC1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQF.ENCFF669MJX.HDAC1.0.txt
# Submitted batch job 29959336
#
# File Prefix (Annotation): K562.ENCSR000AQG.ENCFF182MPT.HDAC2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQG.ENCFF182MPT.HDAC2.0.txt
# Submitted batch job 29959337
#
# File Prefix (Annotation): K562.ENCSR000AQH.ENCFF981ISM.PHF8
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQH.ENCFF981ISM.PHF8.0.txt
# Submitted batch job 29959338
#
# File Prefix (Annotation): K562.ENCSR000AQI.ENCFF942VGF.RBBP5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQI.ENCFF942VGF.RBBP5.0.txt
# Submitted batch job 29959339
#
# File Prefix (Annotation): K562.ENCSR000AQJ.ENCFF383IEP.SAP30
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AQJ.ENCFF383IEP.SAP30.0.txt
# Submitted batch job 29959340
#
# File Prefix (Annotation): K562.ENCSR000ATJ.ENCFF736FGN.HDAC6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATJ.ENCFF736FGN.HDAC6.0.txt
# Submitted batch job 29959341
#
# File Prefix (Annotation): K562.ENCSR000ATL.ENCFF985QBS.CHD4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATL.ENCFF985QBS.CHD4.0.txt
# Submitted batch job 29959342
#
# File Prefix (Annotation): K562.ENCSR000ATM.ENCFF539MIO.REST
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATM.ENCFF539MIO.REST.0.txt
# Submitted batch job 29959343
#
# File Prefix (Annotation): K562.ENCSR000ATT.ENCFF532VPN.CREBBP
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATT.ENCFF532VPN.CREBBP.0.txt
# Submitted batch job 29959344
#
# File Prefix (Annotation): K562.ENCSR000ATU.ENCFF258XBJ.CBX2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATU.ENCFF258XBJ.CBX2.0.txt
# Submitted batch job 29959345
#
# File Prefix (Annotation): K562.ENCSR000ATV.ENCFF068OEJ.CBX3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATV.ENCFF068OEJ.CBX3.0.txt
# Submitted batch job 29959346
#
# File Prefix (Annotation): K562.ENCSR000ATW.ENCFF522HZT.CBX8
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATW.ENCFF522HZT.CBX8.0.txt
# Submitted batch job 29959347
#
# File Prefix (Annotation): K562.ENCSR000ATX.ENCFF054XCG.KDM1A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATX.ENCFF054XCG.KDM1A.0.txt
# Submitted batch job 29959348
#
# File Prefix (Annotation): K562.ENCSR000ATY.ENCFF816AEF.NCOR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATY.ENCFF816AEF.NCOR1.0.txt
# Submitted batch job 29959349
#
# File Prefix (Annotation): K562.ENCSR000ATZ.ENCFF349VSP.KAT2B
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000ATZ.ENCFF349VSP.KAT2B.0.txt
# Submitted batch job 29959350
#
# File Prefix (Annotation): K562.ENCSR000AUA.ENCFF923GDR.RNF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AUA.ENCFF923GDR.RNF2.0.txt
# Submitted batch job 29959351
#
# File Prefix (Annotation): K562.ENCSR000AUB.ENCFF821XJU.SIRT6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AUB.ENCFF821XJU.SIRT6.0.txt
# Submitted batch job 29959352
#
# File Prefix (Annotation): K562.ENCSR000AUC.ENCFF647TBC.SUZ12
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AUC.ENCFF647TBC.SUZ12.0.txt
# Submitted batch job 29959353
#
# File Prefix (Annotation): K562.ENCSR000AUT.ENCFF267QRI.SETDB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AUT.ENCFF267QRI.SETDB1.0.txt
# Submitted batch job 29959354
#
# File Prefix (Annotation): K562.ENCSR000AVD.ENCFF722UJW.CHD7
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AVD.ENCFF722UJW.CHD7.0.txt
# Submitted batch job 29959355
#
# File Prefix (Annotation): K562.ENCSR000AVE.ENCFF862UUR.WHSC1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000AVE.ENCFF862UUR.WHSC1.0.txt
# Submitted batch job 29959356
#
# File Prefix (Annotation): K562.ENCSR000BGW.ENCFF888CKG.SPI1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BGW.ENCFF888CKG.SPI1.0.txt
# Submitted batch job 29959357
#
# File Prefix (Annotation): K562.ENCSR000BGX.ENCFF742ZHT.SIX5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BGX.ENCFF742ZHT.SIX5.0.txt
# Submitted batch job 29959358
#
# File Prefix (Annotation): K562.ENCSR000BKF.ENCFF146GZZ.ZBTB33
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKF.ENCFF146GZZ.ZBTB33.0.txt
# Submitted batch job 29959359
#
# File Prefix (Annotation): K562.ENCSR000BKH.ENCFF070ZTX.BCLAF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKH.ENCFF070ZTX.BCLAF1.0.txt
# Submitted batch job 29959360
#
# File Prefix (Annotation): K562.ENCSR000BKM.ENCFF242YZU.GATA2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKM.ENCFF242YZU.GATA2.0.txt
# Submitted batch job 29959361
#
# File Prefix (Annotation): K562.ENCSR000BKO.ENCFF171NEU.SP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKO.ENCFF171NEU.SP1.0.txt
# Submitted batch job 29959362
#
# File Prefix (Annotation): K562.ENCSR000BKQ.ENCFF886BDQ.ETS1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKQ.ENCFF886BDQ.ETS1.0.txt
# Submitted batch job 29959363
#
# File Prefix (Annotation): K562.ENCSR000BKR.ENCFF060MMW.POLR2AphosphoS5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKR.ENCFF060MMW.POLR2AphosphoS5.0.txt
# Submitted batch job 29959364
#
# File Prefix (Annotation): K562.ENCSR000BKS.ENCFF784BTI.TAF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKS.ENCFF784BTI.TAF1.0.txt
# Submitted batch job 29959365
#
# File Prefix (Annotation): K562.ENCSR000BKT.ENCFF310CCS.USF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKT.ENCFF310CCS.USF1.0.txt
# Submitted batch job 29959366
#
# File Prefix (Annotation): K562.ENCSR000BKU.ENCFF074OAM.YY1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKU.ENCFF074OAM.YY1.0.txt
# Submitted batch job 29959367
#
# File Prefix (Annotation): K562.ENCSR000BKV.ENCFF930WPG.RAD21
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BKV.ENCFF930WPG.RAD21.0.txt
# Submitted batch job 29959368
#
# File Prefix (Annotation): K562.ENCSR000BLI.ENCFF831NDQ.E2F6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BLI.ENCFF831NDQ.E2F6.0.txt
# Submitted batch job 29959369
#
# File Prefix (Annotation): K562.ENCSR000BLK.ENCFF101SEZ.SRF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BLK.ENCFF101SEZ.SRF.0.txt
# Submitted batch job 29959370
#
# File Prefix (Annotation): K562.ENCSR000BLO.ENCFF489EME.GABPA
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BLO.ENCFF489EME.GABPA.0.txt
# Submitted batch job 29959371
#
# File Prefix (Annotation): K562.ENCSR000BLP.ENCFF822FKQ.MAX
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BLP.ENCFF822FKQ.MAX.0.txt
# Submitted batch job 29959372
#
# File Prefix (Annotation): K562.ENCSR000BLR.ENCFF884MNF.SIN3A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BLR.ENCFF884MNF.SIN3A.0.txt
# Submitted batch job 29959373
#
# File Prefix (Annotation): K562.ENCSR000BMD.ENCFF688TNZ.ELF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BMD.ENCFF688TNZ.ELF1.0.txt
# Submitted batch job 29959374
#
# File Prefix (Annotation): K562.ENCSR000BME.ENCFF346AOR.ZBTB7A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BME.ENCFF346AOR.ZBTB7A.0.txt
# Submitted batch job 29959375
#
# File Prefix (Annotation): K562.ENCSR000BMG.ENCFF630HGY.HDAC2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BMG.ENCFF630HGY.HDAC2.0.txt
# Submitted batch job 29959376
#
# File Prefix (Annotation): K562.ENCSR000BMH.ENCFF398UQZ.YY1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BMH.ENCFF398UQZ.YY1.0.txt
# Submitted batch job 29959377
#
# File Prefix (Annotation): K562.ENCSR000BMR.ENCFF634JRD.POLR2A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BMR.ENCFF634JRD.POLR2A.0.txt
# Submitted batch job 29959378
#
# File Prefix (Annotation): K562.ENCSR000BMV.ENCFF004HXL.FOSL1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BMV.ENCFF004HXL.FOSL1.0.txt
# Submitted batch job 29959379
#
# File Prefix (Annotation): K562.ENCSR000BMW.ENCFF707MDI.REST
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BMW.ENCFF707MDI.REST.0.txt
# Submitted batch job 29959380
#
# File Prefix (Annotation): K562.ENCSR000BNE.ENCFF566PRZ.EGR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNE.ENCFF566PRZ.EGR1.0.txt
# Submitted batch job 29959381
#
# File Prefix (Annotation): K562.ENCSR000BNK.ENCFF630YVJ.CTCFL
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNK.ENCFF630YVJ.CTCFL.0.txt
# Submitted batch job 29959382
#
# File Prefix (Annotation): K562.ENCSR000BNL.ENCFF741FZG.SP2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNL.ENCFF741FZG.SP2.0.txt
# Submitted batch job 29959383
#
# File Prefix (Annotation): K562.ENCSR000BNM.ENCFF792CKI.TAF7
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNM.ENCFF792CKI.TAF7.0.txt
# Submitted batch job 29959384
#
# File Prefix (Annotation): K562.ENCSR000BNN.ENCFF823RYG.THAP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNN.ENCFF823RYG.THAP1.0.txt
# Submitted batch job 29959385
#
# File Prefix (Annotation): K562.ENCSR000BNU.ENCFF718VHT.ATF3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNU.ENCFF718VHT.ATF3.0.txt
# Submitted batch job 29959386
#
# File Prefix (Annotation): K562.ENCSR000BNV.ENCFF031NTF.MEF2A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNV.ENCFF031NTF.MEF2A.0.txt
# Submitted batch job 29959387
#
# File Prefix (Annotation): K562.ENCSR000BNW.ENCFF754ZWP.SIX5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BNW.ENCFF754ZWP.SIX5.0.txt
# Submitted batch job 29959388
#
# File Prefix (Annotation): K562.ENCSR000BPJ.ENCFF582SNT.CTCF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BPJ.ENCFF582SNT.CTCF.0.txt
# Submitted batch job 29959389
#
# File Prefix (Annotation): K562.ENCSR000BQY.ENCFF051FNO.PML
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BQY.ENCFF051FNO.PML.0.txt
# Submitted batch job 29959390
#
# File Prefix (Annotation): K562.ENCSR000BRK.ENCFF501XJP.TEAD4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BRK.ENCFF501XJP.TEAD4.0.txt
# Submitted batch job 29959391
#
# File Prefix (Annotation): K562.ENCSR000BRQ.ENCFF022KBK.CEBPB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BRQ.ENCFF022KBK.CEBPB.0.txt
# Submitted batch job 29959392
#
# File Prefix (Annotation): K562.ENCSR000BRR.ENCFF187BVL.STAT5A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BRR.ENCFF187BVL.STAT5A.0.txt
# Submitted batch job 29959393
#
# File Prefix (Annotation): K562.ENCSR000BRS.ENCFF847ZHF.NR2F2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BRS.ENCFF847ZHF.NR2F2.0.txt
# Submitted batch job 29959394
#
# File Prefix (Annotation): K562.ENCSR000BRT.ENCFF386ZWO.CBX3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BRT.ENCFF386ZWO.CBX3.0.txt
# Submitted batch job 29959395
#
# File Prefix (Annotation): K562.ENCSR000BRW.ENCFF634OOU.TRIM28
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BRW.ENCFF634OOU.TRIM28.0.txt
# Submitted batch job 29959396
#
# File Prefix (Annotation): K562.ENCSR000BSO.ENCFF193LLN.CREB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000BSO.ENCFF193LLN.CREB1.0.txt
# Submitted batch job 29959397
#
# File Prefix (Annotation): K562.ENCSR000DJW.ENCFF772UYI.NR4A1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DJW.ENCFF772UYI.NR4A1.0.txt
# Submitted batch job 29959398
#
# File Prefix (Annotation): K562.ENCSR000DJX.ENCFF273KIA.JUND
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DJX.ENCFF273KIA.JUND.0.txt
# Submitted batch job 29959399
#
# File Prefix (Annotation): K562.ENCSR000DJY.ENCFF362UGH.JUNB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DJY.ENCFF362UGH.JUNB.0.txt
# Submitted batch job 29959400
#
# File Prefix (Annotation): K562.ENCSR000DJZ.ENCFF611FTI.HDAC8
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DJZ.ENCFF611FTI.HDAC8.0.txt
# Submitted batch job 29959401
#
# File Prefix (Annotation): K562.ENCSR000DKA.ENCFF165ZEP.GATA2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DKA.ENCFF165ZEP.GATA2.0.txt
# Submitted batch job 29959402
#
# File Prefix (Annotation): K562.ENCSR000DKB.NA.FOS
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DKB.NA.FOS.0.txt
# Submitted batch job 29959403
#
# File Prefix (Annotation): K562.ENCSR000DLY.ENCFF410CPY.POLR2A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DLY.ENCFF410CPY.POLR2A.0.txt
# Submitted batch job 29959404
#
# File Prefix (Annotation): K562.ENCSR000DLZ.ENCFF566CTX.MYC
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DLZ.ENCFF566CTX.MYC.0.txt
# Submitted batch job 29959405
#
# File Prefix (Annotation): K562.ENCSR000DMA.ENCFF221SKA.CTCF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DMA.ENCFF221SKA.CTCF.0.txt
# Submitted batch job 29959406
#
# File Prefix (Annotation): K562.ENCSR000DNZ.ENCFF206BGR.ATF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DNZ.ENCFF206BGR.ATF1.0.txt
# Submitted batch job 29959407
#
# File Prefix (Annotation): K562.ENCSR000DOA.ENCFF642ZYO.CCNT2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOA.ENCFF642ZYO.CCNT2.0.txt
# Submitted batch job 29959408
#
# File Prefix (Annotation): K562.ENCSR000DOB.ENCFF615AKB.HMGN3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOB.ENCFF615AKB.HMGN3.0.txt
# Submitted batch job 29959409
#
# File Prefix (Annotation): K562.ENCSR000DOC.ENCFF944LWS.BRF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOC.ENCFF944LWS.BRF2.0.txt
# Submitted batch job 29959410
#
# File Prefix (Annotation): K562.ENCSR000DOD.ENCFF496PIQ.GTF3C2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOD.ENCFF496PIQ.GTF3C2.0.txt
# Submitted batch job 29959411
#
# File Prefix (Annotation): K562.ENCSR000DOE.ENCFF987FJR.GTF2B
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOE.ENCFF987FJR.GTF2B.0.txt
# Submitted batch job 29959412
#
# File Prefix (Annotation): K562.ENCSR000DOF.ENCFF265KKE.NELFE
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOF.ENCFF265KKE.NELFE.0.txt
# Submitted batch job 29959413
#
# File Prefix (Annotation): K562.ENCSR000DOG.ENCFF895RNS.ATF3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOG.ENCFF895RNS.ATF3.0.txt
# Submitted batch job 29959414
#
# File Prefix (Annotation): K562.ENCSR000DOH.ENCFF217ACS.SIRT6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOH.ENCFF217ACS.SIRT6.0.txt
# Submitted batch job 29959415
#
# File Prefix (Annotation): K562.ENCSR000DOI.ENCFF627DJP.POLR3A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOI.ENCFF627DJP.POLR3A.0.txt
# Submitted batch job 29959416
#
# File Prefix (Annotation): K562.ENCSR000DOJ.ENCFF577LSK.BRF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOJ.ENCFF577LSK.BRF1.0.txt
# Submitted batch job 29959417
#
# File Prefix (Annotation): K562.ENCSR000DOK.ENCFF284FTY.BDP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DOK.ENCFF284FTY.BDP1.0.txt
# Submitted batch job 29959418
#
# File Prefix (Annotation): K562.ENCSR000DWE.ENCFF736NYC.CTCF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000DWE.ENCFF736NYC.CTCF.0.txt
# Submitted batch job 29959419
#
# File Prefix (Annotation): K562.ENCSR000EFN.ENCFF139FMU.HCFC1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFN.ENCFF139FMU.HCFC1.0.txt
# Submitted batch job 29959420
#
# File Prefix (Annotation): K562.ENCSR000EFO.ENCFF838GFC.CUX1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFO.ENCFF838GFC.CUX1.0.txt
# Submitted batch job 29959421
#
# File Prefix (Annotation): K562.ENCSR000EFP.ENCFF864XZP.ZNF384
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFP.ENCFF864XZP.ZNF384.0.txt
# Submitted batch job 29959422
#
# File Prefix (Annotation): K562.ENCSR000EFQ.ENCFF881DAT.ZMIZ1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFQ.ENCFF881DAT.ZMIZ1.0.txt
# Submitted batch job 29959423
#
# File Prefix (Annotation): K562.ENCSR000EFR.ENCFF528SIV.ZC3H11A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFR.ENCFF528SIV.ZC3H11A.0.txt
# Submitted batch job 29959424
#
# File Prefix (Annotation): K562.ENCSR000EFS.ENCFF190CGV.JUN
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFS.ENCFF190CGV.JUN.0.txt
# Submitted batch job 29959425
#
# File Prefix (Annotation): K562.ENCSR000EFT.ENCFF657CTC.GATA1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFT.ENCFF657CTC.GATA1.0.txt
# Submitted batch job 29959426
#
# File Prefix (Annotation): K562.ENCSR000EFU.ENCFF715WGN.ELK1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFU.ENCFF715WGN.ELK1.0.txt
# Submitted batch job 29959427
#
# File Prefix (Annotation): K562.ENCSR000EFV.ENCFF171FVU.MAX
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFV.ENCFF171FVU.MAX.0.txt
# Submitted batch job 29959428
#
# File Prefix (Annotation): K562.ENCSR000EFW.ENCFF568ZPW.UBTF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFW.ENCFF568ZPW.UBTF.0.txt
# Submitted batch job 29959429
#
# File Prefix (Annotation): K562.ENCSR000EFX.ENCFF837NNR.MAZ
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFX.ENCFF837NNR.MAZ.0.txt
# Submitted batch job 29959430
#
# File Prefix (Annotation): K562.ENCSR000EFY.ENCFF891OQP.ARID3A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFY.ENCFF891OQP.ARID3A.0.txt
# Submitted batch job 29959431
#
# File Prefix (Annotation): K562.ENCSR000EFZ.ENCFF326CIT.UBTF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EFZ.ENCFF326CIT.UBTF.0.txt
# Submitted batch job 29959432
#
# File Prefix (Annotation): K562.ENCSR000EGA.ENCFF034SWM.TBL1XR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGA.ENCFF034SWM.TBL1XR1.0.txt
# Submitted batch job 29959433
#
# File Prefix (Annotation): K562.ENCSR000EGB.ENCFF967URJ.TBL1XR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGB.ENCFF967URJ.TBL1XR1.0.txt
# Submitted batch job 29959434
#
# File Prefix (Annotation): K562.ENCSR000EGC.ENCFF224YBQ.RCOR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGC.ENCFF224YBQ.RCOR1.0.txt
# Submitted batch job 29959435
#
# File Prefix (Annotation): K562.ENCSR000EGD.ENCFF026BDA.BACH1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGD.ENCFF026BDA.BACH1.0.txt
# Submitted batch job 29959436
#
# File Prefix (Annotation): K562.ENCSR000EGE.ENCFF702XPO.EP300
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGE.ENCFF702XPO.EP300.0.txt
# Submitted batch job 29959437
#
# File Prefix (Annotation): K562.ENCSR000EGF.ENCFF951KHS.POLR2AphosphoS2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGF.ENCFF951KHS.POLR2AphosphoS2.0.txt
# Submitted batch job 29959438
#
# File Prefix (Annotation): K562.ENCSR000EGG.ENCFF627PLM.RCOR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGG.ENCFF627PLM.RCOR1.0.txt
# Submitted batch job 29959439
#
# File Prefix (Annotation): K562.ENCSR000EGI.ENCFF119AHD.MAFF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGI.ENCFF119AHD.MAFF.0.txt
# Submitted batch job 29959440
#
# File Prefix (Annotation): K562.ENCSR000EGJ.ENCFF608CXN.MYC
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGJ.ENCFF608CXN.MYC.0.txt
# Submitted batch job 29959441
#
# File Prefix (Annotation): K562.ENCSR000EGM.ENCFF660GHM.CTCF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGM.ENCFF660GHM.CTCF.0.txt
# Submitted batch job 29959442
#
# File Prefix (Annotation): K562.ENCSR000EGN.ENCFF306SZL.JUND
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGN.ENCFF306SZL.JUND.0.txt
# Submitted batch job 29959443
#
# File Prefix (Annotation): K562.ENCSR000EGO.ENCFF661EUX.RFX5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGO.ENCFF661EUX.RFX5.0.txt
# Submitted batch job 29959444
#
# File Prefix (Annotation): K562.ENCSR000EGP.ENCFF540TWL.ZNF143
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGP.ENCFF540TWL.ZNF143.0.txt
# Submitted batch job 29959445
#
# File Prefix (Annotation): K562.ENCSR000EGQ.ENCFF718ZFY.NFYB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGQ.ENCFF718ZFY.NFYB.0.txt
# Submitted batch job 29959446
#
# File Prefix (Annotation): K562.ENCSR000EGR.ENCFF908HSL.NFYA
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGR.ENCFF908HSL.NFYA.0.txt
# Submitted batch job 29959447
#
# File Prefix (Annotation): K562.ENCSR000EGV.ENCFF154IVU.BHLHE40
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGV.ENCFF154IVU.BHLHE40.0.txt
# Submitted batch job 29959448
#
# File Prefix (Annotation): K562.ENCSR000EGW.ENCFF289LLT.SMC3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGW.ENCFF289LLT.SMC3.0.txt
# Submitted batch job 29959449
#
# File Prefix (Annotation): K562.ENCSR000EGX.ENCFF439TJM.MAFK
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGX.ENCFF439TJM.MAFK.0.txt
# Submitted batch job 29959450
#
# File Prefix (Annotation): K562.ENCSR000EGY.ENCFF821MKR.EP300
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGY.ENCFF821MKR.EP300.0.txt
# Submitted batch job 29959451
#
# File Prefix (Annotation): K562.ENCSR000EGZ.ENCFF068IGH.MXI1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EGZ.ENCFF068IGH.MXI1.0.txt
# Submitted batch job 29959452
#
# File Prefix (Annotation): K562.ENCSR000EHA.ENCFF370YGS.TBP
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHA.ENCFF370YGS.TBP.0.txt
# Submitted batch job 29959453
#
# File Prefix (Annotation): K562.ENCSR000EHB.ENCFF852ZRK.TAL1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHB.ENCFF852ZRK.TAL1.0.txt
# Submitted batch job 29959454
#
# File Prefix (Annotation): K562.ENCSR000EHC.ENCFF075BRS.GTF2F1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHC.ENCFF075BRS.GTF2F1.0.txt
# Submitted batch job 29959455
#
# File Prefix (Annotation): K562.ENCSR000EHD.ENCFF947AEO.CHD2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHD.ENCFF947AEO.CHD2.0.txt
# Submitted batch job 29959456
#
# File Prefix (Annotation): K562.ENCSR000EHE.ENCFF882ARK.CEBPB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHE.ENCFF882ARK.CEBPB.0.txt
# Submitted batch job 29959457
#
# File Prefix (Annotation): K562.ENCSR000EHF.ENCFF950YZE.POLR2AphosphoS2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHF.ENCFF950YZE.POLR2AphosphoS2.0.txt
# Submitted batch job 29959458
#
# File Prefix (Annotation): K562.ENCSR000EHG.ENCFF744HVD.USF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHG.ENCFF744HVD.USF2.0.txt
# Submitted batch job 29959459
#
# File Prefix (Annotation): K562.ENCSR000EHH.ENCFF410RJD.NRF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHH.ENCFF410RJD.NRF1.0.txt
# Submitted batch job 29959460
#
# File Prefix (Annotation): K562.ENCSR000EHL.ENCFF921FKB.POLR2A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHL.ENCFF921FKB.POLR2A.0.txt
# Submitted batch job 29959461
#
# File Prefix (Annotation): K562.ENCSR000EHN.ENCFF217LXF.SMARCB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHN.ENCFF217LXF.SMARCB1.0.txt
# Submitted batch job 29959462
#
# File Prefix (Annotation): K562.ENCSR000EHO.ENCFF486QCV.SMARCA4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHO.ENCFF486QCV.SMARCA4.0.txt
# Submitted batch job 29959463
#
# File Prefix (Annotation): K562.ENCSR000EHQ.ENCFF307GHJ.POLR3G
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EHQ.ENCFF307GHJ.POLR3G.0.txt
# Submitted batch job 29959464
#
# File Prefix (Annotation): K562.ENCSR000EVX.ENCFF045CFL.ZNF274
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EVX.ENCFF045CFL.ZNF274.0.txt
# Submitted batch job 29959465
#
# File Prefix (Annotation): K562.ENCSR000EVY.ENCFF172CRL.TRIM28
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EVY.ENCFF172CRL.TRIM28.0.txt
# Submitted batch job 29959466
#
# File Prefix (Annotation): K562.ENCSR000EWD.ENCFF319ZYX.SETDB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWD.ENCFF319ZYX.SETDB1.0.txt
# Submitted batch job 29959467
#
# File Prefix (Annotation): K562.ENCSR000EWE.ENCFF742DPO.ZNF274
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWE.ENCFF742DPO.ZNF274.0.txt
# Submitted batch job 29959468
#
# File Prefix (Annotation): K562.ENCSR000EWF.ENCFF589PZO.YY1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWF.ENCFF589PZO.YY1.0.txt
# Submitted batch job 29959469
#
# File Prefix (Annotation): K562.ENCSR000EWG.ENCFF497ISV.GATA2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWG.ENCFF497ISV.GATA2.0.txt
# Submitted batch job 29959470
#
# File Prefix (Annotation): K562.ENCSR000EWH.ENCFF495XYS.NR2C2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWH.ENCFF495XYS.NR2C2.0.txt
# Submitted batch job 29959471
#
# File Prefix (Annotation): K562.ENCSR000EWI.ENCFF752EMN.SETDB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWI.ENCFF752EMN.SETDB1.0.txt
# Submitted batch job 29959472
#
# File Prefix (Annotation): K562.ENCSR000EWJ.ENCFF085GHX.E2F6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWJ.ENCFF085GHX.E2F6.0.txt
# Submitted batch job 29959473
#
# File Prefix (Annotation): K562.ENCSR000EWL.ENCFF064CWA.E2F4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWL.ENCFF064CWA.E2F4.0.txt
# Submitted batch job 29959474
#
# File Prefix (Annotation): K562.ENCSR000EWM.ENCFF509ZLE.GATA1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWM.ENCFF509ZLE.GATA1.0.txt
# Submitted batch job 29959475
#
# File Prefix (Annotation): K562.ENCSR000EWN.ENCFF264BDD.ZNF263
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000EWN.ENCFF264BDD.ZNF263.0.txt
# Submitted batch job 29959476
#
# File Prefix (Annotation): K562.ENCSR000FAC.ENCFF540QPM.XRCC4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAC.ENCFF540QPM.XRCC4.0.txt
# Submitted batch job 29959477
#
# File Prefix (Annotation): K562.ENCSR000FAD.ENCFF258VXX.RAD21
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAD.ENCFF258VXX.RAD21.0.txt
# Submitted batch job 29959478
#
# File Prefix (Annotation): K562.ENCSR000FAE.ENCFF493DCP.MAX
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAE.ENCFF493DCP.MAX.0.txt
# Submitted batch job 29959479
#
# File Prefix (Annotation): K562.ENCSR000FAF.ENCFF714MVQ.NFE2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAF.ENCFF714MVQ.NFE2.0.txt
# Submitted batch job 29959480
#
# File Prefix (Annotation): K562.ENCSR000FAG.ENCFF675PHY.MYC
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAG.ENCFF675PHY.MYC.0.txt
# Submitted batch job 29959481
#
# File Prefix (Annotation): K562.ENCSR000FAH.ENCFF589QXC.JUN
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAH.ENCFF589QXC.JUN.0.txt
# Submitted batch job 29959482
#
# File Prefix (Annotation): K562.ENCSR000FAI.ENCFF258PLH.FOS
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAI.ENCFF258PLH.FOS.0.txt
# Submitted batch job 29959483
#
# File Prefix (Annotation): K562.ENCSR000FAJ.ENCFF107SJD.POLR2A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FAJ.ENCFF107SJD.POLR2A.0.txt
# Submitted batch job 29959484
#
# File Prefix (Annotation): K562.ENCSR000FCB.ENCFF605XYC.MITF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FCB.ENCFF605XYC.MITF.0.txt
# Submitted batch job 29959485
#
# File Prefix (Annotation): K562.ENCSR000FCC.ENCFF474PRJ.NFE2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FCC.ENCFF474PRJ.NFE2.0.txt
# Submitted batch job 29959486
#
# File Prefix (Annotation): K562.ENCSR000FCD.ENCFF971YTJ.SMAD5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FCD.ENCFF971YTJ.SMAD5.0.txt
# Submitted batch job 29959487
#
# File Prefix (Annotation): K562.ENCSR000FCE.ENCFF965PER.ETV6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR000FCE.ENCFF965PER.ETV6.0.txt
# Submitted batch job 29959488
#
# File Prefix (Annotation): K562.ENCSR002ZGC.ENCFF435MHH.ZNF212
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR002ZGC.ENCFF435MHH.ZNF212.0.txt
# Submitted batch job 29959489
#
# File Prefix (Annotation): K562.ENCSR003GUC.ENCFF439KTZ.E4F1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR003GUC.ENCFF439KTZ.E4F1.0.txt
# Submitted batch job 29959490
#
# File Prefix (Annotation): K562.ENCSR004GKA.ENCFF242AOL.ZEB2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR004GKA.ENCFF242AOL.ZEB2.0.txt
# Submitted batch job 29959491
#
# File Prefix (Annotation): K562.ENCSR005NMT.ENCFF375SIS.ID3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR005NMT.ENCFF375SIS.ID3.0.txt
# Submitted batch job 29959492
#
# File Prefix (Annotation): K562.ENCSR008DOU.ENCFF656THP.SNAPC5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR008DOU.ENCFF656THP.SNAPC5.0.txt
# Submitted batch job 29959493
#
# File Prefix (Annotation): K562.ENCSR011NOZ.ENCFF255HEF.ZNF407
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR011NOZ.ENCFF255HEF.ZNF407.0.txt
# Submitted batch job 29959494
#
# File Prefix (Annotation): K562.ENCSR011PEI.ENCFF192MEM.ZNF175
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR011PEI.ENCFF192MEM.ZNF175.0.txt
# Submitted batch job 29959495
#
# File Prefix (Annotation): K562.ENCSR011WGT.ENCFF009RFC.GABPB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR011WGT.ENCFF009RFC.GABPB1.0.txt
# Submitted batch job 29959496
#
# File Prefix (Annotation): K562.ENCSR013UDY.ENCFF917HUH.TOE1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR013UDY.ENCFF917HUH.TOE1.0.txt
# Submitted batch job 29959497
#
# File Prefix (Annotation): K562.ENCSR014ARU.ENCFF121HYT.ATF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR014ARU.ENCFF121HYT.ATF2.0.txt
# Submitted batch job 29959498
#
# File Prefix (Annotation): K562.ENCSR014RCS.ENCFF505RNR.HNRNPK
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR014RCS.ENCFF505RNR.HNRNPK.0.txt
# Submitted batch job 29959499
#
# File Prefix (Annotation): K562.ENCSR015KAM.ENCFF505INE.DMTF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR015KAM.ENCFF505INE.DMTF1.0.txt
# Submitted batch job 29959500
#
# File Prefix (Annotation): K562.ENCSR017EJY.ENCFF832DBU.DLX4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR017EJY.ENCFF832DBU.DLX4.0.txt
# Submitted batch job 29959501
#
# File Prefix (Annotation): K562.ENCSR017GBO.ENCFF362JHQ.TFDP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR017GBO.ENCFF362JHQ.TFDP1.0.txt
# Submitted batch job 29959502
#
# File Prefix (Annotation): K562.ENCSR018MSO.ENCFF283UWH.ZNF148
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR018MSO.ENCFF283UWH.ZNF148.0.txt
# Submitted batch job 29959503
#
# File Prefix (Annotation): K562.ENCSR023OOE.ENCFF049MDN.ZNF764
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR023OOE.ENCFF049MDN.ZNF764.0.txt
# Submitted batch job 29959504
#
# File Prefix (Annotation): K562.ENCSR024CNP.ENCFF136DDO.EGR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR024CNP.ENCFF136DDO.EGR1.0.txt
# Submitted batch job 29959505
#
# File Prefix (Annotation): K562.ENCSR024LKA.ENCFF775PIY.HDAC3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR024LKA.ENCFF775PIY.HDAC3.0.txt
# Submitted batch job 29959506
#
# File Prefix (Annotation): K562.ENCSR026KKZ.ENCFF292HSS.ZBTB17
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR026KKZ.ENCFF292HSS.ZBTB17.0.txt
# Submitted batch job 29959507
#
# File Prefix (Annotation): K562.ENCSR026RAK.ENCFF559MTF.MXD1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR026RAK.ENCFF559MTF.MXD1.0.txt
# Submitted batch job 29959508
#
# File Prefix (Annotation): K562.ENCSR028UIU.ENCFF556SMM.ATF3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR028UIU.ENCFF556SMM.ATF3.0.txt
# Submitted batch job 29959509
#
# File Prefix (Annotation): K562.ENCSR028WJI.ENCFF238XIA.TGIF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR028WJI.ENCFF238XIA.TGIF2.0.txt
# Submitted batch job 29959510
#
# File Prefix (Annotation): K562.ENCSR030TJP.ENCFF729DNM.DACH1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR030TJP.ENCFF729DNM.DACH1.0.txt
# Submitted batch job 29959511
#
# File Prefix (Annotation): K562.ENCSR031TFS.ENCFF842JME.POLR2A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR031TFS.ENCFF842JME.POLR2A.0.txt
# Submitted batch job 29959512
#
# File Prefix (Annotation): K562.ENCSR033NQK.ENCFF896IUI.ZNF830
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR033NQK.ENCFF896IUI.ZNF830.0.txt
# Submitted batch job 29959513
#
# File Prefix (Annotation): K562.ENCSR033VAZ.ENCFF986BYT.TARDBP
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR033VAZ.ENCFF986BYT.TARDBP.0.txt
# Submitted batch job 29959514
#
# File Prefix (Annotation): K562.ENCSR034GHQ.ENCFF099OSI.HMG20B
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR034GHQ.ENCFF099OSI.HMG20B.0.txt
# Submitted batch job 29959515
#
# File Prefix (Annotation): K562.ENCSR036QIR.ENCFF710UAZ.E2F3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR036QIR.ENCFF710UAZ.E2F3.0.txt
# Submitted batch job 29959516
#
# File Prefix (Annotation): K562.ENCSR038DJJ.ENCFF120PGJ.SMAD1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR038DJJ.ENCFF120PGJ.SMAD1.0.txt
# Submitted batch job 29959517
#
# File Prefix (Annotation): K562.ENCSR038RGL.ENCFF674ZQI.MCM7
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR038RGL.ENCFF674ZQI.MCM7.0.txt
# Submitted batch job 29959518
#
# File Prefix (Annotation): K562.ENCSR041AXL.ENCFF820GPR.RFX1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR041AXL.ENCFF820GPR.RFX1.0.txt
# Submitted batch job 29959519
#
# File Prefix (Annotation): K562.ENCSR041QAZ.ENCFF417FFL.RNF219
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR041QAZ.ENCFF417FFL.RNF219.0.txt
# Submitted batch job 29959520
#
# File Prefix (Annotation): K562.ENCSR041YBR.ENCFF021JCJ.ZNF12
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR041YBR.ENCFF021JCJ.ZNF12.0.txt
# Submitted batch job 29959521
#
# File Prefix (Annotation): K562.ENCSR044IXA.ENCFF712NHB.ZNF354B
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR044IXA.ENCFF712NHB.ZNF354B.0.txt
# Submitted batch job 29959522
#
# File Prefix (Annotation): K562.ENCSR044UJJ.ENCFF250MUC.ATF4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR044UJJ.ENCFF250MUC.ATF4.0.txt
# Submitted batch job 29959523
#
# File Prefix (Annotation): K562.ENCSR047LSJ.ENCFF547PES.TAF15
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR047LSJ.ENCFF547PES.TAF15.0.txt
# Submitted batch job 29959524
#
# File Prefix (Annotation): K562.ENCSR051DXE.ENCFF581MLB.FUS
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR051DXE.ENCFF581MLB.FUS.0.txt
# Submitted batch job 29959525
#
# File Prefix (Annotation): K562.ENCSR051OUX.ENCFF972OBR.NFATC3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR051OUX.ENCFF972OBR.NFATC3.0.txt
# Submitted batch job 29959526
#
# File Prefix (Annotation): K562.ENCSR052PTN.ENCFF956MGE.PCBP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR052PTN.ENCFF956MGE.PCBP1.0.txt
# Submitted batch job 29959527
#
# File Prefix (Annotation): K562.ENCSR054JMQ.ENCFF118ECK.REST
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR054JMQ.ENCFF118ECK.REST.0.txt
# Submitted batch job 29959528
#
# File Prefix (Annotation): K562.ENCSR056VMR.ENCFF567CPM.FOXJ3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR056VMR.ENCFF567CPM.FOXJ3.0.txt
# Submitted batch job 29959529
#
# File Prefix (Annotation): K562.ENCSR056VYW.ENCFF822FXR.ZNF174
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR056VYW.ENCFF822FXR.ZNF174.0.txt
# Submitted batch job 29959530
#
# File Prefix (Annotation): K562.ENCSR058DRG.ENCFF558AJI.CEBPG
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR058DRG.ENCFF558AJI.CEBPG.0.txt
# Submitted batch job 29959531
#
# File Prefix (Annotation): K562.ENCSR059BWP.ENCFF130WQT.PHTF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR059BWP.ENCFF130WQT.PHTF2.0.txt
# Submitted batch job 29959532
#
# File Prefix (Annotation): K562.ENCSR065XVO.ENCFF515GUE.CHAMP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR065XVO.ENCFF515GUE.CHAMP1.0.txt
# Submitted batch job 29959533
#
# File Prefix (Annotation): K562.ENCSR068QXO.ENCFF934NEX.SMAD4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR068QXO.ENCFF934NEX.SMAD4.0.txt
# Submitted batch job 29959534
#
# File Prefix (Annotation): K562.ENCSR068VRA.ENCFF239OHL.MCM7
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR068VRA.ENCFF239OHL.MCM7.0.txt
# Submitted batch job 29959535
#
# File Prefix (Annotation): K562.ENCSR072VUO.ENCFF537RNU.SAFB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR072VUO.ENCFF537RNU.SAFB.0.txt
# Submitted batch job 29959536
#
# File Prefix (Annotation): K562.ENCSR075HTM.ENCFF652ZZF.HDAC2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR075HTM.ENCFF652ZZF.HDAC2.0.txt
# Submitted batch job 29959537
#
# File Prefix (Annotation): K562.ENCSR076YPO.ENCFF060JVZ.RNF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR076YPO.ENCFF060JVZ.RNF2.0.txt
# Submitted batch job 29959538
#
# File Prefix (Annotation): K562.ENCSR077DKV.ENCFF324ELP.CREM
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR077DKV.ENCFF324ELP.CREM.0.txt
# Submitted batch job 29959539
#
# File Prefix (Annotation): K562.ENCSR077TKJ.ENCFF959ZKZ.ZNF707
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR077TKJ.ENCFF959ZKZ.ZNF707.0.txt
# Submitted batch job 29959540
#
# File Prefix (Annotation): K562.ENCSR079WHK.ENCFF344LTH.MCM5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR079WHK.ENCFF344LTH.MCM5.0.txt
# Submitted batch job 29959541
#
# File Prefix (Annotation): K562.ENCSR084WHZ.ENCFF974IPP.FOXP4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR084WHZ.ENCFF974IPP.FOXP4.0.txt
# Submitted batch job 29959542
#
# File Prefix (Annotation): K562.ENCSR085DDI.ENCFF341CNM.NFXL1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR085DDI.ENCFF341CNM.NFXL1.0.txt
# Submitted batch job 29959543
#
# File Prefix (Annotation): K562.ENCSR085QEV.ENCFF670POK.NBN
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR085QEV.ENCFF670POK.NBN.0.txt
# Submitted batch job 29959544
#
# File Prefix (Annotation): K562.ENCSR085XDP.ENCFF793HSJ.ATF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR085XDP.ENCFF793HSJ.ATF1.0.txt
# Submitted batch job 29959545
#
# File Prefix (Annotation): K562.ENCSR086FZL.ENCFF113LBV.KAT8
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR086FZL.ENCFF113LBV.KAT8.0.txt
# Submitted batch job 29959546
#
# File Prefix (Annotation): K562.ENCSR087TYG.ENCFF529SRS.NR2F6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR087TYG.ENCFF529SRS.NR2F6.0.txt
# Submitted batch job 29959547
#
# File Prefix (Annotation): K562.ENCSR090JNM.ENCFF614IBI.HLTF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR090JNM.ENCFF614IBI.HLTF.0.txt
# Submitted batch job 29959548
#
# File Prefix (Annotation): K562.ENCSR091GVJ.ENCFF627RSK.ATF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR091GVJ.ENCFF627RSK.ATF1.0.txt
# Submitted batch job 29959549
#
# File Prefix (Annotation): K562.ENCSR091IQZ.ENCFF359ZQQ.DMBX1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR091IQZ.ENCFF359ZQQ.DMBX1.0.txt
# Submitted batch job 29959550
#
# File Prefix (Annotation): K562.ENCSR091JXL.ENCFF671ZGP.HES1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR091JXL.ENCFF671ZGP.HES1.0.txt
# Submitted batch job 29959551
#
# File Prefix (Annotation): K562.ENCSR093FKD.ENCFF950IYB.CREB3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR093FKD.ENCFF950IYB.CREB3.0.txt
# Submitted batch job 29959552
#
# File Prefix (Annotation): K562.ENCSR099MNR.ENCFF307UZC.ZNF75A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR099MNR.ENCFF307UZC.ZNF75A.0.txt
# Submitted batch job 29959553
#
# File Prefix (Annotation): K562.ENCSR099NCH.ENCFF268YOM.ZNF24
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR099NCH.ENCFF268YOM.ZNF24.0.txt
# Submitted batch job 29959554
#
# File Prefix (Annotation): K562.ENCSR100UQX.ENCFF432HRL.TAF9B
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR100UQX.ENCFF432HRL.TAF9B.0.txt
# Submitted batch job 29959555
#
# File Prefix (Annotation): K562.ENCSR102KIN.ENCFF117XRE.ZMYM3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR102KIN.ENCFF117XRE.ZMYM3.0.txt
# Submitted batch job 29959556
#
# File Prefix (Annotation): K562.ENCSR103TYK.ENCFF681YLP.HBP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR103TYK.ENCFF681YLP.HBP1.0.txt
# Submitted batch job 29959557
#
# File Prefix (Annotation): K562.ENCSR106FRG.ENCFF101DBG.TAL1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR106FRG.ENCFF101DBG.TAL1.0.txt
# Submitted batch job 29959558
#
# File Prefix (Annotation): K562.ENCSR107GRP.ENCFF556MUV.MLLT1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR107GRP.ENCFF556MUV.MLLT1.0.txt
# Submitted batch job 29959559
#
# File Prefix (Annotation): K562.ENCSR107RHZ.ENCFF286IPW.YBX1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR107RHZ.ENCFF286IPW.YBX1.0.txt
# Submitted batch job 29959560
#
# File Prefix (Annotation): K562.ENCSR109SJT.ENCFF232ZHD.SMAD4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR109SJT.ENCFF232ZHD.SMAD4.0.txt
# Submitted batch job 29959561
#
# File Prefix (Annotation): K562.ENCSR109YGM.ENCFF118GMS.CREB3L1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR109YGM.ENCFF118GMS.CREB3L1.0.txt
# Submitted batch job 29959562
#
# File Prefix (Annotation): K562.ENCSR110JLQ.ENCFF165JQS.ZNF778
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR110JLQ.ENCFF165JQS.ZNF778.0.txt
# Submitted batch job 29959563
#
# File Prefix (Annotation): K562.ENCSR112RNT.ENCFF833ZNA.HNRNPLL
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR112RNT.ENCFF833ZNA.HNRNPLL.0.txt
# Submitted batch job 29959564
#
# File Prefix (Annotation): K562.ENCSR113LAS.ENCFF478LQC.MTA2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR113LAS.ENCFF478LQC.MTA2.0.txt
# Submitted batch job 29959565
#
# File Prefix (Annotation): K562.ENCSR115BBC.ENCFF553IUR.ASH1L
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR115BBC.ENCFF553IUR.ASH1L.0.txt
# Submitted batch job 29959566
#
# File Prefix (Annotation): K562.ENCSR115HLM.ENCFF435SNP.ZBTB26
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR115HLM.ENCFF435SNP.ZBTB26.0.txt
# Submitted batch job 29959567
#
# File Prefix (Annotation): K562.ENCSR115SMW.ENCFF099RDJ.PKNOX1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR115SMW.ENCFF099RDJ.PKNOX1.0.txt
# Submitted batch job 29959568
#
# File Prefix (Annotation): K562.ENCSR116NDV.ENCFF802NHC.CBFB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR116NDV.ENCFF802NHC.CBFB.0.txt
# Submitted batch job 29959569
#
# File Prefix (Annotation): K562.ENCSR117WTM.ENCFF683VTL.ZNF24
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR117WTM.ENCFF683VTL.ZNF24.0.txt
# Submitted batch job 29959570
#
# File Prefix (Annotation): K562.ENCSR119FAD.ENCFF030AXK.DEAF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR119FAD.ENCFF030AXK.DEAF1.0.txt
# Submitted batch job 29959571
#
# File Prefix (Annotation): K562.ENCSR119ULQ.ENCFF067BCD.NCOA4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR119ULQ.ENCFF067BCD.NCOA4.0.txt
# Submitted batch job 29959572
#
# File Prefix (Annotation): K562.ENCSR119VCX.ENCFF215JWS.PHF21A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR119VCX.ENCFF215JWS.PHF21A.0.txt
# Submitted batch job 29959573
#
# File Prefix (Annotation): K562.ENCSR120MPG.ENCFF405BKB.PRDM10
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR120MPG.ENCFF405BKB.PRDM10.0.txt
# Submitted batch job 29959574
#
# File Prefix (Annotation): K562.ENCSR121PFY.ENCFF408RSJ.CDC5L
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR121PFY.ENCFF408RSJ.CDC5L.0.txt
# Submitted batch job 29959575
#
# File Prefix (Annotation): K562.ENCSR121SPB.ENCFF142ZTD.KLF10
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR121SPB.ENCFF142ZTD.KLF10.0.txt
# Submitted batch job 29959576
#
# File Prefix (Annotation): K562.ENCSR124BJR.ENCFF584QFY.ETV6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR124BJR.ENCFF584QFY.ETV6.0.txt
# Submitted batch job 29959577
#
# File Prefix (Annotation): K562.ENCSR124YFA.ENCFF881MMD.ZNF124
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR124YFA.ENCFF881MMD.ZNF124.0.txt
# Submitted batch job 29959578
#
# File Prefix (Annotation): K562.ENCSR125RFR.ENCFF863ZFH.ATF6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR125RFR.ENCFF863ZFH.ATF6.0.txt
# Submitted batch job 29959579
#
# File Prefix (Annotation): K562.ENCSR125YGM.ENCFF794SCQ.ID3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR125YGM.ENCFF794SCQ.ID3.0.txt
# Submitted batch job 29959580
#
# File Prefix (Annotation): K562.ENCSR126FZN.ENCFF491UBF.PTRF
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR126FZN.ENCFF491UBF.PTRF.0.txt
# Submitted batch job 29959581
#
# File Prefix (Annotation): K562.ENCSR126YJQ.ENCFF118ATD.HMG20A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR126YJQ.ENCFF118ATD.HMG20A.0.txt
# Submitted batch job 29959582
#
# File Prefix (Annotation): K562.ENCSR128KLX.ENCFF647RGI.NR2F6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR128KLX.ENCFF647RGI.NR2F6.0.txt
# Submitted batch job 29959583
#
# File Prefix (Annotation): K562.ENCSR130HEG.ENCFF942JZR.COPS2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR130HEG.ENCFF942JZR.COPS2.0.txt
# Submitted batch job 29959584
#
# File Prefix (Annotation): K562.ENCSR130PDE.ENCFF852ZIK.NR4A1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR130PDE.ENCFF852ZIK.NR4A1.0.txt
# Submitted batch job 29959585
#
# File Prefix (Annotation): K562.ENCSR137ZMQ.ENCFF761YYL.REST
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR137ZMQ.ENCFF761YYL.REST.0.txt
# Submitted batch job 29959586
#
# File Prefix (Annotation): K562.ENCSR138FUZ.ENCFF409SDU.RNF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR138FUZ.ENCFF409SDU.RNF2.0.txt
# Submitted batch job 29959587
#
# File Prefix (Annotation): K562.ENCSR138SFL.ENCFF147IAH.MCM2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR138SFL.ENCFF147IAH.MCM2.0.txt
# Submitted batch job 29959588
#
# File Prefix (Annotation): K562.ENCSR138YYY.ENCFF764HIS.GABPB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR138YYY.ENCFF764HIS.GABPB1.0.txt
# Submitted batch job 29959589
#
# File Prefix (Annotation): K562.ENCSR140GLO.ENCFF335ZTU.SMAD3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR140GLO.ENCFF335ZTU.SMAD3.0.txt
# Submitted batch job 29959590
#
# File Prefix (Annotation): K562.ENCSR142YYA.ENCFF924FYI.EWSR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR142YYA.ENCFF924FYI.EWSR1.0.txt
# Submitted batch job 29959591
#
# File Prefix (Annotation): K562.ENCSR143CEO.ENCFF230DZT.ZC3H8
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR143CEO.ENCFF230DZT.ZC3H8.0.txt
# Submitted batch job 29959592
#
# File Prefix (Annotation): K562.ENCSR145TSJ.ENCFF086TAD.ATF4
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR145TSJ.ENCFF086TAD.ATF4.0.txt
# Submitted batch job 29959593
#
# File Prefix (Annotation): K562.ENCSR149ZBI.ENCFF005MBI.ZNF584
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR149ZBI.ENCFF005MBI.ZNF584.0.txt
# Submitted batch job 29959594
#
# File Prefix (Annotation): K562.ENCSR150QDE.ENCFF710YFH.SREBF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR150QDE.ENCFF710YFH.SREBF2.0.txt
# Submitted batch job 29959595
#
# File Prefix (Annotation): K562.ENCSR153HNT.ENCFF921BXP.STAG1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR153HNT.ENCFF921BXP.STAG1.0.txt
# Submitted batch job 29959596
#
# File Prefix (Annotation): K562.ENCSR154EIH.ENCFF955QCD.TRIP13
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR154EIH.ENCFF955QCD.TRIP13.0.txt
# Submitted batch job 29959597
#
# File Prefix (Annotation): K562.ENCSR155KHM.ENCFF728ITJ.ARNT
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR155KHM.ENCFF728ITJ.ARNT.0.txt
# Submitted batch job 29959598
#
# File Prefix (Annotation): K562.ENCSR157TCS.ENCFF148YMC.SMARCE1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR157TCS.ENCFF148YMC.SMARCE1.0.txt
# Submitted batch job 29959599
#
# File Prefix (Annotation): K562.ENCSR158BGH.ENCFF313VEF.MBD1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR158BGH.ENCFF313VEF.MBD1.0.txt
# Submitted batch job 29959600
#
# File Prefix (Annotation): K562.ENCSR158LJN.ENCFF266YHW.MAX
# ...
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR836COE.ENCFF937QYU.RBM17.0.txt
# Submitted batch job 29959977
#
# File Prefix (Annotation): K562.ENCSR837EYC.ENCFF259YUE.NRF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR837EYC.ENCFF259YUE.NRF1.0.txt
# Submitted batch job 29959978
#
# File Prefix (Annotation): K562.ENCSR841GLE.ENCFF515LWL.ZNF217
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR841GLE.ENCFF515LWL.ZNF217.0.txt
# Submitted batch job 29959979
#
# File Prefix (Annotation): K562.ENCSR844JVU.ENCFF410SWS.TCFL5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR844JVU.ENCFF410SWS.TCFL5.0.txt
# Submitted batch job 29959980
#
# File Prefix (Annotation): K562.ENCSR844MAB.ENCFF809JNC.ZNF77
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR844MAB.ENCFF809JNC.ZNF77.0.txt
# Submitted batch job 29959981
#
# File Prefix (Annotation): K562.ENCSR845BCL.ENCFF643AUL.ZNF639
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR845BCL.ENCFF643AUL.ZNF639.0.txt
# Submitted batch job 29959982
#
# File Prefix (Annotation): K562.ENCSR845GGY.ENCFF295XBK.ZNF263
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR845GGY.ENCFF295XBK.ZNF263.0.txt
# Submitted batch job 29959983
#
# File Prefix (Annotation): K562.ENCSR847LBF.ENCFF957CVJ.FOXJ2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR847LBF.ENCFF957CVJ.FOXJ2.0.txt
# Submitted batch job 29959984
#
# File Prefix (Annotation): K562.ENCSR848AOP.ENCFF987DPX.RBM22
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR848AOP.ENCFF987DPX.RBM22.0.txt
# Submitted batch job 29959985
#
# File Prefix (Annotation): K562.ENCSR849LXI.ENCFF478MAJ.MTF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR849LXI.ENCFF478MAJ.MTF1.0.txt
# Submitted batch job 29959986
#
# File Prefix (Annotation): K562.ENCSR850WUE.ENCFF091TCH.RBM15
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR850WUE.ENCFF091TCH.RBM15.0.txt
# Submitted batch job 29959987
#
# File Prefix (Annotation): K562.ENCSR851BNE.ENCFF861ZJL.MEIS2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR851BNE.ENCFF861ZJL.MEIS2.0.txt
# Submitted batch job 29959988
#
# File Prefix (Annotation): K562.ENCSR851XLW.ENCFF672NBD.ZNF830
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR851XLW.ENCFF672NBD.ZNF830.0.txt
# Submitted batch job 29959989
#
# File Prefix (Annotation): K562.ENCSR854MCV.ENCFF557FUM.IRF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR854MCV.ENCFF557FUM.IRF1.0.txt
# Submitted batch job 29959990
#
# File Prefix (Annotation): K562.ENCSR861UWB.ENCFF285MHB.HOXB6
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR861UWB.ENCFF285MHB.HOXB6.0.txt
# Submitted batch job 29959991
#
# File Prefix (Annotation): K562.ENCSR863KUB.ENCFF736XUU.TCF7
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR863KUB.ENCFF736XUU.TCF7.0.txt
# Submitted batch job 29959992
#
# File Prefix (Annotation): K562.ENCSR867MET.ENCFF906PUB.THRB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR867MET.ENCFF906PUB.THRB.0.txt
# Submitted batch job 29959993
#
# File Prefix (Annotation): K562.ENCSR869IUD.ENCFF192ASP.ATF2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR869IUD.ENCFF192ASP.ATF2.0.txt
# Submitted batch job 29959994
#
# File Prefix (Annotation): K562.ENCSR870YEN.ENCFF537HHU.ZSCAN32
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR870YEN.ENCFF537HHU.ZSCAN32.0.txt
# Submitted batch job 29959995
#
# File Prefix (Annotation): K562.ENCSR871TKJ.ENCFF067FJF.THRAP3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR871TKJ.ENCFF067FJF.THRAP3.0.txt
# Submitted batch job 29959996
#
# File Prefix (Annotation): K562.ENCSR873LYH.ENCFF171ZNN.MLX
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR873LYH.ENCFF171ZNN.MLX.0.txt
# Submitted batch job 29959997
#
# File Prefix (Annotation): K562.ENCSR876GXA.ENCFF917RIN.ZBTB33
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR876GXA.ENCFF917RIN.ZBTB33.0.txt
# Submitted batch job 29959998
#
# File Prefix (Annotation): K562.ENCSR879HUU.ENCFF103YZQ.GABPB2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR879HUU.ENCFF103YZQ.GABPB2.0.txt
# Submitted batch job 29959999
#
# File Prefix (Annotation): K562.ENCSR879KXD.ENCFF057JFH.RAD21
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR879KXD.ENCFF057JFH.RAD21.0.txt
# Submitted batch job 29960000
#
# File Prefix (Annotation): K562.ENCSR882ERE.ENCFF560UGR.ZKSCAN1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR882ERE.ENCFF560UGR.ZKSCAN1.0.txt
# Submitted batch job 29960001
#
# File Prefix (Annotation): K562.ENCSR883UGG.ENCFF416TFM.ZNF445
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR883UGG.ENCFF416TFM.ZNF445.0.txt
# Submitted batch job 29960002
#
# File Prefix (Annotation): K562.ENCSR886RYH.ENCFF318GYM.NONO
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR886RYH.ENCFF318GYM.NONO.0.txt
# Submitted batch job 29960003
#
# File Prefix (Annotation): K562.ENCSR888XZK.ENCFF732ZNB.TCF7L2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR888XZK.ENCFF732ZNB.TCF7L2.0.txt
# Submitted batch job 29960004
#
# File Prefix (Annotation): K562.ENCSR893WSB.ENCFF150FJT.HDAC2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR893WSB.ENCFF150FJT.HDAC2.0.txt
# Submitted batch job 29960005
#
# File Prefix (Annotation): K562.ENCSR894CGX.ENCFF738XMN.SUPT5H
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR894CGX.ENCFF738XMN.SUPT5H.0.txt
# Submitted batch job 29960006
#
# File Prefix (Annotation): K562.ENCSR895HSJ.ENCFF722RWS.SMARCA5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR895HSJ.ENCFF722RWS.SMARCA5.0.txt
# Submitted batch job 29960007
#
# File Prefix (Annotation): K562.ENCSR898IDK.ENCFF063VRD.ZNF23
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR898IDK.ENCFF063VRD.ZNF23.0.txt
# Submitted batch job 29960008
#
# File Prefix (Annotation): K562.ENCSR898XMH.ENCFF835PDO.ZFP91
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR898XMH.ENCFF835PDO.ZFP91.0.txt
# Submitted batch job 29960009
#
# File Prefix (Annotation): K562.ENCSR899GSH.ENCFF071GJH.RBM34
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR899GSH.ENCFF071GJH.RBM34.0.txt
# Submitted batch job 29960010
#
# File Prefix (Annotation): K562.ENCSR901VIE.ENCFF044IDV.TFDP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR901VIE.ENCFF044IDV.TFDP1.0.txt
# Submitted batch job 29960011
#
# File Prefix (Annotation): K562.ENCSR906CWK.ENCFF549NPY.ZFPM2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR906CWK.ENCFF549NPY.ZFPM2.0.txt
# Submitted batch job 29960012
#
# File Prefix (Annotation): K562.ENCSR907JPB.ENCFF316IYH.ZMIZ1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR907JPB.ENCFF316IYH.ZMIZ1.0.txt
# Submitted batch job 29960013
#
# File Prefix (Annotation): K562.ENCSR907MZR.ENCFF527MLG.TRIM24
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR907MZR.ENCFF527MLG.TRIM24.0.txt
# Submitted batch job 29960014
#
# File Prefix (Annotation): K562.ENCSR908CMW.ENCFF346UGW.KDM1A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR908CMW.ENCFF346UGW.KDM1A.0.txt
# Submitted batch job 29960015
#
# File Prefix (Annotation): K562.ENCSR910JAI.ENCFF836PGX.NCOR1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR910JAI.ENCFF836PGX.NCOR1.0.txt
# Submitted batch job 29960016
#
# File Prefix (Annotation): K562.ENCSR914NEI.ENCFF280AIK.MTA3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR914NEI.ENCFF280AIK.MTA3.0.txt
# Submitted batch job 29960017
#
# File Prefix (Annotation): K562.ENCSR918EFA.ENCFF945IST.ZNF57
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR918EFA.ENCFF945IST.ZNF57.0.txt
# Submitted batch job 29960018
#
# File Prefix (Annotation): K562.ENCSR920ASP.ENCFF910JTR.ZFX
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR920ASP.ENCFF910JTR.ZFX.0.txt
# Submitted batch job 29960019
#
# File Prefix (Annotation): K562.ENCSR920BLG.ENCFF469KAH.SIN3A
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR920BLG.ENCFF469KAH.SIN3A.0.txt
# Submitted batch job 29960020
#
# File Prefix (Annotation): K562.ENCSR922YDT.ENCFF441QXF.SLC30A9
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR922YDT.ENCFF441QXF.SLC30A9.0.txt
# Submitted batch job 29960021
#
# File Prefix (Annotation): K562.ENCSR924GXX.ENCFF785QJM.PHB2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR924GXX.ENCFF785QJM.PHB2.0.txt
# Submitted batch job 29960022
#
# File Prefix (Annotation): K562.ENCSR924JOW.ENCFF555IKI.KAT7
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR924JOW.ENCFF555IKI.KAT7.0.txt
# Submitted batch job 29960023
#
# File Prefix (Annotation): K562.ENCSR926KTP.ENCFF724CHN.IRF9
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR926KTP.ENCFF724CHN.IRF9.0.txt
# Submitted batch job 29960024
#
# File Prefix (Annotation): K562.ENCSR928KOR.ENCFF365ETH.GMEB1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR928KOR.ENCFF365ETH.GMEB1.0.txt
# Submitted batch job 29960025
#
# File Prefix (Annotation): K562.ENCSR931HNY.ENCFF660DEP.NCOA1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR931HNY.ENCFF660DEP.NCOA1.0.txt
# Submitted batch job 29960026
#
# File Prefix (Annotation): K562.ENCSR934RJP.ENCFF798AFV.ZNF3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR934RJP.ENCFF798AFV.ZNF3.0.txt
# Submitted batch job 29960027
#
# File Prefix (Annotation): K562.ENCSR935PEA.ENCFF875JMR.CREB5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR935PEA.ENCFF875JMR.CREB5.0.txt
# Submitted batch job 29960028
#
# File Prefix (Annotation): K562.ENCSR935UQL.ENCFF188PLS.MECOM
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR935UQL.ENCFF188PLS.MECOM.0.txt
# Submitted batch job 29960029
#
# File Prefix (Annotation): K562.ENCSR939CDD.ENCFF086FAZ.ARID4B
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR939CDD.ENCFF086FAZ.ARID4B.0.txt
# Submitted batch job 29960030
#
# File Prefix (Annotation): K562.ENCSR942XQI.ENCFF330SHG.RAD21
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR942XQI.ENCFF330SHG.RAD21.0.txt
# Submitted batch job 29960031
#
# File Prefix (Annotation): K562.ENCSR946BXO.ENCFF620FIH.BRCA1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR946BXO.ENCFF620FIH.BRCA1.0.txt
# Submitted batch job 29960032
#
# File Prefix (Annotation): K562.ENCSR946WBN.ENCFF865UPM.JUN
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR946WBN.ENCFF865UPM.JUN.0.txt
# Submitted batch job 29960033
#
# File Prefix (Annotation): K562.ENCSR947PJZ.ENCFF449JMB.HIVEP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR947PJZ.ENCFF449JMB.HIVEP1.0.txt
# Submitted batch job 29960034
#
# File Prefix (Annotation): K562.ENCSR948JND.ENCFF380KJB.ZNF398
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR948JND.ENCFF380KJB.ZNF398.0.txt
# Submitted batch job 29960035
#
# File Prefix (Annotation): K562.ENCSR948KMB.ENCFF835NOD.PTBP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR948KMB.ENCFF835NOD.PTBP1.0.txt
# Submitted batch job 29960036
#
# File Prefix (Annotation): K562.ENCSR948QLZ.ENCFF470CSE.CBX1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR948QLZ.ENCFF470CSE.CBX1.0.txt
# Submitted batch job 29960037
#
# File Prefix (Annotation): K562.ENCSR948VFL.ENCFF637SIR.IKZF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR948VFL.ENCFF637SIR.IKZF1.0.txt
# Submitted batch job 29960038
#
# File Prefix (Annotation): K562.ENCSR949NVY.ENCFF669VJB.ZNF639
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR949NVY.ENCFF669VJB.ZNF639.0.txt
# Submitted batch job 29960039
#
# File Prefix (Annotation): K562.ENCSR953DVM.ENCFF925GLW.E2F8
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR953DVM.ENCFF925GLW.E2F8.0.txt
# Submitted batch job 29960040
#
# File Prefix (Annotation): K562.ENCSR953KEY.ENCFF592NJN.TFE3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR953KEY.ENCFF592NJN.TFE3.0.txt
# Submitted batch job 29960041
#
# File Prefix (Annotation): K562.ENCSR957LDM.ENCFF597YMB.TRIM24
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR957LDM.ENCFF597YMB.TRIM24.0.txt
# Submitted batch job 29960042
#
# File Prefix (Annotation): K562.ENCSR958JPH.ENCFF144ZLB.TSHZ1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR958JPH.ENCFF144ZLB.TSHZ1.0.txt
# Submitted batch job 29960043
#
# File Prefix (Annotation): K562.ENCSR959BQO.ENCFF208OME.ZNF700
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR959BQO.ENCFF208OME.ZNF700.0.txt
# Submitted batch job 29960044
#
# File Prefix (Annotation): K562.ENCSR968GIB.ENCFF768VRG.RFX1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR968GIB.ENCFF768VRG.RFX1.0.txt
# Submitted batch job 29960045
#
# File Prefix (Annotation): K562.ENCSR970NKQ.ENCFF746GDG.NR2F1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR970NKQ.ENCFF746GDG.NR2F1.0.txt
# Submitted batch job 29960046
#
# File Prefix (Annotation): K562.ENCSR970OJY.ENCFF773RNU.TCF3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR970OJY.ENCFF773RNU.TCF3.0.txt
# Submitted batch job 29960047
#
# File Prefix (Annotation): K562.ENCSR971EWR.ENCFF604LXR.ETV5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR971EWR.ENCFF604LXR.ETV5.0.txt
# Submitted batch job 29960048
#
# File Prefix (Annotation): K562.ENCSR972CVS.ENCFF198NGY.ELK3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR972CVS.ENCFF198NGY.ELK3.0.txt
# Submitted batch job 29960049
#
# File Prefix (Annotation): K562.ENCSR972ZBV.ENCFF951BFN.ATF7
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR972ZBV.ENCFF951BFN.ATF7.0.txt
# Submitted batch job 29960050
#
# File Prefix (Annotation): K562.ENCSR975SSR.ENCFF133TSU.ELF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR975SSR.ENCFF133TSU.ELF1.0.txt
# Submitted batch job 29960051
#
# File Prefix (Annotation): K562.ENCSR979QYJ.ENCFF986SXD.MNT
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR979QYJ.ENCFF986SXD.MNT.0.txt
# Submitted batch job 29960052
#
# File Prefix (Annotation): K562.ENCSR980ZWE.ENCFF201BGD.NR3C1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR980ZWE.ENCFF201BGD.NR3C1.0.txt
# Submitted batch job 29960053
#
# File Prefix (Annotation): K562.ENCSR985OYK.ENCFF227HVU.ZBTB11
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR985OYK.ENCFF227HVU.ZBTB11.0.txt
# Submitted batch job 29960054
#
# File Prefix (Annotation): K562.ENCSR986CDX.ENCFF625QHR.NEUROD1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR986CDX.ENCFF625QHR.NEUROD1.0.txt
# Submitted batch job 29960055
#
# File Prefix (Annotation): K562.ENCSR987KYK.ENCFF159END.ZNF717
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR987KYK.ENCFF159END.ZNF717.0.txt
# Submitted batch job 29960056
#
# File Prefix (Annotation): K562.ENCSR987PBI.ENCFF412WOK.DNMT1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR987PBI.ENCFF412WOK.DNMT1.0.txt
# Submitted batch job 29960057
#
# File Prefix (Annotation): K562.ENCSR990AZC.ENCFF583XAW.MCM3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR990AZC.ENCFF583XAW.MCM3.0.txt
# Submitted batch job 29960058
#
# File Prefix (Annotation): K562.ENCSR991ELG.ENCFF553GPK.SP1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR991ELG.ENCFF553GPK.SP1.0.txt
# Submitted batch job 29960059
#
# File Prefix (Annotation): K562.ENCSR992KLV.ENCFF749GMT.MYNN
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR992KLV.ENCFF749GMT.MYNN.0.txt
# Submitted batch job 29960060
#
# File Prefix (Annotation): K562.ENCSR995FUM.ENCFF670RLH.ZNF79
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR995FUM.ENCFF670RLH.ZNF79.0.txt
# Submitted batch job 29960061
#
# File Prefix (Annotation): K562.ENCSR996ESX.ENCFF321LMQ.NFRKB
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR996ESX.ENCFF321LMQ.NFRKB.0.txt
# Submitted batch job 29960062
#
# File Prefix (Annotation): K562.ENCSR996SKD.ENCFF798LLI.CXXC5
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR996SKD.ENCFF798LLI.CXXC5.0.txt
# Submitted batch job 29960063
#
# File Prefix (Annotation): K562.ENCSR997NGQ.ENCFF137OGC.XRCC3
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR997NGQ.ENCFF137OGC.XRCC3.0.txt
# Submitted batch job 29960064
#
# File Prefix (Annotation): K562.ENCSR998AJK.ENCFF777PKJ.NRF1
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR998AJK.ENCFF777PKJ.NRF1.0.txt
# Submitted batch job 29960065
#
# File Prefix (Annotation): K562.ENCSR998OMC.ENCFF392MAR.TFCP2
# File Path (Log):    ${FD_LOG}/peak.annotation.K562.ENCSR998OMC.ENCFF392MAR.TFCP2.0.txt
# Submitted batch job 29960066

# %% [markdown]
# **Check results**

# %%
cat ${FD_LOG}/peak.annotation.K562.ENCSR000AKO.ENCFF769AUF.CTCF.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         06-11-23+15:07:10
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/annotation_chipseq_tf/K562.ENCSR000AKO.ENCFF769AUF.CTCF.bed.gz
#
# show first few lines of input
# chr1	267966	268092	.	1000	.	36.26682	-1.00000	4.33816	58
# chr1	778701	778979	.	1000	.	78.32446	-1.00000	4.65032	175
# chr1	778870	779294	.	1000	.	22.45062	-1.00000	4.08853	212
# chr1	869772	870056	.	1000	.	140.67100	-1.00000	4.65032	149
# chr1	904625	904954	.	1000	.	150.99362	-1.00000	4.65032	154
#
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/annotation_chipseq_tf/peak.annotation.K562.ENCSR000AKO.ENCFF769AUF.CTCF.bed.gz
#
# show first few lines of output:
# chr1	267853	268603	chr1	267966	268092	.	1000	.	36.26682	-1.00000	4.33816	58	126
# chr1	777949	779437	chr1	778701	778979	.	1000	.	78.32446	-1.00000	4.65032	175	278
# chr1	777949	779437	chr1	778870	779294	.	1000	.	22.45062	-1.00000	4.08853	212	424
# chr1	869623	870250	chr1	869772	870056	.	1000	.	140.67100	-1.00000	4.65032	149	284
# chr1	903633	905556	chr1	904625	904954	.	1000	.	150.99362	-1.00000	4.65032	154	329
#
#
# Done!
# Run Time: 0 seconds
