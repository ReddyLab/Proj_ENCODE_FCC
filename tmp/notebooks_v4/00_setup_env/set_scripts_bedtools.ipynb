# %%
ls -1 ../scripts
# Out:
# run_bedtools_annot_A.sh
# run_bedtools_annot.sh
# run_bedtools_closest.sh
# run_bedtools_intersect_inv.sh
# run_bedtools_intersect.sh
# run_bedtools_merge_assay.sh
# run_bedtools_merge_region.sh
# run_bedtools_test.sh

# %% [markdown]
# ## Test

# %%
cat > ../scripts/run_bedtools_test.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute: annotation using intersect
bedtools -h

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_test.sh

# %% [markdown]
# ## Bedtools intersect: overlap

# %%
cat > ../scripts/run_bedtools_intersect.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute: annotation using intersect
bedtools intersect \
    -a ${FP_INP1} \
    -b ${FP_INP2} \
    -wo \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_intersect.sh

# %%
cat > ../scripts/run_bedtools_intersect_inv.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute: annotation using inversed intersect
bedtools intersect \
    -a ${FP_INP1} \
    -b ${FP_INP2} \
    -v    \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_intersect_inv.sh

# %% [markdown]
# ## Bedtools intersect: annotation
#
# **Set requirement of overlapping percentage as 70%**

# %%
cat > ../scripts/run_bedtools_annot.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute: annotation using intersect
bedtools intersect \
    -a ${FP_INP1} \
    -b ${FP_INP2} \
    -wo \
    -f 0.7 \
    -F 0.7 \
    -e \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_annot.sh

# %%
cat > ../scripts/run_bedtools_annot_A.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute: annotation using intersect
bedtools intersect \
    -a ${FP_INP1} \
    -b ${FP_INP2} \
    -wo \
    -f 0.7 \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_annot_A.sh

# %% [markdown]
# ## Bedtools Closest
# get the distance between the closest elements in A and B. if `distance == 0`, the elements overlapped

# %%
cat > ../scripts/run_bedtools_closest.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### setup input and output
source ../config/config_duke.sh
FP_INP1=$1
FP_INP2=$2
FP_OUT=$3

### show I/O file
echo "Input: " ${FP_INP1}
echo
echo "show first few lines of input"
fun_head ${FP_INP1}
echo
echo "Input: " ${FP_INP2}
echo
echo "show first few lines of input"
fun_head ${FP_INP2}
echo

### execute
bedtools closest \
    -a ${FP_INP1} \
    -b ${FP_INP2} \
    -d    \
| awk '{ if($4 != ".") { print }}' \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_closest.sh

# %% [markdown]
# ## Bedtools merge

# %%
cat > ../scripts/run_bedtools_merge_assay.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### arguement
FP_INP=${1}
FP_OUT=${2}

### setup input and output
source ../config/config_duke.sh

### show input file
echo "Input: " ${FP_INP}
echo
echo "show first few lines of input"
fun_head ${FP_INP}
echo

### execute
NUM_COLS=$(zcat ${FP_INP} | head -n 1 | awk -F '\t' '{print NF}')
let NUM_COL1=${NUM_COLS}-1
let NUM_COL2=${NUM_COLS}

bedtools merge \
    -i ${FP_INP} \
    -c ${NUM_COL1},${NUM_COL2} \
    -o distinct,distinct \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_merge_assay.sh

# %%
cat > ../scripts/run_bedtools_merge_region.sh << 'EOF'
#!/bin/bash

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### arguement
FP_INP=${1}
FP_OUT=${2}

### setup input and output
source ../config/config_duke.sh

### show input file
echo "Input: " ${FP_INP}
echo
echo "show first few lines of input"
fun_head ${FP_INP}
echo

### execute
bedtools merge \
    -i ${FP_INP} \
| gzip -c \
> ${FP_OUT}

### show output file
echo
echo "Output: " ${FP_OUT}
echo
echo "show first few lines of output:"
fun_head ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF

chmod +x ../scripts/run_bedtools_merge_region.sh
