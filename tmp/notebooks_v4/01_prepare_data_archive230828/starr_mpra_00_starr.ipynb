# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# SING DIRECTORY (FD_SING): /data/reddylab/Kuei/singularity
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# ## WSTARR WGS files
# ```
# FD_WGS_WSTARR=/data/reddylab/Alex/encode4_duke/data/starr_seq/fragments
# FP_WGS_WSTARR=($(ls ${FD_WGS_WSTARR}/*.fragments.counts.txt.gz))
# ```

# %%
ls /data/reddylab/Alex/encode4_duke/data/starr_seq
# Out:
# fragments  metadata  motifs  peaks  processed_raw_reads  qc  raw_reads

# %%
ls /data/reddylab/Alex/encode4_duke/data/starr_seq/metadata
# Out:
# 210413_KS91_K562ASTARROutputMetadata_hg19.xlsx
# 210413_KS91_K562ASTARROutputMetadata_hg38.xlsx
# 210413_KS91_K562ASTARROutputMetadata_simple_hg38.xlsx
# starr_seq_download_metadata.210401_KS91_K562ASTARR_NovaSeq.hg38.txt
# starr_seq_download_metadata.210401_KS91_K562ASTARR_NovaSeq.txt

# %%
FDIRY=${FD_WGS_WSTARR}
echo ${FDIRY}
echo
ls ${FDIRY}
# Out:
# /data/reddylab/Alex/encode4_duke/data/starr_seq/fragments
#
# A001-input-K562-rep1.masked.dedup.fragments.counts.txt.gz
# A001-input-K562-rep2.masked.dedup.fragments.counts.txt.gz
# A001-input-K562-rep3.masked.dedup.fragments.counts.txt.gz
# A001-input-K562-rep4.masked.dedup.fragments.counts.txt.gz
# A001-K562-rep1.masked.dedup.fragments.bedpe.gz
# A001-K562-rep1.masked.dedup.fragments.counts.txt.gz
# A001-K562-rep2.masked.dedup.fragments.bedpe.gz
# A001-K562-rep2.masked.dedup.fragments.counts.txt.gz
# A001-K562-rep3.masked.dedup.fragments.bedpe.gz
# A001-K562-rep3.masked.dedup.fragments.counts.txt.gz

# %%
FDIRY=${FD_WGS_WSTARR}
FNAME=A001-K562-rep1.masked.dedup.fragments.bedpe.gz
FPATH=${FDIRY}/${FNAME}

ls ${FPATH} 
echo
zcat ${FPATH} | head
# Out:
# /data/reddylab/Alex/encode4_duke/data/starr_seq/fragments/A001-K562-rep1.masked.dedup.fragments.bedpe.gz
#
# chr22	28435543	28435569	chr22	28435961	28435987	NB501800:606:HNC2JBGXH:1:11101:1082:11852	42	+	-
# chr8	96107311	96107336	chr8	96107788	96107814	NB501800:606:HNC2JBGXH:1:11101:1083:3001	42	+	-
# chr3	37902240	37902265	chr3	37902744	37902770	NB501800:606:HNC2JBGXH:1:11101:1084:4570	42	+	-
# chr11	113487921	113487947	chr11	113488317	113488341	NB501800:606:HNC2JBGXH:1:11101:1084:7183	42	+	-
# chr15	75231795	75231821	chr15	75232123	75232149	NB501800:606:HNC2JBGXH:1:11101:1084:16920	42	+	-
# chr12	25935228	25935254	chr12	25935585	25935611	NB501800:606:HNC2JBGXH:1:11101:1085:15170	42	+	-
# chr21	34313584	34313610	chr21	34314031	34314056	NB501800:606:HNC2JBGXH:1:11101:1086:7206	42	+	-
# chr15	78667429	78667455	chr15	78667862	78667887	NB501800:606:HNC2JBGXH:1:11101:1086:9918	42	+	-
# chr6	27688950	27688976	chr6	27689378	27689403	NB501800:606:HNC2JBGXH:1:11101:1086:18506	42	+	-
# ...

# %% [markdown]
# ## ASTARR WGS files
# ```
# FD_WGS_ASTARR_INP=${FD_ALEX}/encode4_duke/processing/atac_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-blacklist-removal/merged2
#
# FD_WGS_ASTARR_OUT=${FD_ALEX}/encode4_duke/processing/starr_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-umis
#
# FP_WGS_ASTARR_INP=($(ls ${FD_WGS_ASTARR_INP}/*counts.txt.gz))
#
# FP_WGS_ASTARR_OUT=($(ls ${FD_WGS_ASTARR_OUT}/*f3q10.fragments.counts.txt.gz))
# ```

# %%
FDIRY=${FD_WGS_ASTARR_INP}
echo ${FDIRY}
echo
ls ${FDIRY}
# Out:
# /data/reddylab/Alex/encode4_duke/processing/atac_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-blacklist-removal/merged2
#
# fragments
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.bedpe.gz
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dedup.fragments.bedpe.gz
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dedup.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dedup.fragments.bedpe.gz
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dedup.fragments.counts.txt.gz
# ...

# %%
FDIRY=${FD_WGS_ASTARR_INP}
FNAME=KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.bedpe.gz
FPATH=${FDIRY}/${FNAME}

ls ${FPATH} 
echo
zcat ${FPATH} | head
# Out:
# /data/reddylab/Alex/encode4_duke/processing/atac_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-blacklist-removal/merged2/KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.bedpe.gz
#
# chr16	1513456	1513557	chr16	1513530	1513631	A00257:568:HWTKHDSXY:1:1101:1000:5635	255	+	-
# chr6	31157968	31158042	chr6	31158066	31158167	A00257:568:HWTKHDSXY:1:1101:1000:5916	255	+	-
# chr12	4276861	4276962	chr12	4277097	4277198	A00257:568:HWTKHDSXY:1:1101:1000:6073	255	+	-
# chr3	150827231	150827332	chr3	150827290	150827391	A00257:568:HWTKHDSXY:1:1101:1000:7639	255	+	-
# chr5	12581434	12581535	chr5	12581515	12581616	A00257:568:HWTKHDSXY:1:1101:1000:8140	255	+	-
# chr20	62122050	62122151	chr20	62122353	62122454	A00257:568:HWTKHDSXY:1:1101:1000:10833	255	+	-
# chr2	179331910	179332011	chr2	179332106	179332207	A00257:568:HWTKHDSXY:1:1101:1000:11678	255	+	-
# chr1	25875342	25875443	chr1	25875387	25875488	A00257:568:HWTKHDSXY:1:1101:1000:13495	255	+	-
# ...

# %%
FDIRY=${FD_WGS_ASTARR_INP}
FNAME=KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.counts.txt.gz
FPATH=${FDIRY}/${FNAME}

ls ${FPATH} 
echo
zcat ${FPATH} | head
# Out:
# /data/reddylab/Alex/encode4_duke/processing/atac_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-blacklist-removal/merged2/KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.counts.txt.gz
#
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.

# %%
FDIRY=${FD_WGS_ASTARR_OUT}
echo ${FDIRY}
echo
ls ${FDIRY}
# Out:
# /data/reddylab/Alex/encode4_duke/processing/starr_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-umis
#
# by_chrom
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.fragments.bedpe
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dedup.cpm.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_included.cpm.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked.bam.bai
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked.cpm.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked_peaks.narrowPeak
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked_peaks.xls
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked_summits.bed
# KS91_K562_hg38_ASTARRseq_Output_rep1.input_subtracted.bw
# ...
