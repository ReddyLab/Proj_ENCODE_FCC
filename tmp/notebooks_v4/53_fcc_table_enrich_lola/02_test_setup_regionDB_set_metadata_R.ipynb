# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
suppressMessages(suppressWarnings(source("../config/config_func.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **Check data**

# %%
fdiry = file.path(
    FD_RES, 
    "results", 
    "region", 
    "KS91_K562_ASTARRseq_peak_macs_input",
    "enrichment_lola",
    "regionDB_test"
)

print(fdiry)
for (txt in dir(fdiry)){cat("*", txt, "\n")}
cat("\n")

fdiry = file.path(fdiry, "encode_chipseq_tf_k562")
print(fdiry)
for (txt in dir(fdiry)){cat("*", txt, "\n")}
cat("\n")

fdiry = file.path(fdiry, "regions")
print(fdiry)
for (txt in dir(fdiry)){cat("*", txt, "\n")}
# Out:
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_lola/regionDB_test"
# * encode_chipseq_tf_k562
#
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_lola/regionDB_test/encode_chipseq_tf_k562"
# * collection.txt
# * encode_chipseq_tf_k562_files.RData
# * encode_chipseq_tf_k562.RData
# * index.txt
# * regions
# * sizes.txt
#
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/region/KS91_K562_ASTARRseq_peak_macs_input/enrichment_lola/regionDB_test/encode_chipseq_tf_k562/regions"
# * K562.ENCSR000BMH.ENCFF398UQZ.YY1.bed.gz
# * K562.ENCSR000BMW.ENCFF707MDI.REST.bed.gz
# * K562.ENCSR000EFS.ENCFF190CGV.JUN.bed.gz
# * K562.ENCSR000EFT.ENCFF657CTC.GATA1.bed.gz
# * K562.ENCSR000EFU.ENCFF715WGN.ELK1.bed.gz
# * K562.ENCSR000EGE.ENCFF702XPO.EP300.bed.gz
# * K562.ENCSR000EGM.ENCFF660GHM.CTCF.bed.gz
# * K562.ENCSR000EHB.ENCFF852ZRK.TAL1.bed.gz
# * K562.ENCSR004GKA.ENCFF242AOL.ZEB2.bed.gz
# * K562.ENCSR091GVJ.ENCFF627RSK.ATF1.bed.gz
# * K562.ENCSR121SPB.ENCFF142ZTD.KLF10.bed.gz
# * K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz
# * K562.ENCSR552YGL.ENCFF023IFO.NFE2.bed.gz
# * K562.ENCSR760UVO.ENCFF488OTN.KLF16.bed.gz
# * K562.ENCSR991ELG.ENCFF553GPK.SP1.bed.gz
# * K562.ENCSR998AJK.ENCFF777PKJ.NRF1.bed.gz

# %% [markdown]
# ## Annotating collections: Create `collection.txt` file
# ```
#     collector (your name)
#     date (time you produced the collection)
#     source (paper or website where you got the data)
#     description (free form field for details)
# ```

# %%
dat = tibble::tribble(
    ~collector, ~date, ~source, ~description,
    "KY KO", "2023/10/21", "ENCODE", "ChIP-seq TF"
)
dat_collection = dat
dat
# Out:
#   collector date       source description
# 1 KY KO     2023/10/21 ENCODE ChIP-seq TF

# %% [markdown]
# ## Annotating region sets: Create `index.txt` file
# ```
#     filename (must match files in the collection exactly)
#     description
#     cellType
#     tissue
#     antibody (for ChIP experiments)
#     treatment
#     dataSource (for publication author, database, etc.)
# ```

# %%
fdiry = file.path(
    FD_RES, 
    "source", 
    "annotation_chipseq_tf"
)
fname = "ENCODE4_TF_Accessions_for_Flagship_update221025.csv"
fpath = file.path(fdiry, fname)

dat = read_csv(fpath, show_col_types = FALSE)
dat_annot_chipseq_tf_info = dat
print(dim(dat))
head(dat)
# Out:
# [1] 3092    6
#   Experiment_Accession Peak_Accession
# 1 ENCSR753RME          ENCFF917CYG
# 2 ENCSR992XTY          ENCFF112GJQ
# 3 ENCSR934GQS          ENCFF483KVM
# 4 ENCSR164ASX          ENCFF238PEB
# 5 ENCSR000VGD          ENCFF870ZRR
# 6 ENCSR856TKC          ENCFF072KJO
#   Biosample                                                          Target
# 1 Homo sapiens testis tissue male adult (37 years)                   CTCF
# 2 Homo sapiens WTC11                                                 CTCF
# 3 Homo sapiens ovary tissue female adult (41 years)                  CTCF
# 4 Homo sapiens upper lobe of right lung tissue male adult (60 years) CTCF
# 5 Homo sapiens right lobe of liver tissue female adult (47 years)    CTCF
# 6 Homo sapiens natural killer cell male adult (33 years)             CTCF
#   Lab                      RFA
# 1 Bradley Bernstein, Broad ENCODE4
# 2 Bradley Bernstein, Broad ENCODE4
# 3 Bradley Bernstein, Broad ENCODE4
# 4 Bradley Bernstein, Broad ENCODE4
# 5 Bradley Bernstein, Broad ENCODE4
# 6 Bradley Bernstein, Broad ENCODE4

# %%
fdiry = file.path(
    FD_RES, 
    "results", 
    "region", 
    "KS91_K562_ASTARRseq_peak_macs_input",
    "enrichment_lola",
    "regionDB_test",
    "encode_chipseq_tf_k562",
    "regions"
)

vec = dir(fdiry)
dat = data.frame(
    filename = vec,
    fprefix  = str_remove_all(vec, pattern = ".bed|.gz")
)
dat = dat %>% 
    tidyr::separate(
        fprefix, 
        c("cellType", "Experiment_Accession", "Peak_Accession", "antibody")
    )

dat_fname = dat
dat
# Out:
#    filename                                   cellType Experiment_Accession
# 1  K562.ENCSR000BMH.ENCFF398UQZ.YY1.bed.gz    K562     ENCSR000BMH
# 2  K562.ENCSR000BMW.ENCFF707MDI.REST.bed.gz   K562     ENCSR000BMW
# 3  K562.ENCSR000EFS.ENCFF190CGV.JUN.bed.gz    K562     ENCSR000EFS
# 4  K562.ENCSR000EFT.ENCFF657CTC.GATA1.bed.gz  K562     ENCSR000EFT
# 5  K562.ENCSR000EFU.ENCFF715WGN.ELK1.bed.gz   K562     ENCSR000EFU
# 6  K562.ENCSR000EGE.ENCFF702XPO.EP300.bed.gz  K562     ENCSR000EGE
# 7  K562.ENCSR000EGM.ENCFF660GHM.CTCF.bed.gz   K562     ENCSR000EGM
# 8  K562.ENCSR000EHB.ENCFF852ZRK.TAL1.bed.gz   K562     ENCSR000EHB
# 9  K562.ENCSR004GKA.ENCFF242AOL.ZEB2.bed.gz   K562     ENCSR004GKA
# 10 K562.ENCSR091GVJ.ENCFF627RSK.ATF1.bed.gz   K562     ENCSR091GVJ
# 11 K562.ENCSR121SPB.ENCFF142ZTD.KLF10.bed.gz  K562     ENCSR121SPB
# 12 K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz K562     ENCSR388QZF
# 13 K562.ENCSR552YGL.ENCFF023IFO.NFE2.bed.gz   K562     ENCSR552YGL
# 14 K562.ENCSR760UVO.ENCFF488OTN.KLF16.bed.gz  K562     ENCSR760UVO
# 15 K562.ENCSR991ELG.ENCFF553GPK.SP1.bed.gz    K562     ENCSR991ELG
# 16 K562.ENCSR998AJK.ENCFF777PKJ.NRF1.bed.gz   K562     ENCSR998AJK
#    Peak_Accession antibody
# 1  ENCFF398UQZ    YY1
# 2  ENCFF707MDI    REST
# 3  ENCFF190CGV    JUN
# 4  ENCFF657CTC    GATA1
# 5  ENCFF715WGN    ELK1
# 6  ENCFF702XPO    EP300
# 7  ENCFF660GHM    CTCF
# 8  ENCFF852ZRK    TAL1
# 9  ENCFF242AOL    ZEB2
# 10 ENCFF627RSK    ATF1
# 11 ENCFF142ZTD    KLF10
# 12 ENCFF355MNE    POLR2A
# 13 ENCFF023IFO    NFE2
# 14 ENCFF488OTN    KLF16
# 15 ENCFF553GPK    SP1
# 16 ENCFF777PKJ    NRF1

# %%
dat = dat_fname
dat = dat %>% 
    dplyr::left_join(dat_annot_chipseq_tf_info, by=c("Experiment_Accession", "Peak_Accession")) %>%
    dplyr::mutate(
        dataSource  = paste(Lab, RFA, sep=";"),
        description = paste(Experiment_Accession, Peak_Accession, Target, Biosample, sep=";")
    ) %>%
    dplyr::select(
        filename, cellType, antibody, dataSource, description)#, 
        #Experiment_Accession, 
        #Peak_Accession, 
        #Biosample, 
        #Target)
        
dat_index = dat
dat
# Out:
#    filename                                   cellType antibody
# 1  K562.ENCSR000BMH.ENCFF398UQZ.YY1.bed.gz    K562     YY1
# 2  K562.ENCSR000BMW.ENCFF707MDI.REST.bed.gz   K562     REST
# 3  K562.ENCSR000EFS.ENCFF190CGV.JUN.bed.gz    K562     JUN
# 4  K562.ENCSR000EFT.ENCFF657CTC.GATA1.bed.gz  K562     GATA1
# 5  K562.ENCSR000EFU.ENCFF715WGN.ELK1.bed.gz   K562     ELK1
# 6  K562.ENCSR000EGE.ENCFF702XPO.EP300.bed.gz  K562     EP300
# 7  K562.ENCSR000EGM.ENCFF660GHM.CTCF.bed.gz   K562     CTCF
# 8  K562.ENCSR000EHB.ENCFF852ZRK.TAL1.bed.gz   K562     TAL1
# 9  K562.ENCSR004GKA.ENCFF242AOL.ZEB2.bed.gz   K562     ZEB2
# 10 K562.ENCSR091GVJ.ENCFF627RSK.ATF1.bed.gz   K562     ATF1
# 11 K562.ENCSR121SPB.ENCFF142ZTD.KLF10.bed.gz  K562     KLF10
# 12 K562.ENCSR388QZF.ENCFF355MNE.POLR2A.bed.gz K562     POLR2A
# 13 K562.ENCSR552YGL.ENCFF023IFO.NFE2.bed.gz   K562     NFE2
# 14 K562.ENCSR760UVO.ENCFF488OTN.KLF16.bed.gz  K562     KLF16
# 15 K562.ENCSR991ELG.ENCFF553GPK.SP1.bed.gz    K562     SP1
# 16 K562.ENCSR998AJK.ENCFF777PKJ.NRF1.bed.gz   K562     NRF1
#    dataSource
# 1  Richard Myers, HAIB;ENCODE2
# 2  Richard Myers, HAIB;ENCODE2
# 3  Michael Snyder, Stanford;ENCODE2
# 4  Michael Snyder, Stanford;ENCODE2
# 5  Michael Snyder, Stanford;ENCODE2
# 6  Michael Snyder, Stanford;ENCODE2
# 7  Michael Snyder, Stanford;ENCODE2
# 8  Michael Snyder, Stanford;ENCODE2
# 9  Michael Snyder, Stanford;ENCODE3
# 10 Michael Snyder, Stanford;ENCODE3
# 11 Michael Snyder, Stanford;ENCODE4
# 12 Michael Snyder, Stanford;ENCODE3
# 13 Michael Snyder, Stanford;ENCODE3
# 14 Richard Myers, HAIB;ENCODE3
# 15 Michael Snyder, Stanford;ENCODE3
# 16 Michael Snyder, Stanford;ENCODE3
#    description
# 1  ENCSR000BMH;ENCFF398UQZ;YY1;Homo sapiens K562
# 2  ENCSR000BMW;ENCFF707MDI;REST;Homo sapiens K562
# 3  ENCSR000EFS;ENCFF190CGV;JUN;Homo sapiens K562
# 4  ENCSR000EFT;ENCFF657CTC;GATA1;Homo sapiens K562
# 5  ENCSR000EFU;ENCFF715WGN;ELK1;Homo sapiens K562
# 6  ENCSR000EGE;ENCFF702XPO;EP300;Homo sapiens K562
# 7  ENCSR000EGM;ENCFF660GHM;CTCF;Homo sapiens K562
# 8  ENCSR000EHB;ENCFF852ZRK;TAL1;Homo sapiens K562
# 9  ENCSR004GKA;ENCFF242AOL;ZEB2;Homo sapiens K562
# 10 ENCSR091GVJ;ENCFF627RSK;ATF1;Homo sapiens K562 stably expressing ATF1
# 11 ENCSR121SPB;ENCFF142ZTD;KLF10;Homo sapiens K562 genetically modified (insertion) using CRISPR targeting H. sapiens KLF10
# 12 ENCSR388QZF;ENCFF355MNE;POLR2A;Homo sapiens K562
# 13 ENCSR552YGL;ENCFF023IFO;NFE2;Homo sapiens K562 stably expressing NFE2
# 14 ENCSR760UVO;ENCFF488OTN;KLF16;Homo sapiens K562
# 15 ENCSR991ELG;ENCFF553GPK;SP1;Homo sapiens K562
# 16 ENCSR998AJK;ENCFF777PKJ;NRF1;Homo sapiens K562

# %% [markdown]
# ## Save results

# %%
fdiry = file.path(
    FD_RES, 
    "results", 
    "region", 
    "KS91_K562_ASTARRseq_peak_macs_input",
    "enrichment_lola",
    "regionDB_test",
    "encode_chipseq_tf_k562"
)

fname = "collection.txt"
fpath = file.path(fdiry, fname)

dat = dat_collection
write_tsv(dat, fpath)

fname = "index.txt"
fpath = file.path(fdiry, fname)

dat = dat_index
write_tsv(dat, fpath)
