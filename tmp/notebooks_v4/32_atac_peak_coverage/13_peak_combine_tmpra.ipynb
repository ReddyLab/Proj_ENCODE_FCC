# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **Check data**

# %%
fdiry = file.path(FD_RES, "results", "Tewhey_K562_TileMPRA", "coverage_astarrseq_peak_macs_input")
dir(fdiry)
# Out:
#  [1] "OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz"
#  [2] "OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz"
#  [3] "OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz"
#  [4] "OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz"
#  [5] "OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz"
#  [6] "OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz"
#  [7] "OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz"
#  [8] "OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz"
#  [9] "OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz"
# [10] "OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz"
# [11] "OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz"
# [12] "OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz"
# [13] "OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz"
# [14] "OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz"
# [15] "OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz"
# [16] "OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz"
# [17] "OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz"
# [18] "OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz"
# [19] "OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz"
# [20] "OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz"
# [21] "OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz"
# [22] "OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz"
# [23] "OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz"
# [24] "OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz"
# [25] "OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz"
# [26] "OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz"
# [27] "OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz"
# [28] "summary"

# %%
ASSAY   = "Tewhey_K562_TileMPRA"
PREFIXS = c("OL13_20220512", "OL43_20221003", "OL45_20220927")

FOLDER  = "coverage_astarrseq_peak_macs_input"
GENOME  = "hg38"

TYPE    = "raw"
GROUPS  = c("Input", "Output")

SAMPLES = c(
    paste0("Input.rep",  1:6),
    paste0("Output.rep", 1:6))

CNAMES = c("Chrom", "Start", "End", "Count")

get_info = function(fpath, strings){
    idx = str_detect(string = fpath, pattern = strings)
    return(strings[idx])
}

get_group  = function(fpath){return(get_info(fpath, GROUPS))}
get_sample = function(fpath){return(get_info(fpath, SAMPLES))}

# %% [markdown]
# ## Library size

# %%
fdiry = file.path(FD_RES, "results", ASSAY, "coverage", "summary")
fname = "library_size_summary.tsv"
fpath = file.path(fdiry, fname)
dat_lib = read_tsv(fpath, show_col_types = FALSE)
dat_lib
# Out:
#    FName                                                Size      Prefix
# 1  OL13_20220512.hg19.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 2  OL13_20220512.hg19.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 3  OL13_20220512.hg19.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 4  OL13_20220512.hg19.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 5  OL13_20220512.hg19.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 6  OL13_20220512.hg19.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 7  OL13_20220512.hg19.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 8  OL13_20220512.hg19.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 9  OL13_20220512.hg19.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 10 OL13_20220512.hg19.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 11 OL13_20220512.hg19.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 12 OL13_20220512.hg19.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 13 OL13_20220512.hg19.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 14 OL13_20220512.hg19.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# 15 OL13_20220512.hg19.raw.Output.rep3.stranded_pos.bed  16323839  OL13_20220512
# 16 OL13_20220512.hg19.raw.Output.rep4.stranded_pos.bed  15755240  OL13_20220512
# 17 OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed   6418470  OL13_20220512
# 18 OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed   6412311  OL13_20220512
# 19 OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed   6413568  OL13_20220512
# 20 OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed   6410822  OL13_20220512
# 21 OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed 24214237  OL13_20220512
# 22 OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed 21967607  OL13_20220512
# 23 OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed 20773782  OL13_20220512
# 24 OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed 19239234  OL13_20220512
# 25 OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed   11710957  OL13_20220512
# 26 OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed    6544172  OL13_20220512
# 27 OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed   10465235  OL13_20220512
# 28 OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed    6601711  OL13_20220512
# 29 OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed  11317273  OL13_20220512
# 30 OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed  10913523  OL13_20220512
# ⋮  ⋮                                                    ⋮         ⋮
# 41 OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed 114646887 OL43_20221003
# 42 OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed 130086009 OL43_20221003
# 43 OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed 120461487 OL43_20221003
# 44 OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed    67808075 OL43_20221003
# 45 OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed    76561739 OL43_20221003
# 46 OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed    71168558 OL43_20221003
# 47 OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed    72593861 OL43_20221003
# 48 OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed    35160045 OL43_20221003
# 49 OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed    35230272 OL43_20221003
# 50 OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed   85916775 OL43_20221003
# 51 OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed   64383745 OL43_20221003
# 52 OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed  106218676 OL43_20221003
# 53 OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed   75440322 OL43_20221003
# 54 OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed   85257860 OL43_20221003
# 55 OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed   42577629 OL45_20220927
# 56 OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed   42657457 OL45_20220927
# 57 OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed   42746400 OL45_20220927
# 58 OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed   42740318 OL45_20220927
# 59 OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed  94286600 OL45_20220927
# 60 OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed  96442408 OL45_20220927
# 61 OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed  99043384 OL45_20220927
# 62 OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed  96478668 OL45_20220927
# 63 OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed    57835964 OL45_20220927
# 64 OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed    49098092 OL45_20220927
# 65 OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed    50494539 OL45_20220927
# 66 OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed    49646312 OL45_20220927
# 67 OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed   76571038 OL45_20220927
# 68 OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed   64193541 OL45_20220927
# 69 OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed   58531500 OL45_20220927
# 70 OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed   86396781 OL45_20220927
#    Sample      Group  Type Genome
# 1  Input.rep1  Input  norm hg19
# 2  Input.rep2  Input  norm hg19
# 3  Input.rep3  Input  norm hg19
# 4  Input.rep4  Input  norm hg19
# 5  Output.rep1 Output norm hg19
# 6  Output.rep2 Output norm hg19
# 7  Output.rep3 Output norm hg19
# 8  Output.rep4 Output norm hg19
# 9  Input.rep1  Input  raw  hg19
# 10 Input.rep2  Input  raw  hg19
# 11 Input.rep3  Input  raw  hg19
# 12 Input.rep4  Input  raw  hg19
# 13 Output.rep1 Output raw  hg19
# 14 Output.rep2 Output raw  hg19
# 15 Output.rep3 Output raw  hg19
# 16 Output.rep4 Output raw  hg19
# 17 Input.rep1  Input  norm hg38
# 18 Input.rep2  Input  norm hg38
# 19 Input.rep3  Input  norm hg38
# 20 Input.rep4  Input  norm hg38
# 21 Output.rep1 Output norm hg38
# 22 Output.rep2 Output norm hg38
# 23 Output.rep3 Output norm hg38
# 24 Output.rep4 Output norm hg38
# 25 Input.rep1  Input  raw  hg38
# 26 Input.rep2  Input  raw  hg38
# 27 Input.rep3  Input  raw  hg38
# 28 Input.rep4  Input  raw  hg38
# 29 Output.rep1 Output raw  hg38
# 30 Output.rep2 Output raw  hg38
# ⋮  ⋮           ⋮      ⋮    ⋮
# 41 Output.rep3 Output norm hg38
# 42 Output.rep4 Output norm hg38
# 43 Output.rep5 Output norm hg38
# 44 Input.rep1  Input  raw  hg38
# 45 Input.rep2  Input  raw  hg38
# 46 Input.rep3  Input  raw  hg38
# 47 Input.rep4  Input  raw  hg38
# 48 Input.rep5  Input  raw  hg38
# 49 Input.rep6  Input  raw  hg38
# 50 Output.rep1 Output raw  hg38
# 51 Output.rep2 Output raw  hg38
# 52 Output.rep3 Output raw  hg38
# 53 Output.rep4 Output raw  hg38
# 54 Output.rep5 Output raw  hg38
# 55 Input.rep1  Input  norm hg38
# 56 Input.rep2  Input  norm hg38
# 57 Input.rep3  Input  norm hg38
# 58 Input.rep4  Input  norm hg38
# 59 Output.rep1 Output norm hg38
# 60 Output.rep2 Output norm hg38
# 61 Output.rep3 Output norm hg38
# 62 Output.rep4 Output norm hg38
# 63 Input.rep1  Input  raw  hg38
# 64 Input.rep2  Input  raw  hg38
# 65 Input.rep3  Input  raw  hg38
# 66 Input.rep4  Input  raw  hg38
# 67 Output.rep1 Output raw  hg38
# 68 Output.rep2 Output raw  hg38
# 69 Output.rep3 Output raw  hg38
# 70 Output.rep4 Output raw  hg38

# %% [markdown]
# ## Loop (Raw)

# %%
for (PREFIX in PREFIXS){
    ###
    cat("\n=========================================\n")
    cat("Prefix:", PREFIX, "\n")
    
    fname  = paste(PREFIX, GENOME, TYPE, "bed.gz", sep="*") 
    fglob  = file.path(FD_RES, "results", ASSAY, FOLDER, fname)
    fpaths = Sys.glob(fglob)
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Metadata:", "\n")
    
    dat_meta = data.frame(
        Sample = sapply(fpaths, get_sample),
        Group  = sapply(fpaths, get_group),
        FPath  = fpaths,
        row.names = NULL
    )
    print(dat_meta)
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Import count data:", "\n")
    
    cnames = c("Chrom", "Start", "End", "Count")
    ctypes = c(col_character(), col_integer(), col_integer(), col_integer())

    lst = lapply(fpaths, function(fpath){
        sam = get_sample(fpath)
        dat = read_tsv(fpath, col_names = cnames, col_types = ctypes) %>% 
            dplyr::filter(Count != ".") %>% 
            dplyr::mutate(Count  = as.integer(Count)) %>%
            dplyr::mutate(
                Peak   = paste0(Chrom, ":", Start, "-", End),
                Sample = sam,
                Prefix = PREFIX,
                Type   = TYPE,
                Genome = GENOME)
        return(dat)
    })
    dat = bind_rows(lst)
    
    dat_count = dat
    cat(dim(dat), "\n\n")
    print(head(dat_count))
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Calulate CPM:", "\n")
    
    dat = left_join(dat_count, dat_lib, by = c("Sample", "Prefix", "Type", "Genome"))
    dat = dat %>%
        dplyr::mutate(CPM = Count * 10^6 / Size) %>%
        dplyr::select(Chrom, Start, End, Peak, Sample, Count, CPM)

    dat_count_cpm = dat
    print(dim(dat))
    print(head(dat))
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Arrange to matrix (Raw):", "\n")    
    dat = dat_count_cpm
    dat = dat %>% 
        dplyr::select(Peak, Sample, Count) %>%
        spread(Sample, Count) %>% 
        replace(is.na(.), 0)

    mat_count_raw = dat
    print(dim(dat))
    print(head(dat))
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Arrange to matrix (CPM):", "\n")    
    dat = dat_count_cpm
    dat = dat %>% 
        dplyr::select(Peak, Sample, CPM) %>%
        spread(Sample, CPM) %>% 
        replace(is.na(.), 0)

    mat_count_cpm = dat
    print(dim(dat))
    print(head(dat))
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Calculate log2fc:", "\n")    
    dat = mat_count_cpm
    dat = dat %>%
        dplyr::mutate(
            Input  = rowMeans(across(starts_with("Input"))),
            Output = rowMeans(across(starts_with("Output")))
        ) %>%
        dplyr::mutate(
            Log2FC  = log2(Output)   - log2(Input),
            pLog2FC = log2(Output+1) - log2(Input+1)
        ) %>%
        dplyr::select(Peak, Input, Output, Log2FC, pLog2FC)

    dat_log2fc = dat
    print(dim(dat))
    print(head(dat))

    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Save results: (Metadata)", "\n")
    
    fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
    fname = paste("metadata", TYPE, PREFIX, "tsv", sep=".") # "metadata.raw.OL13.tsv"
    fpath = file.path(fdiry, fname)
    print(fpath)

    dat = dat_meta
    write_tsv(dat, fpath)
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Save results: (Count)", "\n")
    
    fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
    fname = paste("matrix", TYPE, "count", PREFIX, "tsv", sep=".") # "matrix.raw.count.OL13.tsv"
    fpath = file.path(fdiry, fname)
    print(fpath)

    dat = mat_count_raw
    write_tsv(dat, fpath)
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Save results: (CPM)", "\n")
    
    fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
    fname = paste("matrix", TYPE, "cpm", PREFIX, "tsv", sep=".") # "matrix.raw.cpm.OL13.tsv"
    fpath = file.path(fdiry, fname)
    print(fpath)

    dat = mat_count_cpm
    write_tsv(dat, fpath)
    
    ###
    cat("\n+++++++++++++++++++++++++++++++++++++++++\n")
    cat("Save results: (Log2FC)", "\n")
    fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
    fname = paste("result.Log2FC", TYPE, "cpm", PREFIX, "tsv", sep=".") # "result.Log2FC.raw.cpm.OL13.tsv"
    fpath = file.path(fdiry, fname)
    print(fpath)

    dat = dat_log2fc
    write_tsv(dat, fpath)

    flush.console()
}
# Out:
# =========================================
# Prefix: OL13_20220512
#
# +++++++++++++++++++++++++++++++++++++++++
# Metadata:
#        Sample  Group
# 1  Input.rep1  Input
# 2  Input.rep2  Input
# 3  Input.rep3  Input
# 4  Input.rep4  Input
# 5 Output.rep1 Output
# 6 Output.rep2 Output
# 7 Output.rep3 Output
# 8 Output.rep4 Output
#                                                                                                                                                                       FPath
# 1  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
# 2  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
# 3  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
# 4  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
# 5 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
# 6 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
# 7 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
# 8 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# +++++++++++++++++++++++++++++++++++++++++
# Import count data:
# 176 9
#
# # A tibble: 6 × 9
#   Chrom    Start      End  Count Peak                 Sample Prefix Type  Genome
#   <chr>    <dbl>    <dbl>  <int> <chr>                <chr>  <chr>  <chr> <chr>
# 1 chr11 61792068 61793464 123964 chr11:61792068-6179… Input… OL13_… raw   hg38
# 2 chr11 61800085 61801113  93429 chr11:61800085-6180… Input… OL13_… raw   hg38
# 3 chr11 61806630 61807154  73252 chr11:61806630-6180… Input… OL13_… raw   hg38
# 4 chr11 61814735 61817343 200996 chr11:61814735-6181… Input… OL13_… raw   hg38
# 5 chr11 61822094 61822443  31914 chr11:61822094-6182… Input… OL13_… raw   hg38
# 6 chr11 61825795 61826306  32681 chr11:61825795-6182… Input… OL13_… raw   hg38
#
# +++++++++++++++++++++++++++++++++++++++++
# Calulate CPM:
# [1] 176   7
# # A tibble: 6 × 7
#   Chrom    Start      End Peak                    Sample      Count    CPM
#   <chr>    <dbl>    <dbl> <chr>                   <chr>       <int>  <dbl>
# 1 chr11 61792068 61793464 chr11:61792068-61793464 Input.rep1 123964 10585.
# 2 chr11 61800085 61801113 chr11:61800085-61801113 Input.rep1  93429  7978.
# 3 chr11 61806630 61807154 chr11:61806630-61807154 Input.rep1  73252  6255.
# 4 chr11 61814735 61817343 chr11:61814735-61817343 Input.rep1 200996 17163.
# 5 chr11 61822094 61822443 chr11:61822094-61822443 Input.rep1  31914  2725.
# 6 chr11 61825795 61826306 chr11:61825795-61826306 Input.rep1  32681  2791.
#
# +++++++++++++++++++++++++++++++++++++++++
# Arrange to matrix (Raw):
# [1] 22  9
# # A tibble: 6 × 9
#   Peak       Input.rep1 Input.rep2 Input.rep3 Input.rep4 Output.rep1 Output.rep2
#   <chr>           <int>      <int>      <int>      <int>       <int>       <int>
# 1 chr11:617…     123964      69072     113487      71526      461111      461000
# 2 chr11:618…      93429      53063      83490      53637      424590      398992
# 3 chr11:618…      73252      39188      63205      40131       29775       28918
# 4 chr11:618…     200996     114253     180968     113933     1392238     1406638
# 5 chr11:618…      31914      17567      28311      17860        8275        9393
# 6 chr11:618…      32681      18795      29971      19749       29360       29820
# # ℹ 2 more variables: Output.rep3 <int>, Output.rep4 <int>
#
# +++++++++++++++++++++++++++++++++++++++++
# Arrange to matrix (CPM):
# [1] 22  9
# # A tibble: 6 × 9
#   Peak       Input.rep1 Input.rep2 Input.rep3 Input.rep4 Output.rep1 Output.rep2
#   <chr>           <dbl>      <dbl>      <dbl>      <dbl>       <dbl>       <dbl>
# 1 chr11:617…     10585.     10555.     10844.     10834.      40744.      42241.
# 2 chr11:618…      7978.      8108.      7978.      8125.      37517.      36559.
# 3 chr11:618…      6255.      5988.      6040.      6079.       2631.       2650.
# 4 chr11:618…     17163.     17459.     17292.     17258.     123019.     128889.
# 5 chr11:618…      2725.      2684.      2705.      2705.        731.        861.
# 6 chr11:618…      2791.      2872.      2864.      2991.       2594.       2732.
# # ℹ 2 more variables: Output.rep3 <dbl>, Output.rep4 <dbl>
#
# +++++++++++++++++++++++++++++++++++++++++
# Calculate log2fc:
# [1] 22  5
# # A tibble: 6 × 5
#   Peak                     Input  Output Log2FC pLog2FC
#   <chr>                    <dbl>   <dbl>  <dbl>   <dbl>
# 1 chr11:61792068-61793464 10705.  40948.  1.94    1.94
# 2 chr11:61800085-61801113  8047.  35129.  2.13    2.13
# 3 chr11:61806630-61807154  6090.   2860. -1.09   -1.09
# 4 chr11:61814735-61817343 17293. 120548.  2.80    2.80
# 5 chr11:61822094-61822443  2705.    949. -1.51   -1.51
# 6 chr11:61825795-61826306  2880.   2643. -0.124  -0.124
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Metadata)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/metadata.raw.OL13_20220512.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Count)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/matrix.raw.count.OL13_20220512.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (CPM)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/matrix.raw.cpm.OL13_20220512.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Log2FC)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/result.Log2FC.raw.cpm.OL13_20220512.tsv"
#
# =========================================
# Prefix: OL43_20221003
#
# +++++++++++++++++++++++++++++++++++++++++
# Metadata:
#         Sample  Group
# 1   Input.rep1  Input
# 2   Input.rep2  Input
# 3   Input.rep3  Input
# 4   Input.rep4  Input
# 5   Input.rep5  Input
# 6   Input.rep6  Input
# 7  Output.rep1 Output
# 8  Output.rep2 Output
# 9  Output.rep3 Output
# 10 Output.rep4 Output
# 11 Output.rep5 Output
#                                                                                                                                                                        FPath
# 1   /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
# 2   /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
# 3   /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
# 4   /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
# 5   /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
# 6   /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
# 7  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
# 8  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
# 9  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
# 10 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
# 11 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
#
# +++++++++++++++++++++++++++++++++++++++++
# Import count data:
# 4334 9
#
# # A tibble: 6 × 9
#   Chrom     Start       End Count Peak                Sample Prefix Type  Genome
#   <chr>     <dbl>     <dbl> <int> <chr>               <chr>  <chr>  <chr> <chr>
# 1 chr8  126778902 126779728 10372 chr8:126778902-126… Input… OL43_… raw   hg38
# 2 chr8  126782925 126783318  3076 chr8:126782925-126… Input… OL43_… raw   hg38
# 3 chr8  126804776 126805825 16184 chr8:126804776-126… Input… OL43_… raw   hg38
# 4 chr8  126817018 126817490 10013 chr8:126817018-126… Input… OL43_… raw   hg38
# 5 chr8  126820465 126821393 16573 chr8:126820465-126… Input… OL43_… raw   hg38
# 6 chr8  126824093 126824987 27649 chr8:126824093-126… Input… OL43_… raw   hg38
#
# +++++++++++++++++++++++++++++++++++++++++
# Calulate CPM:
# [1] 4334    7
# # A tibble: 6 × 7
#   Chrom     Start       End Peak                     Sample     Count   CPM
#   <chr>     <dbl>     <dbl> <chr>                    <chr>      <int> <dbl>
# 1 chr8  126778902 126779728 chr8:126778902-126779728 Input.rep1 10372 153.
# 2 chr8  126782925 126783318 chr8:126782925-126783318 Input.rep1  3076  45.4
# 3 chr8  126804776 126805825 chr8:126804776-126805825 Input.rep1 16184 239.
# 4 chr8  126817018 126817490 chr8:126817018-126817490 Input.rep1 10013 148.
# 5 chr8  126820465 126821393 chr8:126820465-126821393 Input.rep1 16573 244.
# 6 chr8  126824093 126824987 chr8:126824093-126824987 Input.rep1 27649 408.
#
# +++++++++++++++++++++++++++++++++++++++++
# Arrange to matrix (Raw):
# [1] 394  12
# # A tibble: 6 × 12
#   Peak         Input.rep1 Input.rep2 Input.rep3 Input.rep4 Input.rep5 Input.rep6
#   <chr>             <int>      <int>      <int>      <int>      <int>      <int>
# 1 chr8:126778…      10372      11304      10609      11042       5318       5475
# 2 chr8:126782…       3076       3477       3122       3211       1563       1614
# 3 chr8:126804…      16184      18791      17453      17754       8529       8533
# 4 chr8:126817…      10013      11400      10553      10900       5157       5076
# 5 chr8:126820…      16573      19018      17231      17757       8703       8698
# 6 chr8:126824…      27649      32054      29605      29659      14783      14827
# # ℹ 5 more variables: Output.rep1 <int>, Output.rep2 <int>, Output.rep3 <int>,
# #   Output.rep4 <int>, Output.rep5 <int>
#
# +++++++++++++++++++++++++++++++++++++++++
# Arrange to matrix (CPM):
# [1] 394  12
# # A tibble: 6 × 12
#   Peak         Input.rep1 Input.rep2 Input.rep3 Input.rep4 Input.rep5 Input.rep6
#   <chr>             <dbl>      <dbl>      <dbl>      <dbl>      <dbl>      <dbl>
# 1 chr8:126778…      153.       148.       149.       152.       151.       155.
# 2 chr8:126782…       45.4       45.4       43.9       44.2       44.5       45.8
# 3 chr8:126804…      239.       245.       245.       245.       243.       242.
# 4 chr8:126817…      148.       149.       148.       150.       147.       144.
# 5 chr8:126820…      244.       248.       242.       245.       248.       247.
# 6 chr8:126824…      408.       419.       416.       409.       420.       421.
# # ℹ 5 more variables: Output.rep1 <dbl>, Output.rep2 <dbl>, Output.rep3 <dbl>,
# #   Output.rep4 <dbl>, Output.rep5 <dbl>
#
# +++++++++++++++++++++++++++++++++++++++++
# Calculate log2fc:
# [1] 394   5
# # A tibble: 6 × 5
#   Peak                     Input Output Log2FC pLog2FC
#   <chr>                    <dbl>  <dbl>  <dbl>   <dbl>
# 1 chr8:126778902-126779728 151.   474.   1.65    1.64
# 2 chr8:126782925-126783318  44.9   31.9 -0.493  -0.481
# 3 chr8:126804776-126805825 243.   726.   1.58    1.58
# 4 chr8:126817018-126817490 148.    95.3 -0.631  -0.626
# 5 chr8:126820465-126821393 246.   215.  -0.195  -0.194
# 6 chr8:126824093-126824987 415.  1346.   1.70    1.69
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Metadata)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/metadata.raw.OL43_20221003.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Count)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/matrix.raw.count.OL43_20221003.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (CPM)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/matrix.raw.cpm.OL43_20221003.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Log2FC)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/result.Log2FC.raw.cpm.OL43_20221003.tsv"
#
# =========================================
# Prefix: OL45_20220927
#
# +++++++++++++++++++++++++++++++++++++++++
# Metadata:
#        Sample  Group
# 1  Input.rep1  Input
# 2  Input.rep2  Input
# 3  Input.rep3  Input
# 4  Input.rep4  Input
# 5 Output.rep1 Output
# 6 Output.rep2 Output
# 7 Output.rep3 Output
# 8 Output.rep4 Output
#                                                                                                                                                                       FPath
# 1  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
# 2  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
# 3  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
# 4  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
# 5 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
# 6 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
# 7 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
# 8 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# +++++++++++++++++++++++++++++++++++++++++
# Import count data:
# 10448 9
#
# # A tibble: 6 × 9
#   Chrom   Start     End Count Peak                  Sample   Prefix Type  Genome
#   <chr>   <dbl>   <dbl> <int> <chr>                 <chr>    <chr>  <chr> <chr>
# 1 chr11 4539569 4540043  3092 chr11:4539569-4540043 Input.r… OL45_… raw   hg38
# 2 chr11 4551336 4552012  4522 chr11:4551336-4552012 Input.r… OL45_… raw   hg38
# 3 chr11 4553969 4555012  5879 chr11:4553969-4555012 Input.r… OL45_… raw   hg38
# 4 chr11 4569016 4569992  5951 chr11:4569016-4569992 Input.r… OL45_… raw   hg38
# 5 chr11 4577444 4578031  4736 chr11:4577444-4578031 Input.r… OL45_… raw   hg38
# 6 chr11 4601808 4602487  4352 chr11:4601808-4602487 Input.r… OL45_… raw   hg38
#
# +++++++++++++++++++++++++++++++++++++++++
# Calulate CPM:
# [1] 10448     7
# # A tibble: 6 × 7
#   Chrom   Start     End Peak                  Sample     Count   CPM
#   <chr>   <dbl>   <dbl> <chr>                 <chr>      <int> <dbl>
# 1 chr11 4539569 4540043 chr11:4539569-4540043 Input.rep1  3092  53.5
# 2 chr11 4551336 4552012 chr11:4551336-4552012 Input.rep1  4522  78.2
# 3 chr11 4553969 4555012 chr11:4553969-4555012 Input.rep1  5879 102.
# 4 chr11 4569016 4569992 chr11:4569016-4569992 Input.rep1  5951 103.
# 5 chr11 4577444 4578031 chr11:4577444-4578031 Input.rep1  4736  81.9
# 6 chr11 4601808 4602487 chr11:4601808-4602487 Input.rep1  4352  75.2
#
# +++++++++++++++++++++++++++++++++++++++++
# Arrange to matrix (Raw):
# [1] 1306    9
# # A tibble: 6 × 9
#   Peak       Input.rep1 Input.rep2 Input.rep3 Input.rep4 Output.rep1 Output.rep2
#   <chr>           <int>      <int>      <int>      <int>       <int>       <int>
# 1 chr11:328…       5796       5349       5093       5236        4190        3932
# 2 chr11:328…       4925       4182       4315       4301        5557        3395
# 3 chr11:328…       8452       7263       7369       7154       12228       10838
# 4 chr11:328…      13661      11814      11553      11485       31756       29398
# 5 chr11:329…       8501       7376       7544       7221        6066        4803
# 6 chr11:329…      10373       8676       9442       9147        7865        6824
# # ℹ 2 more variables: Output.rep3 <int>, Output.rep4 <int>
#
# +++++++++++++++++++++++++++++++++++++++++
# Arrange to matrix (CPM):
# [1] 1306    9
# # A tibble: 6 × 9
#   Peak       Input.rep1 Input.rep2 Input.rep3 Input.rep4 Output.rep1 Output.rep2
#   <chr>           <dbl>      <dbl>      <dbl>      <dbl>       <dbl>       <dbl>
# 1 chr11:328…      100.       109.       101.       105.         54.7        61.3
# 2 chr11:328…       85.2       85.2       85.5       86.6        72.6        52.9
# 3 chr11:328…      146.       148.       146.       144.        160.        169.
# 4 chr11:328…      236.       241.       229.       231.        415.        458.
# 5 chr11:329…      147.       150.       149.       145.         79.2        74.8
# 6 chr11:329…      179.       177.       187.       184.        103.        106.
# # ℹ 2 more variables: Output.rep3 <dbl>, Output.rep4 <dbl>
#
# +++++++++++++++++++++++++++++++++++++++++
# Calculate log2fc:
# [1] 1306    5
# # A tibble: 6 × 5
#   Peak                    Input Output Log2FC pLog2FC
#   <chr>                   <dbl>  <dbl>  <dbl>   <dbl>
# 1 chr11:32870601-32871324 104.    58.7 -0.824  -0.813
# 2 chr11:32874343-32875070  85.6   61.3 -0.482  -0.475
# 3 chr11:32884749-32885822 146.   165.   0.180   0.179
# 4 chr11:32892099-32894437 234.   431.   0.880   0.878
# 5 chr11:32901572-32902485 148.    78.3 -0.919  -0.910
# 6 chr11:32903491-32904506 182.   106.  -0.785  -0.779
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Metadata)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/metadata.raw.OL45_20220927.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Count)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/matrix.raw.count.OL45_20220927.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (CPM)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/matrix.raw.cpm.OL45_20220927.tsv"
#
# +++++++++++++++++++++++++++++++++++++++++
# Save results: (Log2FC)
# [1] "/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/summary/result.Log2FC.raw.cpm.OL45_20220927.tsv"

# %%
dat_meta = data.frame(
        Sample = sapply(fpaths, get_sample),
        Group  = sapply(fpaths, get_group),
        FPath  = fpaths,
    row.names = NULL
    )
    print(dat_meta)
# Out:
#        Sample  Group
# 1  Input.rep1  Input
# 2  Input.rep2  Input
# 3  Input.rep3  Input
# 4  Input.rep4  Input
# 5 Output.rep1 Output
# 6 Output.rep2 Output
# 7 Output.rep3 Output
# 8 Output.rep4 Output
#                                                                                                                                                                       FPath
# 1  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
# 2  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
# 3  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
# 4  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
# 5 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
# 6 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
# 7 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
# 8 /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/Tewhey_K562_TileMPRA/coverage_astarrseq_peak_macs_input/OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
