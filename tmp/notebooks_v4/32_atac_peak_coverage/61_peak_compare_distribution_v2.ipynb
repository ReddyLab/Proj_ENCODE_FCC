# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/out
# CODE DIRECTORY (FD_CODE): /data/reddylab/Kuei/code
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS (FD_RES): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc
# PATH OF LOG     (FD_LOG): /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %% [markdown]
# **Check data files: coverage**

# %%
fdiry  = file.path(
    FD_RES, 
    "results"
)
for(fname in dir(fdiry)){print(fname)}
# Out:
# [1] "A001_K562_WSTARRseq"
# [1] "comparison"
# [1] "CRISPRi_FlowFISH"
# [1] "CRISPRi_Growth_K562_Gersbach"
# [1] "hic_intact_K562_deep"
# [1] "hic_intact_K562_ENCSR479XDG"
# [1] "KS91_K562_ASTARRseq"
# [1] "LentiMPRA_K562_Nadav"
# [1] "region"
# [1] "Tewhey_K562_TileMPRA"

# %% [markdown]
# ## Get ATAC Peaks screened by ASTARR

# %% [markdown]
# **Check data files**

# %%
FOLDER = "KS91_K562_ASTARRseq"
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
for(fname in dir(fdiry)){print(fname)}
# Out:
# [1] "matrix.raw.count.WGS.tsv"
# [1] "matrix.raw.cpm.WGS.tsv"
# [1] "metadata.raw.WGS.tsv"
# [1] "result.Log2FC.raw.cpm.WGS.tsv"
# [1] "result.Log2FC.raw.deseq.WGS.tsv"
# [1] "result.score.raw.cpm.WGS.tsv"

# %% [markdown]
# **Import data**

# %%
### init
FOLDER = "KS91_K562_ASTARRseq"

### get file path
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
fname = "result.Log2FC.raw.deseq.WGS.tsv"
fpath = file.path(fdiry, fname)

### read table
dat = read_tsv(fpath, show_col_types = FALSE)

### assign and show
dat_peak_screened_astarr = dat
print(dim(dat))
head(dat)
# Out:
# [1] 246850      7
#   Peak                     baseMean  log2FoldChange lfcSE      stat
# 1 chr1:100006256-100006880  74.39238 -0.01311792    0.15512423 -0.08456397
# 2 chr1:100010437-100010915  48.25931 -0.80687947    0.22174651 -3.63874709
# 3 chr1:10002087-10003910   224.35927 -0.34892859    0.09743886 -3.58100041
# 4 chr1:100021298-100021629  38.13434 -1.03799571    0.25401013 -4.08643436
# 5 chr1:100023727-100023976  32.62049 -0.19100207    0.25625467 -0.74536036
# 6 chr1:100027983-100029702 290.98442 -0.18001582    0.09610434 -1.87312902
#   pvalue       padj
# 1 9.326080e-01 0.9510236543
# 2 2.739677e-04 0.0008947519
# 3 3.422811e-04 0.0010926173
# 4 4.380534e-05 0.0001707736
# 5 4.560539e-01 0.5497617125
# 6 6.105057e-02 0.1032752224

# %% [markdown]
# ## Get ATAC Peaks screened by WSTARR

# %% [markdown]
# **Check data files**

# %%
FOLDER = "A001_K562_WSTARRseq"
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
for(fname in dir(fdiry)){print(fname)}
# Out:
# [1] "matrix.raw.count.WGS.tsv"
# [1] "matrix.raw.cpm.WGS.tsv"
# [1] "metadata.raw.WGS.tsv"
# [1] "result.Log2FC.raw.cpm.WGS.tsv"
# [1] "result.Log2FC.raw.deseq.WGS.tsv"

# %% [markdown]
# **Import data**

# %%
### init
FOLDER = "A001_K562_WSTARRseq"

### get file path
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
fname = "result.Log2FC.raw.deseq.WGS.tsv"
fpath = file.path(fdiry, fname)

### read table
dat = read_tsv(fpath, show_col_types = FALSE)

### assign and show
dat_peak_screened_wstarr = dat
print(dim(dat))
head(dat)
# Out:
# [1] 246688      7
#   Peak                     baseMean  log2FoldChange lfcSE     stat
# 1 chr1:100006256-100006880 54.500445 -0.48849764    0.1997784 -2.4451969
# 2 chr1:100010437-100010915 30.645878 -0.30895395    0.2528932 -1.2216777
# 3 chr1:10002087-10003910   66.045530 -0.38624192    0.1730120 -2.2324569
# 4 chr1:100021298-100021629  8.289442 -0.59404974    0.4799400 -1.2377583
# 5 chr1:100023727-100023976 12.258468  0.04988694    0.4075494  0.1224071
# 6 chr1:100027983-100029702 80.536286 -0.22927538    0.1665249 -1.3768236
#   pvalue     padj
# 1 0.01447731 0.09534129
# 2 0.22182954 0.50094986
# 3 0.02558478 0.14019267
# 4 0.21580568         NA
# 5 0.90257663 0.96366009
# 6 0.16856680 0.43305688

# %% [markdown]
# ## Get ATAC Peaks screened by TMPRA

# %% [markdown]
# **Check data files**

# %%
FOLDER = "Tewhey_K562_TileMPRA"
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
for(fname in dir(fdiry)){print(fname)}
# Out:
# [1] "matrix.raw.count.OL13_20220512.tsv"
# [1] "matrix.raw.count.OL43_20221003.tsv"
# [1] "matrix.raw.count.OL45_20220927.tsv"
# [1] "matrix.raw.cpm.OL13_20220512.tsv"
# [1] "matrix.raw.cpm.OL43_20221003.tsv"
# [1] "matrix.raw.cpm.OL45_20220927.tsv"
# [1] "metadata.raw.OL13_20220512.tsv"
# [1] "metadata.raw.OL43_20221003.tsv"
# [1] "metadata.raw.OL45_20220927.tsv"
# [1] "result.Log2FC.raw.cpm.Merge.tsv"
# [1] "result.Log2FC.raw.cpm.OL13_20220512.tsv"
# [1] "result.Log2FC.raw.cpm.OL43_20221003.tsv"
# [1] "result.Log2FC.raw.cpm.OL45_20220927.tsv"
# [1] "result.Log2FC.raw.deseq.Merge.tsv"
# [1] "result.Log2FC.raw.deseq.OL13_20220512.tsv"
# [1] "result.Log2FC.raw.deseq.OL43_20221003.tsv"
# [1] "result.Log2FC.raw.deseq.OL45_20220927.tsv"

# %% [markdown]
# **Import data**

# %%
### init
FOLDER = "Tewhey_K562_TileMPRA"

### get file path
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
fname = "result.Log2FC.raw.deseq.Merge.tsv"
fpath = file.path(fdiry, fname)

### read table
dat = read_tsv(fpath, show_col_types = FALSE)

### assign and show
dat_peak_screened_tmpra = dat
print(dim(dat))
head(dat)
# Out:
# [1] 1722    8
#   Dataset Peak                    baseMean  log2FoldChange lfcSE
# 1 OL13    chr11:61792068-61793464 260242.12  1.6665654     0.03671583
# 2 OL13    chr11:61800085-61801113 216437.58  1.8554038     0.04389284
# 3 OL13    chr11:61806630-61807154  49327.33 -1.3562271     0.07733082
# 4 OL13    chr11:61814735-61817343 682819.52  2.5310145     0.03600593
# 5 OL13    chr11:61822094-61822443  20363.10 -1.7731459     0.16511332
# 6 OL13    chr11:61825795-61826306  29539.40 -0.3921375     0.05359585
#   stat       pvalue       padj
# 1  45.390919 0.000000e+00 0.000000e+00
# 2  42.271214 0.000000e+00 0.000000e+00
# 3 -17.537989 7.348170e-69 1.347165e-68
# 4  70.294376 0.000000e+00 0.000000e+00
# 5 -10.738963 6.679004e-27 8.163227e-27
# 6  -7.316565 2.543988e-13 2.665130e-13

# %% [markdown]
# ## Get ATAC Peaks screened by LMPRA

# %% [markdown]
# **Check data files**

# %%
FOLDER = "LentiMPRA_K562_Nadav"
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
for(fname in dir(fdiry)){print(fname)}
# Out:
# [1] "results.score.ENCSR382BVV.ENCFF348WYK.tsv"
# [1] "results.score.tsv"
# [1] "results.score.vikram230621.tsv"
# [1] "results.summary.ENCSR382BVV.ENCFF348WYK.tsv"
# [1] "results.summary.tsv"
# [1] "results.summary.vikram230621.tsv"

# %% [markdown]
# **Import data**

# %%
### init
FOLDER = "LentiMPRA_K562_Nadav"

### get file path
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
fname = "results.summary.vikram230621.tsv"
fpath = file.path(fdiry, fname)

### read table
dat = read_tsv(fpath, show_col_types = FALSE)

### assign and show
dat_peak_screened_lmpra = dat
print(dim(dat))
head(dat)
# Out:
# [1] 68420     8
#   Peak                      Mean       Median     Max       Min         Count
# 1 chr10:100045961-100046653 1.35946554 1.35946554 1.4810917  1.23783940 2
# 2 chr10:100065094-100065486 1.07264569 1.07264569 1.3503890  0.79490241 2
# 3 chr10:100081317-100081607 0.08511404 0.08511404 0.7150285 -0.54480044 2
# 4 chr10:100129051-100131059 0.21944739 0.21944739 0.2611997  0.17769514 2
# 5 chr10:100185017-100187275 0.59521771 0.59521771 1.1724880  0.01794737 2
# 6 chr10:100228452-100230090 5.54013719 5.54013719 6.0266418  5.05363263 2
#   Mean_Neg   Mean_Pos
# 1  0.0000000 1.3594655
# 2  0.0000000 1.0726457
# 3 -0.5448004 0.7150285
# 4  0.0000000 0.2194474
# 5  0.0000000 0.5952177
# 6  0.0000000 5.5401372

# %% [markdown]
# ## Get ATAC Peaks screened by CRISPRi-HCRFF

# %% [markdown]
# **Check data files**

# %%
FOLDER = "CRISPRi_FlowFISH"
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
for(fname in dir(fdiry)){print(fname)}
# Out:
# [1] "results.score.tsv"
# [1] "results.summary.Merge.tsv"
# [1] "results.summary.tsv"

# %% [markdown]
# **Import data**

# %%
### init
FOLDER = "CRISPRi_FlowFISH"

### get file path
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
fname = "results.summary.Merge.tsv"
fpath = file.path(fdiry, fname)

### read table
dat = read_tsv(fpath, show_col_types = FALSE)

### assign and show
dat_peak_screened_crispri_hcrff = dat
print(dim(dat))
head(dat)
# Out:
# [1] 1330    6
#   Peak                    Mean_Tot    Mean_Pos   Mean_Neg   Count
# 1 chr11:33065336-33066228 -0.08308383 0.03675483 -0.2734393 138
# 2 chr11:33068519-33069100 -0.12006903 0.00000000 -0.1593220 159
# 3 chr11:33072412-33072630  0.10643558 0.35299267 -0.1982723  36
# 4 chr11:33103533-33104120  0.98158422 1.44209600  0.0000000   9
# 5 chr11:33114629-33115134  0.22095793 0.42649733  0.0000000  27
# 6 chr11:33125296-33126416 -0.05128921 0.04323581 -0.1542515 159
#   Note
# 1 CAPRIN1:138|CAT:138|LMO2:138
# 2 CAPRIN1:159|CAT:159|LMO2:159
# 3 CAPRIN1:36|CAT:36|LMO2:36
# 4 CAPRIN1:9|CAT:9|LMO2:9
# 5 CAPRIN1:27|CAT:27|LMO2:27
# 6 CAPRIN1:159|CAT:159|LMO2:159

# %% [markdown]
# ## Get ATAC Peaks screened by CRISPRi-Growth

# %% [markdown]
# **Check data files**

# %%
FOLDER = "CRISPRi_Growth_K562_Gersbach"
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
for(fname in dir(fdiry)){print(fname)}
# Out:
# [1] "results.score.tsv"
# [1] "results.summary.tsv"

# %% [markdown]
# **Import data**

# %%
### init
FOLDER = "CRISPRi_Growth_K562_Gersbach"

### get file path
fdiry  = file.path(
    FD_RES, 
    "results",
    FOLDER,
    "coverage_astarrseq_peak_macs_input",
    "summary"
)
fname = "results.summary.tsv"
fpath = file.path(fdiry, fname)

### read table
dat = read_tsv(fpath, show_col_types = FALSE)

### assign and show
dat_peak_screened_crispri_growth = dat
print(dim(dat))
head(dat)
# Out:
# [1] 80288     8
#   Peak                      Mean        Median     Max      Min       Count
# 1 chr10:100009096-100010466 -0.03786170  0.0303830 0.526902 -0.655965 10
# 2 chr10:100045961-100046653  0.10873570  0.1820295 0.646953 -0.497578 10
# 3 chr10:100065094-100065486 -0.00323730 -0.0931995 1.305380 -0.677550 10
# 4 chr10:100129051-100131059 -0.26576144 -0.2617330 0.253159 -0.767330  9
# 5 chr10:100185017-100187275 -0.01202196 -0.0613300 0.730481 -0.954435 25
# 6 chr10:100228452-100230090 -0.01822050  0.0722880 0.446912 -0.768059 10
#   Mean_Neg   Mean_Pos
# 1 -0.3840866 0.3083632
# 2 -0.2750008 0.3645600
# 3 -0.3639722 0.5378650
# 4 -0.4522120 0.1071397
# 5 -0.2790666 0.3278531
# 6 -0.3293750 0.1892158

# %% [markdown]
# ## ASTARR

# %%
dat = dat_peak_screened_astarr
head(dat)
# Out:
#   Peak                     baseMean  log2FoldChange lfcSE      stat
# 1 chr1:100006256-100006880  74.39238 -0.01311792    0.15512423 -0.08456397
# 2 chr1:100010437-100010915  48.25931 -0.80687947    0.22174651 -3.63874709
# 3 chr1:10002087-10003910   224.35927 -0.34892859    0.09743886 -3.58100041
# 4 chr1:100021298-100021629  38.13434 -1.03799571    0.25401013 -4.08643436
# 5 chr1:100023727-100023976  32.62049 -0.19100207    0.25625467 -0.74536036
# 6 chr1:100027983-100029702 290.98442 -0.18001582    0.09610434 -1.87312902
#   pvalue       padj
# 1 9.326080e-01 0.9510236543
# 2 2.739677e-04 0.0008947519
# 3 3.422811e-04 0.0010926173
# 4 4.380534e-05 0.0001707736
# 5 4.560539e-01 0.5497617125
# 6 6.105057e-02 0.1032752224

# %%
dat = dat_peak_screened_astarr
vec = dat$log2FoldChange
txt_title = "ASTARR"
txt_score = "Log2FC"

num_mu  = mean(vec)
num_sd  = sd(vec)
vec_sd1 = num_mu + c(num_sd, -num_sd)
vec_sd2 = num_mu + c(num_sd, -num_sd) * 2
vec_lim = c(-5, 5)

gpt = ggplot(dat, aes(x=log2FoldChange)) + 
    geom_histogram(bins = 50) + 
    labs(x=txt_score, y="Count", title=txt_title) +
    theme_cowplot()
gpt_score_ori = gpt

gpt = gpt + xlim(vec_lim)
gpt_score_lim = gpt

gpt = gpt +
    geom_vline(xintercept = num_mu,  linetype="solid",  color="red") +    
    geom_vline(xintercept = vec_sd1, linetype="dashed", color="blue")
gpt_score_sty = gpt

lst = list(
    gpt_score_ori,
    gpt_score_lim,
    gpt_score_sty
)
lst_gpt_score_astarr = lst

options(repr.plot.height=4, repr.plot.width=15)
plot_grid(plotlist = lst, nrow = 1)
# Out:
# Warning message:
# “Removed 43 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 43 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %%
options(repr.plot.height=4, repr.plot.width=5)
gpt_score_sty
# Out:
# Warning message:
# “Removed 43 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %% [markdown]
# ## WSTARR

# %%
dat = dat_peak_screened_wstarr
vec = dat$log2FoldChange
txt_title = "WSTARR"
txt_score = "Log2FC"

num_mu  = mean(vec)
num_sd  = sd(vec)
vec_sd1 = num_mu + c(num_sd, -num_sd)
vec_sd2 = num_mu + c(num_sd, -num_sd) * 2
vec_lim = c(-3, 3)

gpt = ggplot(dat, aes(x=log2FoldChange)) + 
    geom_histogram(bins = 50) + 
    labs(x=txt_score, y="Count", title=txt_title) +
    theme_cowplot()
gpt_score_ori = gpt

gpt = gpt + xlim(vec_lim)
gpt_score_lim = gpt

gpt = gpt +
    geom_vline(xintercept = num_mu,  linetype="solid",  color="red") +    
    geom_vline(xintercept = vec_sd1, linetype="dashed", color="blue")
gpt_score_sty = gpt

lst = list(
    gpt_score_ori,
    gpt_score_lim,
    gpt_score_sty
)
lst_gpt_score_wstarr = lst

options(repr.plot.height=4, repr.plot.width=15)
plot_grid(plotlist = lst, nrow = 1)
# Out:
# Warning message:
# “Removed 3 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 3 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %%
options(repr.plot.height=4, repr.plot.width=5)
gpt_score_sty
# Out:
# Warning message:
# “Removed 3 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %% [markdown]
# ## TMPRA

# %%
dat = dat_peak_screened_tmpra
vec = dat$log2FoldChange
txt_title = "TMPRA"
txt_score = "Log2FC"

num_mu  = mean(vec)
num_sd  = sd(vec)
vec_sd1 = num_mu + c(num_sd, -num_sd)
vec_sd2 = num_mu + c(num_sd, -num_sd) * 2
#vec_lim = range(vec)

gpt = ggplot(dat, aes(x=log2FoldChange)) + 
    geom_histogram(bins = 50) + 
    labs(x=txt_score, y="Count", title=txt_title) +
    theme_cowplot()
gpt_score_ori = gpt

#gpt = gpt + xlim(vec_lim)
gpt_score_lim = gpt

gpt = gpt +
    geom_vline(xintercept = num_mu,  linetype="solid",  color="red") +    
    geom_vline(xintercept = vec_sd1, linetype="dashed", color="blue")
gpt_score_sty = gpt

lst = list(
    gpt_score_ori,
    gpt_score_lim,
    gpt_score_sty
)
lst_gpt_score_tmpra = lst

options(repr.plot.height=4, repr.plot.width=15)
plot_grid(plotlist = lst, nrow = 1)
# Out:
# plot without title

# %%
options(repr.plot.height=4, repr.plot.width=5)
gpt_score_sty
# Out:
# plot without title

# %% [markdown]
# ## LMPRA

# %%
dat = dat_peak_screened_lmpra
vec = dat$Mean
txt_title = "LMPRA"
txt_score = "Z Score"

num_mu  = mean(vec)
num_sd  = sd(vec)
vec_sd1 = num_mu + c(num_sd, -num_sd)
vec_sd2 = num_mu + c(num_sd, -num_sd) * 2
vec_lim = range(vec)

gpt = ggplot(dat, aes(x=Mean)) + 
    geom_histogram(bins = 50) + 
    labs(x=txt_score, y="Count", title=txt_title) +
    theme_cowplot()
gpt_score_ori = gpt

#gpt = gpt + xlim(vec_lim)
gpt_score_lim = gpt

gpt = gpt +
    geom_vline(xintercept = num_mu,  linetype="solid",  color="red") +    
    geom_vline(xintercept = vec_sd1, linetype="dashed", color="blue")
gpt_score_sty = gpt

lst = list(
    gpt_score_ori,
    gpt_score_lim,
    gpt_score_sty
)
lst_gpt_score_lmpra = lst

options(repr.plot.height=4, repr.plot.width=15)
plot_grid(plotlist = lst, nrow = 1)
# Out:
# plot without title

# %%
options(repr.plot.height=4, repr.plot.width=5)
gpt_score_sty
# Out:
# plot without title

# %% [markdown]
# ## CRISPRi-HCRFF

# %%
dat = dat_peak_screened_crispri_hcrff
head(dat)
# Out:
#   Peak                    Mean_Tot    Mean_Pos   Mean_Neg   Count
# 1 chr11:33065336-33066228 -0.08308383 0.03675483 -0.2734393 138
# 2 chr11:33068519-33069100 -0.12006903 0.00000000 -0.1593220 159
# 3 chr11:33072412-33072630  0.10643558 0.35299267 -0.1982723  36
# 4 chr11:33103533-33104120  0.98158422 1.44209600  0.0000000   9
# 5 chr11:33114629-33115134  0.22095793 0.42649733  0.0000000  27
# 6 chr11:33125296-33126416 -0.05128921 0.04323581 -0.1542515 159
#   Note
# 1 CAPRIN1:138|CAT:138|LMO2:138
# 2 CAPRIN1:159|CAT:159|LMO2:159
# 3 CAPRIN1:36|CAT:36|LMO2:36
# 4 CAPRIN1:9|CAT:9|LMO2:9
# 5 CAPRIN1:27|CAT:27|LMO2:27
# 6 CAPRIN1:159|CAT:159|LMO2:159

# %%
dat = dat_peak_screened_crispri_hcrff
vec = dat$Mean_Tot
txt_title = "CRISPRi-HCRFF"
txt_score = "Z Score"

num_mu  = mean(vec)
num_sd  = sd(vec)
vec_sd1 = num_mu + c(num_sd, -num_sd)
vec_sd2 = num_mu + c(num_sd, -num_sd) * 2
vec_lim = c(-1, 1)

gpt = ggplot(dat, aes(x=Mean_Tot)) + 
    geom_histogram(bins = 50) + 
    labs(x=txt_score, y="Count", title=txt_title) +
    theme_cowplot()
gpt_score_ori = gpt

gpt = gpt + xlim(vec_lim)
gpt_score_lim = gpt

gpt = gpt +
    geom_vline(xintercept = num_mu,  linetype="solid",  color="red") +    
    geom_vline(xintercept = vec_sd1, linetype="dashed", color="blue")
gpt_score_sty = gpt

lst = list(
    gpt_score_ori,
    gpt_score_lim,
    gpt_score_sty
)
lst_gpt_score_crispri_hcrff = lst

options(repr.plot.height=4, repr.plot.width=15)
plot_grid(plotlist = lst, nrow = 1)
# Out:
# Warning message:
# “Removed 23 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# Warning message:
# “Removed 23 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# plot without title

# %% [markdown]
# ## CRISPRi-Growth

# %%
dat = dat_peak_screened_crispri_growth
head(dat)
# Out:
#   Peak                      Mean        Median     Max      Min       Count
# 1 chr10:100009096-100010466 -0.03786170  0.0303830 0.526902 -0.655965 10
# 2 chr10:100045961-100046653  0.10873570  0.1820295 0.646953 -0.497578 10
# 3 chr10:100065094-100065486 -0.00323730 -0.0931995 1.305380 -0.677550 10
# 4 chr10:100129051-100131059 -0.26576144 -0.2617330 0.253159 -0.767330  9
# 5 chr10:100185017-100187275 -0.01202196 -0.0613300 0.730481 -0.954435 25
# 6 chr10:100228452-100230090 -0.01822050  0.0722880 0.446912 -0.768059 10
#   Mean_Neg   Mean_Pos
# 1 -0.3840866 0.3083632
# 2 -0.2750008 0.3645600
# 3 -0.3639722 0.5378650
# 4 -0.4522120 0.1071397
# 5 -0.2790666 0.3278531
# 6 -0.3293750 0.1892158

# %%
dat = dat_peak_screened_crispri_growth
vec = dat$Mean
txt_title = "CRISPRi-Growth"
txt_score = "Z Score"

num_mu  = mean(vec)
num_sd  = sd(vec)
vec_sd1 = num_mu + c(num_sd, -num_sd)
vec_sd2 = num_mu + c(num_sd, -num_sd) * 2
vec_lim = c(-1.5, 1.5)

gpt = ggplot(dat, aes(x=Mean)) + 
    geom_histogram(bins = 50) + 
    labs(x=txt_score, y="Count", title=txt_title) +
    theme_cowplot()
gpt_score_ori = gpt

gpt = gpt + xlim(vec_lim)
gpt_score_lim = gpt

gpt = gpt +
    geom_vline(xintercept = num_mu,  linetype="solid",  color="red") +    
    geom_vline(xintercept = vec_sd1, linetype="dashed", color="blue")
gpt_score_sty = gpt

lst = list(
    gpt_score_ori,
    gpt_score_lim,
    gpt_score_sty
)
lst_gpt_score_crispri_growth = lst

options(repr.plot.height=4, repr.plot.width=15)
plot_grid(plotlist = lst, nrow = 1)
# Out:
# Warning message:
# “Removed 243 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 243 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %% [markdown]
# ## Combine distribution plot

# %%
lst_lst_gpt = list(
    lst_gpt_score_astarr,
    lst_gpt_score_wstarr,
    lst_gpt_score_tmpra,
    lst_gpt_score_lmpra,
    lst_gpt_score_crispri_hcrff,
    lst_gpt_score_crispri_growth
)

# %%
gpt = lst_gpt_score_astarr[[2]]
options(repr.plot.height=4, repr.plot.width=5)
gpt
# Out:
# Warning message:
# “Removed 43 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %%
lst = lst_lst_gpt
lst = lapply(lst, function(lst){
    gpt = lst[[1]]
    return(gpt)
})

options(repr.plot.height=8, repr.plot.width=15)
plot_grid(plotlist = lst, nrow=2)
# Out:
# plot without title

# %%
lst = lst_lst_gpt
lst = lapply(lst, function(lst){
    gpt = lst[[2]]
    return(gpt)
})

options(repr.plot.height=8, repr.plot.width=15)
plot_grid(plotlist = lst, nrow=2)
# Out:
# Warning message:
# “Removed 43 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 3 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 23 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# Warning message:
# “Removed 243 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %%
lst = lst_lst_gpt
lst = lapply(lst, function(lst){
    gpt = lst[[3]]
    return(gpt)
})

options(repr.plot.height=8, repr.plot.width=15)
plot_grid(plotlist = lst, nrow=2)
# Out:
# Warning message:
# “Removed 43 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 3 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 23 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# Warning message:
# “Removed 243 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %% [markdown]
# ## Scatter plot

# %%
dat = dat_peak_screened_crispri_growth
head(dat)
# Out:
#   Peak                      Mean        Median     Max      Min       Count
# 1 chr10:100009096-100010466 -0.03786170  0.0303830 0.526902 -0.655965 10
# 2 chr10:100045961-100046653  0.10873570  0.1820295 0.646953 -0.497578 10
# 3 chr10:100065094-100065486 -0.00323730 -0.0931995 1.305380 -0.677550 10
# 4 chr10:100129051-100131059 -0.26576144 -0.2617330 0.253159 -0.767330  9
# 5 chr10:100185017-100187275 -0.01202196 -0.0613300 0.730481 -0.954435 25
# 6 chr10:100228452-100230090 -0.01822050  0.0722880 0.446912 -0.768059 10
#   Mean_Neg   Mean_Pos
# 1 -0.3840866 0.3083632
# 2 -0.2750008 0.3645600
# 3 -0.3639722 0.5378650
# 4 -0.4522120 0.1071397
# 5 -0.2790666 0.3278531
# 6 -0.3293750 0.1892158

# %%
dat1 = dat_peak_screened_astarr
dat2 = dat_peak_screened_wstarr
dat3 = dat_peak_screened_tmpra
dat4 = dat_peak_screened_lmpra
dat5 = dat_peak_screened_crispri_hcrff
dat6 = dat_peak_screened_crispri_growth


dat1 = dat1 %>% 
    dplyr::mutate(ASTARR = log2FoldChange) %>%
    dplyr::select(Peak, ASTARR)

dat2 = dat2 %>% 
    dplyr::mutate(WSTARR = log2FoldChange) %>%
    dplyr::select(Peak, WSTARR)

dat3 = dat3 %>% 
    dplyr::mutate(TMPRA = log2FoldChange) %>%
    dplyr::select(Peak, TMPRA)

dat4 = dat4 %>%
    dplyr::mutate(LMPRA = Mean) %>%
    dplyr::select(Peak, LMPRA)

dat5 = dat5 %>%
    dplyr::mutate(CRISPRi_HCRFF = Mean_Tot) %>%
    dplyr::select(Peak, CRISPRi_HCRFF)

dat6 = dat6 %>%
    dplyr::mutate(CRISPRi_Growth = Mean) %>%
    dplyr::select(Peak, CRISPRi_Growth)

lst = list(dat1, dat2, dat3, dat4, dat5, dat6)
fun = function(df1, df2) {
    dat = dplyr::full_join(df1, df2, by="Peak")
    return(dat)
}

dat_peak_score_merge = Reduce(fun, lst)
head(dat)
# Out:
#   Peak                     ASTARR      WSTARR      TMPRA LMPRA CRISPRi_HCRFF
# 1 chr1:100006256-100006880 -0.01311792 -0.48849764 NA    NA    NA
# 2 chr1:100010437-100010915 -0.80687947 -0.30895395 NA    NA    NA
# 3 chr1:10002087-10003910   -0.34892859 -0.38624192 NA    NA    NA
# 4 chr1:100021298-100021629 -1.03799571 -0.59404974 NA    NA    NA
# 5 chr1:100023727-100023976 -0.19100207  0.04988694 NA    NA    NA
# 6 chr1:100027983-100029702 -0.18001582 -0.22927538 NA    NA    NA
#   CRISPRi_Growth
# 1          NA
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6 -0.05102367

# %% [markdown]
# https://r-graphics.org/recipe-scatter-splom

# %%
dat = dat_peak_score_merge 
dat = dat%>% dplyr::select(-Peak)

options(repr.plot.height=10, repr.plot.width=10)
pairs(dat, pch = 20)
# Out:
# plot without title

# %%
panel.cor <- function(x, y, digits = 2, prefix = "", cex.cor, ...) {
  usr <- par("usr")
  on.exit(par(usr))
  par(usr = c(0, 1, 0, 1))
  r <- abs(cor(x, y, use = "complete.obs"))
  txt <- format(c(r, 0.123456789), digits = digits)[1]
  txt <- paste(prefix, txt, sep = "")
  if (missing(cex.cor)) cex.cor <- 0.8/strwidth(txt)
  text(0.5, 0.5, txt, cex =  cex.cor * (1 + r) / 2)
}

# %%
panel.hist <- function(x, ...) {
  usr <- par("usr")
  on.exit(par(usr))
  par(usr = c(usr[1:2], 0, 1.5) )
  h <- hist(x, plot = FALSE)
  breaks <- h$breaks
  nB <- length(breaks)
  y <- h$counts
  y <- y/max(y)
  rect(breaks[-nB], 0, breaks[-1], y, col = "white", ...)
}

# %%
dat = dat_peak_score_merge 
dat = dat%>% dplyr::select(-Peak)

options(repr.plot.height=10, repr.plot.width=10)
pairs(
    dat,
    upper.panel = panel.cor,
    diag.panel  = panel.hist,
    lower.panel = panel.smooth,
    cex.labels=1.3
)
# Out:
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# Warning message in par(usr):
# “argument 1 does not name a graphical parameter”
# ...

# %%
dat1 = dat_peak_screened_astarr
dat2 = dat_peak_screened_wstarr

dat1 = dat1 %>% 
    dplyr::mutate(ASTARR = log2FoldChange) %>%
    dplyr::select(Peak, ASTARR)

dat2 = dat2 %>% 
    dplyr::mutate(WSTARR = log2FoldChange) %>%
    dplyr::select(Peak, WSTARR)

dat = dplyr::inner_join(dat1, dat2, by="Peak")
gpt = ggplot(dat, aes(x=ASTARR, y=WSTARR)) + geom_point(size=1) + theme_cowplot()

options(repr.plot.height=5, repr.plot.width=5)
print(gpt)
# Out:
# plot without title

# %%
dat1 = dat_peak_screened_astarr
dat2 = dat_peak_screened_tmpra

dat1 = dat1 %>% 
    dplyr::mutate(ASTARR = log2FoldChange) %>%
    dplyr::select(Peak, ASTARR)

dat2 = dat2 %>% 
    dplyr::mutate(TMPRA = log2FoldChange) %>%
    dplyr::select(Peak, TMPRA)

dat = dplyr::inner_join(dat1, dat2, by="Peak")
gpt = ggplot(dat, aes(x=ASTARR, y=TMPRA)) + geom_point(size=1) + theme_cowplot()

options(repr.plot.height=5, repr.plot.width=5)
print(gpt)
# Out:
# plot without title
