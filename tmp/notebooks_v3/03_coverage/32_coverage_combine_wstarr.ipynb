# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_combeffect
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# **Check data**

# %%
ASSAY = "A001_K562_WSTARRseq"
REGIONS=c("GATA1", "MYC", "FADS")

get_group  = function(fpath){return(str_extract(fpath, "Input|Output"))}
get_sample = function(fpath){return(str_extract(fpath, "Input.rep\\d|Input.mean|Output.rep\\d|Output.mean"))}
get_region = function(fpath){return(str_extract(fpath, "WGS|GATA1|MYC|FADS"))}

# %%
region = REGIONS[1]
fdiry  = file.path(FD_RES, "results", ASSAY, "coverage")
fname  = paste("", region, "bed.gz", sep="*")
fglob  = file.path(fdiry, fname)
fpaths = Sys.glob(fglob)

for (fpath in fpaths){
    fname  = basename(fpath)
    region = get_region(fpath) 
    group  = get_group(fpath)
    sam    = get_sample(fpath)
    print(fname)
    print(region)
    print(group)
    print(sam)
    cat("++++++++++++++++++++++\n")
}
# Out:
# [1] "A001_K562_WSTARRseq.Input.rep1.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep1"
# ++++++++++++++++++++++
# [1] "A001_K562_WSTARRseq.Input.rep2.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep2"
# ++++++++++++++++++++++
# [1] "A001_K562_WSTARRseq.Input.rep3.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep3"
# ++++++++++++++++++++++
# [1] "A001_K562_WSTARRseq.Input.rep4.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep4"
# ++++++++++++++++++++++
# [1] "A001_K562_WSTARRseq.Output.rep1.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Output"
# [1] "Output.rep1"
# ++++++++++++++++++++++
# [1] "A001_K562_WSTARRseq.Output.rep2.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Output"
# [1] "Output.rep2"
# ++++++++++++++++++++++
# [1] "A001_K562_WSTARRseq.Output.rep3.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Output"
# [1] "Output.rep3"
# ++++++++++++++++++++++

# %% [markdown]
# **RUN**

# %%
### import library size
fdiry  = file.path(FD_RES, "results", ASSAY, "coverage", "summary")
fname  = "library_size_summary.csv"
fpath  = file.path(fdiry, fname)
dat_lib = read_csv(fpath, show_col_types = FALSE)
dat_lib = dat_lib %>% dplyr::select(-FName)
dat_lib
# Out:
#    Type Region Group  Sample      Size
# 1  raw  FADS   Input  Input.rep1       1892
# 2  raw  GATA1  Input  Input.rep1      19540
# 3  raw  MYC    Input  Input.rep1      21892
# 4  raw  WGS    Input  Input.rep1   26908970
# 5  raw  FADS   Input  Input.rep2       6921
# 6  raw  GATA1  Input  Input.rep2      72119
# 7  raw  MYC    Input  Input.rep2      81027
# 8  raw  WGS    Input  Input.rep2   99899775
# 9  raw  FADS   Input  Input.rep3       7348
# 10 raw  GATA1  Input  Input.rep3      75963
# 11 raw  MYC    Input  Input.rep3      86311
# 12 raw  WGS    Input  Input.rep3  105623984
# 13 raw  FADS   Input  Input.rep4       7511
# 14 raw  GATA1  Input  Input.rep4      78600
# 15 raw  MYC    Input  Input.rep4      88615
# 16 raw  WGS    Input  Input.rep4  108635002
# 17 raw  FADS   Output Output.rep1     11794
# 18 raw  GATA1  Output Output.rep1    119231
# 19 raw  MYC    Output Output.rep1    126539
# 20 raw  WGS    Output Output.rep1 160349140
# 21 raw  FADS   Output Output.rep2     11531
# 22 raw  GATA1  Output Output.rep2    116787
# 23 raw  MYC    Output Output.rep2    124349
# 24 raw  WGS    Output Output.rep2 157326312
# 25 raw  FADS   Output Output.rep3     24483
# 26 raw  GATA1  Output Output.rep3    238763
# 27 raw  MYC    Output Output.rep3    259970
# 28 raw  WGS    Output Output.rep3 328185275

# %%
cnames = c("Chrom", "Start", "End", "Count")
ctypes = c("ciic")

for (region in REGIONS){
    ### show progress
    cat("\n+++++++++++++++++++\n")
    cat("Region:", region, "\n")
    flush.console()
    
    ### set file paths
    fdiry  = file.path(FD_RES, "results", ASSAY, "coverage")
    fname  = paste("", region, "bed.gz", sep="*")
    fglob  = file.path(fdiry, fname)
    fpaths = Sys.glob(fglob)
    
    ### import data and add info
    lst = lapply(fpaths, function(fpath){
        ### import data
        dat = read_tsv(fpath, col_names = cnames, col_types = ctypes)
        dat = dat %>% 
           dplyr::mutate(Count = replace(Count, Count == ".", 0)) %>%
           dplyr::mutate(Count = as.double(Count))

        ### add information
        #dat$Region = get_region(fpath)
        dat$Region = "WGS"
        dat$Group  = get_group(fpath)
        dat$Sample = get_sample(fpath)

        ### return result dataframe
        return(dat)
    })
    
    ### get raw counts
    dat_count = bind_rows(lst) %>% 
        dplyr::select(Chrom, Start, End, Count, Sample) %>% 
        tidyr::spread(Sample, Count)
    
    cat("\nGet raw counts\n")
    print(dim(dat_count))
    print(head(dat_count))
    flush.console()
    
    ### calculate counts per million
    dat_cpm = bind_rows(lst) %>% 
        dplyr::left_join(dat_lib, by=c("Region", "Group", "Sample")) %>%
        dplyr::mutate(CPM = Count * 1000000 / Size) %>% 
        dplyr::select(Chrom, Start, End, CPM, Sample) %>% 
        tidyr::spread(Sample, CPM)
    
    cat("\nGet CPM\n")
    print(dim(dat_cpm))
    print(head(dat_cpm))
    flush.console()
    
    ### summarize input and output to calculate fold changes
    dat   = dat_cpm %>% dplyr::select(Chrom, Start, End)
    x_inp = dat_cpm %>% dplyr::select(starts_with("Input"))  %>% apply(., 1, mean, na.omit=TRUE)
    x_out = dat_cpm %>% dplyr::select(starts_with("Output")) %>% apply(., 1, mean, na.omit=TRUE)
    x_xfc =      x_out      /      x_inp
    x_lfc = log2(x_out)     - log2(x_inp)
    x_pfc = log2(x_out + 1) - log2(x_inp + 1)
    
    dat_Log2fc = data.frame(cbind(dat, x_inp, x_out, x_xfc, x_lfc, x_pfc))
    colnames(dat_Log2fc) = c("Chrom", "Start", "End", "Input", "Output", "FC", "Log2FC", "pLog2FC")
    
    cat("\nGet Log2FC\n")
    print(dim(dat_Log2fc))
    print(head(dat_Log2fc))
    flush.console()
    
    ### store the results
    fdiry = file.path(FD_RES, "results", ASSAY, "coverage", "summary")
    fname = paste("track", "raw", "count",  region, "tsv", sep=".")
    fpath = file.path(fdiry, fname)
    write_tsv(dat_count, fpath)
    cat(fpath, "\n")
          
    fname = paste("track", "raw", "cpm",    region, "tsv", sep=".")
    fpath = file.path(fdiry, fname)
    write_tsv(dat_cpm, fpath)
    cat(fpath, "\n")
          
    fname = paste("track", "raw", "Log2FC", region, "tsv", sep=".")
    fpath = file.path(fdiry, fname)
    write_tsv(dat_Log2fc, fpath)
    cat(fpath, "\n")
    flush.console()
}
# Out:
# +++++++++++++++++++
# Region: GATA1
#
# Get raw counts
# [1] 2095150      10
# # A tibble: 6 × 10
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Outpu…⁵ Outpu…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chrX  47785501  4.78e7       0       1       5       8       6       4       8
# 2 chrX  47785502  4.78e7       0       1       5       8       6       4       8
# 3 chrX  47785503  4.78e7       0       1       5       8       6       4       8
# 4 chrX  47785504  4.78e7       0       1       5       8       6       4       8
# 5 chrX  47785505  4.78e7       0       1       5       8       6       4       8
# 6 chrX  47785506  4.78e7       0       1       5       8       6       4       8
# # … with abbreviated variable names ¹​Input.rep1, ²​Input.rep2, ³​Input.rep3,
# #   ⁴​Input.rep4, ⁵​Output.rep1, ⁶​Output.rep2, ⁷​Output.rep3
#
# Get CPM
# [1] 2095150      10
# # A tibble: 6 × 10
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Outpu…⁵ Outpu…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chrX  47785501  4.78e7       0  0.0100  0.0473  0.0736  0.0374  0.0254  0.0244
# 2 chrX  47785502  4.78e7       0  0.0100  0.0473  0.0736  0.0374  0.0254  0.0244
# 3 chrX  47785503  4.78e7       0  0.0100  0.0473  0.0736  0.0374  0.0254  0.0244
# 4 chrX  47785504  4.78e7       0  0.0100  0.0473  0.0736  0.0374  0.0254  0.0244
# 5 chrX  47785505  4.78e7       0  0.0100  0.0473  0.0736  0.0374  0.0254  0.0244
# 6 chrX  47785506  4.78e7       0  0.0100  0.0473  0.0736  0.0374  0.0254  0.0244
# # … with abbreviated variable names ¹​Input.rep1, ²​Input.rep2, ³​Input.rep3,
# #   ⁴​Input.rep4, ⁵​Output.rep1, ⁶​Output.rep2, ⁷​Output.rep3
#
# Get Log2FC
# [1] 2095150       8
#   Chrom    Start      End      Input     Output        FC     Log2FC
# 1  chrX 47785501 47785502 0.03274721 0.02907323 0.8878077 -0.1716809
# 2  chrX 47785502 47785503 0.03274721 0.02907323 0.8878077 -0.1716809
# 3  chrX 47785503 47785504 0.03274721 0.02907323 0.8878077 -0.1716809
# 4  chrX 47785504 47785505 0.03274721 0.02907323 0.8878077 -0.1716809
# 5  chrX 47785505 47785506 0.03274721 0.02907323 0.8878077 -0.1716809
# 6  chrX 47785506 47785507 0.03274721 0.02907323 0.8878077 -0.1716809
#       pLog2FC
# 1 -0.00514152
# 2 -0.00514152
# 3 -0.00514152
# 4 -0.00514152
# 5 -0.00514152
# 6 -0.00514152
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.count.GATA1.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.cpm.GATA1.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.Log2FC.GATA1.tsv
#
# +++++++++++++++++++
# Region: MYC
#
# Get raw counts
# [1] 2000650      10
# # A tibble: 6 × 10
#   Chrom     Start    End Input…¹ Input…² Input…³ Input…⁴ Outpu…⁵ Outpu…⁶ Outpu…⁷
#   <chr>     <int>  <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr8  126735901 1.27e8      10      16      20      23      26      23      52
# 2 chr8  126735902 1.27e8      10      16      20      23      25      23      52
# 3 chr8  126735903 1.27e8      10      16      20      23      25      23      52
# 4 chr8  126735904 1.27e8      10      16      19      23      25      23      52
# 5 chr8  126735905 1.27e8      10      16      19      23      25      23      52
# 6 chr8  126735906 1.27e8      10      16      19      23      25      23      52
# # … with abbreviated variable names ¹​Input.rep1, ²​Input.rep2, ³​Input.rep3,
# #   ⁴​Input.rep4, ⁵​Output.rep1, ⁶​Output.rep2, ⁷​Output.rep3
#
# Get CPM
# [1] 2000650      10
# # A tibble: 6 × 10
#   Chrom     Start    End Input…¹ Input…² Input…³ Input…⁴ Outpu…⁵ Outpu…⁶ Outpu…⁷
#   <chr>     <int>  <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr8  126735901 1.27e8   0.372   0.160   0.189   0.212   0.162   0.146   0.158
# 2 chr8  126735902 1.27e8   0.372   0.160   0.189   0.212   0.156   0.146   0.158
# 3 chr8  126735903 1.27e8   0.372   0.160   0.189   0.212   0.156   0.146   0.158
# 4 chr8  126735904 1.27e8   0.372   0.160   0.180   0.212   0.156   0.146   0.158
# 5 chr8  126735905 1.27e8   0.372   0.160   0.180   0.212   0.156   0.146   0.158
# 6 chr8  126735906 1.27e8   0.372   0.160   0.180   0.212   0.156   0.146   0.158
# # … with abbreviated variable names ¹​Input.rep1, ²​Input.rep2, ³​Input.rep3,
# #   ⁴​Input.rep4, ⁵​Output.rep1, ⁶​Output.rep2, ⁷​Output.rep3
#
# Get Log2FC
# [1] 2000650       8
#   Chrom     Start       End     Input    Output        FC     Log2FC
# 1  chr8 126735901 126735902 0.2332132 0.1555954 0.6671809 -0.5838501
# 2  chr8 126735902 126735903 0.2332132 0.1535166 0.6582672 -0.6032548
# 3  chr8 126735903 126735904 0.2332132 0.1535166 0.6582672 -0.6032548
# 4  chr8 126735904 126735905 0.2308463 0.1535166 0.6650165 -0.5885380
# 5  chr8 126735905 126735906 0.2308463 0.1535166 0.6650165 -0.5885380
# 6  chr8 126735906 126735907 0.2308463 0.1535166 0.6650165 -0.5885380
#       pLog2FC
# 1 -0.09378588
# 2 -0.09638348
# 3 -0.09638348
# 4 -0.09361188
# 5 -0.09361188
# 6 -0.09361188
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.count.MYC.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.cpm.MYC.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.Log2FC.MYC.tsv
#
# +++++++++++++++++++
# Region: FADS
#
# Get raw counts
# [1] 111020     10
# # A tibble: 6 × 10
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Outpu…⁵ Outpu…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr11 61554801  6.16e7      10      33      25      45      47      43     117
# 2 chr11 61554802  6.16e7      10      33      25      45      46      42     117
# 3 chr11 61554803  6.16e7      10      33      25      45      48      42     119
# 4 chr11 61554804  6.16e7      10      33      25      46      48      42     120
# 5 chr11 61554805  6.16e7      10      33      25      46      48      42     120
# 6 chr11 61554806  6.16e7      10      33      25      46      48      42     120
# # … with abbreviated variable names ¹​Input.rep1, ²​Input.rep2, ³​Input.rep3,
# #   ⁴​Input.rep4, ⁵​Output.rep1, ⁶​Output.rep2, ⁷​Output.rep3
#
# Get CPM
# [1] 111020     10
# # A tibble: 6 × 10
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Outpu…⁵ Outpu…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr11 61554801  6.16e7   0.372   0.330   0.237   0.414   0.293   0.273   0.357
# 2 chr11 61554802  6.16e7   0.372   0.330   0.237   0.414   0.287   0.267   0.357
# 3 chr11 61554803  6.16e7   0.372   0.330   0.237   0.414   0.299   0.267   0.363
# 4 chr11 61554804  6.16e7   0.372   0.330   0.237   0.423   0.299   0.267   0.366
# 5 chr11 61554805  6.16e7   0.372   0.330   0.237   0.423   0.299   0.267   0.366
# 6 chr11 61554806  6.16e7   0.372   0.330   0.237   0.423   0.299   0.267   0.366
# # … with abbreviated variable names ¹​Input.rep1, ²​Input.rep2, ³​Input.rep3,
# #   ⁴​Input.rep4, ⁵​Output.rep1, ⁶​Output.rep2, ⁷​Output.rep3
#
# Get Log2FC
# [1] 111020      8
#   Chrom    Start      End     Input    Output        FC     Log2FC     pLog2FC
# 1 chr11 61554801 61554802 0.3382185 0.3076445 0.9096028 -0.1366914 -0.03334332
# 2 chr11 61554802 61554803 0.3382185 0.3034470 0.8971921 -0.1565112 -0.03798181
# 3 chr11 61554803 61554804 0.3382185 0.3096360 0.9154908 -0.1273827 -0.03114789
# 4 chr11 61554804 61554805 0.3405198 0.3106517 0.9122866 -0.1324410 -0.03250826
# 5 chr11 61554805 61554806 0.3405198 0.3106517 0.9122866 -0.1324410 -0.03250826
# 6 chr11 61554806 61554807 0.3405198 0.3106517 0.9122866 -0.1324410 -0.03250826
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.count.FADS.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.cpm.FADS.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/track.raw.Log2FC.FADS.tsv
