# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# SING DIRECTORY:     /data/reddylab/Kuei/singularity
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
ASSAY=KS91_K562_ASTARRseq
FDIRY=${FD_RES}/results/${ASSAY}/fragment_count
ls ${FDIRY}
# Out:
# KS91_K562_ASTARRseq.Input.rep1.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.WGS.unstranded.bed.gz

# %%
ASSAY=KS91_K562_ASTARRseq
FDIRY=${FD_RES}/results/${ASSAY}/fragment_count
FP_INPS=($(ls ${FDIRY}/*bed.gz))

echo Total: ${#FP_INPS[@]}
for FP_INP in ${FP_INPS[@]}; do
    echo $(basename ${FP_INP})
done
# Out:
# Total: 40
# KS91_K562_ASTARRseq.Input.rep1.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.WGS.unstranded.bed.gz

# %%
FPATH=${FP_INPS[30]}
FNAME=$(basename ${FPATH})
echo ${FPATH}
echo ++++++++++++++++++++++++
echo ${FNAME}
echo ++++++++++++++++++++++++
zcat ${FPATH} | head -n 10
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep2.MYC.unstranded.bed.gz
# ++++++++++++++++++++++++
# KS91_K562_ASTARRseq.Output.rep2.MYC.unstranded.bed.gz
# ++++++++++++++++++++++++
# chr8	126735791	126736129	chr8_126735791_126736129	1	.
# chr8	126735987	126736392	chr8_126735987_126736392	1	.
# chr8	126736025	126736188	chr8_126736025_126736188	1	.
# chr8	126736085	126736346	chr8_126736085_126736346	1	.
# chr8	126736086	126736346	chr8_126736086_126736346	1	.
# chr8	126736167	126736548	chr8_126736167_126736548	1	.
# chr8	126736212	126736393	chr8_126736212_126736393	1	.
# chr8	126736250	126736533	chr8_126736250_126736533	1	.
# chr8	126736388	126736529	chr8_126736388_126736529	3	.
# chr8	126736389	126736529	chr8_126736389_126736529	2	.

# %%
zcat ${FPATH} | head -n 10 | awk -v OFS=, -v FNAME=${FNAME} '{sum += $5} END {print FNAME, sum}'
# Out:
# KS91_K562_ASTARRseq.Output.rep2.MYC.unstranded.bed.gz,13

# %% [markdown]
# **RUN**

# %%
sbatch -p ${NODE} \
    --exclude=dl-01 \
    --cpus-per-task 8 \
    --mem 20G \
    --output ${FD_LOG}/coverage_library_size_ASTARR.%a.txt \
    --array 0 \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config/config_duke.sh

### set input and output file paths
ASSAY=KS91_K562_ASTARRseq

FD_INP=${FD_RES}/results/${ASSAY}/fragment_count
FP_INPS=($(ls ${FD_INP}/*bed.gz))

FD_OUT=${FD_RES}/results/${ASSAY}/coverage/summary
FN_OUT=library_size_output.csv
FP_OUT=${FD_OUT}/${FN_OUT}

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### init
mkdir -p   ${FD_OUT}
echo  -n > ${FP_OUT}

### get library size
for FP_INP in ${FP_INPS[@]}; do
    
    ### show I/O file
    echo ++++++++++++++++++++++++++++++++++++
    echo "Input file path: ${FP_INP}"
    echo "Show the first few lines"
    zcat ${FP_INP} | head -n 3
    echo
    
    ### count the total counts and append the results to the output file
    FN_INP=$(basename ${FP_INP})
    zcat ${FP_INP} |\
        awk -v OFS=, -v FNAME=${FN_INP} '{sum += $5} END {print FNAME, sum}' \
        >> ${FP_OUT}
done

### show I/O file
echo "Output file path: ${FP_OUT}"
echo "Show the lines"
cat ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 29423782

# %% [markdown]
# **CHECK**

# %%
cat ${FD_LOG}/coverage_library_size_ASTARR.0.txt
# Out:
# Hostname:           x1-01-4.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         12-13-22+13:06:51
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep1.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554341	61554829	chr11_61554341_61554829	1	.
# chr11	61554409	61554803	chr11_61554409_61554803	1	.
# chr11	61554409	61555000	chr11_61554409_61555000	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785383	47785713	chrX_47785383_47785713	1	.
# chrX	47785456	47785689	chrX_47785456_47785689	1	.
# chrX	47785485	47785703	chrX_47785485_47785703	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep1.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735763	126736137	chr8_126735763_126736137	1	.
# chr8	126735775	126736127	chr8_126735775_126736127	1	.
# chr8	126735780	126735916	chr8_126735780_126735916	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep2.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554383	61554809	chr11_61554383_61554809	1	.
# chr11	61554409	61554803	chr11_61554409_61554803	1	.
# chr11	61554426	61554845	chr11_61554426_61554845	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785379	47785643	chrX_47785379_47785643	1	.
# chrX	47785452	47785694	chrX_47785452_47785694	1	.
# chrX	47785456	47785689	chrX_47785456_47785689	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep2.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735746	126736029	chr8_126735746_126736029	1	.
# chr8	126735765	126735963	chr8_126735765_126735963	1	.
# chr8	126735766	126736003	chr8_126735766_126736003	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep2.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10001	10233	chr1_10001_10233	1	.
# chr1	10001	10351	chr1_10001_10351	1	.
# chr1	10002	10119	chr1_10002_10119	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep3.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554331	61554937	chr11_61554331_61554937	1	.
# chr11	61554341	61554829	chr11_61554341_61554829	1	.
# chr11	61554385	61554806	chr11_61554385_61554806	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785391	47785661	chrX_47785391_47785661	1	.
# chrX	47785439	47785731	chrX_47785439_47785731	1	.
# chrX	47785458	47785727	chrX_47785458_47785727	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep3.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735330	126736013	chr8_126735330_126736013	1	.
# chr8	126735642	126736001	chr8_126735642_126736001	1	.
# chr8	126735716	126735994	chr8_126735716_126735994	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep3.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10001	10203	chr1_10001_10203	1	.
# chr1	10002	10113	chr1_10002_10113	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep4.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554331	61554937	chr11_61554331_61554937	1	.
# chr11	61554426	61554845	chr11_61554426_61554845	1	.
# chr11	61554448	61554867	chr11_61554448_61554867	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785391	47785661	chrX_47785391_47785661	1	.
# chrX	47785424	47785718	chrX_47785424_47785718	1	.
# chrX	47785456	47785689	chrX_47785456_47785689	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep4.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735665	126735964	chr8_126735665_126735964	1	.
# chr8	126735751	126736001	chr8_126735751_126736001	1	.
# chr8	126735763	126736137	chr8_126735763_126736137	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep4.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10001	10125	chr1_10001_10125	1	.
# chr1	10001	10326	chr1_10001_10326	1	.
# chr1	10002	10119	chr1_10002_10119	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep5.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554198	61554809	chr11_61554198_61554809	1	.
# chr11	61554466	61554803	chr11_61554466_61554803	1	.
# chr11	61554476	61554882	chr11_61554476_61554882	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep5.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785439	47785731	chrX_47785439_47785731	1	.
# chrX	47785452	47785694	chrX_47785452_47785694	1	.
# chrX	47785456	47785689	chrX_47785456_47785689	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep5.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735586	126735955	chr8_126735586_126735955	1	.
# chr8	126735665	126735964	chr8_126735665_126735964	1	.
# chr8	126735726	126735917	chr8_126735726_126735917	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep5.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10001	10119	chr1_10001_10119	1	.
# chr1	10001	10131	chr1_10001_10131	1	.
# chr1	10001	10215	chr1_10001_10215	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep6.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554407	61554818	chr11_61554407_61554818	1	.
# chr11	61554466	61554946	chr11_61554466_61554946	1	.
# chr11	61554515	61554845	chr11_61554515_61554845	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep6.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785452	47785694	chrX_47785452_47785694	1	.
# chrX	47785466	47785703	chrX_47785466_47785703	1	.
# chrX	47785527	47785694	chrX_47785527_47785694	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep6.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735555	126735904	chr8_126735555_126735904	1	.
# chr8	126735665	126735964	chr8_126735665_126735964	1	.
# chr8	126735695	126736003	chr8_126735695_126736003	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep6.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10001	10119	chr1_10001_10119	1	.
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10119	chr1_10002_10119	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep1.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554643	61554903	chr11_61554643_61554903	1	.
# chr11	61554644	61554903	chr11_61554644_61554903	1	.
# chr11	61554645	61554902	chr11_61554645_61554902	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep1.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785527	47785632	chrX_47785527_47785632	1	.
# chrX	47785527	47785634	chrX_47785527_47785634	1	.
# chrX	47785733	47786034	chrX_47785733_47786034	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep1.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126736089	126736257	chr8_126736089_126736257	1	.
# chr8	126736089	126736258	chr8_126736089_126736258	1	.
# chr8	126736089	126736259	chr8_126736089_126736259	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep1.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10057	10233	chr1_10057_10233	2	.
# chr1	10188	10442	chr1_10188_10442	1	.
# chr1	10285	10349	chr1_10285_10349	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep2.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554494	61554847	chr11_61554494_61554847	1	.
# chr11	61554512	61555472	chr11_61554512_61555472	1	.
# chr11	61554549	61554936	chr11_61554549_61554936	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep2.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785334	47785689	chrX_47785334_47785689	1	.
# chrX	47785600	47785796	chrX_47785600_47785796	1	.
# chrX	47785600	47785797	chrX_47785600_47785797	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep2.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735791	126736129	chr8_126735791_126736129	1	.
# chr8	126735987	126736392	chr8_126735987_126736392	1	.
# chr8	126736025	126736188	chr8_126736025_126736188	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep2.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10051	10233	chr1_10051_10233	1	.
# chr1	10056	10233	chr1_10056_10233	1	.
# chr1	10057	10233	chr1_10057_10233	5	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep3.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554407	61554818	chr11_61554407_61554818	1	.
# chr11	61554494	61554847	chr11_61554494_61554847	1	.
# chr11	61554651	61554845	chr11_61554651_61554845	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep3.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785334	47785689	chrX_47785334_47785689	1	.
# chrX	47785335	47785689	chrX_47785335_47785689	1	.
# chrX	47785733	47786020	chrX_47785733_47786020	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep3.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735949	126736321	chr8_126735949_126736321	1	.
# chr8	126735950	126736321	chr8_126735950_126736321	1	.
# chr8	126735987	126736392	chr8_126735987_126736392	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep3.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10057	10233	chr1_10057_10233	2	.
# chr1	10087	10412	chr1_10087_10412	1	.
# chr1	10342	10452	chr1_10342_10452	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep4.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554349	61554801	chr11_61554349_61554801	1	.
# chr11	61554351	61554801	chr11_61554351_61554801	1	.
# chr11	61554409	61555000	chr11_61554409_61555000	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep4.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785456	47785770	chrX_47785456_47785770	1	.
# chrX	47785733	47786021	chrX_47785733_47786021	1	.
# chrX	47786243	47786455	chrX_47786243_47786455	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep4.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126736025	126736220	chr8_126736025_126736220	1	.
# chr8	126736089	126736259	chr8_126736089_126736259	1	.
# chr8	126736091	126736273	chr8_126736091_126736273	2	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep4.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10033	10130	chr1_10033_10130	1	.
# chr1	10057	10233	chr1_10057_10233	3	.
# chr1	10104	10345	chr1_10104_10345	1	.
#
# Output file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/library_size_output.csv
# Show the lines
# KS91_K562_ASTARRseq.Input.rep1.FADS.unstranded.bed.gz,25269
# KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz,369389
# KS91_K562_ASTARRseq.Input.rep1.MYC.unstranded.bed.gz,255645
# KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz,348695063
# KS91_K562_ASTARRseq.Input.rep2.FADS.unstranded.bed.gz,32374
# KS91_K562_ASTARRseq.Input.rep2.GATA1.unstranded.bed.gz,475159
# KS91_K562_ASTARRseq.Input.rep2.MYC.unstranded.bed.gz,331480
# KS91_K562_ASTARRseq.Input.rep2.WGS.unstranded.bed.gz,451369741
# KS91_K562_ASTARRseq.Input.rep3.FADS.unstranded.bed.gz,34910
# KS91_K562_ASTARRseq.Input.rep3.GATA1.unstranded.bed.gz,510810
# KS91_K562_ASTARRseq.Input.rep3.MYC.unstranded.bed.gz,359298
# KS91_K562_ASTARRseq.Input.rep3.WGS.unstranded.bed.gz,487579055
# KS91_K562_ASTARRseq.Input.rep4.FADS.unstranded.bed.gz,32896
# KS91_K562_ASTARRseq.Input.rep4.GATA1.unstranded.bed.gz,478434
# KS91_K562_ASTARRseq.Input.rep4.MYC.unstranded.bed.gz,336062
# KS91_K562_ASTARRseq.Input.rep4.WGS.unstranded.bed.gz,456246254
# KS91_K562_ASTARRseq.Input.rep5.FADS.unstranded.bed.gz,31666
# KS91_K562_ASTARRseq.Input.rep5.GATA1.unstranded.bed.gz,467368
# KS91_K562_ASTARRseq.Input.rep5.MYC.unstranded.bed.gz,326501
# KS91_K562_ASTARRseq.Input.rep5.WGS.unstranded.bed.gz,444268950
# KS91_K562_ASTARRseq.Input.rep6.FADS.unstranded.bed.gz,28645
# KS91_K562_ASTARRseq.Input.rep6.GATA1.unstranded.bed.gz,420979
# KS91_K562_ASTARRseq.Input.rep6.MYC.unstranded.bed.gz,291162
# KS91_K562_ASTARRseq.Input.rep6.WGS.unstranded.bed.gz,397333562
# KS91_K562_ASTARRseq.Output.rep1.FADS.unstranded.bed.gz,2454
# KS91_K562_ASTARRseq.Output.rep1.GATA1.unstranded.bed.gz,50008
# KS91_K562_ASTARRseq.Output.rep1.MYC.unstranded.bed.gz,35777
# KS91_K562_ASTARRseq.Output.rep1.WGS.unstranded.bed.gz,44103844
# KS91_K562_ASTARRseq.Output.rep2.FADS.unstranded.bed.gz,4441
# KS91_K562_ASTARRseq.Output.rep2.GATA1.unstranded.bed.gz,84148
# KS91_K562_ASTARRseq.Output.rep2.MYC.unstranded.bed.gz,66613
# KS91_K562_ASTARRseq.Output.rep2.WGS.unstranded.bed.gz,97471282
# KS91_K562_ASTARRseq.Output.rep3.FADS.unstranded.bed.gz,4659
# KS91_K562_ASTARRseq.Output.rep3.GATA1.unstranded.bed.gz,89369
# KS91_K562_ASTARRseq.Output.rep3.MYC.unstranded.bed.gz,69278
# KS91_K562_ASTARRseq.Output.rep3.WGS.unstranded.bed.gz,84103298
# KS91_K562_ASTARRseq.Output.rep4.FADS.unstranded.bed.gz,8720
# KS91_K562_ASTARRseq.Output.rep4.GATA1.unstranded.bed.gz,165516
# KS91_K562_ASTARRseq.Output.rep4.MYC.unstranded.bed.gz,126056
# KS91_K562_ASTARRseq.Output.rep4.WGS.unstranded.bed.gz,183115379
#
#
# Done!
# Run Time: 14 minutes and 56 seconds
