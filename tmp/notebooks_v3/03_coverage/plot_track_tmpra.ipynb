# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_combeffect
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
ASSAY  = "Tewhey_K562_TileMPRA"
FOLDER = "coverage_astarrseq_peak_macs_input"

### set file path
fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
fname = "peak_regions.tsv"
fpath = file.path(fdiry, fname)

### import data
dat_region = read_tsv(fpath, show_col_types = FALSE)
peaks = dat_region$Peak

print(dim(dat_region))
head(dat_region)
# Out:
# [1] 417   5
#   Chrom Start     End       Peak                     Region
# 1 chr8  126778902 126779728 chr8_126778902_126779728 MYC
# 2 chr8  126782925 126783318 chr8_126782925_126783318 MYC
# 3 chr8  126804776 126805825 chr8_126804776_126805825 MYC
# 4 chr8  126817018 126817490 chr8_126817018_126817490 MYC
# 5 chr8  126820465 126821393 chr8_126820465_126821393 MYC
# 6 chr8  126824093 126824987 chr8_126824093_126824987 MYC

# %%
ASSAY  = "Tewhey_K562_TileMPRA"
FOLDER = "coverage"
fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
print(dir(fdiry))
# Out:
#  [1] "library_size_output.csv"
#  [2] "library_size_summary.csv"
#  [3] "Tewhey_K562_TileMPRA.track.raw.FC.bw"
#  [4] "Tewhey_K562_TileMPRA.track.raw.Input.bw"
#  [5] "Tewhey_K562_TileMPRA.track.raw.Log2FC.bw"
#  [6] "Tewhey_K562_TileMPRA.track.raw.Output.bw"
#  [7] "Tewhey_K562_TileMPRA.track.raw.pLog2FC.bw"
#  [8] "track.norm.count.FADS.tsv"
#  [9] "track.norm.count.GATA1.tsv"
# [10] "track.norm.count.MYC.tsv"
# [11] "track.norm.cpm.FADS.tsv"
# [12] "track.norm.cpm.GATA1.tsv"
# [13] "track.norm.cpm.MYC.tsv"
# [14] "track.norm.Log2FC.FADS.tsv"
# [15] "track.norm.Log2FC.GATA1.tsv"
# [16] "track.norm.Log2FC.MYC.tsv"
# [17] "track.raw.count.FADS.tsv"
# [18] "track.raw.count.GATA1.tsv"
# [19] "track.raw.count.MYC.tsv"
# [20] "track.raw.cpm.FADS.tsv"
# [21] "track.raw.cpm.GATA1.tsv"
# [22] "track.raw.cpm.MYC.tsv"
# [23] "track.raw.FC.bw"
# [24] "track.raw.Input.bw"
# [25] "track.raw.Log2FC.bw"
# [26] "track.raw.Log2FC.FADS.tsv"
# [27] "track.raw.Log2FC.GATA1.tsv"
# [28] "track.raw.Log2FC.MYC.tsv"
# [29] "track.raw.Output.bw"
# [30] "track.raw.pLog2FC.bw"

# %%
ASSAY  = "Tewhey_K562_TileMPRA"
FOLDER = "coverage"

### set file path
fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
fname = "track.raw.Log2FC.GATA1.tsv"
fpath = file.path(fdiry, fname)

### import data
dat = read_tsv(fpath, show_col_types = FALSE)

dat_track_raw = dat
print(dim(dat))
head(dat)
# Out:
# [1] 2095150       8
#   Chrom Start    End      Input    Output   FC        Log2FC     pLog2FC
# 1 chrX  47785501 47785502 40.42376 22.23699 0.5500968 -0.8622425 -0.8340358
# 2 chrX  47785502 47785503 40.42376 22.23699 0.5500968 -0.8622425 -0.8340358
# 3 chrX  47785503 47785504 40.42376 22.23699 0.5500968 -0.8622425 -0.8340358
# 4 chrX  47785504 47785505 40.42376 22.23699 0.5500968 -0.8622425 -0.8340358
# 5 chrX  47785505 47785506 40.42376 22.23699 0.5500968 -0.8622425 -0.8340358
# 6 chrX  47785506 47785507 40.42376 22.23699 0.5500968 -0.8622425 -0.8340358

# %%
dat = dat_track_raw
dat = dat %>% dplyr::filter(Chrom == "chrX", Start >= 48780000, End <= 48810000)
gpt = ggplot(dat, aes(x=Start, y=Log2FC)) + geom_line(linewidth=1) + theme_cowplot() + geom_hline(yintercept = 0)

options(repr.plot.height=5, repr.plot.width=30)
print(gpt)
# Out:
# plot without title

# %%
ASSAY  = "Tewhey_K562_TileMPRA"
FOLDER = "coverage"

### set file path
fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
fname = "track.norm.Log2FC.GATA1.tsv"
fpath = file.path(fdiry, fname)

### import data
dat = read_tsv(fpath, show_col_types = FALSE)

dat_track_norm = dat
print(dim(dat))
head(dat)
# Out:
# [1] 2095150       8
#   Chrom Start    End      Input    Output   FC       Log2FC    pLog2FC
# 1 chrX  47785501 47785502 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 2 chrX  47785502 47785503 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 3 chrX  47785503 47785504 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 4 chrX  47785504 47785505 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 5 chrX  47785505 47785506 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 6 chrX  47785506 47785507 1020.556 1858.489 1.821056 0.8647756 0.8641387

# %%
dat = dat_track_norm
dat = dat %>% dplyr::filter(Chrom == "chrX", Start >= 48780000, End <= 48810000)
gpt = ggplot(dat, aes(x=Start, y=pLog2FC)) + geom_line(linewidth=1) + theme_cowplot() + geom_hline(yintercept = 0)

options(repr.plot.height=5, repr.plot.width=30)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_track_norm
dat = dat %>% dplyr::filter(Chrom == "chrX", Start >= 48780000, End <= 48810000)
gpt = ggplot(dat, aes(x=Start, y=Log2FC)) + geom_line(linewidth=1) + theme_cowplot() + geom_hline(yintercept = 0)

options(repr.plot.height=5, repr.plot.width=30)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_track_norm
dat = dat %>% dplyr::filter(Chrom == "chrX", Start >= 48780000, End <= 48810000)
gpt = ggplot(dat, aes(x=Start, y=pLog2FC)) + geom_line(linewidth=1) + theme_cowplot() + geom_hline(yintercept = 0)

options(repr.plot.height=5, repr.plot.width=30)
print(gpt)
# Out:
# plot without title
