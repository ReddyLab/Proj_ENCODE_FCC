# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_combeffect
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# ## Import data (track)

# %%
ASSAY  = "KS91_K562_ASTARRseq"
FOLDER = "coverage"

### set file path
fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
fname = "track.raw.Log2FC.GATA1.tsv"
fpath = file.path(fdiry, fname)

### import data
dat = read_tsv(fpath, show_col_types = FALSE)

dat_track_astarr = dat
print(dim(dat))
head(dat)
# Out:
# [1] 2095150       8
#   Chrom Start    End      Input       Output      FC       Log2FC
# 1 chrX  47785501 47785502 0.008420745 0.009875188 1.172721 0.2298602
# 2 chrX  47785502 47785503 0.008420745 0.009875188 1.172721 0.2298602
# 3 chrX  47785503 47785504 0.008420745 0.009875188 1.172721 0.2298602
# 4 chrX  47785504 47785505 0.008420745 0.009875188 1.172721 0.2298602
# 5 chrX  47785505 47785506 0.008420745 0.009875188 1.172721 0.2298602
# 6 chrX  47785506 47785507 0.008420745 0.009875188 1.172721 0.2298602
#   pLog2FC
# 1 0.002079296
# 2 0.002079296
# 3 0.002079296
# 4 0.002079296
# 5 0.002079296
# 6 0.002079296

# %%
ASSAY  = "A001_K562_WSTARRseq"
FOLDER = "coverage"

### set file path
fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
fname = "track.raw.Log2FC.GATA1.tsv"
fpath = file.path(fdiry, fname)

### import data
dat = read_tsv(fpath, show_col_types = FALSE)

dat_track_wstarr = dat
print(dim(dat))
head(dat)
# Out:
# [1] 2095150       8
#   Chrom Start    End      Input      Output     FC        Log2FC
# 1 chrX  47785501 47785502 0.03274721 0.02907323 0.8878077 -0.1716809
# 2 chrX  47785502 47785503 0.03274721 0.02907323 0.8878077 -0.1716809
# 3 chrX  47785503 47785504 0.03274721 0.02907323 0.8878077 -0.1716809
# 4 chrX  47785504 47785505 0.03274721 0.02907323 0.8878077 -0.1716809
# 5 chrX  47785505 47785506 0.03274721 0.02907323 0.8878077 -0.1716809
# 6 chrX  47785506 47785507 0.03274721 0.02907323 0.8878077 -0.1716809
#   pLog2FC
# 1 -0.00514152
# 2 -0.00514152
# 3 -0.00514152
# 4 -0.00514152
# 5 -0.00514152
# 6 -0.00514152

# %%
ASSAY  = "Tewhey_K562_TileMPRA"
FOLDER = "coverage"

### set file path
fdiry = file.path(FD_RES, "results", ASSAY, FOLDER, "summary")
fname = "track.norm.Log2FC.GATA1.tsv"
fpath = file.path(fdiry, fname)

### import data
dat = read_tsv(fpath, show_col_types = FALSE)

dat_track_tmpra = dat
print(dim(dat))
head(dat)
# Out:
# [1] 2095150       8
#   Chrom Start    End      Input    Output   FC       Log2FC    pLog2FC
# 1 chrX  47785501 47785502 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 2 chrX  47785502 47785503 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 3 chrX  47785503 47785504 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 4 chrX  47785504 47785505 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 5 chrX  47785505 47785506 1020.556 1858.489 1.821056 0.8647756 0.8641387
# 6 chrX  47785506 47785507 1020.556 1858.489 1.821056 0.8647756 0.8641387

# %% [markdown]
# ## Import data (annotation)

# %%
### set file path
fdiry = file.path(FD_RES, "region", "annotation_remap2022")
fname = "remap2022_K562_nr_macs2_hg38_v1_0.GATA1.tsv"
fpath = file.path(fdiry, fname)

### import data
dat = read_tsv(fpath, show_col_types = FALSE)

dat_annot_gata1 = dat
print(dim(dat))
head(dat)
# Out:
# [1] 104505     10
#   Chrom Start  End    TF    Biotype                                 Score
# 1 chr1  861820 861970 GATA1 K-562,CD34                              4
# 2 chr1  911271 911453 GATA1 K-562,HUDEP-2,erythroblast,CD34         7
# 3 chr1  916603 916888 GATA1 K-562,erythroid-progenitor,erythroblast 4
# 4 chr1  918759 918943 GATA1 K-562                                   1
# 5 chr1  923546 923711 GATA1 K-562                                   1
# 6 chr1  936612 936808 GATA1 K-562                                   1
#   Strand thickStart_ReMap thickStop_ReMap Reserved
# 1 .      861892           861893          2522828
# 2 .      911374           911375          2522828
# 3 .      916711           916712          2522828
# 4 .      918887           918888          2522828
# 5 .      923600           923601          2522828
# 6 .      936650           936651          2522828

# %%
### set file path
fdiry = file.path(FD_RES, "region", "KS91_K562_ASTARRseq_peak_macs")
fname = "KS91_K562_hg38_ASTARRseq_Input.peaks.MYC.FADS.GATA1.tsv"
fpath = file.path(fdiry, fname)

### import data
dat_region = read_tsv(fpath, show_col_types = FALSE)
peaks = dat_region$Peak

print(dim(dat_region))
head(dat_region)
# Out:
# [1] 417   5
#   Chrom Start     End       Peak                     Region
# 1 chr8  126778902 126779728 chr8_126778902_126779728 MYC
# 2 chr8  126782925 126783318 chr8_126782925_126783318 MYC
# 3 chr8  126804776 126805825 chr8_126804776_126805825 MYC
# 4 chr8  126817018 126817490 chr8_126817018_126817490 MYC
# 5 chr8  126820465 126821393 chr8_126820465_126821393 MYC
# 6 chr8  126824093 126824987 chr8_126824093_126824987 MYC

# %% [markdown]
# ## Plot

# %%
### chrX:48780000-48810000
CHROM = "chrX"
START = 48780000
END   = 48810000

# %%
dat_ant = dat_annot_gata1 %>% dplyr::filter(Chrom == CHROM, Start >= START, End <= END)
print(dim(dat_ant))
head(dat_ant)
# Out:
# [1] 10 10
#   Chrom Start    End      TF
# 1 chrX  48782857 48783162 GATA1
# 2 chrX  48785826 48786141 GATA1
# 3 chrX  48787004 48787171 GATA1
# 4 chrX  48787850 48788100 GATA1
# 5 chrX  48789602 48789873 GATA1
# 6 chrX  48794371 48794807 GATA1
#   Biotype                                                        Score Strand
# 1 HUDEP-2,erythroid-progenitor,CD34,erythroid,K-562,erythroblast 18    .
# 2 HUDEP-2,erythroid-progenitor,CD34,erythroid,K-562,erythroblast 18    .
# 3 K-562                                                           1    .
# 4 K-562,erythroid-progenitor,erythroid,CD34                       9    .
# 5 erythroid,K-562,erythroblast,CD34                               4    .
# 6 K-562,HUDEP-2,erythroblast,CD34                                 7    .
#   thickStart_ReMap thickStop_ReMap Reserved
# 1 48783015         48783016        2522828
# 2 48785978         48785979        2522828
# 3 48787071         48787072        2522828
# 4 48787980         48787981        2522828
# 5 48789721         48789722        2522828
# 6 48794537         48794538        2522828

# %%
dat_reg = dat_region %>% dplyr::filter(Chrom == CHROM, Start >= START, End <= END)
print(dim(dat_reg))
head(dat_reg)
# Out:
# [1] 6 5
#   Chrom Start    End      Peak                   Region
# 1 chrX  48782524 48783758 chrX_48782524_48783758 GATA1
# 2 chrX  48784956 48785503 chrX_48784956_48785503 GATA1
# 3 chrX  48785773 48786737 chrX_48785773_48786737 GATA1
# 4 chrX  48793902 48795694 chrX_48793902_48795694 GATA1
# 5 chrX  48800352 48802804 chrX_48800352_48802804 GATA1
# 6 chrX  48807974 48808435 chrX_48807974_48808435 GATA1

# %%
lst_dat = list(
    "ASTARR" = dat_track_astarr %>% mutate(Coverage = pLog2FC),
    "WSTARR" = dat_track_wstarr %>% mutate(Coverage = pLog2FC),
    "TMPRA"  = dat_track_tmpra  %>% mutate(Coverage =  Log2FC)
)

lst_dat = lapply(lst_dat, function(dat){
    dat = dat %>% dplyr::filter(Chrom == CHROM, Start >= START, End <= END)
    return(dat)
})

names(lst_dat)
# Out:
# [1] "ASTARR" "WSTARR" "TMPRA"

# %%
lst_gpt = lapply(names(lst_dat), function(idx){
    txt = idx
    dat = lst_dat[[idx]]
    gpt = ggplot() + 
        geom_hline(yintercept = 0, color="grey50") +    
        geom_line(data = dat, aes(x=Start, y=Coverage), linewidth=1) +
        labs(x="", title=txt) +
        theme_cowplot()
    return(gpt)
})

options(repr.plot.height=8, repr.plot.width=15)
plot_grid(plotlist = lst_gpt, align="v", ncol=1)
# Out:
# plot without title

# %%
lst_gpt = lapply(names(lst_dat), function(idx){
    txt = idx
    dat = lst_dat[[idx]]
    gpt = ggplot() + 
        geom_hline(yintercept = 0, color="grey50") +    
        geom_line(data = dat, aes(x=Start, y=Coverage), linewidth=1) +
        geom_rect(
            data = dat_ant,
            aes(xmin=Start, xmax=End, ymin=-Inf, ymax=Inf),
            fill = "red",
            alpha=0.5) +
        labs(x="", title=txt) +
        theme_cowplot()
    return(gpt)
})

options(repr.plot.height=8, repr.plot.width=15)
plot_grid(plotlist = lst_gpt, align="v", ncol=1)
# Out:
# plot without title

# %%
lst_gpt = lapply(names(lst_dat), function(idx){
    txt = idx
    dat = lst_dat[[idx]]
    gpt = ggplot() + 
        geom_hline(yintercept = 0, color="grey50") +    
        geom_line(data = dat, aes(x=Start, y=Coverage), linewidth=1) +
        geom_rect(
            data = dat_reg,
            aes(xmin=Start, xmax=End, ymin=-Inf, ymax=Inf),
            fill = "red",
            alpha=0.5) +
        labs(x="", title=txt) +
        theme_cowplot()
    return(gpt)
})

options(repr.plot.height=8, repr.plot.width=15)
plot_grid(plotlist = lst_gpt, align="v", ncol=1)
# Out:
# plot without title
