# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_combeffect
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# **Check data**

# %%
ASSAY = "KS91_K562_ASTARRseq"
REGIONS=c("GATA1", "MYC", "FADS")

get_group  = function(fpath){return(str_extract(fpath, "Input|Output"))}
get_sample = function(fpath){return(str_extract(fpath, "Input.rep\\d|Input.mean|Output.rep\\d|Output.mean"))}
get_region = function(fpath){return(str_extract(fpath, "WGS|GATA1|MYC|FADS"))}

# %%
region = REGIONS[1]
fdiry  = file.path(FD_RES, "results", ASSAY, "coverage")
fname  = paste("", region, "bed.gz", sep="*")
fglob  = file.path(fdiry, fname)
fpaths = Sys.glob(fglob)

for (fpath in fpaths){
    fname  = basename(fpath)
    region = get_region(fpath) 
    group  = get_group(fpath)
    sam    = get_sample(fpath)
    print(fname)
    print(region)
    print(group)
    print(sam)
    cat("++++++++++++++++++++++\n")
}
# Out:
# [1] "KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep1"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Input.rep2.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep2"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Input.rep3.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep3"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Input.rep4.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep4"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Input.rep5.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep5"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Input.rep6.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Input"
# [1] "Input.rep6"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Output.rep1.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Output"
# [1] "Output.rep1"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Output.rep2.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Output"
# [1] "Output.rep2"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Output.rep3.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Output"
# [1] "Output.rep3"
# ++++++++++++++++++++++
# [1] "KS91_K562_ASTARRseq.Output.rep4.GATA1.unstranded.bed.gz"
# [1] "GATA1"
# [1] "Output"
# [1] "Output.rep4"
# ++++++++++++++++++++++

# %% [markdown]
# **RUN**

# %%
### import library size
fdiry  = file.path(FD_RES, "results", ASSAY, "coverage", "summary")
fname  = "library_size_summary.csv"
fpath  = file.path(fdiry, fname)
dat_lib = read_csv(fpath, show_col_types = FALSE)
dat_lib = dat_lib %>% dplyr::select(-FName)
dat_lib
# Out:
#    Type Region Group  Sample      Size
# 1  raw  FADS   Input  Input.rep1      25269
# 2  raw  GATA1  Input  Input.rep1     369389
# 3  raw  MYC    Input  Input.rep1     255645
# 4  raw  WGS    Input  Input.rep1  348695063
# 5  raw  FADS   Input  Input.rep2      32374
# 6  raw  GATA1  Input  Input.rep2     475159
# 7  raw  MYC    Input  Input.rep2     331480
# 8  raw  WGS    Input  Input.rep2  451369741
# 9  raw  FADS   Input  Input.rep3      34910
# 10 raw  GATA1  Input  Input.rep3     510810
# 11 raw  MYC    Input  Input.rep3     359298
# 12 raw  WGS    Input  Input.rep3  487579055
# 13 raw  FADS   Input  Input.rep4      32896
# 14 raw  GATA1  Input  Input.rep4     478434
# 15 raw  MYC    Input  Input.rep4     336062
# 16 raw  WGS    Input  Input.rep4  456246254
# 17 raw  FADS   Input  Input.rep5      31666
# 18 raw  GATA1  Input  Input.rep5     467368
# 19 raw  MYC    Input  Input.rep5     326501
# 20 raw  WGS    Input  Input.rep5  444268950
# 21 raw  FADS   Input  Input.rep6      28645
# 22 raw  GATA1  Input  Input.rep6     420979
# 23 raw  MYC    Input  Input.rep6     291162
# 24 raw  WGS    Input  Input.rep6  397333562
# 25 raw  FADS   Output Output.rep1      2454
# 26 raw  GATA1  Output Output.rep1     50008
# 27 raw  MYC    Output Output.rep1     35777
# 28 raw  WGS    Output Output.rep1  44103844
# 29 raw  FADS   Output Output.rep2      4441
# 30 raw  GATA1  Output Output.rep2     84148
# 31 raw  MYC    Output Output.rep2     66613
# 32 raw  WGS    Output Output.rep2  97471282
# 33 raw  FADS   Output Output.rep3      4659
# 34 raw  GATA1  Output Output.rep3     89369
# 35 raw  MYC    Output Output.rep3     69278
# 36 raw  WGS    Output Output.rep3  84103298
# 37 raw  FADS   Output Output.rep4      8720
# 38 raw  GATA1  Output Output.rep4    165516
# 39 raw  MYC    Output Output.rep4    126056
# 40 raw  WGS    Output Output.rep4 183115379

# %%
cnames = c("Chrom", "Start", "End", "Count")
ctypes = c("ciic")

for (region in REGIONS){
    ### show progress
    cat("\n+++++++++++++++++++\n")
    cat("Region:", region, "\n")
    flush.console()
    
    ### set file paths
    fdiry  = file.path(FD_RES, "results", ASSAY, "coverage")
    fname  = paste("", region, "bed.gz", sep="*")
    fglob  = file.path(fdiry, fname)
    fpaths = Sys.glob(fglob)
    
    ### import data and add info
    lst = lapply(fpaths, function(fpath){
        ### import data
        dat = read_tsv(fpath, col_names = cnames, col_types = ctypes)
        dat = dat %>% 
           dplyr::mutate(Count = replace(Count, Count == ".", 0)) %>%
           dplyr::mutate(Count = as.double(Count))

        ### add information
        #dat$Region = get_region(fpath)
        dat$Region = "WGS"
        dat$Group  = get_group(fpath)
        dat$Sample = get_sample(fpath)

        ### return result dataframe
        return(dat)
    })
    
    ### get raw counts
    dat_count = bind_rows(lst) %>% 
        dplyr::select(Chrom, Start, End, Count, Sample) %>% 
        tidyr::spread(Sample, Count)
    
    cat("\nGet raw counts\n")
    print(dim(dat_count))
    print(head(dat_count))
    flush.console()
    
    ### calculate counts per million
    dat_cpm = bind_rows(lst) %>% 
        dplyr::left_join(dat_lib, by=c("Region", "Group", "Sample")) %>%
        dplyr::mutate(CPM = Count * 1000000 / Size) %>% 
        dplyr::select(Chrom, Start, End, CPM, Sample) %>% 
        tidyr::spread(Sample, CPM)
    
    cat("\nGet CPM\n")
    print(dim(dat_cpm))
    print(head(dat_cpm))
    flush.console()
    
    ### summarize input and output to calculate fold changes
    dat   = dat_cpm %>% dplyr::select(Chrom, Start, End)
    x_inp = dat_cpm %>% dplyr::select(starts_with("Input"))  %>% apply(., 1, mean, na.omit=TRUE)
    x_out = dat_cpm %>% dplyr::select(starts_with("Output")) %>% apply(., 1, mean, na.omit=TRUE)
    x_xfc =      x_out      /      x_inp
    x_lfc = log2(x_out)     - log2(x_inp)
    x_pfc = log2(x_out + 1) - log2(x_inp + 1)
    
    dat_Log2fc = data.frame(cbind(dat, x_inp, x_out, x_xfc, x_lfc, x_pfc))
    colnames(dat_Log2fc) = c("Chrom", "Start", "End", "Input", "Output", "FC", "Log2FC", "pLog2FC")
    
    cat("\nGet Log2FC\n")
    print(dim(dat_Log2fc))
    print(head(dat_Log2fc))
    flush.console()
    
    ### store the results
    fdiry = file.path(FD_RES, "results", ASSAY, "coverage", "summary")
    fname = paste("track", "raw", "count",  region, "tsv", sep=".")
    fpath = file.path(fdiry, fname)
    write_tsv(dat_count, fpath)
    cat(fpath, "\n")
          
    fname = paste("track", "raw", "cpm",    region, "tsv", sep=".")
    fpath = file.path(fdiry, fname)
    write_tsv(dat_cpm, fpath)
    cat(fpath, "\n")
          
    fname = paste("track", "raw", "Log2FC", region, "tsv", sep=".")
    fpath = file.path(fdiry, fname)
    write_tsv(dat_Log2fc, fpath)
    cat(fpath, "\n")
    flush.console()
}
# Out:
# +++++++++++++++++++
# Region: GATA1
#
# Get raw counts
# [1] 2095150      13
# # A tibble: 6 × 13
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Input…⁵ Input…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chrX  47785501  4.78e7       3       4       5       4       4       2       0
# 2 chrX  47785502  4.78e7       3       4       5       4       4       2       0
# 3 chrX  47785503  4.78e7       3       4       5       4       4       2       0
# 4 chrX  47785504  4.78e7       3       4       5       4       4       2       0
# 5 chrX  47785505  4.78e7       3       4       5       4       4       2       0
# 6 chrX  47785506  4.78e7       3       4       5       4       4       2       0
# # … with 3 more variables: Output.rep2 <dbl>, Output.rep3 <dbl>,
# #   Output.rep4 <dbl>, and abbreviated variable names ¹​Input.rep1, ²​Input.rep2,
# #   ³​Input.rep3, ⁴​Input.rep4, ⁵​Input.rep5, ⁶​Input.rep6, ⁷​Output.rep1
#
# Get CPM
# [1] 2095150      13
# # A tibble: 6 × 13
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Input…⁵ Input…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chrX  47785501  4.78e7 0.00860 0.00886  0.0103 0.00877 0.00900 0.00503       0
# 2 chrX  47785502  4.78e7 0.00860 0.00886  0.0103 0.00877 0.00900 0.00503       0
# 3 chrX  47785503  4.78e7 0.00860 0.00886  0.0103 0.00877 0.00900 0.00503       0
# 4 chrX  47785504  4.78e7 0.00860 0.00886  0.0103 0.00877 0.00900 0.00503       0
# 5 chrX  47785505  4.78e7 0.00860 0.00886  0.0103 0.00877 0.00900 0.00503       0
# 6 chrX  47785506  4.78e7 0.00860 0.00886  0.0103 0.00877 0.00900 0.00503       0
# # … with 3 more variables: Output.rep2 <dbl>, Output.rep3 <dbl>,
# #   Output.rep4 <dbl>, and abbreviated variable names ¹​Input.rep1, ²​Input.rep2,
# #   ³​Input.rep3, ⁴​Input.rep4, ⁵​Input.rep5, ⁶​Input.rep6, ⁷​Output.rep1
#
# Get Log2FC
# [1] 2095150       8
#   Chrom    Start      End       Input      Output       FC    Log2FC
# 1  chrX 47785501 47785502 0.008420745 0.009875188 1.172721 0.2298602
# 2  chrX 47785502 47785503 0.008420745 0.009875188 1.172721 0.2298602
# 3  chrX 47785503 47785504 0.008420745 0.009875188 1.172721 0.2298602
# 4  chrX 47785504 47785505 0.008420745 0.009875188 1.172721 0.2298602
# 5  chrX 47785505 47785506 0.008420745 0.009875188 1.172721 0.2298602
# 6  chrX 47785506 47785507 0.008420745 0.009875188 1.172721 0.2298602
#       pLog2FC
# 1 0.002079296
# 2 0.002079296
# 3 0.002079296
# 4 0.002079296
# 5 0.002079296
# 6 0.002079296
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.count.GATA1.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.cpm.GATA1.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.Log2FC.GATA1.tsv
#
# +++++++++++++++++++
# Region: MYC
#
# Get raw counts
# [1] 2000650      13
# # A tibble: 6 × 13
#   Chrom     Start    End Input…¹ Input…² Input…³ Input…⁴ Input…⁵ Input…⁶ Outpu…⁷
#   <chr>     <int>  <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr8  126735901 1.27e8      14      14      17      18      14      19       0
# 2 chr8  126735902 1.27e8      14      14      17      18      14      19       0
# 3 chr8  126735903 1.27e8      14      15      17      19      14      20       0
# 4 chr8  126735904 1.27e8      14      15      17      19      14      19       0
# 5 chr8  126735905 1.27e8      14      15      17      19      14      19       0
# 6 chr8  126735906 1.27e8      14      15      17      19      14      19       0
# # … with 3 more variables: Output.rep2 <dbl>, Output.rep3 <dbl>,
# #   Output.rep4 <dbl>, and abbreviated variable names ¹​Input.rep1, ²​Input.rep2,
# #   ³​Input.rep3, ⁴​Input.rep4, ⁵​Input.rep5, ⁶​Input.rep6, ⁷​Output.rep1
#
# Get CPM
# [1] 2000650      13
# # A tibble: 6 × 13
#   Chrom     Start    End Input…¹ Input…² Input…³ Input…⁴ Input…⁵ Input…⁶ Outpu…⁷
#   <chr>     <int>  <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr8  126735901 1.27e8  0.0401  0.0310  0.0349  0.0395  0.0315  0.0478       0
# 2 chr8  126735902 1.27e8  0.0401  0.0310  0.0349  0.0395  0.0315  0.0478       0
# 3 chr8  126735903 1.27e8  0.0401  0.0332  0.0349  0.0416  0.0315  0.0503       0
# 4 chr8  126735904 1.27e8  0.0401  0.0332  0.0349  0.0416  0.0315  0.0478       0
# 5 chr8  126735905 1.27e8  0.0401  0.0332  0.0349  0.0416  0.0315  0.0478       0
# 6 chr8  126735906 1.27e8  0.0401  0.0332  0.0349  0.0416  0.0315  0.0478       0
# # … with 3 more variables: Output.rep2 <dbl>, Output.rep3 <dbl>,
# #   Output.rep4 <dbl>, and abbreviated variable names ¹​Input.rep1, ²​Input.rep2,
# #   ³​Input.rep3, ⁴​Input.rep4, ⁵​Input.rep5, ⁶​Input.rep6, ⁷​Output.rep1
#
# Get Log2FC
# [1] 2000650       8
#   Chrom     Start       End      Input      Output         FC    Log2FC
# 1  chr8 126735901 126735902 0.03746935 0.002564858 0.06845216 -3.868760
# 2  chr8 126735902 126735903 0.03746935 0.002564858 0.06845216 -3.868760
# 3  chr8 126735903 126735904 0.03862336 0.002564858 0.06640691 -3.912523
# 4  chr8 126735904 126735905 0.03820390 0.002564858 0.06713603 -3.896769
# 5  chr8 126735905 126735906 0.03820390 0.002564858 0.06713603 -3.896769
# 6  chr8 126735906 126735907 0.03820390 0.002564858 0.06713603 -3.896769
#       pLog2FC
# 1 -0.04937315
# 2 -0.04937315
# 3 -0.05097701
# 4 -0.05039424
# 5 -0.05039424
# 6 -0.05039424
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.count.MYC.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.cpm.MYC.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.Log2FC.MYC.tsv
#
# +++++++++++++++++++
# Region: FADS
#
# Get raw counts
# [1] 111020     13
# # A tibble: 6 × 13
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Input…⁵ Input…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr11 61554801  6.16e7      78     110      91     110      96      85       6
# 2 chr11 61554802  6.16e7      78     110      91     110      96      85       6
# 3 chr11 61554803  6.16e7      75     107      89     108      93      84       6
# 4 chr11 61554804  6.16e7      76     107      90     110      96      85       6
# 5 chr11 61554805  6.16e7      76     107      90     110      96      85       6
# 6 chr11 61554806  6.16e7      76     107      89     110      97      85       6
# # … with 3 more variables: Output.rep2 <dbl>, Output.rep3 <dbl>,
# #   Output.rep4 <dbl>, and abbreviated variable names ¹​Input.rep1, ²​Input.rep2,
# #   ³​Input.rep3, ⁴​Input.rep4, ⁵​Input.rep5, ⁶​Input.rep6, ⁷​Output.rep1
#
# Get CPM
# [1] 111020     13
# # A tibble: 6 × 13
#   Chrom    Start     End Input…¹ Input…² Input…³ Input…⁴ Input…⁵ Input…⁶ Outpu…⁷
#   <chr>    <int>   <int>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>   <dbl>
# 1 chr11 61554801  6.16e7   0.224   0.244   0.187   0.241   0.216   0.214   0.136
# 2 chr11 61554802  6.16e7   0.224   0.244   0.187   0.241   0.216   0.214   0.136
# 3 chr11 61554803  6.16e7   0.215   0.237   0.183   0.237   0.209   0.211   0.136
# 4 chr11 61554804  6.16e7   0.218   0.237   0.185   0.241   0.216   0.214   0.136
# 5 chr11 61554805  6.16e7   0.218   0.237   0.185   0.241   0.216   0.214   0.136
# 6 chr11 61554806  6.16e7   0.218   0.237   0.183   0.241   0.218   0.214   0.136
# # … with 3 more variables: Output.rep2 <dbl>, Output.rep3 <dbl>,
# #   Output.rep4 <dbl>, and abbreviated variable names ¹​Input.rep1, ²​Input.rep2,
# #   ³​Input.rep3, ⁴​Input.rep4, ⁵​Input.rep5, ⁶​Input.rep6, ⁷​Output.rep1
#
# Get Log2FC
# [1] 111020      8
#   Chrom    Start      End     Input    Output        FC     Log2FC    pLog2FC
# 1 chr11 61554801 61554802 0.2208566 0.1321553 0.5983760 -0.7408759 -0.1088219
# 2 chr11 61554802 61554803 0.2208566 0.1321553 0.5983760 -0.7408759 -0.1088219
# 3 chr11 61554803 61554804 0.2153558 0.1307900 0.6073207 -0.7194696 -0.1040476
# 4 chr11 61554804 61554805 0.2184511 0.1307900 0.5987153 -0.7400578 -0.1077173
# 5 chr11 61554805 61554806 0.2184511 0.1307900 0.5987153 -0.7400578 -0.1077173
# 6 chr11 61554806 61554807 0.2184844 0.1307900 0.5986240 -0.7402779 -0.1077567
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.count.FADS.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.cpm.FADS.tsv
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/summary/track.raw.Log2FC.FADS.tsv
