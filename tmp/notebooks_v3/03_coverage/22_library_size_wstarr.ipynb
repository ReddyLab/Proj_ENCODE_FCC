# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# SING DIRECTORY:     /data/reddylab/Kuei/singularity
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
ASSAY=A001_K562_WSTARRseq
FDIRY=${FD_RES}/results/${ASSAY}/fragment_count
ls ${FDIRY}
# Out:
# A001_K562_WSTARRseq.Input.rep1.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep1.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep1.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz

# %%
ASSAY=A001_K562_WSTARRseq
FDIRY=${FD_RES}/results/${ASSAY}/fragment_count
FP_INPS=($(ls ${FDIRY}/*bed.gz))

echo Total: ${#FP_INPS[@]}
for FP_INP in ${FP_INPS[@]}; do
    echo $(basename ${FP_INP})
done
# Out:
# Total: 28
# A001_K562_WSTARRseq.Input.rep1.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep1.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep1.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep2.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep3.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Input.rep4.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep1.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep2.WGS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.FADS.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.GATA1.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.MYC.unstranded.bed.gz
# A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz

# %%
FPATH=${FP_INPS[27]}
FNAME=$(basename ${FPATH})
echo ${FPATH}
echo ++++++++++++++++++++++++
echo ${FNAME}
echo ++++++++++++++++++++++++
zcat ${FPATH} | head -n 10
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz
# ++++++++++++++++++++++++
# A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz
# ++++++++++++++++++++++++
# chr1	10537	11067	chr1_10537_11067	1	.
# chr1	14408	14799	chr1_14408_14799	1	.
# chr1	14498	14937	chr1_14498_14937	1	.
# chr1	14676	15184	chr1_14676_15184	1	.
# chr1	14684	15162	chr1_14684_15162	1	.
# chr1	14690	15158	chr1_14690_15158	1	.
# chr1	14839	15209	chr1_14839_15209	1	.
# chr1	14853	15208	chr1_14853_15208	1	.
# chr1	14933	15190	chr1_14933_15190	1	.
# chr1	14934	15190	chr1_14934_15190	1	.

# %%
zcat ${FPATH} | head -n 10 | awk -v OFS=, -v FNAME=${FNAME} '{sum += $5} END {print FNAME, sum}'
# Out:
# A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz,10

# %% [markdown]
# **RUN**

# %%
sbatch -p ${NODE} \
    --exclude=dl-01 \
    --cpus-per-task 8 \
    --mem 20G \
    --output ${FD_LOG}/coverage_library_size_WSTARR.%a.txt \
    --array 0 \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config/config_duke.sh

### set input and output file paths
ASSAY=A001_K562_WSTARRseq

FD_INP=${FD_RES}/results/${ASSAY}/fragment_count
FP_INPS=($(ls ${FD_INP}/*bed.gz))

FD_OUT=${FD_RES}/results/${ASSAY}/coverage/summary
FN_OUT=library_size_output.csv
FP_OUT=${FD_OUT}/${FN_OUT}

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### init
mkdir -p   ${FD_OUT}
echo  -n > ${FP_OUT}

### get library size
for FP_INP in ${FP_INPS[@]}; do
    
    ### show I/O file
    echo ++++++++++++++++++++++++++++++++++++
    echo "Input file path: ${FP_INP}"
    echo "Show the first few lines"
    zcat ${FP_INP} | head -n 3
    echo
    
    ### count the total counts and append the results to the output file
    FN_INP=$(basename ${FP_INP})
    zcat ${FP_INP} |\
        awk -v OFS=, -v FNAME=${FN_INP} '{sum += $5} END {print FNAME, sum}' \
        >> ${FP_OUT}
done

### show I/O file
echo "Output file path: ${FP_OUT}"
echo "Show the lines"
cat ${FP_OUT}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 29430787

# %% [markdown]
# **CHECK**

# %%
cat ${FD_LOG}/coverage_library_size_WSTARR.0.txt
# Out:
# Hostname:           x1-01-4.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         12-13-22+20:37:36
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep1.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554443	61554815	chr11_61554443_61554815	1	.
# chr11	61554444	61554815	chr11_61554444_61554815	1	.
# chr11	61554449	61554957	chr11_61554449_61554957	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785906	47786328	chrX_47785906_47786328	1	.
# chrX	47787533	47787772	chrX_47787533_47787772	1	.
# chrX	47787569	47787735	chrX_47787569_47787735	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep1.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735578	126735929	chr8_126735578_126735929	1	.
# chr8	126735592	126736074	chr8_126735592_126736074	1	.
# chr8	126735615	126735927	chr8_126735615_126735927	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep1.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10335	10549	chr1_10335_10549	1	.
# chr1	16983	17500	chr1_16983_17500	1	.
# chr1	16985	17499	chr1_16985_17499	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep2.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554345	61554866	chr11_61554345_61554866	1	.
# chr11	61554386	61554915	chr11_61554386_61554915	1	.
# chr11	61554388	61554856	chr11_61554388_61554856	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785197	47785559	chrX_47785197_47785559	1	.
# chrX	47785541	47785895	chrX_47785541_47785895	1	.
# chrX	47785577	47786006	chrX_47785577_47786006	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep2.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735548	126736010	chr8_126735548_126736010	1	.
# chr8	126735612	126735952	chr8_126735612_126735952	1	.
# chr8	126735626	126736141	chr8_126735626_126736141	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep2.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10244	10370	chr1_10244_10370	1	.
# chr1	14494	14961	chr1_14494_14961	1	.
# chr1	15593	16258	chr1_15593_16258	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep3.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554179	61554815	chr11_61554179_61554815	1	.
# chr11	61554327	61554865	chr11_61554327_61554865	1	.
# chr11	61554330	61554858	chr11_61554330_61554858	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785068	47785631	chrX_47785068_47785631	1	.
# chrX	47785098	47785680	chrX_47785098_47785680	1	.
# chrX	47785104	47785662	chrX_47785104_47785662	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep3.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735466	126736037	chr8_126735466_126736037	1	.
# chr8	126735490	126735927	chr8_126735490_126735927	1	.
# chr8	126735613	126735977	chr8_126735613_126735977	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep3.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10247	10299	chr1_10247_10299	1	.
# chr1	14684	15184	chr1_14684_15184	1	.
# chr1	14690	15158	chr1_14690_15158	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep4.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554179	61554814	chr11_61554179_61554814	1	.
# chr11	61554331	61554815	chr11_61554331_61554815	1	.
# chr11	61554457	61554874	chr11_61554457_61554874	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785067	47785572	chrX_47785067_47785572	1	.
# chrX	47785093	47785529	chrX_47785093_47785529	1	.
# chrX	47785112	47785515	chrX_47785112_47785515	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep4.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735493	126736016	chr8_126735493_126736016	1	.
# chr8	126735496	126735991	chr8_126735496_126735991	1	.
# chr8	126735523	126736014	chr8_126735523_126736014	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Input.rep4.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10086	10542	chr1_10086_10542	1	.
# chr1	14845	15207	chr1_14845_15207	1	.
# chr1	15520	15834	chr1_15520_15834	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep1.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554193	61554879	chr11_61554193_61554879	1	.
# chr11	61554309	61554854	chr11_61554309_61554854	1	.
# chr11	61554368	61554833	chr11_61554368_61554833	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep1.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785060	47785582	chrX_47785060_47785582	1	.
# chrX	47785199	47785735	chrX_47785199_47785735	1	.
# chrX	47785248	47785654	chrX_47785248_47785654	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep1.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735192	126735902	chr8_126735192_126735902	1	.
# chr8	126735437	126735918	chr8_126735437_126735918	1	.
# chr8	126735557	126735918	chr8_126735557_126735918	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep1.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	14845	15207	chr1_14845_15207	1	.
# chr1	15512	16248	chr1_15512_16248	1	.
# chr1	15652	16254	chr1_15652_16254	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep2.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554013	61554821	chr11_61554013_61554821	1	.
# chr11	61554186	61554802	chr11_61554186_61554802	1	.
# chr11	61554331	61554815	chr11_61554331_61554815	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep2.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785188	47785571	chrX_47785188_47785571	1	.
# chrX	47785197	47785555	chrX_47785197_47785555	1	.
# chrX	47785231	47785658	chrX_47785231_47785658	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep2.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735420	126735991	chr8_126735420_126735991	1	.
# chr8	126735509	126735931	chr8_126735509_126735931	1	.
# chr8	126735557	126736017	chr8_126735557_126736017	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep2.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	14510	14960	chr1_14510_14960	1	.
# chr1	14684	15162	chr1_14684_15162	1	.
# chr1	14688	15199	chr1_14688_15199	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep3.FADS.unstranded.bed.gz
# Show the first few lines
# chr11	61554286	61554911	chr11_61554286_61554911	1	.
# chr11	61554306	61555169	chr11_61554306_61555169	1	.
# chr11	61554312	61554854	chr11_61554312_61554854	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep3.GATA1.unstranded.bed.gz
# Show the first few lines
# chrX	47785062	47785649	chrX_47785062_47785649	1	.
# chrX	47785094	47785628	chrX_47785094_47785628	1	.
# chrX	47785156	47785640	chrX_47785156_47785640	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep3.MYC.unstranded.bed.gz
# Show the first few lines
# chr8	126735490	126735925	chr8_126735490_126735925	1	.
# chr8	126735503	126735986	chr8_126735503_126735986	1	.
# chr8	126735540	126735902	chr8_126735540_126735902	1	.
#
# ++++++++++++++++++++++++++++++++++++
# Input file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/fragment_count/A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz
# Show the first few lines
# chr1	10537	11067	chr1_10537_11067	1	.
# chr1	14408	14799	chr1_14408_14799	1	.
# chr1	14498	14937	chr1_14498_14937	1	.
#
# Output file path: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/A001_K562_WSTARRseq/coverage/summary/library_size_output.csv
# Show the lines
# A001_K562_WSTARRseq.Input.rep1.FADS.unstranded.bed.gz,1892
# A001_K562_WSTARRseq.Input.rep1.GATA1.unstranded.bed.gz,19540
# A001_K562_WSTARRseq.Input.rep1.MYC.unstranded.bed.gz,21892
# A001_K562_WSTARRseq.Input.rep1.WGS.unstranded.bed.gz,26908970
# A001_K562_WSTARRseq.Input.rep2.FADS.unstranded.bed.gz,6921
# A001_K562_WSTARRseq.Input.rep2.GATA1.unstranded.bed.gz,72119
# A001_K562_WSTARRseq.Input.rep2.MYC.unstranded.bed.gz,81027
# A001_K562_WSTARRseq.Input.rep2.WGS.unstranded.bed.gz,99899775
# A001_K562_WSTARRseq.Input.rep3.FADS.unstranded.bed.gz,7348
# A001_K562_WSTARRseq.Input.rep3.GATA1.unstranded.bed.gz,75963
# A001_K562_WSTARRseq.Input.rep3.MYC.unstranded.bed.gz,86311
# A001_K562_WSTARRseq.Input.rep3.WGS.unstranded.bed.gz,105623984
# A001_K562_WSTARRseq.Input.rep4.FADS.unstranded.bed.gz,7511
# A001_K562_WSTARRseq.Input.rep4.GATA1.unstranded.bed.gz,78600
# A001_K562_WSTARRseq.Input.rep4.MYC.unstranded.bed.gz,88615
# A001_K562_WSTARRseq.Input.rep4.WGS.unstranded.bed.gz,108635002
# A001_K562_WSTARRseq.Output.rep1.FADS.unstranded.bed.gz,11794
# A001_K562_WSTARRseq.Output.rep1.GATA1.unstranded.bed.gz,119231
# A001_K562_WSTARRseq.Output.rep1.MYC.unstranded.bed.gz,126539
# A001_K562_WSTARRseq.Output.rep1.WGS.unstranded.bed.gz,160349140
# A001_K562_WSTARRseq.Output.rep2.FADS.unstranded.bed.gz,11531
# A001_K562_WSTARRseq.Output.rep2.GATA1.unstranded.bed.gz,116787
# A001_K562_WSTARRseq.Output.rep2.MYC.unstranded.bed.gz,124349
# A001_K562_WSTARRseq.Output.rep2.WGS.unstranded.bed.gz,157326312
# A001_K562_WSTARRseq.Output.rep3.FADS.unstranded.bed.gz,24483
# A001_K562_WSTARRseq.Output.rep3.GATA1.unstranded.bed.gz,238763
# A001_K562_WSTARRseq.Output.rep3.MYC.unstranded.bed.gz,259970
# A001_K562_WSTARRseq.Output.rep3.WGS.unstranded.bed.gz,328185275
#
#
# Done!
# Run Time: 5 minutes and 31 seconds
