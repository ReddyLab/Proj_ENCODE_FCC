# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
source ../config/config_load_module_bedtools.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# SING DIRECTORY:     /data/reddylab/Kuei/singularity
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# ## Calculate coverage perbase for input and output

# %% [markdown]
# **TEST**

# %%
ASSAY=KS91_K562_ASTARRseq
PREFIX=KS91_K562_ASTARRseq
FD_INP=${FD_RES}/results/${ASSAY}/fragment_count
ls ${FD_INP}
# Out:
# KS91_K562_ASTARRseq.Input.rep1.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.FADS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.MYC.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.WGS.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.FADS.unstranded.bed.gz
# ...

# %%
ASSAY=KS91_K562_ASTARRseq
PREFIX=KS91_K562_ASTARRseq
REGION=GATA1

FD_INP=${FD_RES}/results/${ASSAY}/fragment_count
FD_OUT=${FD_RES}/results/${ASSAY}/coverage

FP_INPS=($(ls ${FD_INP}/*${REGION}*))
echo "Total:  ${#FP_INPS[@]}"

for FP_INP in ${FP_INPS[@]}; do
    FN_INP=$(basename ${FP_INP})
    echo ${FN_INP}
done
# Out:
# Total:  10
# KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep2.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep3.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep4.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep5.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Input.rep6.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep1.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep2.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep3.GATA1.unstranded.bed.gz
# KS91_K562_ASTARRseq.Output.rep4.GATA1.unstranded.bed.gz

# %%
ASSAY=KS91_K562_ASTARRseq
PREFIX=KS91_K562_ASTARRseq

FD_INP=${FD_RES}/results/${ASSAY}/fragment_count
FD_OUT=${FD_RES}/results/${ASSAY}/coverage
IDX=0

REGIONS=(GATA1 MYC FADS)
for REGION in ${REGIONS[@]}; do
    FP_REG=${FD_OUT}/region_${REGION}_perbase.bed
    FP_INPS=($(ls ${FD_INP}/*${REGION}*))
    FP_INP=${FP_INPS[${IDX}]}
    FN_INP=$(basename ${FP_INP})
    
    echo "Region: ${REGION}"
    echo ${FP_REG}
    echo ${FN_INP}
    echo
done
# Out:
# Region: GATA1
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/region_GATA1_perbase.bed
# KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
#
# Region: MYC
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/region_MYC_perbase.bed
# KS91_K562_ASTARRseq.Input.rep1.MYC.unstranded.bed.gz
#
# Region: FADS
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/region_FADS_perbase.bed
# KS91_K562_ASTARRseq.Input.rep1.FADS.unstranded.bed.gz

# %% [markdown]
# **TEST**

# %%
sbatch -p ${NODE} \
    --mem 8G \
    -o ${FD_LOG}/test_bedtools.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config/config_duke.sh
bedtools --help
EOF
# Out:
# Submitted batch job 29420074

# %%
cat ${FD_LOG}/test_bedtools.txt
# Out:
# bedtools: flexible tools for genome arithmetic and DNA sequence analysis.
# usage:    bedtools <subcommand> [options]
#
# The bedtools sub-commands include:
#
# [ Genome arithmetic ]
#     intersect     Find overlapping intervals in various ways.
#     window        Find overlapping intervals within a window around an interval.
#     closest       Find the closest, potentially non-overlapping interval.
#     coverage      Compute the coverage over defined intervals.
#     map           Apply a function to a column for each overlapping interval.
#     genomecov     Compute the coverage over an entire genome.
#     merge         Combine overlapping/nearby intervals into a single interval.
#     cluster       Cluster (but don't merge) overlapping/nearby intervals.
#     complement    Extract intervals _not_ represented by an interval file.
#     subtract      Remove intervals based on overlaps b/w two files.
#     slop          Adjust the size of intervals.
# ...

# %% [markdown]
# **RUN**

# %%
sbatch -p ${NODE} \
    --mem 20G \
    --array 0-9 \
    -o ${FD_LOG}/coverage_perbase_ASTARR.%a.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config/config_duke.sh
ASSAY=KS91_K562_ASTARRseq
PREFIX=KS91_K562_ASTARRseq
REGIONS=(GATA1 MYC FADS)

### set input and output directory
FD_INP=${FD_RES}/results/${ASSAY}/fragment_count
FD_OUT=${FD_RES}/results/${ASSAY}/coverage

### print start message
timer_start=`date +%s`
echo "Hostname:          " $(hostname)
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### +++++++++++++++++++++++++++++++++++++++++++++++

for REGION in ${REGIONS[@]}; do

    ### set input and output file
    FP_REG=${FD_OUT}/region_${REGION}_perbase.bed
    
    FP_INPS=($(ls ${FD_INP}/*${REGION}*))
    FP_INP=${FP_INPS[${SLURM_ARRAY_TASK_ID}]}
    FN_INP=$(basename ${FP_INP})
    
    FN_OUT=${FN_INP}
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    ### show input file
    echo ++++++++++++++++++++++++++++++++++++++
    echo
    echo "Input: " ${FP_INP}
    echo
    echo "show first few lines of input"
    zcat ${FP_INP} | head -n 5
    echo
    echo "show last few lines of output"
    zcat ${FP_INP} | tail -n 5
    echo
    echo "Input: " ${FP_REG}
    echo
    echo "show first few lines of input"
    cat  ${FP_REG} | head -n 5
    echo
    echo "show last few lines of output"
    cat  ${FP_REG} | tail -n 5
    echo
    echo
    
    ### execute
    bedtools map \
        -a ${FP_REG} \
        -b ${FP_INP} \
        -o sum |\
        gzip -c > ${FP_OUT}
    
    ### show output file
    echo "Output: " ${FP_OUT}
    echo
    echo "show first few lines of output:"
    zcat ${FP_OUT} | head -n 5
    echo
    echo "show last few lines of output"
    zcat ${FP_OUT} | tail -n 5
    echo
done

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"
EOF
# Out:
# Submitted batch job 29422635

# %%
ls ${FD_LOG}/coverage_perbase_ASTARR.*.txt
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.0.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.1.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.2.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.3.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.4.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.5.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.6.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.7.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.8.txt
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.9.txt

# %%
tail -n 10 ${FD_LOG}/coverage_perbase_ASTARR.*.txt
# Out:
# ==> /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.0.txt <==
# show last few lines of output
# chr11	61665816	61665817	54
# chr11	61665817	61665818	54
# chr11	61665818	61665819	54
# chr11	61665819	61665820	54
# chr11	61665820	61665821	53
#
#
# Done!
# Run Time: 41 seconds
#
# ==> /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.1.txt <==
# show last few lines of output
# chr11	61665816	61665817	74
# chr11	61665817	61665818	74
# chr11	61665818	61665819	75
# chr11	61665819	61665820	77
# chr11	61665820	61665821	72
#
#
# Done!
# Run Time: 48 seconds
#
# ==> /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.2.txt <==
# show last few lines of output
# chr11	61665816	61665817	77
# chr11	61665817	61665818	77
# chr11	61665818	61665819	77
# chr11	61665819	61665820	77
# chr11	61665820	61665821	75
#
#
# Done!
# Run Time: 50 seconds
#
# ...

# %%
cat ${FD_LOG}/coverage_perbase_ASTARR.0.txt
# Out:
# Hostname:           dl-01.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         12-08-22+17:01:33
#
# ++++++++++++++++++++++++++++++++++++++
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
#
# show first few lines of input
# chrX	47785383	47785713	chrX_47785383_47785713	1	.
# chrX	47785456	47785689	chrX_47785456_47785689	1	.
# chrX	47785485	47785703	chrX_47785485_47785703	1	.
# chrX	47785548	47785742	chrX_47785548_47785742	1	.
# chrX	47785617	47785729	chrX_47785617_47785729	1	.
#
# show last few lines of output
# chrX	49880602	49880829	chrX_49880602_49880829	1	.
# chrX	49880604	49880882	chrX_49880604_49880882	1	.
# chrX	49880614	49880772	chrX_49880614_49880772	1	.
# chrX	49880642	49880758	chrX_49880642_49880758	1	.
# chrX	49880642	49881003	chrX_49880642_49881003	1	.
#
# ...

# %% [markdown]
# -----
#
# previous

# %%
tail ${FD_LOG}/coverage_perbase_ASTARR.*.txt
# Out:
# ==> /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.0.txt <==
# show last few lines of output
# chr11	61665466	61665467	25
# chr11	61665467	61665468	25
# chr11	61665468	61665469	25
# chr11	61665469	61665470	25
# chr11	61665470	6
#
# Done!
# Run Time: 17 minutes and 53 seconds
# slurmstepd: error: Detected 1 oom-kill event(s) in StepId=29420107.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.
#
# ==> /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log/coverage_perbase_ASTARR.1.txt <==
# show last few lines of output
# chr11	61665273	61665274	15
# chr11	61665274	61665275	15
# chr11	61665275	61665276	15
# chr11	61665276	61665277	15
# chr11	61665277	61665278	1
#
# Done!
# Run Time: 22 minutes and 0 seconds
# slurmstepd: error: Detected 1 oom-kill event(s) in StepId=29420108.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.
#
# ...

# %%
cat ${FD_LOG}/coverage_perbase_ASTARR.0.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         12-07-22+15:40:40
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
#
# ++++++++++++++++++++++++++++++++++++++
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/KS91_K562_ASTARRseq.Input.rep1.GATA1.unstranded.bed.gz
#
# show first few lines of output:
# chrX	47785501	47785502	3
# chrX	47785502	47785503	3
# chrX	47785503	47785504	3
# chrX	47785504	47785505	3
# chrX	47785505	47785506	3
#
# show last few lines of output
# chrX	49880646	49880647	51
# chrX	49880647	49880648	50
# chrX	49880648	49880649	50
# ...

# %%
cat ${FD_LOG}/coverage_perbase_ASTARR.9.txt
# Out:
# Hostname:           x1-02-2.genome.duke.edu
# Slurm Array Index:  9
# Time Stamp:         12-07-22+15:40:40
#
# Input:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/fragment_count/KS91_K562_ASTARRseq.Output.rep4.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10033	10130	chr1_10033_10130	1	.
# chr1	10057	10233	chr1_10057_10233	3	.
# chr1	10104	10345	chr1_10104_10345	1	.
# chr1	10116	10461	chr1_10116_10461	1	.
# chr1	10147	10430	chr1_10147_10430	1	.
#
# ++++++++++++++++++++++++++++++++++++++
#
# Output:  /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/results/KS91_K562_ASTARRseq/coverage/KS91_K562_ASTARRseq.Output.rep4.GATA1.unstranded.bed.gz
#
# show first few lines of output:
# chrX	47785501	47785502	1
# chrX	47785502	47785503	1
# chrX	47785503	47785504	1
# chrX	47785504	47785505	1
# chrX	47785505	47785506	1
#
# show last few lines of output
# chrX	49880646	49880647	22
# chrX	49880647	49880648	22
# chrX	49880648	49880649	22
# ...
