# %%
### set env
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# SING DIRECTORY:     /data/reddylab/Kuei/singularity
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
ls ${FD_RES}/source/annotation_enhancer_junke/*
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/annotation_enhancer_junke/ATAC_STARR_deep:
# deep_ATAC_STARR_seq.full_overlap_30bp_bin_10bp_stepSize
# deep_ATAC_STARR_seq.full_overlap_30bp_bin_10bp_stepSize.tar.gz
# deep_ATAC_STARR_seq.full_overlap_30bp_bin_10bp_stepSize.zip
#
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/annotation_enhancer_junke/WHG_STARR_seq_TR:
# WHG_STARR_seq_TR.full_overlap_30bp_bin_10bp_stepSize
# WHG_STARR_seq_TR.full_overlap_30bp_bin_10bp_stepSize.tar.gz
# WHG_STARR_seq_TR.full_overlap_30bp_bin_10bp_stepSize.zip

# %%
FD_ANN=${FD_RES}/source/annotation_enhancer_junke/
FDIRY=${FD_ANN}/ATAC_STARR_deep/deep_ATAC_STARR_seq.full_overlap_30bp_bin_10bp_stepSize/processed
ls ${FDIRY}
# Out:
# bin_level  merged_peak

# %%
FD_ANN=${FD_RES}/source/annotation_enhancer_junke/
FDIRY=${FD_ANN}/ATAC_STARR_deep/deep_ATAC_STARR_seq.full_overlap_30bp_bin_10bp_stepSize/processed
ls ${FDIRY}/bin_level
# Out:
# all_bin_tested_in_both_orientations.bed.gz
# inactive_bins_with_raw_count.bed.gz
# orientation_independent_significantly_up_regulated_bins.bed.gz
# significantly_down_regulated_bins_with_raw_count.bed.gz
# significantly_up_regulated_bins_with_raw_count.bed.gz

# %%
FD_ANN=${FD_RES}/source/annotation_enhancer_junke/
FDIRY=${FD_ANN}/ATAC_STARR_deep/deep_ATAC_STARR_seq.full_overlap_30bp_bin_10bp_stepSize/processed
ls ${FDIRY}/merged_peak
# Out:
# merged_sig_down_in_each_orientation.bed.gz
# merged_sig_up_in_each_orientation.bed.gz
# orientation_independent_up_regulated_peaks_intersection.bed.gz
# orientation_independent_up_regulated_peaks_union.bed.gz
# size_constrained_merged_sig_down_in_each_orientation.bed.gz
# size_constrained_merged_sig_up_in_each_orientation.bed.gz
# size_constrained_orientation_independent_up_regulated_peaks_intersection.bed.gz
# size_constrained_orientation_independent_up_regulated_peaks_union.bed.gz

# %%
zcat ${FDIRY}/merged_peak/merged_sig_up_in_each_orientation.bed.gz | head
# Out:
# chr1	115560	115690	.	1.4299846052688818	+	130	1.61218649059031,1.82095079987959,1.74277916472736,1.91413871907028,1.30901836693522,1.09315926195444,1.06569367686141,1.43837516687016,1.36211622436814,1.32902519097671,1.04238759572408	0.0348468434836336,0.0002249817054419,0.0001961828089644,6.18635866067873e-05,7.77809830207413e-06,2.84966922713597e-05,2.77684173499341e-05,4.1692503032885e-07,4.09940781385953e-07,3.51314762617429e-07,0.0002549781737512
# ...

# %%
zcat ${FDIRY}/merged_peak/orientation_independent_up_regulated_peaks_intersection.bed.gz | head
# Out:
# chr1	115570	115690	1.4952896512620995	1.82095079987959,1.66186347192832,1.74277916472736,1.54387790434756,1.91413871907028,1.4181134451867,1.86643627905353,1.30901836693522,1.84216866291719,1.09315926195444,1.82767631312962,1.06569367686141,1.41344635184672,1.43837516687016,1.37092951623346,1.36211622436814,1.34860686377287,1.32902519097671,1.49503004945863,1.04238759572408	120
# chr1	605280	605300	1.6238683456372849	1.58785326486738,1.65988342640719	20
# chr1	605330	605340	1.5091428036904149	1.4930959195631,1.52518968781773	10
# chr1	605350	605370	1.42610648932794	1.42523404635122,1.42697893230466	20
# chr1	605440	605480	1.3046829521276848	1.25570268932241,1.35366321493296	40
# ...

# %%
zcat ${FDIRY}/merged_peak/orientation_independent_up_regulated_peaks_union.bed.gz | head
# Out:
# chr1	115570	115690	1.4952896512620995	1.82095079987959,1.66186347192832,1.74277916472736,1.54387790434756,1.91413871907028,1.4181134451867,1.86643627905353,1.30901836693522,1.84216866291719,1.09315926195444,1.82767631312962,1.06569367686141,1.41344635184672,1.43837516687016,1.37092951623346,1.36211622436814,1.34860686377287,1.32902519097671,1.49503004945863,1.04238759572408	120
# chr1	605280	605300	1.6238683456372849	1.58785326486738,1.65988342640719	20
# chr1	605330	605340	1.5091428036904149	1.4930959195631,1.52518968781773	10
# chr1	605350	605370	1.42610648932794	1.42523404635122,1.42697893230466	20
# chr1	605440	605480	1.3046829521276848	1.25570268932241,1.35366321493296	40
# ...

# %%
zcat ${FDIRY}/merged_peak/orientation_independent_up_regulated_peaks_union.bed.gz |\
    cut -f1-3 |\
    head
# Out:
# chr1	115570	115690
# chr1	605280	605300
# chr1	605330	605340
# chr1	605350	605370
# chr1	605440	605480
# chr1	778380	778500
# chr1	778600	778870
# chr1	827380	827400
# chr1	842880	842960
# chr1	944400	944440

# %%
ls ${FD_RES}/region/annotation_enhancer_junke
# Out:
# ATAC_STARR_deep  WHG_STARR_seq_TR

# %%
# Out:
# /data/reddylab/Kuei/source

# %%
FD_ANN=${FD_RES}/source/annotation_enhancer_junke/
FDIRY=${FD_ANN}/ATAC_STARR_deep/deep_ATAC_STARR_seq.full_overlap_30bp_bin_10bp_stepSize/processed
ls ${FDIRY}/merged_peak

# %%
FOLDER=ATAC_STARR_deep
