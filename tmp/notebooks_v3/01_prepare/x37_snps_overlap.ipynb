# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_combeffect
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
fdiry = file.path(FD_RES, "region", "control_tmpra")
fname = "snps_OL13_rsid_loc.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath)

dat_snps_OL13_loc = dat
print(dim(dat))
head(dat)
# Out:
# Rows: 206 Columns: 6
# ── Column specification ───────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): RSID, Chrom, Allele_Ref, Allele_Alt
# dbl (2): Loc_hg19, Loc_hg38
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 206   6
#   RSID        Chrom Allele_Ref Allele_Alt Loc_hg19 Loc_hg38
# 1 rs4846217   chr1  C          T          10451799 10391742
# 2 rs4908346   chr1  C          T          28690858 28364347
# 3 rs796493340 chr1  CA         TG         28690858 28364347
# 4 rs12060242  chr1  G          C          36988612 36523011
# 5 rs115675756 chr1  G          A          53304050 52838378
# 6 rs61797307  chr1  C          T          76144459 75678774

# %%
fdiry = file.path(FD_RES, "region", "control_tmpra")
fname = "control_OL43_OL45_info.tsv"
fpath = file.path(fdiry, fname)

dat = read_tsv(fpath)

dat_snps_OL43_OL45_loc = dat
print(dim(dat))
head(dat)
# Out:
# Rows: 1194 Columns: 8
# ── Column specification ───────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (6): Dataset, Project, SNP, Chrom, Allele_Ref, Allele_Alt
# dbl (2): Loc_hg19, Loc_hg38
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 1194    8
#   Dataset Project  SNP               Chrom Loc_hg19  Loc_hg38  Allele_Ref
# 1 OL43    ctrl_pos 1:10437778:C:T    chr1   10437778  10377720 C
# 2 OL43    ctrl_neg 1:10451799:C:T    chr1   10451799  10391742 C
# 3 OL43    ctrl_pos 1:110198727:C:G   chr1  110198727 109656105 C
# 4 OL43    ctrl_pos 1:110881742:NA:NA chr1  110881742 110339120 NA
# 5 OL43    ctrl_pos 1:111838694:C:T   chr1  111838694 111296072 C
# 6 OL43    ctrl_neg 1:113047064:NA:NA chr1  113047064 112504442 NA
#   Allele_Alt
# 1 T
# 2 T
# 3 G
# 4 NA
# 5 T
# 6 NA

# %% [markdown]
# ## Overlap

# %%
dat = dat_snps_OL13_loc
dat = dat %>% 
    dplyr::mutate(
        LOC = paste(Chrom, Loc_hg38, sep="_")
    )

x = dat$LOC

# %%
dat = dat_snps_OL43_OL45_loc
dat = dat %>% 
    dplyr::mutate(
        LOC = paste(Chrom, Loc_hg38, sep="_")
    )

y = dat$LOC

# %%
intersect(x, y)
# Out:
#   [1] "chr1_10391742"   "chr1_28364347"   "chr1_36523011"   "chr1_52838378"
#   [5] "chr1_75678774"   "chr1_75685568"   "chr1_75701161"   "chr1_118521025"
#   [9] "chr1_171924859"  "chr1_217143694"  "chr1_218222585"  "chr1_220676484"
#  [13] "chr1_238823300"  "chr2_36270518"   "chr2_49207021"   "chr2_76822170"
#  [17] "chr2_88650408"   "chr2_88656096"   "chr2_130321910"  "chr2_130321953"
#  [21] "chr2_153952245"  "chr2_199756697"  "chr3_33464339"   "chr3_34935333"
#  [25] "chr3_73487356"   "chr3_86668670"   "chr3_104227305"  "chr3_106737087"
#  [29] "chr3_115674624"  "chr3_120138483"  "chr3_125740330"  "chr3_125745025"
#  [33] "chr3_125751665"  "chr3_145435327"  "chr3_146534670"  "chr3_152171997"
#  [37] "chr3_164476977"  "chr3_175103081"  "chr3_195608394"  "chr4_12941252"
#  [41] "chr4_41963533"   "chr4_107144419"  "chr4_121801213"  "chr4_129117519"
#  [45] "chr4_142926552"  "chr4_153458328"  "chr5_974440"     "chr5_19453083"
# ...
