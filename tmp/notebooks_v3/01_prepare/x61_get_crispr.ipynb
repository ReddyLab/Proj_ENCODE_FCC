# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# SING DIRECTORY:     /data/reddylab/Kuei/singularity
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
echo ${FD_SRC}
# Out:
# /data/reddylab/Kuei/source

# %%
ls ${FD_RES}/source/CRISPR
# Out:
# GATA1_HCRFF_rAVG.log2FC_2.bw  trackDb.txt

# %%
cat ${FD_RES}/source/CRISPR/trackDb.txt | grep Url
# Out:
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CRISPRi_rAVG_log2FC_2.bw
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CAPRIN1_HCRFF_rAVG.log2FC_2.bw
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CAPRIN1_HCRFF_peaks.bb
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CAT_HCRFF_rAVG.log2FC_2.bw
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CAT_HCRFF_peaks.bb
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CD164_HCRFF_rAVG.log2FC_2.bw
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CD164_HCRFF_peaks.bb
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/ERP29_HCRFF_rAVG.log2FC_2.bw
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/ERP29_HCRFF_peaks.bb
# bigDataUrl	https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/FADS1_HCRFF_rAVG.log2FC_2.bw
# ...

# %%
URLS=$(cat ${FD_RES}/source/CRISPR/trackDb.txt | grep Url | grep bw | cut -f2)
for URL in ${URLS[@]}; do
    echo ${URL}
done
# Out:
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CRISPRi_rAVG_log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CAPRIN1_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CAT_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CD164_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/ERP29_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/FADS1_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/FADS2_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/FADS3_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/FEN1_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/GATA1_HCRFF_rAVG.log2FC_2.bw
# https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/HBE1_HCRFF_rAVG.log2FC_2.bw
# ...

# %%
FD_OUT=${FD_RES}/source/CRISPR
URLS=$(cat ${FD_RES}/source/CRISPR/trackDb.txt | grep Url | grep bw | cut -f2)

for URL in ${URLS[@]}; do
    wget ${URL} -P ${FD_OUT}
done
# Out:
# --2023-02-07 20:53:22--  https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CRISPRi_rAVG_log2FC_2.bw
# Resolving data.cyverse.org (data.cyverse.org)... 206.207.252.35
# Connecting to data.cyverse.org (data.cyverse.org)|206.207.252.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21103568 (20M) [application/octet-stream]
# Saving to: ‘/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/CRISPRi_rAVG_log2FC_2.bw’
#
# 100%[======================================>] 21,103,568  6.07MB/s   in 5.0s
#
# 2023-02-07 20:53:30 (3.99 MB/s) - ‘/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/CRISPRi_rAVG_log2FC_2.bw’ saved [21103568/21103568]
#
# --2023-02-07 20:53:30--  https://data.cyverse.org/dav-anon/iplant/home/ohjinwoo94/CAPRIN1_HCRFF_rAVG.log2FC_2.bw
# Resolving data.cyverse.org (data.cyverse.org)... 206.207.252.35
# Connecting to data.cyverse.org (data.cyverse.org)|206.207.252.35|:443... connected.
# ...

# %%
ls ${FD_OUT}/*.bw
# Out:
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/CAPRIN1_HCRFF_rAVG.log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/CAT_HCRFF_rAVG.log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/CD164_HCRFF_rAVG.log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/CRISPRi_rAVG_log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/ERP29_HCRFF_rAVG.log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/FADS1_HCRFF_rAVG.log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/FADS2_HCRFF_rAVG.log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/FADS3_HCRFF_rAVG.log2FC_2.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/FEN1_FADS123_MPRA_tiling.Z_bp.bw
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/CRISPR/FEN1_HCRFF_rAVG.log2FC_2.bw
# ...

# %%
ls ${FD_OUT}/*.bw | wc -l
# Out:
# 26
