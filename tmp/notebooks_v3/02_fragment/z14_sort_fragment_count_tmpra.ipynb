# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /data/reddylab/Kuei
# WORK DIRECTORY:     /data/reddylab/Kuei/out
# CODE DIRECTORY:     /data/reddylab/Kuei/code
# SING DIRECTORY:     /data/reddylab/Kuei/singularity
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/bin
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/code/Proj_CombEffect_ENCODE_FCC
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# **Check data**

# %%
FDIRY=${FD_RES}/results/Tewhey_K562_TileMPRA
ls ${FDIRY}
# Out:
# coverage                            fragment        fragment_nuc
# coverage_astarrseq_peak_macs_input  fragment_count

# %%
FDIRY=${FD_RES}/results/Tewhey_K562_TileMPRA/fragment_count
FPATHS=${FDIRY}/*hg38*
basename -a ${FPATHS}
# Out:
# OL13_20220512.hg38.norm.Input.mean.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed
# OL13_20220512.hg38.norm.Log2FC.mean.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.mean.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.mean.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed
# OL43_20221003.hg38.norm.Log2FC.mean.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.mean.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.mean.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed
# OL45_20220927.hg38.norm.Log2FC.mean.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.mean.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed

# %%
FDIRY=${FD_RES}/results/Tewhey_K562_TileMPRA/fragment_count
FPATHS=${FDIRY}/*hg38*

for FP_INP in ${FPATHS[@]}; do
    ###
    FN_INP=$(basename ${FP_INP})
    PREFIX=$(basename -s .bed ${FP_INP})
    FN_OUT=${PREFIX}.sorted.bed
    FP_OUT=${FDIRY}/${FN_OUT}
    
    ###
    #sort -k 1,1 -k2,2n .bed
    
    ### show progress
    echo ${FN_INP}
    echo ${FN_OUT}
    echo ==================
done
# Out:
# OL13_20220512.hg38.norm.Input.mean.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.mean.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep1.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep2.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep3.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed
# OL13_20220512.hg38.norm.Input.rep4.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Log2FC.mean.stranded_pos.bed
# OL13_20220512.hg38.norm.Log2FC.mean.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Output.mean.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.mean.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep1.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep2.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep3.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed
# OL13_20220512.hg38.norm.Output.rep4.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep1.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep2.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep3.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed
# OL13_20220512.hg38.raw.Input.rep4.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep1.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep2.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep3.stranded_pos.sorted.bed
# ==================
# OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed
# OL13_20220512.hg38.raw.Output.rep4.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Input.mean.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.mean.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep1.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep2.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep3.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep4.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep5.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed
# OL43_20221003.hg38.norm.Input.rep6.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Log2FC.mean.stranded_pos.bed
# OL43_20221003.hg38.norm.Log2FC.mean.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Output.mean.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.mean.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep1.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep2.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep3.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep4.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed
# OL43_20221003.hg38.norm.Output.rep5.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep1.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep2.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep3.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep4.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep5.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed
# OL43_20221003.hg38.raw.Input.rep6.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep1.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep2.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep3.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep4.stranded_pos.sorted.bed
# ==================
# OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed
# OL43_20221003.hg38.raw.Output.rep5.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Input.mean.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.mean.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep1.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep2.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep3.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed
# OL45_20220927.hg38.norm.Input.rep4.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Log2FC.mean.stranded_pos.bed
# OL45_20220927.hg38.norm.Log2FC.mean.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Output.mean.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.mean.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep1.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep2.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep3.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed
# OL45_20220927.hg38.norm.Output.rep4.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep1.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep2.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep3.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed
# OL45_20220927.hg38.raw.Input.rep4.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep1.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep2.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep3.stranded_pos.sorted.bed
# ==================
# OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed
# OL45_20220927.hg38.raw.Output.rep4.stranded_pos.sorted.bed
# ==================
