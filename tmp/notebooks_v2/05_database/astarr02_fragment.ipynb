# %% [markdown]
# **Set environment**

# %%
source ../config/config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /data/reddylab/Kuei
# PATH OF SOURCE:     /data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /data/reddylab/Kuei/GitRepo/Proj_CombEffect_ENCODE_FCC/notebooks
# PATH OF RESULTS:    /data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# ## RUN

# %%
echo ${NODE}
echo ${FD_LOG}
# Out:
# all
# /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/log

# %%
sbatch \
    -J astarr_db \
    -o ${FD_LOG}/create_database_astarr.%a.out \
    run_create_database_starr.sh KS91_K562_ASTARRseq
# Out:
# Submitted batch job 29305007

# %%
sbatch \
    -J wstarr_db \
    -o ${FD_LOG}/create_database_wstarr.%a.out \
    run_create_database_starr.sh A001_K562_WSTARRseq
# Out:
# Submitted batch job 29305008

# %%
cat ${FD_LOG}/create_database_astarr.0.out
# Out:
# Hostname:           x2-07-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         11-07-22+19:29:01
#
# Assay:    KS91_K562_ASTARRseq
# Region:   GATA1
# Database: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/KS91_K562_ASTARRseq/database/fragment_GATA1.db
#
# Reset tables...
#
# Create tables...
#
# Show table names...
# ('Sample',)
# ('Fragment',)
# ('Motif',)
# ('Count',)
# ('Annotation',)
# ('Coverage',)
#
# Show table indices...
# ('sqlite_autoindex_Sample_1',)
# ('sqlite_autoindex_Fragment_1',)
# ('sqlite_autoindex_Motif_1',)
# ('sqlite_autoindex_Annotation_1',)
# Insert Table: Sample
#   Input: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/KS91_K562_ASTARRseq/coverage/library_size/library_size_summary.csv
# Insert Table: Motif
#   Input: /data/reddylab/Kuei/annotation/motif_cluster_jvierstra/hg38_archetype_motifs_v1/chrX_rm_mouse_merge.bed.gz
# Insert Table: Fragment
# ...

# %%
cat ${FD_LOG}/create_database_astarr.1.out
# Out:
# Hostname:           x2-07-1.genome.duke.edu
# Slurm Array Index:  1
# Time Stamp:         11-07-22+19:29:01
#
# Assay:    KS91_K562_ASTARRseq
# Region:   MYC
# Database: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/KS91_K562_ASTARRseq/database/fragment_MYC.db
#
# Reset tables...
#
# Create tables...
#
# Show table names...
# ('Sample',)
# ('Fragment',)
# ('Motif',)
# ('Count',)
# ('Annotation',)
# ('Coverage',)
#
# Show table indices...
# ('sqlite_autoindex_Sample_1',)
# ('sqlite_autoindex_Fragment_1',)
# ('sqlite_autoindex_Motif_1',)
# ('sqlite_autoindex_Annotation_1',)
# Insert Table: Sample
#   Input: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/KS91_K562_ASTARRseq/coverage/library_size/library_size_summary.csv
# Insert Table: Motif
#   Input: /data/reddylab/Kuei/annotation/motif_cluster_jvierstra/hg38_archetype_motifs_v1/chr8_rm_mouse_merge.bed.gz
# Insert Table: Fragment
# ...

# %%
cat ${FD_LOG}/create_database_wstarr.0.out
# Out:
# Hostname:           x2-07-1.genome.duke.edu
# Slurm Array Index:  0
# Time Stamp:         11-07-22+19:29:01
#
# Assay:    A001_K562_WSTARRseq
# Region:   GATA1
# Database: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/A001_K562_WSTARRseq/database/fragment_GATA1.db
#
# Reset tables...
#
# Create tables...
#
# Show table names...
# ('Sample',)
# ('Fragment',)
# ('Motif',)
# ('Count',)
# ('Annotation',)
# ('Coverage',)
#
# Show table indices...
# ('sqlite_autoindex_Sample_1',)
# ('sqlite_autoindex_Fragment_1',)
# ('sqlite_autoindex_Motif_1',)
# ('sqlite_autoindex_Annotation_1',)
# Insert Table: Sample
#   Input: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/A001_K562_WSTARRseq/coverage/library_size/library_size_summary.csv
# Insert Table: Motif
#   Input: /data/reddylab/Kuei/annotation/motif_cluster_jvierstra/hg38_archetype_motifs_v1/chrX_rm_mouse_merge.bed.gz
# Insert Table: Fragment
# ...

# %%
cat ${FD_LOG}/create_database_wstarr.1.out
# Out:
# Hostname:           x2-07-1.genome.duke.edu
# Slurm Array Index:  1
# Time Stamp:         11-07-22+19:29:01
#
# Assay:    A001_K562_WSTARRseq
# Region:   MYC
# Database: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/A001_K562_WSTARRseq/database/fragment_MYC.db
#
# Reset tables...
#
# Create tables...
#
# Show table names...
# ('Sample',)
# ('Fragment',)
# ('Motif',)
# ('Count',)
# ('Annotation',)
# ('Coverage',)
#
# Show table indices...
# ('sqlite_autoindex_Sample_1',)
# ('sqlite_autoindex_Fragment_1',)
# ('sqlite_autoindex_Motif_1',)
# ('sqlite_autoindex_Annotation_1',)
# Insert Table: Sample
#   Input: /data/reddylab/Kuei/out/proj_combeffect_encode_fcc/A001_K562_WSTARRseq/coverage/library_size/library_size_summary.csv
# Insert Table: Motif
#   Input: /data/reddylab/Kuei/annotation/motif_cluster_jvierstra/hg38_archetype_motifs_v1/chr8_rm_mouse_merge.bed.gz
# Insert Table: Fragment
# ...
