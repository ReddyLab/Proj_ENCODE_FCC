# %%
suppressMessages(suppressWarnings(source("../config/config_sing.R")))
show_env()
# Out:
# You are in Singularity: singularity_proj_combeffect
# BASE DIRECTORY:     /mount/work
# PATH OF SOURCE:     /mount/work/source
# PATH OF EXECUTABLE: /mount/work/exe
# PATH OF ANNOTATION: /mount/work/annotation
# PATH OF PROJECT:    /mount/project
# PATH OF RESULTS:    /mount/work/out/proj_combeffect_encode_fcc

# %% [markdown]
# ## Import results

# %%
PREFIX = "KS91_K562_ASTARRseq"
FOLDER = "coverage_astarrseq_peak_macs_input"

fdiry = file.path(FD_RES, PREFIX, FOLDER, "summary")
fname = "wgs_deseq_results.tsv"
fpath = file.path(fdiry, fname)

res_astarr = read_tsv(fpath)
# Out:
# Rows: 246850 Columns: 7
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): Peak
# dbl (6): baseMean, log2FoldChange, lfcSE, stat, pvalue, padj
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
PREFIX = "A001_K562_WSTARRseq"
FOLDER = "coverage_astarrseq_peak_macs_input"

fdiry = file.path(FD_RES, PREFIX, FOLDER, "summary")
fname = "wgs_deseq_results.tsv"
fpath = file.path(fdiry, fname)

res_wstarr = read_tsv(fpath)
# Out:
# Rows: 246688 Columns: 7
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): Peak
# dbl (6): baseMean, log2FoldChange, lfcSE, stat, pvalue, padj
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## Plot

# %%
head(res_astarr)
# Out:
#   Peak             baseMean  log2FoldChange lfcSE     stat        pvalue
# 1 chr1_10015_10442  71.40375 -2.2136128     0.2691517  -8.2244060 1.961605e-16
# 2 chr1_14253_14645  68.63035  0.2221859     0.1534101   1.4483134 1.475294e-01
# 3 chr1_16015_16477  71.25409 -1.2712950     0.2019628  -6.2946978 3.079993e-10
# 4 chr1_17237_17772 124.03128 -1.3852891     0.1638628  -8.4539594 2.815873e-17
# 5 chr1_28903_29613 113.63103 -1.9422003     0.1886131 -10.2972733 7.248682e-25
# 6 chr1_30803_31072  57.37875 -0.1332069     0.2145692  -0.6208109 5.347240e-01
#   padj
# 1 2.910689e-15
# 2 2.178106e-01
# 3 2.653010e-09
# 4 4.431894e-16
# 5 1.723665e-23
# 6 6.231400e-01

# %%
dat = res_astarr
gpt = ggplot(dat, aes(x=log2FoldChange, y=-log10(padj))) + 
    geom_point(size=0.5, alpha=0.7) + 
    labs(title="ASTARR") +
    theme_cowplot()

options(repr.plot.width=8, repr.plot.height=6)
print(gpt)
# Out:
# plot without title

# %%
dat = res_wstarr
gpt = ggplot(dat, aes(x=log2FoldChange, y=-log10(padj))) + 
    geom_point(size=0.5, alpha=0.7) + 
    labs(title="WSTARR") +
    theme_cowplot()

options(repr.plot.width=8, repr.plot.height=6)
print(gpt)
# Out:
# Warning message:
# “Removed 4783 rows containing missing values (geom_point).”
# plot without title
