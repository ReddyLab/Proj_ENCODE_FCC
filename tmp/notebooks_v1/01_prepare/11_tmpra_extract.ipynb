# %% [markdown]
# **Set environment**

# %%
source ../config_duke.sh; show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_ENCODE_FCC/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# ## View Tiling MPRA data

# %%
FDIRY=${FD_RES}/source/syn26435687
FNAME=GATA-MYC_Tile_K562_K562_20210130.hg38.bed
head -3 ${FDIRY}/${FNAME}
# Out:
# chr	start	stop	id	score	strand	log2fc	input-count	output-count	log10pval	log10fdr	lfc-se
# 1	NA	NA	1:10437778:C:T:R:wC	.	+	2.38642090193675	883.092934703281	4616.08256005733	106.737138191871	105.572680362196	0.108372623188431
# 1	NA	NA	1:10451799:C:T:R:wC	.	+	0.163269738241717	404.448967317715	452.617975315935	0.695386164226944	0.506974721975921	0.127869739155127

# %% [markdown]
# **Region: GATA1**

# %%
FDIRY=${FD_RES}/source/syn26435687
FNAME=GATA-MYC_Tile_K562_K562_20210130.hg38.cleaned.GATA1.bed
head -5 ${FDIRY}/${FNAME}
# Out:
# chrX	47786401	47786600	X:47786401-47786600	.	+	2.30593934460149	2117.78684083014	10474.868702612	112.11265261617	110.931130790033	0.102147903305184
# chrX	47786451	47786650	X:47786451-47786650	.	+	0.783056057422144	1386.00739237509	2387.11896574661	11.3173883956403	10.6425168461249	0.113307047070907
# chrX	47786501	47786700	X:47786501-47786700	.	+	-0.128731962724311	1955.62553108109	1788.23614005802	0.845069660219201	0.628722618349189	0.0878596785422427
# chrX	47786551	47786750	X:47786551-47786750	.	+	0.588295148181817	2388.99664261419	3591.26381774846	11.2404554080035	10.5666788666818	0.0854366059937647
# chrX	47786601	47786800	X:47786601-47786800	.	+	0.0667001449192146	2102.91633517956	2202.38454860936	0.309589962802377	0.21047015199996	0.096677408925751

# %% [markdown]
# **Region: MYC**

# %%
FDIRY=${FD_RES}/source/syn26435687
FNAME=GATA-MYC_Tile_K562_K562_20210130.hg38.cleaned.MYC.bed
head -5 ${FDIRY}/${FNAME}
# Out:
# chr8	126735901	126736100	8:126735901-126736100	.	+	3.2160073089731	889.870007626957	8270.0812492101	284.968919800667	283.460926583012	0.0890350708144434
# chr8	126735951	126736150	8:126735951-126736150	.	+	2.7418446306345	125.834560461689	840.938846837603	113.688833083897	112.501493383409	0.12060330887403
# chr8	126736001	126736200	8:126736001-126736200	.	+	2.97274231280755	510.315518509142	4005.35667727079	184.577200225273	183.231899086814	0.102397694468983
# chr8	126736051	126736250	8:126736051-126736250	.	+	0.518237538807382	702.549323072363	1005.35942223587	5.59034059223642	5.03343239300409	0.110201760903996
# chr8	126736101	126736300	8:126736101-126736300	.	+	0.854181054733534	551.083056684629	995.469820297553	14.4458053269591	13.7295762580818	0.108553853362847

# %% [markdown]
# **Region: FADS**

# %%
FDIRY=${FD_RES}/source/syn22348180
FNAME=FADS_Tile_K562_K562_20200905.hg38.txt
head -5 ${FDIRY}/${FNAME}
# Out:
# chr	start	stop	id	score	strand	log2fc	input-count	output-count	log10pval	log10fdr	lfc-se	cigar	md-tag	project
# chr11	61787329	61787528	11:61554801-61555000	.	+	-0.85763898433268	539.06986501396	297.715189120701	0.931483643269041	0.434220074327503	0.547274403273541	200=	200	Tiles
# chr11	61787329	61787528	11:61554801-61555000_RC	.	-	-0.881673566105872	325.844662728475	176.742458595972	0.662985926208364	0.246985056545332	0.714599633819389	200=	200	Tiles
# chr11	61787334	61787533	11:61554806-61555005	.	+	-0.779124828017293	609.292251213609	355.039015219307	0.863277358508061	0.383434414853537	0.52393863052786	200=	200	Tiles
# chr11	61787334	61787533	11:61554806-61555005_RC	.	-	-0.831905443335537	336.926589204788	189.098087771129	0.278503265787216	0.0672740754748282	1.31386301202738	200=	200	Tiles

# %% [markdown]
# ## Extract fragment

# %% [markdown]
# **Region: GATA1**

# %%
FDIRY=${FD_RES}/source/syn26435687
FNAME=GATA-MYC_Tile_K562_K562_20210130.hg38.cleaned.GATA1.bed
FP_INP=${FDIRY}/${FNAME}

FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/fragment
FNAME=Tile_K562_hg38_20210130.GATA1.stranded_pos.bed
FP_OUT=${FDIRY}/${FNAME}

cat ${FP_INP} | cut -f 1-6 > ${FP_OUT}
head ${FP_OUT}
# Out:
# chrX	47786401	47786600	X:47786401-47786600	.	+
# chrX	47786451	47786650	X:47786451-47786650	.	+
# chrX	47786501	47786700	X:47786501-47786700	.	+
# chrX	47786551	47786750	X:47786551-47786750	.	+
# chrX	47786601	47786800	X:47786601-47786800	.	+
# chrX	47786651	47786850	X:47786651-47786850	.	+
# chrX	47786701	47786900	X:47786701-47786900	.	+
# chrX	47786751	47786950	X:47786751-47786950	.	+
# chrX	47786801	47787000	X:47786801-47787000	.	+
# chrX	47786851	47787050	X:47786851-47787050	.	+

# %% [markdown]
# **Region: MYC**

# %%
FDIRY=${FD_RES}/source/syn26435687
FNAME=GATA-MYC_Tile_K562_K562_20210130.hg38.cleaned.MYC.bed
FP_INP=${FDIRY}/${FNAME}

FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/fragment
FNAME=Tile_K562_hg38_20210130.MYC.stranded_pos.bed
FP_OUT=${FDIRY}/${FNAME}

cat ${FP_INP} | cut -f 1-6 > ${FP_OUT}
head ${FP_OUT}
# Out:
# chr8	126735901	126736100	8:126735901-126736100	.	+
# chr8	126735951	126736150	8:126735951-126736150	.	+
# chr8	126736001	126736200	8:126736001-126736200	.	+
# chr8	126736051	126736250	8:126736051-126736250	.	+
# chr8	126736101	126736300	8:126736101-126736300	.	+
# chr8	126736151	126736350	8:126736151-126736350	.	+
# chr8	126736201	126736400	8:126736201-126736400	.	+
# chr8	126736251	126736450	8:126736251-126736450	.	+
# chr8	126736301	126736500	8:126736301-126736500	.	+
# chr8	126736351	126736550	8:126736351-126736550	.	+

# %% [markdown]
# **Region: FADS**

# %%
FDIRY=${FD_RES}/source/syn22348180
FNAME=FADS_Tile_K562_K562_20200905.hg38.txt
FP_INP=${FDIRY}/${FNAME}

### postive strand
FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/fragment
FNAME=Tile_K562_hg38_20200905.FADS.stranded_pos.bed
FP_OUT=${FDIRY}/${FNAME}

cat ${FP_INP} |\
    tail -n +2 |\
    awk -v OFS='\t' {'if ($NF == "Tiles" && $6 == "+") {print}'} |\
    cut -f 1-6 > ${FP_OUT}
head ${FP_OUT}

echo ++++++++++++++++++++++++++++++++++++++++++++++++++++

### negative strand
FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/fragment
FNAME=Tile_K562_hg38_20200905.FADS.stranded_neg.bed
FP_OUT=${FDIRY}/${FNAME}

cat ${FP_INP} |\
    tail -n +2 |\
    awk -v OFS='\t' {'if ($NF == "Tiles" && $6 == "-") {print}'} |\
    cut -f 1-6 > ${FP_OUT}
head ${FP_OUT}
# Out:
# chr11	61787329	61787528	11:61554801-61555000	.	+
# chr11	61787334	61787533	11:61554806-61555005	.	+
# chr11	61787339	61787538	11:61554811-61555010	.	+
# chr11	61787344	61787543	11:61554816-61555015	.	+
# chr11	61787349	61787548	11:61554821-61555020	.	+
# chr11	61787354	61787553	11:61554826-61555025	.	+
# chr11	61787359	61787558	11:61554831-61555030	.	+
# chr11	61787364	61787563	11:61554836-61555035	.	+
# chr11	61787369	61787568	11:61554841-61555040	.	+
# chr11	61787374	61787573	11:61554846-61555045	.	+
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
# chr11	61787329	61787528	11:61554801-61555000_RC	.	-
# chr11	61787334	61787533	11:61554806-61555005_RC	.	-
# chr11	61787339	61787538	11:61554811-61555010_RC	.	-
# chr11	61787344	61787543	11:61554816-61555015_RC	.	-
# chr11	61787349	61787548	11:61554821-61555020_RC	.	-
# chr11	61787354	61787553	11:61554826-61555025_RC	.	-
# chr11	61787359	61787558	11:61554831-61555030_RC	.	-
# chr11	61787364	61787563	11:61554836-61555035_RC	.	-
# chr11	61787369	61787568	11:61554841-61555040_RC	.	-
# chr11	61787374	61787573	11:61554846-61555045_RC	.	-

# %% [markdown]
# ## Extract Count

# %% [markdown]
# **Region: GATA1**

# %%
FDIRY=${FD_RES}/source/syn26435687
FNAME=GATA-MYC_Tile_K562_K562_20210130.hg38.cleaned.GATA1.bed
FP_INP=${FDIRY}/${FNAME}

FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/count
FNAME=Tile_K562_hg38_20210130.GATA1.stranded_pos.bed
FP_OUT=${FDIRY}/${FNAME}

echo "Number of rows:     " $(cat ${FP_INP} | wc -l)
echo "Number of columns:  " $(awk '{print NF}' ${FP_INP} | sort -nu | tail -n 1)
echo "Number of Input 0:  " $(cat ${FP_INP} | awk -v OFS='\t' {'if ($8 == "0") {print}'} | wc -l)
echo "Number of Value NA :" $(cat ${FP_INP} | awk -v OFS='\t' {'if ($7 == "NA") {print}'} | wc -l)
echo ++++++++++++++++++++++++++++++++++++++++++++
cat ${FP_INP} | awk -v OFS='\t' {'if ($8 != "0") {print}'} > ${FP_OUT}
head ${FP_OUT}
# Out:
# Number of rows:      52312
# Number of columns:   12
# Number of Input 0:   14
# Number of Value NA : 0
# ++++++++++++++++++++++++++++++++++++++++++++
# chrX	47786401	47786600	X:47786401-47786600	.	+	2.30593934460149	2117.78684083014	10474.868702612	112.11265261617	110.931130790033	0.102147903305184
# chrX	47786451	47786650	X:47786451-47786650	.	+	0.783056057422144	1386.00739237509	2387.11896574661	11.3173883956403	10.6425168461249	0.113307047070907
# chrX	47786501	47786700	X:47786501-47786700	.	+	-0.128731962724311	1955.62553108109	1788.23614005802	0.845069660219201	0.628722618349189	0.0878596785422427
# chrX	47786551	47786750	X:47786551-47786750	.	+	0.588295148181817	2388.99664261419	3591.26381774846	11.2404554080035	10.5666788666818	0.0854366059937647
# chrX	47786601	47786800	X:47786601-47786800	.	+	0.0667001449192146	2102.91633517956	2202.38454860936	0.309589962802377	0.21047015199996	0.096677408925751
# chrX	47786651	47786850	X:47786651-47786850	.	+	-0.0296770285855712	1571.25883312174	1537.47500511577	0.10093990529751	0.0645309864135248	0.11287405577848
# chrX	47786701	47786900	X:47786701-47786900	.	+	-0.14075229487499	1203.48578659625	1091.84377528483	0.825108335723858	0.612237990840887	0.0976771932403185
# chrX	47786751	47786950	X:47786751-47786950	.	+	-0.0885922350756983	353.512101989425	332.442633189546	0.253160744492879	0.1696398049799	0.151330371648385
# chrX	47786801	47787000	X:47786801-47787000	.	+	0.0391523438172218	579.598940974745	594.330606996562	0.0990177524483432	0.0632252218092235	0.151540085938414
# chrX	47786851	47787050	X:47786851-47787050	.	+	-0.180031837594759	1441.753500779	1272.18932724085	0.993521192614518	0.751361305586954	0.109935692261477

# %% [markdown]
# **Region: MYC**

# %%
FDIRY=${FD_RES}/source/syn26435687
FNAME=GATA-MYC_Tile_K562_K562_20210130.hg38.cleaned.MYC.bed
FP_INP=${FDIRY}/${FNAME}

FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/count
FNAME=Tile_K562_hg38_20210130.MYC.stranded_pos.bed
FP_OUT=${FDIRY}/${FNAME}

echo "Number of rows:     " $(cat ${FP_INP} | wc -l)
echo "Number of columns:  " $(awk '{print NF}' ${FP_INP} | sort -nu | tail -n 1)
echo "Number of Input 0:  " $(cat ${FP_INP} | awk -v OFS='\t' {'if ($8 == "0") {print}'} | wc -l)
echo "Number of Value NA :" $(cat ${FP_INP} | awk -v OFS='\t' {'if ($7 == "NA") {print}'} | wc -l)
echo ++++++++++++++++++++++++++++++++++++++++++++
cat ${FP_INP} | awk -v OFS='\t' {'if ($8 != "0") {print}'} > ${FP_OUT}
head ${FP_OUT}
# Out:
# Number of rows:      41898
# Number of columns:   12
# Number of Input 0:   8
# Number of Value NA : 0
# ++++++++++++++++++++++++++++++++++++++++++++
# chr8	126735901	126736100	8:126735901-126736100	.	+	3.2160073089731	889.870007626957	8270.0812492101	284.968919800667	283.460926583012	0.0890350708144434
# chr8	126735951	126736150	8:126735951-126736150	.	+	2.7418446306345	125.834560461689	840.938846837603	113.688833083897	112.501493383409	0.12060330887403
# chr8	126736001	126736200	8:126736001-126736200	.	+	2.97274231280755	510.315518509142	4005.35667727079	184.577200225273	183.231899086814	0.102397694468983
# chr8	126736051	126736250	8:126736051-126736250	.	+	0.518237538807382	702.549323072363	1005.35942223587	5.59034059223642	5.03343239300409	0.110201760903996
# chr8	126736101	126736300	8:126736101-126736300	.	+	0.854181054733534	551.083056684629	995.469820297553	14.4458053269591	13.7295762580818	0.108553853362847
# chr8	126736151	126736350	8:126736151-126736350	.	+	-0.170536518919497	916.625712816023	814.060406737518	0.869176270302198	0.648678251321294	0.114140812593879
# chr8	126736201	126736400	8:126736201-126736400	.	+	-0.228389349286036	252.295210997601	215.270243875253	0.631792435759102	0.456673166036636	0.191682206789696
# chr8	126736251	126736450	8:126736251-126736450	.	+	-0.282547596063233	206.33956338419	169.445419693817	0.854670352603126	0.636650338189754	0.191330787603918
# chr8	126736301	126736500	8:126736301-126736500	.	+	0.341850449719078	225.170969884281	284.651952860765	1.22819243176126	0.950092596669581	0.181139132639869
# chr8	126736351	126736550	8:126736351-126736550	.	+	0.340369413983315	588.097277025173	745.181174540557	2.54673138133352	2.13394881164837	0.114042632145658

# %% [markdown]
# **FADS**

# %%
FDIRY=${FD_RES}/source/syn22348180
FNAME=FADS_Tile_K562_K562_20200905.hg38.txt
FP_INP=${FDIRY}/${FNAME}

### postive strand
FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/count
FNAME=Tile_K562_hg38_20200905.FADS.stranded_pos.bed
FP_OUT=${FDIRY}/${FNAME}

echo "Number of rows:     " $(cat ${FP_INP} | wc -l)
echo "Number of columns:  " $(awk '{print NF}' ${FP_INP} | sort -nu | tail -n 1)
echo "Number of Input 0:  " $(cat ${FP_INP} | awk -v OFS='\t' {'if ($8 == "0" ) {print}'} | wc -l)
echo "Number of Value NA :" $(cat ${FP_INP} | awk -v OFS='\t' {'if ($7 == "NA") {print}'} | wc -l)
echo ++++++++++++++++++++++++++++++++++++++++++++
cat ${FP_INP} |\
    tail -n +2 |\
    awk -v OFS='\t' {'if ($NF == "Tiles" && $6 == "+" && $7 != "NA" && $8 != "0") {print}'} |\
    cut -f 1-12 > ${FP_OUT}
head ${FP_OUT}

echo ============================================

### negative strand
FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/count
FNAME=Tile_K562_hg38_20200905.FADS.stranded_neg.bed
FP_OUT=${FDIRY}/${FNAME}

cat ${FP_INP} |\
    tail -n +2 |\
    awk -v OFS='\t' {'if ($NF == "Tiles" && $6 == "-" && $7 != "NA" && $8 != "0") {print}'} |\
    cut -f 1-12 > ${FP_OUT}
head ${FP_OUT}
# Out:
# Number of rows:      57011
# Number of columns:   15
# Number of Input 0:   39
# Number of Value NA : 539
# ++++++++++++++++++++++++++++++++++++++++++++
# chr11	61787329	61787528	11:61554801-61555000	.	+	-0.85763898433268	539.06986501396	297.715189120701	0.931483643269041	0.434220074327503	0.547274403273541
# chr11	61787334	61787533	11:61554806-61555005	.	+	-0.779124828017293	609.292251213609	355.039015219307	0.863277358508061	0.383434414853537	0.52393863052786
# chr11	61787339	61787538	11:61554811-61555010	.	+	-0.39640169893204	643.658290648892	489.535669788046	0.260937494339268	0.0622971516235022	0.660421157413616
# chr11	61787344	61787543	11:61554816-61555015	.	+	-0.489028709894157	564.827141504192	402.104987130375	0.512708372311238	0.161654577894315	0.478825704512005
# chr11	61787349	61787548	11:61554821-61555020	.	+	-0.589012981257324	573.688523074222	381.088870415759	0.653718918688817	0.240975448970365	0.482274017768384
# chr11	61787354	61787553	11:61554826-61555025	.	+	-0.886826947337017	385.0238526526	208.415928577797	0.701674002423147	0.272542705561603	0.690085981404518
# chr11	61787359	61787558	11:61554831-61555030	.	+	-1.23510375952542	438.427027998934	186.218491601184	0.476728356635425	0.143241969013808	1.27749356559374
# chr11	61787364	61787563	11:61554836-61555035	.	+	-1.16397283671082	416.886780957384	185.891438055511	0.431013114320826	0.122621342319342	1.30020879471098
# chr11	61787369	61787568	11:61554841-61555040	.	+	-0.430016148494686	479.861637704056	356.157119555091	0.48592792619196	0.147668226952405	0.438389366200442
# chr11	61787374	61787573	11:61554846-61555045	.	+	-0.0830757814539764	535.545670298258	505.632427338953	0.0519986117419171	0.0113863357614027	0.585452240588126
# ============================================
# chr11	61787329	61787528	11:61554801-61555000_RC	.	-	-0.881673566105872	325.844662728475	176.742458595972	0.662985926208364	0.246985056545332	0.714599633819389
# chr11	61787334	61787533	11:61554806-61555005_RC	.	-	-0.831905443335537	336.926589204788	189.098087771129	0.278503265787216	0.0672740754748282	1.31386301202738
# chr11	61787339	61787538	11:61554811-61555010_RC	.	-	-0.391323407285527	310.187693964429	236.290578726164	0.180792851064123	0.040252375782999	0.888120663288669
# chr11	61787344	61787543	11:61554816-61555015_RC	.	-	-0.768088636319577	580.395698972717	341.076247832192	1.08265326177516	0.551321581181327	0.442600043327791
# chr11	61787349	61787548	11:61554821-61555020_RC	.	-	-1.09307676068112	544.991456047723	255.805417713842	1.44627625104804	0.857793695448426	0.520676195746961
# chr11	61787354	61787553	11:61554826-61555025_RC	.	-	-0.443857128845408	386.633282271827	284.080875662447	0.398854325918082	0.109895132051638	0.526443108247893
# chr11	61787359	61787558	11:61554831-61555030_RC	.	-	0.0423291327351706	617.472038382845	635.432968670977	0.0424264472978934	0.00885749857894007	0.362058846287437
# chr11	61787364	61787563	11:61554836-61555035_RC	.	-	0.173368929947347	537.556351502236	605.493017932346	0.176969682277413	0.0389410334503899	0.400778474417306
# chr11	61787369	61787568	11:61554841-61555040_RC	.	-	0.442716843681015	382.796203754273	520.550443130582	0.550093762621701	0.18143664953187	0.411318813669237
# chr11	61787374	61787573	11:61554846-61555045_RC	.	-	-0.605622647013755	471.064685201544	309.652718060334	0.39747855491422	0.109288704883873	0.720240225332275
