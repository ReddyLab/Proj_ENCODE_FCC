# %% [markdown]
# **Set environment**

# %%
source ../config_duke.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_ENCODE_FCC/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %% [markdown]
# ## Alex folder for ENCODE FCC Capstone data

# %%
FD_ALEX=${FD_RLAB}/Alex/encode4_duke/ipynbs/jamborees/20211025_MPRA_STARR_Jamboree/data
ls ${FD_ALEX}
# Out:
# fads  gata1_myc

# %%
ls ${FD_ALEX}/gata1_myc
# Out:
# mpra  starrseq

# %%
ls ${FD_ALEX}/fads
# Out:
# mpra  starrseq

# %% [markdown]
# **STARR-seq**

# %%
ls ${FD_ALEX}/gata1_myc/starrseq
# Out:
# bams  bams.manifest.tsv  foo  fragments  fragments.manifest.tsv

# %%
ls ${FD_ALEX}/fads/starrseq
# Out:
# bams  fragments

# %% [markdown]
# ```
# stat -c "%y %N" ${FD_ALEX}/gata1_myc/starrseq/fragments/KS*Input*GATA1*unstranded*
# ```

# %%
ls ${FD_ALEX}/gata1_myc/starrseq/fragments
# Out:
# A001.K562.starrseq.GATA1.stranded.counts.txt
# A001.K562.starrseq.GATA1.unstranded.counts.txt
# A001.K562.starrseq.input.rep1.GATA1.fragment_counts.stranded.bed
# A001.K562.starrseq.input.rep1.GATA1.fragment_counts.unstranded.bed
# A001.K562.starrseq.input.rep1.MYC.fragment_counts.stranded.bed
# A001.K562.starrseq.input.rep1.MYC.fragment_counts.unstranded.bed
# A001.K562.starrseq.input.rep2.GATA1.fragment_counts.stranded.bed
# A001.K562.starrseq.input.rep2.GATA1.fragment_counts.unstranded.bed
# A001.K562.starrseq.input.rep2.MYC.fragment_counts.stranded.bed
# A001.K562.starrseq.input.rep2.MYC.fragment_counts.unstranded.bed
# A001.K562.starrseq.input.rep3.GATA1.fragment_counts.stranded.bed
# A001.K562.starrseq.input.rep3.GATA1.fragment_counts.unstranded.bed
# A001.K562.starrseq.input.rep3.MYC.fragment_counts.stranded.bed
# A001.K562.starrseq.input.rep3.MYC.fragment_counts.unstranded.bed
# A001.K562.starrseq.input.rep4.GATA1.fragment_counts.stranded.bed
# ...

# %%
ls ${FD_ALEX}/fads/starrseq/fragments
# Out:
# KS91_K562_hg38_ASTARRseq.FADS.stranded.counts.txt
# KS91_K562_hg38_ASTARRseq.FADS.unstranded.counts.txt
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.FADS.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.FADS.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.sorted.FADS.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.sorted.FADS.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep5.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# ...

# %% [markdown]
# ## Data of Keith's ATAC-STARR

# %% [markdown]
# ## Copy data

# %% [markdown]
# ```
# cp -r ${FD_ALEX}/mpra ${FD_RES}/source/
# cp ${FD_ALEX}/starrseq/fragments/KS* ${FD_RES}/source/starrseq
# ```

# %%
mkdir -p ${FD_RES}/source/starrseq_220510
cp ${FD_ALEX}/gata1_myc/starrseq/fragments/KS*sorted* ${FD_RES}/source/starrseq_220510
cp ${FD_ALEX}/fads/starrseq/fragments/KS*sorted*      ${FD_RES}/source/starrseq_220510

# %%
ls ${FD_RES}/source/starrseq_220510
# Out:
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.FADS.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.GATA1.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.GATA1.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.MYC.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.MYC.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.FADS.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.GATA1.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.GATA1.fragment_counts.unstranded.bed
# ...

# %%
ls ${FD_RES}/source/starrseq_220510
# Out:
# KS91_K562_hg38_ASTARRseq.FADS.stranded.counts.txt
# KS91_K562_hg38_ASTARRseq.FADS.unstranded.counts.txt
# KS91_K562_hg38_ASTARRseq.GATA1.stranded.counts.txt
# KS91_K562_hg38_ASTARRseq.GATA1.unstranded.counts.txt
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.GATA1.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.GATA1.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.MYC.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.MYC.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.FADS.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.FADS.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.GATA1.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.GATA1.fragment_counts.unstranded.bed
# ...

# %% [markdown]
# -----

# %% [markdown]
# ## Scratch

# %%
echo ${FD_ALEX}
# Out:
# /gpfs/fs1/data/reddylab/Alex/encode4_duke/ipynbs/jamborees/20211025_MPRA_STARR_Jamboree/data/gata1_myc

# %%
FD_ALEX=/data/reddylab/Alex/encode4_duke/processing/starr_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-umis

# %%
FDIRY=/data/reddylab/Alex/encode4_duke/processing/atac_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-blacklist-removal/merged2/
ls ${FDIRY}
# Out:
# fragments
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.sorted.bam
# ...

# %%
ls ${FDIRY}/fragments
# Out:
# A001.common_fragments.txt
# A001.f3q10.sorted.dups_marked.fragment_counts.stranded.bed
# A001.f3q10.sorted.dups_marked.fragment_counts.unstranded.bed
# A001.f3q10.sorted.dups_marked.fragment_counts.unstranded.simple_with_frag_length.bed
# A001-K562-rep2.f3q10.sorted.dups_marked.fragment_counts.stranded.bed
# A001-K562-rep2.f3q10.sorted.dups_marked.fragment_counts.unstranded.bed
# A001-K562-rep2.f3q10.sorted.dups_marked.fragment_counts.unstranded.simple_with_frag_length.bed
# common_fragments.txt
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.sorted.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.sorted.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.sorted.fragment_counts.unstranded.simple_with_frag_length.bed
# KS91_K562_hg38_ASTARRseq_Output_rep4.f3q10.sorted.with_umis.dups_marked.fragment_counts.stranded.bed
# ...

# %%
FDIRY=/data/reddylab/Alex/encode4_duke/processing/atac_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-blacklist-removal/merged2/
ls ${FDIRY}
# Out:
# fragments
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.sorted.bam
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.sorted.bam.bai
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.exclude_dups.cpm.bw
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dups_marked.sorted.bam
# ...

# %%
FDIRY=/data/reddylab/Alex/encode4_duke//processing/starr_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-umis
ls ${FDIRY}
# Out:
# by_chrom
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dedup.cpm.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_included.cpm.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked.bam.bai
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked.cpm.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked_peaks.narrowPeak
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked_peaks.xls
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dups_marked_summits.bed
# KS91_K562_hg38_ASTARRseq_Output_rep1.input_subtracted.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1.input_subtracted.pseudo_10.bw
# KS91_K562_hg38_ASTARRseq_Output_rep1_L001.bowtie2.log
# KS91_K562_hg38_ASTARRseq_Output_rep1_L001.f3q10.fragments.bedpe
# ...

# %%
FDIRY=/data/reddylab/Alex/encode4_duke//processing/starr_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-umis
ls ${FDIRY}/by_chrom
# Out:
# chr1   chr11  chr13  chr15  chr17  chr19  chr20  chr22  chr4  chr6  chr8  chrX
# chr10  chr12  chr14  chr16  chr18  chr2   chr21  chr3   chr5  chr7  chr9

# %%
FDIRY=/data/reddylab/Alex/encode4_duke//processing/starr_seq/210401_KS91_K562ASTARR_NovaSeq.hg38-pe-umis
ls ${FDIRY}/by_chrom/chrX
# Out:
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.chrX.bam
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.chrX.dedup_metrics.txt
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.chrX.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.chrX.dups_marked.bam.bai
# KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.sorted.with_umis.chrX.bam
# KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.sorted.with_umis.chrX.dedup_metrics.txt
# KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.sorted.with_umis.chrX.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.sorted.with_umis.chrX.dups_marked.bam.bai
# KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.sorted.with_umis.chrX.bam
# KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.sorted.with_umis.chrX.dedup_metrics.txt
# KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.sorted.with_umis.chrX.dups_marked.bam
# KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.sorted.with_umis.chrX.dups_marked.bam.bai
# ...

# %% [markdown]
# ****

# %%
head ${FD_ALEX}/KS91_K562_hg38_ASTARRseq_Output_rep1_L001.f3q10.fragments.bedpe
# Out:
# chr1	10287	10332
# chr1	10365	10449
# chr1	10389	10442
# chr1	14098	14507
# chr1	14098	14507
# chr1	14132	14498
# chr1	14134	14498
# chr1	14337	14545
# chr1	14491	14699
# chr1	15695	15896
