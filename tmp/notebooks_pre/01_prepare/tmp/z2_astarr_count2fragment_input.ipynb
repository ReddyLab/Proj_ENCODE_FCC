# %%
source ../config_duke.sh -v
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_ENCODE_FCC/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
ls ${FD_RES}
# Out:
# KS91_K562_ASTARRseq  regulatory_landscape  Tewhey_K562_TileMPRA
# log                  source                track_compare

# %%
ls ${FD_RES}/source/starrseq
# Out:
# KS91_K562_hg38_ASTARRseq.GATA1.stranded.counts.txt
# KS91_K562_hg38_ASTARRseq.GATA1.unstranded.counts.txt
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.GATA1.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.GATA1.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.MYC.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.MYC.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.GATA1.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.GATA1.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.MYC.fragment_counts.stranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dups_marked.MYC.fragment_counts.unstranded.bed
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dups_marked.GATA1.fragment_counts.stranded.bed
# ...

# %%
FD_INP=${FD_RES}/source/starrseq
FN_INP=KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.GATA1.fragment_counts.unstranded.bed

FD_OUT=${FD_RES}/KS91_K562_ASTARRseq/fragment
FN_OUT=KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bed

head ${FD_INP}/${FN_INP} | awk -v OFS='\t' {'print $1, $2, $3, $4'}
# Out:
# chrX	47787165	47787363	chrX_47787165_47787363
# chrX	47787557	47787773	chrX_47787557_47787773
# chrX	47787593	47787783	chrX_47787593_47787783
# chrX	47787598	47787772	chrX_47787598_47787772
# chrX	47787661	47788058	chrX_47787661_47788058
# chrX	47787743	47787849	chrX_47787743_47787849
# chrX	47787998	47788231	chrX_47787998_47788231
# chrX	47788008	47788157	chrX_47788008_47788157
# chrX	47788008	47788181	chrX_47788008_47788181
# chrX	47788140	47788547	chrX_47788140_47788547

# %%
FD_INP=${FD_RES}/source/starrseq
FN_INP=KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.MYC.fragment_counts.unstranded.bed

FD_OUT=${FD_RES}/KS91_K562_ASTARRseq/fragment
FN_OUT=KS91_K562_hg38_ASTARRseq_Input_rep1.MYC.unstranded.dedups.bed

head ${FD_INP}/${FN_INP} | awk -v OFS='\t' {'print $1, $2, $3, $4'}
# Out:
# chr8	126735990	126736404	chr8_126735990_126736404
# chr8	126736004	126736113	chr8_126736004_126736113
# chr8	126736010	126736129	chr8_126736010_126736129
# chr8	126736025	126736241	chr8_126736025_126736241
# chr8	126736083	126736313	chr8_126736083_126736313
# chr8	126736084	126736273	chr8_126736084_126736273
# chr8	126736091	126736259	chr8_126736091_126736259
# chr8	126736091	126736273	chr8_126736091_126736273
# chr8	126736094	126736199	chr8_126736094_126736199
# chr8	126736094	126736231	chr8_126736094_126736231

# %% [markdown]
# ## GATA1 region

# %%
sbatch -p ${NODE} \
    --mem 8G \
    --array 1-6 \
    -o ${FD_LOG}/ASTARR_count2fragment_input_GATA1.%a.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh
SAMPLE=Input
REPLICATE=rep${SLURM_ARRAY_TASK_ID}
REGION=GATA1

### set input and output
FD_INP=${FD_RES}/source/starrseq
FD_OUT=${FD_RES}/KS91_K562_ASTARRseq/fragment

FN_INP=KS91_K562_hg38_ASTARRseq_${SAMPLE}_${REPLICATE}.masked.dups_marked.${REGION}.fragment_counts.unstranded.bed
FN_OUT=KS91_K562_hg38_ASTARRseq_${SAMPLE}_${REPLICATE}.${REGION}.unstranded.dedups.bed

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### show input file
echo "INPUT FILE: ${FD_INP}/${FN_INP}"
head ${FD_INP}/${FN_INP}

### execution
cat ${FD_INP}/${FN_INP} | awk -v OFS='\t' {'print $1, $2, $3, $4'} > ${FD_OUT}/${FN_OUT}

### show output file
echo "OUTPUT FILE: ${FD_OUT}/${FN_OUT}"
head ${FD_OUT}/${FN_OUT}

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 28195046

# %% [markdown]
# ## MYC region

# %%
sbatch -p ${NODE} \
    --mem 8G \
    --array 1-6 \
    -o ${FD_LOG}/ASTARR_count2fragment_input_MYC.%a.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh
SAMPLE=Input
REPLICATE=rep${SLURM_ARRAY_TASK_ID}
REGION=MYC

### set input and output
FD_INP=${FD_RES}/source/starrseq
FD_OUT=${FD_RES}/KS91_K562_ASTARRseq/fragment

FN_INP=KS91_K562_hg38_ASTARRseq_${SAMPLE}_${REPLICATE}.masked.dups_marked.${REGION}.fragment_counts.unstranded.bed
FN_OUT=KS91_K562_hg38_ASTARRseq_${SAMPLE}_${REPLICATE}.${REGION}.unstranded.dedups.bed

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### show input file
echo "INPUT FILE: ${FD_INP}/${FN_INP}"
head ${FD_INP}/${FN_INP}

### execution
cat ${FD_INP}/${FN_INP} | awk -v OFS='\t' {'print $1, $2, $3, $4'} > ${FD_OUT}/${FN_OUT}

### show output file
echo "OUTPUT FILE: ${FD_OUT}/${FN_OUT}"
head ${FD_OUT}/${FN_OUT}

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 28195058

# %% [markdown]
# ## Check results

# %%
cat ${FD_LOG}/ASTARR_count2fragment_input_GATA1.*.txt
# Out:
# Slurm Array Index:  1
# Time Stamp:         04-29-22+12:34:37
#
# INPUT FILE: /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/starrseq/KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.GATA1.fragment_counts.unstranded.bed
# chrX	47787165	47787363	chrX_47787165_47787363	1	.
# chrX	47787557	47787773	chrX_47787557_47787773	2	.
# chrX	47787593	47787783	chrX_47787593_47787783	1	.
# chrX	47787598	47787772	chrX_47787598_47787772	1	.
# chrX	47787661	47788058	chrX_47787661_47788058	3	.
# chrX	47787743	47787849	chrX_47787743_47787849	2	.
# chrX	47787998	47788231	chrX_47787998_47788231	1	.
# chrX	47788008	47788157	chrX_47788008_47788157	1	.
# chrX	47788008	47788181	chrX_47788008_47788181	1	.
# chrX	47788140	47788547	chrX_47788140_47788547	1	.
# OUTPUT FILE: /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/KS91_K562_ASTARRseq/fragment/KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bed
# chrX	47787165	47787363	chrX_47787165_47787363
# ...

# %%
cat ${FD_LOG}/ASTARR_count2fragment_input_MYC.*.txt
# Out:
# Slurm Array Index:  1
# Time Stamp:         04-29-22+12:36:07
#
# INPUT FILE: /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/source/starrseq/KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dups_marked.MYC.fragment_counts.unstranded.bed
# chr8	126735990	126736404	chr8_126735990_126736404	1	.
# chr8	126736004	126736113	chr8_126736004_126736113	1	.
# chr8	126736010	126736129	chr8_126736010_126736129	2	.
# chr8	126736025	126736241	chr8_126736025_126736241	1	.
# chr8	126736083	126736313	chr8_126736083_126736313	1	.
# chr8	126736084	126736273	chr8_126736084_126736273	1	.
# chr8	126736091	126736259	chr8_126736091_126736259	3	.
# chr8	126736091	126736273	chr8_126736091_126736273	2	.
# chr8	126736094	126736199	chr8_126736094_126736199	1	.
# chr8	126736094	126736231	chr8_126736094_126736231	1	.
# OUTPUT FILE: /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc/KS91_K562_ASTARRseq/fragment/KS91_K562_hg38_ASTARRseq_Input_rep1.MYC.unstranded.dedups.bed
# ...
