# %% [markdown]
# **Set environment**

# %%
source ../config_duke.sh -v
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_ENCODE_FCC/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_encode_fcc

# %% [markdown]
# ## RUN

# %%
sbatch -p ${NODE} \
    --mem 10G \
    -o ${FD_LOG}/ASTARR_database_gata1_annotation.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### execution
${FD_PRJ}/sing_proj_encode_fcc.sh python astarr_gata1_table_annotation.py

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 27852451

# %% [markdown]
# ## Check

# %%
cat ${FD_LOG}/ASTARR_database_gata1_annotation.txt
# Out:
# Slurm Array Index:
# Time Stamp:         03-25-22+10:39:59
#
# You are on Duke Server: Singularity: Proj ENCODE FCC
# BASE DIRECTORY:     /mount/work
# PATH OF SOURCE:     /mount/work/source
# PATH OF EXECUTABLE: /mount/work/exe
# PATH OF ANNOTATION: /mount/work/annotation
# PATH OF PROJECT:    /mount/project
# PATH OF RESULTS:    /mount/work/out/proj_encode_fcc
#
# Global variables:
# Database:        /mount/work/out/proj_encode_fcc/KS91_K562_ASTARRseq/database/fragment_astarr_gata1.db
# Table directory: /mount/work/out/proj_encode_fcc/KS91_K562_ASTARRseq/annotation
#
# /mount/work/out/proj_encode_fcc/KS91_K562_ASTARRseq/annotation/KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bed.gz
# # Rows: 23826457
# /mount/work/out/proj_encode_fcc/KS91_K562_ASTARRseq/annotation/KS91_K562_hg38_ASTARRseq_Input_rep2.GATA1.unstranded.dedups.bed.gz
# # Rows: 31012918
# ...

# %%
cat ${FD_LOG}/ASTARR_database_gata1_annotation.txt
# Out:
# Slurm Array Index:
# Time Stamp:         03-25-22+10:32:59
#
# You are on Duke Server: Singularity: Proj ENCODE FCC
# BASE DIRECTORY:     /mount/work
# PATH OF SOURCE:     /mount/work/source
# PATH OF EXECUTABLE: /mount/work/exe
# PATH OF ANNOTATION: /mount/work/annotation
# PATH OF PROJECT:    /mount/project
# PATH OF RESULTS:    /mount/work/out/proj_encode_fcc
#
# Global variables:
# Database:        /mount/work/out/proj_encode_fcc/KS91_K562_ASTARRseq/database/fragment_astarr_gata1.db
# Table directory: /mount/work/out/proj_encode_fcc/KS91_K562_ASTARRseq/annotation
#
# /mount/work/out/proj_encode_fcc/KS91_K562_ASTARRseq/annotation/KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bed.gz
# ('chrX_47787165_47787363', 'chrX_47787180_47787190_FOX/8')
# ('chrX_47787165_47787363', 'chrX_47787182_47787192_HINFP1/1')
# ('chrX_47787165_47787363', 'chrX_47787194_47787216_ZNF146')
# +++++++++++++++
# ('chrX_47787165_47787363', 'chrX_47787196_47787211_NR/15')
# ...
