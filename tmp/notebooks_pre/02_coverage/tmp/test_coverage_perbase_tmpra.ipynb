# %%
source ../config_duke.sh
source ../config_load_module_bedtools.sh
show_env
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_ENCODE_FCC/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect_encode_fcc

# %%
ls ${FD_RES}/Tewhey_K562_TileMPRA/count
# Out:
# Tile_K562_20210130.GATA1.unstranded.bed
# Tile_K562_hg38_20210130.GATA1.bed
# Tile_K562_hg38_20210130.GATA1.count.bed
# Tile_K562_hg38_20210130.MYC.bed

# %%
head ${FD_RES}/Tewhey_K562_TileMPRA/count/Tile_K562_hg38_20210130.GATA1.count.bed
# Out:
# chrX	47786401	47786600	X:47786401-47786600	.	+	2.306	2117.787	10474.869
# chrX	47786451	47786650	X:47786451-47786650	.	+	0.783	1386.007	2387.119
# chrX	47786501	47786700	X:47786501-47786700	.	+	-0.129	1955.626	1788.236
# chrX	47786551	47786750	X:47786551-47786750	.	+	0.588	2388.997	3591.264
# chrX	47786601	47786800	X:47786601-47786800	.	+	0.067	2102.916	2202.385
# chrX	47786651	47786850	X:47786651-47786850	.	+	-0.03	1571.259	1537.475
# chrX	47786701	47786900	X:47786701-47786900	.	+	-0.141	1203.486	1091.844
# chrX	47786751	47786950	X:47786751-47786950	.	+	-0.089	353.512	332.443
# chrX	47786801	47787000	X:47786801-47787000	.	+	0.039	579.599	594.331
# chrX	47786851	47787050	X:47786851-47787050	.	+	-0.18	1441.754	1272.189

# %%
FP_INP=${FD_RES}/Tewhey_K562_TileMPRA/count/Tile_K562_hg38_20210130.GATA1.count.bed
FP_OUT=${FD_RES}/Tewhey_K562_TileMPRA/scratch/coverage/B.bed
head -2 ${FP_INP} > ${FP_OUT}
cat ${FP_OUT}
# Out:
# chrX	47786401	47786600	X:47786401-47786600	.	+	2.306	2117.787	10474.869
# chrX	47786451	47786650	X:47786451-47786650	.	+	0.783	1386.007	2387.119

# %%
START=47786400
END=47786650
CHROM=chrX

FP_OUT=${FD_RES}/Tewhey_K562_TileMPRA/scratch/coverage/A.bed
cat /dev/null > ${FP_OUT}
for LOC in $(seq ${START} ${END}); do
    echo -e "${CHROM}\\t${LOC}\\t$((${LOC} + 1))" >> ${FP_OUT}
done

head -n 5 ${FP_OUT}
echo ++++++++++++++++++++++
tail -n 5 ${FP_OUT}
# Out:
# chrX	47786400	47786401
# chrX	47786401	47786402
# chrX	47786402	47786403
# chrX	47786403	47786404
# chrX	47786404	47786405
# ++++++++++++++++++++++
# chrX	47786646	47786647
# chrX	47786647	47786648
# chrX	47786648	47786649
# chrX	47786649	47786650
# chrX	47786650	47786651

# %%
FDIRY=${FD_RES}/Tewhey_K562_TileMPRA/scratch/coverage

bedtools map -a ${FDIRY}/A.bed -b ${FDIRY}/B.bed -o mean -c 8 > ${FDIRY}/C.bed

# %%
python -c "x=(2117.787 + 1386.007)/2; print(x)"
# Out:
# 1751.897

# %%
cat ${FDIRY}/C.bed
# Out:
# chrX	47786400	47786401	.
# chrX	47786401	47786402	2117.787
# chrX	47786402	47786403	2117.787
# chrX	47786403	47786404	2117.787
# chrX	47786404	47786405	2117.787
# chrX	47786405	47786406	2117.787
# chrX	47786406	47786407	2117.787
# chrX	47786407	47786408	2117.787
# chrX	47786408	47786409	2117.787
# chrX	47786409	47786410	2117.787
# chrX	47786410	47786411	2117.787
# chrX	47786411	47786412	2117.787
# chrX	47786412	47786413	2117.787
# chrX	47786413	47786414	2117.787
# chrX	47786414	47786415	2117.787
# chrX	47786415	47786416	2117.787
# chrX	47786416	47786417	2117.787
# chrX	47786417	47786418	2117.787
# chrX	47786418	47786419	2117.787
# chrX	47786419	47786420	2117.787
# chrX	47786420	47786421	2117.787
# chrX	47786421	47786422	2117.787
# chrX	47786422	47786423	2117.787
# chrX	47786423	47786424	2117.787
# chrX	47786424	47786425	2117.787
# chrX	47786425	47786426	2117.787
# chrX	47786426	47786427	2117.787
# chrX	47786427	47786428	2117.787
# chrX	47786428	47786429	2117.787
# ...
