# %% [markdown]
# **Set environment**

# %%
suppressMessages(source("../config_sing.R"))
# Out:
# You are in Singularity: singularity_proj_combeffect
# BASE DIRECTORY:     /mount/work
# PATH OF SOURCE:     /mount/work/source
# PATH OF EXECUTABLE: /mount/work/exe
# PATH OF ANNOTATION: /mount/work/annotation
# PATH OF PROJECT:    /mount/project
# PATH OF RESULTS:    /mount/work/out/proj_combeffect_encode_fcc

# %%
fdiry = file.path(FD_RES, "KS91_K562_ASTARRseq", "coverage")
dir(fdiry)
# Out:
#  [1] "KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bin100.bed.gz"
#  [2] "KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bin1000.bed.gz"
#  [3] "KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bin200.bed.gz"
#  [4] "KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.bin500.bed.gz"
#  [5] "KS91_K562_hg38_ASTARRseq_Input_rep1.GATA1.unstranded.dedups.perbase.tsv.gz"
#  [6] "KS91_K562_hg38_ASTARRseq_Input_rep2.GATA1.unstranded.dedups.bin100.bed.gz"
#  [7] "KS91_K562_hg38_ASTARRseq_Input_rep2.GATA1.unstranded.dedups.bin1000.bed.gz"
#  [8] "KS91_K562_hg38_ASTARRseq_Input_rep2.GATA1.unstranded.dedups.bin200.bed.gz"
#  [9] "KS91_K562_hg38_ASTARRseq_Input_rep2.GATA1.unstranded.dedups.bin500.bed.gz"
# [10] "KS91_K562_hg38_ASTARRseq_Input_rep2.GATA1.unstranded.dedups.perbase.tsv.gz"
# [11] "KS91_K562_hg38_ASTARRseq_Input_rep3.GATA1.unstranded.dedups.bin100.bed.gz"
# [12] "KS91_K562_hg38_ASTARRseq_Input_rep3.GATA1.unstranded.dedups.bin1000.bed.gz"
# [13] "KS91_K562_hg38_ASTARRseq_Input_rep3.GATA1.unstranded.dedups.bin200.bed.gz"
# [14] "KS91_K562_hg38_ASTARRseq_Input_rep3.GATA1.unstranded.dedups.bin500.bed.gz"
# [15] "KS91_K562_hg38_ASTARRseq_Input_rep3.GATA1.unstranded.dedups.perbase.tsv.gz"
# [16] "KS91_K562_hg38_ASTARRseq_Input_rep4.GATA1.unstranded.dedups.bin100.bed.gz"
# [17] "KS91_K562_hg38_ASTARRseq_Input_rep4.GATA1.unstranded.dedups.bin1000.bed.gz"
# [18] "KS91_K562_hg38_ASTARRseq_Input_rep4.GATA1.unstranded.dedups.bin200.bed.gz"
# [19] "KS91_K562_hg38_ASTARRseq_Input_rep4.GATA1.unstranded.dedups.bin500.bed.gz"
# [20] "KS91_K562_hg38_ASTARRseq_Input_rep4.GATA1.unstranded.dedups.perbase.tsv.gz"
# [21] "KS91_K562_hg38_ASTARRseq_Input_rep5.GATA1.unstranded.dedups.bin100.bed.gz"
# [22] "KS91_K562_hg38_ASTARRseq_Input_rep5.GATA1.unstranded.dedups.bin1000.bed.gz"
# [23] "KS91_K562_hg38_ASTARRseq_Input_rep5.GATA1.unstranded.dedups.bin200.bed.gz"
# [24] "KS91_K562_hg38_ASTARRseq_Input_rep5.GATA1.unstranded.dedups.bin500.bed.gz"
# [25] "KS91_K562_hg38_ASTARRseq_Input_rep5.GATA1.unstranded.dedups.perbase.tsv.gz"
# [26] "KS91_K562_hg38_ASTARRseq_Input_rep6.GATA1.unstranded.dedups.bin100.bed.gz"
# [27] "KS91_K562_hg38_ASTARRseq_Input_rep6.GATA1.unstranded.dedups.bin1000.bed.gz"
# [28] "KS91_K562_hg38_ASTARRseq_Input_rep6.GATA1.unstranded.dedups.bin200.bed.gz"
# [29] "KS91_K562_hg38_ASTARRseq_Input_rep6.GATA1.unstranded.dedups.bin500.bed.gz"
# [30] "KS91_K562_hg38_ASTARRseq_Input_rep6.GATA1.unstranded.dedups.perbase.tsv.gz"
# [31] "KS91_K562_hg38_ASTARRseq_Output_rep1.GATA1.unstranded.bin100.bed.gz"
# [32] "KS91_K562_hg38_ASTARRseq_Output_rep1.GATA1.unstranded.bin1000.bed.gz"
# [33] "KS91_K562_hg38_ASTARRseq_Output_rep1.GATA1.unstranded.bin200.bed.gz"
# [34] "KS91_K562_hg38_ASTARRseq_Output_rep1.GATA1.unstranded.bin500.bed.gz"
# [35] "KS91_K562_hg38_ASTARRseq_Output_rep1.GATA1.unstranded.perbase.tsv.gz"
# [36] "KS91_K562_hg38_ASTARRseq_Output_rep2.GATA1.unstranded.bin100.bed.gz"
# [37] "KS91_K562_hg38_ASTARRseq_Output_rep2.GATA1.unstranded.bin1000.bed.gz"
# [38] "KS91_K562_hg38_ASTARRseq_Output_rep2.GATA1.unstranded.bin200.bed.gz"
# [39] "KS91_K562_hg38_ASTARRseq_Output_rep2.GATA1.unstranded.bin500.bed.gz"
# [40] "KS91_K562_hg38_ASTARRseq_Output_rep2.GATA1.unstranded.perbase.tsv.gz"
# [41] "KS91_K562_hg38_ASTARRseq_Output_rep3.GATA1.unstranded.bin100.bed.gz"
# [42] "KS91_K562_hg38_ASTARRseq_Output_rep3.GATA1.unstranded.bin1000.bed.gz"
# [43] "KS91_K562_hg38_ASTARRseq_Output_rep3.GATA1.unstranded.bin200.bed.gz"
# [44] "KS91_K562_hg38_ASTARRseq_Output_rep3.GATA1.unstranded.bin500.bed.gz"
# [45] "KS91_K562_hg38_ASTARRseq_Output_rep3.GATA1.unstranded.perbase.tsv.gz"
# [46] "KS91_K562_hg38_ASTARRseq_Output_rep4.GATA1.unstranded.bin100.bed.gz"
# [47] "KS91_K562_hg38_ASTARRseq_Output_rep4.GATA1.unstranded.bin1000.bed.gz"
# [48] "KS91_K562_hg38_ASTARRseq_Output_rep4.GATA1.unstranded.bin200.bed.gz"
# [49] "KS91_K562_hg38_ASTARRseq_Output_rep4.GATA1.unstranded.bin500.bed.gz"
# [50] "KS91_K562_hg38_ASTARRseq_Output_rep4.GATA1.unstranded.perbase.tsv.gz"
# [51] "KS91_K562_hg38_ASTARRseq_Ratio.GATA1.unstranded.perbase.tsv"
# [52] "region_GATA1_bin1.bed"
# [53] "region_GATA1_bin100.bed"
# [54] "region_GATA1_bin1000.bed"
# [55] "region_GATA1_bin200.bed"
# [56] "region_GATA1_bin500.bed"
# [57] "region_GATA1.bed"

# %%
fdiry = file.path(FD_RES, "KS91_K562_ASTARRseq", "fragment")
fname = "library_size.tsv"
fpath = file.path(fdiry, fname)
dat_lib = read_tsv(fpath, show_col_types = FALSE)
head(dat_lib)
# Out:
#   Sample     Group Replicate Size
# 1 Input_rep1 Input rep1      358823
# 2 Input_rep2 Input rep2      461577
# 3 Input_rep3 Input rep3      496229
# 4 Input_rep4 Input rep4      464845
# 5 Input_rep5 Input rep5      454013
# 6 Input_rep6 Input rep6      409058

# %%
### init: file directory
fdiry = file.path(FD_RES, "KS91_K562_ASTARRseq", "coverage")

### init: column names and types
ctypes = c(col_character(), col_integer(), col_integer(), col_integer())
cnames = c("Chrom", "Start", "End", "Depth")

### init
SIZES = c(100, 200, 500, 1000)

### loop: foreach size import data and summmarize the count of fragments
for (size in SIZES){
    
    ### INPUT: set sample group and number of replicates
    GROUP = "Input"
    REPLS = paste0("rep", 1:6)
     
    ### INPUT: import data
    lst_dat_inp = lapply(REPLS, function(repl){
        ### get sample file path
        sam   = paste(GROUP, repl, sep="_")
        fglob = paste0("*", sam, "*", "bin", size, ".bed.gz")
        fpath = Sys.glob(file.path(fdiry, fglob))
        
        ### read data
        dat = read_tsv(
            fpath, 
            col_types = ctypes, 
            col_names = cnames)
        dat$Sample = sam
        return(dat)
    })
    
    ### OUTPUT: set sample group and number of replicates
    GROUP = "Output"
    REPLS = paste0("rep", 1:4)

    ### OUTPUT: import data
    lst_dat_out = lapply(REPLS, function(repl){
        ### get sample file path
        sam   = paste(GROUP, repl, sep="_")
        fglob = paste0("*", sam, "*", "bin", size, ".bed.gz")
        fpath = Sys.glob(file.path(fdiry, fglob))
        
        ### read data
        dat = read_tsv(
            fpath, 
            col_types = ctypes, 
            col_names = cnames)
        dat$Sample = sam
        return(dat)
    })
    
    ### Combine input and output
    dat = bind_rows(lst_dat_inp, lst_dat_out) %>% 
        left_join(dat_lib, by="Sample") %>%
        mutate(Depth_Norm = Depth / Size)
    
    ### rearrange and save results
    dat = dat %>% dplyr::select(
        "Chrom",  "Start", "End", 
        "Sample", "Group", "Replicate", 
        "Depth",  "Size",  "Depth_Norm")
    
    fname = paste0(
        "KS91_K562_hg38_ASTARRseq_Depth.GATA1.unstranded.",
        "bin", size, 
        ".tsv")
    fpath = file.path(fdiry, fname)
    write_tsv(dat, fpath)
}

# %% [markdown]
# -----
