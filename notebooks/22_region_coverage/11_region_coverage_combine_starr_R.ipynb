# %% [raw]
# ---
# title: Region Coverage 11
# subtitle: Combine counts across samples and generate count matrix (STARR)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %%
txt_fdiry = file.path(FD_RES, "assay_fcc")
vec = dir(txt_fdiry)
for (txt in vec) {cat(txt, "\n")}
# Out:
# CRISPRi_FlowFISH_K562_Riley_JinWoo
# CRISPRi_Growth_K562_Gersbach_JinWoo
# MPRA_Lenti_K562_Nadav_Vikram
# MPRA_Tiling_K562_Tewhey_Hannah
# STARR_ATAC_K562_Reddy_KS274
# STARR_ATAC_K562_Reddy_KS91
# STARR_ATAC_K562_Reddy_KSMerge
# STARR_WHG_K562_Reddy_A001

# %% [markdown]
# ## Import region data

# %% [markdown]
# **Read region metadata table**

# %%
### set directory
txt_fdiry = file.path(FD_RES, "region", "summary")
txt_fname = "metadata.label.ocr.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

### read table
dat = read_tsv(txt_fpath, show_col_types = FALSE)

### assign and show
dat_meta_region = dat
fun_display_table(dat)
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Folder </th>
#    <th style="text-align:left;"> FName </th>
#    <th style="text-align:left;"> Label </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> encode_open_chromatin </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz </td>
#    <td style="text-align:left;"> dnase_ENCFF274YGF </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_open_chromatin </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz </td>
#    <td style="text-align:left;"> dnase_ENCFF185XRG </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_open_chromatin </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz </td>
#    <td style="text-align:left;"> atac_ENCFF558BLC </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_open_chromatin </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz </td>
#    <td style="text-align:left;"> atac_ENCFF925CYR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_open_chromatin </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz </td>
#    <td style="text-align:left;"> atac_ENCFF333TAT </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_open_chromatin </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz </td>
#    <td style="text-align:left;"> atac_ENCFF948AFM </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs </td>
#    <td style="text-align:left;"> K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs </td>
#    <td style="text-align:left;"> K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# **Create region list for looping**

# %%
dat = dat_meta_region
lst = split(dat$Folder, dat$Label)

lst_region = lst
print(lst)
# Out:
# $atac_ENCFF333TAT
# [1] "encode_open_chromatin"
#
# $atac_ENCFF558BLC
# [1] "encode_open_chromatin"
#
# $atac_ENCFF925CYR
# [1] "encode_open_chromatin"
#
# $atac_ENCFF948AFM
# [1] "encode_open_chromatin"
#
# $dnase_ENCFF185XRG
# [1] "encode_open_chromatin"
#
# $dnase_ENCFF274YGF
# [1] "encode_open_chromatin"
#
# $fcc_astarr_macs_input_overlap
# [1] "fcc_astarr_macs"
#
# $fcc_astarr_macs_input_union
# [1] "fcc_astarr_macs"

# %% [markdown]
# ## Loop through regions and assays to create count matrix

# %% [markdown]
# **Test loop**

# %%
### init: region folders
txt_fdiry = file.path(FD_RES, "region_coverage_fcc")
vec_txt_region = dir(txt_fdiry)
print(vec_txt_region)
cat("\n")

### pick one region for test loop
vec_txt_region = "fcc_astarr_macs_input_overlap"

### init: assay name
vec_txt_assay = c(
    "STARR_ATAC_K562_Reddy_KS91",
    "STARR_ATAC_K562_Reddy_KS274",
    "STARR_ATAC_K562_Reddy_KSMerge",
    "STARR_WHG_K562_Reddy_A001"
)

### loop
for (txt_region_label in vec_txt_region) {

    ### set directory for region description
    txt_region_folder = lst_region[[txt_region_label]]
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### get region description and set column names/types
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    vec = dat$Name
    vec_txt_cname = c(vec, "Count")
    vec_col_ctype = cols(Count = col_character())
    
    ### loop through each assay under each region
    for (txt_assay in vec_txt_assay) {

        ### set directory for assay metadata
        txt_fdiry = file.path(FD_RES, "assay_fcc", txt_assay, "fragment_counts", "summary")
        txt_fname = "metadata.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
    
        ### read metadata and setup sample names
        dat  = read_tsv(txt_fpath, show_col_types = FALSE)
        vec1 = dat$FName
        vec2 = dat$Sample
        dat_meta_assay = dat
        vec_txt_sample = setNames(vec1, vec2)

        ### set directory for assay counts
        txt_fdiry = file.path(
            FD_RES, 
            "region_coverage_fcc",
            txt_region_label,
            txt_assay,
            "overlap_count"
        )
        txt_fname = "*WGS*bed.gz"
        txt_fglob = file.path(txt_fdiry, txt_fname)

        ### get count files
        vec_txt_fpath = Sys.glob(txt_fglob)
        vec_txt_fname = basename(vec_txt_fpath)

        ### show progress:
        cat("\n====================\n")
        cat("Region Folder:", txt_region_folder, "\n")
        cat("Region Label: ", txt_region_label,  "\n")
        cat("Assay  Folder:", txt_assay,         "\n")
        cat("Import Counts:\n")
        print(vec_txt_fname)
        cat("\n")
        flush.console()
    }
}
# Out:
# [1] "atac_ENCFF333TAT"              "atac_ENCFF558BLC"
# [3] "atac_ENCFF925CYR"              "atac_ENCFF948AFM"
# [5] "dnase_ENCFF185XRG"             "dnase_ENCFF274YGF"
# [7] "fcc_astarr_macs_input_overlap" "fcc_astarr_macs_input_union"
#
#
# ====================
# Region Folder: fcc_astarr_macs
# Region Label:  fcc_astarr_macs_input_overlap
# Assay  Folder: STARR_ATAC_K562_Reddy_KS91
# Import Counts:
#  [1] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
#
# ====================
# Region Folder: fcc_astarr_macs
# Region Label:  fcc_astarr_macs_input_overlap
# Assay  Folder: STARR_ATAC_K562_Reddy_KS274
# Import Counts:
# [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
# [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
# [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
# [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
# [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
# [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
#
#
# ====================
# Region Folder: fcc_astarr_macs
# Region Label:  fcc_astarr_macs_input_overlap
# Assay  Folder: STARR_ATAC_K562_Reddy_KSMerge
# Import Counts:
#  [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [11] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [12] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [13] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
#
# ====================
# Region Folder: fcc_astarr_macs
# Region Label:  fcc_astarr_macs_input_overlap
# Assay  Folder: STARR_WHG_K562_Reddy_A001
# Import Counts:
# [1] "WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz"
# [2] "WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz"
# [3] "WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz"
# [4] "WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz"
# [5] "WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [6] "WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [7] "WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz"

# %% [markdown]
# **Define helper function**

# %%
fun = function(dat1, dat2){
    dat = dplyr::full_join(dat1, dat2, by = c("Chrom", "ChromStart", "ChromEnd", "Region"))
    return(dat)
}

# %% [markdown]
# **Generate count matrix for each region set for each assay**

# %%
### init: region folders
txt_fdiry = file.path(FD_RES, "region_coverage_fcc")
vec_txt_region = dir(txt_fdiry)
print(vec_txt_region)
cat("\n")

### init: assay name
vec_txt_assay = c(
    "STARR_ATAC_K562_Reddy_KS91",
    "STARR_ATAC_K562_Reddy_KS274",
    "STARR_ATAC_K562_Reddy_KSMerge",
    "STARR_WHG_K562_Reddy_A001"
)

### loop
for (txt_region_label in vec_txt_region) {

    ### set directory for region description
    txt_region_folder = lst_region[[txt_region_label]]
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### get region description and set column names/types
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    vec = dat$Name
    vec_txt_cname = c(vec, "Count")
    vec_col_ctype = cols(Count = col_character())
    
    ### loop through each assay under each region
    for (txt_assay in vec_txt_assay) {

        ### set directory for assay metadata
        txt_fdiry = file.path(FD_RES, "assay_fcc", txt_assay, "fragment_counts", "summary")
        txt_fname = "metadata.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
    
        ### read metadata and setup sample names
        dat  = read_tsv(txt_fpath, show_col_types = FALSE)
        vec1 = dat$FName
        vec2 = dat$Sample
        dat_meta_assay = dat
        vec_txt_sample = setNames(vec1, vec2)

        ### set directory for assay counts
        txt_fdiry = file.path(
            FD_RES, 
            "region_coverage_fcc",
            txt_region_label,
            txt_assay,
            "overlap_count"
        )
        txt_fname = "*WGS*bed.gz"
        txt_fglob = file.path(txt_fdiry, txt_fname)

        ### get count files
        vec_txt_fpath = Sys.glob(txt_fglob)
        vec_txt_fname = basename(vec_txt_fpath)

        ### show progress:
        cat("\n====================\n")
        cat("Region Folder:", txt_region_folder, "\n")
        cat("Region Label: ", txt_region_label,  "\n")
        cat("Assay  Folder:", txt_assay,         "\n")
        cat("Import Counts:\n")
        print(vec_txt_fname)
        cat("\n")
        flush.console()
        
        ### loop through count files and import them
        lst_dat = lapply(vec_txt_fpath, function(txt_fpath){

            ### read table
            dat = read_tsv(
                txt_fpath, 
                col_names = vec_txt_cname, 
                col_types = vec_col_ctype, 
                show_col_types = FALSE)

            ### arrange the columns
            dat = dat %>% 
                dplyr::select(Chrom, ChromStart, ChromEnd, Count) %>%
                dplyr::mutate(Region = paste0(Chrom, ":", ChromStart, "-", ChromEnd)) %>%
                dplyr::mutate(Count  = replace(Count, Count == ".", "0")) %>%
                dplyr::mutate(Count  = as.integer(Count)) %>%
                dplyr::select(Chrom, ChromStart, ChromEnd, Region, Count) %>%
                dplyr::distinct()

            ### rename column to include the file name
            txt_fname = basename(txt_fpath)
            vec = c("Chrom", "ChromStart", "ChromEnd", "Region", txt_fname)
            colnames(dat) = vec
            
            return(dat)
        })
        
        ### combine imported counts into a matrix
        dat_cnt = Reduce(fun, lst_dat)
        dat_cnt = dplyr::rename(dat_cnt, any_of(vec_txt_sample))
        
        ### filter out unaligned reigons
        mat_cnt = dat_cnt %>%
            dplyr::select(-Chrom, -ChromStart, -ChromEnd) %>%
            column_to_rownames(var = "Region")
        vec  = apply(mat_cnt, 1, sum)
        idx1 = (vec != 0)
        
        ### re-order columns: Input ---> Output
        vec  = colnames(mat_cnt)
        vec  = sort(vec)
        idx2 = c("Chrom", "ChromStart", "ChromEnd", "Region", vec)
        
        ### get the final count matrix
        dat_cnt = dat_cnt[idx1,idx2]

        ### combine count matrix and column data
        dat_col = dat_meta_assay %>% dplyr::filter(FName %in% vec_txt_fname)
        lst_dat = list(
            "data_cnt" = dat_cnt,
            "data_col" = dat_col
        )

        ### show progress
        cat("Removing zero:", "\n")
        cat("Before removing zero:", nrow(mat_cnt), "\n")
        cat("After  removing zero:", nrow(dat_cnt), "\n")
        cat("\n")
        flush.console()

        ### show progress
        cat("Save count matrix and data list.\n")
        flush.console()
        
        ### set directory for saving results
        txt_fdiry = file.path(
            FD_RES, "region_coverage_fcc",
            txt_region_label,
            txt_assay,
            "overlap_count",
            "summary"
        )
        txt_cmd = paste("mkdir -p", txt_fdiry)
        system(txt_cmd)

        ### save count matrix
        txt_fname = "matrix.count.raw.WGS.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
        cat(txt_fname, "\n")
        flush.console()
        
        dat = dat_cnt
        write_tsv(dat, txt_fpath)

        ### save data list
        txt_fname = "data.count_column.raw.WGS.rds"
        txt_fpath = file.path(txt_fdiry, txt_fname)
        cat(txt_fname, "\n")
        flush.console()
        
        obj = lst_dat
        saveRDS(obj, txt_fpath)

        ### show progress: matrix
        fun_display_table(head(dat_cnt, 3))
        fun_display_table(tail(dat_cnt, 3))
        cat("\n")
        flush.console()
    }
}
# Out:
# [1] "atac_ENCFF333TAT"              "atac_ENCFF558BLC"
# [3] "atac_ENCFF925CYR"              "atac_ENCFF948AFM"
# [5] "dnase_ENCFF185XRG"             "dnase_ENCFF274YGF"
# [7] "fcc_astarr_macs_input_overlap" "fcc_astarr_macs_input_union"
#
#
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF333TAT
# Assay  Folder: STARR_ATAC_K562_Reddy_KS91
# Import Counts:
#  [1] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 161693
# After  removing zero: 161187
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 40649 </td>
#    <td style="text-align:right;"> 41403 </td>
#    <td style="text-align:left;"> chr1:40649-41403 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 42030 </td>
#    <td style="text-align:right;"> 42399 </td>
#    <td style="text-align:left;"> chr1:42030-42399 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46255 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46255-47025 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156002261 </td>
#    <td style="text-align:right;"> 156002983 </td>
#    <td style="text-align:left;"> chrX:156002261-156002983 </td>
#    <td style="text-align:right;"> 645 </td>
#    <td style="text-align:right;"> 814 </td>
#    <td style="text-align:right;"> 928 </td>
#    <td style="text-align:right;"> 897 </td>
#    <td style="text-align:right;"> 829 </td>
#    <td style="text-align:right;"> 763 </td>
#    <td style="text-align:right;"> 116 </td>
#    <td style="text-align:right;"> 255 </td>
#    <td style="text-align:right;"> 207 </td>
#    <td style="text-align:right;"> 451 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156010068 </td>
#    <td style="text-align:right;"> 156011134 </td>
#    <td style="text-align:left;"> chrX:156010068-156011134 </td>
#    <td style="text-align:right;"> 68 </td>
#    <td style="text-align:right;"> 66 </td>
#    <td style="text-align:right;"> 92 </td>
#    <td style="text-align:right;"> 73 </td>
#    <td style="text-align:right;"> 77 </td>
#    <td style="text-align:right;"> 57 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 13 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156015981 </td>
#    <td style="text-align:right;"> 156017173 </td>
#    <td style="text-align:left;"> chrX:156015981-156017173 </td>
#    <td style="text-align:right;"> 210 </td>
#    <td style="text-align:right;"> 284 </td>
#    <td style="text-align:right;"> 298 </td>
#    <td style="text-align:right;"> 271 </td>
#    <td style="text-align:right;"> 273 </td>
#    <td style="text-align:right;"> 242 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 4 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF333TAT
# Assay  Folder: STARR_ATAC_K562_Reddy_KS274
# Import Counts:
# [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
# [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
# [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
# [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
# [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
# [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 161693
# After  removing zero: 161167
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 40649 </td>
#    <td style="text-align:right;"> 41403 </td>
#    <td style="text-align:left;"> chr1:40649-41403 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 42030 </td>
#    <td style="text-align:right;"> 42399 </td>
#    <td style="text-align:left;"> chr1:42030-42399 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46255 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46255-47025 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156002261 </td>
#    <td style="text-align:right;"> 156002983 </td>
#    <td style="text-align:left;"> chrX:156002261-156002983 </td>
#    <td style="text-align:right;"> 645 </td>
#    <td style="text-align:right;"> 814 </td>
#    <td style="text-align:right;"> 928 </td>
#    <td style="text-align:right;"> 897 </td>
#    <td style="text-align:right;"> 829 </td>
#    <td style="text-align:right;"> 763 </td>
#    <td style="text-align:right;"> 138 </td>
#    <td style="text-align:right;"> 108 </td>
#    <td style="text-align:right;"> 129 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156010068 </td>
#    <td style="text-align:right;"> 156011134 </td>
#    <td style="text-align:left;"> chrX:156010068-156011134 </td>
#    <td style="text-align:right;"> 68 </td>
#    <td style="text-align:right;"> 66 </td>
#    <td style="text-align:right;"> 92 </td>
#    <td style="text-align:right;"> 73 </td>
#    <td style="text-align:right;"> 77 </td>
#    <td style="text-align:right;"> 57 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156015981 </td>
#    <td style="text-align:right;"> 156017173 </td>
#    <td style="text-align:left;"> chrX:156015981-156017173 </td>
#    <td style="text-align:right;"> 210 </td>
#    <td style="text-align:right;"> 284 </td>
#    <td style="text-align:right;"> 298 </td>
#    <td style="text-align:right;"> 271 </td>
#    <td style="text-align:right;"> 273 </td>
#    <td style="text-align:right;"> 242 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF333TAT
# Assay  Folder: STARR_ATAC_K562_Reddy_KSMerge
# Import Counts:
#  [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [11] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [12] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [13] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 161693
# After  removing zero: 161187
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 40649 </td>
#    <td style="text-align:right;"> 41403 </td>
#    <td style="text-align:left;"> chr1:40649-41403 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 42030 </td>
#    <td style="text-align:right;"> 42399 </td>
#    <td style="text-align:left;"> chr1:42030-42399 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46255 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46255-47025 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156002261 </td>
#    <td style="text-align:right;"> 156002983 </td>
#    <td style="text-align:left;"> chrX:156002261-156002983 </td>
#    <td style="text-align:right;"> 645 </td>
#    <td style="text-align:right;"> 814 </td>
#    <td style="text-align:right;"> 928 </td>
#    <td style="text-align:right;"> 897 </td>
#    <td style="text-align:right;"> 829 </td>
#    <td style="text-align:right;"> 763 </td>
#    <td style="text-align:right;"> 116 </td>
#    <td style="text-align:right;"> 255 </td>
#    <td style="text-align:right;"> 207 </td>
#    <td style="text-align:right;"> 451 </td>
#    <td style="text-align:right;"> 138 </td>
#    <td style="text-align:right;"> 108 </td>
#    <td style="text-align:right;"> 129 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156010068 </td>
#    <td style="text-align:right;"> 156011134 </td>
#    <td style="text-align:left;"> chrX:156010068-156011134 </td>
#    <td style="text-align:right;"> 68 </td>
#    <td style="text-align:right;"> 66 </td>
#    <td style="text-align:right;"> 92 </td>
#    <td style="text-align:right;"> 73 </td>
#    <td style="text-align:right;"> 77 </td>
#    <td style="text-align:right;"> 57 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 13 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156015981 </td>
#    <td style="text-align:right;"> 156017173 </td>
#    <td style="text-align:left;"> chrX:156015981-156017173 </td>
#    <td style="text-align:right;"> 210 </td>
#    <td style="text-align:right;"> 284 </td>
#    <td style="text-align:right;"> 298 </td>
#    <td style="text-align:right;"> 271 </td>
#    <td style="text-align:right;"> 273 </td>
#    <td style="text-align:right;"> 242 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF333TAT
# Assay  Folder: STARR_WHG_K562_Reddy_A001
# Import Counts:
# [1] "WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz"
# [2] "WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz"
# [3] "WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz"
# [4] "WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz"
# [5] "WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [6] "WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [7] "WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 161693
# After  removing zero: 161124
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46255 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46255-47025 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 8 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 67629 </td>
#    <td style="text-align:right;"> 67864 </td>
#    <td style="text-align:left;"> chr1:67629-67864 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 68056 </td>
#    <td style="text-align:right;"> 68341 </td>
#    <td style="text-align:left;"> chr1:68056-68341 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 2 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrY </td>
#    <td style="text-align:right;"> 11098228 </td>
#    <td style="text-align:right;"> 11099023 </td>
#    <td style="text-align:left;"> chrY:11098228-11099023 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 26 </td>
#    <td style="text-align:right;"> 34 </td>
#    <td style="text-align:right;"> 35 </td>
#    <td style="text-align:right;"> 85 </td>
#    <td style="text-align:right;"> 76 </td>
#    <td style="text-align:right;"> 130 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrY </td>
#    <td style="text-align:right;"> 11103101 </td>
#    <td style="text-align:right;"> 11103309 </td>
#    <td style="text-align:left;"> chrY:11103101-11103309 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 8 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 10 </td>
#    <td style="text-align:right;"> 11 </td>
#    <td style="text-align:right;"> 27 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrY </td>
#    <td style="text-align:right;"> 12394949 </td>
#    <td style="text-align:right;"> 12395289 </td>
#    <td style="text-align:left;"> chrY:12394949-12395289 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF558BLC
# Assay  Folder: STARR_ATAC_K562_Reddy_KS91
# Import Counts:
#  [1] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 107082
# After  removing zero: 106688
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;">
</td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 6 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156016242 </td>
#    <td style="text-align:right;"> 156016999 </td>
#    <td style="text-align:left;"> chrX:156016242-156016999 </td>
#    <td style="text-align:right;"> 181 </td>
#    <td style="text-align:right;"> 243 </td>
#    <td style="text-align:right;"> 240 </td>
#    <td style="text-align:right;"> 230 </td>
#    <td style="text-align:right;"> 235 </td>
#    <td style="text-align:right;"> 215 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156029850 </td>
#    <td style="text-align:right;"> 156030236 </td>
#    <td style="text-align:left;"> chrX:156029850-156030236 </td>
#    <td style="text-align:right;"> 36 </td>
#    <td style="text-align:right;"> 39 </td>
#    <td style="text-align:right;"> 45 </td>
#    <td style="text-align:right;"> 30 </td>
#    <td style="text-align:right;"> 39 </td>
#    <td style="text-align:right;"> 34 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF558BLC
# Assay  Folder: STARR_ATAC_K562_Reddy_KSMerge
# Import Counts:
#  [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [11] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [12] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [13] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 107082
# After  removing zero: 106690
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10509 </td>
#    <td style="text-align:right;"> 10674 </td>
#    <td style="text-align:left;"> chr1:10509-10674 </td>
#    <td style="text-align:right;"> 21 </td>
#    <td style="text-align:right;"> 34 </td>
#    <td style="text-align:right;"> 35 </td>
#    <td style="text-align:right;"> 24 </td>
#    <td style="text-align:right;"> 37 </td>
#    <td style="text-align:right;"> 36 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 41987 </td>
#    <td style="text-align:right;"> 42385 </td>
#    <td style="text-align:left;"> chr1:41987-42385 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46755 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46755-47025 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156010065 </td>
#    <td style="text-align:right;"> 156010405 </td>
#    <td style="text-align:left;"> chrX:156010065-156010405 </td>
#    <td style="text-align:right;"> 66 </td>
#    <td style="text-align:right;"> 64 </td>
#    <td style="text-align:right;"> 81 </td>
#    <td style="text-align:right;"> 70 </td>
#    <td style="text-align:right;"> 71 </td>
#    <td style="text-align:right;"> 52 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 13 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 6 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156016242 </td>
#    <td style="text-align:right;"> 156016999 </td>
#    <td style="text-align:left;"> chrX:156016242-156016999 </td>
#    <td style="text-align:right;"> 181 </td>
#    <td style="text-align:right;"> 243 </td>
#    <td style="text-align:right;"> 240 </td>
#    <td style="text-align:right;"> 230 </td>
#    <td style="text-align:right;"> 235 </td>
#    <td style="text-align:right;"> 215 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156029850 </td>
#    <td style="text-align:right;"> 156030236 </td>
#    <td style="text-align:left;"> chrX:156029850-156030236 </td>
#    <td style="text-align:right;"> 36 </td>
#    <td style="text-align:right;"> 39 </td>
#    <td style="text-align:right;"> 45 </td>
#    <td style="text-align:right;"> 30 </td>
#    <td style="text-align:right;"> 39 </td>
#    <td style="text-align:right;"> 34 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF558BLC
# Assay  Folder: STARR_WHG_K562_Reddy_A001
# Import Counts:
# [1] "WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz"
# [2] "WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz"
# [3] "WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz"
# [4] "WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz"
# [5] "WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [6] "WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [7] "WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 107082
# After  removing zero: 106660
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10509 </td>
#    <td style="text-align:right;"> 10674 </td>
#    <td style="text-align:left;"> chr1:10509-10674 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46755 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46755-47025 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 6 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 68969 </td>
#    <td style="text-align:right;"> 69964 </td>
#    <td style="text-align:left;"> chr1:68969-69964 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 8 </td>
# ...
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16015 </td>
#    <td style="text-align:right;"> 16477 </td>
#    <td style="text-align:left;"> chr1:16015-16477 </td>
#    <td style="text-align:right;"> 141 </td>
#    <td style="text-align:right;"> 208 </td>
#    <td style="text-align:right;"> 206 </td>
#    <td style="text-align:right;"> 190 </td>
#    <td style="text-align:right;"> 202 </td>
#    <td style="text-align:right;"> 182 </td>
#    <td style="text-align:right;"> 15 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 6 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156016391 </td>
#    <td style="text-align:right;"> 156016836 </td>
#    <td style="text-align:left;"> chrX:156016391-156016836 </td>
#    <td style="text-align:right;"> 146 </td>
#    <td style="text-align:right;"> 197 </td>
#    <td style="text-align:right;"> 197 </td>
#    <td style="text-align:right;"> 186 </td>
#    <td style="text-align:right;"> 193 </td>
#    <td style="text-align:right;"> 178 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156024950 </td>
#    <td style="text-align:right;"> 156025593 </td>
#    <td style="text-align:left;"> chrX:156024950-156025593 </td>
#    <td style="text-align:right;"> 307 </td>
#    <td style="text-align:right;"> 381 </td>
#    <td style="text-align:right;"> 422 </td>
#    <td style="text-align:right;"> 418 </td>
#    <td style="text-align:right;"> 408 </td>
#    <td style="text-align:right;"> 350 </td>
#    <td style="text-align:right;"> 25 </td>
#    <td style="text-align:right;"> 19 </td>
#    <td style="text-align:right;"> 25 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156030187 </td>
#    <td style="text-align:right;"> 156030740 </td>
#    <td style="text-align:left;"> chrX:156030187-156030740 </td>
#    <td style="text-align:right;"> 164 </td>
#    <td style="text-align:right;"> 254 </td>
#    <td style="text-align:right;"> 249 </td>
#    <td style="text-align:right;"> 238 </td>
#    <td style="text-align:right;"> 236 </td>
#    <td style="text-align:right;"> 187 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: fcc_astarr_macs
# Region Label:  fcc_astarr_macs_input_union
# Assay  Folder: STARR_ATAC_K562_Reddy_KSMerge
# Import Counts:
#  [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [11] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [12] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [13] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 246852
# After  removing zero: 246852
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10015 </td>
#    <td style="text-align:right;"> 10442 </td>
#    <td style="text-align:left;"> chr1:10015-10442 </td>
#    <td style="text-align:right;"> 155 </td>
#    <td style="text-align:right;"> 214 </td>
#    <td style="text-align:right;"> 257 </td>
#    <td style="text-align:right;"> 236 </td>
#    <td style="text-align:right;"> 185 </td>
#    <td style="text-align:right;"> 214 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 12 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 11 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 14253 </td>
#    <td style="text-align:right;"> 14645 </td>
#    <td style="text-align:left;"> chr1:14253-14645 </td>
#    <td style="text-align:right;"> 110 </td>
#    <td style="text-align:right;"> 144 </td>
#    <td style="text-align:right;"> 160 </td>
#    <td style="text-align:right;"> 141 </td>
#    <td style="text-align:right;"> 130 </td>
#    <td style="text-align:right;"> 130 </td>
#    <td style="text-align:right;"> 8 </td>
#    <td style="text-align:right;"> 26 </td>
#    <td style="text-align:right;"> 30 </td>
#    <td style="text-align:right;"> 57 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 10 </td>
#    <td style="text-align:right;"> 9 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16015 </td>
#    <td style="text-align:right;"> 16477 </td>
#    <td style="text-align:left;"> chr1:16015-16477 </td>
#    <td style="text-align:right;"> 141 </td>
#    <td style="text-align:right;"> 208 </td>
#    <td style="text-align:right;"> 206 </td>
#    <td style="text-align:right;"> 190 </td>
#    <td style="text-align:right;"> 202 </td>
#    <td style="text-align:right;"> 182 </td>
#    <td style="text-align:right;"> 9 </td>
#    <td style="text-align:right;"> 9 </td>
#    <td style="text-align:right;"> 18 </td>
#    <td style="text-align:right;"> 23 </td>
#    <td style="text-align:right;"> 15 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 6 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156016391 </td>
#    <td style="text-align:right;"> 156016836 </td>
#    <td style="text-align:left;"> chrX:156016391-156016836 </td>
#    <td style="text-align:right;"> 146 </td>
#    <td style="text-align:right;"> 197 </td>
#    <td style="text-align:right;"> 197 </td>
#    <td style="text-align:right;"> 186 </td>
#    <td style="text-align:right;"> 193 </td>
#    <td style="text-align:right;"> 178 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156024950 </td>
#    <td style="text-align:right;"> 156025593 </td>
#    <td style="text-align:left;"> chrX:156024950-156025593 </td>
#    <td style="text-align:right;"> 307 </td>
#    <td style="text-align:right;"> 381 </td>
#    <td style="text-align:right;"> 422 </td>
#    <td style="text-align:right;"> 418 </td>
#    <td style="text-align:right;"> 408 </td>
#    <td style="text-align:right;"> 350 </td>
#    <td style="text-align:right;"> 20 </td>
#    <td style="text-align:right;"> 46 </td>
#    <td style="text-align:right;"> 43 </td>
#    <td style="text-align:right;"> 112 </td>
#    <td style="text-align:right;"> 25 </td>
#    <td style="text-align:right;"> 19 </td>
#    <td style="text-align:right;"> 25 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156030187 </td>
#    <td style="text-align:right;"> 156030740 </td>
#    <td style="text-align:left;"> chrX:156030187-156030740 </td>
#    <td style="text-align:right;"> 164 </td>
#    <td style="text-align:right;"> 254 </td>
#    <td style="text-align:right;"> 249 </td>
#    <td style="text-align:right;"> 238 </td>
#    <td style="text-align:right;"> 236 </td>
#    <td style="text-align:right;"> 187 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: fcc_astarr_macs
# Region Label:  fcc_astarr_macs_input_union
# Assay  Folder: STARR_WHG_K562_Reddy_A001
# Import Counts:
# [1] "WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz"
# [2] "WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz"
# [3] "WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz"
# [4] "WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz"
# [5] "WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [6] "WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [7] "WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz"
#
# Removing zero:
# Before removing zero: 246852
# After  removing zero: 246828
#
# Save count matrix and data list.
# matrix.count.raw.WGS.tsv
# data.count_column.raw.WGS.rds
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10015 </td>
#    <td style="text-align:right;"> 10442 </td>
#    <td style="text-align:left;"> chr1:10015-10442 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 14253 </td>
#    <td style="text-align:right;"> 14645 </td>
#    <td style="text-align:left;"> chr1:14253-14645 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16015 </td>
#    <td style="text-align:right;"> 16477 </td>
#    <td style="text-align:left;"> chr1:16015-16477 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 9 </td>
#    <td style="text-align:right;"> 12 </td>
#    <td style="text-align:right;"> 20 </td>
#    <td style="text-align:right;"> 14 </td>
#    <td style="text-align:right;"> 33 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156016391 </td>
#    <td style="text-align:right;"> 156016836 </td>
#    <td style="text-align:left;"> chrX:156016391-156016836 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 8 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 11 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156024950 </td>
#    <td style="text-align:right;"> 156025593 </td>
#    <td style="text-align:left;"> chrX:156024950-156025593 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 13 </td>
#    <td style="text-align:right;"> 19 </td>
#    <td style="text-align:right;"> 13 </td>
#    <td style="text-align:right;"> 38 </td>
#    <td style="text-align:right;"> 26 </td>
#    <td style="text-align:right;"> 82 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156030187 </td>
#    <td style="text-align:right;"> 156030740 </td>
#    <td style="text-align:left;"> chrX:156030187-156030740 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 2 </td>
#   </tr>
# </tbody>
# </table>

# %%
### get region folders
txt_fdiry = file.path(FD_RES, "region_coverage_fcc")
vec_txt_region = dir(txt_fdiry)
print(vec_txt_region)

### pick one region
vec_txt_region = "fcc_astarr_macs_input_overlap"
vec_txt_assay  = c(
    "STARR_ATAC_K562_Reddy_KS274",
    "STARR_ATAC_K562_Reddy_KS91", 
    "STARR_ATAC_K562_Reddy_KSMerge",
    "STARR_WHG_K562_Reddy_A001"
)

### loop
for (txt_region_label in vec_txt_region) {

    ### set directory for region description
    txt_region_folder = lst_region[[txt_region_label]]
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### get region description and set column names/types
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    vec = dat$Name
    vec_txt_cname = c(vec, "Count")
    vec_col_ctype = cols(Count = col_character())

    ### get assay folders
    txt_fdiry = file.path(FD_RES, "region_coverage_fcc", txt_region_label)
    vec_txt_assay = dir(txt_fdiry)
    
    ### loop through each assay under each region
    for (txt_assay in vec_txt_assay) {
        

        

        ### combine imported counts into a matrix
        dat_cnt = Reduce(fun, lst_dat)
        dat_cnt = dplyr::rename(dat_cnt, any_of(vec_txt_sample))
        
        ### filter out unaligned reigons
        mat_cnt = dat_cnt %>%
            dplyr::select(-Chrom, -ChromStart, -ChromEnd) %>%
            column_to_rownames(var = "Region")
        vec  = apply(mat_cnt, 1, sum)
        idx1 = (vec != 0)
        
        ### re-order columns: Input ---> Output
        vec  = colnames(mat_cnt)
        vec  = sort(vec)
        idx2 = c("Chrom", "ChromStart", "ChromEnd", "Region", vec)
        
        ### get the final count matrix
        dat_cnt = dat_cnt[idx1,idx2]

        ### combine count matrix and column data
        lst_dat = list(
            "data_cnt" = dat_cnt,
            "data_col" = dat_meta_assay)

        ### set directory for saving results
        txt_fdiry = file.path(
            FD_RES, "region_coverage_fcc",
            txt_region_label,
            txt_assay,
            "overlap_count",
            "summary"
        )
        txt_cmd = paste("mkdir -p", txt_fdiry)
        system(txt_cmd)

        ### save count matrix
        txt_fname = "matrix.raw.count.WGS.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
        
        dat = dat_cnt
        write_tsv(dat, txt_fpath)

        ### save data list
        txt_fname = "data_list_count_column.rds"
        txt_fpath = file.path(txt_fdiry, txt_fname)

        obj = lst_dat
        saveRDS(obj, txt_fpath)

        ### show progress: results
        cat("Save count matrix and data list.\n")
        flush.console()
        fun_display_table(head(dat_cnt))
        fun_display_table(tail(dat_cnt))
        cat("\n")
        flush.console()
    }
    cat("\n")
}
# Out:
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF333TAT
# Assay  Folder: STARR_ATAC_K562_Reddy_KS274
# Import Counts:
# [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
# [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
# [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
# [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
# [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
# [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
#
# Save count matrix and data list.
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 40649 </td>
#    <td style="text-align:right;"> 41403 </td>
#    <td style="text-align:left;"> chr1:40649-41403 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 42030 </td>
#    <td style="text-align:right;"> 42399 </td>
#    <td style="text-align:left;"> chr1:42030-42399 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46255 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46255-47025 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 67629 </td>
#    <td style="text-align:right;"> 67864 </td>
#    <td style="text-align:left;"> chr1:67629-67864 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 68056 </td>
#    <td style="text-align:right;"> 68341 </td>
#    <td style="text-align:left;"> chr1:68056-68341 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 68963 </td>
#    <td style="text-align:right;"> 70035 </td>
#    <td style="text-align:left;"> chr1:68963-70035 </td>
#    <td style="text-align:right;"> 24 </td>
#    <td style="text-align:right;"> 29 </td>
#    <td style="text-align:right;"> 20 </td>
#    <td style="text-align:right;"> 25 </td>
#    <td style="text-align:right;"> 23 </td>
#    <td style="text-align:right;"> 19 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;">
</td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156002261 </td>
#    <td style="text-align:right;"> 156002983 </td>
#    <td style="text-align:left;"> chrX:156002261-156002983 </td>
#    <td style="text-align:right;"> 645 </td>
#    <td style="text-align:right;"> 814 </td>
#    <td style="text-align:right;"> 928 </td>
#    <td style="text-align:right;"> 897 </td>
#    <td style="text-align:right;"> 829 </td>
#    <td style="text-align:right;"> 763 </td>
#    <td style="text-align:right;"> 116 </td>
#    <td style="text-align:right;"> 255 </td>
#    <td style="text-align:right;"> 207 </td>
#    <td style="text-align:right;"> 451 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156010068 </td>
#    <td style="text-align:right;"> 156011134 </td>
#    <td style="text-align:left;"> chrX:156010068-156011134 </td>
#    <td style="text-align:right;"> 68 </td>
#    <td style="text-align:right;"> 66 </td>
#    <td style="text-align:right;"> 92 </td>
#    <td style="text-align:right;"> 73 </td>
#    <td style="text-align:right;"> 77 </td>
#    <td style="text-align:right;"> 57 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 13 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;"> 156015981 </td>
#    <td style="text-align:right;"> 156017173 </td>
#    <td style="text-align:left;"> chrX:156015981-156017173 </td>
#    <td style="text-align:right;"> 210 </td>
#    <td style="text-align:right;"> 284 </td>
#    <td style="text-align:right;"> 298 </td>
#    <td style="text-align:right;"> 271 </td>
#    <td style="text-align:right;"> 273 </td>
#    <td style="text-align:right;"> 242 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 4 </td>
#   </tr>
# </tbody>
# </table>
# ====================
# Region Folder: encode_open_chromatin
# Region Label:  atac_ENCFF333TAT
# Assay  Folder: STARR_ATAC_K562_Reddy_KSMerge
# Import Counts:
#  [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
#  [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
#  [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
#  [4] "ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz"
#  [5] "ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz"
#  [6] "ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz"
#  [7] "ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz"
#  [8] "ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz"
#  [9] "ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz"
# [10] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [11] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [12] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [13] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
#
# Save count matrix and data list.
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 40649 </td>
#    <td style="text-align:right;"> 41403 </td>
#    <td style="text-align:left;"> chr1:40649-41403 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 42030 </td>
#    <td style="text-align:right;"> 42399 </td>
#    <td style="text-align:left;"> chr1:42030-42399 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 46255 </td>
#    <td style="text-align:right;"> 47025 </td>
#    <td style="text-align:left;"> chr1:46255-47025 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 67629 </td>
#    <td style="text-align:right;"> 67864 </td>
#    <td style="text-align:left;"> chr1:67629-67864 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 68056 </td>
#    <td style="text-align:right;"> 68341 </td>
#    <td style="text-align:left;"> chr1:68056-68341 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 68963 </td>
#    <td style="text-align:right;"> 70035 </td>
#    <td style="text-align:left;"> chr1:68963-70035 </td>
#    <td style="text-align:right;"> 24 </td>
#    <td style="text-align:right;"> 29 </td>
#    <td style="text-align:right;"> 20 </td>
#    <td style="text-align:right;"> 25 </td>
#    <td style="text-align:right;"> 23 </td>
#    <td style="text-align:right;"> 19 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input.rep1 </th>
#    <th style="text-align:right;"> Input.rep2 </th>
#    <th style="text-align:right;"> Input.rep3 </th>
#    <th style="text-align:right;"> Input.rep4 </th>
#    <th style="text-align:right;"> Input.rep5 </th>
#    <th style="text-align:right;"> Input.rep6 </th>
#    <th style="text-align:right;"> Output.rep1 </th>
#    <th style="text-align:right;"> Output.rep2 </th>
#    <th style="text-align:right;"> Output.rep3 </th>
#    <th style="text-align:right;"> Output.rep4 </th>
#    <th style="text-align:right;"> Output.rep5 </th>
#    <th style="text-align:right;"> Output.rep6 </th>
#    <th style="text-align:right;"> Output.rep7 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chrX </td>
#    <td style="text-align:right;">