# %% [raw]
# ---
# title: Region Coverage 01
# subtitle: Calculate coverage of given region set (STARR and Tiling MPRA)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif

# %% [markdown]
# ## Get data

# %%
### set directory
FDIRY=${FD_RES}/region/summary
FNAME=metadata.label.ocr.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label
# encode_open_chromatin	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# encode_open_chromatin	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
### Assay
ASSAY_TYPE=assay_fcc
ASSAY_NAMES=(
    MPRA_Tiling_K562_Tewhey_Hannah
)

# %%
### Assay
#ASSAY_TYPE=assay_fcc
#ASSAY_NAMES=(
#    STARR_ATAC_K562_Reddy_KS91
#    STARR_ATAC_K562_Reddy_KS274
#    STARR_ATAC_K562_Reddy_KSMerge
#    STARR_WHG_K562_Reddy_A001
#    MPRA_Tiling_K562_Tewhey_Hannah
#)

# %% [markdown]
# ## Check input

# %% [markdown]
# **Test loop: Region**

# %%
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### show progress
    echo ==============================
    echo "Region folder:" ${FOLDER_REG}
    echo "Region label: " ${LABEL_REG}
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_overlap
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union

# %%
cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}'
# Out:
# encode_open_chromatin	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# encode_open_chromatin	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %% [markdown]
# **Test loop: Assay**

# %%
for ASSAY_NAME in ${ASSAY_NAMES[@]}; do
    
    ### show progress
    echo ==============================
    echo "Assay name: " ${ASSAY_NAME}
    
    ### Set directory
    FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
    FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
    
    ### loop through each sample
    for FP_INP_B in ${FP_INPS[@]}; do
        FN_INP_B=$(basename ${FP_INP_B})
        echo ${FN_INP_B}
    done
    echo
done
# Out:
# ==============================
# Assay name:  MPRA_Tiling_K562_Tewhey_Hannah
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz

# %% [markdown]
# **Test loop: Region + Assay**

# %%
ls -d ${FD_RES}/region_coverage_fcc
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc/${LABEL_REG}/${ASSAY_NAME}/overlap_count
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt

# %% [markdown]
# ## Execute

# %% [markdown]
# **RUN**

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc/${LABEL_REG}/${ASSAY_NAME}/overlap_count
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo
            
            ### execute
            mkdir -p ${FD_OUT}
            sbatch -p ${NODE} \
                --exclude=dl-01 \
                --cpus-per-task 4 \
                --mem 10G \
                --output ${FP_LOG} \
                ${FD_EXE}/run_bedtools_coverage.sh ${FD_PRJ} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
            echo
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864331
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864332
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864333
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864334
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864335
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864336
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864337
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864338
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864339
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864340
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864341
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864342
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864343
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864344
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864345
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864346
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864347
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864348
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864349
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864350
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864351
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864352
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864353
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864354
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864355
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864356
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864357
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864358
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864359
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864360
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864361
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864362
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864363
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864364
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864365
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864366
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864367
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864368
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864369
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864370
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864371
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864372
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864373
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864374
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864375
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864376
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864377
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864378
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864379
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864380
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864381
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864382
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864383
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864384
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864385
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864386
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864387
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864388
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864389
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864390
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864391
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864392
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864393
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864394
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864395
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864396
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864397
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864398
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864399
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864400
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864401
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864402
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864403
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864404
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864405
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864406
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864407
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864408
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864409
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864410
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864411
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864412
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864413
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864414
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864415
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864416
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864417
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864418
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864419
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864420
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# ...
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864734
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864735
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864736
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864737
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864738
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864739
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864740
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864741
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864742
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864743
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864744
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864745
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864746
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864747
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864748
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864749
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864750
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864751
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864752
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864753
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864754
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864755
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864756
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864757
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864758
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864759
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864760
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864761
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30864762

# %% [markdown]
# ## Review

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/
FDIRY=${FDIRY}/dnase_ENCFF274YGF
FDIRY=${FDIRY}/MPRA_Tiling_K562_Tewhey_Hannah
FDIRY=${FDIRY}/overlap_count
ls ${FDIRY}
# Out:
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
# TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz

# %%
cat ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
# Out:
# Hostname:           x2-07-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         06-20-24+20:52:48
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_open_chromatin/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
#
# show first few lines of input
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/fragment_counts/TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# show first few lines of input
# chr11	61787329	61787528	chr11:61554801-61555000	532.18	+
# chr11	61787334	61787533	chr11:61554806-61555005	694.41	+
# chr11	61787339	61787538	chr11:61554811-61555010	648.371	+
# chr11	61787344	61787543	chr11:61554816-61555015	559.035	+
# chr11	61787349	61787548	chr11:61554821-61555020	623.708	+
# chr11	61787354	61787553	chr11:61554826-61555025	384.748	+
# chr11	61787359	61787558	chr11:61554831-61555030	357.344	+
# chr11	61787364	61787563	chr11:61554836-61555035	291.027	+
# chr11	61787369	61787568	chr11:61554841-61555040	536.564	+
# chr11	61787374	61787573	chr11:61554846-61555045	660.429	+
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Tiling_K562_Tewhey_Hannah/overlap_count/TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# show first few lines of output:
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75	.
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75	.
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75	.
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75	.
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75	.
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75	.
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75	.
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75	.
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75	.
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75	.
#
#
# Done!
# Run Time: 3 seconds

# %% [markdown]
# ## Review

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/STARR_ATAC_K562_Reddy_KS91/overlap_count
ls ${FDIRY}
# Out:
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/dnase_ENCFF274YGF/STARR_ATAC_K562_Reddy_KS91/overlap_count
ls -lh ${FDIRY}
# Out:
# total 16M
# -rw-rw-r-- 1 kk319 reddylab 1.6M May 31 12:34 ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.6M May 31 12:35 ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.6M May 31 12:35 ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.6M May 31 12:35 ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.6M May 31 12:35 ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.6M May 31 12:34 ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.5M May 31 12:30 ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.5M May 31 12:30 ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.5M May 31 12:30 ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 1.6M May 31 12:31 ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz

# %% [markdown]
# **Test loop: Region + Assay**

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=$(dirname ${FD_INP_B})
            FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_count
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" ${FN_LOG}
            echo
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# ...
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt

# %% [markdown]
# ## Execute

# %% [markdown]
# **RUN**

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=$(dirname ${FD_INP_B})
            FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_count
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" ${FN_LOG}
            echo
            
            ### execute
            mkdir -p ${FD_OUT}
            sbatch -p ${NODE} \
                --exclude=dl-01 \
                --cpus-per-task 4 \
                --mem 4G \
                --output ${FP_LOG} \
                ${FD_EXE}/run_bedtools_coverage.sh ${FD_PRJ} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
            echo
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761302
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761303
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761304
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761305
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761306
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761307
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761308
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761309
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761310
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761311
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761312
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761313
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761314
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761315
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761316
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761317
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761318
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761319
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761320
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761321
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761322
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761323
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761324
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761325
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761326
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761327
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761328
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761329
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761330
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761331
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761332
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761333
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761334
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761335
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761336
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761337
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761338
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761339
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761340
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761341
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761342
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761343
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761344
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761345
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761346
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761347
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761348
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761349
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761350
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761351
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761352
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761353
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761354
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761355
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761356
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761357
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761358
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL43_20221003.hg38.raw.Output.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761359
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761360
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761361
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761362
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761363
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761364
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761365
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761366
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761367
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761368
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761369
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761370
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761371
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761372
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761373
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761374
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count
# Output fname:  TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.dnase_ENCFF274YGF.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761375
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761376
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761377
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761378
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761379
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761380
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761381
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761382
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761383
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761384
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761385
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761386
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761387
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761388
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761389
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.dnase_ENCFF185XRG.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761390
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# ...
#
# Submitted batch job 30761833
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761834
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761835
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761836
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761837
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761838
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30761839
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761840
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761841
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761842
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761843
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761844
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761845
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761846
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.norm.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761847
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761848
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761849
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761850
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761851
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761852
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761853
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761854
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL13_20220512.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761855
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761856
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep2.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761857
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep3.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761858
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep4.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761859
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep5.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761860
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Input.rep6.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761861
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   MPRA_Tiling_K562_Tewhey_Hannah
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count
# Output fname:  TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz
#
# Log file: region.coverage.astarr_macs_input_union.TMPRA_K562_OL43_20221003.hg38.norm.Output.rep1.stranded_pos.bed.gz.txt
#
# Submitted batch job 30761862
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union

# %% [markdown]
# ## Check output

# %%
ls ${FD_RES}/assay_fcc/STARR*/coverage
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage:
# encode_open_chromatin  fcc_astarr_macs
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage:
# encode_open_chromatin  fcc_astarr_macs
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage:
# encode_open_chromatin  fcc_astarr_macs

# %%
ls ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/*/*
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT:
# overlap_count
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC:
# overlap_count
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR:
# overlap_count
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM:
# overlap_count
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG:
# overlap_count
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF:
# overlap_count
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap:
# overlap_count         overlap_fragment          overlap_fragment_unique
# overlap_count_unique  overlap_fragment_one2one
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union:
# overlap_count         overlap_fragment          overlap_fragment_unique
# overlap_count_unique  overlap_fragment_one2one

# %%
FDIRY=${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage
FDIRY=${FDIRY}/fcc_astarr_macs/astarr_macs_input_union
FDIRY=${FDIRY}/overlap_count

ls -lh ${FDIRY}
# Out:
# total 25M
# -rw-rw-r--  1 kk319 reddylab 2.4M Apr 17 10:32 ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.5M Apr 17 10:33 ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.5M Apr 17 10:33 ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.5M Apr 17 10:34 ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.5M Apr 17 10:34 ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.4M Apr 17 10:32 ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:27 ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:27 ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:28 ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.4M Apr 17 10:28 ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
# drwxrwsr-x+ 2 kk319 reddylab  512 Apr 11 11:08 summary

# %%
FDIRY=${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage
FDIRY=${FDIRY}/fcc_astarr_macs/astarr_macs_input_union
FDIRY=${FDIRY}/overlap_count
FDIRY=${FDIRY}/summary

ls -lh ${FDIRY}
# Out:
# total 29M
# -rw-rw-r-- 1 kk319 reddylab 8.1M Apr 18 10:27 data_list_count_column.rds
# -rw-rw-r-- 1 kk319 reddylab  20M Apr 18 10:27 matrix.raw.count.WGS.tsv

# %%
FDIRY=${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage
FDIRY=${FDIRY}/fcc_astarr_macs/astarr_macs_input_union
FDIRY=${FDIRY}/overlap_count

ls -lh ${FDIRY}
# Out:
# total 7.1M
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:27 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:27 ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:27 ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
# drwxrwsr-x+ 2 kk319 reddylab  512 Apr 11 14:52 summary

# %%
FDIRY=${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage
FDIRY=${FDIRY}/fcc_astarr_macs/astarr_macs_input_union
FDIRY=${FDIRY}/overlap_count
FDIRY=${FDIRY}/summary

ls -lh ${FDIRY}
# Out:
# total 19M
# -rw-rw-r-- 1 kk319 reddylab 4.9M Apr 18 10:27 data_list_count_column.rds
# -rw-rw-r-- 1 kk319 reddylab  14M Apr 18 10:27 matrix.raw.count.WGS.tsv

# %%
FDIRY=${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage
FDIRY=${FDIRY}/fcc_astarr_macs/astarr_macs_input_union
FDIRY=${FDIRY}/overlap_count

ls -lh ${FDIRY}
# Out:
# total 17M
# drwxrwsr-x+ 2 kk319 reddylab  512 Apr 11 11:08 summary
# -rw-rw-r--  1 kk319 reddylab 2.2M Apr 17 10:27 WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:28 WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:28 WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:28 WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.4M Apr 17 10:29 WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.3M Apr 17 10:29 WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
# -rw-rw-r--  1 kk319 reddylab 2.4M Apr 17 10:31 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz

# %%
FDIRY=${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage
FDIRY=${FDIRY}/fcc_astarr_macs/astarr_macs_input_union
FDIRY=${FDIRY}/overlap_count
FDIRY=${FDIRY}/summary

ls -lh ${FDIRY}
# Out:
# total 23M
# -rw-rw-r-- 1 kk319 reddylab 6.3M Apr 18 10:27 data_list_count_column.rds
# -rw-rw-r-- 1 kk319 reddylab  17M Apr 18 10:27 matrix.raw.count.WGS.tsv

# %% [markdown]
# **Check results (ASTARR)**

# %%
FN_LOG=region.coverage.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# Hostname:           x1-03-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-17-24+10:26:54
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10015	10442	155
# chr1	14253	14645	110
# chr1	16015	16477	141
# chr1	17237	17772	259
# chr1	28903	29613	263
# chr1	30803	31072	82
# chr1	101603	101849	73
# chr1	115411	115986	951
# chr1	118518	118743	85
# chr1	136071	137429	1465
#
#
# Done!
# Run Time: 5 minutes and 48 seconds

# %%
FN_LOG=region.coverage.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# Hostname:           x2-04-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-11-24+10:09:05
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10015	10442	155
# chr1	14253	14645	110
# chr1	16015	16477	141
# chr1	17237	17772	259
# chr1	28903	29613	263
# chr1	30803	31072	82
# chr1	101603	101849	73
# chr1	115411	115986	951
# chr1	118518	118743	85
# chr1	136071	137429	1465
#
#
# Done!
# Run Time: 5 minutes and 54 seconds

# %%
FN_LOG=region.coverage.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# Hostname:           x2-03-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-11-24+10:08:49
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_open_chromatin/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
#
# show first few lines of input
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75	166
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75	3014
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75	1137
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75	2402
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75	448
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75	880
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75	31
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75	157
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75	85
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75	133
#
#
# Done!
# Run Time: 6 minutes and 28 seconds

# %%
FN_LOG=region.coverage.astarr_macs_input_union.ASTARRseq_K562_KS279.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# cat: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log/region.coverage.astarr_macs_input_union.ASTARRseq_K562_KS279.hg38.Input.rep1.WGS.unstranded.bed.gz.txt: No such file or directory
# : 1

# %% [markdown]
# **Check results (WSTARR)**

# %%
FN_LOG=region.coverage.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# Hostname:           x2-05-4
# Slurm Array Index:
# Time Stamp:         04-11-24+10:09:06
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10335	10549	chr1_10335_10549	1	.
# chr1	16983	17500	chr1_16983_17500	1	.
# chr1	16985	17499	chr1_16985_17499	1	.
# chr1	17004	17500	chr1_17004_17500	1	.
# chr1	17483	17898	chr1_17483_17898	1	.
# chr1	17487	17941	chr1_17487_17941	1	.
# chr1	33606	33997	chr1_33606_33997	1	.
# chr1	33617	33997	chr1_33617_33997	1	.
# chr1	38785	39226	chr1_38785_39226	1	.
# chr1	46328	46678	chr1_46328_46678	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10015	10442	1
# chr1	14253	14645	.
# chr1	16015	16477	.
# chr1	17237	17772	5
# chr1	28903	29613	.
# chr1	30803	31072	.
# chr1	101603	101849	.
# chr1	115411	115986	.
# chr1	118518	118743	.
# chr1	136071	137429	3
#
#
# Done!
# Run Time: 25 seconds

# %%
FN_LOG=region.coverage.dnase_ENCFF274YGF.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# Hostname:           x2-02-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-11-24+10:08:52
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_open_chromatin/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
#
# show first few lines of input
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10335	10549	chr1_10335_10549	1	.
# chr1	16983	17500	chr1_16983_17500	1	.
# chr1	16985	17499	chr1_16985_17499	1	.
# chr1	17004	17500	chr1_17004_17500	1	.
# chr1	17483	17898	chr1_17483_17898	1	.
# chr1	17487	17941	chr1_17487_17941	1	.
# chr1	33606	33997	chr1_33606_33997	1	.
# chr1	33617	33997	chr1_33617_33997	1	.
# chr1	38785	39226	chr1_38785_39226	1	.
# chr1	46328	46678	chr1_46328_46678	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_count/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75	3
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75	10
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75	8
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75	10
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75	7
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75	9
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75	2
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75	7
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75	4
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75	10
#
#
# Done!
# Run Time: 25 seconds

# %% [markdown]
# **Check results (TMPRA)**

# %%
FN_LOG=region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# Hostname:           x1-03-4.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-11-24+10:09:08
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/fragment_counts/TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# show first few lines of input
# chr11	4505501	4505700	chr11:4505501-4505700	714	+
# chr11	4505601	4505800	chr11:4505601-4505800	395	+
# chr11	4505701	4505900	chr11:4505701-4505900	291	+
# chr11	4505801	4506000	chr11:4505801-4506000	406	+
# chr11	4505901	4506100	chr11:4505901-4506100	179	+
# chr11	4506001	4506200	chr11:4506001-4506200	383	+
# chr11	4506101	4506300	chr11:4506101-4506300	476	+
# chr11	4506201	4506400	chr11:4506201-4506400	903	+
# chr11	4506301	4506500	chr11:4506301-4506500	615	+
# chr11	4506401	4506600	chr11:4506401-4506600	160	+
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count/TMPRA_K562_OL45_20220927.hg38.raw.Output.rep4.stranded_pos.bed.gz
#
# show first few lines of output:
# chr1	10015	10442	.
# chr1	14253	14645	.
# chr1	16015	16477	.
# chr1	17237	17772	.
# chr1	28903	29613	.
# chr1	30803	31072	.
# chr1	101603	101849	.
# chr1	115411	115986	.
# chr1	118518	118743	.
# chr1	136071	137429	.
#
#
# Done!
# Run Time: 0 seconds

# %%
FN_LOG=region.coverage.astarr_macs_input_union.TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz.txt
cat ${FD_LOG}/${FN_LOG}
# Out:
# Hostname:           x1-01-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-11-24+10:09:08
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/fragment_counts/TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# show first few lines of input
# chr11	4505501	4505700	chr11:4505501-4505700	815	+
# chr11	4505601	4505800	chr11:4505601-4505800	551	+
# chr11	4505701	4505900	chr11:4505701-4505900	371	+
# chr11	4505801	4506000	chr11:4505801-4506000	812	+
# chr11	4505901	4506100	chr11:4505901-4506100	280	+
# chr11	4506001	4506200	chr11:4506001-4506200	473	+
# chr11	4506101	4506300	chr11:4506101-4506300	1037	+
# chr11	4506201	4506400	chr11:4506201-4506400	1137	+
# chr11	4506301	4506500	chr11:4506301-4506500	760	+
# chr11	4506401	4506600	chr11:4506401-4506600	387	+
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Tiling_K562_Tewhey_Hannah/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_count/TMPRA_K562_OL45_20220927.hg38.raw.Input.rep4.stranded_pos.bed.gz
#
# show first few lines of output:
# chr1	10015	10442	.
# chr1	14253	14645	.
# chr1	16015	16477	.
# chr1	17237	17772	.
# chr1	28903	29613	.
# chr1	30803	31072	.
# chr1	101603	101849	.
# chr1	115411	115986	.
# chr1	118518	118743	.
# chr1	136071	137429	.
#
#
# Done!
# Run Time: 0 seconds
