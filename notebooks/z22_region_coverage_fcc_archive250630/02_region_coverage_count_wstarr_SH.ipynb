# %% [raw]
# ---
# title: Region Coverage 01
# subtitle: Calculate coverage of given region set (STARR and Tiling MPRA)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# ## Get data

# %%
### set directory
FDIRY=${FD_RES}/region/summary
FNAME=metadata.label.region_for_analysis.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label	FPath
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz

# %%
cat ${FP_REGION_LABEL} | cut -f 1-3
# Out:
# Folder	FName	Label
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM

# %%
### Assay
ASSAY_TYPE=assay_fcc
ASSAY_NAMES=(
    STARR_WHG_K562_Reddy_A001
)

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loop: Region**

# %%
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### show progress
    echo ==============================
    echo "Region folder:" ${FOLDER_A}
    echo "Region label: " ${LABEL_A}
    
    ### Set directory
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM

# %%
cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}'
# Out:
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz

# %% [markdown]
# **Test loop: Assay**

# %%
for ASSAY_NAME in ${ASSAY_NAMES[@]}; do
    
    ### show progress
    echo ==============================
    echo "Assay name: " ${ASSAY_NAME}
    
    ### Set directory
    FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
    FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
    
    ### loop through each sample
    for FP_INP_B in ${FP_INPS[@]}; do
        FN_INP_B=$(basename ${FP_INP_B})
        echo ${FN_INP_B}
    done
    echo
done
# Out:
# ==============================
# Assay name:  STARR_WHG_K562_Reddy_A001
# WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz

# %% [markdown]
# **Test loop: Region + Assay**

# %%
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### set input file
    FD_INP_A=$(dirname ${FPATH_A})
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        #FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep1*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
        
            ### set input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc/${LABEL_A}/${ASSAY_NAME}/overlap_count
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_A}.${ASSAY_NAME}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_A}
            echo "Region label: " ${LABEL_A}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Input fdiry:  " ${FD_INP_A/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_A}
            echo "Input fdiry:  " ${FD_INP_B/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_B}
            echo
            echo "Output fdiry: " ${FD_OUT/${FD_RES}/'${FD_RES}'}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo
        done
    done
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)    
#done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt

# %% [markdown]
# ## Execute

# %% [markdown]
# **Check**

# %%
echo ${FP_CNF}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **RUN**

# %%
### init: set executable
FN_EXE="run_bedtools_coverage.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### Execute
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### set input file
    FD_INP_A=$(dirname ${FPATH_A})
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
        #FP_INPS=($(ls ${FD_INP_B}/*hg38*rep1*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
        
            ### set input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc/${LABEL_A}/${ASSAY_NAME}/overlap_count
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_A}.${ASSAY_NAME}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_A}
            echo "Region label: " ${LABEL_A}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Input fdiry:  " ${FD_INP_A/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_A}
            echo "Input fdiry:  " ${FD_INP_B/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_B}
            echo
            echo "Output fdiry: " ${FD_OUT/${FD_RES}/'${FD_RES}'}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo

            ### execute
            mkdir -p ${FD_OUT}
            sbatch \
                --cpus-per-task 4 \
                --mem 10G \
                --output ${FP_LOG} \
                ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
            echo
        done
    done
#done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291721
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291722
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291723
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291724
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291725
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291726
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291727
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291728
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291729
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291730
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291731
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291732
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291733
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291734
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291735
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291736
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291737
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291738
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291739
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291740
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291741
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291742
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291743
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291744
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291745
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291746
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291747
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291748
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291749
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291750
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291751
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291752
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291753
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291754
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291755
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291756
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291757
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291758
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291759
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291760
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291761
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291762
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291763
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291764
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291765
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291766
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291767
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291768
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291769
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291770
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291771
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291772
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291773
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291774
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291775
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
# Input fname:   WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 291776

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-03
# Slurm Array Index:
# Time Stamp:         06-29-25+11:56:09
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10335	10549	chr1_10335_10549	1	.
# chr1	16983	17500	chr1_16983_17500	1	.
# chr1	16985	17499	chr1_16985_17499	1	.
# chr1	17004	17500	chr1_17004_17500	1	.
# chr1	17483	17898	chr1_17483_17898	1	.
# chr1	17487	17941	chr1_17487_17941	1	.
# chr1	33606	33997	chr1_33606_33997	1	.
# chr1	33617	33997	chr1_33617_33997	1	.
# chr1	38785	39226	chr1_38785_39226	1	.
# chr1	46328	46678	chr1_46328_46678	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_overlap/STARR_WHG_K562_Reddy_A001/overlap_count/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10038	10405	chr1:10038-10405	.
# chr1	14282	14614	chr1:14282-14614	.
# chr1	16025	16338	chr1:16025-16338	.
# chr1	17288	17689	chr1:17288-17689	5
# chr1	28934	29499	chr1:28934-29499	.
# chr1	115429	115969	chr1:115429-115969	.
# chr1	136201	137353	chr1:136201-137353	3
# chr1	137748	138049	chr1:137748-138049	1
# chr1	138321	139517	chr1:138321-139517	12
# chr1	181005	181854	chr1:181005-181854	7
#
#
# Done!
# Run Time: 12 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-05
# Slurm Array Index:
# Time Stamp:         06-29-25+11:56:09
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
#
# show first few lines of input
# chr1	778328	779235	chr1:778328-779235
# chr1	817237	818202	chr1:817237-818202
# chr1	826647	828124	chr1:826647-828124
# chr1	842282	843322	chr1:842282-843322
# chr1	869581	870256	chr1:869581-870256
# chr1	898813	899211	chr1:898813-899211
# chr1	904068	905212	chr1:904068-905212
# chr1	906791	907164	chr1:906791-907164
# chr1	911094	911500	chr1:911094-911500
# chr1	912934	913144	chr1:912934-913144
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts/WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10537	11067	chr1_10537_11067	1	.
# chr1	14408	14799	chr1_14408_14799	1	.
# chr1	14498	14937	chr1_14498_14937	1	.
# chr1	14676	15184	chr1_14676_15184	1	.
# chr1	14684	15162	chr1_14684_15162	1	.
# chr1	14690	15158	chr1_14690_15158	1	.
# chr1	14839	15209	chr1_14839_15209	1	.
# chr1	14853	15208	chr1_14853_15208	1	.
# chr1	14933	15190	chr1_14933_15190	1	.
# chr1	14934	15190	chr1_14934_15190	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/atac_ENCFF925CYR/STARR_WHG_K562_Reddy_A001/overlap_count/WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	778328	779235	chr1:778328-779235	438
# chr1	817237	818202	chr1:817237-818202	139
# chr1	826647	828124	chr1:826647-828124	268
# chr1	842282	843322	chr1:842282-843322	165
# chr1	869581	870256	chr1:869581-870256	135
# chr1	898813	899211	chr1:898813-899211	63
# chr1	904068	905212	chr1:904068-905212	227
# chr1	906791	907164	chr1:906791-907164	116
# chr1	911094	911500	chr1:911094-911500	183
# chr1	912934	913144	chr1:912934-913144	206
#
#
# Done!
# Run Time: 2 minutes and 15 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_WHG_K562_Reddy_A001.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-05
# Slurm Array Index:
# Time Stamp:         06-29-25+11:56:09
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
#
# show first few lines of input
# chr1	42030	42399	chr1:42030-42399
# chr1	68963	70035	chr1:68963-70035
# chr1	79151	79653	chr1:79151-79653
# chr1	778339	779268	chr1:778339-779268
# chr1	804424	805054	chr1:804424-805054
# chr1	811420	811854	chr1:811420-811854
# chr1	812328	812983	chr1:812328-812983
# chr1	817227	818384	chr1:817227-818384
# chr1	826581	828166	chr1:826581-828166
# chr1	842062	843249	chr1:842062-843249
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10335	10549	chr1_10335_10549	1	.
# chr1	16983	17500	chr1_16983_17500	1	.
# chr1	16985	17499	chr1_16985_17499	1	.
# chr1	17004	17500	chr1_17004_17500	1	.
# chr1	17483	17898	chr1_17483_17898	1	.
# chr1	17487	17941	chr1_17487_17941	1	.
# chr1	33606	33997	chr1_33606_33997	1	.
# chr1	33617	33997	chr1_33617_33997	1	.
# chr1	38785	39226	chr1_38785_39226	1	.
# chr1	46328	46678	chr1_46328_46678	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count/WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	42030	42399	chr1:42030-42399	.
# chr1	68963	70035	chr1:68963-70035	1
# chr1	79151	79653	chr1:79151-79653	6
# chr1	778339	779268	chr1:778339-779268	17
# chr1	804424	805054	chr1:804424-805054	2
# chr1	811420	811854	chr1:811420-811854	1
# chr1	812328	812983	chr1:812328-812983	4
# chr1	817227	818384	chr1:817227-818384	8
# chr1	826581	828166	chr1:826581-828166	15
# chr1	842062	843249	chr1:842062-843249	14
#
#
# Done!
# Run Time: 12 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-13
# Slurm Array Index:
# Time Stamp:         06-29-25+11:20:32
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
#
# show first few lines of input
# chr1	10509	10674	chr1:10509-10674
# chr1	41987	42385	chr1:41987-42385
# chr1	46755	47025	chr1:46755-47025
# chr1	68969	69964	chr1:68969-69964
# chr1	78951	79407	chr1:78951-79407
# chr1	778328	779235	chr1:778328-779235
# chr1	796042	796413	chr1:796042-796413
# chr1	797433	797885	chr1:797433-797885
# chr1	804503	805016	chr1:804503-805016
# chr1	811468	811809	chr1:811468-811809
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10119	chr1_10001_10119	1	.
# chr1	10001	10131	chr1_10001_10131	1	.
# chr1	10001	10215	chr1_10001_10215	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10233	chr1_10002_10233	1	.
# chr1	10002	10308	chr1_10002_10308	1	.
# chr1	10002	10442	chr1_10002_10442	1	.
# chr1	10003	10111	chr1_10003_10111	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/atac_ENCFF558BLC/STARR_ATAC_K562_Reddy_KS91/overlap_count/ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10509	10674	chr1:10509-10674	37
# chr1	41987	42385	chr1:41987-42385	.
# chr1	46755	47025	chr1:46755-47025	.
# chr1	68969	69964	chr1:68969-69964	23
# chr1	78951	79407	chr1:78951-79407	35
# chr1	778328	779235	chr1:778328-779235	8362
# chr1	796042	796413	chr1:796042-796413	110
# chr1	797433	797885	chr1:797433-797885	64
# chr1	804503	805016	chr1:804503-805016	112
# chr1	811468	811809	chr1:811468-811809	73
#
#
# Done!
# Run Time: 3 minutes and 8 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF948AFM.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-23
# Slurm Array Index:
# Time Stamp:         06-29-25+11:20:35
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
#
# show first few lines of input
# chr1	42030	42399	chr1:42030-42399
# chr1	68963	70035	chr1:68963-70035
# chr1	79151	79653	chr1:79151-79653
# chr1	778339	779268	chr1:778339-779268
# chr1	804424	805054	chr1:804424-805054
# chr1	811420	811854	chr1:811420-811854
# chr1	812328	812983	chr1:812328-812983
# chr1	817227	818384	chr1:817227-818384
# chr1	826581	828166	chr1:826581-828166
# chr1	842062	843249	chr1:842062-843249
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts/WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	14510	14960	chr1_14510_14960	1	.
# chr1	14684	15162	chr1_14684_15162	1	.
# chr1	14688	15199	chr1_14688_15199	1	.
# chr1	14853	15208	chr1_14853_15208	1	.
# chr1	15133	15826	chr1_15133_15826	1	.
# chr1	15520	15834	chr1_15520_15834	1	.
# chr1	15527	15824	chr1_15527_15824	1	.
# chr1	15654	16248	chr1_15654_16248	1	.
# chr1	15815	16187	chr1_15815_16187	1	.
# chr1	15843	16265	chr1_15843_16265	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/atac_ENCFF948AFM/STARR_WHG_K562_Reddy_A001/overlap_count/WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	42030	42399	chr1:42030-42399	.
# chr1	68963	70035	chr1:68963-70035	7
# chr1	79151	79653	chr1:79151-79653	17
# chr1	778339	779268	chr1:778339-779268	268
# chr1	804424	805054	chr1:804424-805054	17
# chr1	811420	811854	chr1:811420-811854	13
# chr1	812328	812983	chr1:812328-812983	35
# chr1	817227	818384	chr1:817227-818384	76
# chr1	826581	828166	chr1:826581-828166	168
# chr1	842062	843249	chr1:842062-843249	75
#
#
# Done!
# Run Time: 1 minutes and 5 seconds
