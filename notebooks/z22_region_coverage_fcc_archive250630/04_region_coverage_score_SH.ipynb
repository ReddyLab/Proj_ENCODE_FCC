# %% [raw]
# ---
# title: Region Coverage 02
# subtitle: Calculate coverage of given region set (CRISPRi and Lenti-MPRA)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# FCC Assay: CRISPRi and Lenti-MPRA

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# ## Get data

# %%
### set directory
FDIRY=${FD_RES}/region/summary
FNAME=metadata.label.region_for_analysis.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label	FPath
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz

# %%
cat ${FP_REGION_LABEL} | cut -f 1-3
# Out:
# Folder	FName	Label
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM

# %%
### Assay
ASSAY_TYPE=assay_fcc
ASSAY_NAMES=(
    CRISPRi_FlowFISH_K562_Riley_JinWoo
    CRISPRi_Growth_K562_Gersbach_JinWoo
    MPRA_Lenti_K562_Nadav_Vikram
)

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loop: Region**

# %%
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### show progress
    echo ==============================
    echo "Region folder:" ${FOLDER_A}
    echo "Region label: " ${LABEL_A}
    
    ### Set directory
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM

# %%
cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}'
# Out:
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz

# %% [markdown]
# **Test loop: Assay**

# %%
for ASSAY_NAME in ${ASSAY_NAMES[@]}; do
    
    ### show progress
    echo ==============================
    echo "Assay name: " ${ASSAY_NAME}
    FD_INP=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/coverage
    FP_INPS=($(ls ${FD_INP}/*hg38*ZScore*bed.gz))
    
    ### loop through each sample
    for FP_INP_B in ${FP_INPS[@]}; do
        FD_INP_B=$(dirname  ${FP_INP_B})
        FN_INP_B=$(basename ${FP_INP_B})
        echo ${FD_INP_B}
        echo ${FN_INP_B}
    done
    echo
done
# Out:
# ==============================
# Assay name:  CRISPRi_FlowFISH_K562_Riley_JinWoo
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# ==============================
# Assay name:  CRISPRi_Growth_K562_Gersbach_JinWoo
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# ==============================
# Assay name:  MPRA_Lenti_K562_Nadav_Vikram
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# LMPRA_K562.hg38.ZScore.stranded.bed.gz

# %% [markdown]
# **Test loop: Region + Assay**

# %%
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### set input file
    FD_INP_A=$(dirname ${FPATH_A})
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set input file
        FD_INP=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/coverage
        FP_INPS=($(ls ${FD_INP}/*hg38*ZScore*bed.gz))
    
        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
        
            ### set input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc/${LABEL_A}/${ASSAY_NAME}/overlap_score
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_A}.${ASSAY_NAME}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_A}
            echo "Region label: " ${LABEL_A}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Input fdiry:  " ${FD_INP_A/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_A}
            echo "Input fdiry:  " ${FD_INP_B/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_B}
            echo
            echo "Output fdiry: " ${FD_OUT/${FD_RES}/'${FD_RES}'}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo
        done
    done
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)    
#done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt

# %% [markdown]
# ## Execute

# %% [markdown]
# **Check**

# %%
echo ${FP_CNF}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **RUN**

# %%
### init: set executable
FN_EXE="run_bedtools_intersect.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### Execute
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### set input file
    FD_INP_A=$(dirname ${FPATH_A})
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set input file
        FD_INP=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/coverage
        FP_INPS=($(ls ${FD_INP}/*hg38*ZScore*bed.gz))
    
        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
        
            ### set input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc/${LABEL_A}/${ASSAY_NAME}/overlap_score
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_A}.${ASSAY_NAME}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_A}
            echo "Region label: " ${LABEL_A}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Input fdiry:  " ${FD_INP_A/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_A}
            echo "Input fdiry:  " ${FD_INP_B/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_B}
            echo
            echo "Output fdiry: " ${FD_OUT/${FD_RES}/'${FD_RES}'}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo
            
            ### execute
            mkdir -p ${FD_OUT}
            sbatch \
                --cpus-per-task 4 \
                --mem 10G \
                --output ${FP_LOG} \
                ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
            echo
        done
    done
#done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292211
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292212
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292213
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_overlap/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292214
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292215
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292216
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292217
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/fcc_astarr_macs_input_union/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292218
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292219
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292220
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292221
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF274YGF/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292222
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292223
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292224
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292225
#
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/dnase_ENCFF185XRG/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292226
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292227
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292228
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292229
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF558BLC/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292230
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292231
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292232
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292233
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF925CYR/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292234
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292235
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292236
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292237
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF333TAT/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292238
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
#
# Submitted batch job 292239
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   CRISPRi_FlowFISH_K562_Riley_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage
# Input fname:   CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score
# Output fname:  CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292240
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   CRISPRi_Growth_K562_Gersbach_JinWoo
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage
# Input fname:   CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score
# Output fname:  CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
#
# Submitted batch job 292241
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   MPRA_Lenti_K562_Nadav_Vikram
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage
# Input fname:   LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc/atac_ENCFF948AFM/MPRA_Lenti_K562_Nadav_Vikram/overlap_score
# Output fname:  LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
#
# Submitted batch job 292242

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-03
# Slurm Array Index:
# Time Stamp:         06-29-25+12:19:25
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage/CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# show first few lines of input
# chr11	4091884	4091885	id-99	0.114291	.	HBE1
# chr11	4091884	4091885	id-99	0.650791	.	HBG1
# chr11	4091884	4091885	id-99	0.694152	.	HBG2
# chr11	4091884	4091885	id-99	-0.074553	.	HBS1L
# chr11	4091884	4091885	id-99	-0.257127	.	MYB
# chr11	4091885	4091886	id-100	-0.546764	.	HBE1
# chr11	4091885	4091886	id-100	0.084442	.	HBG1
# chr11	4091885	4091886	id-100	-0.119862	.	HBG2
# chr11	4091885	4091886	id-100	0.240283	.	HBS1L
# chr11	4091885	4091886	id-100	0.212189	.	MYB
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_overlap/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score/CRISPRi_HCRFF_K562.hg38.ZScore.filtered.unstranded.bed.gz
#
# show first few lines of output:
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092122	4092123	id-145	-1.10103	.	HBE1	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092122	4092123	id-145	-0.015199	.	HBG1	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092122	4092123	id-145	0.304337	.	HBG2	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092122	4092123	id-145	-0.675545	.	HBS1L	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092122	4092123	id-145	0.134939	.	MYB	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092123	4092124	id-146	-0.061961	.	HBE1	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092123	4092124	id-146	0.666595	.	HBG1	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092123	4092124	id-146	0.267739	.	HBG2	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092123	4092124	id-146	-0.384682	.	HBS1L	1
# chr11	4092109	4092511	chr11:4092109-4092511	chr11	4092123	4092124	id-146	-0.100842	.	MYB	1
#
#
# Done!
# Run Time: 1 seconds

# %%
cat ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.CRISPRi_FlowFISH_K562_Riley_JinWoo.CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-01
# Slurm Array Index:
# Time Stamp:         06-29-25+12:19:25
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442	chr1:10015-10442
# chr1	14253	14645	chr1:14253-14645
# chr1	16015	16477	chr1:16015-16477
# chr1	17237	17772	chr1:17237-17772
# chr1	28903	29613	chr1:28903-29613
# chr1	30803	31072	chr1:30803-31072
# chr1	101603	101849	chr1:101603-101849
# chr1	115411	115986	chr1:115411-115986
# chr1	118518	118743	chr1:118518-118743
# chr1	136071	137429	chr1:136071-137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/CRISPRi_FlowFISH_K562_Riley_JinWoo/coverage/CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# show first few lines of input
# chr1	74582275	74582276	id-1	0.414014	.	CD164
# chr1	74582275	74582276	id-1	-0.493091	.	MYC
# chr1	74582275	74582276	id-1	0.024514	.	NMU
# chr1	74582275	74582276	id-1	0.44089	.	PVT1
# chr1	74582309	74582310	id-2	-0.181799	.	CD164
# chr1	74582309	74582310	id-2	0.997649	.	MYC
# chr1	74582309	74582310	id-2	-0.439687	.	NMU
# chr1	74582309	74582310	id-2	1.25627	.	PVT1
# chr1	80526338	80526339	id-3	-0.186275	.	CD164
# chr1	80526338	80526339	id-3	0.340142	.	MYC
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/fcc_astarr_macs_input_union/CRISPRi_FlowFISH_K562_Riley_JinWoo/overlap_score/CRISPRi_HCRFF_K562.hg38.ZScore.unstranded.bed.gz
#
# show first few lines of output:
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729052	100729053	id-241	-0.282619	.	CAPRIN1	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729052	100729053	id-241	-1.27947	.	CAT	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729052	100729053	id-340	0.65685	.	CD164	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729052	100729053	id-241	-0.323226	.	ERP29	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729052	100729053	id-241	-0.582477	.	LMO2	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729052	100729053	id-241	-0.499114	.	MEF2C	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729052	100729053	id-340	0.229685	.	NMU	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729112	100729113	id-242	-1.31977	.	CAPRIN1	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729112	100729113	id-242	-0.259811	.	CAT	1
# chr10	100729027	100729908	chr10:100729027-100729908	chr10	100729112	100729113	id-341	-0.422878	.	CD164	1
#
#
# Done!
# Run Time: 2 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF948AFM.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-04
# Slurm Array Index:
# Time Stamp:         06-29-25+12:19:27
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
#
# show first few lines of input
# chr1	42030	42399	chr1:42030-42399
# chr1	68963	70035	chr1:68963-70035
# chr1	79151	79653	chr1:79151-79653
# chr1	778339	779268	chr1:778339-779268
# chr1	804424	805054	chr1:804424-805054
# chr1	811420	811854	chr1:811420-811854
# chr1	812328	812983	chr1:812328-812983
# chr1	817227	818384	chr1:817227-818384
# chr1	826581	828166	chr1:826581-828166
# chr1	842062	843249	chr1:842062-843249
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage/CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# show first few lines of input
# chr1	605580	605581	id-1	-0.18066	.
# chr1	605581	605582	id-2	0.486646	.
# chr1	605589	605590	id-3	3.17124	.
# chr1	605591	605592	id-4	-0.364573	.
# chr1	605592	605593	id-5	-0.206319	.
# chr1	605609	605610	id-6	-0.26675	.
# chr1	605617	605618	id-7	-0.7741	.
# chr1	605618	605619	id-8	-0.353224	.
# chr1	605619	605620	id-9	-0.187707	.
# chr1	605620	605621	id-10	-0.420401	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/atac_ENCFF948AFM/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score/CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# show first few lines of output:
# chr1	778339	779268	chr1:778339-779268	chr1	778628	778629	id-11	0.511467	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778629	778630	id-12	0.242298	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778634	778635	id-13	0.537248	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778707	778708	id-14	-0.167125	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778708	778709	id-15	0.666834	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778720	778721	id-16	-0.40553	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778721	778722	id-17	-0.223393	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778745	778746	id-18	-0.173731	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778763	778764	id-19	0.173191	.	1
# chr1	778339	779268	chr1:778339-779268	chr1	778877	778878	id-20	8.06e-4	.	1
#
#
# Done!
# Run Time: 3 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF558BLC.CRISPRi_Growth_K562_Gersbach_JinWoo.CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-02
# Slurm Array Index:
# Time Stamp:         06-29-25+12:19:27
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
#
# show first few lines of input
# chr1	10509	10674	chr1:10509-10674
# chr1	41987	42385	chr1:41987-42385
# chr1	46755	47025	chr1:46755-47025
# chr1	68969	69964	chr1:68969-69964
# chr1	78951	79407	chr1:78951-79407
# chr1	778328	779235	chr1:778328-779235
# chr1	796042	796413	chr1:796042-796413
# chr1	797433	797885	chr1:797433-797885
# chr1	804503	805016	chr1:804503-805016
# chr1	811468	811809	chr1:811468-811809
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/CRISPRi_Growth_K562_Gersbach_JinWoo/coverage/CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# show first few lines of input
# chr1	605580	605581	id-1	-0.18066	.
# chr1	605581	605582	id-2	0.486646	.
# chr1	605589	605590	id-3	3.17124	.
# chr1	605591	605592	id-4	-0.364573	.
# chr1	605592	605593	id-5	-0.206319	.
# chr1	605609	605610	id-6	-0.26675	.
# chr1	605617	605618	id-7	-0.7741	.
# chr1	605618	605619	id-8	-0.353224	.
# chr1	605619	605620	id-9	-0.187707	.
# chr1	605620	605621	id-10	-0.420401	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/atac_ENCFF558BLC/CRISPRi_Growth_K562_Gersbach_JinWoo/overlap_score/CRISPRi_Growth_K562.hg38.ZScore.unstranded.bed.gz
#
# show first few lines of output:
# chr1	778328	779235	chr1:778328-779235	chr1	778628	778629	id-11	0.511467	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778629	778630	id-12	0.242298	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778634	778635	id-13	0.537248	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778707	778708	id-14	-0.167125	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778708	778709	id-15	0.666834	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778720	778721	id-16	-0.40553	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778721	778722	id-17	-0.223393	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778745	778746	id-18	-0.173731	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778763	778764	id-19	0.173191	.	1
# chr1	778328	779235	chr1:778328-779235	chr1	778877	778878	id-20	8.06e-4	.	1
#
#
# Done!
# Run Time: 3 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF948AFM.MPRA_Lenti_K562_Nadav_Vikram.LMPRA_K562.hg38.ZScore.stranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-04
# Slurm Array Index:
# Time Stamp:         06-29-25+12:19:27
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
#
# show first few lines of input
# chr1	42030	42399	chr1:42030-42399
# chr1	68963	70035	chr1:68963-70035
# chr1	79151	79653	chr1:79151-79653
# chr1	778339	779268	chr1:778339-779268
# chr1	804424	805054	chr1:804424-805054
# chr1	811420	811854	chr1:811420-811854
# chr1	812328	812983	chr1:812328-812983
# chr1	817227	818384	chr1:817227-818384
# chr1	826581	828166	chr1:826581-828166
# chr1	842062	843249	chr1:842062-843249
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/MPRA_Lenti_K562_Nadav_Vikram/coverage/LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# show first few lines of input
# chr1	115631	115831	peak1_Reversed:	2.0511007569226227	-
# chr1	138940	139140	peak2_Reversed:	1.5391817792648435	-
# chr1	138940	139140	peak2	-0.06555714360564233	+
# chr1	203225	203425	peak3	1.2305781402512883	+
# chr1	203225	203425	peak3_Reversed:	0.8856681907655505	-
# chr1	267911	268111	peak4_Reversed:	-1.6049447076261982	-
# chr1	267911	268111	peak4	2.7227675006580068	+
# chr1	586093	586293	peak5	0.30476722321062366	+
# chr1	586093	586293	peak5_Reversed:	1.5137673619343153	-
# chr1	629847	630047	peak6_Reversed:	-1.4451969415485937	-
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc/atac_ENCFF948AFM/MPRA_Lenti_K562_Nadav_Vikram/overlap_score/LMPRA_K562.hg38.ZScore.stranded.bed.gz
#
# show first few lines of output:
# chr1	778339	779268	chr1:778339-779268	chr1	778638	778838	peak11	5.376758796174578	+	200
# chr1	778339	779268	chr1:778339-779268	chr1	778638	778838	peak11_Reversed:	6.447794955103975	-	200
# chr1	842062	843249	chr1:842062-843249	chr1	842870	843070	peak13_Reversed:	3.0059567223410335	-	200
# chr1	842062	843249	chr1:842062-843249	chr1	842870	843070	peak13	2.893407159877267	+	200
# chr1	898760	899148	chr1:898760-899148	chr1	898800	899000	peak15_Reversed:	0.9764339669460079	-	200
# chr1	898760	899148	chr1:898760-899148	chr1	898800	899000	peak15	3.499722544762722	+	200
# chr1	904027	905234	chr1:904027-905234	chr1	904350	904550	peak16	3.103983760615928	+	200
# chr1	904027	905234	chr1:904027-905234	chr1	904350	904550	peak16_Reversed:	3.358127933921208	-	200
# chr1	911019	911495	chr1:911019-911495	chr1	911257	911457	peak18_Reversed:	0.22852397121903947	-	200
# chr1	911019	911495	chr1:911019-911495	chr1	911257	911457	peak18	1.771542166286814	+	200
#
#
# Done!
# Run Time: 1 seconds
