# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import FCC scores

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    "fcc_astarr_macs_input_overlap",
    "summary"
)
vec = dir(txt_fdiry)
for(txt in vec){cat(txt, "\n")}
# Out:
# result.coverage.score.merge.fcc.atac.tsv
# result.coverage.zscore.final.tsv
# result.coverage.zscore.share.tsv
# result.coverage.zscore.total.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "result.coverage.zscore.share.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_type = "FALSE")

dat_region_score_fcc = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 432505      6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:left;"> Assay </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr10 </td>
#    <td style="text-align:right;"> 100729094 </td>
#    <td style="text-align:right;"> 100729750 </td>
#    <td style="text-align:left;"> chr10:100729094-100729750 </td>
#    <td style="text-align:right;"> -0.3065107 </td>
#    <td style="text-align:left;"> CRISPRi-HCR FlowFISH </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr10 </td>
#    <td style="text-align:right;"> 100743501 </td>
#    <td style="text-align:right;"> 100744571 </td>
#    <td style="text-align:left;"> chr10:100743501-100744571 </td>
# ...

# %% [markdown]
# ## Import proximal/distal x active/repressive label

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.fcc_peak_call.label.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_region_annot_fcc = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 155926     19
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Type </th>
#    <th style="text-align:right;"> Num_Assay </th>
#    <th style="text-align:right;"> TSS_Total </th>
#    <th style="text-align:right;"> TSS_Essential </th>
#    <th style="text-align:left;"> Label1 </th>
#    <th style="text-align:left;"> Label2 </th>
#    <th style="text-align:left;"> Label3 </th>
#    <th style="text-align:right;"> Screen_CRISPR_Total </th>
#    <th style="text-align:right;"> Screen_CRISPR_Growth </th>
#    <th style="text-align:right;"> Screen_CRISPR_HCRFF </th>
#    <th style="text-align:right;"> Screen_CRISPR_E2G </th>
#    <th style="text-align:right;"> Signif_CRISPR_Total </th>
#    <th style="text-align:right;"> Signif_CRISPR_Growth </th>
# ...

# %% [markdown]
# ## Import chromatin states

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation",
    "fcc_astarr_macs_input_overlap",
    "summary"
)
vec = dir(txt_fdiry)
for(txt in vec){cat(txt, "\n")}
# Out:
# matrix.annotation.encode_chipseq_flagship.tsv
# matrix.annotation.encode_chipseq_full.tsv
# matrix.annotation.encode_chipseq_histone.tsv
# matrix.annotation.encode_chipseq_subset.tsv
# matrix.annotation.encode_chromatin_states.ccres.tsv
# matrix.annotation.encode_chromatin_states.chromhmm.tsv
# matrix.annotation.encode_chromatin_states.full.tsv
# matrix.annotation.fcc_peak_call.tsv
# matrix.annotation.genome_tss.tsv
# matrix.annotation.merge.fcc.tss.chipseq.tsv
# region.annotation.encode_chipseq_flagship.tmp.tsv
# region.annotation.encode_chipseq_flagship.tsv
# region.annotation.encode_chipseq_histone.tsv
# region.annotation.encode_chipseq_subset.tsv
# region.annotation.encode_chromatin_states.tsv
# region.annotation.encode_e2g_benchmark.tsv
# region.annotation.fcc_astarr_csaw.tsv
# region.annotation.fcc_crispri_growth.tsv
# region.annotation.fcc_crispri_hcrff.tsv
# region.annotation.fcc_mpra_agarwal2023.tsv
# region.annotation.fcc_starrmpra_junke.tsv
# ...

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation",
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.encode_chromatin_states.ccres.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_type = "FALSE")

dat_region_annot_ccres = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 193629      6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:left;"> cCREs </td>
#    <td style="text-align:left;"> Low-DNase </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
#    <td style="text-align:right;"> 16338 </td>
#    <td style="text-align:left;"> chr1:16025-16338 </td>
#    <td style="text-align:left;"> cCREs </td>
#    <td style="text-align:left;"> Low-DNase </td>
# ...

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation",
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.encode_chromatin_states.chromhmm.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_type = "FALSE")

dat_region_annot_chromhmm = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 220966      6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:left;"> ChromHMM </td>
#    <td style="text-align:left;"> Quies </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 14282 </td>
#    <td style="text-align:right;"> 14614 </td>
#    <td style="text-align:left;"> chr1:14282-14614 </td>
#    <td style="text-align:left;"> ChromHMM </td>
#    <td style="text-align:left;"> Quies </td>
# ...

# %% [markdown]
# ## Import ChIP-seq score

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "atac_full",
    "prepare_matrix"
)
vec = dir(txt_fdiry)
for(txt in vec){cat(txt, "\n")}
# Out:
# matrix.coverage.encode_chipseq_full_log2p.fcc_zscore.tss.tsv
# matrix.coverage.encode_chipseq_full_log2p.fcc_zscore.tsv
# matrix.coverage.encode_chipseq_full_log2p.tsv
# matrix.coverage.encode_chipseq_full_mean0.tsv
# matrix.coverage.encode_chipseq_full_zscore.fcc_zscore.tss.tsv
# matrix.coverage.encode_chipseq_full_zscore.fcc_zscore.tsv
# matrix.coverage.encode_chipseq_full_zscore.tsv
# matrix.coverage.fcc_zscore.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "atac_full",
    "prepare_matrix"
)
txt_fname = "matrix.coverage.encode_chipseq_full_log2p.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_type = "FALSE")

mat_region_coverage_score_chipseq_log2p = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 150042    522
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
# ...

# %% [markdown]
# ## Import UMAP coordinate

# %%
txt_fdiry = file.path(
    FD_RES,
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "fcc_starrmpracrispri_vote2",
    "umap"
)
txt_fname = "umap.metric_euclidean.neighbors_070.coverage.encode_chipseq_full_log2p.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_region_umap = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 33953     3
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:right;"> UMAP1 </th>
#    <th style="text-align:right;"> UMAP2 </th>
#    <th style="text-align:left;"> Region </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 7.761389 </td>
#    <td style="text-align:right;"> 5.123120 </td>
#    <td style="text-align:left;"> chr1:100036895-100039189 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 8.937765 </td>
#    <td style="text-align:right;"> 5.504427 </td>
#    <td style="text-align:left;"> chr1:100132375-100133491 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> 7.081500 </td>
#    <td style="text-align:right;"> 5.860942 </td>
#    <td style="text-align:left;"> chr1:100248956-100250290 </td>
#   </tr>
# </tbody>
# </table>

# %%
dat = dat_region_umap
gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
    geom_point(size=0.1) + 
    theme_cowplot()
print(gpt)
# Out:
# plot without title

# %% [markdown]
# ## Arrange: FCC Score

# %%
dat = dat_region_score_fcc
dat = dat %>% 
    dplyr::select(Region, Assay, Score) %>% 
    tidyr::spread(Assay, Score) %>%
    dplyr::select(
        Region, 
        `ATAC-STARR`,  `WHG-STARR`, 
        `Tiling-MPRA`, `Lenti-MPRA`,
        `CRISPRi-HCR FlowFISH`, `CRISPRi-Growth`
    )

mat_region_score_fcc = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 150041      7
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> ATAC-STARR </th>
#    <th style="text-align:right;"> WHG-STARR </th>
#    <th style="text-align:right;"> Tiling-MPRA </th>
#    <th style="text-align:right;"> Lenti-MPRA </th>
#    <th style="text-align:right;"> CRISPRi-HCR FlowFISH </th>
#    <th style="text-align:right;"> CRISPRi-Growth </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1:100028014-100029653 </td>
#    <td style="text-align:right;"> -0.2125505 </td>
#    <td style="text-align:right;"> -0.7757209 </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> -0.2144696 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1:100036895-100039189 </td>
#    <td style="text-align:right;"> 1.7130117 </td>
# ...

# %% [markdown]
# ## Arrange: FCC Annotation

# %%
dat = dat_region_annot_fcc

vec = c("Enhance", "Repress")
dat = dat %>% 
    dplyr::filter(Type %in% vec) %>%
    dplyr::filter(Num_Assay > 1) 

dat_region_annot_fcc_subset = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 18346    19
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Type </th>
#    <th style="text-align:right;"> Num_Assay </th>
#    <th style="text-align:right;"> TSS_Total </th>
#    <th style="text-align:right;"> TSS_Essential </th>
#    <th style="text-align:left;"> Label1 </th>
#    <th style="text-align:left;"> Label2 </th>
#    <th style="text-align:left;"> Label3 </th>
#    <th style="text-align:right;"> Screen_CRISPR_Total </th>
#    <th style="text-align:right;"> Screen_CRISPR_Growth </th>
#    <th style="text-align:right;"> Screen_CRISPR_HCRFF </th>
#    <th style="text-align:right;"> Screen_CRISPR_E2G </th>
#    <th style="text-align:right;"> Signif_CRISPR_Total </th>
#    <th style="text-align:right;"> Signif_CRISPR_Growth </th>
# ...

# %% [markdown]
# ### Mapping the labels

# %%
fun_str_map = function(vec_txt_input){
    vec_txt_pattern = c("Enhancer", "Silencer", "TSS:Enhancer", "TSS:Silencer")
    vec_txt_replace = c("Distal:Active", "Distal:Repressive", "Proximal:Active", "Proximal:Repressive")
    vec_txt_output = fun_str_map_match(
        vec_txt_input,
        vec_txt_pattern,
        vec_txt_replace
    )
    return(vec_txt_output)
}

# %% [markdown]
# **Test mapping function**

# %%
dat = dat_region_annot_fcc_subset
dat = dat %>% dplyr::mutate(Group = fun_str_map(Label3)) 

print(table(dat$Label3, dat$Group))
# Out:
#
#                Distal:Active Distal:Repressive Proximal:Active
#   Enhancer             11623                 0               0
#   Silencer                 0              1640               0
#   TSS:Enhancer             0                 0            4974
#   TSS:Silencer             0                 0               0
#
#                Proximal:Repressive
#   Enhancer                       0
#   Silencer                       0
#   TSS:Enhancer                   0
#   TSS:Silencer                 109

# %%
dat = dat_region_annot_fcc_subset
dat = dat %>% 
    dplyr::mutate(Group = fun_str_map(Label3)) %>%
    #dplyr::mutate(Group = Label3) %>%
    dplyr::select(Chrom:Region, Group)

dat_region_focal = dat
print(dim(dat))
print(table(dat$Group))
head(dat)
# Out:
# [1] 18346     5
#
#       Distal:Active   Distal:Repressive     Proximal:Active Proximal:Repressive
#               11623                1640                4974                 109
#   Chrom ChromStart ChromEnd Region               Group
# 1 chr1   778233     779389  chr1:778233-779389   Distal:Active
# 2 chr1   958722     959968  chr1:958722-959968   Proximal:Active
# 3 chr1   960468     961615  chr1:960468-961615   Proximal:Active
# 4 chr1  1005094    1005553  chr1:1005094-1005553 Distal:Active
# 5 chr1  1013154    1014482  chr1:1013154-1014482 Proximal:Active
# 6 chr1  1059012    1060137  chr1:1059012-1060137 Distal:Active

# %%
dat = dat_region_focal
dat = dat %>% 
    dplyr::mutate(Label = Group) %>%
    dplyr::select(Region, Label)
dat = dplyr::right_join(dat_region_umap, dat, by = "Region")

dat_region_umap_annot_starrmpra_vote2 = dat
print(dim(dat))
head(dat)
# Out:
# [1] 18346     4
#   UMAP1    UMAP2    Region                   Label
# 1 7.761389 5.123120 chr1:100036895-100039189 Proximal:Active
# 2 8.937765 5.504427 chr1:100132375-100133491 Proximal:Active
# 3 7.489602 5.386488 chr1:100265562-100266994 Proximal:Active
# 4 9.208714 4.615319 chr1:10032429-10033763   Proximal:Active
# 5 5.600899 6.791666 chr1:100362769-100363401 Distal:Active
# 6 1.977909 7.495390 chr1:100400445-100400762 Distal:Active

# %% [markdown]
# ## Arrange cCREs

# %%
dat = dat_region_annot_ccres
res = table(dat$Label)

print(res)
fun_display_table(head(dat, 3))
# Out:
#    CA-CTCF CA-H3K4me3    CA-only      CA-TF       dELS  Low-DNase       pELS
#      20916       3144       1279      23545      15332     104419      12893
#        PLS
#      12101
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:left;"> cCREs </td>
#    <td style="text-align:left;"> Low-DNase </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
# ...

# %% [markdown]
# ## Arrange ChIP-seq

# %%
fun = function(x){(x-min(x))/(max(x)-min(x))}
dat = mat_region_coverage_score_chipseq_log2p
dat = dat %>% dplyr::mutate(across(where(is.double), fun))

mat_region_coverage_score_chipseq_scale = dat
print(dim(dat))
head(dat)
# Out:
# [1] 150042    522
#   Region                   H2AFZ       H3K27ac   H3K27me3   H3K36me3  H3K4me1
# 1 chr1:100028014-100029653 0.183451797 0.2312779 0.10091383 0.3109356 0.2861042
# 2 chr1:100036895-100039189 0.570479733 0.7522100 0.11237694 0.3161297 0.2026280
# 3 chr1:100046252-100046533 0.008442267 0.2099858 0.12053492 0.1421704 0.4069874
# 4 chr1:100048290-100048918 0.100216443 0.2857300 0.16199788 0.3118129 0.3764480
# 5 chr1:100050225-100050529 0.168549622 0.3318505 0.06258577 0.5095759 0.3643350
# 6 chr1:100064757-100065161 0.083329080 0.2386680 0.11057545 0.4125194 0.3016867
#   H3K4me2    H3K4me3   H3K79me2   H3K9ac    ⋯ ZNF778    ZNF780A   ZNF785
# 1 0.11229378 0.0911140 0.05629239 0.1676043 ⋯ 0.2503401 0.2351712 0.2563192
# 2 0.81480328 0.8501070 0.73207803 0.7595136 ⋯ 0.1715204 0.3195533 0.1954653
# 3 0.20450769 0.1738851 0.62732070 0.1793258 ⋯ 0.3626518 0.2239213 0.2199525
# 4 0.23249555 0.1494607 0.61631784 0.2002644 ⋯ 0.2571198 0.3627017 0.3056766
# ...

# %%
dat = mat_region_coverage_score_chipseq_scale
summary(dat$H2AFZ)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.0000  0.1381  0.2546  0.2982  0.4352  1.0000

# %%
dat =  dplyr::inner_join(
    dat_region_umap,
    mat_region_coverage_score_chipseq_scale, 
    by = "Region")

dat_region_umap_score_chipseq_scale = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 33953   524
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:right;"> UMAP1 </th>
#    <th style="text-align:right;"> UMAP2 </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
# ...

# %%
txt_fdiry = file.path(
    FD_RES,
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "summary"
)
txt_fname = "fcc_starrmpracrispr_vote2.umap.chipseq_scale.rds"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = dat_region_umap_score_chipseq_scale
write_rds(dat, txt_fpath)

# %%
#txt_fdiry = file.path(FD_REF, "test_app")
#txt_fname = "dat_region_test.tsv.gz"
#txt_fpath = file.path(txt_fdiry, txt_fname)

txt_fdiry = file.path(
    FD_RES,
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "summary"
)
txt_fname = "fcc_starrmpracrispr_vote2.umap.chipseq_scale.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = dat_region_umap_score_chipseq_scale
write_tsv(dat, txt_fpath)

# %%
txt_fdiry = file.path(
    FD_RES,
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "summary"
)
txt_fname = "fcc_starrmpracrispr_vote2.umap.starrmpra_vote2.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = dat_region_umap_annot_starrmpra_vote2
write_tsv(dat, txt_fpath)

# %%
#txt_fdiry = file.path(FD_REF, "test_app")
#txt_fname = "dat_region_test.tsv.gz"
#txt_fpath = file.path(txt_fdiry, txt_fname)

txt_fdiry = file.path(
    FD_RES,
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "summary"
)
txt_fname = "fcc_starrmpracrispr_vote2.umap.chipseq_log2p.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = dat_region_merge_log2p
write_tsv(dat, txt_fpath)

# %%
#txt_fdiry = file.path(FD_REF, "test_app")
#txt_fname = "dat_region_test.tsv.gz"
#txt_fpath = file.path(txt_fdiry, txt_fname)

txt_fdiry = file.path(
    FD_RES,
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_umap_cluster_by_coverage_score", 
    "summary"
)
txt_fname = "fcc_starrmpracrispr_vote2.umap.chipseq_scale.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = dat_region_merge_scale
write_tsv(dat, txt_fpath)

# %%
vec = brewer.pal("Reds", n = 9)
vec = c("#FFFFFF", vec)
vec
# Out:
#  [1] "#FFFFFF" "#FFF5F0" "#FEE0D2" "#FCBBA1" "#FC9272" "#FB6A4A" "#EF3B2C"
#  [8] "#CB181D" "#A50F15" "#67000D"
