# %% [raw]
# ---
# title: Region annotation 01 (ASTARR MACS peaks)
# subtitle: Annotate peaks (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_flagship
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chromatin_states
# encode_e2g_benchmark
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs
# fcc_astarr_macs_narrowpeak
# fcc_crispri_growth
# fcc_crispri_hcrff
# fcc_mpra_agarwal2023
# fcc_screened
# fcc_starrmpra_junke
# fcc_table
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_flagship.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_histone.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
FDIRY=${FD_RES}/region/fcc_astarr_macs_narrowpeak/summary
ls -1 ${FDIRY}
echo
head ${FDIRY}/metadata.label.tsv
# Out:
# description.tsv
# metadata.label.tsv
#
# Folder	FName	Label
# fcc_astarr_macs_narrowpeak	K562.hg38.ASTARR.macs.KS91.input.rep1.narrowpeak.bed.gz	fcc_astarr_macs_input_rep1
# fcc_astarr_macs_narrowpeak	K562.hg38.ASTARR.macs.KS91.input.rep2.narrowpeak.bed.gz	fcc_astarr_macs_input_rep2
# fcc_astarr_macs_narrowpeak	K562.hg38.ASTARR.macs.KS91.input.rep3.narrowpeak.bed.gz	fcc_astarr_macs_input_rep3
# fcc_astarr_macs_narrowpeak	K562.hg38.ASTARR.macs.KS91.input.rep4.narrowpeak.bed.gz	fcc_astarr_macs_input_rep4
# fcc_astarr_macs_narrowpeak	K562.hg38.ASTARR.macs.KS91.input.rep5.narrowpeak.bed.gz	fcc_astarr_macs_input_rep5
# fcc_astarr_macs_narrowpeak	K562.hg38.ASTARR.macs.KS91.input.rep6.narrowpeak.bed.gz	fcc_astarr_macs_input_rep6

# %%
FDIRY=${FD_RES}/region/fcc_astarr_macs/summary
ls -1 ${FDIRY}
echo
head ${FDIRY}/metadata.label.tsv
# Out:
# description.tsv
# metadata.label.tsv
#
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs.tsv
head ${FP_REGION_LABEL_A}
# Out:
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
FP_REGION_LABEL_A=${FD_RES}/region/fcc_astarr_macs/summary/metadata.label.tsv
FP_REGION_LABEL_B=${FD_RES}/region/fcc_astarr_macs_narrowpeak/summary/metadata.label.tsv

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set output
        FD_OUT=${FD_RES}/region/fcc_astarr_macs/intersect/${LABEL_REG_A}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep1
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep1.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep1.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep2.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep3
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep3.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep3.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep4
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep4.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep4.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep5
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep5.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep5.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep6
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep6.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep6.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep1
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep1.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep1.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep2.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep3
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep3.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep3.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep4
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep4.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep4.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep5
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep5.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep5.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep6
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep6.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep6.txt

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set output
        FD_OUT=${FD_RES}/region/fcc_astarr_macs/intersect/${LABEL_REG_A}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep1
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep1.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep1.txt
#
# Submitted batch job 65038
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep2.txt
#
# Submitted batch job 65039
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep3
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep3.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep3.txt
#
# Submitted batch job 65040
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep4
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep4.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep4.txt
#
# Submitted batch job 65041
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep5
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep5.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep5.txt
#
# Submitted batch job 65042
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_macs_input_rep6
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_overlap
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep6.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_macs_input_rep6.txt
#
# Submitted batch job 65043
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep1
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep1.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep1.txt
#
# Submitted batch job 65044
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep2.txt
#
# Submitted batch job 65045
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep3
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep3.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep3.txt
#
# Submitted batch job 65046
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep4
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep4.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep4.txt
#
# Submitted batch job 65047
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep5
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep5.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep5.txt
#
# Submitted batch job 65048
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_macs_input_rep6
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/intersect/fcc_astarr_macs_input_union
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep6.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_macs_input_rep6.txt
#
# Submitted batch job 65049
