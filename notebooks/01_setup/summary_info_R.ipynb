# %% [markdown]
# ## Assay

# %%
vec_txt_assay_name = c(
    "STARR_ATAC_K562_Reddy_KS91",
    "STARR_ATAC_K562_Reddy_KS274",
    "STARR_WHG_K562_Reddy_A001",
    "MPRA_Tiling_K562_Tewhey_Hannah",
    "MPRA_Lenti_K562_Nadav_Vikram",
    "CRISPRi_FlowFISH_K562_Riley_JinWoo",
    "CRISPRi_Growth_K562_Gersbach_JinWoo",
    "CRISPRi_Growth_K562_Gersbach_Alex",
    "hic_insitu_K562_ENCSR545YBD",
    "hic_intact_K562_ENCSR479XDG",
    "hic_intact_K562_deep"
)

vec_txt_assay_group = c(
    "ASTARR",
    "ASTARR",
    "WSTARR",
    "TMPRA",
    "LMPRA",
    "CRISPRi-FlowFISH",
    "CRISPRi-Growth",
    "CRISPRi-Growth",
    "HiC-insitu",
    "HiC-intact",
    "HiC-intact"
)

vec_txt_assay_label = c(
    "ASTARR_AB/ASTARR_A/ASTARR_R",
    "ASTARR_AB/ASTARR_A/ASTARR_R",
    "WSTARR_AB/WSTARR_A/WSTARR_R",
    "TMPRA_A/TMPRA_R",
    "LMPRA_A/LMPRA_R",
    "CRISPRi-HCRFF:GATA1/CRISPRi-HCRFF:MYC",
    "CRISPRi-Growth",
    "CRISPRi-Growth",
    "Loop/TAD",
    "Loop/TAD",
    "Loop/TAD"
)

vec_txt_assay_type = c(
    rep("FCC", 8),
    rep("HiC", 3)
)

vec_txt_assay_score = c(
    "Input/Output/Log2FC",
    "Input/Output/Log2FC",
    "Input/Output/Log2FC",
    "Input/Output/Log2FC",
    "Input/Output/Log2FC",
    "Log2FC/ZScore",
    "Log2FC/ZScore",
    "Log2FC/ZScore",
    "observed(o)/expected(e)/ratio(oe)",
    "observed(o)/expected(e)/ratio(oe)",
    "observed(o)/expected(e)/ratio(oe)"
)

dat = data.frame(
    "Assay_Type"  = vec_txt_assay_type,
    "Assay_Name"  = vec_txt_assay_name,
    "Assay_Group" = vec_txt_assay_group,
    "Assay_Label" = vec_txt_assay_label,
    "Assay_Score" = vec_txt_assay_score
)

dat
# Out:
#    Assay_Type Assay_Name                          Assay_Group
# 1  FCC        STARR_ATAC_K562_Reddy_KS91          ASTARR
# 2  FCC        STARR_ATAC_K562_Reddy_KS274         ASTARR
# 3  FCC        STARR_WHG_K562_Reddy_A001           WSTARR
# 4  FCC        MPRA_Tiling_K562_Tewhey_Hannah      TMPRA
# 5  FCC        MPRA_Lenti_K562_Nadav_Vikram        LMPRA
# 6  FCC        CRISPRi_FlowFISH_K562_Riley_JinWoo  CRISPRi-FlowFISH
# 7  FCC        CRISPRi_Growth_K562_Gersbach_JinWoo CRISPRi-Growth
# 8  FCC        CRISPRi_Growth_K562_Gersbach_Alex   CRISPRi-Growth
# 9  HiC        hic_insitu_K562_ENCSR545YBD         HiC-insitu
# 10 HiC        hic_intact_K562_ENCSR479XDG         HiC-intact
# 11 HiC        hic_intact_K562_deep                HiC-intact
#    Assay_Label                           Assay_Score
# 1  ASTARR_AB/ASTARR_A/ASTARR_R           Input/Output/Log2FC
# 2  ASTARR_AB/ASTARR_A/ASTARR_R           Input/Output/Log2FC
# 3  WSTARR_AB/WSTARR_A/WSTARR_R           Input/Output/Log2FC
# ...

# %%
lst = list(
    "STARR"   = "Input/Output/Log2FC",
    "MPRA"    = "Input/Output/Log2FC",
    "CRISPRi" = "Log2FC/ZScore",
    "HiC"     = "observed(o)/expected(e)/ratio(oe)"
)
lst
# Out:
# $STARR
# [1] "Input/Output/Log2FC"
#
# $MPRA
# [1] "Input/Output/Log2FC"
#
# $CRISPRi
# [1] "Log2FC/ZScore"
#
# $HiC
# [1] "observed(o)/expected(e)/ratio(oe)"

# %%
lst = list(
    "STARR"          = c("A (Active; Enhancer)", "R (Repressed; Repressor)"),
    "MPRA"           = c("A (Active; Enhancer)", "R (Repressed; Repressor)"),
    "CRISPRi-HCRFF"  = c("GATA1", "MYC"),
    "CRISPRi-Growth" = c(""),
    "HiC"            = c("Loop", "TAD")
)
lst
# Out:
# $STARR
# [1] "A (Active; Enhancer)"     "R (Repressed; Repressor)"
#
# $MPRA
# [1] "A (Active; Enhancer)"     "R (Repressed; Repressor)"
#
# $`CRISPRi-HCRFF`
# [1] "GATA1" "MYC"
#
# $`CRISPRi-Growth`
# [1] ""
#
# $HiC
# [1] "Loop" "TAD"

# %% [markdown]
# ## Region

# %%
vec_txt_type  = c("ChIPseq", "ChIPseq", "ChromState", "ChromState", "OCR",  "OCR")
vec_txt_name  = c("ChIPseq", "ChIPseq", "cCREs",   "ChromHMM", "ATAC", "DNase")
vec_txt_group = c("ChIPseq:TF", "ChIPseq:Histone", "cCREs",   "ChromHMM", "ATAC", "DHS")
vec_txt_label = c("EP300",    "H3K27ac",  "PLS/ELS", "TSS",      "ATAC", "DHS")

dat = data.frame(
    "Region_Type"  = vec_txt_type,
    "Region_Name"  = vec_txt_name,
    "Region_Group" = vec_txt_group,
    "Region_Label" = vec_txt_label
)

dat
# Out:
#   Region_Type Region_Name Region_Group    Region_Label
# 1 ChIPseq     ChIPseq     ChIPseq:TF      EP300
# 2 ChIPseq     ChIPseq     ChIPseq:Histone H3K27ac
# 3 ChromState  cCREs       cCREs           PLS/ELS
# 4 ChromState  ChromHMM    ChromHMM        TSS
# 5 OCR         ATAC        ATAC            ATAC
# 6 OCR         DNase       DHS             DHS
