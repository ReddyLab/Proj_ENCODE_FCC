# %% [raw]
# ---
# title: Region annotation 02 (ASTARR MACS peaks)
# subtitle: Annotate peaks (ChIP-seq; subset)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ...

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_flagship
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chromatin_states
# encode_e2g_benchmark
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs
# fcc_astarr_macs_narrowpeak
# fcc_crispri_growth
# fcc_crispri_hcrff
# fcc_mpra_agarwal2023
# fcc_screened
# fcc_starrmpra_junke
# fcc_table
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_flagship.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_histone.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
ls -1 ${FD_RES}/annotation
# Out:
# encode_chipseq_histone
# encode_chipseq_tf
# protein_interpro

# %%
ls -1 ${FD_RES}/annotation/encode_chipseq_tf/summary
# Out:
# metadata.label.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs.tsv
FP_REGION_LABEL_B=${FD_RES}/annotation/encode_chipseq_tf/summary/metadata.label.tsv

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs.tsv
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B} | wc -l
cat ${FP_REGION_LABEL_B} | head
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/summary/metadata.label.tsv
# 721
# Folder	Label	FPath
# encode_chipseq_tf	encode_chipseq_ZNF347_ENCFF465ZAR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF465ZAR.bigWig
# encode_chipseq_tf	encode_chipseq_ZBTB9_ENCFF178FEN	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF178FEN.bigWig
# encode_chipseq_tf	encode_chipseq_AFF4_ENCFF040PTP	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF040PTP.bigWig
# encode_chipseq_tf	encode_chipseq_ZFX_ENCFF193LUC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF193LUC.bigWig
# encode_chipseq_tf	encode_chipseq_KAT7_ENCFF922ZTM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF922ZTM.bigWig
# ...

# %% [markdown]
# ## Preview

# %% [markdown]
# **Check loop**

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B LABEL_REG_B FPATH_REG_B; do

        ### Set input B
        FP_INP_B=${FPATH_REG_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_coverage_chipseq/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bigWigAverageOverBed.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF347_ENCFF465ZAR
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.txt
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZBTB9_ENCFF178FEN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZBTB9_ENCFF178FEN.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZBTB9_ENCFF178FEN.txt
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# ...

# %%
echo 1
# Out:
# 1

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B LABEL_REG_B FPATH_REG_B; do

        ### Set input B
        FP_INP_B=${FPATH_REG_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_coverage_chipseq/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bigWigAverageOverBed.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF347_ENCFF465ZAR
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.txt
#
# Submitted batch job 69847
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZBTB9_ENCFF178FEN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZBTB9_ENCFF178FEN.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZBTB9_ENCFF178FEN.txt
#
# Submitted batch job 69848
#
# ...

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/annotation/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_coverage_chipseq/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bigWigAverageOverBed.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF465ZAR.bigWig
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf
# Output FName:   fcc_astarr_macs_input_overlap./data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF465ZAR.bigWig.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap./data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF465ZAR.bigWig.txt
#
# Submitted batch job 71289
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF178FEN.bigWig
#
# ...

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.txt
# Out:
# Hostname:           plp-rcc-node-04
# Slurm Array Index:
# Time Stamp:         01-26-25+18:59:28
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF465ZAR.bigWig
#
# processing chromosomes
#
# ...

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_LARP7_ENCFF689OKC.txt
# Out:
# Hostname:           plp-rcc-node-10
# Slurm Array Index:
# Time Stamp:         01-26-25+18:59:41
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF689OKC.bigWig
#
# processing chromosomesudc couldn't read 4 bytes from /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF689OKC.bigWig, did read 0
#
# ...

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_LARP7_ENCFF689OKC.txt
# Out:
# Hostname:           plp-rcc-node-08
# Slurm Array Index:
# Time Stamp:         01-26-25+19:22:20
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442	chr1:10015-10442
# chr1	14253	14645	chr1:14253-14645
# chr1	16015	16477	chr1:16015-16477
# chr1	17237	17772	chr1:17237-17772
# chr1	28903	29613	chr1:28903-29613
# chr1	30803	31072	chr1:30803-31072
# chr1	101603	101849	chr1:101603-101849
# chr1	115411	115986	chr1:115411-115986
# chr1	118518	118743	chr1:118518-118743
# chr1	136071	137429	chr1:136071-137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF689OKC.bigWig
#
# processing chromosomesudc couldn't read 4 bytes from /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_tf/signal_fold_change/ENCFF689OKC.bigWig, did read 0
#
# ...

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF847BFA.txt
# Out:
# Hostname:           plp-rcc-node-19
# Slurm Array Index:
# Time Stamp:         01-09-25+11:21:04
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442	chr1:10015-10442
# chr1	14253	14645	chr1:14253-14645
# chr1	16015	16477	chr1:16015-16477
# chr1	17237	17772	chr1:17237-17772
# chr1	28903	29613	chr1:28903-29613
# chr1	30803	31072	chr1:30803-31072
# chr1	101603	101849	chr1:101603-101849
# chr1	115411	115986	chr1:115411-115986
# chr1	118518	118743	chr1:118518-118743
# chr1	136071	137429	chr1:136071-137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_histone/ENCFF847BFA.bigWig
#
# bigWigAverageOverBed v2 - Compute average score of big wig over each bed, which may have introns.
# usage:
#    bigWigAverageOverBed in.bw in.bed out.tab
# The output columns are:
# ...
