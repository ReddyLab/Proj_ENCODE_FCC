# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ...

# %%
ls ${FD_NBK}
# Out:
# 00_setup                      build_tracks
# 01_prepare_fcc                discussion
# 02_prepare_hic                Readme.md
# 03_prepare_chipseq            run_config_project.sh
# 04_prepare_annotation         run_config_project_sing.py
# 05_prepare_region             run_config_project_sing.R
# 11_fcc_process                run_config_test.sh
# 12_fcc_starrmpra              shared
# 21_region_summary             tmp
# 22_region_coverage_fcc_score  z02_prepare_hic
# 23_region_coverage_chipseq    z04_prepare_annotation_archive250501
# 24_region_annotation          z05_prepare_region_archive250501
# 31_hic_process                z22_region_coverage_fcc_archive250627
# 34_hic_meta                   z22_region_coverage_fcc_archive250630
# 41_fcc_correlation            z23_region_coverage_chipseq_archive250610
# 42_fcc_comparison             z24_region_annotation_archive241024
# 43_fcc_table                  z24_region_annotation_archive250529
# ...

# %%
ls -1 ${FD_PRJ}/site/notebooks
# Out:
# 00_setup
# 01_prepare_fcc
# 02_prepare_hic
# 03_prepare_chipseq
# 04_prepare_annotation
# 05_prepare_region
# 21_region_summary
# 22_region_coverage_fcc_score
# 24_region_annotation
# 41_fcc_correlation
# 42_fcc_comparison
# test

# %% [markdown]
# ## Copy notebooks: Preparing Hi-C data

# %%
FD_INP=${FD_NBK}/02_prepare_hic
FD_OUT=${FD_PRJ}/site/notebooks/02_prepare_hic

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/02_prepare_hic
#
# fig.hic_intact_deep.distribution.loop.distance.png
# fig.hic_intact_deep.distribution.loop.distance.svg
# fig.hic_intact_deep.distribution.loop.Log2OE.png
# fig.hic_intact_deep.distribution.loop.Log2OE.svg
# hic_insitu_01_create_download_script_R.ipynb
# hic_insitu_02_execute_download_data_SH.ipynb
# hic_insitu_03_check_download_data_SH.ipynb
# hic_insitu_11_export_region_loop_R.ipynb
# hic_insitu_12_export_region_TAD_R.ipynb
# hic_insitu_13_export_metadata_R.ipynb
# hic_insitu_21_explore_region_loop_R.ipynb
# hic_insitu_22_explore_region_TAD_R.ipynb
# hic_insitu_23_explore_matrix_PY.ipynb
# hic_intact_01_create_download_script_R.ipynb
# hic_intact_02_execute_download_script_SH.ipynb
# hic_intact_03_check_download_data_SH.ipynb
# hic_intact_11_export_region_loop_R.ipynb
# hic_intact_12_export_region_TAD_R.ipynb
# hic_intact_13_export_metadata_R.ipynb
# hic_intact_21_explore_region_loop_R.ipynb
# ...

# %%
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/hic* ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/02_prepare_hic
#
# hic_insitu_01_create_download_script_R.ipynb
# hic_insitu_02_execute_download_data_SH.ipynb
# hic_insitu_03_check_download_data_SH.ipynb
# hic_insitu_11_export_region_loop_R.ipynb
# hic_insitu_12_export_region_TAD_R.ipynb
# hic_insitu_13_export_metadata_R.ipynb
# hic_insitu_21_explore_region_loop_R.ipynb
# hic_insitu_22_explore_region_TAD_R.ipynb
# hic_insitu_23_explore_matrix_PY.ipynb
# hic_intact_01_create_download_script_R.ipynb
# hic_intact_02_execute_download_script_SH.ipynb
# hic_intact_03_check_download_data_SH.ipynb
# hic_intact_11_export_region_loop_R.ipynb
# hic_intact_12_export_region_TAD_R.ipynb
# hic_intact_13_export_metadata_R.ipynb
# hic_intact_21_explore_region_loop_R.ipynb
# hic_intact_22_explore_region_TAD_R.ipynb
# hic_intact_deep_01_download_data_SH.ipynb
# hic_intact_deep_02_check_download_data_SH.ipynb
# hic_intact_deep_11_export_region_loop_R.ipynb
# ...

# %% [markdown]
# ## Copy notebooks: Preparing ChIP-seq data

# %%
FD_INP=${FD_NBK}/03_prepare_chipseq
FD_OUT=${FD_PRJ}/site/notebooks/03_prepare_chipseq
mkdir -p ${FD_OUT}

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/03_prepare_chipseq
#
# chip_histone_01_create_download_script_R.ipynb
# chip_histone_02_execute_download_files_SH.ipynb
# chip_histone_03_check_download_files_R.ipynb
# chip_histone_11_export_region_SH.ipynb
# chip_histone_12_export_signal_SH.ipynb
# chip_histone_13_export_metadata_region_R.ipynb
# chip_histone_14_export_metadata_signal_R.ipynb
# chip_tf_full_01_create_download_script_R.ipynb
# chip_tf_full_02_execute_download_region_SH.ipynb
# chip_tf_full_03_execute_download_signal_fold_change_SH.ipynb
# chip_tf_full_04_check_download_files_R.ipynb
# chip_tf_full_11_export_region_SH.ipynb
# chip_tf_full_12_export_signal_SH.ipynb
# chip_tf_full_13_export_metadata_region_R.ipynb
# chip_tf_full_14_export_metadata_signal_R.ipynb
# chip_tf_subset_01_create_download_script_R.ipynb
# chip_tf_subset_02_subset_execute_download_SH.ipynb
# chip_tf_subset_03_export_data_SH.ipynb
# chip_tf_subset_04_export_metadata_R.ipynb
# ...

# %%
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/chip_histone*   ${FD_OUT}/
cp ${FD_INP}/chip_tf_subset* ${FD_OUT}/
cp ${FD_INP}/chip_tf_full*   ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/03_prepare_chipseq
#
# chip_histone_01_create_download_script_R.ipynb
# chip_histone_02_execute_download_files_SH.ipynb
# chip_histone_03_check_download_files_R.ipynb
# chip_histone_11_export_region_SH.ipynb
# chip_histone_12_export_signal_SH.ipynb
# chip_histone_13_export_metadata_region_R.ipynb
# chip_histone_14_export_metadata_signal_R.ipynb
# chip_tf_full_01_create_download_script_R.ipynb
# chip_tf_full_02_execute_download_region_SH.ipynb
# chip_tf_full_03_execute_download_signal_fold_change_SH.ipynb
# chip_tf_full_04_check_download_files_R.ipynb
# chip_tf_full_11_export_region_SH.ipynb
# chip_tf_full_12_export_signal_SH.ipynb
# chip_tf_full_13_export_metadata_region_R.ipynb
# chip_tf_full_14_export_metadata_signal_R.ipynb
# chip_tf_subset_01_create_download_script_R.ipynb
# chip_tf_subset_02_subset_execute_download_SH.ipynb
# chip_tf_subset_03_export_data_SH.ipynb
# chip_tf_subset_04_export_metadata_R.ipynb

# %% [markdown]
# ## Copy notebooks: Preparing annotations

# %%
FD_INP=${FD_NBK}/04_prepare_annotation
FD_OUT=${FD_PRJ}/site/notebooks/04_prepare_annotation
mkdir -p ${FD_OUT}

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/04_prepare_annotation
#
# fig.rnaseq.distribution.tpm.nonzero.below2k.png
# fig.rnaseq.distribution.tpm.nonzero.below2k.svg
# gene_essential_01_export_R.ipynb
# rnaseq_01_total_create_download_script_R.ipynb
# rnaseq_02_total_execute_download_script_SH.ipynb
# rnaseq_03_total_explore_data_R.ipynb
#
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/04_prepare_annotation
#
# rnaseq_01_total_create_download_script_R.ipynb
# rnaseq_02_total_execute_download_script_SH.ipynb
# rnaseq_03_total_explore_data_R.ipynb

# %%
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/rnaseq* ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/04_prepare_annotation
#
# rnaseq_01_total_create_download_script_R.ipynb
# rnaseq_02_total_execute_download_script_SH.ipynb
# rnaseq_03_total_explore_data_R.ipynb

# %% [markdown]
# ## Copy notebooks: Preparing regions

# %%
FD_INP=${FD_NBK}/05_prepare_region
FD_OUT=${FD_PRJ}/site/notebooks/05_prepare_region
mkdir -p ${FD_OUT}

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/05_prepare_region
#
# fig.matrix.module_tf_mapping.png
# fig.matrix.region2module.png
# fig.matrix.region2TF.png
# fig.region.chromstate_ccres.distribution.region_length.png
# fig.region.chromstate_ccres.distribution.region_length.svg
# fig.region.chromstate_chromhmm.distribution.region_length.below10k.png
# fig.region.chromstate_chromhmm.distribution.region_length.below10k.svg
# fig.region.compare_ocr.distribution.chromosome.png
# fig.region.compare_ocr.distribution.chromosome.svg
# fig.region.compare_ocr.enrichment.genomic_partition.png
# fig.region.compare_ocr.enrichment.genomic_partition.svg
# fig.region.compare_ocr.frequency.genomic_partition.png
# fig.region.compare_ocr.frequency.genomic_partition.svg
# fig.region.encode_e2g.distribution.score.png
# fig.region.encode_e2g.distribution.score.svg
# fig.region.encode_ocr.distribution.region_length.png
# fig.region.encode_ocr.distribution.region_length.svg
# ...

# %%
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/region_astarr_macs* ${FD_OUT}/
cp ${FD_INP}/region_astarr_csaw* ${FD_OUT}/
cp ${FD_INP}/region_tss* ${FD_OUT}/
cp ${FD_INP}/region_ocr* ${FD_OUT}/
cp ${FD_INP}/region_chromstate* ${FD_OUT}/
cp ${FD_INP}/region_tfmodule*   ${FD_OUT}/
cp ${FD_INP}/region_enhancer_junke* ${FD_OUT}/
cp ${FD_INP}/region_crispri_growth* ${FD_OUT}/
cp ${FD_INP}/region_crispri_hcrff*  ${FD_OUT}/
cp ${FD_INP}/region_encode_e2g*     ${FD_OUT}/
cp ${FD_INP}/region_summary*        ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# cp: cannot stat '/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/05_prepare_region/region_summary*': No such file or directory
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/05_prepare_region
#
# region_astarr_csaw_01_acquire_data_SH.ipynb
# region_astarr_csaw_02_export_data_R.ipynb
# region_astarr_csaw_03_export_metadata_R.ipynb
# region_astarr_csaw_04_explore_data_R.ipynb
# region_astarr_macs_merge_01_export_data_R.ipynb
# region_astarr_macs_merge_02_export_metadata_R.ipynb
# region_astarr_macs_merge_03_explore_data_R.ipynb
# region_astarr_macs_narrowpeak_01_export_data_R.ipynb
# region_astarr_macs_narrowpeak_02_metadata_R.ipynb
# region_astarr_macs_narrowpeak_03_explore_data_R.ipynb
# region_chromstate_01_create_download_script_R.ipynb
# region_chromstate_02_execute_download_script_SH.ipynb
# region_chromstate_03_export_data_R.ipynb
# region_chromstate_04_export_metadata_R.ipynb
# region_chromstate_05_explore_data_R.ipynb
# ...

# %% [markdown]
# ## Copy notebooks: Region summary

# %%
FD_INP=${FD_NBK}/21_region_summary
FD_OUT=${FD_PRJ}/site/notebooks/21_region_summary
mkdir -p ${FD_OUT}

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/21_region_summary
#
# fig.region.fcc_astarr_macs_input.distribution.gc_content.png
# fig.region.fcc_astarr_macs_input.distribution.gc_content.svg
# fig.region.fcc_astarr_macs_input_merge.distribution.gc_content.png
# fig.region.fcc_astarr_macs_input_merge.distribution.gc_content.svg
# fig.region_pair.atac_tss.distribution.distance.png
# fig.region_pair.atac_tss.distribution.distance.svg
# region_closest_01_atac_tss_SH.ipynb
# region_closest_02_atac_tss_pair_R.ipynb
# region_closest_03_atac_tss_summary_R.ipynb
# region_closest_04_atac_tss_proximity_R.ipynb
# region_closest_05_atac_tss_essential_R.ipynb
# region_closest_06_atac_tss_explore_R.ipynb
# region_nuc_01_atac_SH.ipynb
# region_nuc_02_atac_export_R.ipynb
# region_nuc_03_atac_explore_R.ipynb
# z_region_chromstate_03_explore_regions_R.ipynb
# z_region_closest_01_atac_tss_calc_SH.ipynb
# z_region_closest_04_atac_tss_explore_R.ipynb
# z_region_explore_ocr.ipynb
# ...

# %%
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/region_closest* ${FD_OUT}/
cp ${FD_INP}/region_nuc*     ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/21_region_summary
#
# region_closest_01_atac_tss_SH.ipynb
# region_closest_02_atac_tss_pair_R.ipynb
# region_closest_03_atac_tss_summary_R.ipynb
# region_closest_04_atac_tss_proximity_R.ipynb
# region_closest_05_atac_tss_essential_R.ipynb
# region_closest_06_atac_tss_explore_R.ipynb
# region_nuc_01_atac_SH.ipynb
# region_nuc_02_atac_export_R.ipynb
# region_nuc_03_atac_explore_R.ipynb

# %% [markdown]
# ## Copy notebooks: Region coverage FCC

# %%
FD_INP=${FD_NBK}/22_region_coverage_fcc_score
FD_OUT=${FD_PRJ}/site/notebooks/22_region_coverage_fcc_score
mkdir -p ${FD_OUT}

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/22_region_coverage_fcc_score
#
# 01_region_coverage_count_astarr_SH.ipynb
# 02_region_coverage_count_wstarr_SH.ipynb
# 03_region_coverage_count_tmpra_SH.ipynb
# 04_region_coverage_score_SH.ipynb
# 11_region_coverage_combine_starr_R.ipynb
# 12_region_coverage_combine_tmpra_R.ipynb
# 21_region_coverage_deseq_starr_R.ipynb
# 22_region_coverage_deseq_tmpra_R.ipynb
# 31_region_coverage_summary_starr_R.ipynb
# 32_region_coverage_summary_tmpra_R.ipynb
# 33_region_coverage_summary_lmpra_log2fc_R.ipynb
# 33_region_coverage_summary_lmpra_zscore_R.ipynb
# 34_region_coverage_summary_cgrowth_R.ipynb
# 35_region_coverage_summary_chcrff_R.ipynb
# 36_region_coverage_summary_chcrff_filtered_R.ipynb
# 41_region_coverage_summary_fcc_R.ipynb
# 42_region_coverage_summary_atac_R.ipynb
# 43_region_coverage_summary_test_R.ipynb
# 50_region_coverage_explore_screen_fcc_R.ipynb
# 51_region_coverage_explore_screen_astarr_R.ipynb
# ...

# %%
rm ${FD_OUT}/*ipynb

cp ${FD_INP}/0*_region_coverage_* ${FD_OUT}/
cp ${FD_INP}/1*_region_coverage_* ${FD_OUT}/
cp ${FD_INP}/2*_region_coverage_* ${FD_OUT}/
cp ${FD_INP}/3*_region_coverage_* ${FD_OUT}/
cp ${FD_INP}/4*_region_coverage_* ${FD_OUT}/
cp ${FD_INP}/5*_region_coverage_* ${FD_OUT}/
cp ${FD_INP}/6*_region_coverage_* ${FD_OUT}/
cp ${FD_INP}/7*_region_coverage_* ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/22_region_coverage_fcc_score
#
# 01_region_coverage_count_astarr_SH.ipynb
# 02_region_coverage_count_wstarr_SH.ipynb
# 03_region_coverage_count_tmpra_SH.ipynb
# 04_region_coverage_score_SH.ipynb
# 11_region_coverage_combine_starr_R.ipynb
# 12_region_coverage_combine_tmpra_R.ipynb
# 21_region_coverage_deseq_starr_R.ipynb
# 22_region_coverage_deseq_tmpra_R.ipynb
# 31_region_coverage_summary_starr_R.ipynb
# 32_region_coverage_summary_tmpra_R.ipynb
# 33_region_coverage_summary_lmpra_log2fc_R.ipynb
# 33_region_coverage_summary_lmpra_zscore_R.ipynb
# 34_region_coverage_summary_cgrowth_R.ipynb
# 35_region_coverage_summary_chcrff_R.ipynb
# 36_region_coverage_summary_chcrff_filtered_R.ipynb
# 41_region_coverage_summary_fcc_R.ipynb
# 42_region_coverage_summary_atac_R.ipynb
# 43_region_coverage_summary_test_R.ipynb
# 50_region_coverage_explore_screen_fcc_R.ipynb
# 51_region_coverage_explore_screen_astarr_R.ipynb
# ...

# %% [markdown]
# ## Copy notebooks: Region annotation

# %%
FD_INP=${FD_NBK}/24_region_annotation
FD_OUT=${FD_PRJ}/site/notebooks/24_region_annotation
mkdir -p ${FD_OUT}

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/24_region_annotation
#
# fig.region_annot.astarr_input_overlap.encode_e2g_benchmark.upset.gene.png
# fig.region_annot.astarr_input_overlap.encode_e2g_benchmark.upset.gene.svg
# fig.region_annot.astarr_input_overlap.fcc_crispri_hcrff.upset.gene.png
# fig.region_annot.astarr_input_overlap.fcc_crispri_hcrff.upset.gene.svg
# fig.region_annot.astarr_input_overlap.fcc_starrmpracrispr_vote2.upset.type.png
# fig.region_annot.astarr_input_overlap.fcc_starrmpracrispr_vote2.upset.type.svg
# fig.region_annot.astarr_input_overlap.fcc_starrmpra_junke.by_direction.distribution.gc_content.png
# fig.region_annot.astarr_input_overlap.fcc_starrmpra_junke.by_direction.distribution.gc_content.svg
# fig.region_annot.astarr_input_overlap.fcc_starrmpra_junke.by_direction.distribution.length.png
# fig.region_annot.astarr_input_overlap.fcc_starrmpra_junke.by_direction.distribution.length.svg
# ...

# %%
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/region_astarr_input_0* ${FD_OUT}/

cp ${FD_INP}/region_astarr_input_11_arrange* ${FD_OUT}/
cp ${FD_INP}/region_astarr_input_2* ${FD_OUT}/
cp ${FD_INP}/region_astarr_input_3* ${FD_OUT}/
cp ${FD_INP}/region_astarr_input_4* ${FD_OUT}/
cp ${FD_INP}/region_astarr_input_5* ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/24_region_annotation
#
# region_astarr_input_01_intersect_main_SH.ipynb
# region_astarr_input_02_intersect_hic_SH.ipynb
# region_astarr_input_03_intersect_chipseq_subset_SH.ipynb
# region_astarr_input_04_intersect_chipseq_histone_SH.ipynb
# region_astarr_input_05_intersect_chipseq_full_SH.ipynb
# region_astarr_input_11_arrange_main_R.ipynb
# region_astarr_input_21_export_01_fcc_starrmpra_junke_R.ipynb
# region_astarr_input_21_export_02_fcc_crispri_hcrff_R.ipynb
# region_astarr_input_21_export_03_fcc_crispri_growth_R.ipynb
# region_astarr_input_21_export_04_genome_tss_R.ipynb
# region_astarr_input_21_export_05_encode_e2g_R.ipynb
# region_astarr_input_21_export_06_encode_chromstates_R.ipynb
# region_astarr_input_21_export_07_genome_cres_R.ipynb
# region_astarr_input_22_explore_01_fcc_starrmpra_junke_R.ipynb
# region_astarr_input_22_explore_02_fcc_crispri_hcrff_R.ipynb
# region_astarr_input_22_explore_03_fcc_crispri_growth_R.ipynb
# ...

# %% [markdown]
# ## Copy notebooks: FCC correlation

# %%
FD_INP=${FD_NBK}/41_fcc_correlation
FD_OUT=${FD_PRJ}/site/notebooks/41_fcc_correlation
mkdir -p ${FD_OUT}

echo ${FD_INP}
echo
ls   ${FD_INP}
echo
echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/41_fcc_correlation
#
# 01_region_coverage_concat_export_R.ipynb
# 02_region_coverage_concat_explore_R.ipynb
# 11_ranknorm_overlap_export_starrmpra_R.ipynb
# 12_ranknorm_overlap_export_starrmpracrispr_R.ipynb
# 13_ranknorm_aggreg_export_starrmpracrispr_R.ipynb
# 14_ranknorm_aggreg_explore_starrmpracrispr_R.ipynb
# 21_region_coverage_overlap_explore_ranknorm_starrmpra_R.ipynb
# 22_region_covearge_overlap_explore_ranknorm_starrmpracrispr_R.ipynb
# 23_region_coverage_overlap_explore_log2fc_starrmpra_R.ipynb
# 23_region_coverage_overlap_explore_score_starrmpra_R.ipynb
# 23_region_coverage_overlap_explore_zcore_starrmpra_R.ipynb
# 31_region_coverage_overlap_explore_combine_by_ranknorm_R.ipynb
# 32_region_coverage_overlap_explore_combine_by_log2fc_R.ipynb
# 33_region_coverage_overlap_explore_combine_zoomin_top_R.ipynb
# 34_region_coverage_overlap_explore_combine_zoomin_mid_R.ipynb
# 35_region_coverage_overlap_explore_combine_proximal.ipynb
# ...

# %%
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/region_astarr_input_0* ${FD_OUT}/

cp ${FD_INP}/0*_region_coverage_concat_*          ${FD_OUT}/
cp ${FD_INP}/1*_ranknorm_*                        ${FD_OUT}/
cp ${FD_INP}/2*_region_covearge_overlap_explore_* ${FD_OUT}/
cp ${FD_INP}/3*_region_covearge_overlap_explore_* ${FD_OUT}/
cp ${FD_INP}/4*_starrmpra_vs_crispr_export_*      ${FD_OUT}/
cp ${FD_INP}/5*_starrmpra_vs_crispr_explore_*     ${FD_OUT}/

echo ${FD_OUT}
echo
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/24_region_annotation
#
# region_astarr_input_01_intersect_main_SH.ipynb
# region_astarr_input_02_intersect_hic_SH.ipynb
# region_astarr_input_03_intersect_chipseq_subset_SH.ipynb
# region_astarr_input_04_intersect_chipseq_histone_SH.ipynb
# region_astarr_input_05_intersect_chipseq_full_SH.ipynb
# region_astarr_input_11_arrange_main_R.ipynb
# region_astarr_input_21_export_01_fcc_starrmpra_junke_R.ipynb
# region_astarr_input_21_export_02_fcc_crispri_hcrff_R.ipynb
# region_astarr_input_21_export_03_fcc_crispri_growth_R.ipynb
# region_astarr_input_21_export_04_genome_tss_R.ipynb
# region_astarr_input_21_export_05_encode_e2g_R.ipynb
# region_astarr_input_21_export_06_encode_chromstates_R.ipynb
# region_astarr_input_21_export_07_genome_cres_R.ipynb
# region_astarr_input_22_explore_01_fcc_starrmpra_junke_R.ipynb
# region_astarr_input_22_explore_02_fcc_crispri_hcrff_R.ipynb
# region_astarr_input_22_explore_03_fcc_crispri_growth_R.ipynb
# ...

# %% [markdown]
# **Copy test notebook**

# %%
ls ${FD_NBK}/build_site
# Out:
# 01_create_site.ipynb       04_copy_table_SH.ipynb   test_quarto_files
# 02_copy_notebook_SH.ipynb  11_render_site_SH.ipynb  test_quarto.html
# 03_copy_figure_SH.ipynb    test_notebook.ipynb      test_quarto.ipynb

# %%
FD_INP=${FD_NBK}/build_site
FD_OUT=${FD_PRJ}/site/notebooks/test

mkdir -p ${FD_OUT}
cp ${FD_INP}/test_notebook.ipynb ${FD_OUT}/

# %%
ls ${FD_PRJ}/site/notebooks/test
# Out:
# test_notebook.ipynb

# %% [markdown]
# **Copy notebook for setup**

# %%
FD_INP=${FD_NBK}/01_setup
FD_OUT=${FD_PRJ}/site/notebooks/01_setup

# %%
echo ${FD_INP}
ls   ${FD_INP}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/01_setup
# 01_setup_folder_on_hardac_SH.ipynb       33_check_script_bedtools_SH.ipynb
# 02_setup_config_on_duke_hardac_SH.ipynb  4_targz_results_SH.ipynb
# 03_setup_config_on_sing_SH.ipynb         A.bed
# 04_setup_config_module_SH.ipynb          B.bed
# 11_check_config_and_kernel_PY.ipynb      bedtools
# 12_check_config_and_kernel_R.ipynb       link2test
# 13_check_config_sing_SH.ipynb            link2testgz
# 14_check_config_SH.ipynb                 Readmd.md
# 21_setup_script_test_SH.ipynb            test_bedops_compare_SH.ipynb
# 22_setup_script_SH.ipynb                 test_bedtools_compare_SH.ipynb
# 23_setup_script_app_SH.ipynb             test.txt
# 24_setup_script_bedtools_SH.ipynb        test.txt.gz
# 25_setup_script_ucsc_SH.ipynb            x1_wrap_image.ipynb
# 26_setup_other_SH.ipynb                  x2_test_export.ipynb
# 31_check_script_test_SH.ipynb            x4_summary_info_R.ipynb
# 32_check_script_ucsc_SH.ipynb

# %%
mkdir -p ${FD_OUT}
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/0*_setup*.ipynb ${FD_OUT}/
cp ${FD_INP}/1*_check*.ipynb ${FD_OUT}/
cp ${FD_INP}/2*_setup*.ipynb ${FD_OUT}/
cp ${FD_INP}/3*_check*.ipynb ${FD_OUT}/

# %%
echo ${FD_OUT}
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/01_setup
# 01_setup_folder_on_hardac_SH.ipynb       22_setup_script_SH.ipynb
# 02_setup_config_on_duke_hardac_SH.ipynb  23_setup_script_app_SH.ipynb
# 03_setup_config_on_sing_SH.ipynb         24_setup_script_bedtools_SH.ipynb
# 04_setup_config_module_SH.ipynb          25_setup_script_ucsc_SH.ipynb
# 11_check_config_and_kernel_PY.ipynb      26_setup_other_SH.ipynb
# 12_check_config_and_kernel_R.ipynb       31_check_script_test_SH.ipynb
# 13_check_config_sing_SH.ipynb            32_check_script_ucsc_SH.ipynb
# 14_check_config_SH.ipynb                 33_check_script_bedtools_SH.ipynb
# 21_setup_script_test_SH.ipynb

# %% [markdown]
# **Copy notebook for data preparation**

# %%
FD_INP=${FD_NBK}/02_prepare
FD_OUT=${FD_PRJ}/site/notebooks/02_prepare

# %%
echo ${FD_INP}
ls   ${FD_INP}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks/02_prepare
# fcc_01_acquire_data_STARR_TR_SH.ipynb
# fcc_02_explore_data_STARR_TR_SH.ipynb
# fcc_031_prepare_data_STARR_TR_KS91_SH.ipynb
# fcc_032_prepare_data_STARR_TR_KS274_SH.ipynb
# fcc_04_export_metadata_STARR_TR_R.ipynb
# fcc_11_acquire_data_TMPRA_Hannah_SH.ipynb
# fcc_12_explore_data_TMPRA_Hannah_SH.ipynb
# fcc_13_extract_fragment_counts_R.ipynb
# fcc_14_convert_table_to_bed_R.ipynb
# fcc_15_liftover_TMPRA_OL13_SH.ipynb
# fcc_16_export_ranges_TMPRA_Hannah_R.ipynb
# fcc_17_export_metadata_TMPRA_Hannah_R.ipynb
# fcc_21_acquire_data_LMPRA_Vikram_SH.ipynb
# fcc_22_explore_data_LMPRA_Vikram_R.ipynb
# fcc_23_export_data_LMPRA_Vikram_R.ipynb
# fcc_31_acquire_data_trackhub_JinWoo_SH.ipynb
# fcc_32_extract_info_trackhub_JinWoo_SH.ipynb
# fcc_33_bw2bed_data_trackhub_JinWoo_SH.ipynb
# fcc_34_export_metadata_trackhub_JinWoo_R.ipynb
# fcc_351_prepare_data_crispri_hcrff_JinWoo_R.ipynb
# fcc_352_prepare_data_crispri_growth_JinWoo_R.ipynb
# ...

# %%
mkdir -p ${FD_OUT}
rm ${FD_OUT}/*ipynb
cp ${FD_INP}/region_ocr_0* ${FD_OUT}/
cp ${FD_INP}/fcc_0* ${FD_OUT}/
cp ${FD_INP}/fcc_1* ${FD_OUT}/
cp ${FD_INP}/fcc_2* ${FD_OUT}/
cp ${FD_INP}/fcc_3* ${FD_OUT}/

# %%
echo ${FD_OUT}
ls   ${FD_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/site/notebooks/02_prepare
# fcc_01_acquire_data_STARR_TR_SH.ipynb
# fcc_02_explore_data_STARR_TR_SH.ipynb
# fcc_031_prepare_data_STARR_TR_KS91_SH.ipynb
# fcc_032_prepare_data_STARR_TR_KS274_SH.ipynb
# fcc_04_export_metadata_STARR_TR_R.ipynb
# fcc_11_acquire_data_TMPRA_Hannah_SH.ipynb
# fcc_12_explore_data_TMPRA_Hannah_SH.ipynb
# fcc_13_extract_fragment_counts_R.ipynb
# fcc_14_convert_table_to_bed_R.ipynb
# fcc_15_liftover_TMPRA_OL13_SH.ipynb
# fcc_16_export_ranges_TMPRA_Hannah_R.ipynb
# fcc_17_export_metadata_TMPRA_Hannah_R.ipynb
# fcc_21_acquire_data_LMPRA_Vikram_SH.ipynb
# fcc_22_explore_data_LMPRA_Vikram_R.ipynb
# fcc_23_export_data_LMPRA_Vikram_R.ipynb
# fcc_31_acquire_data_trackhub_JinWoo_SH.ipynb
# fcc_32_extract_info_trackhub_JinWoo_SH.ipynb
# fcc_33_bw2bed_data_trackhub_JinWoo_SH.ipynb
# fcc_34_export_metadata_trackhub_JinWoo_R.ipynb
# fcc_351_prepare_data_crispri_hcrff_JinWoo_R.ipynb
# ...
