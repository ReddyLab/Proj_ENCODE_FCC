# %% [raw]
# ---
# title: Region Coverage 51
# subtitle: Overlap fragments with each region set
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
source ${FD_EXE}/config_load_module_bedtools.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/app/singularity_proj_encode_fcc.sif

# %% [markdown]
# ## Get data

# %%
### set directory
FDIRY=${FD_RES}/region/summary
FNAME=metadata_region_label.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label
# encode_open_chromatin	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# encode_open_chromatin	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz	astarr_macs_input_overlap
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz	astarr_macs_input_union

# %%
### Assay
ASSAY_TYPE=assay_fcc
ASSAY_NAMES=(
    STARR_ATAC_K562_Reddy_KS274
    STARR_ATAC_K562_Reddy_KS91
)

# %%
ls -1 ${FD_RES}/assay_fcc
# Out:
# MPRA_Tiling_K562_Tewhey_hannah
# STARR_ATAC_K562_Reddy_KS274
# STARR_ATAC_K562_Reddy_KS91
# STARR_WHG_K562_Reddy_A001

# %% [markdown]
# ## Check input

# %% [markdown]
# **Test loop: Region**

# %%
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### show progress
    echo ==============================
    echo "Region folder:" ${FOLDER_REG}
    echo "Region label: " ${LABEL_REG}
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union

# %% [markdown]
# **Test loop: Assay**

# %%
for ASSAY_NAME in ${ASSAY_NAMES[@]}; do
    
    ### show progress
    echo ==============================
    echo "Assay name: " ${ASSAY_NAME}
    
    ### Set directory
    FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
    FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
    
    ### loop through each sample
    for FP_INP_B in ${FP_INPS[@]}; do
        FN_INP_B=$(basename ${FP_INP_B})
        echo ${FN_INP_B}
    done
done
# Out:
# ==============================
# Assay name:  STARR_ATAC_K562_Reddy_KS274
# ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
# ==============================
# Assay name:  STARR_ATAC_K562_Reddy_KS91
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz

# %% [markdown]
# **Test loop: Region + Assay**

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=$(dirname ${FD_INP_B})
            FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_fragment
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.overlap.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" ${FN_LOG}
            echo
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt

# %% [markdown]
# ## Execute

# %% [markdown]
# **RUN**

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=$(dirname ${FD_INP_B})
            FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_fragment
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.overlap.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" ${FN_LOG}
            echo
            
            ### execute
            mkdir -p ${FD_OUT}
            sbatch -p ${NODE} \
                --exclude=dl-01 \
                --cpus-per-task 4 \
                --mem 4G \
                --output ${FP_LOG} \
                ${FD_EXE}/run_bedtools_intersect.sh ${FD_PRJ} ${FP_INP_B} ${FP_INP_A} ${FP_OUT}
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743212
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743213
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743214
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743215
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743216
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743217
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743218
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743219
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743220
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743221
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743222
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743223
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF274YGF
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743224
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743225
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743226
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743227
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743228
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743229
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743230
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743231
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743232
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743233
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743234
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743235
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743236
# ==============================
# Region folder: encode_open_chromatin
# Region label:  dnase_ENCFF185XRG
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF185XRG/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.dnase_ENCFF185XRG.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743237
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743238
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743239
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743241
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743242
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743243
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743244
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743245
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743246
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743247
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743248
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743249
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743250
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF558BLC
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF558BLC/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF558BLC.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743251
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743252
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743253
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743254
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743255
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743256
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743257
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743258
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743259
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743260
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743261
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743262
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743263
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF925CYR
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF925CYR/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF925CYR.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743264
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743265
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743266
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743267
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743268
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743269
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743270
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743271
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743272
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743273
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743274
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743275
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743276
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF333TAT
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF333TAT/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF333TAT.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743277
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743278
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743279
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743280
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743281
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743282
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743283
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743284
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743285
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743286
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743287
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743288
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743289
# ==============================
# Region folder: encode_open_chromatin
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/atac_ENCFF948AFM/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.atac_ENCFF948AFM.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743290
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743291
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743292
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743293
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743294
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743295
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743296
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743297
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743298
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743299
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743300
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743301
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743302
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743303
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743304
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743305
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743306
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743307
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743308
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743309
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743310
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743311
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743312
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743313
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743314
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743315
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30743316

# %% [markdown]
# ## Review

# %%
FN_LOG=region.coverage.overlap.dnase_ENCFF274YGF.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
FP_LOG=${FD_LOG}/${FN_LOG}
cat ${FP_LOG}
# Out:
# Hostname:           x3-03-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-04-24+10:48:34
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10125	chr1_10001_10125	1	.
# chr1	10001	10326	chr1_10001_10326	1	.
# chr1	10002	10119	chr1_10002_10119	1	.
# chr1	10002	10125	chr1_10002_10125	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10136	chr1_10002_10136	1	.
# chr1	10002	10137	chr1_10002_10137	1	.
# chr1	10002	10149	chr1_10002_10149	1	.
# chr1	10002	10208	chr1_10002_10208	1	.
# chr1	10002	10220	chr1_10002_10220	1	.
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_open_chromatin/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
#
# show first few lines of input
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_fragment/ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	181120	181433	chr1_181120_181433	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	33
# chr1	181145	181456	chr1_181145_181456	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	56
# chr1	181146	181422	chr1_181146_181422	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	22
# chr1	181146	181429	chr1_181146_181429	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	29
# chr1	181146	181451	chr1_181146_181451	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	51
# chr1	181146	181462	chr1_181146_181462	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	62
# chr1	181146	181485	chr1_181146_181485	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	85
# chr1	181156	181456	chr1_181156_181456	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	56
# chr1	181156	181475	chr1_181156_181475	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	75
# chr1	181156	181484	chr1_181156_181484	1	.	chr1	181400	181530	.	0	.	0.299874	-1	-1	75	84
#
#
# Done!
# Run Time: 10 minutes and 43 seconds

# %%
FN_LOG=region.coverage.overlap.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
FP_LOG=${FD_LOG}/${FN_LOG}
cat ${FP_LOG}
# Out:
# Hostname:           x1-03-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-04-24+10:48:40
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10033	10130	chr1_10033_10130	1	.
# chr1	10057	10233	chr1_10057_10233	3	.
# chr1	10104	10345	chr1_10104_10345	1	.
# chr1	10116	10461	chr1_10116_10461	1	.
# chr1	10147	10430	chr1_10147_10430	1	.
# chr1	10164	10240	chr1_10164_10240	1	.
# chr1	10231	10455	chr1_10231_10455	1	.
# chr1	10342	10461	chr1_10342_10461	1	.
# chr1	10371	10441	chr1_10371_10441	1	.
# chr1	10706	10975	chr1_10706_10975	1	.
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment/ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10033	10130	chr1_10033_10130	1	.	chr1	10015	10442	97
# chr1	10057	10233	chr1_10057_10233	3	.	chr1	10015	10442	176
# chr1	10104	10345	chr1_10104_10345	1	.	chr1	10015	10442	241
# chr1	10116	10461	chr1_10116_10461	1	.	chr1	10015	10442	326
# chr1	10147	10430	chr1_10147_10430	1	.	chr1	10015	10442	283
# chr1	10164	10240	chr1_10164_10240	1	.	chr1	10015	10442	76
# chr1	10231	10455	chr1_10231_10455	1	.	chr1	10015	10442	211
# chr1	10342	10461	chr1_10342_10461	1	.	chr1	10015	10442	100
# chr1	10371	10441	chr1_10371_10441	1	.	chr1	10015	10442	70
# chr1	14096	14772	chr1_14096_14772	1	.	chr1	14253	14645	392
#
#
# Done!
# Run Time: 3 minutes and 23 seconds
