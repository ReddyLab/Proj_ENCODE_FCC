# %% [raw]
# ---
# title: Library complexity at OCR 02
# subtitle: Overlap fragments with each region set and get unique fragments
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
source ${FD_EXE}/config_load_module_bedtools.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/app/singularity_proj_encode_fcc.sif

# %% [markdown]
# ## Prepare

# %% [markdown]
# **Check data**

# %%
### set directory
FDIRY=${FD_RES}/region/summary
FNAME=metadata_region_label.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label
# encode_open_chromatin	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# encode_open_chromatin	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz	astarr_macs_input_overlap
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz	astarr_macs_input_union

# %%
ls -1 ${FD_RES}/assay_fcc
# Out:
# CRISPRi_FlowFISH_K562_Riley_JinWoo
# CRISPRi_Growth_K562_Gersbach_JinWoo
# MPRA_Tiling_K562_Tewhey_Hannah
# STARR_ATAC_K562_Reddy_KS274
# STARR_ATAC_K562_Reddy_KS91
# STARR_WHG_K562_Reddy_A001

# %% [markdown]
# **Set global environment**

# %%
### Assay
ASSAY_TYPE=assay_fcc
ASSAY_NAMES=(
    STARR_ATAC_K562_Reddy_KS274
    STARR_ATAC_K562_Reddy_KS91
    STARR_WHG_K562_Reddy_A001
)

# %% [markdown]
# **Test loop: Region**

# %%
cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}'
# Out:
# encode_open_chromatin	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# encode_open_chromatin	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# encode_open_chromatin	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# encode_open_chromatin	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz	astarr_macs_input_overlap
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz	astarr_macs_input_union

# %%
cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | grep fcc_astarr_macs
# Out:
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz	astarr_macs_input_overlap
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz	astarr_macs_input_union

# %%
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### show progress
    echo ==============================
    echo "Region folder:" ${FOLDER_REG}
    echo "Region label: " ${LABEL_REG}
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | grep fcc_astarr_macs)
# Out:
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union

# %% [markdown]
# **Test loop: Assay**

# %%
for ASSAY_NAME in ${ASSAY_NAMES[@]}; do
    
    ### show progress
    echo ==============================
    echo "Assay name: " ${ASSAY_NAME}
    
    ### Set directory
    FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
    FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
    
    ### loop through each sample
    for FP_INP_B in ${FP_INPS[@]}; do
        FN_INP_B=$(basename ${FP_INP_B})
        echo ${FN_INP_B}
    done
done
# Out:
# ==============================
# Assay name:  STARR_ATAC_K562_Reddy_KS274
# ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
# ==============================
# Assay name:  STARR_ATAC_K562_Reddy_KS91
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
# ==============================
# Assay name:  STARR_WHG_K562_Reddy_A001
# WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz

# %% [markdown]
# **Test loop: Region + Assay**

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=$(dirname ${FD_INP_B})
            FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_fragment_unique
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.overlap.unique.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" ${FN_LOG}
            echo
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | grep fcc_astarr_macs)
# Out:
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt

# %% [markdown]
# ## Execute

# %% [markdown]
# **RUN**

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=$(dirname ${FD_INP_B})
            FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_fragment_unique
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.overlap.unique.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" ${FN_LOG}
            echo
            
            ### execute
            mkdir -p ${FD_OUT}
            sbatch -p ${NODE} \
                --exclude=dl-01 \
                --cpus-per-task 4 \
                --mem 4G \
                --output ${FP_LOG} \
                ${FD_EXE}/run_bedtools_intersect_unique.sh ${FD_PRJ} ${FP_INP_B} ${FP_INP_A} ${FP_OUT}
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | grep fcc_astarr_macs)
# Out:
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760638
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760639
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760640
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760641
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760642
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760643
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760644
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760645
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760646
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760647
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760648
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760649
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760650
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760651
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760652
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760653
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760654
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760655
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760656
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_overlap
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_overlap/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_overlap.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760657
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760658
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760659
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760660
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760661
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760662
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760663
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760664
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760665
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760666
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760667
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760668
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760669
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760670
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760671
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760672
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760673
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760674
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760675
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760676
# ==============================
# Region folder: fcc_astarr_macs
# Region label:  astarr_macs_input_union
# Assay  name:   STARR_WHG_K562_Reddy_A001
#
# Output fdiry:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_WHG_K562_Reddy_A001/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_fragment_unique
# Output fname:  WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: region.coverage.overlap.unique.astarr_macs_input_union.WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 30760677

# %% [markdown]
# ## Review

# %% [markdown]
# **Check results**

# %%
FN_LOG=region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
FP_LOG=${FD_LOG}/${FN_LOG}
cat ${FP_LOG}
# Out:
# Hostname:           x3-03-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-02-24+22:30:03
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10033	10130	chr1_10033_10130	1	.
# chr1	10057	10233	chr1_10057_10233	3	.
# chr1	10104	10345	chr1_10104_10345	1	.
# chr1	10116	10461	chr1_10116_10461	1	.
# chr1	10147	10430	chr1_10147_10430	1	.
# chr1	10164	10240	chr1_10164_10240	1	.
# chr1	10231	10455	chr1_10231_10455	1	.
# chr1	10342	10461	chr1_10342_10461	1	.
# chr1	10371	10441	chr1_10371_10441	1	.
# chr1	10706	10975	chr1_10706_10975	1	.
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_unique/ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10033	10130	chr1_10033_10130	1	.
# chr1	10057	10233	chr1_10057_10233	3	.
# chr1	10104	10345	chr1_10104_10345	1	.
# chr1	10116	10461	chr1_10116_10461	1	.
# chr1	10147	10430	chr1_10147_10430	1	.
# chr1	10164	10240	chr1_10164_10240	1	.
# chr1	10231	10455	chr1_10231_10455	1	.
# chr1	10342	10461	chr1_10342_10461	1	.
# chr1	10371	10441	chr1_10371_10441	1	.
# chr1	14096	14772	chr1_14096_14772	1	.
#
#
# Done!
# Run Time: 18 minutes and 35 seconds

# %%
FN_LOG=region.coverage.overlap.unique.dnase_ENCFF274YGF.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
FP_LOG=${FD_LOG}/${FN_LOG}
cat ${FP_LOG}
# Out:
# Hostname:           x1-01-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-02-24+22:29:59
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	14145	14485	chr1:14145-14485	2	.
# chr1	14243	14498	chr1:14243-14498	1	.
# chr1	14454	14729	chr1:14454-14729	1	.
# chr1	14522	14725	chr1:14522-14725	1	.
# chr1	14599	14850	chr1:14599-14850	1	.
# chr1	14659	14864	chr1:14659-14864	2	.
# chr1	14781	15268	chr1:14781-15268	1	.
# chr1	15172	15659	chr1:15172-15659	1	.
# chr1	15503	15729	chr1:15503-15729	3	.
# chr1	15508	15711	chr1:15508-15711	4	.
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_open_chromatin/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
#
# show first few lines of input
# chr1	181400	181530	.	0	.	0.299874	-1	-1	75
# chr1	778660	778800	.	0	.	14.1383	-1	-1	75
# chr1	779137	779200	.	0	.	0.33144	-1	-1	75
# chr1	827460	827554	.	0	.	3.38384	-1	-1	75
# chr1	842880	843060	.	0	.	1.64457	-1	-1	75
# chr1	869800	869980	.	0	.	2.23485	-1	-1	75
# chr1	875760	875920	.	0	.	0.356692	-1	-1	75
# chr1	898828	899004	.	0	.	0.363005	-1	-1	75
# chr1	900030	900100	.	0	.	0.249369	-1	-1	75
# chr1	901580	901645	.	0	.	0.217803	-1	-1	75
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_unique/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	181292	181550	chr1:181292-181550	1	.
# chr1	181319	181484	chr1:181319-181484	1	.
# chr1	181319	181485	chr1:181319-181485	1	.
# chr1	181319	181538	chr1:181319-181538	2	.
# chr1	181340	181494	chr1:181340-181494	1	.
# chr1	181341	181494	chr1:181341-181494	1	.
# chr1	181366	181462	chr1:181366-181462	2	.
# chr1	181390	181518	chr1:181390-181518	3	.
# chr1	181395	181444	chr1:181395-181444	1	.
# chr1	181400	181492	chr1:181400-181492	1	.
#
#
# Done!
# Run Time: 4 minutes and 14 seconds

# %%
FN_LOG=region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
FP_LOG=${FD_LOG}/${FN_LOG}
cat ${FP_LOG}
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-02-24+22:30:03
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_unique/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
#
# Done!
# Run Time: 1 hours 16 minutes and 4 seconds

# %%
ls -l /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_unique/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# Out:
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:45 /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/coverage/encode_open_chromatin/dnase_ENCFF274YGF/overlap_unique/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz

# %%
FDIRY=${FD_RES}
FDIRY=${FDIRY}/assay_fcc
FDIRY=${FDIRY}/STARR_ATAC_K562_Reddy_KS91/coverage
FDIRY=${FDIRY}/fcc_astarr_macs
FDIRY=${FDIRY}/astarr_macs_input_union
ls ${FDIRY}
# Out:
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
# overlap_unique
# summary

# %%
FDIRY=${FD_RES}
FDIRY=${FDIRY}/assay_fcc
FDIRY=${FDIRY}/STARR_ATAC_K562_Reddy_KS91/coverage
FDIRY=${FDIRY}/fcc_astarr_macs
FDIRY=${FDIRY}/astarr_macs_input_union
FDIRY=${FDIRY}/overlap_unique
ls -lh ${FDIRY}
# Out:
# total 5.0K
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 20 Apr  2 21:42 ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz

# %%
### loop through each region set
while read FOLDER_REG FNAME_REG LABEL_REG; do
    
    ### Set directory
    FD_INP_A=${FD_RES}/region/${FOLDER_REG}
    FN_INP_A=${FNAME_REG}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
            ### setup input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=$(dirname ${FD_INP_B})
            FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_unique
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.overlap.unique.${LABEL_REG}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_REG}
            echo "Region label: " ${LABEL_REG}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Output fdiry: " ${FD_OUT}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" ${FN_LOG}
            echo
            
            ### execute
            mkdir -p ${FD_OUT}
            sbatch -p ${NODE} \
                --exclude=dl-01 \
                --cpus-per-task 4 \
                --mem 4G \
                --output ${FP_LOG} \
                ${FD_EXE}/run_bedtools_intersect_unique.sh ${FD_PRJ} ${FP_INP_B} ${FP_INP_A} ${FP_OUT}
        done
    done
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')

# %% [markdown]
# ## Test

# %%
FOLDER_REG=fcc_astarr_macs
LABEL_REG=astarr_macs_input_union
FNAME_REG=ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz

FD_INP_A=${FD_RES}/region/${FOLDER_REG}
FN_INP_A=${FNAME_REG}
FP_INP_A=${FD_INP_A}/${FN_INP_A}

zcat ${FP_INP_A} | head
# Out:
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429

# %%
ASSAY_NAME=STARR_ATAC_K562_Reddy_KS91
FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
FN_INP_B=ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
FP_INP_B=${FD_INP_B}/${FN_INP_B}

zcat ${FP_INP_B} | head
# Out:
# chr1	10057	10233	chr1_10057_10233	2	.
# chr1	10188	10442	chr1_10188_10442	1	.
# chr1	10285	10349	chr1_10285_10349	1	.
# chr1	10287	10332	chr1_10287_10332	1	.
# chr1	10365	10449	chr1_10365_10449	1	.
# chr1	10389	10442	chr1_10389_10442	1	.
# chr1	13471	13708	chr1_13471_13708	1	.
# chr1	14098	14507	chr1_14098_14507	1	.
# chr1	14132	14498	chr1_14132_14498	1	.
# chr1	14134	14498	chr1_14134_14498	1	.

# %%
### setup output file
FD_OUT=$(dirname ${FD_INP_B})
FD_OUT=${FD_OUT}/coverage/${FOLDER_REG}/${LABEL_REG}/overlap_unique
FN_OUT=${FN_INP_B}
FP_OUT=${FD_OUT}/${FN_OUT}

echo ${FP_OUT}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/coverage/fcc_astarr_macs/astarr_macs_input_union/overlap_unique/ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz

# %%
### setup log file
FN_LOG=region.coverage.overlap.unique.${LABEL_REG}.${FN_OUT}.txt
FP_LOG=${FD_LOG}/${FN_LOG}

echo ${FP_LOG}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log/region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt

# %% [markdown]
# ```
# sbatch -p ${NODE} \
#     --exclude=dl-01 \
#     --cpus-per-task 4 \
#     --mem 4G \
#     --output ${FP_LOG} \
#     ${FD_EXE}/run_bedtools_intersect_unique.sh ${FD_PRJ} ${FP_INP_B} ${FP_INP_A} ${FP_OUT}
# ```

# %%
cat /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log/region.coverage.overlap.unique.astarr_macs_input_union.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           x1-02-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         04-02-24+22:30:03
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
