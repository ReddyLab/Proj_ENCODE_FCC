# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import data

# %%
txt_assay = "STARR_ATAC_K562_Reddy_KS91"
txt_fdiry = file.path(
    FD_RES, 
    "assay_fcc", 
    txt_assay,
    "fragment_counts",
    "summary"
)
txt_fname = "metadata.size.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_lib_size_KS91 = dat
head(dat)
# Out:
#   FName
# 1 ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# 2 ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# 3 ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# 4 ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# 5 ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# 6 ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#   Assay                      Prefix              Group Sample     Size_Unique
# 1 STARR_ATAC_K562_Reddy_KS91 ASTARRseq_K562_KS91 Input Input.rep1 348695063
# 2 STARR_ATAC_K562_Reddy_KS91 ASTARRseq_K562_KS91 Input Input.rep2 451369741
# 3 STARR_ATAC_K562_Reddy_KS91 ASTARRseq_K562_KS91 Input Input.rep3 487579055
# 4 STARR_ATAC_K562_Reddy_KS91 ASTARRseq_K562_KS91 Input Input.rep4 456246254
# 5 STARR_ATAC_K562_Reddy_KS91 ASTARRseq_K562_KS91 Input Input.rep5 444268950
# 6 STARR_ATAC_K562_Reddy_KS91 ASTARRseq_K562_KS91 Input Input.rep6 397333562
#   Size_Total
# 1 348695063
# 2 451369741
# 3 487579055
# ...

# %%
txt_assay = "STARR_ATAC_K562_Reddy_KS274"
txt_fdiry = file.path(
    FD_RES, 
    "assay_fcc", 
    txt_assay,
    "fragment_counts",
    "summary"
)
txt_fname = "metadata.size.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_lib_size_KS274 = dat
head(dat)
# Out:
#   FName
# 1 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 2 ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
# 3 ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#   Assay                       Prefix               Group  Sample
# 1 STARR_ATAC_K562_Reddy_KS274 ASTARRseq_K562_KS274 Output Output.rep1
# 2 STARR_ATAC_K562_Reddy_KS274 ASTARRseq_K562_KS274 Output Output.rep2
# 3 STARR_ATAC_K562_Reddy_KS274 ASTARRseq_K562_KS274 Output Output.rep3
#   Size_Unique Size_Total
# 1 41119652    75921554
# 2 33845018    61846404
# 3 46177734    80233063

# %%
txt_assay = "STARR_WHG_K562_Reddy_A001"
txt_fdiry = file.path(
    FD_RES, 
    "assay_fcc", 
    txt_assay,
    "fragment_counts",
    "summary"
)
txt_fname = "metadata.size.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_lib_size_A001 = dat
head(dat)
# Out:
#   FName
# 1 WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
# 2 WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
# 3 WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
# 4 WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
# 5 WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
# 6 WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
#   Assay                     Prefix              Group  Sample      Size_Unique
# 1 STARR_WHG_K562_Reddy_A001 WSTARRseq_K562_A001 Input  Input.rep1   26908970
# 2 STARR_WHG_K562_Reddy_A001 WSTARRseq_K562_A001 Input  Input.rep2   99899775
# 3 STARR_WHG_K562_Reddy_A001 WSTARRseq_K562_A001 Input  Input.rep3  105623984
# 4 STARR_WHG_K562_Reddy_A001 WSTARRseq_K562_A001 Input  Input.rep4  108635002
# 5 STARR_WHG_K562_Reddy_A001 WSTARRseq_K562_A001 Output Output.rep1 160349140
# 6 STARR_WHG_K562_Reddy_A001 WSTARRseq_K562_A001 Output Output.rep2 157326312
#   Size_Total
# 1  26908970
# 2  99899775
# 3 105623984
# ...

# %%
dat = bind_rows(dat_lib_size_KS91, dat_lib_size_KS274, dat_lib_size_A001)
dat_lib_size = dat
dat
# Out:
#    FName
# 1  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# 2  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# 3  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# 4  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# 5  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# 6  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# 7  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# 8  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# 9  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# 10 ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
# 11 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 12 ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
# 13 ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
# 14 WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
# 15 WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
# ...

# %%
txt_assay = "STARR_ATAC_K562_Reddy_KS91"
txt_fdiry = file.path(
    FD_RES, 
    "assay_fcc", 
    txt_assay,
    "coverage", 
    "fcc_astarr_macs", 
    "astarr_macs_input_union",
    "overlap_count",
    "summary"
)
txt_fname = "result.score.mean.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_score_astarr = dat
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Region           Input_FPKM  Input_TPM Output_FPKM
# 1 chr1  10015      10442    chr1:10015-10442 0.003083020 3.160573  0.0006187167
# 2 chr1  14253      14645    chr1:14253-14645 0.002176306 2.231167  0.0019510008
# 3 chr1  16015      16477    chr1:16015-16477 0.002554920 2.619283  0.0009084734
# 4 chr1  17237      17772    chr1:17237-17772 0.004051316 4.153273  0.0011264281
# 5 chr1  28903      29613    chr1:28903-29613 0.002907835 2.981219  0.0006404741
# 6 chr1  30803      31072    chr1:30803-31072 0.002793456 2.863264  0.0021818358
#   Output_TPM
# 1 0.6571619
# 2 2.0734986
# 3 0.9661250
# 4 1.2014016
# 5 0.6827709
# 6 2.3197849

# %%
dat = dat_score_astarr
dat = dat %>% dplyr::arrange(-Input_TPM)
vec = dat$Region

vec_txt_region = vec
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Region                  Input_FPKM Input_TPM
# 1 chr22 21735349   21736556 chr22:21735349-21736556 0.10795469 110.68905
# 2 chr13 91346980   91349411 chr13:91346980-91349411 0.10665694 109.35470
# 3 chr22 20916756   20918312 chr22:20916756-20918312 0.09937897 101.89384
# 4 chr22 21628337   21630433 chr22:21628337-21630433 0.09146123  93.77399
# 5 chr22 21641359   21643456 chr22:21641359-21643456 0.08821299  90.44383
# 6 chr22 20858084   20859511 chr22:20858084-20859511 0.08596410  88.14075
#   Output_FPKM Output_TPM
# 1 0.04136528   44.13293
# 2 0.14607039  155.94848
# 3 0.24064077  256.18196
# 4 0.12925010  137.63261
# 5 0.08341200   88.74938
# 6 0.08762421   93.35384

# %%
dat = dat_score_astarr
table(dat$Chrom)
# Out:
#  chr1 chr10 chr11 chr12 chr13 chr14 chr15 chr16 chr17 chr18 chr19  chr2 chr20
# 30534 11398 12010 10725  3675  4386  7965  8999 10104  5088  8447 19379  6046
# chr21 chr22  chr3  chr4  chr5  chr6  chr7  chr8  chr9  chrX
#  4241  4946 14422 10120 13453 18166 20036 10120  8378  4214

# %%
vec_txt_assay = c(
    "STARR_ATAC_K562_Reddy_KS274",
    "STARR_ATAC_K562_Reddy_KS91",
    "STARR_WHG_K562_Reddy_A001"
)
vec_txt_assay
# Out:
# [1] "STARR_ATAC_K562_Reddy_KS274" "STARR_ATAC_K562_Reddy_KS91"
# [3] "STARR_WHG_K562_Reddy_A001"

# %%
for (txt_assay in vec_txt_assay){
    cat(txt_assay, "\n")
    txt_fdiry = file.path(
        FD_RES, 
        "assay_fcc", 
        txt_assay,
        "coverage", 
        "fcc_astarr_macs", 
        "astarr_macs_input_union",
        "overlap_count_one2one"
    )
    vec = dir(txt_fdiry)
    print(vec)
}
# Out:
# STARR_ATAC_K562_Reddy_KS274
# [1] "ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [2] "ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [3] "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz"
# STARR_ATAC_K562_Reddy_KS91
# [1] "ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [2] "ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [3] "ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz"
# [4] "ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz"
# STARR_WHG_K562_Reddy_A001
# [1] "WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz"
# [2] "WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz"
# [3] "WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz"

# %%
lst = lapply(vec_txt_assay, function(txt_assay){
    txt_fdiry = file.path(
        FD_RES, 
        "assay_fcc", 
        txt_assay,
        "coverage", 
        "fcc_astarr_macs", 
        "astarr_macs_input_union",
        "overlap_count_one2one"
    )

    vec_txt_fname = dir(txt_fdiry)
    vec_txt_cname = c("Chrom", "ChromStart", "ChromEnd", "Count_Unique", "Count_Total")

    lst = lapply(vec_txt_fname, function(txt_fname){
        txt_fpath = file.path(txt_fdiry, txt_fname)
        dat = read_tsv(txt_fpath, col_names = vec_txt_cname, show_col_types = FALSE)
        dat = dat %>% dplyr::mutate(Region = paste0(Chrom, ":", ChromStart, "-", ChromEnd))

        dat = dat %>% dplyr::filter(Chrom != "chrM")
        
        dat = dat %>% 
            dplyr::mutate(Region = factor(Region, levels=vec_txt_region)) %>%
            dplyr::arrange(Region) %>%
            dplyr::mutate(
                CumSum_Index  = 1:nrow(dat),
                CumSum_Total  = cumsum(Count_Total),
                CumSum_Unique = cumsum(Count_Unique)
            ) %>%
            dplyr::mutate(FName = txt_fname)
        return(dat)
    })
    dat = bind_rows(lst)
    return(dat)
})
dat = bind_rows(lst)

### assign and show
dat_count_cumsum = dat
print(dim(dat))
head(dat)
# Out:
# [1] 2352762      10
#   Chrom ChromStart ChromEnd Count_Unique Count_Total Region
# 1 chr22 21735349   21736556  964         1556        chr22:21735349-21736556
# 2 chr13 91346980   91349411 3918         6396        chr13:91346980-91349411
# 3 chr22 20916756   20918312 3388         6006        chr22:20916756-20918312
# 4 chr22 21628337   21630433 2838         4685        chr22:21628337-21630433
# 5 chr22 21641359   21643456 2595         4357        chr22:21641359-21643456
# 6 chr22 20858084   20859511 1901         3557        chr22:20858084-20859511
#   CumSum_Index CumSum_Total CumSum_Unique
# 1 1             1556          964
# 2 2             7952         4882
# 3 3            13958         8270
# 4 4            18643        11108
# 5 5            23000        13703
# 6 6            26557        15604
#   FName
# 1 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 2 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ...

# %%
dat = dplyr::left_join(
    dat_count_cumsum, 
    dat_lib_size, by="FName")
dat = dat %>%
    dplyr::mutate(
        CumFreq_Unique = CumSum_Unique / Size_Unique,
        CumFreq_Total  = CumSum_Total  / Size_Total,
        
    )
dat_count_cumsum_full = dat
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Count_Unique Count_Total Region
# 1 chr22 21735349   21736556  964         1556        chr22:21735349-21736556
# 2 chr13 91346980   91349411 3918         6396        chr13:91346980-91349411
# 3 chr22 20916756   20918312 3388         6006        chr22:20916756-20918312
# 4 chr22 21628337   21630433 2838         4685        chr22:21628337-21630433
# 5 chr22 21641359   21643456 2595         4357        chr22:21641359-21643456
# 6 chr22 20858084   20859511 1901         3557        chr22:20858084-20859511
#   CumSum_Index CumSum_Total CumSum_Unique
# 1 1             1556          964
# 2 2             7952         4882
# 3 3            13958         8270
# 4 4            18643        11108
# 5 5            23000        13703
# 6 6            26557        15604
#   FName
# 1 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 2 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 3 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ...

# %%
dat = dat_count_cumsum_full
gpt = ggplot(dat, aes(x=CumSum_Total, y=CumSum_Unique, group=FName, color=FName)) +
    geom_line() +
    labs(x = "Cumulative Fragments", y = "Cumulative Unique Fragments") +
    theme_cowplot() +
    background_grid() 
options(repr.plot.width=13, repr.plot.height=7)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_count_cumsum
gpt = ggplot(dat, aes(x=CumSum_Index, y=CumSum_Unique, group=FName, color=FName)) +
    geom_line() +
    labs(x = "Ranked Accessibility", y = "Cumulative Unique Fragments") +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=13, repr.plot.height=7)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_count_cumsum
gpt = ggplot(dat, aes(x=CumSum_Index, y=CumSum_Total, group=FName, color=FName)) +
    geom_line() +
    labs(x = "Ranked Accessibility", y = "Cumulative Total Fragments") +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=13, repr.plot.height=7)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_count_cumsum_full
gpt = ggplot(dat, aes(x=CumSum_Index, y=CumFreq_Total, group=FName, color=FName)) +
    geom_line() +
    labs(x = "Ranked Accessibility", y = "Cumulative Total Fragments / Library Size") +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=13, repr.plot.height=7)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_count_cumsum_full
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Count_Unique Count_Total Region
# 1 chr22 21735349   21736556  964         1556        chr22:21735349-21736556
# 2 chr13 91346980   91349411 3918         6396        chr13:91346980-91349411
# 3 chr22 20916756   20918312 3388         6006        chr22:20916756-20918312
# 4 chr22 21628337   21630433 2838         4685        chr22:21628337-21630433
# 5 chr22 21641359   21643456 2595         4357        chr22:21641359-21643456
# 6 chr22 20858084   20859511 1901         3557        chr22:20858084-20859511
#   CumSum_Index CumSum_Total CumSum_Unique
# 1 1             1556          964
# 2 2             7952         4882
# 3 3            13958         8270
# 4 4            18643        11108
# 5 5            23000        13703
# 6 6            26557        15604
#   FName
# 1 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 2 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 3 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ...

# %%
dat = dat_count_cumsum_full
dat = dat %>% dplyr::mutate(Length = ChromEnd-ChromStart)
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Count_Unique Count_Total Region
# 1 chr22 21735349   21736556  964         1556        chr22:21735349-21736556
# 2 chr13 91346980   91349411 3918         6396        chr13:91346980-91349411
# 3 chr22 20916756   20918312 3388         6006        chr22:20916756-20918312
# 4 chr22 21628337   21630433 2838         4685        chr22:21628337-21630433
# 5 chr22 21641359   21643456 2595         4357        chr22:21641359-21643456
# 6 chr22 20858084   20859511 1901         3557        chr22:20858084-20859511
#   CumSum_Index CumSum_Total CumSum_Unique
# 1 1             1556          964
# 2 2             7952         4882
# 3 3            13958         8270
# 4 4            18643        11108
# 5 5            23000        13703
# 6 6            26557        15604
#   FName
# 1 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 2 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# 3 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ...

# %%
gpt = ggplot(dat, aes(x=CumSum_Index, y=Length, group=FName, color=FName)) +
    geom_line() +
    #labs(x = "Ranked Accessibility", y = "Cumulative Total Fragments / Library Size") +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=13, repr.plot.height=7)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_count_cumsum_full
dat = dat %>% dplyr::filter(FName == "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz")
tail(dat, 20)
# Out:
#    Chrom ChromStart ChromEnd  Count_Unique Count_Total
# 1  chr2  106466739  106467837      1             1
# 2  chr13 113752182  113752863      3             5
# 3  chr1  248383280  248384332      5             8
# 4  chr15 101892600  101893647      2             3
# 5  chr7   12526789   12528298     21            24
# 6  chr6  169126278  169127507      4             4
# 7  chr12    420022     421619      3             3
# 8  chr15  23047144   23048007      3             3
# 9  chr2  242008034  242010034      5             5
# 10 chr5   69633357   69635182      5             8
# 11 chr5     260684     262125      2             3
# 12 chr17  43271129   43272843     19            20
# 13 chr15 101754400  101755262      2             2
# 14 chr18  79357349   79358369      1             1
# 15 chr21   8219783    8221061    758          1054
# 16 chr21   8396525    8397035      3             3
# 17 chrM        119       4332 353621       5243567
# ...

# %%
dat = dat_count_cumsum_full
dat = dat %>% dplyr::filter(FName == "ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz")
table(tmp$Chrom)
# Out:
#  chr1 chr10 chr11 chr12 chr13 chr14 chr15 chr16 chr17 chr18 chr19  chr2 chr20
# 30522 11387 12004 10722  3674  4383  7953  8989 10098  5085  8441 19369  6044
# chr21 chr22  chr3  chr4  chr5  chr6  chr7  chr8  chr9  chrM  chrX
#  4227  4934 14415 10118 13444 18164 20029 10115  8375     4  4207

# %%
dat = dat_count_cumsum_full
dat = dat %>% dplyr::filter(Chrom == "chrM")
dat
# Out:
#    Chrom ChromStart ChromEnd Count_Unique Count_Total Region CumSum_Index
# 1  chrM   119        4332    340576       4835307     NA     246699
# 2  chrM  4783        5593     41886        374463     NA     246700
# 3  chrM  6179        8238    113511       1539086     NA     246701
# 4  chrM  9091       16274    563271       7075204     NA     246702
# 5  chrM   119        4332    308856       3970229     NA     246621
# 6  chrM  4783        5593     40214        336763     NA     246622
# 7  chrM  6179        8238    105094       1284631     NA     246623
# 8  chrM  9091       16274    519607       6065260     NA     246624
# 9  chrM   119        4332    353621       5243567     NA     246700
# 10 chrM  4783        5593     46418        437576     NA     246701
# 11 chrM  6179        8238    117635       1648762     NA     246702
# 12 chrM  9091       16274    587088       7826878     NA     246703
# 13 chrM   119        4332     81159         81159     NA     246788
# ...

# %%
dat = dat_count_cumsum_full
dat = dat %>% dplyr::filter(Chrom == "chrM")
dat
# Out:
#    Chrom ChromStart ChromEnd Count_Unique Count_Total Region CumSum_Index
# 1  chrM   119        4332    340576       4835307     NA     246699
# 2  chrM  4783        5593     41886        374463     NA     246700
# 3  chrM  6179        8238    113511       1539086     NA     246701
# 4  chrM  9091       16274    563271       7075204     NA     246702
# 5  chrM   119        4332    308856       3970229     NA     246621
# 6  chrM  4783        5593     40214        336763     NA     246622
# 7  chrM  6179        8238    105094       1284631     NA     246623
# 8  chrM  9091       16274    519607       6065260     NA     246624
# 9  chrM   119        4332    353621       5243567     NA     246700
# 10 chrM  4783        5593     46418        437576     NA     246701
# 11 chrM  6179        8238    117635       1648762     NA     246702
# 12 chrM  9091       16274    587088       7826878     NA     246703
# 13 chrM   119        4332     81159         81159     NA     246788
# ...

# %%
length(lst)
# Out:
# [1] 3

# %%
lst = split(dat, dat$Assay_Name)

# %%
length(lst)
# Out:
# [1] 10

# %%
dat = lst[[1]]
gpt = ggplot(dat, aes(x=CumSum_Total, y=CumSum_Unique, group=Assay_Name, color=Assay_Name)) +
    geom_line() +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=15, repr.plot.height=10)
print(gpt)
# Out:
# plot without title

# %%
dat = lst[[2]]
gpt = ggplot(dat, aes(x=CumSum_Total, y=CumSum_Unique, group=Assay_Name, color=Assay_Name)) +
    geom_line() +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=15, repr.plot.height=10)
print(gpt)
# Out:
# plot without title

# %%
dat = lst[[3]]
gpt = ggplot(dat, aes(x=CumSum_Total, y=CumSum_Unique, group=Assay_Name, color=Assay_Name)) +
    geom_line() +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=15, repr.plot.height=10)
print(gpt)
# Out:
# plot without title

# %%
dat = lst[[4]]
gpt = ggplot(dat, aes(x=CumSum_Total, y=CumSum_Unique, group=Assay_Name, color=Assay_Name)) +
    geom_line() +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=15, repr.plot.height=10)
print(gpt)
# Out:
# plot without title

# %%
dat = lst[[10]]
gpt = ggplot(dat, aes(x=CumSum_Total, y=CumSum_Unique, group=Assay_Name, color=Assay_Name)) +
    geom_line() +
    theme_cowplot() +
    background_grid() #+
    #facet_wrap(~Assay_Name)
options(repr.plot.width=15, repr.plot.height=10)
print(gpt)
# Out:
# Warning message:
# “Removed 34314 rows containing missing values or values outside the
# scale range (`geom_line()`).”
# plot without title

# %%
head(dat)
# Out:
#   Chrom ChromStart ChromEnd  Count_Unique Count_Total Region
# 1 chr13  91346980   91349411 1513         1513        chr13:91346980-91349411
# 2 chr16  84013669   84014797  420          420        chr16:84013669-84014797
# 3 chr19  42267964   42269309 1285         1285        chr19:42267964-42269309
# 4 chr19  54189224   54191599 1290         1290        chr19:54189224-54191599
# 5 chr1   16643694   16645841 1937         1937        chr1:16643694-16645841
# 6 chr1  172532149  172533788  965          965        chr1:172532149-172533788
#   CumSum_Total CumSum_Unique
# 1 1513         1513
# 2 1933         1933
# 3 3218         3218
# 4 4508         4508
# 5 6445         6445
# 6 7410         7410
#   Assay_Name
# 1 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# 2 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# 3 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# 4 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# ...

# %%
tail(dat)
# Out:
#   Chrom ChromStart ChromEnd  Count_Unique Count_Total Region
# 1 chr18  78512974   78514309  20           20         chr18:78512974-78514309
# 2 chr12    420022     421619   1            1         chr12:420022-421619
# 3 chr15  23047144   23048007  48           48         chr15:23047144-23048007
# 4 chr18  79618666   79620638 175          175         chr18:79618666-79620638
# 5 chr17  43271129   43272843   5            5         chr17:43271129-43272843
# 6 chr15 101754400  101755262  11           11         chr15:101754400-101755262
#   CumSum_Total CumSum_Unique
# 1 NA           30122424
# 2 NA           30122425
# 3 NA           30122473
# 4 NA           30122648
# 5 NA           30122653
# 6 NA           30122664
#   Assay_Name
# 1 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# 2 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# 3 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# 4 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# ...

# %%
vec = dat$Count_Total
print(length(vec))
vec[1:10]
# Out:
# [1] 2352782
#  [1] 1556 6396 6006 4685 4357 3557 2579 2252 3877 2675

# %%
vec = dat$Count_Total
tail(vec)
# Out:
# [1] 87 12  5 11 90 19

# %%
vec = cumsum(vec)
tail(vec)
# Out:
# [1] 362864608 362864620 362864625 362864636 362864726 362864745

# %%
vec = dat$Count_Total
which(is.na(vec))
# Out:
# integer(0)

# %%
dat[80808,]
# Out:
#   Chrom ChromStart ChromEnd Count_Unique Count_Total Region
# 1 chr1  46255332   46255796 29           51          chr1:46255332-46255796
#   CumSum_Total CumSum_Unique
# 1 18908009     11947325
#   Assay_Name
# 1 ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
