# %% [raw]
# ---
# title: Annotation of ATAC (ASTARR Input) 04
# subtitle: Intersection (ChIP-seq Histone)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **Set global variables**

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs_merge.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/metadata.label.chipseq_histone.tsv

# %% [markdown]
# ## Prepare

# %% [markdown]
# **View files**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chipseq_tf_full
# encode_chromatin_states
# encode_e2g_benchmark
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs_merge
# fcc_astarr_macs_narrowpeak
# fcc_crispri_growth
# fcc_crispri_hcrff
# fcc_screened
# fcc_starrmpra_junke
# fcc_table
# fcc_table_cluster
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs_merge.tsv
# metadata.label.chipseq_histone.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.chipseq_tf_full.tsv
# metadata.label.hic.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %% [markdown]
# **View: Metatable label A**

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs_merge.tsv
# Folder	FName	Label	FPath
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz

# %%
cat ${FP_REGION_LABEL_A} | cut -f 1,3
# Out:
# Folder	Label
# fcc_astarr_macs_merge	fcc_astarr_macs_input_overlap
# fcc_astarr_macs_merge	fcc_astarr_macs_input_union

# %% [markdown]
# **View: Metatable label B**

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.chipseq_histone.tsv
# Folder	FName	Label	FPath
# encode_chipseq_histone	ENCFF122CSI.bed.gz	encode_chipseq_H3K4me3_ENCFF122CSI	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF122CSI.bed.gz
# encode_chipseq_histone	ENCFF135ZLM.bed.gz	encode_chipseq_H3K4me1_ENCFF135ZLM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF135ZLM.bed.gz
# encode_chipseq_histone	ENCFF148UQI.bed.gz	encode_chipseq_H3K9ac_ENCFF148UQI	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF148UQI.bed.gz
# encode_chipseq_histone	ENCFF193ERO.bed.gz	encode_chipseq_H3K36me3_ENCFF193ERO	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF193ERO.bed.gz
# encode_chipseq_histone	ENCFF209OQD.bed.gz	encode_chipseq_H3K79me2_ENCFF209OQD	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF209OQD.bed.gz
# encode_chipseq_histone	ENCFF213OTI.bed.gz	encode_chipseq_H2AFZ_ENCFF213OTI	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF213OTI.bed.gz
# encode_chipseq_histone	ENCFF323WOT.bed.gz	encode_chipseq_H3K27me3_ENCFF323WOT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF323WOT.bed.gz
# encode_chipseq_histone	ENCFF462AVD.bed.gz	encode_chipseq_H3K9me1_ENCFF462AVD	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF462AVD.bed.gz
# encode_chipseq_histone	ENCFF540NGG.bed.gz	encode_chipseq_H3K4me1_ENCFF540NGG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF540NGG.bed.gz
# encode_chipseq_histone	ENCFF544LXB.bed.gz	encode_chipseq_H3K27ac_ENCFF544LXB	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF544LXB.bed.gz
# encode_chipseq_histone	ENCFF561OUZ.bed.gz	encode_chipseq_H3K36me3_ENCFF561OUZ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF561OUZ.bed.gz
# encode_chipseq_histone	ENCFF689QIJ.bed.gz	encode_chipseq_H3K4me3_ENCFF689QIJ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF689QIJ.bed.gz
# encode_chipseq_histone	ENCFF706WUF.bed.gz	encode_chipseq_H3K4me3_ENCFF706WUF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF706WUF.bed.gz
# encode_chipseq_histone	ENCFF749KLQ.bed.gz	encode_chipseq_H3K4me2_ENCFF749KLQ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF749KLQ.bed.gz
# encode_chipseq_histone	ENCFF801AHF.bed.gz	encode_chipseq_H3K27me3_ENCFF801AHF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF801AHF.bed.gz
# encode_chipseq_histone	ENCFF885FQN.bed.gz	encode_chipseq_H3K4me3_ENCFF885FQN	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF885FQN.bed.gz
# encode_chipseq_histone	ENCFF891CHI.bed.gz	encode_chipseq_H3K9ac_ENCFF891CHI	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF891CHI.bed.gz
# encode_chipseq_histone	ENCFF909RKY.bed.gz	encode_chipseq_H4K20me1_ENCFF909RKY	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF909RKY.bed.gz
# encode_chipseq_histone	ENCFF963GZJ.bed.gz	encode_chipseq_H3K9me3_ENCFF963GZJ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCFF963GZJ.bed.gz

# %%
cat ${FP_REGION_LABEL_B} | cut -f 1,3
# Out:
# Folder	Label
# encode_chipseq_histone	encode_chipseq_H3K4me3_ENCFF122CSI
# encode_chipseq_histone	encode_chipseq_H3K4me1_ENCFF135ZLM
# encode_chipseq_histone	encode_chipseq_H3K9ac_ENCFF148UQI
# encode_chipseq_histone	encode_chipseq_H3K36me3_ENCFF193ERO
# encode_chipseq_histone	encode_chipseq_H3K79me2_ENCFF209OQD
# encode_chipseq_histone	encode_chipseq_H2AFZ_ENCFF213OTI
# encode_chipseq_histone	encode_chipseq_H3K27me3_ENCFF323WOT
# encode_chipseq_histone	encode_chipseq_H3K9me1_ENCFF462AVD
# encode_chipseq_histone	encode_chipseq_H3K4me1_ENCFF540NGG
# encode_chipseq_histone	encode_chipseq_H3K27ac_ENCFF544LXB
# encode_chipseq_histone	encode_chipseq_H3K36me3_ENCFF561OUZ
# encode_chipseq_histone	encode_chipseq_H3K4me3_ENCFF689QIJ
# encode_chipseq_histone	encode_chipseq_H3K4me3_ENCFF706WUF
# encode_chipseq_histone	encode_chipseq_H3K4me2_ENCFF749KLQ
# encode_chipseq_histone	encode_chipseq_H3K27me3_ENCFF801AHF
# encode_chipseq_histone	encode_chipseq_H3K4me3_ENCFF885FQN
# encode_chipseq_histone	encode_chipseq_H3K9ac_ENCFF891CHI
# encode_chipseq_histone	encode_chipseq_H4K20me1_ENCFF909RKY
# encode_chipseq_histone	encode_chipseq_H3K9me3_ENCFF963GZJ

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loop**

# %%
### init: set executable
FN_EXE="run_bedtools_intersect.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### init: check results and log folder
echo "- FD_RES:" ${FD_RES}
echo "- FD_LOG:" ${FD_LOG}

### Loop region A
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do

    ### Set input A
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### Loop region B
    while read FOLDER_B FNAME_B LABEL_B FPATH_B; do
    
        ### Set input B
        FN_INP_B=${FNAME_B}
        FP_INP_B=${FPATH_B}
        
        ### Set output
        FOLDER=region_annotation/${LABEL_A}/${FOLDER_B}
        FD_OUT=${FD_RES}/${FOLDER}
        FN_OUT=${LABEL_A}.${LABEL_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_A}.${LABEL_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Input:"
        echo "- Label A:" ${LABEL_A}
        echo "- Label B:" ${LABEL_B}
        echo "Output:"
        echo "- FDiry:" '${FD_RES}'/${FOLDER}
        echo "- FName:" ${FN_OUT}
        echo "Log:" 
        echo "- FPath:" '${FD_LOG}'/${FN_LOG}
        echo  
        
    done < <(cat ${FP_REGION_LABEL_B} | head -n 3 | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# - FD_RES: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# - FD_LOG: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF122CSI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me3_ENCFF122CSI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt

# %% [markdown]
# **Execute**

# %%
### init: set executable
FN_EXE="run_bedtools_intersect.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### init: check results and log folder
echo "- FD_RES:" ${FD_RES}
echo "- FD_LOG:" ${FD_LOG}

### Loop region A
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do

    ### Set input A
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### Loop region B
    while read FOLDER_B FNAME_B LABEL_B FPATH_B; do
    
        ### Set input B
        FN_INP_B=${FNAME_B}
        FP_INP_B=${FPATH_B}
        
        ### Set output
        FOLDER=region_annotation/${LABEL_A}/${FOLDER_B}
        FD_OUT=${FD_RES}/${FOLDER}
        FN_OUT=${LABEL_A}.${LABEL_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.intersect.${LABEL_A}.${LABEL_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Input:"
        echo "- Label A:" ${LABEL_A}
        echo "- Label B:" ${LABEL_B}
        echo "Output:"
        echo "- FDiry:" '${FD_RES}'/${FOLDER}
        echo "- FName:" ${FN_OUT}
        echo "Log:" 
        echo "- FPath:" '${FD_LOG}'/${FN_LOG}
        echo  
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# - FD_RES: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# - FD_LOG: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF122CSI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# Submitted batch job 277553
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 277554
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9ac_ENCFF148UQI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.txt
#
# Submitted batch job 277555
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K36me3_ENCFF193ERO
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.txt
#
# Submitted batch job 277556
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K79me2_ENCFF209OQD
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.txt
#
# Submitted batch job 277557
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H2AFZ_ENCFF213OTI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.txt
#
# Submitted batch job 277558
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27me3_ENCFF323WOT
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 277559
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9me1_ENCFF462AVD
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.txt
#
# Submitted batch job 277560
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me1_ENCFF540NGG
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.txt
#
# Submitted batch job 277561
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27ac_ENCFF544LXB
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 277562
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K36me3_ENCFF561OUZ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.txt
#
# Submitted batch job 277563
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF689QIJ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.txt
#
# Submitted batch job 277564
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF706WUF
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.txt
#
# Submitted batch job 277565
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 277566
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27me3_ENCFF801AHF
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.txt
#
# Submitted batch job 277567
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF885FQN
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 277568
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9ac_ENCFF891CHI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.txt
#
# Submitted batch job 277569
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H4K20me1_ENCFF909RKY
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.txt
#
# Submitted batch job 277570
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9me3_ENCFF963GZJ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.txt
#
# Submitted batch job 277571
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me3_ENCFF122CSI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# Submitted batch job 277572
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 277573
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K9ac_ENCFF148UQI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.txt
#
# Submitted batch job 277574
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3