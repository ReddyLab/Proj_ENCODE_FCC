# %% [raw]
# ---
# title: FCC Peak calls
# subtitle: export annotation
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import data

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
vec = dir(txt_fdiry)
for (txt in vec){
    cat(txt, "\n")
}
# Out:
# matrix.annotation.encode_chipseq_flagship.tsv
# matrix.annotation.encode_chipseq_full.tsv
# matrix.annotation.encode_chipseq_histone.tsv
# matrix.annotation.encode_chipseq_subset.tsv
# matrix.annotation.fcc_peak_call.tsv
# matrix.annotation.genome_tss.tsv
# matrix.annotation.merge.fcc.tss.chipseq.tsv
# region.annotation.encode_chipseq_flagship.tmp.tsv
# region.annotation.encode_chipseq_flagship.tsv
# region.annotation.encode_chipseq_histone.tsv
# region.annotation.encode_chipseq_subset.tsv
# region.annotation.encode_chromatin_states.tsv
# region.annotation.encode_e2g_benchmark.tsv
# region.annotation.fcc_astarr_csaw.tsv
# region.annotation.fcc_crispri_growth.tsv
# region.annotation.fcc_crispri_hcrff.tsv
# region.annotation.fcc_mpra_agarwal2023.tsv
# region.annotation.fcc_starrmpra_junke.tsv
# region.annotation.genome_tss.tsv
# region.annotation.module_tf_shannon.tsv
# region.intersect.encode_chipseq_flagship.tmp.tsv
# region.intersect.encode_chipseq_flagship.tsv
# region.intersect.encode_chipseq_histone.tsv
# region.intersect.encode_chipseq_subset.tsv
# region.intersect.encode_chromatin_states.tsv
# region.intersect.encode_e2g_benchmark.tsv
# region.intersect.fcc_astarr_csaw.tsv
# region.intersect.fcc_crispri_growth.tsv
# region.intersect.fcc_crispri_hcrff.tsv
# region.intersect.fcc_mpra_agarwal2023.tsv
# region.intersect.fcc_starrmpra_junke.tsv
# region.intersect.genome_tss.tsv
# region.intersect.module_tf_shannon.tsv
# region.summary.encode_chipseq_flagship.tsv
# region.summary.encode_chipseq_full.tsv
# region.summary.encode_chipseq_histone.tsv
# region.summary.encode_chipseq_subset.tsv
# region.summary.encode_e2g_benchmark.regulated.tsv
# region.summary.encode_e2g_benchmark.tsv
# region.summary.fcc_peak_call.assayvote.tsv
# region.summary.fcc_peak_call.label.tsv
# region.summary.fcc_peak_call.tsv
# region.summary.genome_tss.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.fcc_peak_call.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_region_annot_fcc = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 156686      8
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#    <th style="text-align:left;"> Label2 </th>
#    <th style="text-align:left;"> Label3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> Repress (R) </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
#    <td style="text-align:right;"> 16338 </td>
#    <td style="text-align:left;"> chr1:16025-16338 </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> Repress (R) </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 17288 </td>
#    <td style="text-align:right;"> 17689 </td>
#    <td style="text-align:left;"> chr1:17288-17689 </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> Repress (R) </td>
#   </tr>
# </tbody>
# </table>

# %%
dat = dat_region_annot_fcc
vec = unique(dat$Region)
print(length(vec))
table(dat$Group)
# Out:
# [1] 100454
#         ASTARR     CRISPR-E2G CRISPRi-Growth  CRISPRi-HCRFF          LMPRA
#          99884            360           4380             84          20937
#          TMPRA         WSTARR
#            860          30181

# %%
dat = dat_region_annot_fcc
dat = dat %>% 
    dplyr::select(Chrom:Region, Group) %>% 
    dplyr::distinct()
dat = dat %>% 
    dplyr::group_by(Chrom, ChromStart, ChromEnd, Region) %>% 
    dplyr::summarise(
        Num_Assay = n(),
        Assays    = paste(Group, collapse = ","),
        .groups   = "drop"
    )

dat_region_fcc_assayvote = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 100454      6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Num_Assay </th>
#    <th style="text-align:left;"> Assays </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
#    <td style="text-align:right;"> 16338 </td>
#    <td style="text-align:left;"> chr1:16025-16338 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 17288 </td>
#    <td style="text-align:right;"> 17689 </td>
#    <td style="text-align:left;"> chr1:17288-17689 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
# </tbody>
# </table>

# %%
fun_display_table(head(dat, 100))
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Num_Assay </th>
#    <th style="text-align:left;"> Assays </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
#    <td style="text-align:right;"> 16338 </td>
#    <td style="text-align:left;"> chr1:16025-16338 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 17288 </td>
#    <td style="text-align:right;"> 17689 </td>
#    <td style="text-align:left;"> chr1:17288-17689 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 28934 </td>
#    <td style="text-align:right;"> 29499 </td>
#    <td style="text-align:left;"> chr1:28934-29499 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 115429 </td>
#    <td style="text-align:right;"> 115969 </td>
#    <td style="text-align:left;"> chr1:115429-115969 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 136201 </td>
#    <td style="text-align:right;"> 137353 </td>
#    <td style="text-align:left;"> chr1:136201-137353 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 181005 </td>
#    <td style="text-align:right;"> 181854 </td>
#    <td style="text-align:left;"> chr1:181005-181854 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 184091 </td>
#    <td style="text-align:right;"> 184563 </td>
#    <td style="text-align:left;"> chr1:184091-184563 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> WSTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 186343 </td>
#    <td style="text-align:right;"> 187136 </td>
#    <td style="text-align:left;"> chr1:186343-187136 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 191204 </td>
#    <td style="text-align:right;"> 191722 </td>
#    <td style="text-align:left;"> chr1:191204-191722 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 202166 </td>
#    <td style="text-align:right;"> 202422 </td>
#    <td style="text-align:left;"> chr1:202166-202422 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 267910 </td>
#    <td style="text-align:right;"> 268557 </td>
#    <td style="text-align:left;"> chr1:267910-268557 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 605104 </td>
#    <td style="text-align:right;"> 605675 </td>
#    <td style="text-align:left;"> chr1:605104-605675 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:left;"> ASTARR,CRISPRi-Growth </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 727136 </td>
#    <td style="text-align:right;"> 727493 </td>
#    <td style="text-align:left;"> chr1:727136-727493 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 778233 </td>
#    <td style="text-align:right;"> 779389 </td>
#    <td style="text-align:left;"> chr1:778233-779389 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:left;"> ASTARR,LMPRA,WSTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 795924 </td>
#    <td style="text-align:right;"> 796344 </td>
#    <td style="text-align:left;"> chr1:795924-796344 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 812348 </td>
#    <td style="text-align:right;"> 812956 </td>
#    <td style="text-align:left;"> chr1:812348-812956 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 817031 </td>
#    <td style="text-align:right;"> 817525 </td>
#    <td style="text-align:left;"> chr1:817031-817525 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 818708 </td>
#    <td style="text-align:right;"> 819335 </td>
#    <td style="text-align:left;"> chr1:818708-819335 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:left;"> ASTARR,WSTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 826796 </td>
#    <td style="text-align:right;"> 828040 </td>
#    <td style="text-align:left;"> chr1:826796-828040 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:left;"> ASTARR,WSTARR,CRISPRi-Growth </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 842516 </td>
#    <td style="text-align:right;"> 843431 </td>
#    <td style="text-align:left;"> chr1:842516-843431 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:left;"> ASTARR,LMPRA </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 849583 </td>
#    <td style="text-align:right;"> 850403 </td>
#    <td style="text-align:left;"> chr1:849583-850403 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 856221 </td>
#    <td style="text-align:right;"> 856882 </td>
#    <td style="text-align:left;"> chr1:856221-856882 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 864008 </td>
#    <td style="text-align:right;"> 864343 </td>
#    <td style="text-align:left;"> chr1:864008-864343 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 869637 </td>
#    <td style="text-align:right;"> 870233 </td>
#    <td style="text-align:left;"> chr1:869637-870233 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:left;"> ASTARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 876493 </td>
#    <td style="text-align:right;"> 877795 </

# %%
dat = dat_region_fcc_assayvote
table(dat$Num_Assay)
# Out:
#     1     2     3     4     5     6     7
# 66501 22994  9740  1177    31     6     5

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.fcc_peak_call.assayvote.starrmpracrispri.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = dat_region_fcc_assayvote
write_tsv(dat, txt_fpath)
