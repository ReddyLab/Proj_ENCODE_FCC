# %% [raw]
# ---
# title: Region annotation 03 (ASTARR MACS peaks)
# subtitle: Annotate peaks (ChIP-seq; histone)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_flagship
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chromatin_states
# encode_e2g_benchmark
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs
# fcc_crispri_growth
# fcc_crispri_hcrff
# fcc_mpra_agarwal2023
# fcc_screened
# fcc_starrmpra_junke
# fcc_table
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_flagship.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_histone.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/metadata.label.chipseq_histone.tsv

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs.tsv
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.chipseq_histone.tsv
# Folder	FName	Label
# encode_chipseq_histone	ENCFF122CSI.bed.gz	encode_chipseq_H3K4me3_ENCFF122CSI
# encode_chipseq_histone	ENCFF135ZLM.bed.gz	encode_chipseq_H3K4me1_ENCFF135ZLM
# encode_chipseq_histone	ENCFF148UQI.bed.gz	encode_chipseq_H3K9ac_ENCFF148UQI
# encode_chipseq_histone	ENCFF193ERO.bed.gz	encode_chipseq_H3K36me3_ENCFF193ERO
# encode_chipseq_histone	ENCFF209OQD.bed.gz	encode_chipseq_H3K79me2_ENCFF209OQD
# encode_chipseq_histone	ENCFF213OTI.bed.gz	encode_chipseq_H2AFZ_ENCFF213OTI
# encode_chipseq_histone	ENCFF323WOT.bed.gz	encode_chipseq_H3K27me3_ENCFF323WOT
# encode_chipseq_histone	ENCFF462AVD.bed.gz	encode_chipseq_H3K9me1_ENCFF462AVD
# encode_chipseq_histone	ENCFF540NGG.bed.gz	encode_chipseq_H3K4me1_ENCFF540NGG
# encode_chipseq_histone	ENCFF544LXB.bed.gz	encode_chipseq_H3K27ac_ENCFF544LXB
# encode_chipseq_histone	ENCFF561OUZ.bed.gz	encode_chipseq_H3K36me3_ENCFF561OUZ
# encode_chipseq_histone	ENCFF689QIJ.bed.gz	encode_chipseq_H3K4me3_ENCFF689QIJ
# encode_chipseq_histone	ENCFF706WUF.bed.gz	encode_chipseq_H3K4me3_ENCFF706WUF
# encode_chipseq_histone	ENCFF749KLQ.bed.gz	encode_chipseq_H3K4me2_ENCFF749KLQ
# encode_chipseq_histone	ENCFF801AHF.bed.gz	encode_chipseq_H3K27me3_ENCFF801AHF
# encode_chipseq_histone	ENCFF885FQN.bed.gz	encode_chipseq_H3K4me3_ENCFF885FQN
# encode_chipseq_histone	ENCFF891CHI.bed.gz	encode_chipseq_H3K9ac_ENCFF891CHI
# encode_chipseq_histone	ENCFF909RKY.bed.gz	encode_chipseq_H4K20me1_ENCFF909RKY
# encode_chipseq_histone	ENCFF963GZJ.bed.gz	encode_chipseq_H3K9me3_ENCFF963GZJ

# %% [markdown]
# ## Preview

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF122CSI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF148UQI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF193ERO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K79me2_ENCFF209OQD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H2AFZ_ENCFF213OTI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me1_ENCFF462AVD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF540NGG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF561OUZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF689QIJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF706WUF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF801AHF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF891CHI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H4K20me1_ENCFF909RKY
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me3_ENCFF963GZJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF122CSI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF148UQI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF193ERO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF193ERO.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K79me2_ENCFF209OQD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF209OQD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H2AFZ_ENCFF213OTI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF213OTI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me1_ENCFF462AVD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF462AVD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF540NGG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF540NGG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF561OUZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF561OUZ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF689QIJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF689QIJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF706WUF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF706WUF.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF801AHF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF801AHF.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF891CHI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF891CHI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H4K20me1_ENCFF909RKY
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF909RKY.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me3_ENCFF963GZJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF963GZJ.txt

# %% [markdown]
# ## Execute

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir  -p ${FD_OUT}
        sbatch \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF122CSI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# Submitted batch job 32837
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 32838
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF148UQI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.txt
#
# Submitted batch job 32839
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF193ERO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.txt
#
# Submitted batch job 32840
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K79me2_ENCFF209OQD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.txt
#
# Submitted batch job 32841
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H2AFZ_ENCFF213OTI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.txt
#
# Submitted batch job 32842
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 32843
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me1_ENCFF462AVD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.txt
#
# Submitted batch job 32844
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF540NGG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.txt
#
# Submitted batch job 32845
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 32846
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF561OUZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.txt
#
# Submitted batch job 32847
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF689QIJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.txt
#
# Submitted batch job 32848
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF706WUF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.txt
#
# Submitted batch job 32849
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 32850
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF801AHF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.txt
#
# Submitted batch job 32851
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 32852
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF891CHI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.txt
#
# Submitted batch job 32853
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H4K20me1_ENCFF909RKY
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.txt
#
# Submitted batch job 32854
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me3_ENCFF963GZJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.txt
#
# Submitted batch job 32855
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF122CSI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# Submitted batch job 32856
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 32857
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF148UQI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.txt
#
# Submitted batch job 32858
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF193ERO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF193ERO.txt
#
# Submitted batch job 32859
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K79me2_ENCFF209OQD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF209OQD.txt
#
# Submitted batch job 32860
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H2AFZ_ENCFF213OTI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF213OTI.txt
#
# Submitted batch job 32861
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 32862
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me1_ENCFF462AVD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF462AVD.txt
#
# Submitted batch job 32863
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF540NGG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF540NGG.txt
#
# Submitted batch job 32864
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 32865
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF561OUZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF561OUZ.txt
#
# Submitted batch job 32866
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF689QIJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF689QIJ.txt
#
# Submitted batch job 32867
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF706WUF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF706WUF.txt
#
# Submitted batch job 32868
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 32869
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF801AHF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF801AHF.txt
#
# Submitted batch job 32870
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 32871
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF891CHI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF891CHI.txt
#
# Submitted batch job 32872
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H4K20me1_ENCFF909RKY
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF909RKY.txt
#
# Submitted batch job 32873
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me3_ENCFF963GZJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF963GZJ.txt
#
# Submitted batch job 32874

# %% [markdown]
# ## Review

# %%
ls -1 /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
# Out:
# fcc_astarr_macs_input_overlap
# fcc_astarr_macs_input_union

# %%
FDIRY=${FD_RES}/region/encode_chipseq_histone
ls    ${FDIRY}/*.bed.gz | wc -l
ls -1 ${FDIRY}/*.bed.gz | xargs -n 1 basename
# Out:
# 19
# ENCFF122CSI.bed.gz
# ENCFF135ZLM.bed.gz
# ENCFF148UQI.bed.gz
# ENCFF193ERO.bed.gz
# ENCFF209OQD.bed.gz
# ENCFF213OTI.bed.gz
# ENCFF323WOT.bed.gz
# ENCFF462AVD.bed.gz
# ENCFF540NGG.bed.gz
# ENCFF544LXB.bed.gz
# ENCFF561OUZ.bed.gz
# ENCFF689QIJ.bed.gz
# ENCFF706WUF.bed.gz
# ENCFF749KLQ.bed.gz
# ENCFF801AHF.bed.gz
# ENCFF885FQN.bed.gz
# ENCFF891CHI.bed.gz
# ENCFF909RKY.bed.gz
# ENCFF963GZJ.bed.gz

# %%
FDIRY=${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
ls    ${FDIRY}/*.bed.gz | wc -l
ls -1 ${FDIRY}/*.bed.gz | xargs -n 1 basename
# Out:
# 19
# fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz

# %%
FDIRY=${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
ls    ${FDIRY}/*.bed.gz | wc -l
ls -1 ${FDIRY}/*.bed.gz | xargs -n 1 basename
# Out:
# 19
# fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.txt
# Out:
# Hostname:           plp-rcc-node-10
# Slurm Array Index:
# Time Stamp:         12-09-24+14:15:31
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405
# chr1	14282	14614
# chr1	16025	16338
# chr1	17288	17689
# chr1	28934	29499
# chr1	115429	115969
# chr1	136201	137353
# chr1	137748	138049
# chr1	138321	139517
# chr1	181005	181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/ENCF