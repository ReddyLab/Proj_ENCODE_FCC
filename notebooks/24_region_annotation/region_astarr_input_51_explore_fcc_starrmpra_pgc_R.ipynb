# %% [raw]
# ---
# title: FCC Peak calls
# subtitle: export annotation
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Prepare

# %% [markdown]
# **Set global variable**

# %%
TXT_FNAME_INP = "region.annotation.fcc_starrmpra_junke.group.tsv"
TXT_FNAME_OUT = "region.annotation.genome_tss.tsv"

# %% [markdown]
# **View files**

# %%
### get annotated region folder
txt_fdiry = file.path(FD_RES, "region_annotation")
vec = dir(txt_fdiry)

### assign and show
vec_txt_folder = vec
for(txt in vec){cat(txt, "\n")}
# Out:
# fcc_astarr_macs_input_overlap
# fcc_astarr_macs_input_union

# %%
txt_fdiry = file.path(FD_RES, "region_annotation", "*", "summary")
txt_fname = TXT_FNAME_INP
txt_fglob = file.path(txt_fdiry, txt_fname)

vec = Sys.glob(txt_fglob)
for(txt in vec){cat(txt, "\n")}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary/region.annotation.fcc_starrmpra_junke.group.tsv
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/summary/region.annotation.fcc_starrmpra_junke.group.tsv

# %% [markdown]
# ## Import data

# %%
### loop to import data
lst = lapply(vec_txt_folder, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_annotation", txt_folder, "summary")
    txt_fname = TXT_FNAME_INP
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})
names(lst) = vec_txt_folder

### assign and show
lst_dat_region_annot_fcc_starrmpra_vote2_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 109394     10
#
# $fcc_astarr_macs_input_union
# [1] 146148     10
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Direction_Assay </th>
#    <th style="text-align:right;"> Num_Assay </th>
#    <th style="text-align:right;"> TSS </th>
#    <th style="text-align:right;"> Distance2TSS </th>
#    <th style="text-align:left;"> TSS_Proximity </th>
#    <th style="text-align:left;"> Group </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 115429 </td>
#    <td style="text-align:right;"> 115969 </td>
#    <td style="text-align:left;"> chr1:115429-115969 </td>
#    <td style="text-align:left;"> Active </td>
#    <td style="text-align:right;"> 1 </td>
# ...

# %%
### loop to import data
lst = lapply(vec_txt_folder, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_annotation", txt_folder, "summary")
    txt_fname = "region.annotation.fcc_starrmpra_junke.merge_direction.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})
names(lst) = vec_txt_folder

### assign and show
lst_dat_region_annot_fcc_starrmpra_concat_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 141847      8
#
# $fcc_astarr_macs_input_union
# [1] 183250      8
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#    <th style="text-align:left;"> Direction </th>
#    <th style="text-align:right;"> Count </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> R </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
# ...

# %% [markdown]
# **Import TSS annotation**

# %%
### loop to import data
lst = lapply(vec_txt_folder, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_annotation", txt_folder, "summary")
    txt_fname = "matrix.annotation.genome_tss.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})
names(lst) = vec_txt_folder

### assign and show
lst_dat_region_annot_tss_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 9649    5
#
# $fcc_astarr_macs_input_union
# [1] 9788    5
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> TSS </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 28934 </td>
#    <td style="text-align:right;"> 29499 </td>
#    <td style="text-align:left;"> chr1:28934-29499 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 826796 </td>
#    <td style="text-align:right;"> 828040 </td>
#    <td style="text-align:left;"> chr1:826796-828040 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
# ...

# %% [markdown]
# **Import GC content**

# %%
lst = list(
    "fcc_astarr_macs_input_overlap" = "K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.tsv",
    "fcc_astarr_macs_input_union"   = "K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.tsv"
    
)
lst = lapply(lst, function(txt_fname){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_nuc", "fcc_astarr_macs", "summary")
    txt_fpath = file.path(txt_fdiry, txt_fname)
    
    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})

### assign and show
lst_dat_region_nuc_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 150042      6
#
# $fcc_astarr_macs_input_union
# [1] 246852      6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> pGC </th>
#    <th style="text-align:right;"> Length </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:right;"> 0.523161 </td>
#    <td style="text-align:right;"> 367 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 14282 </td>
#    <td style="text-align:right;"> 14614 </td>
#    <td style="text-align:left;"> chr1:14282-14614 </td>
# ...

# %% [markdown]
# ## Question: How many TSS

# %% [markdown]
# It turns out most TSS are showed to be significant in STARR/MPRA after vote 2 selection

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ###
    dat_region_annot_fcc = lst_dat_region_annot_fcc_import[[txt_folder]]
    dat_region_tss       = lst_dat_region_annot_tss_import[[txt_folder]]

    ###
    dat = dat_region_annot_fcc
    dat = dat %>% 
        dplyr::filter(Num_Assay > 1) %>%
        dplyr::select(Region, Group) %>% 
        dplyr::mutate(Label = "FCC STARR/MPRA")
    dat_region_fcc = dat
    
    ###
    dat = dat_region_tss
    dat = dat %>%
        dplyr::left_join(dat_region_fcc, by = "Region") %>%
        replace(is.na(.), "Inactive")
    return(dat)
})
names(lst) = vec_txt_folder

### assign and show
lst_dat_region_annot_result = lst

# %%
lst = lst_dat_region_annot_result
dat = lst[["fcc_astarr_macs_input_overlap"]]
print(dim(dat))
head(dat)
# Out:
# [1] 9650    7
#   Chrom ChromStart ChromEnd Region              TSS Group
# 1 chr1   28934       29499  chr1:28934-29499    1   Inactive
# 2 chr1  826796      828040  chr1:826796-828040  1   Inactive
# 3 chr1  876493      877795  chr1:876493-877795  1   Inactive
# 4 chr1  958722      959968  chr1:958722-959968  1   Proximal:Active
# 5 chr1  960468      961615  chr1:960468-961615  1   Proximal:Active
# 6 chr1  998960     1001192  chr1:998960-1001192 1   Inactive
#   Label
# 1 Inactive
# 2 Inactive
# 3 Inactive
# 4 FCC STARR/MPRA
# 5 FCC STARR/MPRA
# 6 Inactive

# %%
lst = lst_dat_region_annot_result
dat = lst[["fcc_astarr_macs_input_overlap"]]
dat = dat %>% dplyr::select(Region, Label) %>% dplyr::distinct()
res = table(dat$Label)

print(res)
print(dim(dat))
head(dat)
# Out:
# FCC STARR/MPRA       Inactive
#           5082           4567
# [1] 9649    2
#   Region              Label
# 1 chr1:28934-29499    Inactive
# 2 chr1:826796-828040  Inactive
# 3 chr1:876493-877795  Inactive
# 4 chr1:958722-959968  FCC STARR/MPRA
# 5 chr1:960468-961615  FCC STARR/MPRA
# 6 chr1:998960-1001192 Inactive

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ###
    dat_region_annot_fcc = lst_dat_region_annot_fcc_starrmpra_concat_import[[txt_folder]]
    dat_region_nuc       = lst_dat_region_nuc_import[[txt_folder]]

    ###
    dat = dat_region_annot_fcc
    dat = dat %>% 
        dplyr::select(Region, Group, Label, Direction) %>%
        dplyr::distinct()
    dat_region_fcc = dat
    
    ###
    dat = dat_region_fcc
    dat = dat %>% dplyr::left_join(dat_region_nuc, by = "Region")
    return(dat)
})
names(lst) = vec_txt_folder

### assign and show
lst_dat_region_annot_result = lst

# %%
lst = lst_dat_region_annot_result
dat = lst[["fcc_astarr_macs_input_overlap"]]
head(dat)
# Out:
#   Region             Group  Label    Direction Chrom ChromStart ChromEnd
# 1 chr1:10038-10405   ASTARR ASTARR_R R         chr1   10038      10405
# 2 chr1:16025-16338   ASTARR ASTARR_R R         chr1   16025      16338
# 3 chr1:17288-17689   ASTARR ASTARR_R R         chr1   17288      17689
# 4 chr1:28934-29499   ASTARR ASTARR_R R         chr1   28934      29499
# 5 chr1:115429-115969 ASTARR ASTARR_A A         chr1  115429     115969
# 6 chr1:136201-137353 ASTARR ASTARR_R R         chr1  136201     137353
#   pGC      Length
# 1 0.523161  367
# 2 0.587859  313
# 3 0.625935  401
# 4 0.771681  565
# 5 0.381481  540
# 6 0.694444 1152

# %%
lst = lst_dat_region_annot_result
dat = lst[["fcc_astarr_macs_input_overlap"]]
#dat = dat %>% dplyr::mutate(Note = factor(Group, levels = rev(vec)))

gpt = ggplot(dat, aes(x=Length, fill=Direction)) + 
    geom_density(alpha = 0.7) + 
    theme_cowplot() + 
    background_grid() +
    labs(x="ATAC Region Length", y = "Density") +
    facet_wrap(~Group, nrow=2, ncol=2)
    

options(repr.plot.height = 5, repr.plot.width = 12)
print(gpt)
# Out:
# Warning message:
# “Groups with fewer than two data points have been dropped.”
# Warning message in max(ids, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# plot without title

# %% [markdown]
# ## Question: GC content

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ###
    dat_region_annot_fcc = lst_dat_region_annot_fcc_starrmpra_vote2_import[[txt_folder]]
    dat_region_nuc       = lst_dat_region_nuc_import[[txt_folder]]

    ###
    dat = dat_region_annot_fcc
    dat = dat %>% 
        dplyr::filter(Num_Assay > 1) %>%
        dplyr::select(Region, Group)
    dat_region_fcc = dat
    
    ###
    dat = dat_region_nuc
    dat = dat %>%
        dplyr::left_join(dat_region_fcc, by = "Region") %>%
        replace(is.na(.), "Inactive")
    return(dat)
})
names(lst) = vec_txt_folder

### assign and show
lst_dat_region_annot_result = lst

# %%
lst = lst_dat_region_annot_result
dat = lst[["fcc_astarr_macs_input_overlap"]]

res = table(dat$Group)
print(res)

head(dat)
# Out:
#       Distal:Active   Distal:Repressive            Inactive     Proximal:Active
#               11435                1613              131701                5162
# Proximal:Repressive
#                 136
#   Chrom ChromStart ChromEnd Region             pGC      Length Group
# 1 chr1   10038      10405   chr1:10038-10405   0.523161 367    Inactive
# 2 chr1   14282      14614   chr1:14282-14614   0.578313 332    Inactive
# 3 chr1   16025      16338   chr1:16025-16338   0.587859 313    Inactive
# 4 chr1   17288      17689   chr1:17288-17689   0.625935 401    Inactive
# 5 chr1   28934      29499   chr1:28934-29499   0.771681 565    Inactive
# 6 chr1  115429     115969   chr1:115429-115969 0.381481 540    Inactive

# %%
lst = lst_dat_region_annot_result
dat = lst[["fcc_astarr_macs_input_overlap"]]
vec = c("Proximal:Active", "Proximal:Repressive", "Distal:Active", "Distal:Repressive", "Inactive")

dat = dat %>% dplyr::mutate(Note = factor(Group, levels = rev(vec)))

gpt = ggplot(dat, aes(x=pGC, fill=Note)) + 
    geom_density(alpha = 0.7) + 
    theme_cowplot() + 
    background_grid() +
    labs(x="GC content", y = "Density")

options(repr.plot.height = 4, repr.plot.width = 8)
print(gpt)
# Out:
# plot without title

# %%
lst = lst_dat_region_annot_result
dat = lst[["fcc_astarr_macs_input_overlap"]]
vec = c("Proximal:Active", "Proximal:Repressive", "Distal:Active", "Distal:Repressive", "Inactive")

dat = dat %>% dplyr::mutate(Note = factor(Group, levels = rev(vec)))

gpt = ggplot(dat, aes(x=Length, fill=Note)) + 
    geom_density(alpha = 0.7) + 
    theme_cowplot() + 
    background_grid() +
    labs(x="Region Length", y = "Density")

options(repr.plot.height = 4, repr.plot.width = 8)
print(gpt)
# Out:
# plot without title
