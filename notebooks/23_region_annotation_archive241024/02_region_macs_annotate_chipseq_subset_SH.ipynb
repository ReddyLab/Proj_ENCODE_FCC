# %% [raw]
# ---
# title: Region annotation 02 (ASTARR MACS peaks)
# subtitle: Annotate peaks (ChIP-seq; subset)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_flagship
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chromatin_states
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs
# fcc_crispri_hcrff
# fcc_mpra_agarwal2023
# fcc_screened
# fcc_starrmpra_junke
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/metadata.label.chipseq_subset.tsv

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs.tsv
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.chipseq_subset.tsv
# Folder	FName	Label
# encode_chipseq_subset	ENCFF023IFO.bed.gz	encode_chipseq_NFE2_ENCFF023IFO
# encode_chipseq_subset	ENCFF135ZLM.bed.gz	encode_chipseq_H3K4me1_ENCFF135ZLM
# encode_chipseq_subset	ENCFF142ZTD.bed.gz	encode_chipseq_KLF10_ENCFF142ZTD
# encode_chipseq_subset	ENCFF190CGV.bed.gz	encode_chipseq_JUN_ENCFF190CGV
# encode_chipseq_subset	ENCFF242AOL.bed.gz	encode_chipseq_ZEB2_ENCFF242AOL
# encode_chipseq_subset	ENCFF323WOT.bed.gz	encode_chipseq_H3K27me3_ENCFF323WOT
# encode_chipseq_subset	ENCFF355MNE.bed.gz	encode_chipseq_POLR2A_ENCFF355MNE
# encode_chipseq_subset	ENCFF398UQZ.bed.gz	encode_chipseq_YY1_ENCFF398UQZ
# encode_chipseq_subset	ENCFF488OTN.bed.gz	encode_chipseq_KLF16_ENCFF488OTN
# encode_chipseq_subset	ENCFF544LXB.bed.gz	encode_chipseq_H3K27ac_ENCFF544LXB
# encode_chipseq_subset	ENCFF553GPK.bed.gz	encode_chipseq_SP1_ENCFF553GPK
# encode_chipseq_subset	ENCFF627RSK.bed.gz	encode_chipseq_ATF1_ENCFF627RSK
# encode_chipseq_subset	ENCFF657CTC.bed.gz	encode_chipseq_GATA1_ENCFF657CTC
# encode_chipseq_subset	ENCFF660GHM.bed.gz	encode_chipseq_CTCF_ENCFF660GHM
# encode_chipseq_subset	ENCFF702XPO.bed.gz	encode_chipseq_EP300_ENCFF702XPO
# encode_chipseq_subset	ENCFF707MDI.bed.gz	encode_chipseq_REST_ENCFF707MDI
# encode_chipseq_subset	ENCFF715WGN.bed.gz	encode_chipseq_ELK1_ENCFF715WGN
# encode_chipseq_subset	ENCFF749KLQ.bed.gz	encode_chipseq_H3K4me2_ENCFF749KLQ
# encode_chipseq_subset	ENCFF777PKJ.bed.gz	encode_chipseq_NRF1_ENCFF777PKJ
# encode_chipseq_subset	ENCFF852ZRK.bed.gz	encode_chipseq_TAL1_ENCFF852ZRK
# encode_chipseq_subset	ENCFF885FQN.bed.gz	encode_chipseq_H3K4me3_ENCFF885FQN

# %% [markdown]
# ## Preview

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_

#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.txt
#
# Submitted batch job 33193849
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_GATA1_ENCFF657CTC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.txt
#
# Submitted batch job 33193850
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_CTCF_ENCFF660GHM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.txt
#
# Submitted batch job 33193851
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_EP300_ENCFF702XPO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.txt
#
# Submitted batch job 33193852
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_REST_ENCFF707MDI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.txt
#
# Submitted batch job 33193853
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_ELK1_ENCFF715WGN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.txt
#
# Submitted batch job 33193854
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 33193855
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_NRF1_ENCFF777PKJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.txt
#
# Submitted batch job 33193856
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_TAL1_ENCFF852ZRK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.txt
#
# Submitted batch job 33193857
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 33193858

# %% [markdown]
# ## Review

# %%
ls -1 /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
# Out:
# fcc_astarr_macs_input_overlap
# fcc_astarr_macs_input_union

# %%
FDIRY=${FD_RES}/region
ls    ${FDIRY}/encode_chipseq_subset/*.bed.gz | wc -l
ls -1 ${FDIRY}/encode_chipseq_subset/*.bed.gz | xargs -n 1 basename
# Out:
# 21
# ENCFF023IFO.bed.gz
# ENCFF135ZLM.bed.gz
# ENCFF142ZTD.bed.gz
# ENCFF190CGV.bed.gz
# ENCFF242AOL.bed.gz
# ENCFF323WOT.bed.gz
# ENCFF355MNE.bed.gz
# ENCFF398UQZ.bed.gz
# ENCFF488OTN.bed.gz
# ENCFF544LXB.bed.gz
# ENCFF553GPK.bed.gz
# ENCFF627RSK.bed.gz
# ENCFF657CTC.bed.gz
# ENCFF660GHM.bed.gz
# ENCFF702XPO.bed.gz
# ENCFF707MDI.bed.gz
# ENCFF715WGN.bed.gz
# ENCFF749KLQ.bed.gz
# ENCFF777PKJ.bed.gz
# ENCFF852ZRK.bed.gz
# ENCFF885FQN.bed.gz

# %%
FDIRY=${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
ls    ${FDIRY}/*.bed.gz | wc -l
ls -1 ${FDIRY}/*.bed.gz | xargs -n 1 basename
# Out:
# 21
# fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_REST_ENCFF707MDI.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# fcc_astarr_macs_input_overlap.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz

# %%
FDIRY=${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
ls    ${FDIRY}/*.bed.gz | wc -l
ls -1 ${FDIRY}/*.bed.gz | xargs -n 1 basename
# Out:
# 21
# fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# fcc_astarr_macs_input_union.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.txt
# Out:
# Hostname:           x1-01-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         07-09-24+13:43:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405
# chr1	14282	14614
# chr1	16025	16338
# chr1	17288	17689
# chr1	28934	29499
# chr1	115429	115969
# chr1	136201	137353
# chr1	137748	138049
# chr1	138321	139517
# chr1	181005	181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF627RSK.bed.gz
#
# show first few lines of input
# chr1	778198	779139	.	1000	.	10888.81006	-1.00000	4.26233	505
# chr1	817203	817893	.	1000	.	111.09106	-1.00000	3.87876	345
# chr1	817206	817533	.	1000	.	258.40874	-1.00000	4.26233	141
# chr1	827315	827649	.	1000	.	157.62140	-1.00000	3.91482	176
# chr1	842533	843223	.	754	.	66.73495	-1.00000	3.71724	345
# chr1	869692	870382	.	866	.	67.40187	-1.00000	3.78482	345
# chr1	898551	899241	.	734	.	60.20284	-1.00000	3.55963	345
# chr1	904380	905070	.	1000	.	91.00031	-1.00000	3.83481	345
# chr1	920875	921565	.	1000	.	143.04016	-1.00000	3.74425	345
# chr1	921081	921771	.	587	.	50.64527	-1.00000	2.99022	345
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset/fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.bed.gz