# %% [raw]
# ---
# title: Region annotation 14 (ASTARR MACS peaks)
# subtitle: Summarize annotations (ChIP-seq; histone)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# **Set global variables**

# %%
txt_fdiry = file.path(FD_RES, "region", "summary")
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
TXT_FDIRY_REGION_LABEL   = file.path(FD_RES, "region", "summary")
TXT_FNAME_REGION_LABEL_A = "metadata.label.astarr_macs.tsv"
TXT_FNAME_REGION_LABEL_B = "metadata.label.chipseq_full.tsv"

# %% [markdown]
# ## Import data

# %%
txt_fdiry = TXT_FDIRY_REGION_LABEL
txt_fname = TXT_FNAME_REGION_LABEL_A
txt_fpath = file.path(txt_fdiry, txt_fname)

dat_region_label_A = read_tsv(txt_fpath, show_col_types = FALSE)
dat_region_label_A
# Out:
#   Folder
# 1 fcc_astarr_macs
# 2 fcc_astarr_macs
#   FName
# 1 K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# 2 K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#   Label
# 1 fcc_astarr_macs_input_overlap
# 2 fcc_astarr_macs_input_union

# %%
txt_fdiry = TXT_FDIRY_REGION_LABEL
txt_fname = TXT_FNAME_REGION_LABEL_B
txt_fpath = file.path(txt_fdiry, txt_fname)

dat_region_label_B = read_tsv(txt_fpath, show_col_types = FALSE)
head(dat_region_label_B)
# Out:
#   Folder                  FName              Label
# 1 encode_chipseq_flagship ENCFF003LPE.bed.gz encode_chipseq_RUNX1_ENCFF003LPE
# 2 encode_chipseq_flagship ENCFF004HXL.bed.gz encode_chipseq_FOSL1_ENCFF004HXL
# 3 encode_chipseq_flagship ENCFF004YCK.bed.gz encode_chipseq_ZNF740_ENCFF004YCK
# 4 encode_chipseq_flagship ENCFF005MBI.bed.gz encode_chipseq_ZNF584_ENCFF005MBI
# 5 encode_chipseq_flagship ENCFF009RFC.bed.gz encode_chipseq_GABPB1_ENCFF009RFC
# 6 encode_chipseq_flagship ENCFF014HYS.bed.gz encode_chipseq_ZNF84_ENCFF014HYS

# %% [markdown]
# **Check colnumn names**

# %%
dat = dat_region_label_A
vec = unique(dat$Folder)
vec_txt_region_folder_A = vec

for (txt_region_folder_A in vec_txt_region_folder_A){
    ### get column names for region A
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_A, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_A = dat_cname$Name

    ### show results
    cat(txt_region_folder_A, "\n")
    print(vec_txt_cname_A)
    cat("\n")
}
# Out:
# fcc_astarr_macs
# [1] "Chrom"      "ChromStart" "ChromEnd"

# %%
dat = dat_region_label_B
vec = unique(dat$Folder)
vec_txt_region_folder_B = vec

for (txt_region_folder_B in vec_txt_region_folder_B){
    ### get column names for region B
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_B, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_B = dat_cname$Name

    ### show results
    cat(txt_region_folder_B, "\n")
    print(vec_txt_cname_B)
    cat("\n")
}
# Out:
# encode_chipseq_flagship
#  [1] "Chrom"       "ChromStart"  "ChromEnd"    "Name"        "Score"
#  [6] "Strand"      "SignalValue" "PValue"      "QValue"      "Peak"
#
# encode_chipseq_histone
#  [1] "Chrom"       "ChromStart"  "ChromEnd"    "Name"        "Score"
#  [6] "Strand"      "SignalValue" "PValue"      "QValue"      "Peak"

# %% [markdown]
# ## Main

# %%
dat = dat_region_label_A
lst = split(dat, 1:nrow(dat))
lst = lapply(lst, as.list)
lst_region_label_A = lst[1]
lst
# Out:
# $`1`
# $`1`$Folder
# [1] "fcc_astarr_macs"
#
# $`1`$FName
# [1] "K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz"
#
# $`1`$Label
# [1] "fcc_astarr_macs_input_overlap"
#
#
# $`2`
# $`2`$Folder
# [1] "fcc_astarr_macs"
#
# $`2`$FName
# [1] "K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz"
#
# $`2`$Label
# [1] "fcc_astarr_macs_input_union"

# %%
dat = dat_region_label_B
vec = unique(dat$Folder)
print(vec)

vec_txt_region_folder_B = "encode_chipseq_histone"
# Out:
# [1] "encode_chipseq_flagship" "encode_chipseq_histone"

# %% [markdown]
# **Loop**

# %%
### loop through region A
for (idx in seq_along(lst_region_label_A)){
    ### get region A
    lst = lst_region_label_A[[idx]]
    txt_region_folder_A = lst$Folder
    txt_region_label_A  = lst$Label

    ### get column names for region A
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_A, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_A = dat_cname$Name

    ### loop through region B
    for (txt_region_folder_B in vec_txt_region_folder_B){
        ### get column names for region B
        txt_fdiry = file.path(FD_RES, "region", txt_region_folder_B, "summary")
        txt_fname = "description.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
        dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
        vec_txt_cname_B = dat_cname$Name

        ### get total column names for annotation table
        vec_txt_cname = c(
            paste0(vec_txt_cname_A, "_A"),
            paste0(vec_txt_cname_B, "_B"),
            "Overlap"
        )
        
        ### get directory of annotation table
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A, 
            txt_region_folder_B
        )
        txt_fname = "*bed.gz"
        txt_fglob = file.path(txt_fdiry, txt_fname)

        ### get annotation table files
        vec_txt_fpath = Sys.glob(txt_fglob)
        vec_txt_fname = basename(vec_txt_fpath)

        ### show progress
        cat("===========================================\n")
        cat("Read annotation...", "\n")
        cat("Region A:", txt_region_folder_A, "|", txt_region_label_A, "\n")
        cat("Region B:", txt_region_folder_B, "\n")
        cat("FDiry:   ", "\n")
        print(txt_fdiry)
        cat("FName:   ", "\n")
        print(vec_txt_fname)
        cat("\n")
        flush.console()
        
        ### import annotation tables
        lst = lapply(vec_txt_fname, function(txt_fname){
            ### set directory
            txt_fpath = file.path(txt_fdiry, txt_fname)
            
            ### get annotation of region A and region B
            vec = str_split(txt_fname, "\\.")[[1]]
            txt_annot_A = vec[1]
            txt_annot_B = vec[2]

            ### get group,label of region B
            vec = str_split(txt_annot_B, "_")[[1]]
            txt_group_B = "ChIP-seq:Histone"
            txt_label_B = vec[3]
            
            ### read table and add annotation labels
            dat = read_tsv(txt_fpath, col_names = vec_txt_cname, show_col_types = FALSE)
            dat = dat %>% 
                dplyr::mutate(
                    Region_A = fun_gen_region(Chrom_A, ChromStart_A, ChromEnd_A),
                    Region_B = fun_gen_region(Chrom_B, ChromStart_B, ChromEnd_B),
                    Annotation_A = txt_annot_A,
                    Annotation_B = txt_annot_B,
                    Group_B = txt_group_B,
                    Label_B = txt_label_B
                )
            return(dat)
        }) 

        ### concatenate tables
        dat = bind_rows(lst)
        dat_region_annot_pair = dat
        
        ### summarize annotation tables
        dat = dat_region_annot_pair
        dat = dat %>%
            dplyr::group_by(
                Chrom_A, ChromStart_A, ChromEnd_A, Region_A,
                Annotation_A,
                Annotation_B,
                Group_B,
                Label_B
            ) %>%
            dplyr::summarise(
                Region_B = paste(Region_B, collapse=";"),
                Count_B  = n(),
                .groups = "drop")
        dat_region_annot_summary = dat


        ### set directory
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A,
            "summary"
        )
        txt_fname1 = paste("region", "annotation", txt_region_folder_B, "tsv", sep = ".")
        txt_fpath1 = file.path(txt_fdiry, txt_fname1)
        txt_fname2 = paste("region", "summary",    txt_region_folder_B, "tsv", sep = ".")
        txt_fpath2 = file.path(txt_fdiry, txt_fname2)
        
        ### show progress
        cat("Save annotation...",  "\n")
        cat("FDiry: ", txt_fdiry, "\n")
        cat("FName1:", txt_fname1, "\n")
        cat("FName2:", txt_fname2, "\n")
        cat("\n")
        flush.console()

        ### write tables
        dir.create(txt_fdiry, showWarnings = FALSE)
        write_tsv(dat_region_annot_pair,    txt_fpath1)
        write_tsv(dat_region_annot_summary, txt_fpath2)
    } ### end loop region B
} ### end loop region A
# Out:
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: encode_chipseq_histone
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone"
# FName:
#  [1] "fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz"
#  [2] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz"
#  [3] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz"
#  [4] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz"
#  [5] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz"
#  [6] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz"
#  [7] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz"
#  [8] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz"
#  [9] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz"
# [10] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz"
# [11] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz"
# [12] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz"
# [13] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz"
# [14] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz"
# [15] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz"
# [16] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz"
# [17] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz"
# [18] "fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz"
# [19] "fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.encode_chipseq_histone.tsv
# FName2: region.summary.encode_chipseq_histone.tsv

# %% [markdown]
# ## Review

# %%
head(dat_region_annot_pair)
# Out:
#   Chrom_A ChromStart_A ChromEnd_A Chrom_B ChromStart_B ChromEnd_B Name_B
# 1 chr1    605104       605675     chr1    605268       605529     Peak_47666
# 2 chr1    778233       779389     chr1    778410       778710     Peak_8638
# 3 chr1    778233       779389     chr1    778914       779389     Peak_22352
# 4 chr1    812348       812956     chr1    812754       813043     Peak_49239
# 5 chr1    826796       828040     chr1    826693       827529     Peak_14708
# 6 chr1    826796       828040     chr1    827701       827862     Peak_49240
#   Score_B Strand_B SignalValue_B PValue_B QValue_B Peak_B Overlap
# 1 143     .         5.45970      14.34741 12.12313 131    261
# 2 607     .        19.66396      60.70675 57.38058 127    300
# 3 308     .        10.97061      30.87924 28.19931 297    475
# 4 138     .         7.02968      13.82738 11.62081 129    202
# 5 435     .        15.46530      43.50309 40.53623 727    733
# 6 138     .         7.02968      13.82738 11.62081  36    161
#   Region_A           Region_B           Annotation_A
# 1 chr1:605104-605675 chr1:605268-605529 fcc_astarr_macs_input_overlap
# 2 chr1:778233-779389 chr1:778410-778710 fcc_astarr_macs_input_overlap
# 3 chr1:778233-779389 chr1:778914-779389 fcc_astarr_macs_input_overlap
# 4 chr1:812348-812956 chr1:812754-813043 fcc_astarr_macs_input_overlap
# 5 chr1:826796-828040 chr1:826693-827529 fcc_astarr_macs_input_overlap
# 6 chr1:826796-828040 chr1:827701-827862 fcc_astarr_macs_input_overlap
#   Annotation_B                     Group_B          Label_B
# 1 encode_chipseq_H2AFZ_ENCFF213OTI ChIP-seq:Histone H2AFZ
# 2 encode_chipseq_H2AFZ_ENCFF213OTI ChIP-seq:Histone H2AFZ
# 3 encode_chipseq_H2AFZ_ENCFF213OTI ChIP-seq:Histone H2AFZ
# 4 encode_chipseq_H2AFZ_ENCFF213OTI ChIP-seq:Histone H2AFZ
# 5 encode_chipseq_H2AFZ_ENCFF213OTI ChIP-seq:Histone H2AFZ
# 6 encode_chipseq_H2AFZ_ENCFF213OTI ChIP-seq:Histone H2AFZ

# %%
head(dat_region_annot_summary)
# Out:
#   Chrom_A ChromStart_A ChromEnd_A Region_A
# 1 chr1     16025        16338     chr1:16025-16338
# 2 chr1     16025        16338     chr1:16025-16338
# 3 chr1    137748       138049     chr1:137748-138049
# 4 chr1    137748       138049     chr1:137748-138049
# 5 chr1    137748       138049     chr1:137748-138049
# 6 chr1    137748       138049     chr1:137748-138049
#   Annotation_A                  Annotation_B
# 1 fcc_astarr_macs_input_overlap encode_chipseq_H3K36me3_ENCFF193ERO
# 2 fcc_astarr_macs_input_overlap encode_chipseq_H3K36me3_ENCFF561OUZ
# 3 fcc_astarr_macs_input_overlap encode_chipseq_H3K27ac_ENCFF544LXB
# 4 fcc_astarr_macs_input_overlap encode_chipseq_H3K4me2_ENCFF749KLQ
# 5 fcc_astarr_macs_input_overlap encode_chipseq_H3K4me3_ENCFF122CSI
# 6 fcc_astarr_macs_input_overlap encode_chipseq_H3K4me3_ENCFF689QIJ
#   Group_B          Label_B  Region_B           Count_B
# 1 ChIP-seq:Histone H3K36me3 chr1:16092-16380   1
# 2 ChIP-seq:Histone H3K36me3 chr1:16209-16339   1
# 3 ChIP-seq:Histone H3K27ac  chr1:137650-138169 1
# 4 ChIP-seq:Histone H3K4me2  chr1:137654-138013 1
# 5 ChIP-seq:Histone H3K4me3  chr1:137633-138169 1
# 6 ChIP-seq:Histone H3K4me3  chr1:137660-138147 1

# %%
### init
dat = dat_region_label_A
lst = split(dat, 1:nrow(dat))
lst = lapply(lst, as.list)
lst_region_label_A = lst

dat = dat_region_label_B
vec = unique(dat$Folder)
vec_txt_region_folder_B = c("encode_chipseq_histone")

###
for (idx in seq_along(lst_region_label_A)){
    ###
    lst = lst_region_label_A[[idx]]
    txt_region_folder_A = lst$Folder
    txt_region_label_A  = lst$Label

    ###
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_A, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_A = dat_cname$Name

    for (txt_region_folder_B in vec_txt_region_folder_B){
        ###
        txt_fdiry = file.path(FD_RES, "region", txt_region_folder_B, "summary")
        txt_fname = "description.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
        dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
        vec_txt_cname_B = dat_cname$Name

        ###
        vec_txt_cname = c(
            paste0(vec_txt_cname_A, "_A"),
            paste0(vec_txt_cname_B, "_B"),
            "Overlap"
        )
        
        ###
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A, 
            txt_region_folder_B
        )
        txt_fname = "*bed.gz"
        txt_fglob = file.path(txt_fdiry, txt_fname)
        
        vec_txt_fpath = Sys.glob(txt_fglob)
        vec_txt_fname = basename(vec_txt_fpath)

        ### show progress
        cat("===========================================\n")
        cat("Read annotation...", "\n")
        cat("Region A:", txt_region_folder_A, "|", txt_region_label_A, "\n")
        cat("Region B:", txt_region_folder_B, "\n")
        cat("FDiry:   ", txt_fdiry, "\n")
        cat("FName:   ", "\n")
        print(vec_txt_fname)
        cat("\n")
        flush.console()
        
        ###
        lst = lapply(vec_txt_fname, function(txt_fname){
            ###
            txt_fpath = file.path(txt_fdiry, txt_fname)
            
            ###
            vec = str_split(txt_fname, "\\.")[[1]]
            txt_annot_A = vec[1]
            txt_annot_B = vec[2]

            ###
            vec = str_split(txt_annot_B, "_")[[1]]
            txt_group_B = "ChIP-seq; Histone"
            txt_label_B = vec[2]
            
            ###
            dat = read_tsv(txt_fpath, col_names = vec_txt_cname, show_col_types = FALSE)
            dat = dat %>% 
                dplyr::mutate(
                    Region_A = paste0(Chrom_A, ":", ChromStart_A, "-", ChromEnd_A),
                    Region_B = paste0(Chrom_B, ":", ChromStart_B, "-", ChromEnd_B),
                    Annotation_A = txt_annot_A,
                    Annotation_B = txt_annot_B,
                    Group_B      = txt_group_B,
                    Label_B      = txt_label_B
                )
            return(dat)
        }) 

        ###
        dat = bind_rows(lst)
        dat = dat %>%
            dplyr::group_by(
                Chrom_A, ChromStart_A, ChromEnd_A, Region_A,
                Annotation_A,
                Annotation_B,
                Group_B, 
                Label_B
            ) %>%
            dplyr::summarise(
                Region_B = paste(Region_B, collapse="|"),
                Count  = n(),
                .groups = "drop")

        ###
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A,
            "summary"
        )
        txt_fname = paste("region", "summary", txt_region_folder_B, "tsv", sep = ".")
        txt_fpath = file.path(txt_fdiry, txt_fname)

        dir.create(txt_fdiry, showWarnings = FALSE)
        write_tsv(dat, txt_fpath)
        
        ### show progress
        cat("Save annotation...",  "\n")
        cat("FDiry:", txt_fdiry, "\n")
        cat("FName:", txt_fname, "\n")
        cat("\n")
        flush.console()
    } ### end loop region B
} ### end loop region A
# Out:
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: encode_chipseq_histone
# FDiry:    /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# FName:
#  [1] "fcc_astarr_macs_input_overlap.chipseq_H2AFZ_ENCFF213OTI.bed.gz"
#  [2] "fcc_astarr_macs_input_overlap.chipseq_H3K27ac_ENCFF544LXB.bed.gz"
#  [3] "fcc_astarr_macs_input_overlap.chipseq_H3K27me3_ENCFF323WOT.bed.gz"
#  [4] "fcc_astarr_macs_input_overlap.chipseq_H3K27me3_ENCFF801AHF.bed.gz"
#  [5] "fcc_astarr_macs_input_overlap.chipseq_H3K36me3_ENCFF193ERO.bed.gz"
#  [6] "fcc_astarr_macs_input_overlap.chipseq_H3K36me3_ENCFF561OUZ.bed.gz"
#  [7] "fcc_astarr_macs_input_overlap.chipseq_H3K4me1_ENCFF135ZLM.bed.gz"
#  [8] "fcc_astarr_macs_input_overlap.chipseq_H3K4me1_ENCFF540NGG.bed.gz"
#  [9] "fcc_astarr_macs_input_overlap.chipseq_H3K4me2_ENCFF749KLQ.bed.gz"
# [10] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF122CSI.bed.gz"
# [11] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF689QIJ.bed.gz"
# [12] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF706WUF.bed.gz"
# [13] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF885FQN.bed.gz"
# [14] "fcc_astarr_macs_input_overlap.chipseq_H3K79me2_ENCFF209OQD.bed.gz"
# [15] "fcc_astarr_macs_input_overlap.chipseq_H3K9ac_ENCFF148UQI.bed.gz"
# [16] "fcc_astarr_macs_input_overlap.chipseq_H3K9ac_ENCFF891CHI.bed.gz"
# [17] "fcc_astarr_macs_input_overlap.chipseq_H3K9me1_ENCFF462AVD.bed.gz"
# [18] "fcc_astarr_macs_input_overlap.chipseq_H3K9me3_ENCFF963GZJ.bed.gz"
# [19] "fcc_astarr_macs_input_overlap.chipseq_H4K20me1_ENCFF909RKY.bed.gz"
#
# Save annotation...
# FDiry: /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName: region.summary.encode_chipseq_histone.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_union
# Region B: encode_chipseq_histone
# FDiry:    /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# FName:
#  [1] "fcc_astarr_macs_input_union.chipseq_H2AFZ_ENCFF213OTI.bed.gz"
#  [2] "fcc_astarr_macs_input_union.chipseq_H3K27ac_ENCFF544LXB.bed.gz"
#  [3] "fcc_astarr_macs_input_union.chipseq_H3K27me3_ENCFF323WOT.bed.gz"
#  [4] "fcc_astarr_macs_input_union.chipseq_H3K27me3_ENCFF801AHF.bed.gz"
#  [5] "fcc_astarr_macs_input_union.chipseq_H3K36me3_ENCFF193ERO.bed.gz"
#  [6] "fcc_astarr_macs_input_union.chipseq_H3K36me3_ENCFF561OUZ.bed.gz"
#  [7] "fcc_astarr_macs_input_union.chipseq_H3K4me1_ENCFF135ZLM.bed.gz"
#  [8] "fcc_astarr_macs_input_union.chipseq_H3K4me1_ENCFF540NGG.bed.gz"
#  [9] "fcc_astarr_macs_input_union.chipseq_H3K4me2_ENCFF749KLQ.bed.gz"
# [10] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF122CSI.bed.gz"
# [11] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF689QIJ.bed.gz"
# [12] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF706WUF.bed.gz"
# [13] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF885FQN.bed.gz"
# [14] "fcc_astarr_macs_input_union.chipseq_H3K79me2_ENCFF209OQD.bed.gz"
# [15] "fcc_astarr_macs_input_union.chipseq_H3K9ac_ENCFF148UQI.bed.gz"
# [16] "fcc_astarr_macs_input_union.chipseq_H3K9ac_ENCFF891CHI.bed.gz"
# [17] "fcc_astarr_macs_input_union.chipseq_H3K9me1_ENCFF462AVD.bed.gz"
# [18] "fcc_astarr_macs_input_union.chipseq_H3K9me3_ENCFF963GZJ.bed.gz"
# [19] "fcc_astarr_macs_input_union.chipseq_H4K20me1_ENCFF909RKY.bed.gz"
#
# Save annotation...
# FDiry: /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/summary
# FName: region.summary.encode_chipseq_histone.tsv

# %%
head(dat)
# Out:
#   Chrom_A ChromStart_A ChromEnd_A Region_A
# 1 chr1     16015        16477     chr1:16015-16477
# 2 chr1     16015        16477     chr1:16015-16477
# 3 chr1    118518       118743     chr1:118518-118743
# 4 chr1    118518       118743     chr1:118518-118743
# 5 chr1    137737       139544     chr1:137737-139544
# 6 chr1    137737       139544     chr1:137737-139544
#   Annotation_A                Annotation_B                 Group_B
# 1 fcc_astarr_macs_input_union chipseq_H3K36me3_ENCFF193ERO ChIP-seq; Histone
# 2 fcc_astarr_macs_input_union chipseq_H3K36me3_ENCFF561OUZ ChIP-seq; Histone
# 3 fcc_astarr_macs_input_union chipseq_H3K4me3_ENCFF689QIJ  ChIP-seq; Histone
# 4 fcc_astarr_macs_input_union chipseq_H3K9ac_ENCFF891CHI   ChIP-seq; Histone
# 5 fcc_astarr_macs_input_union chipseq_H3K27ac_ENCFF544LXB  ChIP-seq; Histone
# 6 fcc_astarr_macs_input_union chipseq_H3K36me3_ENCFF193ERO ChIP-seq; Histone
#   Label_B  Region_B                                                 Count
# 1 H3K36me3 chr1:16092-16380                                         1
# 2 H3K36me3 chr1:16209-16339                                         1
# 3 H3K4me3  chr1:118439-118645                                       1
# 4 H3K9ac   chr1:118435-119129                                       1
# 5 H3K27ac  chr1:137650-138169|chr1:138356-139236|chr1:139285-139490 3
# 6 H3K36me3 chr1:139300-139473                                       1
