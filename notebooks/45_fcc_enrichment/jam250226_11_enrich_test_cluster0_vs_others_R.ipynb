# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
suppressMessages(suppressWarnings(library("nullranges")))
suppressMessages(suppressWarnings(library("coin")))
suppressMessages(suppressWarnings(library("pheatmap")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import data

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_enrichment_v2",
    "fcc_starrmpracrispri_vote2_phenograph_neighbors070"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# List.data_region.cluster_vs_others.rds
# MatchedGRanges_Cluster00_vs_inactive.rds
# MatchedGRanges_Cluster00_vs_others.rds
# MatchedGRanges_Cluster01_vs_inactive.rds
# MatchedGRanges_Cluster01_vs_others.rds
# MatchedGRanges_Cluster02_vs_inactive.rds
# MatchedGRanges_Cluster02_vs_others.rds
# MatchedGRanges_Cluster03_vs_inactive.rds
# MatchedGRanges_Cluster03_vs_others.rds
# MatchedGRanges_Cluster04_vs_inactive.rds
# MatchedGRanges_Cluster04_vs_others.rds
# MatchedGRanges_Cluster05_vs_inactive.rds
# MatchedGRanges_Cluster05_vs_others.rds
# MatchedGRanges_Cluster06_vs_inactive.rds
# MatchedGRanges_Cluster06_vs_others.rds
# MatchedGRanges_Cluster07_vs_inactive.rds
# MatchedGRanges_Cluster07_vs_others.rds
# MatchedGRanges_Cluster08_vs_inactive.rds
# MatchedGRanges_Cluster08_vs_others.rds
# MatchedGRanges_Cluster09_vs_inactive.rds
# MatchedGRanges_Cluster09_vs_others.rds
# MatchedGRanges_Cluster10_vs_inactive.rds
# MatchedGRanges_Cluster10_vs_others.rds
# MatchedGRanges_Cluster11_vs_inactive.rds
# MatchedGRanges_Cluster11_vs_others.rds
# MatchedGRanges_Cluster12_vs_inactive.rds
# MatchedGRanges_Cluster12_vs_others.rds
# MatchedGRanges_Cluster13_vs_inactive.rds
# MatchedGRanges_Cluster13_vs_others.rds
# MatchedGRanges_Cluster14_vs_inactive.rds
# MatchedGRanges_Cluster14_vs_others.rds
# region.prepare.group.tsv
# results_Cluster00_vs_inactive_perm10k.rds
# results_Cluster00_vs_others_perm10k.rds
# results_Cluster01_vs_inactive_perm10k.rds
# results_Cluster01_vs_others_perm10k.rds
# results_Cluster02_vs_inactive_perm10k.rds
# results_Cluster02_vs_others_perm10k.rds
# results_Cluster03_vs_inactive_perm10k.rds
# results_Cluster03_vs_others_perm10k.rds
# results_Cluster04_vs_inactive_perm10k.rds
# results_Cluster04_vs_others_perm10k.rds
# results_Cluster05_vs_inactive_perm10k.rds
# results_Cluster05_vs_others_perm10k.rds
# results_Cluster06_vs_inactive_perm10k.rds
# results_Cluster06_vs_others_perm10k.rds
# results_Cluster07_vs_inactive_perm10k.rds
# results_Cluster07_vs_others_perm10k.rds
# results_Cluster08_vs_inactive_perm10k.rds
# results_Cluster08_vs_others_perm10k.rds
# results_Cluster09_vs_inactive_perm10k.rds
# results_Cluster09_vs_others_perm10k.rds
# results_Cluster10_vs_inactive_perm10k.rds
# results_Cluster10_vs_others_perm10k.rds
# results_Cluster11_vs_inactive_perm10k.rds
# results_Cluster11_vs_others_perm10k.rds
# results_Cluster12_vs_inactive_perm10k.rds
# results_Cluster12_vs_others_perm10k.rds
# results_Cluster13_vs_inactive_perm10k.rds
# results_Cluster13_vs_others_perm10k.rds
# results_Cluster14_vs_inactive_perm10k.rds
# results_Cluster14_vs_others_perm10k.rds
# results.enrich.fcc_cluster_vs_inactive.perm_n10k.tsv
# results.enrich.fcc_cluster_vs_others.perm_n10k.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_enrichment_v2",
    "fcc_starrmpracrispri_vote2_phenograph_neighbors070"
)
txt_fname = "MatchedGRanges_Cluster00_vs_others.rds"
txt_fpath = file.path(txt_fdiry, txt_fname)

obj = readRDS(txt_fpath)

mgr_region_target_vs_others = obj
print(obj)
# Out:
# MatchedGRanges object with 4629 ranges and 4 metadata columns:
#          seqnames              ranges strand |                 Region      ATAC
#             <Rle>           <IRanges>  <Rle> |            <character> <numeric>
#      [1]     chr3   65039459-65040525      * | chr3:65039459-65040525   1.35817
#      [2]    chr16   88686103-88688809      * | chr16:88686103-88688..   1.50650
#      [3]     chr8   22056379-22057259      * | chr8:22056379-22057259   1.11612
#      [4]     chr1 155070649-155071601      * | chr1:155070649-15507..   1.37316
#      [5]     chr2   86105295-86106701      * | chr2:86105295-86106701   1.37688
#      ...      ...                 ...    ... .                    ...       ...
#   [4625]    chr20   57432737-57433454      * | chr20:57432737-57433..  1.089942
#   [4626]     chr1   31954665-31956606      * | chr1:31954665-31956606  1.124133
#   [4627]    chr19   47240925-47241361      * | chr19:47240925-47241..  1.330555
#   [4628]    chr22   50674759-50675298      * | chr22:50674759-50675..  0.644806
#   [4629]     chr8   73008351-73009432      * | chr8:73008351-73009432  1.309364
#                pGC    Length
#          <numeric> <numeric>
#      [1]  0.503752      1066
#      [2]  0.620473      2706
#      [3]  0.644318       880
#      [4]  0.637605       952
#      [5]  0.512802      1406
#      ...       ...       ...
#   [4625]  0.566248       717
#   [4626]  0.510562      1941
#   [4627]  0.672018       436
#   [4628]  0.784787       539
#   [4629]  0.574468      1081
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_enrichment_v2"
)
txt_fname = "region.prepare.score.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

mat_region_score_import = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 150041    531
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID3B </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ASH1L </th>
#    <th style="text-align:right;"> ATF1 </th>
#    <th style="text-align:right;"> ATF2 </th>
#    <th style="text-align:right;"> ATF3 </th>
#    <th style="text-align:right;"> ATF4 </th>
#    <th style="text-align:right;"> ATF6 </th>
#    <th style="text-align:right;"> ATF7 </th>
#    <th style="text-align:right;"> BACH1 </th>
#    <th style="text-align:right;"> BCL6 </th>
#    <th style="text-align:right;"> BCLAF1 </th>
#    <th style="text-align:right;"> BCOR </th>
#    <th style="text-align:right;"> BDP1 </th>
#    <th style="text-align:right;"> BHLHE40 </th>
#    <th style="text-align:right;"> BMI1 </th>
#    <th style="text-align:right;"> BRCA1 </th>
#    <th style="text-align:right;"> BRD4 </th>
#    <th style="text-align:right;"> BRD9 </th>
#    <th style="text-align:right;"> BRF2 </th>
#    <th style="text-align:right;"> C11orf30 </th>
#    <th style="text-align:right;"> CAMTA2 </th>
#    <th style="text-align:right;"> CBFA2T2 </th>
#    <th style="text-align:right;"> CBFA2T3 </th>
#    <th style="text-align:right;"> CBFB </th>
#    <th style="text-align:right;"> CBX1 </th>
#    <th style="text-align:right;"> CBX2 </th>
#    <th style="text-align:right;"> CBX3 </th>
#    <th style="text-align:right;"> CBX5 </th>
#    <th style="text-align:right;"> CC2D1A </th>
#    <th style="text-align:right;"> CCAR2 </th>
#    <th style="text-align:right;"> CDC5L </th>
#    <th style="text-align:right;"> CEBPB </th>
#    <th style="text-align:right;"> CEBPG </th>
#    <th style="text-align:right;"> CEBPZ </th>
#    <th style="text-align:right;"> CGGBP1 </th>
#    <th style="text-align:right;"> CHAMP1 </th>
#    <th style="text-align:right;"> CHCHD3 </th>
#    <th style="text-align:right;"> CHD1 </th>
#    <th style="text-align:right;"> CHD2 </th>
#    <th style="text-align:right;"> CHD4 </th>
#    <th style="text-align:right;"> CHD7 </th>
#    <th style="text-align:right;"> CLOCK </th>
#    <th style="text-align:right;"> COPS2 </th>
#    <th style="text-align:right;"> CREB1 </th>
#    <th style="text-align:right;"> CREB3 </th>
#    <th style="text-align:right;"> CREB3L1 </th>
#    <th style="text-align:right;"> CREB5 </th>
#    <th style="text-align:right;"> CREBBP </th>
#    <th style="text-align:right;"> CREM </th>
#    <th style="text-align:right;"> CSDE1 </th>
#    <th style="text-align:right;"> CTBP1 </th>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> CTCFL </th>
#    <th style="text-align:right;"> CUX1 </th>
#    <th style="text-align:right;"> CXXC5 </th>
#    <th style="text-align:right;"> DACH1 </th>
#    <th style="text-align:right;"> DDIT3 </th>
#    <th style="text-align:right;"> DDX20 </th>
#    <th style="text-align:right;"> DEAF1 </th>
#    <th style="text-align:right;"> DIDO1 </th>
#    <th style="text-align:right;"> DLX4 </th>
#    <th style="text-align:right;"> DMBX1 </th>
#    <th style="text-align:right;"> DMTF1 </th>
#    <th style="text-align:right;"> DNMT1 </th>
#    <th style="text-align:right;"> DPF2 </th>
#    <th style="text-align:right;"> E2F1 </th>
#    <th style="text-align:right;"> E2F3 </th>
#    <th style="text-align:right;"> E2F4 </th>
#    <th style="text-align:right;"> E2F5 </th>
#    <th style="text-align:right;"> E2F6 </th>
#    <th style="text-align:right;"> E2F7 </th>
#    <th style="text-align:right;"> E2F8 </th>
#    <th style="text-align:right;"> E4F1 </th>
#    <th style="text-align:right;"> EGR1 </th>
#    <th style="text-align:right;"> EHMT2 </th>
#    <th style="text-align:right;"> ELF1 </th>
#    <th style="text-align:right;"> ELF2 </th>
#    <th style="text-align:right;"> ELF4 </th>
#    <th style="text-align:right;"> ELK1 </th>
#    <th style="text-align:right;"> ELK3 </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> EP400 </th>
#    <th style="text-align:right;"> ERF </th>
#    <th style="text-align:right;"> ESRRA </th>
#    <th style="text-align:right;"> ESRRB </th>
#    <th style="text-align:right;"> ETS1 </th>
#    <th style="text-align:right;"> ETS2 </th>
#    <th style="text-align:right;"> ETV1 </th>
#    <th style="text-align:right;"> ETV5 </th>
#    <th style="text-align:right;"> ETV6 </th>
#    <th style="text-align:right;"> EWSR1 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> FIP1L1 </th>
#    <th style="text-align:right;"> FOSL1 </th>
#    <th style="text-align:right;"> FOXA1 </th>
#    <th style="text-align:right;"> FOXA3 </th>
#    <th style="text-align:right;"> FOXJ2 </th>
#    <th style="text-align:right;"> FOXJ3 </th>
#    <th style="text-align:right;"> FOXK1 </th>
#    <th style="text-align:right;"> FOXK2 </th>
#    <th style="text-align:right;"> FOXM1 </th>
#    <th style="text-align:right;"> FOXO4 </th>
#    <th style="text-align:right;"> FOXP1 </th>
#    <th style="text-align:right;"> FOXP4 </th>
#    <th style="text-align:right;"> FUS </th>
#    <th style="text-align:right;"> GABPA </th>
#    <th style="text-align:right;"> GABPB1 </th>
#    <th style="text-align:right;"> GABPB2 </th>
#    <th style="text-align:right;"> GATA1 </th>
#    <th style="text-align:right;"> GATA2 </th>
#    <th style="text-align:right;"> GATAD2A </th>
#    <th style="text-align:right;"> GATAD2B </th>
#    <th style="text-align:right;"> GMEB1 </th>
#    <th style="text-align:right;"> GTF2A2 </th>
#    <th style="text-align:right;"> GTF2E2 </th>
#    <th style="text-align:right;"> GTF2F1 </th>
#    <th style="text-align:right;"> GTF2I </th>
#    <th style="text-align:right;"> HBP1 </th>
#    <th style="text-align:right;"> HCFC1 </th>
#    <th style="text-align:right;"> HDAC1 </th>
#    <th style="text-align:right;"> HDAC2 </th>
#    <th style="text-align:right;"> HDAC3 </th>
#    <th style="text-align:right;"> HDAC6 </th>
#    <th style="text-align:right;"> HDAC8 </th>
#    <th style="text-align:right;"> HDGF </th>
#    <th style="text-align:right;"> HES1 </th>
#    <th style="text-align:right;"> HEY1 </th>
#    <th style="text-align:right;"> HINFP </th>
#    <th style="text-align:right;"> HIVEP1 </th>
#    <th style="text-align:right;"> HLTF </th>
#    <th style="text-align:right;"> HMBOX1 </th>
#    <th style="text-align:right;"> HMG20A </th>
#    <th style="text-align:right;"> HMG20B </th>
#    <th style="text-align:right;"> HMGXB4 </th>
#    <th style="text-align:right;"> HNRNPH1 </th>
#    <th style="text-align:right;"> HNRNPK </th>
#    <th style="text-align:right;"> HNRNPL </th>
#    <th style="text-align:right;"> HNRNPLL </th>
#    <th style="text-align:right;"> HNRNPUL1 </th>
#    <th style="text-align:right;"> HOMEZ </th>
#    <th style="text-align:right;"> HOXB6 </th>
#    <th style="text-align:right;"> HSF4 </th>
#    <th style="text-align:right;"> ID3 </th>
#    <th style="text-align:right;"> IFI16 </th>
#    <th style="text-align:right;"> IKZF1 </th>
#    <th style="text-align:right;"> ILF3 </th>
#    <th style="text-align:right;"> ILK </th>
#    <

# %% [markdown]
# ## Arrange matrix

# %%
dat = mat_region_score_import
dat = dat %>% dplyr::select(-Chrom, -ChromStart, -ChromEnd) %>% column_to_rownames("Region")
mat_region_score = dat
head(dat, 3)
# Out:
#                          H2AFZ      H3K27ac  H3K27me3  H3K36me3  H3K4me1
# chr1:100028014-100029653 0.93242936 1.202217 0.3674175 1.1781314 1.510638
# chr1:100036895-100039189 2.89957396 3.910099 0.4091536 1.1978119 1.069881
# chr1:100046252-100046533 0.04290946 1.091537 0.4388560 0.5386822 2.148905
#                          H3K4me2   H3K4me3   H3K79me2  H3K9ac   H3K9me1   ⋯
# chr1:100028014-100029653 0.6818927 0.5918414 0.3212089 1.029037 0.8262739 ⋯
# chr1:100036895-100039189 4.9478111 5.5219678 4.1772959 4.663171 0.9431997 ⋯
# chr1:100046252-100046533 1.2418524 1.1294906 3.5795422 1.101003 1.6372764 ⋯
#                          ZNF84     ZSCAN29   ZSCAN32   ZZZ3     ASTARR
# chr1:100028014-100029653 1.0330670 0.9713258 0.8083307 1.123223 -0.2125505
# chr1:100036895-100039189 1.1498056 1.2491389 1.0451144 1.033166  1.7130117
# chr1:100046252-100046533 0.7301539 1.1432014 1.1482769 1.394350 -1.6867521
#                          CRISPRi-Growth CRISPRi-HCRFF LMPRA    TMPRA WSTARR
# chr1:100028014-100029653 -0.21446960    0             0.000000 0     -0.7757209
# chr1:100036895-100039189 -0.05130039    0             1.832751 0      2.2235590
# chr1:100046252-100046533  0.00000000    0             0.000000 0     -1.2221295

# %%
vec_txt_assay = c("ASTARR", "WSTARR", "TMPRA", "LMPRA", "CRISPRi-HCRFF", "CRISPRi-Growth")
print(vec_txt_assay)
# Out:
# [1] "ASTARR"         "WSTARR"         "TMPRA"          "LMPRA"
# [5] "CRISPRi-HCRFF"  "CRISPRi-Growth"

# %%
dat = mat_region_score
vec = colnames(dat)
vec = setdiff(vec, vec_txt_assay)

vec_txt_feature = vec
print(length(vec))
print(head(vec))
print(tail(vec))
# Out:
# [1] 521
# [1] "H2AFZ"    "H3K27ac"  "H3K27me3" "H3K36me3" "H3K4me1"  "H3K4me2"
# [1] "ZNF83"   "ZNF830"  "ZNF84"   "ZSCAN29" "ZSCAN32" "ZZZ3"

# %% [markdown]
# ## Prepare for test

# %%
###
mgr  = mgr_region_target_vs_others
dat  = mat_region_score
vec1 = focal(mgr)$Region
vec2 = matched(mgr)$Region
dat1 = dat[vec1,]
dat2 = dat[vec2,]

###
dat1$Group = "1"
dat2$Group = "0"
dat = bind_rows(dat1, dat2)

###
dat_region_test = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 9258  528
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;">   </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID3B </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ASH1L </th>
#    <th style="text-align:right;"> ATF1 </th>
#    <th style="text-align:right;"> ATF2 </th>
#    <th style="text-align:right;"> ATF3 </th>
#    <th style="text-align:right;"> ATF4 </th>
#    <th style="text-align:right;"> ATF6 </th>
#    <th style="text-align:right;"> ATF7 </th>
#    <th style="text-align:right;"> BACH1 </th>
#    <th style="text-align:right;"> BCL6 </th>
#    <th style="text-align:right;"> BCLAF1 </th>
#    <th style="text-align:right;"> BCOR </th>
#    <th style="text-align:right;"> BDP1 </th>
#    <th style="text-align:right;"> BHLHE40 </th>
#    <th style="text-align:right;"> BMI1 </th>
#    <th style="text-align:right;"> BRCA1 </th>
#    <th style="text-align:right;"> BRD4 </th>
#    <th style="text-align:right;"> BRD9 </th>
#    <th style="text-align:right;"> BRF2 </th>
#    <th style="text-align:right;"> C11orf30 </th>
#    <th style="text-align:right;"> CAMTA2 </th>
#    <th style="text-align:right;"> CBFA2T2 </th>
#    <th style="text-align:right;"> CBFA2T3 </th>
#    <th style="text-align:right;"> CBFB </th>
#    <th style="text-align:right;"> CBX1 </th>
#    <th style="text-align:right;"> CBX2 </th>
#    <th style="text-align:right;"> CBX3 </th>
#    <th style="text-align:right;"> CBX5 </th>
#    <th style="text-align:right;"> CC2D1A </th>
#    <th style="text-align:right;"> CCAR2 </th>
#    <th style="text-align:right;"> CDC5L </th>
#    <th style="text-align:right;"> CEBPB </th>
#    <th style="text-align:right;"> CEBPG </th>
#    <th style="text-align:right;"> CEBPZ </th>
#    <th style="text-align:right;"> CGGBP1 </th>
#    <th style="text-align:right;"> CHAMP1 </th>
#    <th style="text-align:right;"> CHCHD3 </th>
#    <th style="text-align:right;"> CHD1 </th>
#    <th style="text-align:right;"> CHD2 </th>
#    <th style="text-align:right;"> CHD4 </th>
#    <th style="text-align:right;"> CHD7 </th>
#    <th style="text-align:right;"> CLOCK </th>
#    <th style="text-align:right;"> COPS2 </th>
#    <th style="text-align:right;"> CREB1 </th>
#    <th style="text-align:right;"> CREB3 </th>
#    <th style="text-align:right;"> CREB3L1 </th>
#    <th style="text-align:right;"> CREB5 </th>
#    <th style="text-align:right;"> CREBBP </th>
#    <th style="text-align:right;"> CREM </th>
#    <th style="text-align:right;"> CSDE1 </th>
#    <th style="text-align:right;"> CTBP1 </th>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> CTCFL </th>
#    <th style="text-align:right;"> CUX1 </th>
#    <th style="text-align:right;"> CXXC5 </th>
#    <th style="text-align:right;"> DACH1 </th>
#    <th style="text-align:right;"> DDIT3 </th>
#    <th style="text-align:right;"> DDX20 </th>
#    <th style="text-align:right;"> DEAF1 </th>
#    <th style="text-align:right;"> DIDO1 </th>
#    <th style="text-align:right;"> DLX4 </th>
#    <th style="text-align:right;"> DMBX1 </th>
#    <th style="text-align:right;"> DMTF1 </th>
#    <th style="text-align:right;"> DNMT1 </th>
#    <th style="text-align:right;"> DPF2 </th>
#    <th style="text-align:right;"> E2F1 </th>
#    <th style="text-align:right;"> E2F3 </th>
#    <th style="text-align:right;"> E2F4 </th>
#    <th style="text-align:right;"> E2F5 </th>
#    <th style="text-align:right;"> E2F6 </th>
#    <th style="text-align:right;"> E2F7 </th>
#    <th style="text-align:right;"> E2F8 </th>
#    <th style="text-align:right;"> E4F1 </th>
#    <th style="text-align:right;"> EGR1 </th>
#    <th style="text-align:right;"> EHMT2 </th>
#    <th style="text-align:right;"> ELF1 </th>
#    <th style="text-align:right;"> ELF2 </th>
#    <th style="text-align:right;"> ELF4 </th>
#    <th style="text-align:right;"> ELK1 </th>
#    <th style="text-align:right;"> ELK3 </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> EP400 </th>
#    <th style="text-align:right;"> ERF </th>
#    <th style="text-align:right;"> ESRRA </th>
#    <th style="text-align:right;"> ESRRB </th>
#    <th style="text-align:right;"> ETS1 </th>
#    <th style="text-align:right;"> ETS2 </th>
#    <th style="text-align:right;"> ETV1 </th>
#    <th style="text-align:right;"> ETV5 </th>
#    <th style="text-align:right;"> ETV6 </th>
#    <th style="text-align:right;"> EWSR1 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> FIP1L1 </th>
#    <th style="text-align:right;"> FOSL1 </th>
#    <th style="text-align:right;"> FOXA1 </th>
#    <th style="text-align:right;"> FOXA3 </th>
#    <th style="text-align:right;"> FOXJ2 </th>
#    <th style="text-align:right;"> FOXJ3 </th>
#    <th style="text-align:right;"> FOXK1 </th>
#    <th style="text-align:right;"> FOXK2 </th>
#    <th style="text-align:right;"> FOXM1 </th>
#    <th style="text-align:right;"> FOXO4 </th>
#    <th style="text-align:right;"> FOXP1 </th>
#    <th style="text-align:right;"> FOXP4 </th>
#    <th style="text-align:right;"> FUS </th>
#    <th style="text-align:right;"> GABPA </th>
#    <th style="text-align:right;"> GABPB1 </th>
#    <th style="text-align:right;"> GABPB2 </th>
#    <th style="text-align:right;"> GATA1 </th>
#    <th style="text-align:right;"> GATA2 </th>
#    <th style="text-align:right;"> GATAD2A </th>
#    <th style="text-align:right;"> GATAD2B </th>
#    <th style="text-align:right;"> GMEB1 </th>
#    <th style="text-align:right;"> GTF2A2 </th>
#    <th style="text-align:right;"> GTF2E2 </th>
#    <th style="text-align:right;"> GTF2F1 </th>
#    <th style="text-align:right;"> GTF2I </th>
#    <th style="text-align:right;"> HBP1 </th>
#    <th style="text-align:right;"> HCFC1 </th>
#    <th style="text-align:right;"> HDAC1 </th>
#    <th style="text-align:right;"> HDAC2 </th>
#    <th style="text-align:right;"> HDAC3 </th>
#    <th style="text-align:right;"> HDAC6 </th>
#    <th style="text-align:right;"> HDAC8 </th>
#    <th style="text-align:right;"> HDGF </th>
#    <th style="text-align:right;"> HES1 </th>
#    <th style="text-align:right;"> HEY1 </th>
#    <th style="text-align:right;"> HINFP </th>
#    <th style="text-align:right;"> HIVEP1 </th>
#    <th style="text-align:right;"> HLTF </th>
#    <th style="text-align:right;"> HMBOX1 </th>
#    <th style="text-align:right;"> HMG20A </th>
#    <th style="text-align:right;"> HMG20B </th>
#    <th style="text-align:right;"> HMGXB4 </th>
#    <th style="text-align:right;"> HNRNPH1 </th>
#    <th style="text-align:right;"> HNRNPK </th>
#    <th style="text-align:right;"> HNRNPL </th>
#    <th style="text-align:right;"> HNRNPLL </th>
#    <th style="text-align:right;"> HNRNPUL1 </th>
#    <th style="text-align:right;"> HOMEZ </th>
#    <th style="text-align:right;"> HOXB6 </th>
#    <th style="text-align:right;"> HSF4 </th>
#    <th style="text-align:right;"> ID3 </th>
#    <th style="text-align:right;"> IFI16 </th>
#    <th style="text-align:right;"> IKZF1 </th>
#    <th style="text-align:right;"> ILF3 </th>
#    <th style="text-align:right;"> ILK </th>
#    <th style="text-align:right;"> IRF1 </th>
#    <th style="text-align:right;"> IRF2 </th>
#    <th style="text-align:right;"> IRF9 </th>
#    <th style="text-

# %% [markdown]
# ## Test all features for the targeted cluster

# %%
### init: parameters
num_iter = 10000

### loop through each region group
set.seed(123)

### show progress
dat = dat_region_test
cat(nrow(dat), "\n")
flush.console()

### perform permutation test for each feature
lst = lapply(vec_txt_feature, function(txt_feature){
    
    ### select the feature and group lable
    dat = dat_region_test
    vec = c(txt_feature, "Group")
    dat = dat[, vec]
    colnames(dat) = c("Score", "Group")

    ### perform a permutation test
    dat = dat %>% dplyr::mutate(Group = factor(Group, levels = c("1", "0")))
    res = coin::oneway_test(
        Score ~ Group, 
        data = dat, 
        distribution = approximate(nresample = num_iter)
    )

    return(res)
})
names(lst) = vec_txt_feature
    

### assign and show
lst_fit_object = lst
print(names(lst))
# Out:
# 9258
#   [1] "H2AFZ"           "H3K27ac"         "H3K27me3"        "H3K36me3"
#   [5] "H3K4me1"         "H3K4me2"         "H3K4me3"         "H3K79me2"
#   [9] "H3K9ac"          "H3K9me1"         "H3K9me3"         "H4K20me1"
#  [13] "ADNP"            "AFF1"            "AFF4"            "AGO1"
#  [17] "ARHGAP35"        "ARID1B"          "ARID2"           "ARID3A"
#  [21] "ARID3B"          "ARID4B"          "ARNT"            "ASH1L"
#  [25] "ATF1"            "ATF2"            "ATF3"            "ATF4"
#  [29] "ATF6"            "ATF7"            "BACH1"           "BCL6"
#  [33] "BCLAF1"          "BCOR"            "BDP1"            "BHLHE40"
#  [37] "BMI1"            "BRCA1"           "BRD4"            "BRD9"
#  [41] "BRF2"            "C11orf30"        "CAMTA2"          "CBFA2T2"
#  [45] "CBFA2T3"         "CBFB"            "CBX1"            "CBX2"
#  [49] "CBX3"            "CBX5"            "CC2D1A"          "CCAR2"
#  [53] "CDC5L"           "CEBPB"           "CEBPG"           "CEBPZ"
#  [57] "CGGBP1"          "CHAMP1"          "CHCHD3"          "CHD1"
#  [61] "CHD2"            "CHD4"            "CHD7"            "CLOCK"
#  [65] "COPS2"           "CREB1"           "CREB3"           "CREB3L1"
#  [69] "CREB5"           "CREBBP"          "CREM"            "CSDE1"
#  [73] "CTBP1"           "CTCF"            "CTCFL"           "CUX1"
#  [77] "CXXC5"           "DACH1"           "DDIT3"           "DDX20"
#  [81] "DEAF1"           "DIDO1"           "DLX4"            "DMBX1"
#  [85] "DMTF1"           "DNMT1"           "DPF2"            "E2F1"
#  [89] "E2F3"            "E2F4"            "E2F5"            "E2F6"
#  [93] "E2F7"            "E2F8"            "E4F1"            "EGR1"
#  [97] "EHMT2"           "ELF1"            "ELF2"            "ELF4"
# [101] "ELK1"            "ELK3"            "EP300"           "EP400"
# [105] "ERF"             "ESRRA"           "ESRRB"           "ETS1"
# [109] "ETS2"            "ETV1"            "ETV5"            "ETV6"
# [113] "EWSR1"           "EZH2"            "FIP1L1"          "FOSL1"
# [117] "FOXA1"           "FOXA3"           "FOXJ2"           "FOXJ3"
# [121] "FOXK1"           "FOXK2"           "FOXM1"           "FOXO4"
# [125] "FOXP1"           "FOXP4"           "FUS"             "GABPA"
# [129] "GABPB1"          "GABPB2"          "GATA1"           "GATA2"
# [133] "GATAD2A"         "GATAD2B"         "GMEB1"           "GTF2A2"
# [137] "GTF2E2"          "GTF2F1"          "GTF2I"           "HBP1"
# [141] "HCFC1"           "HDAC1"           "HDAC2"           "HDAC3"
# [145] "HDAC6"           "HDAC8"           "HDGF"            "HES1"
# [149] "HEY1"            "HINFP"           "HIVEP1"          "HLTF"
# [153] "HMBOX1"          "HMG20A"          "HMG20B"          "HMGXB4"
# [157] "HNRNPH1"         "HNRNPK"          "HNRNPL"          "HNRNPLL"
# [161] "HNRNPUL1"        "HOMEZ"           "HOXB6"           "HSF4"
# [165] "ID3"             "IFI16"           "IKZF1"           "ILF3"
# [169] "ILK"             "IRF1"            "IRF2"            "IRF9"
# [173] "JUN"             "JUNB"            "JUND"            "KAT2B"
# [177] "KAT7"            "KAT8"            "KDM1A"           "KDM2B"
# [181] "KDM4B"           "KDM5B"           "KHSRP"           "KLF1"
# [185] "KLF10"           "KLF13"           "KLF16"           "KLF6"
# [189] "L3MBTL2"         "LCOR"            "LEF1"            "MAFF"
# [193] "MAFG"            "MAFK"            "MAX"             "MAZ"
# [197] "MBD1"            "MBD2"            "MCM2"            "MCM3"
# [201] "MCM5"            "MCM7"            "MECOM"           "MED1"
# [205] "MEF2A"           "MEF2D"           "MEIS2"           "MGA"
# [209] "MIER1"           "MITF"            "MLLT1"           "MLX"
# [213] "MNT"             "MTA1"            "MTA2"            "MTA3"
# [217] "MTF1"            "MXD1"            "MXI1"            "MYBL2"
# [221] "MYC"             "MYNN"            "NBN"             "NCOA1"
# [225] "NCOA2"           "NCOA4"           "NCOA6"           "NCOR1"
# [229] "NELFE"           "NEUROD1"         "NFATC3"          "NFE2"
# [233] "NFE2L1"          "NFIC"            "NFIX"            "NFRKB"
# [237] "NFXL1"           "NFYA"            "NKRF"            "NONO"
# [241] "NR0B1"           "NR1H2"           "NR2C1"           "NR2C2"
# [245] "NR2F1"           "NR2F2"           "NR2F6"           "NR3C1"
# [249] "NR4A1"           "NRF1"            "NUFIP1"          "OTX1"
# [253] "PATZ1"           "PBX2"            "PCBP1"           "PCBP2"
# [257] "PHB"             "PHB2"            "PHF20"           "PHF21A"
# [261] "PHF8"            "PHTF2"           "PKNOX1"          "PML"
# [265] "POLR2A"          "POLR2AphosphoS2" "POLR2AphosphoS5" "POLR2B"
# [269] "POLR2G"          "POLR2H"          "POU5F1"          "PPARD"
# [273] "PRDM10"          "PREB"            "PRMT5"           "PRPF4"
# [277] "PTBP1"           "PTRF"            "PTTG1"           "PURB"
# [281] "PYGO2"           "RAD21"           "RAD51"           "RB1"
# [285] "RBBP5"           "RBFOX2"          "RBM14"           "RBM15"
# [289] "RBM17"           "RBM22"           "RBM25"           "RBM34"
# [293] "RBM39"           "RBPJ"            "RCOR1"           "RELA"
# [297] "RERE"            "REST"            "RFX1"            "RFX5"
# [301] "RFX7"            "RHOXF2B"         "RLF"             "RNF2"
# [305] "RNF219"          "RREB1"           "RUNX1"           "SAFB"
# [309] "SAFB2"           "SAP30"           "SETDB1"          "SFPQ"
# [313] "SIN3A"           "SIN3B"           "SIRT6"           "SIX5"
# [317] "SKIL"            "SLC30A9"         "SMAD1"           "SMAD2"
# [321] "SMAD3"           "SMAD4"           "SMAD5"           "SMARCA4"
# [325] "SMARCA5"         "SMARCB1"         "SMARCC2"         "SMARCE1"
# [329] "SMC3"            "SNAPC5"          "SNIP1"           "SNRNP70"
# [333] "SOX6"            "SP1"             "SPI1"            "SREBF1"
# [337] "SREBF2"          "SRF"             "SRSF1"           "SRSF3"
# [341] "SRSF7"           "SRSF9"           "STAG1"           "STAT5A"
# [345] "STAT5B"          "STAT6"           "SUPT5H"          "SUZ12"
# [349] "TAF15"           "TAF7"            "TAF9B"           "TAL1"
# [353] "TARDBP"          "TBL1XR1"         "TBPL1"           "TBX18"
# [357] "TCF12"           "TCF15"           "TCF3"            "TCF7"
# [361] "TCF7L2"          "TCFL5"           "TEAD1"           "TEAD2"
# [365] "TEAD4"           "TFAM"            "TFAP4"           "TFCP2"
# [369] "TFDP1"           "TFE3"            "TGIF2"           "THAP1"
# [373] "THAP12"          "THAP7"           "THRA"            "THRAP3"
# [377] "THRB"            "TOE1"            "TRIM24"          "TRIM25"
# [381] "TRIM28"          "TRIP13"          "TSC22D4"         "TSHZ1"
# [385] "U2AF1"           "U2AF2"           "UBTF"            "USF1"
# [389] "USF2"            "VEZF1"           "WHSC1"           "XRCC3"
# [393] "XRCC5"           "YBX1"            "YBX3"            "YY1"
# [397] "ZBED1"           "ZBTB1"           "ZBTB11"          "ZBTB12"
# [401] "ZBTB17"          "ZBTB2"           "ZBTB26"          "ZBTB33"
# [405] "ZBTB34"          "ZBTB40"          "ZBTB43"          "ZBTB49"
# [409] "ZBTB5"           "ZBTB7A"          "ZBTB8A"          "ZBTB9"
# [413] "ZC3H11A"         "ZC3H4"           "ZC3H8"           "ZEB2"
# [417] "ZFP1"            "ZFP30"           "ZFP36"           "ZFP91"
# [421] "ZFPM2"           "ZFX"             "ZHX1"            "ZKSCAN1"
# [425] "ZKSCAN3"         "ZKSCAN8"         "ZMIZ1"           "ZMYM3"
# [429] "ZNF12"           "ZNF121"          "ZNF124"          "ZNF133"
# [433] "ZNF134"          "ZNF140"          "ZNF143"          "ZNF146"
# [437] "ZNF148"          "ZNF165"          "ZNF174"          "ZNF175"
# [441] "ZNF184"          "ZNF197"          "ZNF212"          "ZNF215"
# [445] "ZNF217"          "ZNF224"          "ZNF23"           "ZNF232"
# [449] "ZNF239"          "ZNF24"           "ZNF253"          "ZNF257"
# [453] "ZNF263"          "ZNF274"          "ZNF277"          "ZNF280A"
# [457] "ZNF280B"         "ZNF281"          "ZNF282"          "ZNF3"
# [461] "ZNF311"          "ZNF316"          "ZNF317"          "ZNF318"
# [465] "ZNF319"          "ZNF324"          "ZNF347"          "ZNF354B"
# [469] "ZNF354C"         "ZNF384"          "ZNF395"          "ZNF397"
# [473] "ZNF398"          "ZNF407"          "ZNF408"          "ZNF41"
# [477] "ZNF431"          "ZNF436"          "ZNF444"          "ZNF445"
# [481] "ZNF449"          "ZNF507"          "ZNF511"          "ZNF512"
# [485] "ZNF518B"         "ZNF551"          "ZNF561"          "ZNF57"
# [489] "ZNF583"          "ZNF584"          "ZNF586"          "ZNF589"
# [493] "ZNF592"          "ZNF609"          "ZNF639"          "ZNF644"
# [497] "ZNF655"          "ZNF668"          "ZNF695"          "ZNF696"
# [501] "ZNF699"          "ZNF7"            "ZNF700"          "ZNF707"
# [505] "ZNF717"          "ZNF740"          "ZNF75A"          "ZNF76"
# [509] "ZNF764"          "ZNF766"          "ZNF77"           "ZNF778"
# [513] "ZNF780A"         "ZNF785"          "ZNF79"           "ZNF83"
# [517] "ZNF830"          "ZNF84"           "ZSCAN29"         "ZSCAN32"
# [521] "ZZZ3"

# %% [markdown]
# ## Summarize the results

# %%
lst = lst_fit_object
lst = lapply(lst, function(fit){
    res = c(
        coin::statistic(fit), 
        coin::pvalue(fit) 
    )
    names(res) = c("Stat", "Pval")
    return(res)
})

###
dat = bind_rows(lst, .id = "Feature")
dat = dat %>% 
    dplyr::mutate(Score = as.numeric(scale(Stat))) %>%
    dplyr::mutate(Padj  = p.adjust(Pval, method = "BH"))

### assign and show
dat_fit_summary = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 521   5
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Feature </th>
#    <th style="text-align:right;"> Stat </th>
#    <th style="text-align:right;"> Pval </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:right;"> Padj </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> H2AFZ </td>
#    <td style="text-align:right;"> 33.10713 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1.634034 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K27ac </td>
#    <td style="text-align:right;"> 28.39601 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1.325957 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K27me3 </td>
#    <td style="text-align:right;"> -10.90312 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> -1.243961 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>

# %%
dat = dat_fit_summary

vec = dat$Stat
summary(vec)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -33.239  -2.629   7.979   8.120  17.546  54.454

# %%
dat = dat_fit_summary

vec = dat$Score
summary(vec)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.70461 -0.70290 -0.00919  0.00000  0.61643  3.02999

# %%
dat = dat_fit_summary
dat = dat %>% dplyr::mutate(nLog10Padj = -log10(Padj))

### summary
idx = is.infinite(dat$nLog10Padj)
vec = dat$nLog10Padj[!idx]
summary(vec)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.04978 0.49998 1.57662 1.72646 2.76508 3.92265

# %%
dat = dat_fit_summary
dat = dat %>% dplyr::mutate(nLog10Padj = -log10(Padj))

### capped pvalues
idx = is.infinite(dat$nLog10Padj)
dat$nLog10Padj[idx] = 5

### assign and show
dat_fit_summary_nlogp = dat
print(dim(dat))
fun_display_table(head(dat))
# Out:
# [1] 521   6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Feature </th>
#    <th style="text-align:right;"> Stat </th>
#    <th style="text-align:right;"> Pval </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:right;"> Padj </th>
#    <th style="text-align:right;"> nLog10Padj </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> H2AFZ </td>
#    <td style="text-align:right;"> 33.107126 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1.6340344 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K27ac </td>
#    <td style="text-align:right;"> 28.396013 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1.3259570 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K27me3 </td>
#    <td style="text-align:right;"> -10.903121 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> -1.2439611 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K36me3 </td>
#    <td style="text-align:right;"> 7.978978 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> -0.0091896 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K4me1 </td>
#    <td style="text-align:right;"> -32.965805 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> -2.6867228 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K4me2 </td>
#    <td style="text-align:right;"> 48.054838 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2.6115214 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 5 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Visualization

# %%
options(repr.plot.height = 4, repr.plot.width=7)
dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Stat)) + geom_density() + theme_cowplot()

print(gpt)
# Out:
# plot without title

# %%
options(repr.plot.height = 4, repr.plot.width=7)
dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Score)) + geom_density() + theme_cowplot()

print(gpt)
# Out:
# plot without title

# %%
options(repr.plot.height = 4, repr.plot.width=7)
dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Padj)) + geom_density() + theme_cowplot()

print(gpt)
# Out:
# plot without title

# %%
options(repr.plot.height = 4, repr.plot.width=5)
dat = dat_fit_summary_nlogp
gpt = ggplot(dat, aes(x=Stat, y=nLog10Padj)) + geom_point() + theme_cowplot()

print(gpt)
# Out:
# plot without title

# %%
options(repr.plot.height = 4, repr.plot.width=5)
dat = dat_fit_summary_nlogp
gpt = ggplot(dat, aes(x=Score, y=nLog10Padj)) + geom_point() + theme_cowplot()

print(gpt)
# Out:
# plot without title

# %%
vec_txt_feature_subset = c(
    "CTCF", "SMC3", "RAD21", "POLR2A", "EP300", "EZH2", "REST", "SIN3A",
    'H3K27ac', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K27me3')

# %%
dat = dat_fit_summary

dat = dat %>% dplyr::filter(Feature %in% vec_txt_feature_subset)

dat_fit_summary_subset = dat
print(dim(dat))
fun_display_table(head(dat))
# Out:
# [1] 13  5
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Feature </th>
#    <th style="text-align:right;"> Stat </th>
#    <th style="text-align:right;"> Pval </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:right;"> Padj </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> H3K27ac </td>
#    <td style="text-align:right;"> 28.396013 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1.3259570 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K27me3 </td>
#    <td style="text-align:right;"> -10.903121 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> -1.2439611 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K4me1 </td>
#    <td style="text-align:right;"> -32.965805 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> -2.6867228 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K4me2 </td>
#    <td style="text-align:right;"> 48.054838 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 2.6115214 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K4me3 </td>
#    <td style="text-align:right;"> 54.454053 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 3.0299902 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> CTCF </td>
#    <td style="text-align:right;"> 5.495184 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> -0.1716143 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>

# %%
dat = dat_fit_summary_subset

dat = dat %>% 
    dplyr::select(Feature, Stat) %>% 
    tidyr::spread(Feature, Stat)

mat_fit_summary_subset = dat
print(dim(dat))
fun_display_table(dat)
# Out:
# [1]  1 13
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> POLR2A </th>
#    <th style="text-align:right;"> RAD21 </th>
#    <th style="text-align:right;"> REST </th>
#    <th style="text-align:right;"> SIN3A </th>
#    <th style="text-align:right;"> SMC3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 5.495184 </td>
#    <td style="text-align:right;"> -19.96092 </td>
#    <td style="text-align:right;"> -8.689696 </td>
#    <td style="text-align:right;"> 28.39601 </td>
#    <td style="text-align:right;"> -10.90312 </td>
#    <td style="text-align:right;"> -32.96581 </td>
#    <td style="text-align:right;"> 48.05484 </td>
#    <td style="text-align:right;"> 54.45405 </td>
#    <td style="text-align:right;"> 44.31256 </td>
#    <td style="text-align:right;"> -3.756588 </td>
#    <td style="text-align:right;"> 1.557422 </td>
#    <td style="text-align:right;"> 36.32787 </td>
#    <td style="text-align:right;"> -1.909401 </td>
#   </tr>
# </tbody>
# </table>

# %%
vec_num_breaks = seq(-50, 50, by = 0.1)

vec = brewer.pal(n = 7, name = "RdBu")
vec = colorRampPalette(rev(vec))(length(vec_num_breaks))
vec_txt_colors = vec

# %%
options(repr.plot.height = 3, repr.plot.width=10)

dat = mat_fit_summary_subset
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %%
dat = dat_fit_summary_subset

dat = dat %>% 
    dplyr::select(Feature, Score) %>% 
    tidyr::spread(Feature, Score)

mat_fit_summary_subset = dat
print(dim(dat))
fun_display_table(dat)
# Out:
# [1]  1 13
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> POLR2A </th>
#    <th style="text-align:right;"> RAD21 </th>
#    <th style="text-align:right;"> REST </th>
#    <th style="text-align:right;"> SIN3A </th>
#    <th style="text-align:right;"> SMC3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> -0.1716143 </td>
#    <td style="text-align:right;"> -1.836284 </td>
#    <td style="text-align:right;"> -1.099217 </td>
#    <td style="text-align:right;"> 1.325957 </td>
#    <td style="text-align:right;"> -1.243961 </td>
#    <td style="text-align:right;"> -2.686723 </td>
#    <td style="text-align:right;"> 2.611521 </td>
#    <td style="text-align:right;"> 3.02999 </td>
#    <td style="text-align:right;"> 2.3668 </td>
#    <td style="text-align:right;"> -0.7766224 </td>
#    <td style="text-align:right;"> -0.4291193 </td>
#    <td style="text-align:right;"> 1.844651 </td>
#    <td style="text-align:right;"> -0.6558278 </td>
#   </tr>
# </tbody>
# </table>

# %%
vec_num_breaks = seq(-3, 3, by = 0.1)

vec = brewer.pal(n = 7, name = "RdBu")
vec = colorRampPalette(rev(vec))(length(vec_num_breaks))
vec_txt_colors = vec

# %%
options(repr.plot.height = 3, repr.plot.width=10)

dat = mat_fit_summary_subset
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %% [markdown]
# ## Explore the name list

# %%
dat = dat_fit_summary
dat = dat %>% dplyr::arrange(Score)
head(dat, 10)
# Out:
#    Feature Stat      Pval Score     Padj
# 1  CBFA2T2 -33.23932 0    -2.704609 0
# 2  PBX2    -33.21182 0    -2.702811 0
# 3  H3K4me1 -32.96581 0    -2.686723 0
# 4  CBFA2T3 -30.52986 0    -2.527427 0
# 5  PKNOX1  -29.71659 0    -2.474244 0
# 6  ARID1B  -27.91430 0    -2.356386 0
# 7  TCF12   -26.89683 0    -2.289850 0
# 8  TAL1    -26.76873 0    -2.281473 0
# 9  DPF2    -25.21155 0    -2.179643 0
# 10 TCF3    -23.38316 0    -2.060078 0

# %%
dat = dat_fit_summary
dat = dat %>% dplyr::arrange(-Score)
head(dat, 10)
# Out:
#    Feature Stat     Pval Score    Padj
# 1  H3K4me3 54.45405 0    3.029990 0
# 2  PHF8    52.97634 0    2.933357 0
# 3  H3K9ac  50.07075 0    2.743350 0
# 4  H3K4me2 48.05484 0    2.611521 0
# 5  RBFOX2  47.22093 0    2.556989 0
# 6  SUPT5H  46.12854 0    2.485553 0
# 7  SMAD5   45.47299 0    2.442685 0
# 8  POLR2A  44.31256 0    2.366800 0
# 9  KDM5B   43.83511 0    2.335578 0
# 10 POLR2G  43.78357 0    2.332207 0
