# %% [raw]
# ---
# title: Prepare STARR-seq data 031
# subtitle: Prepare STARR-seq data files from `PROJECT/data` to `PROJECT/results` folder
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/app/singularity_proj_encode_fcc.sif

# %%
mkdir -p ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
mkdir -p ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
mkdir -p ${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
mkdir -p ${FD_RES}/region/fcc_astarr_macs

# %% [markdown]
# ## Prepare fragment counts of ASTARR (KS91)

# %% [markdown]
# **Data: Original files**
#
# `PROJECT/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments`
#
# ```
# KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dedup.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dedup.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dedup.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Input_rep5.masked.dedup.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Input_rep6.masked.dedup.fragments.counts.txt.gz
#
# KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.fragments.counts.txt.gz
# KS91_K562_hg38_ASTARRseq_Output_rep4.f3q10.fragments.counts.txt.gz
# ```

# %% [markdown]
# **Results: SymLinks**
#
# `PROJECT/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts`
#
# ```
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
# ```

# %% [markdown]
# **Check data**

# %%
FD_INP=${FD_DAT}/processed/ASTARRseq_K562_hg38_KS91_210401/fragments
ls -lh ${FD_INP}
# Out:
# total 40G
# -rw-r--r-- 1 kk319 reddylab 3.0G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 2.0G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep1.masked.exclude_dups.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 3.8G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 2.4G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep2.masked.exclude_dups.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 4.0G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 2.5G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep3.masked.exclude_dups.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 3.8G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 2.4G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep4.masked.exclude_dups.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 3.7G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep5.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 2.4G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep5.masked.exclude_dups.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 3.4G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep6.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 2.1G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input_rep6.masked.exclude_dups.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 306M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 262M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.sorted.with_umis.dedup.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 569M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 480M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.sorted.with_umis.dedup.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 642M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 531M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.sorted.with_umis.dedup.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 1.1G Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep4.f3q10.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 834M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep4.f3q10.sorted.with_umis.dedup.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 125M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep5.f3q10.sorted.with_umis.dedup.cpm.bw
# -rw-r--r-- 1 kk319 reddylab 179M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Output_rep6.f3q10.sorted.with_umis.dedup.cpm.bw

# %% [markdown]
# **Execute**
#
# List the file names, loop the list, and link the files

# %%
FD_INP=${FD_DAT}/processed/ASTARRseq_K562_hg38_KS91_210401/fragments
FN_INPS=(
    KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dedup.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dedup.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dedup.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Input_rep5.masked.dedup.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Input_rep6.masked.dedup.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.fragments.counts.txt.gz
    KS91_K562_hg38_ASTARRseq_Output_rep4.f3q10.fragments.counts.txt.gz
)

# %%
FD_OUT=${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
FN_OUTS=(
    ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
    ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
)

# %%
for idx in "${!FN_INPS[@]}"
do
    FN_INP=${FN_INPS[idx]}
    FN_OUT=${FN_OUTS[idx]}
    
    FILE=${FD_INP}/${FN_INP}
    LINK=${FD_OUT}/${FN_OUT}
    
    if [[ -h ${LINK} ]]; then
        echo "Remove existing link."
        rm ${LINK}
    fi
    
    if [[ ! -e ${LINK} ]]; then
        echo "Create symbolic links."
        ln -s ${FILE} ${LINK}
    fi
done
# Out:
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.

# %% [markdown]
# **Check results**

# %%
FD_OUT=${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
ls -l ${FD_OUT}
# Out:
# total 11
# lrwxrwxrwx  1 kk319 reddylab 170 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Input_rep1.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 170 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Input_rep2.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 170 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Input_rep3.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 170 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Input_rep4.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 170 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Input_rep5.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 170 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Input_rep6.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 164 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Output_rep1.f3q10.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 164 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Output_rep2.f3q10.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 164 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Output_rep3.f3q10.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 164 Apr  1 12:33 ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/ASTARRseq_K562_hg38_KS91_210401/fragments/KS91_K562_hg38_ASTARRseq_Output_rep4.f3q10.fragments.counts.txt.gz
# drwxrwsr-x+ 3 kk319 reddylab 512 Mar 12 14:11 summary

# %%
FD_OUT=${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
FN_OUT=ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
FP_OUT=${FD_OUT}/${FN_OUT}

zcat ${FP_OUT} | head -n 6
# Out:
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.

# %% [markdown]
# ## Prepare fragment counts of WSTARR (A001)

# %% [markdown]
# **Data: Original files**
#
# `PROJECT/data/processed/WSTARRseq_K562_hg38_A001/fragments`
#
# ```
# A001-input-K562-rep1.masked.dedup.fragments.counts.txt.gz
# A001-input-K562-rep2.masked.dedup.fragments.counts.txt.gz
# A001-input-K562-rep3.masked.dedup.fragments.counts.txt.gz
# A001-input-K562-rep4.masked.dedup.fragments.counts.txt.gz
# A001-K562-rep1.masked.dedup.fragments.counts.txt.gz
# A001-K562-rep2.masked.dedup.fragments.counts.txt.gz
# A001-K562-rep3.masked.dedup.fragments.counts.txt.gz
# ```

# %% [markdown]
# **Results: SymLinks**
#
# `PROJECT/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts`
#
# ```
# WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
# WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
# ```

# %% [markdown]
# **Check data**

# %%
FD_INP=${FD_DAT}/processed/WSTARRseq_K562_hg38_A001/fragments
ls -lh ${FD_INP}
# Out:
# total 9.8G
# -rw-r--r-- 1 kk319 reddylab  284M Mar 29 21:55 A001-input-K562-rep1.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab 1022M Mar 29 21:55 A001-input-K562-rep2.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab  1.1G Mar 29 21:55 A001-input-K562-rep3.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab  1.1G Mar 29 21:55 A001-input-K562-rep4.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab  1.6G Mar 29 21:55 A001-K562-rep1.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab  1.6G Mar 29 21:55 A001-K562-rep2.masked.dedup.fragments.counts.txt.gz
# -rw-r--r-- 1 kk319 reddylab  3.2G Mar 29 21:56 A001-K562-rep3.masked.dedup.fragments.counts.txt.gz

# %% [markdown]
# **Execute**
#
# List the file names, loop the list, and link the files

# %%
FD_INP=${FD_DAT}/processed/WSTARRseq_K562_hg38_A001/fragments
FN_INPS=(
    A001-input-K562-rep1.masked.dedup.fragments.counts.txt.gz
    A001-input-K562-rep2.masked.dedup.fragments.counts.txt.gz
    A001-input-K562-rep3.masked.dedup.fragments.counts.txt.gz
    A001-input-K562-rep4.masked.dedup.fragments.counts.txt.gz
    A001-K562-rep1.masked.dedup.fragments.counts.txt.gz
    A001-K562-rep2.masked.dedup.fragments.counts.txt.gz
    A001-K562-rep3.masked.dedup.fragments.counts.txt.gz
)

# %%
FD_OUT=${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
FN_OUTS=(
    WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
    WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz
    WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz
    WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz
    WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz
    WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz
    WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz
)

# %%
for idx in "${!FN_INPS[@]}"
do
    FN_INP=${FN_INPS[idx]}
    FN_OUT=${FN_OUTS[idx]}
    
    FILE=${FD_INP}/${FN_INP}
    LINK=${FD_OUT}/${FN_OUT}
    
    if [[ -h ${LINK} ]]; then
        echo "Remove existing link."
        rm ${LINK}
    fi
    
    if [[ ! -e ${LINK} ]]; then
        echo "Create symbolic links."
        ln -s ${FILE} ${LINK}
    fi
done
# Out:
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.
# Remove existing link.
# Create symbolic links.

# %% [markdown]
# **Check results**

# %%
FD_OUT=${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
ls -lh ${FD_OUT}
# Out:
# total 8.0K
# drwxrwsr-x+ 2 kk319 reddylab 512 Mar 12 14:11 summary
# lrwxrwxrwx  1 kk319 reddylab 148 Apr  1 12:33 WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/WSTARRseq_K562_hg38_A001/fragments/A001-input-K562-rep1.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 148 Apr  1 12:33 WSTARRseq_K562_A001.hg38.Input.rep2.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/WSTARRseq_K562_hg38_A001/fragments/A001-input-K562-rep2.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 148 Apr  1 12:33 WSTARRseq_K562_A001.hg38.Input.rep3.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/WSTARRseq_K562_hg38_A001/fragments/A001-input-K562-rep3.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 148 Apr  1 12:33 WSTARRseq_K562_A001.hg38.Input.rep4.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/WSTARRseq_K562_hg38_A001/fragments/A001-input-K562-rep4.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 142 Apr  1 12:33 WSTARRseq_K562_A001.hg38.Output.rep1.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/WSTARRseq_K562_hg38_A001/fragments/A001-K562-rep1.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 142 Apr  1 12:33 WSTARRseq_K562_A001.hg38.Output.rep2.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/WSTARRseq_K562_hg38_A001/fragments/A001-K562-rep2.masked.dedup.fragments.counts.txt.gz
# lrwxrwxrwx  1 kk319 reddylab 142 Apr  1 12:33 WSTARRseq_K562_A001.hg38.Output.rep3.WGS.unstranded.bed.gz -> /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/processed/WSTARRseq_K562_hg38_A001/fragments/A001-K562-rep3.masked.dedup.fragments.counts.txt.gz

# %%
FD_OUT=${FD_RES}/assay_fcc/STARR_WHG_K562_Reddy_A001/fragment_counts
FN_OUT=WSTARRseq_K562_A001.hg38.Input.rep1.WGS.unstranded.bed.gz
FP_OUT=${FD_OUT}/${FN_OUT}

zcat ${FP_OUT} | head
# Out:
# chr1	10335	10549	chr1_10335_10549	1	.
# chr1	16983	17500	chr1_16983_17500	1	.
# chr1	16985	17499	chr1_16985_17499	1	.
# chr1	17004	17500	chr1_17004_17500	1	.
# chr1	17483	17898	chr1_17483_17898	1	.
# chr1	17487	17941	chr1_17487_17941	1	.
# chr1	33606	33997	chr1_33606_33997	1	.
# chr1	33617	33997	chr1_33617_33997	1	.
# chr1	38785	39226	chr1_38785_39226	1	.
# chr1	46328	46678	chr1_46328_46678	1	.

# %% [markdown]
# ## Prepare regions of MACS peaks called in ASTARR input libraries

# %% [markdown]
# **Data: Original files**
#
# `PROJECT/data/processed/ASTARRseq_K562_hg38_KS91_210401/peaks`
#
# ```
# KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed
# KS91_K562_hg38_ASTARRseq_Input.q5.in_all.max_overlaps.bed
# ```

# %% [markdown]
# **Results: SymLinks**
#
# `PROJECT/results/region/starr_macs`
#
# ```
# ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed
# ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed
# ```

# %% [markdown]
# **Check data**

# %%
FD_INP=${FD_DAT}/processed/ASTARRseq_K562_hg38_KS91_210401/peaks
ls -lh ${FD_INP}
# Out:
# total 9.5M
# -rw-r--r-- 1 kk319 reddylab 5.7M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed
# -rw-r--r-- 1 kk319 reddylab 3.8M Mar 29 21:56 KS91_K562_hg38_ASTARRseq_Input.q5.in_all.max_overlaps.bed

# %%
FD_INP=${FD_DAT}/processed/ASTARRseq_K562_hg38_KS91_210401/peaks
FN_INP=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed
FP_INP=${FD_INP}/${FN_INP}

cat ${FP_INP} | head
# Out:
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429

# %%
FD_INP=${FD_DAT}/processed/ASTARRseq_K562_hg38_KS91_210401/peaks
FN_INP=KS91_K562_hg38_ASTARRseq_Input.q5.in_all.max_overlaps.bed
FP_INP=${FD_INP}/${FN_INP}

cat ${FP_INP} | head
# Out:
# chr1	10038	10405	6
# chr1	14282	14614	6
# chr1	16025	16338	6
# chr1	17288	17689	6
# chr1	28934	29499	6
# chr1	115429	115969	6
# chr1	136201	137353	6
# chr1	137748	138049	6
# chr1	138321	139517	6
# chr1	181005	181854	6

# %% [markdown]
# **Execute**

# %% [markdown]
# Copy union peak file

# %%
FD_INP=${FD_DAT}/processed/ASTARRseq_K562_hg38_KS91_210401/peaks
FN_INP=KS91_K562_hg38_ASTARRseq_Input.all_reps.masked.union_narrowPeak.q5.bed
FP_INP=${FD_INP}/${FN_INP}

FD_OUT=${FD_RES}/region/fcc_astarr_macs
FN_OUT=ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
FP_OUT=${FD_OUT}/${FN_OUT}

gzip -c ${FP_INP} > ${FP_OUT}
zcat ${FP_OUT} | head
# Out:
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429

# %% [markdown]
# Update overlap/intersect peak file

# %%
FD_INP=${FD_DAT}/processed/ASTARRseq_K562_hg38_KS91_210401/peaks
FN_INP=KS91_K562_hg38_ASTARRseq_Input.q5.in_all.max_overlaps.bed
FP_INP=${FD_INP}/${FN_INP}

FD_OUT=${FD_RES}/region/fcc_astarr_macs
FN_OUT=ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz
FP_OUT=${FD_OUT}/${FN_OUT}

cat ${FP_INP} | cut -f1-3 | gzip -c > ${FP_OUT}
zcat ${FP_OUT} | head
# Out:
# chr1	10038	10405
# chr1	14282	14614
# chr1	16025	16338
# chr1	17288	17689
# chr1	28934	29499
# chr1	115429	115969
# chr1	136201	137353
# chr1	137748	138049
# chr1	138321	139517
# chr1	181005	181854

# %% [markdown]
# Create metadata

# %%
TAB="$(printf '\t')"

FD_OUT=${FD_RES}/region/fcc_astarr_macs
FN_OUT=description.tsv
FP_OUT=${FD_OUT}/${FN_OUT}

cat > ${FP_OUT} << EOF
Name${TAB}Note
Chrom${TAB}Name of the chromosome
ChromStart${TAB}The starting position of the feature in the chromosome
ChromEnd${TAB}The ending position of the feature in the chromosome
EOF

cat ${FP_OUT} | expand -t 15
# Out:
# Name           Note
# Chrom          Name of the chromosome
# ChromStart     The starting position of the feature in the chromosome
# ChromEnd       The ending position of the feature in the chromosome

# %% [markdown]
# **Check results**

# %%
FD_OUT=${FD_RES}/region/fcc_astarr_macs
ls -lh ${FD_OUT}
# Out:
# total 3.3M
# -rw-rw-r-- 1 kk319 reddylab 1.2M Apr  1 12:42 ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 2.0M Apr  1 12:42 ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
# -rw-rw-r-- 1 kk319 reddylab  167 Apr  1 12:51 description.tsv

# %% [markdown]
# ## Copy ATAC peaks to `reference` folder

# %%
FD_OUT=${FD_RES}/region/fcc_astarr_macs
FN_OUT=ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
FP_OUT=${FD_OUT}/${FN_OUT}

FD_REF=${FD_PRJ}/references/fcc_peak_call_atac
FN_REF=STARRseq_ATAC.K562.TR.hg38.Input.rep_all.union.q5.bed.gz
FP_REF=${FD_REF}/${FN_REF}

cp ${FP_OUT} ${FP_REF}

# %%
FD_OUT=${FD_RES}/region/fcc_astarr_macs
FN_OUT=ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz
FP_OUT=${FD_OUT}/${FN_OUT}

FD_REF=${FD_PRJ}/references/fcc_peak_call_atac
FN_REF=STARRseq_ATAC.K562.TR.hg38.Input.rep_all.max_overlaps.q5.bed.gz
FP_REF=${FD_REF}/${FN_REF}

cp ${FP_OUT} ${FP_REF}

# %%
ls -lh ${FD_PRJ}/references/fcc_peak_call_atac
# Out:
# total 0
# -rw-rw-r-- 1 kk319 reddylab 1.2M Apr  1 12:52 STARRseq_ATAC.K562.TR.hg38.Input.rep_all.max_overlaps.q5.bed.gz
# -rw-rw-r-- 1 kk319 reddylab 2.0M Apr  1 12:52 STARRseq_ATAC.K562.TR.hg38.Input.rep_all.union.q5.bed.gz
