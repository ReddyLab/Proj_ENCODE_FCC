# %% [raw]
# ---
# title: Prepare ENCODE ChIP-seq 24 (TF; Flagship)
# subtitle: Create metadata
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# **Set global variables**

# %%
TXT_REGION_FOLDER = "encode_chipseq_flagship"

# %% [markdown]
# ## Define column description
# The peak file is in narrowPeak format, which is a standard six field bed with four additional fields (BED6+4 format)

# %%
### ENCODE narrowPeak: Narrow (or Point-Source) Peaks format
dat = tribble(
    ~Name,        ~Note,
    "Chrom",      "Name of the chromosome",
    "ChromStart", "The starting position of the feature in the chromosome",
    "ChromEnd",   "The ending position of the feature in the chromosome",
    "Name",       "Name given to a region; Use '.' if no name is assigned.",
    "Score",      "Indicates how dark the peak will be displayed in the browser (0-1000).",
    "Strand",     "+/- to denote strand or orientation. Use '.' if no orientation is assigned.",
    "SignalValue","Measurement of overall (usually, average) enrichment for the region.",
    "PValue",     "Measurement of statistical significance (-log10). Use -1 if no pValue is assigned.",
    "QValue",     "Measurement of statistical significance using false discovery rate (-log10). Use -1 if no qValue is assigned.",
    "Peak",       "Point-source called for this peak; 0-based offset from chromStart. Use -1 if no point-source called."
    
)

### assign and show
dat_cnames = dat
fun_display_table(dat)
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Name </th>
#    <th style="text-align:left;"> Note </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> Chrom </td>
#    <td style="text-align:left;"> Name of the chromosome </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> ChromStart </td>
#    <td style="text-align:left;"> The starting position of the feature in the chromosome </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> ChromEnd </td>
#    <td style="text-align:left;"> The ending position of the feature in the chromosome </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Name </td>
#    <td style="text-align:left;"> Name given to a region; Use '.' if no name is assigned. </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Score </td>
#    <td style="text-align:left;"> Indicates how dark the peak will be displayed in the browser (0-1000). </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Strand </td>
#    <td style="text-align:left;"> +/- to denote strand or orientation. Use '.' if no orientation is assigned. </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> SignalValue </td>
#    <td style="text-align:left;"> Measurement of overall (usually, average) enrichment for the region. </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> PValue </td>
#    <td style="text-align:left;"> Measurement of statistical significance (-log10). Use -1 if no pValue is assigned. </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> QValue </td>
#    <td style="text-align:left;"> Measurement of statistical significance using false discovery rate (-log10). Use -1 if no qValue is assigned. </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Peak </td>
#    <td style="text-align:left;"> Point-source called for this peak; 0-based offset from chromStart. Use -1 if no point-source called. </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Define file labeling

# %%
### set directory
txt_folder = TXT_REGION_FOLDER
txt_fdiry  = file.path(FD_RES, "region", txt_folder)
txt_fglob  = file.path(txt_fdiry, "*bed*")

### get file names
vec_txt_fpath = Sys.glob(txt_fglob)
vec_txt_fname = basename(vec_txt_fpath)

### init info table
dat = data.frame(
    "Folder" = txt_folder,
    "FName"  = vec_txt_fname
)

### arrange table
dat = dat %>% tidyr::separate(
        FName, 
        c("Biosample", "Genome", "Index_Experiment", "Index_File", "Assay", "Target", "File_Type", "File_Ext"),
        sep = "\\.",
        remove = FALSE
    ) %>%
    dplyr::mutate(Label = paste(tolower(Assay), Target, Index_File, sep="_")) %>%
    dplyr::select(Folder, FName, Label) 

### assign and show
dat_region_label = dat
print(dim(dat))
fun_display_table(dat)
# Out:
# [1] 734   3
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Folder </th>
#    <th style="text-align:left;"> FName </th>
#    <th style="text-align:left;"> Label </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AKO.ENCFF769AUF.ChIPseq.CTCF.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CTCF_ENCFF769AUF </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQA.ENCFF807FNB.ChIPseq.KDM5B.bed.gz </td>
#    <td style="text-align:left;"> chipseq_KDM5B_ENCFF807FNB </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQD.ENCFF408NUX.ChIPseq.CHD1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CHD1_ENCFF408NUX </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQE.ENCFF804RVA.ChIPseq.EZH2.bed.gz </td>
#    <td style="text-align:left;"> chipseq_EZH2_ENCFF804RVA </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQF.ENCFF669MJX.ChIPseq.HDAC1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_HDAC1_ENCFF669MJX </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQG.ENCFF182MPT.ChIPseq.HDAC2.bed.gz </td>
#    <td style="text-align:left;"> chipseq_HDAC2_ENCFF182MPT </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQH.ENCFF981ISM.ChIPseq.PHF8.bed.gz </td>
#    <td style="text-align:left;"> chipseq_PHF8_ENCFF981ISM </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQI.ENCFF942VGF.ChIPseq.RBBP5.bed.gz </td>
#    <td style="text-align:left;"> chipseq_RBBP5_ENCFF942VGF </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AQJ.ENCFF383IEP.ChIPseq.SAP30.bed.gz </td>
#    <td style="text-align:left;"> chipseq_SAP30_ENCFF383IEP </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATJ.ENCFF736FGN.ChIPseq.HDAC6.bed.gz </td>
#    <td style="text-align:left;"> chipseq_HDAC6_ENCFF736FGN </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATL.ENCFF985QBS.ChIPseq.CHD4.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CHD4_ENCFF985QBS </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATM.ENCFF539MIO.ChIPseq.REST.bed.gz </td>
#    <td style="text-align:left;"> chipseq_REST_ENCFF539MIO </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATT.ENCFF532VPN.ChIPseq.CREBBP.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CREBBP_ENCFF532VPN </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATU.ENCFF258XBJ.ChIPseq.CBX2.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CBX2_ENCFF258XBJ </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATV.ENCFF068OEJ.ChIPseq.CBX3.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CBX3_ENCFF068OEJ </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATW.ENCFF522HZT.ChIPseq.CBX8.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CBX8_ENCFF522HZT </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATX.ENCFF054XCG.ChIPseq.KDM1A.bed.gz </td>
#    <td style="text-align:left;"> chipseq_KDM1A_ENCFF054XCG </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATY.ENCFF816AEF.ChIPseq.NCOR1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_NCOR1_ENCFF816AEF </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000ATZ.ENCFF349VSP.ChIPseq.KAT2B.bed.gz </td>
#    <td style="text-align:left;"> chipseq_KAT2B_ENCFF349VSP </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AUA.ENCFF923GDR.ChIPseq.RNF2.bed.gz </td>
#    <td style="text-align:left;"> chipseq_RNF2_ENCFF923GDR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AUB.ENCFF821XJU.ChIPseq.SIRT6.bed.gz </td>
#    <td style="text-align:left;"> chipseq_SIRT6_ENCFF821XJU </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AUC.ENCFF647TBC.ChIPseq.SUZ12.bed.gz </td>
#    <td style="text-align:left;"> chipseq_SUZ12_ENCFF647TBC </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AUT.ENCFF267QRI.ChIPseq.SETDB1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_SETDB1_ENCFF267QRI </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AVD.ENCFF722UJW.ChIPseq.CHD7.bed.gz </td>
#    <td style="text-align:left;"> chipseq_CHD7_ENCFF722UJW </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000AVE.ENCFF862UUR.ChIPseq.WHSC1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_WHSC1_ENCFF862UUR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BGW.ENCFF888CKG.ChIPseq.SPI1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_SPI1_ENCFF888CKG </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BGX.ENCFF742ZHT.ChIPseq.SIX5.bed.gz </td>
#    <td style="text-align:left;"> chipseq_SIX5_ENCFF742ZHT </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BKF.ENCFF146GZZ.ChIPseq.ZBTB33.bed.gz </td>
#    <td style="text-align:left;"> chipseq_ZBTB33_ENCFF146GZZ </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BKH.ENCFF070ZTX.ChIPseq.BCLAF1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_BCLAF1_ENCFF070ZTX </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BKM.ENCFF242YZU.ChIPseq.GATA2.bed.gz </td>
#    <td style="text-align:left;"> chipseq_GATA2_ENCFF242YZU </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BKO.ENCFF171NEU.ChIPseq.SP1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_SP1_ENCFF171NEU </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BKQ.ENCFF886BDQ.ChIPseq.ETS1.bed.gz </td>
#    <td style="text-align:left;"> chipseq_ETS1_ENCFF886BDQ </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> encode_chipseq_flagship </td>
#    <td style="text-align:left;"> K562.hg38.ENCSR000BKR.ENCFF060MMW.ChIPseq.POLR2AphosphoS5.bed.gz </td>
#    <td style="text-align:left;"> chipseq_POLR2AphosphoS5_ENCFF060MMW </td>
#   </t

# %% [markdown]
# ## Save results

# %%
txt_folder = TXT_REGION_FOLDER
txt_fdiry  = file.path(FD_RES, "region", txt_folder, "summary")
txt_fname  = "description.tsv"
txt_fpath  = file.path(txt_fdiry, txt_fname)

dir.create(txt_fdiry, showWarnings = FALSE)
dat = dat_cnames
write_tsv(dat, txt_fpath)

# %%
txt_folder = TXT_REGION_FOLDER
txt_fdiry  = file.path(FD_RES, "region", txt_folder, "summary")
txt_fname  = "metadata.label.tsv"
txt_fpath  = file.path(txt_fdiry, txt_fname)

dir.create(txt_fdiry, showWarnings = FALSE)
dat = dat_region_label
write_tsv(dat, txt_fpath)
