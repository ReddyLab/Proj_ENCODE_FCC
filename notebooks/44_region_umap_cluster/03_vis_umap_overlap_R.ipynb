# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import data

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage", 
    "fcc_astarr_macs_input_overlap",
    "fcc_starrmpracrispri_vote2",
    "run_umap"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# umap.metric_euclidean.neighbors_070.coverage.encode_chipseq_full_log2p.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage", 
    "fcc_astarr_macs_input_overlap",
    "fcc_starrmpracrispri_vote2",
    "run_umap"
)
txt_fname = "umap.metric_euclidean.neighbors_070.coverage.encode_chipseq_full_log2p.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)
#dat = dat %>% dplyr::left_join(mat_region_annot_merge, by = "Region")

dat_region_umap = dat
print(dim(dat))
head(dat)
# Out:
# [1] 33953     3
#   UMAP1     UMAP2    Region
# 1 -1.680812 5.204691 chr1:605104-605675
# 2  8.620607 5.645398 chr1:778233-779389
# 3 -1.475871 3.743281 chr1:818708-819335
# 4  6.664661 4.790435 chr1:826796-828040
# 5  2.103905 6.490981 chr1:842516-843431
# 6  6.647105 4.062519 chr1:903783-905204

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage", 
    "fcc_astarr_macs_input_overlap",
    "fcc_starrmpracrispri_vote2",
    "prepare_matrix"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# matrix.coverage.encode_chipseq_full_log2p.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage",
    "fcc_astarr_macs_input_overlap",
    "fcc_starrmpracrispri_vote2",
    "prepare_matrix"
)
txt_fname = "matrix.coverage.encode_chipseq_full_log2p.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_region_score = dat
print(dim(dat))
head(dat)
# Out:
# [1] 33953   523
#   Region             H2AFZ    H3K27ac   H3K27me3   H3K36me3  H3K4me1   H3K4me2
# 1 chr1:605104-605675 2.094986 0.9201233 0.09549239 0.0000000 1.6243630 1.560025
# 2 chr1:778233-779389 3.119901 3.1743137 0.39243888 0.8656374 1.1477264 3.991318
# 3 chr1:818708-819335 1.074821 1.1568108 0.49421334 1.7651931 1.1150599 1.075847
# 4 chr1:826796-828040 3.028686 3.1233037 0.23484175 0.4983632 0.9520562 4.076243
# 5 chr1:842516-843431 1.222347 1.3519505 0.47134512 1.4539152 2.3484052 3.213781
# 6 chr1:903783-905204 2.615482 1.8773556 0.47148768 0.3476248 2.9831970 2.836837
#   H3K4me3   H3K79me2  H3K9ac   ⋯ ZNF780A   ZNF785    ZNF79     ZNF7
# 1 0.9445916 0.1477144 1.314610 ⋯ 0.6586712 0.7180867 0.7701288 1.0974422
# 2 4.8284374 2.3029331 3.739369 ⋯ 0.7208764 0.7477105 1.2779312 1.5079316
# 3 0.5142511 0.8425887 1.258866 ⋯ 0.6420148 0.3466574 0.1973735 0.6480494
# 4 4.6315932 1.9689497 3.798574 ⋯ 0.4582234 0.4192714 0.4277252 0.8947565
# 5 1.3750059 1.4738077 1.795823 ⋯ 1.1283132 0.7744324 0.5117271 1.6152374
# 6 3.2457025 0.8516431 2.843692 ⋯ 0.8883626 0.7103359 0.6911241 1.1713349
#   ZNF830    ZNF83     ZNF84     ZSCAN29  ZSCAN32   ZZZ3
# 1 0.8853357 1.1409618 0.9121700 1.148158 0.8503978 1.0693103
# 2 0.6926837 0.9203619 1.3328110 1.112834 1.1075004 0.9739852
# 3 0.4066633 0.8281344 0.5028296 0.332551 0.2216259 0.6857617
# 4 0.5832781 0.8698982 0.7338784 2.411239 0.7679615 0.6075060
# 5 0.6972730 0.7085007 0.9212428 1.096289 0.7903675 0.9266325
# 6 0.7032200 0.8390485 1.1736136 1.020574 0.8518877 0.6823324

# %%
dat = dplyr::left_join(
    dat_region_umap,
    dat_region_score,
    by = "Region"
)
dat_region_umap_chipseq = dat

# %%
dat = dat_region_umap_chipseq
gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
    geom_point(size=0.1) + 
    theme_cowplot() +
    labs(title = "CREs (ATAC overlap; ~34k)")
options(repr.plot.height = 5, repr.plot.width = 5)
print(gpt)
# Out:
# plot without title
