# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import data

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage", 
    "fcc_astarr_macs_input_union",
    "fcc_starrmpracrispri_vote2",
    "run_umap"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# umap.metric_euclidean.neighbors_070.coverage.encode_chipseq_full_log2p.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage", 
    "fcc_astarr_macs_input_union",
    "fcc_starrmpracrispri_vote2",
    "run_umap"
)
txt_fname = "umap.metric_euclidean.neighbors_070.coverage.encode_chipseq_full_log2p.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)
#dat = dat %>% dplyr::left_join(mat_region_annot_merge, by = "Region")

dat_region_umap = dat
print(dim(dat))
head(dat)
# Out:
# [1] 39788     3
#   UMAP1     UMAP2    Region
# 1 -2.704307 5.962251 chr1:605090-605823
# 2  8.017845 7.124260 chr1:777949-779437
# 3 -2.496098 4.366557 chr1:818602-819380
# 4  7.690060 7.069760 chr1:826754-828040
# 5  1.905707 7.566984 chr1:842480-843449
# 6  6.245972 5.581694 chr1:903633-905556

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage", 
    "fcc_astarr_macs_input_union",
    "fcc_starrmpracrispri_vote2",
    "prepare_matrix"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# matrix.coverage.encode_chipseq_full_log2p.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage",
    "fcc_astarr_macs_input_union",
    "fcc_starrmpracrispri_vote2",
    "prepare_matrix"
)
txt_fname = "matrix.coverage.encode_chipseq_full_log2p.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_region_score = dat
print(dim(dat))
head(dat)
# Out:
# [1] 39788   523
#   Region             H2AFZ     H3K27ac   H3K27me3   H3K36me3  H3K4me1
# 1 chr1:605090-605823 1.8659821 0.7946205 0.07492531 0.0000000 1.4612318
# 2 chr1:777949-779437 2.8953278 3.1388046 0.33226052 0.8363790 1.1665580
# 3 chr1:818602-819380 0.9196894 1.1118860 0.45346121 1.6125554 1.0571355
# 4 chr1:826754-828040 3.0184490 3.1205444 0.25040560 0.4998362 0.9587391
# 5 chr1:842480-843449 1.1811853 1.3135013 0.46257798 1.4139812 2.3069009
# 6 chr1:903633-905556 2.4809966 1.7206681 0.56580382 0.4482291 3.1712020
#   H3K4me2   H3K4me3   H3K79me2  H3K9ac   ⋯ ZNF780A   ZNF785    ZNF79
# 1 1.3963952 0.7958307 0.1163453 1.170399 ⋯ 0.5412462 0.5876069 0.6318186
# 2 4.0944219 4.8734823 2.6185535 3.850834 ⋯ 0.8319923 0.9058207 1.3036872
# 3 0.9206127 0.4747621 0.8315027 1.188888 ⋯ 0.6740529 0.4164074 0.2388407
# 4 4.1005993 4.6318202 2.0340079 3.807803 ⋯ 0.4693348 0.4266920 0.4598166
# 5 3.1479465 1.3341061 1.4394955 1.762123 ⋯ 1.1063148 0.7676862 0.5091364
# 6 2.7637855 3.0223536 0.9621647 2.705802 ⋯ 0.8664412 0.7983732 0.7778089
#   ZNF7      ZNF830    ZNF83     ZNF84     ZSCAN29   ZSCAN32   ZZZ3
# 1 0.9167503 0.7328125 1.0681273 0.7561480 0.9765931 0.7009084 0.9160730
# 2 1.4784334 0.6949081 1.0023209 1.3354947 1.1249765 1.1479188 0.9382406
# 3 0.6550110 0.4208413 0.8246481 0.5244047 0.3649086 0.2172444 0.6718033
# 4 0.9766027 0.6003440 0.8644259 0.7636019 2.4016864 0.8064099 0.6601364
# 5 1.5730109 0.6916440 0.6813035 0.8923405 1.0796546 0.7750573 0.9334495
# 6 1.2452705 0.7914610 0.8094663 1.1484526 1.1943203 0.9376615 0.7320521

# %%
dat = dplyr::left_join(
    dat_region_umap,
    dat_region_score,
    by = "Region"
)
dat_region_umap_chipseq = dat

# %%
dat = dat_region_umap_chipseq
gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
    geom_point(size=0.1) + 
    theme_cowplot() +
    labs(title = "CREs (ATAC union; ~40k)")
options(repr.plot.height = 5, repr.plot.width = 5)
print(gpt)
# Out:
# plot without title
