# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import data

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage_score", 
    "fcc_astarr_macs_input_overlap",
    "atac_10k",
    "umap"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# umap.metric_euclidean.neighbors_15.coverage.encode_chipseq_full_mean0.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage_score", 
    "fcc_astarr_macs_input_overlap",
    "atac_full",
    "umap"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# umap.metric_euclidean.neighbors_15.coverage.encode_chipseq_full_mean0.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage_score", 
    "fcc_astarr_macs_input_overlap",
    "atac_10k",
    "umap"
)
txt_fname = "umap.metric_euclidean.neighbors_15.coverage.encode_chipseq_full_mean0.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_umap_chipseq_full = dat
print(dim(dat))
head(dat)
# Out:
# [1] 10000     3
#   UMAP1      UMAP2     Region
# 1 -1.2513646  7.238779 chr1:100184509-100184772
# 2  0.2714417  8.285042 chr1:100323413-100323923
# 3  3.8759840 10.938533 chr1:10032429-10033763
# 4  0.5962320  7.999349 chr1:10035024-10035463
# 5 -1.9781275  6.092954 chr1:100394178-100394637
# 6 -2.7965446 12.771832 chr1:100455628-100456077

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage_score", 
    "fcc_astarr_macs_input_overlap",
    "atac_full",
    "umap"
)
txt_fname = "umap.metric_euclidean.neighbors_15.coverage.encode_chipseq_full_mean0.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_umap_chipseq_full = dat
print(dim(dat))
head(dat)
# Out:
# [1] 150042      3
#   UMAP1      UMAP2      Region
# 1 -1.1993874 -0.4905716 chr1:100028014-100029653
# 2  9.5403470  0.6069768 chr1:100036895-100039189
# 3 -0.7346483 -1.9662793 chr1:100046252-100046533
# 4 -0.1900961 -2.0148084 chr1:100048290-100048918
# 5  5.1834116 -2.5021160 chr1:100050225-100050529
# 6 -1.6770324 -0.3091461 chr1:100064757-100065161

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage_score", 
    "fcc_astarr_macs_input_overlap",
    "atac_full",
    "umap"
)
txt_fname = "umap.metric_euclidean.neighbors_70.coverage.encode_chipseq_full_mean0.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_umap_chipseq_full = dat
print(dim(dat))
head(dat)
# Out:
# [1] 150042      3
#   UMAP1      UMAP2     Region
# 1 -0.1630698 -1.029142 chr1:100028014-100029653
# 2  8.9831590  1.234464 chr1:100036895-100039189
# 3  0.3322169 -2.308855 chr1:100046252-100046533
# 4  0.8947283 -2.101368 chr1:100048290-100048918
# 5  5.8766203 -1.507596 chr1:100050225-100050529
# 6 -0.7976286 -0.844861 chr1:100064757-100065161

# %%
txt_fdiry = file.path(
    FD_RES, 
    "analysis_umap_cluster_by_coverage_score", 
    "fcc_astarr_macs_input_overlap",
    "atac_full",
    "umap"
)
txt_fname = "umap.metric_manhattan.neighbors_70.coverage.encode_chipseq_full_mean0.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_umap_chipseq_full = dat
print(dim(dat))
head(dat)
# Out:
# [1] 150042      3
#   UMAP1       UMAP2      Region
# 1 -0.52776030  0.6105017 chr1:100028014-100029653
# 2  7.81621740 -1.4413334 chr1:100036895-100039189
# 3 -0.04301362  0.1675593 chr1:100046252-100046533
# 4  1.18013130 -0.6566290 chr1:100048290-100048918
# 5  2.43919590 -1.2736148 chr1:100050225-100050529
# 6 -1.27813270  1.2356849 chr1:100064757-100065161

# %%
dat = dat_umap_chipseq_full
gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
    geom_point(size=0.1) + 
    theme_cowplot()
print(gpt)
# Out:
# plot without title

# %%
dat = dat_umap_chipseq_full
gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
    geom_point(size=0.1) + 
    theme_cowplot()
print(gpt)
# Out:
# plot without title

# %%
dat = dat_umap_chipseq_full
gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
    geom_point(size=0.01, alpha = 0.5) + 
    theme_cowplot()
print(gpt)
# Out:
# plot without title

# %%
dat = dat_umap_chipseq_full
gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
    geom_point(size=0.01, alpha = 0.5) + 
    theme_cowplot()
print(gpt)
# Out:
# plot without title
