# %% [raw]
# ---
# title: FCC Peak calls
# subtitle: export annotation
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Preview

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
vec = dir(txt_fdiry)
print(vec)
# Out:
#   [1] "hclust.col.annotation.prepare.chipseq_full.fcc.tss.rds"
#   [2] "hclust.col.annotation.prepare.chipseq_full.only.rds"
#   [3] "hclust.col.annotation.test_chrX.chipseq_full.only.rds"
#   [4] "hclust.row.annotation.prepare.chipseq_full.fcc.tss.rds"
#   [5] "hclust.row.annotation.prepare.chipseq_full.only.rds"
#   [6] "hclust.row.annotation.test_chrX.chipseq_full.only.rds"
#   [7] "hdbscan.metric_euclidean.min_cluster_size_1e2.umap.prepare.cre.chipseq_full.fcc.tss.pkl"
#   [8] "hdbscan.metric_euclidean.min_cluster_size_1e3.umap.prepare.cre.chipseq_full.fcc.tss.pkl"
#   [9] "hdbscan.metric_manhattan.min_cluster_size_1e2.annotation.prepare.cre.chipseq_full.fcc.pkl"
#  [10] "hdbscan.metric_manhattan.min_cluster_size_1e2.annotation.prepare.cre.chipseq_full.fcc.tss.pkl"
#  [11] "hdbscan.metric_manhattan.min_cluster_size_1e2.annotation.prepare.cre.chipseq_full.only.pkl"
#  [12] "hdbscan.metric_manhattan.min_cluster_size_1e2.annotation.test_chrX.chipseq_full.fcc.tss.pkl"
#  [13] "hdbscan.metric_manhattan.min_cluster_size_1e2.annotation.test_chrX.chipseq_full.only.pkl"
#  [14] "hdbscan.metric_manhattan.min_cluster_size_1e3.annotation.prepare.cre.chipseq_full.fcc.pkl"
#  [15] "hdbscan.metric_manhattan.min_cluster_size_1e3.annotation.prepare.cre.chipseq_full.fcc.tss.pkl"
#  [16] "hdbscan.metric_manhattan.min_cluster_size_1e3.annotation.prepare.cre.chipseq_full.only.pkl"
#  [17] "hdbscan.metric_manhattan.min_cluster_size_1e3.annotation.test_chrX.chipseq_full.fcc.tss.pkl"
#  [18] "hdbscan.metric_manhattan.min_cluster_size_1e3.annotation.test_chrX.chipseq_full.only.pkl"
#  [19] "hdbscan.metric_manhattan.min_cluster_size_1e4.annotation.prepare.cre.chipseq_full.fcc.pkl"
#  [20] "hdbscan.metric_manhattan.min_cluster_size_1e4.annotation.prepare.cre.chipseq_full.fcc.tss.pkl"
#  [21] "hdbscan.metric_manhattan.min_cluster_size_1e4.annotation.prepare.cre.chipseq_full.only.pkl"
#  [22] "hdbscan.metric_manhattan.min_cluster_size_1e4.annotation.test_chrX.chipseq_full.fcc.tss.pkl"
#  [23] "hdbscan.metric_manhattan.min_cluster_size_1e4.annotation.test_chrX.chipseq_full.only.pkl"
#  [24] "matrix.annotation.chipseq_flagship.tsv"
#  [25] "matrix.annotation.chipseq_full.tsv"
#  [26] "matrix.annotation.chipseq_histone.tsv"
#  [27] "matrix.annotation.chipseq_subset.tsv"
#  [28] "matrix.annotation.fcc_peak_call.tsv"
#  [29] "matrix.annotation.genome_tss.tsv"
#  [30] "matrix.annotation.merge.chipseq_full.fcc.tss.tsv"
#  [31] "matrix.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
#  [32] "matrix.annotation.prepare.cre.chipseq_full.fcc.tsv"
#  [33] "matrix.annotation.prepare.cre.chipseq_full.only.tsv"
#  [34] "matrix.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
#  [35] "matrix.annotation.prepare.enh.chipseq_full.fcc.tsv"
#  [36] "matrix.annotation.prepare.enh.chipseq_full.only.tsv"
#  [37] "matrix.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
#  [38] "matrix.annotation.prepare.full.chipseq_full.fcc.tsv"
#  [39] "matrix.annotation.prepare.full.chipseq_full.only.tsv"
#  [40] "matrix.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
#  [41] "matrix.annotation.test_chrX.chipseq_full.only.tsv"
#  [42] "matrix.mca_exp90.prepare.cre.chipseq_full.fcc.tss.tsv"
#  [43] "matrix.mca_exp90.test_chrX.chipseq_full.fcc.tss.tsv"
#  [44] "region.annotation.encode_chipseq_flagship.tsv"
#  [45] "region.annotation.encode_chipseq_histone.tsv"
#  [46] "region.annotation.encode_chipseq_subset.tsv"
#  [47] "region.annotation.encode_chromatin_states.tsv"
#  [48] "region.annotation.fcc_astarr_csaw.tsv"
#  [49] "region.annotation.fcc_crispri_growth.tsv"
#  [50] "region.annotation.fcc_crispri_hcrff.tsv"
#  [51] "region.annotation.fcc_mpra_agarwal2023.tsv"
#  [52] "region.annotation.fcc_starrmpra_junke.tsv"
#  [53] "region.annotation.genome_tss.tsv"
#  [54] "region.annotation.hic_insitu_K562_ENCSR545YBD.tsv"
#  [55] "region.annotation.hic_intact_K562_deep.tsv"
#  [56] "region.annotation.hic_intact_K562_ENCSR479XDG.tsv"
#  [57] "region.annotation.module_tf_shannon.tsv"
#  [58] "region.summary.encode_chipseq_encode4.tsv"
#  [59] "region.summary.encode_chipseq_flagship.tsv"
#  [60] "region.summary.encode_chipseq_histone.tsv"
#  [61] "region.summary.encode_chipseq_subset.tsv"
#  [62] "region.summary.encode_chromatin_states.tsv"
#  [63] "region.summary.fcc_astarr_csaw.tsv"
#  [64] "region.summary.fcc_crispri_growth.tsv"
#  [65] "region.summary.fcc_crispri_hcrff.tsv"
#  [66] "region.summary.fcc_mpra_agarwal2023.tsv"
#  [67] "region.summary.fcc_starrmpra_junke.tsv"
#  [68] "region.summary.genome_tss.tsv"
#  [69] "region.summary.hic_insitu_K562_ENCSR545YBD.tsv"
#  [70] "region.summary.hic_intact_K562_deep.tsv"
#  [71] "region.summary.hic_intact_K562_ENCSR479XDG.tsv"
#  [72] "region.summary.module_tf_shannon.tsv"
#  [73] "result.summary.chipseq_flagship.tsv"
#  [74] "result.summary.chipseq_full.tsv"
#  [75] "result.summary.chipseq_histone.tsv"
#  [76] "result.summary.chipseq_subset.tsv"
#  [77] "result.summary.connectivity.loop.tsv"
#  [78] "result.summary.encode_chromatin_states.tsv"
#  [79] "result.summary.fcc_peak_call.tsv"
#  [80] "result.summary.genome_tss.tsv"
#  [81] "result.summary.tfmodule.tsv"
#  [82] "tmp"
#  [83] "umap.metric_cosine.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
#  [84] "umap.metric_cosine.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tsv"
#  [85] "umap.metric_cosine.n_neighbors_15.annotation.prepare.cre.chipseq_full.only.tsv"
#  [86] "umap.metric_cosine.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
#  [87] "umap.metric_cosine.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tsv"
#  [88] "umap.metric_cosine.n_neighbors_15.annotation.prepare.enh.chipseq_full.only.tsv"
#  [89] "umap.metric_cosine.n_neighbors_15.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
#  [90] "umap.metric_cosine.n_neighbors_15.annotation.prepare.full.chipseq_full.fcc.tsv"
#  [91] "umap.metric_cosine.n_neighbors_15.annotation.prepare.full.chipseq_full.only.tsv"
#  [92] "umap.metric_cosine.n_neighbors_15.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
#  [93] "umap.metric_cosine.n_neighbors_15.annotation.test_chrX.chipseq_full.only.tsv"
#  [94] "umap.metric_cosine.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
#  [95] "umap.metric_cosine.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tsv"
#  [96] "umap.metric_cosine.n_neighbors_50.annotation.prepare.cre.chipseq_full.only.tsv"
#  [97] "umap.metric_cosine.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
#  [98] "umap.metric_cosine.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tsv"
#  [99] "umap.metric_cosine.n_neighbors_50.annotation.prepare.enh.chipseq_full.only.tsv"
# [100] "umap.metric_cosine.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [101] "umap.metric_cosine.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tsv"
# [102] "umap.metric_cosine.n_neighbors_50.annotation.prepare.full.chipseq_full.only.tsv"
# [103] "umap.metric_cosine.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [104] "umap.metric_cosine.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [105] "umap.metric_cosine.n_neighbors_60.annotation.prepare.cre.chipseq_full.only.tsv"
# [106] "umap.metric_cosine.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [107] "umap.metric_cosine.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [108] "umap.metric_cosine.n_neighbors_60.annotation.prepare.enh.chipseq_full.only.tsv"
# [109] "umap.metric_cosine.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [110] "umap.metric_cosine.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tsv"
# [111] "umap.metric_cosine.n_neighbors_60.annotation.prepare.full.chipseq_full.only.tsv"
# [112] "umap.metric_cosine.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [113] "umap.metric_cosine.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [114] "umap.metric_cosine.n_neighbors_70.annotation.prepare.cre.chipseq_full.only.tsv"
# [115] "umap.metric_cosine.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [116] "umap.metric_cosine.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [117] "umap.metric_cosine.n_neighbors_70.annotation.prepare.enh.chipseq_full.only.tsv"
# [118] "umap.metric_cosine.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [119] "umap.metric_cosine.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tsv"
# [120] "umap.metric_cosine.n_neighbors_70.annotation.prepare.full.chipseq_full.only.tsv"
# [121] "umap.metric_cosine.n_neighbors_70.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [122] "umap.metric_cosine.n_neighbors_70.annotation.test_chrX.chipseq_full.only.tsv"
# [123] "umap.metric_cosine.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [124] "umap.metric_cosine.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [125] "umap.metric_cosine.n_neighbors_90.annotation.prepare.cre.chipseq_full.only.tsv"
# [126] "umap.metric_cosine.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [127] "umap.metric_cosine.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [128] "umap.metric_cosine.n_neighbors_90.annotation.prepare.enh.chipseq_full.only.tsv"
# [129] "umap.metric_cosine.n_neighbors_90.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [130] "umap.metric_cosine.n_neighbors_90.annotation.prepare.full.chipseq_full.fcc.tsv"
# [131] "umap.metric_cosine.n_neighbors_90.annotation.prepare.full.chipseq_full.only.tsv"
# [132] "umap.metric_euclidean.n_neighbors_15.mca_exp90.test_chrX.chipseq_full.fcc.tss.tsv"
# [133] "umap.metric_euclidean.n_neighbors_70.mca_exp90.test_chrX.chipseq_full.fcc.tss.tsv"
# [134] "umap.metric_hamming.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [135] "umap.metric_hamming.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [136] "umap.metric_hamming.n_neighbors_15.annotation.prepare.cre.chipseq_full.only.tsv"
# [137] "umap.metric_hamming.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [138] "umap.metric_hamming.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [139] "umap.metric_hamming.n_neighbors_15.annotation.prepare.enh.chipseq_full.only.tsv"
# [140] "umap.metric_hamming.n_neighbors_15.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [141] "umap.metric_hamming.n_neighbors_15.annotation.prepare.full.chipseq_full.only.tsv"
# [142] "umap.metric_hamming.n_neighbors_15.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [143] "umap.metric_hamming.n_neighbors_15.annotation.test_chrX.chipseq_full.only.tsv"
# [144] "umap.metric_hamming.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [145] "umap.metric_hamming.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [146] "umap.metric_hamming.n_neighbors_50.annotation.prepare.cre.chipseq_full.only.tsv"
# [147] "umap.metric_hamming.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [148] "umap.metric_hamming.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [149] "umap.metric_hamming.n_neighbors_50.annotation.prepare.enh.chipseq_full.only.tsv"
# [150] "umap.metric_hamming.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [151] "umap.metric_hamming.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tsv"
# [152] "umap.metric_hamming.n_neighbors_50.annotation.prepare.full.chipseq_full.only.tsv"
# [153] "umap.metric_hamming.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [154] "umap.metric_hamming.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [155] "umap.metric_hamming.n_neighbors_60.annotation.prepare.cre.chipseq_full.only.tsv"
# [156] "umap.metric_hamming.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [157] "umap.metric_hamming.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [158] "umap.metric_hamming.n_neighbors_60.annotation.prepare.enh.chipseq_full.only.tsv"
# [159] "umap.metric_hamming.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [160] "umap.metric_hamming.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tsv"
# [161] "umap.metric_hamming.n_neighbors_60.annotation.prepare.full.chipseq_full.only.tsv"
# [162] "umap.metric_hamming.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [163] "umap.metric_hamming.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [164] "umap.metric_hamming.n_neighbors_70.annotation.prepare.cre.chipseq_full.only.tsv"
# [165] "umap.metric_hamming.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [166] "umap.metric_hamming.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [167] "umap.metric_hamming.n_neighbors_70.annotation.prepare.enh.chipseq_full.only.tsv"
# [168] "umap.metric_hamming.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [169] "umap.metric_hamming.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tsv"
# [170] "umap.metric_hamming.n_neighbors_70.annotation.prepare.full.chipseq_full.only.tsv"
# [171] "umap.metric_hamming.n_neighbors_70.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [172] "umap.metric_hamming.n_neighbors_70.annotation.test_chrX.chipseq_full.only.tsv"
# [173] "umap.metric_hamming.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [174] "umap.metric_hamming.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [175] "umap.metric_hamming.n_neighbors_90.annotation.prepare.cre.chipseq_full.only.tsv"
# [176] "umap.metric_hamming.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [177] "umap.metric_hamming.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [178] "umap.metric_hamming.n_neighbors_90.annotation.prepare.enh.chipseq_full.only.tsv"
# [179] "umap.metric_hamming.n_neighbors_90.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [180] "umap.metric_hamming.n_neighbors_90.annotation.prepare.full.chipseq_full.fcc.tsv"
# [181] "umap.metric_hamming.n_neighbors_90.annotation.prepare.full.chipseq_full.only.tsv"
# [182] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [183] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [184] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.cre.chipseq_full.only.tsv"
# [185] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [186] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [187] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.enh.chipseq_full.only.tsv"
# [188] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [189] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.full.chipseq_full.fcc.tsv"
# [190] "umap.metric_jaccard.n_neighbors_15.annotation.prepare.full.chipseq_full.only.tsv"
# [191] "umap.metric_jaccard.n_neighbors_15.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [192] "umap.metric_jaccard.n_neighbors_15.annotation.test_chrX.chipseq_full.only.tsv"
# [193] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [194] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [195] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.cre.chipseq_full.only.tsv"
# [196] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [197] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [198] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.enh.chipseq_full.only.tsv"
# [199] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [200] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tsv"
# [201] "umap.metric_jaccard.n_neighbors_50.annotation.prepare.full.chipseq_full.only.tsv"
# [202] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [203] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [204] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.cre.chipseq_full.only.tsv"
# [205] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [206] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [207] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.enh.chipseq_full.only.tsv"
# [208] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [209] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tsv"
# [210] "umap.metric_jaccard.n_neighbors_60.annotation.prepare.full.chipseq_full.only.tsv"
# [211] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [212] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [213] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.cre.chipseq_full.only.tsv"
# [214] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [215] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [216] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.enh.chipseq_full.only.tsv"
# [217] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [218] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tsv"
# [219] "umap.metric_jaccard.n_neighbors_70.annotation.prepare.full.chipseq_full.only.tsv"
# [220] "umap.metric_jaccard.n_neighbors_70.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [221] "umap.metric_jaccard.n_neighbors_70.annotation.test_chrX.chipseq_full.only.tsv"
# [222] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [223] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [224] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.cre.chipseq_full.only.tsv"
# [225] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [226] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [227] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.enh.chipseq_full.only.tsv"
# [228] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [229] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.full.chipseq_full.fcc.tsv"
# [230] "umap.metric_jaccard.n_neighbors_90.annotation.prepare.full.chipseq_full.only.tsv"
# [231] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [232] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [233] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.cre.chipseq_full.only.tsv"
# [234] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [235] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [236] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.enh.chipseq_full.only.tsv"
# [237] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [238] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.full.chipseq_full.fcc.tsv"
# [239] "umap.metric_manhattan.n_neighbors_15.annotation.prepare.full.chipseq_full.only.tsv"
# [240] "umap.metric_manhattan.n_neighbors_15.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [241] "umap.metric_manhattan.n_neighbors_15.annotation.test_chrX.chipseq_full.only.tsv"
# [242] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [243] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [244] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.cre.chipseq_full.only.tsv"
# [245] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [246] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [247] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.enh.chipseq_full.only.tsv"
# [248] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [249] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.full.chipseq_full.fcc.tsv"
# [250] "umap.metric_manhattan.n_neighbors_50.annotation.prepare.full.chipseq_full.only.tsv"
# [251] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [252] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.cre.chipseq_full.only.tsv"
# [253] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [254] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [255] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.enh.chipseq_full.only.tsv"
# [256] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [257] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.full.chipseq_full.fcc.tsv"
# [258] "umap.metric_manhattan.n_neighbors_60.annotation.prepare.full.chipseq_full.only.tsv"
# [259] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [260] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [261] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.cre.chipseq_full.only.tsv"
# [262] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [263] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tsv"
# [264] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.enh.chipseq_full.only.tsv"
# [265] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [266] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.full.chipseq_full.fcc.tsv"
# [267] "umap.metric_manhattan.n_neighbors_70.annotation.prepare.full.chipseq_full.only.tsv"
# [268] "umap.metric_manhattan.n_neighbors_70.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [269] "umap.metric_manhattan.n_neighbors_70.annotation.test_chrX.chipseq_full.only.tsv"
# [270] "umap.metric_manhattan.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [271] "umap.metric_manhattan.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tsv"
# [272] "umap.metric_manhattan.n_neighbors_90.annotation.prepare.cre.chipseq_full.only.tsv"
# [273] "umap.metric_manhattan.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [274] "umap.metric_manhattan.n_neighbors_90.annotation.prepare.enh.chipseq_full.only.tsv"
# [275] "umap.metric_manhattan.n_neighbors_90.annotation.prepare.full.chipseq_full.fcc.tss.tsv"
# [276] "umap.metric_manhattan.n_neighbors_90.annotation.prepare.full.chipseq_full.only.tsv"
# [277] "umap.n_neighbors_15.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [278] "umap.n_neighbors_15.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [279] "umap.n_neighbors_15.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [280] "umap.n_neighbors_15.annotation.test_chrX.chipseq_full.only.tsv"
# [281] "umap.n_neighbors_50.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [282] "umap.n_neighbors_50.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [283] "umap.n_neighbors_60.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [284] "umap.n_neighbors_60.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [285] "umap.n_neighbors_70.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [286] "umap.n_neighbors_70.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"
# [287] "umap.n_neighbors_70.annotation.test_chrX.chipseq_full.fcc.tss.tsv"
# [288] "umap.n_neighbors_70.annotation.test_chrX.chipseq_full.only.tsv"
# [289] "umap.n_neighbors_90.annotation.prepare.cre.chipseq_full.fcc.tss.tsv"
# [290] "umap.n_neighbors_90.annotation.prepare.enh.chipseq_full.fcc.tss.tsv"

# %% [markdown]
# ## Import data

# %%
vec_txt_metric    = c("manhattan", "cosine", "hamming", "jaccard")
vec_num_neighbors = c("15", "70")

dat = expand.grid(X = vec_txt_metric, Y = vec_num_neighbors)
dat = dat %>% dplyr::mutate(
    Z = paste(
        "umap",
        paste("metric",      X, sep = "_"),
        paste("n_neighbors", Y, sep = "_"),
        sep = "."
    )
)
vec_txt_prefix = dat$Z
print(vec_txt_prefix)
# Out:
# [1] "umap.metric_manhattan.n_neighbors_15"
# [2] "umap.metric_cosine.n_neighbors_15"
# [3] "umap.metric_hamming.n_neighbors_15"
# [4] "umap.metric_jaccard.n_neighbors_15"
# [5] "umap.metric_manhattan.n_neighbors_70"
# [6] "umap.metric_cosine.n_neighbors_70"
# [7] "umap.metric_hamming.n_neighbors_70"
# [8] "umap.metric_jaccard.n_neighbors_70"

# %%
### set directory
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)

### import data
lst = lapply(vec_txt_prefix, function(txt_prefix){
    
    txt_fname = paste(
        txt_prefix, 
        "annotation.test_chrX.chipseq_full.fcc.tss.tsv",
        sep = "."
    )
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})
names(lst) = vec_txt_prefix

### assign
lst_dat_umap = lst

# %%
### init
lst = lst_dat_umap
num = 1000

###
theme_txt = theme(title = element_text(size=20))

###
lst = lapply(names(lst), function(txt){

    ### get data
    dat = lst[[txt]]
    
    ### sample rows
    set.seed(123)
    idx = sort(sample(1:nrow(dat), size = num))
    dat = dat[idx,]

    ### plot
    gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
        geom_point() + 
        labs(title = txt) +
        theme_cowplot() + 
        background_grid() +
        theme_txt
    
    return(gpt)
})

lst_gpt = lst

# %%
options(repr.plot.height=14, repr.plot.width=30)
plot_grid(plotlist = lst_gpt, nrow=2)
# Out:
# plot without title

# %%
vec_txt_metric    = c("euclidean")
vec_num_neighbors = c("15", "70")

dat = expand.grid(X = vec_txt_metric, Y = vec_num_neighbors)
dat = dat %>% dplyr::mutate(
    Z = paste(
        "umap",
        paste("metric",      X, sep = "_"),
        paste("n_neighbors", Y, sep = "_"),
        sep = "."
    )
)
vec_txt_prefix = dat$Z
print(vec_txt_prefix)
# Out:
# [1] "umap.metric_euclidean.n_neighbors_15"
# [2] "umap.metric_euclidean.n_neighbors_70"

# %%
### set directory
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)

### import data
lst = lapply(vec_txt_prefix, function(txt_prefix){
    
    txt_fname = paste(
        txt_prefix, 
        "mca_exp90.test_chrX.chipseq_full.fcc.tss.tsv",
        sep = "."
    )
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})
names(lst) = vec_txt_prefix

### assign
lst_dat_umap = lst
print(length(lst))
# Out:
# [1] 2

# %%
### init
lst = lst_dat_umap
num = 1000

###
theme_txt = theme(title = element_text(size=20))

###
lst = lapply(names(lst), function(txt){

    ### get data
    dat = lst[[txt]]
    
    ### sample rows
    set.seed(123)
    idx = sort(sample(1:nrow(dat), size = num))
    dat = dat[idx,]

    ### plot
    gpt = ggplot(dat, aes(x=UMAP1, y=UMAP2)) + 
        geom_point() + 
        labs(title = txt) +
        theme_cowplot() + 
        background_grid() +
        theme_txt
    
    return(gpt)
})

lst_gpt = lst

# %%
options(repr.plot.height=14, repr.plot.width=7)
plot_grid(plotlist = lst_gpt, nrow=2)
# Out:
# plot without title
