# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import umap

# %%
os.listdir("/mount/repo/Proj_ENCODE_FCC/results")
# Out:
# ['region_coverage_fcc',
#  '.ipynb_checkpoints',
#  'region',
#  'assay_fcc',
#  'region_converage_hic',
#  'region_annotation',
#  'assay_hic']

# %%
FD_RES = "/mount/repo/Proj_ENCODE_FCC/results"
txt_fdiry = os.path.join(
    FD_RES,
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
np.sort(os.listdir(txt_fdiry))
# Out:
# array(['.ipynb_checkpoints', 'matrix.annotation.chipseq.tsv',
#        'matrix.annotation.subset.tsv',
#        'matrix.annotation.tss.chipseq_histone.chipseq_encode4.tsv',
#        'region.annotation.encode_chromatin_states.tsv',
#        'region.annotation.fcc_astarr_csaw.tsv',
#        'region.annotation.fcc_crispri_hcrff.tsv',
#        'region.annotation.genome_tss.tsv',
#        'region.annotation.hic_insitu_K562_ENCSR545YBD.tsv',
#        'region.annotation.hic_intact_K562_ENCSR479XDG.tsv',
#        'region.annotation.hic_intact_K562_deep.tsv',
#        'region.summary.encode_chipseq_encode4.tsv',
#        'region.summary.encode_chipseq_flagship.tsv',
#        'region.summary.encode_chipseq_histone.tsv',
#        'region.summary.encode_chipseq_subset.tsv',
#        'region.summary.encode_chromatin_states.tsv',
#        'region.summary.fcc_astarr_csaw.tsv',
#        'region.summary.fcc_crispri_hcrff.tsv',
#        'region.summary.genome_tss.tsv',
# ...

# %%
txt_fdiry = os.path.join(
    FD_RES,
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "matrix.annotation.tss.chipseq_histone.chipseq_encode4.tsv"
txt_fpath = os.path.join(txt_fdiry, txt_fname)

### read data
mat = pd.read_csv(txt_fpath, sep="\t")
mat = mat.set_index('Region_A')

### assign and show
mat_annot_chipseq = mat
print(mat.shape)
mat.head()
# Out:
# (110648, 247)
#                           chipseq_AFF4  chipseq_ARID3B  chipseq_ARID4B  \
# Region_A
# chr1:100028014-100029653             0               0               0
# chr1:100036895-100039189             1               0               1
# chr1:100046252-100046533             0               0               0
# chr1:100048290-100048918             0               0               0
# chr1:100050225-100050529             0               0               0
#
#                           chipseq_ATF1  chipseq_ATF2  chipseq_ATF3  \
# Region_A
# chr1:100028014-100029653             0             0             0
# chr1:100036895-100039189             1             0             1
# chr1:100046252-100046533             0             0             0
# chr1:100048290-100048918             0             0             0
# chr1:100050225-100050529             0             0             0
#
#                           chipseq_ATF4  chipseq_ATF6  chipseq_BCL6  \
# Region_A
# ...

# %%
X = mat_annot_chipseq.to_numpy()
X.shape
# Out:
# (110648, 247)

# %%
fit = umap.UMAP(metric='manhattan', n_neighbors=50)
# %time U = fit.fit_transform(X)
# Out:
# CPU times: user 44min 52s, sys: 2min 56s, total: 47min 49s
# Wall time: 5min 5s

# %%
fit = umap.UMAP(metric='manhattan', n_neighbors=70, random_state=123)
# %time U = fit.fit_transform(X)
# Out:
# /opt/conda/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# CPU times: user 15min 59s, sys: 3min 4s, total: 19min 3s
# Wall time: 13min 52s

# %%
plt.scatter(U[:,0], U[:,1], s=1)
plt.title('UMAP embedding of ATAC peaks');

# %%
plt.scatter(U[:,0], U[:,1], s=1)
plt.title('UMAP embedding of ATAC peaks');

# %%
txt1 = ["CTCF"]
txt2 = ["chipseq_" + txt for txt in txt1]
txt3 = " x ".join(txt1)
mat  = mat_annot_chipseq
mat  = mat.loc[:, txt2]
vec  = mat.sum(axis = 1)
idx  = (vec == len(txt1))

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt3})');

# %%
txt1 = ["CTCF", "RAD21"] # , "SMC3"
txt2 = ["chipseq_" + txt for txt in txt1]
txt3 = " x ".join(txt1)
mat  = mat_annot_chipseq
mat  = mat.loc[:, txt2]
vec  = mat.sum(axis = 1)
idx  = (vec == len(txt1))

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt3})');

# %%
txt1 = ["H3K27ac", "EP300"]
txt2 = ["chipseq_" + txt for txt in txt1]
txt3 = " x ".join(txt1)
mat  = mat_annot_chipseq
mat  = mat.loc[:, txt2]
vec  = mat.sum(axis = 1)
idx  = (vec == len(txt1))

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt3})');

# %%
txt1 = ["H3K4me3", "POLR2A"]
txt2 = ["chipseq_" + txt for txt in txt1]
txt3 = " x ".join(txt1)
mat  = mat_annot_chipseq
mat  = mat.loc[:, txt2]
vec  = mat.sum(axis = 1)
idx  = (vec == len(txt1))

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt3})');

# %%
txt1 = "TSS"
txt2 = "TSS_Pol2_RNAseq"
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
U
# Out:
# array([[-4.1214931e+01, -1.4709896e+00],
#        [-4.1126072e+01,  2.2741774e-01],
#        [-1.1780747e+01, -1.9079342e+00],
#        ...,
#        [-1.9615429e+01,  6.2014079e-03],
#        [-4.5196896e+01, -6.1432714e+00],
#        [-1.2553554e+01, -3.0674295e+00]], dtype=float32)

# %%
dat = pd.DataFrame(U, index=mat.index, columns=["UMAP1", "UMAP2"])
dat = dat.reset_index()
dat.head()
# Out:
#                              Region_A      UMAP1     UMAP2
# 0  chr1_KI270713v1_random:21061-22355 -41.214931 -1.470990
# 1            chr1:100028014-100029653 -41.126072  0.227418
# 2            chr1:100036895-100039189 -11.780747 -1.907934
# 3            chr1:100046252-100046533 -41.778851 -0.195887
# 4            chr1:100048290-100048918 -17.473164  2.650036

# %%
txt_fdiry = os.path.join(
    FD_RES,
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "umap.annotation.chipseq.tsv"
txt_fpath = os.path.join(txt_fdiry, txt_fname)

dat = pd.DataFrame(U, index=mat.index, columns=["UMAP1", "UMAP2"])
dat = dat.reset_index()
dat.to_csv(txt_fpath, sep="\t", index=False)

# %%
txt1 = ["CTCF", "SMC3"]
txt2 = ["chipseq_" + txt for txt in txt1]
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
vec
# Out:
#                                     chipseq_CTCF  chipseq_SMC3
# Region_A
# chr1_KI270713v1_random:21061-22355             0             0
# chr1:100028014-100029653                       0             0
# chr1:100036895-100039189                       0             1
# chr1:100046252-100046533                       0             0
# chr1:100048290-100048918                       0             0
# ...                                          ...           ...
# chrX:98581487-98581761                         0             0
# chrX:9864107-9864508                           0             0
# chrX:9882663-9883076                           1             0
# chrX:9894563-9895394                           0             0
# chrX:989825-990522                             0             0
#
# [124046 rows x 2 columns]

# %%
txt1 = ["CTCF", "SMC3"]
txt2 = ["chipseq_" + txt for txt in txt1]
mat  = mat_annot_chipseq
mat  = mat.loc[:, txt2]
vec  = mat.sum(axis = 1)
idx  = (vec == len(txt1))
# Out:
# 20524

# %%
txt1 = ["CTCF", "SMC3"]
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "SMC3"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "RAD21"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "POLR2A"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "TSS"
txt2 = "TSS_Pol2_RNAseq"
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
plt.scatter(U[:,0], U[:,1], s=1)
plt.title('UMAP embedding of ATAC peaks');

# %%
target = mat_annot_chipseq.columns.str.split(pat="_").str[1]
target
# Out:
# Index(['ADNP', 'AFF1', 'AGO1', 'ARHGAP35', 'ARID1B', 'ARID2', 'ARID3A',
#        'ARID3B', 'ARID4B', 'ARNT',
#        ...
#        'ZNF780A', 'ZNF785', 'ZNF79', 'ZNF83', 'ZNF830', 'ZNF84', 'ZSCAN29',
#        'ZSCAN32', 'ZZZ3', 'Pol2'],
#       dtype='object', length=526)

# %%
txt1 = "CTCF"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "SMC3"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "RAD21"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "POLR2A"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "H3K27ac"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "H3K4me3"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "MYC"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
txt1 = "TSS"
txt2 = "TSS_Pol2_RNAseq"
mat  = mat_annot_chipseq
vec  = mat.loc[:, txt2]
idx  = (vec > 0)

plt.scatter(U[:,  0], U[:,  1], s=1,   c="grey")
plt.scatter(U[idx,0], U[idx,1], s=0.5, c="red")
plt.title(f'UMAP embedding of ATAC peaks (Red: {txt1})');

# %%
idx = (dat > 0)
np.sum(idx)
# Out:
# 39800

# %%
txt1 = "CTCF"
txt2 = "chipseq_" + txt1
mat  = mat_annot_chipseq
idx = np.where(target == txt1)[0]
dat = mat_annot_chipseq.iloc[:, idx]
# Out:
# array([63])

# %%
dat = mat_annot_chipseq.iloc[:, idx]
#idx = dat.CTCF_ENCFF221SKA > 1
#idx.head()
dat
# Out:
#                                     chipseq_CTCF
# Region_A
# chr1_KI270713v1_random:21061-22355             0
# chr1:100028014-100029653                       0
# chr1:100036895-100039189                       0
# chr1:100046252-100046533                       0
# chr1:100048290-100048918                       0
# ...                                          ...
# chrX:98581487-98581761                         0
# chrX:9864107-9864508                           0
# chrX:9882663-9883076                           1
# chrX:9894563-9895394                           0
# chrX:989825-990522                             0
#
# [124046 rows x 1 columns]

# %%
txt_fdiry = os.path.join(
    "/mount/work/proj_encode_fcc",
    "results_v4",
    "region",
    "KS91_K562_ASTARRseq_peak_macs_input",
    "summary"
)

os.listdir(txt_fdiry)
# Out:
# ['peak.summary.enhancer_zscore_junke.ASTARR_AB.tsv',
#  'peak.summary.encode_e2g_benchmark.active.tsv',
#  'peak.summary.chipseq_histone.tsv',
#  'peak.screened.fcc.active.tsv',
#  'peak.summary.enhancer_zscore_junke.LMPRA.tsv',
#  'peak.summary.encode_e2g_prediction.active.tsv',
#  'peak.summary.enhancer_zscore_junke.LMPRA_AB.tsv',
#  'peak.summary.enhancer_zscore_junke.ASTARR_A.tsv',
#  'peak.summary.hic_intact.deep.overlap.tsv',
#  '.ipynb_checkpoints',
#  'peak.screened.fcc.inactive.tsv',
#  'peak.screened.atac.quantile.tsv',
#  'peak.summary.tss_pol2.tsv',
#  'peak.summary.enhancer_zscore_junke.STARRMPRA.tsv',
#  'peak.summary.enhancer_zscore_junke.TMPRA_R.tsv',
#  'peak.summary.encode_e2g_prediction.total.tsv',
#  'peak.summary.enhancer_zscore_junke.ASTARR.tsv',
#  'peak.summary.enhancer_zscore_junke.TMPRA.tsv',
#  'peak.summary.encode_e2g_benchmark.total.tsv',
#  'peak.summary.crispri_hcrff.casa.tsv',
#  'peak.summary.enhancer_zscore_junke.TMPRA_A.tsv',
# ...

# %%
txt_fdiry = os.path.join(
    "/mount/work/proj_encode_fcc",
    "results_v4",
    "region",
    "KS91_K562_ASTARRseq_peak_macs_input",
    "summary"
)
txt_fname = "peak.summary.chipseq_tf.tsv"
txt_fpath = os.path.join(txt_fdiry, txt_fname)

### read data
dat = pd.read_csv(txt_fpath, sep="\t")

### spread into a count matrix
dat = dat.pivot(index='Peak', columns='Label', values='Count').fillna(0)
dat_chipseq_tf_count = dat

### convert into binary matrix
dat = (dat != 0)
dat = dat.astype(int)
dat_chipseq_tf_binary = dat

# %%
dat_chipseq_tf_binary.head()
# Out:
# Label                      ADNP_ENCFF739AJO  AFF1_ENCFF195YGC  \
# Peak
# chr10:100009096-100010466                 0                 0
# chr10:100045961-100046653                 0                 0
# chr10:100065094-100065486                 0                 0
# chr10:100111648-100111979                 0                 0
# chr10:100129051-100131059                 0                 0
#
# Label                      AFF1_ENCFF674XTY  AGO1_ENCFF794IRP  \
# Peak
# chr10:100009096-100010466                 0                 0
# chr10:100045961-100046653                 0                 0
# chr10:100065094-100065486                 0                 0
# chr10:100111648-100111979                 0                 0
# chr10:100129051-100131059                 0                 0
#
# Label                      ARHGAP35_ENCFF952WKN  ARID1B_ENCFF879NTL  \
# Peak
# chr10:100009096-100010466                     0                   0
# ...

# %%
X = dat_chipseq_tf_count.to_numpy()
X.shape
# Out:
# (151753, 733)

# %%
#import numpy as np
#from sklearn.decomposition import PCA
#X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
pca = PCA(n_components=2)
pca.fit(X)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [0.33793383 0.06095241]
# [1763.84217901  749.0992209 ]

# %%
pca = PCA(n_components=0.9, svd_solver='full')
pca.fit(X)
len(pca.explained_variance_ratio_)
# Out:
# 306

# %%
Y = pca.transform(X)
print(Y.shape)

dat = pd.DataFrame(Y)
print(dat.shape)
dat.head()
# Out:
# (151753, 306)
# (151753, 306)
#         0         1         2         3         4         5         6    \
# 0  2.854796  2.284378 -3.838387 -1.899617 -0.428951  1.204939  0.994670
# 1 -1.857007  0.770359 -2.746917  0.594513  0.558143  0.125688 -0.126846
# 2 -2.156166  0.448383  0.026814  0.269417 -0.033197 -0.196475 -0.069671
# 3 -2.207407  0.349159  0.253449  0.337562 -0.043134 -0.269500 -0.122993
# 4 -1.219430 -0.404057  0.585378 -1.138172 -0.378292 -0.486120  0.260733
#
#         7         8         9    ...       296       297       298       299  \
# 0  0.387142 -1.305607 -0.791627  ...  0.139331  0.016292  0.157757 -0.380105
# 1 -0.239053 -0.046100 -0.222204  ... -0.002962 -0.015838  0.005584 -0.002587
# 2 -0.117608 -0.135135  0.075610  ...  0.105578 -0.097875 -0.029706 -0.030018
# 3 -0.037629 -0.051505  0.270972  ... -0.006279 -0.140284 -0.024153 -0.076103
# 4 -0.644035  1.829770 -0.542168  ...  0.035332  0.049341 -0.127718 -0.046978
#
# ...

# %%
fit = umap.UMAP(metric='manhattan')
# %time U_count = fit.fit_transform(X)
# Out:
# CPU times: user 19min 31s, sys: 1min 46s, total: 21min 17s
# Wall time: 2min 21s

# %%
#fit = umap.UMAP(metric='manhattan', random_state=123)
#%time U_count = fit.fit_transform(X)

fit = umap.UMAP(n_components = 2)
# %time U_pca = fit.fit_transform(Y)
# Out:
# /opt/conda/lib/python3.11/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# CPU times: user 34min 55s, sys: 14min 36s, total: 49min 32s
# Wall time: 5min 5s

# %%
print(U_count.shape)
print(U_pca.shape)
# Out:
# (151753, 2)
# (151753, 2)

# %%
U = U_count

# %%
plt.scatter(U[:,0], U[:,1], s=1)
plt.title('UMAP embedding of ATAC peaks');

# %%
target = dat_chipseq_tf_count.columns.str.split(pat="_").str[0]
target
# Out:
# Index(['ADNP', 'AFF1', 'AFF1', 'AGO1', 'ARHGAP35', 'ARID1B', 'ARID2', 'ARID3A',
#        'ARID3B', 'ARID4B',
#        ...
#        'ZNF7', 'ZNF830', 'ZNF830', 'ZNF830', 'ZNF83', 'ZNF84', 'ZSCAN29',
#        'ZSCAN29', 'ZSCAN32', 'ZZZ3'],
#       dtype='object', name='Label', length=733)

# %%
idx = np.where(target == "CTCF")[0]
idx
# Out:
# array([88, 89, 90, 91, 92])

# %%
dat = dat_chipseq_tf_count
dat.head()
# Out:
# Label                      ADNP_ENCFF739AJO  AFF1_ENCFF195YGC  \
# Peak
# chr10:100009096-100010466               0.0               0.0
# chr10:100045961-100046653               0.0               0.0
# chr10:100065094-100065486               0.0               0.0
# chr10:100111648-100111979               0.0               0.0
# chr10:100129051-100131059               0.0               0.0
#
# Label                      AFF1_ENCFF674XTY  AGO1_ENCFF794IRP  \
# Peak
# chr10:100009096-100010466               0.0               0.0
# chr10:100045961-100046653               0.0               0.0
# chr10:100065094-100065486               0.0               0.0
# chr10:100111648-100111979               0.0               0.0
# chr10:100129051-100131059               0.0               0.0
#
# Label                      ARHGAP35_ENCFF952WKN  ARID1B_ENCFF879NTL  \
# Peak
# chr10:100009096-100010466                   0.0                 0.0
# ...

# %%
dat = dat_chipseq_tf_count.iloc[:, idx]
dat.head()
# Out:
# Label                      CTCF_ENCFF221SKA  CTCF_ENCFF582SNT  \
# Peak
# chr10:100009096-100010466               2.0               2.0
# chr10:100045961-100046653               1.0               1.0
# chr10:100065094-100065486               0.0               0.0
# chr10:100111648-100111979               1.0               0.0
# chr10:100129051-100131059               0.0               0.0
#
# Label                      CTCF_ENCFF660GHM  CTCF_ENCFF736NYC  \
# Peak
# chr10:100009096-100010466               2.0               2.0
# chr10:100045961-100046653               1.0               1.0
# chr10:100065094-100065486               0.0               0.0
# chr10:100111648-100111979               0.0               0.0
# chr10:100129051-100131059               0.0               0.0
#
# Label                      CTCF_ENCFF769AUF
# Peak
# chr10:100009096-100010466               1.0
# chr10:100045961-100046653               1.0
# chr10:100065094-100065486               0.0
# ...

# %%
dat = dat_chipseq_tf_count.iloc[:, idx]
idx = dat.CTCF_ENCFF221SKA > 1
idx.head()
# Out:
# Peak
# chr10:100009096-100010466     True
# chr10:100045961-100046653    False
# chr10:100065094-100065486    False
# chr10:100111648-100111979    False
# chr10:100129051-100131059    False
# Name: CTCF_ENCFF221SKA, dtype: bool

# %%
plt.scatter(U[:,  0], U[:,  1], s=1, c="grey")
plt.scatter(U[idx,0], U[idx,1], s=1, c="red")
plt.title('UMAP embedding of ATAC peaks (Red: CTCF)');

# %%
idx = np.where(target == "CTCF")[0]
dat = dat_chipseq_tf_count

dat = dat.iloc[:, idx]
dat.head()
# Out:
# Label                      CTCF_ENCFF221SKA  CTCF_ENCFF582SNT  \
# Peak
# chr10:100009096-100010466               2.0               2.0
# chr10:100045961-100046653               1.0               1.0
# chr10:100065094-100065486               0.0               0.0
# chr10:100111648-100111979               1.0               0.0
# chr10:100129051-100131059               0.0               0.0
#
# Label                      CTCF_ENCFF660GHM  CTCF_ENCFF736NYC  \
# Peak
# chr10:100009096-100010466               2.0               2.0
# chr10:100045961-100046653               1.0               1.0
# chr10:100065094-100065486               0.0               0.0
# chr10:100111648-100111979               0.0               0.0
# chr10:100129051-100131059               0.0               0.0
#
# Label                      CTCF_ENCFF769AUF
# Peak
# chr10:100009096-100010466               1.0
# chr10:100045961-100046653               1.0
# chr10:100065094-100065486               0.0
# ...

# %%
idx = np.where(target == "CTCF")[0]
dat = dat_chipseq_tf_count

dat = dat.iloc[:, idx]
vec = dat.iloc[:, 0]
idx = vec > 1 

plt.scatter(U[:,  0], U[:,  1], s=1, c="grey")
plt.scatter(U[idx,0], U[idx,1], s=1, c="red")
plt.title('UMAP embedding of ATAC peaks (Red: CTCF)');

# %%
idx = target.str.contains("POL")
target[idx]
# Out:
# Index(['POLR2A', 'POLR2A', 'POLR2A', 'POLR2A', 'POLR2A', 'POLR2A',
#        'POLR2AphosphoS2', 'POLR2AphosphoS2', 'POLR2AphosphoS5', 'POLR2B',
#        'POLR2G', 'POLR2H', 'POLR3A', 'POLR3G'],
#       dtype='object', name='Label')

# %%
idx = np.where(target == "POLR2A")[0]
dat = dat_chipseq_tf_count

dat = dat.iloc[:, idx]
vec = dat.iloc[:, 0]
idx = vec > 1

plt.scatter(U[:,  0], U[:,  1], s=1, c="grey")
plt.scatter(U[idx,0], U[idx,1], s=1, c="red")
plt.title('UMAP embedding of ATAC peaks (Red: POL2RA)');

# %%
idx = target.str.contains("EP300")
target[idx]
# Out:
# Index(['EP300', 'EP300'], dtype='object', name='Label')

# %%
idx = np.where(target == "EP300")[0]
dat = dat_chipseq_tf_count

dat = dat.iloc[:, idx]
vec = dat.iloc[:, 0]
idx = vec > 1

plt.scatter(U[:,  0], U[:,  1], s=1, c="grey")
plt.scatter(U[idx,0], U[idx,1], s=1, c="red")
plt.title('UMAP embedding of ATAC peaks (Red: EP300)');

# %%
idx = target.str.contains("H3")
target[idx]
# Out:
# Index([], dtype='object', name='Label')
