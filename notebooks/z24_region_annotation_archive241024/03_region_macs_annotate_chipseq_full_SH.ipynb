# %% [raw]
# ---
# title: Region annotation 02 (ASTARR MACS peaks)
# subtitle: Annotate peaks (ChIP-seq; full)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_flagship
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chromatin_states
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs
# fcc_crispri_hcrff
# fcc_mpra_agarwal2023
# fcc_screened
# fcc_starrmpra_junke
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/metadata.label.chipseq_full.tsv

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs.tsv
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B} | head -n 10
cat ${FP_REGION_LABEL_B} | tail -n 10
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.chipseq_full.tsv
# Folder	FName	Label
# encode_chipseq_flagship	ENCFF003LPE.bed.gz	encode_chipseq_RUNX1_ENCFF003LPE
# encode_chipseq_flagship	ENCFF004HXL.bed.gz	encode_chipseq_FOSL1_ENCFF004HXL
# encode_chipseq_flagship	ENCFF004YCK.bed.gz	encode_chipseq_ZNF740_ENCFF004YCK
# encode_chipseq_flagship	ENCFF005MBI.bed.gz	encode_chipseq_ZNF584_ENCFF005MBI
# encode_chipseq_flagship	ENCFF009RFC.bed.gz	encode_chipseq_GABPB1_ENCFF009RFC
# encode_chipseq_flagship	ENCFF014HYS.bed.gz	encode_chipseq_ZNF84_ENCFF014HYS
# encode_chipseq_flagship	ENCFF015FXW.bed.gz	encode_chipseq_ZNF407_ENCFF015FXW
# encode_chipseq_flagship	ENCFF018HWM.bed.gz	encode_chipseq_ZNF7_ENCFF018HWM
# encode_chipseq_flagship	ENCFF018TNP.bed.gz	encode_chipseq_PRMT5_ENCFF018TNP
# encode_chipseq_histone	ENCFF544LXB.bed.gz	encode_chipseq_H3K27ac_ENCFF544LXB
# encode_chipseq_histone	ENCFF561OUZ.bed.gz	encode_chipseq_H3K36me3_ENCFF561OUZ
# encode_chipseq_histone	ENCFF689QIJ.bed.gz	encode_chipseq_H3K4me3_ENCFF689QIJ
# encode_chipseq_histone	ENCFF706WUF.bed.gz	encode_chipseq_H3K4me3_ENCFF706WUF
# encode_chipseq_histone	ENCFF749KLQ.bed.gz	encode_chipseq_H3K4me2_ENCFF749KLQ
# encode_chipseq_histone	ENCFF801AHF.bed.gz	encode_chipseq_H3K27me3_ENCFF801AHF
# encode_chipseq_histone	ENCFF885FQN.bed.gz	encode_chipseq_H3K4me3_ENCFF885FQN
# encode_chipseq_histone	ENCFF891CHI.bed.gz	encode_chipseq_H3K9ac_ENCFF891CHI
# encode_chipseq_histone	ENCFF909RKY.bed.gz	encode_chipseq_H4K20me1_ENCFF909RKY
# encode_chipseq_histone	ENCFF963GZJ.bed.gz	encode_chipseq_H3K9me3_ENCFF963GZJ

# %% [markdown]
# ## Preview

# %%
cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}' | head -n 3
# Out:
# encode_chipseq_flagship	ENCFF003LPE.bed.gz	encode_chipseq_RUNX1_ENCFF003LPE
# encode_chipseq_flagship	ENCFF004HXL.bed.gz	encode_chipseq_FOSL1_ENCFF004HXL
# encode_chipseq_flagship	ENCFF004YCK.bed.gz	encode_chipseq_ZNF740_ENCFF004YCK

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
    done < <(cat ${FP_REGION_LABEL_B} | head -n 3 | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_RUNX1_ENCFF003LPE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_RUNX1_ENCFF003LPE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_RUNX1_ENCFF003LPE.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_FOSL1_ENCFF004HXL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_FOSL1_ENCFF004HXL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_FOSL1_ENCFF004HXL.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_RUNX1_ENCFF003LPE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_RUNX1_ENCFF003LPE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_RUNX1_ENCFF003LPE.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_FOSL1_ENCFF004HXL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_FOSL1_ENCFF004HXL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_FOSL1_ENCFF004HXL.txt

# %% [markdown]
# ## Execute

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir  -p ${FD_OUT}
        sbatch -p ${NODE} \
            --exclude=dl-01 \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FD_PRJ} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_RUNX1_ENCFF003LPE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_RUNX1_ENCFF003LPE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_RUNX1_ENCFF003LPE.txt
#
# Submitted batch job 33197440
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_FOSL1_ENCFF004HXL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_FOSL1_ENCFF004HXL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_FOSL1_ENCFF004HXL.txt
#
# Submitted batch job 33197441
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF740_ENCFF004YCK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF740_ENCFF004YCK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF740_ENCFF004YCK.txt
#
# Submitted batch job 33197442
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF584_ENCFF005MBI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF584_ENCFF005MBI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF584_ENCFF005MBI.txt
#
# Submitted batch job 33197443
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_GABPB1_ENCFF009RFC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_GABPB1_ENCFF009RFC.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_GABPB1_ENCFF009RFC.txt
#
# Submitted batch job 33197444
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF84_ENCFF014HYS
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF84_ENCFF014HYS.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF84_ENCFF014HYS.txt
#
# Submitted batch job 33197445
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF407_ENCFF015FXW
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF407_ENCFF015FXW.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF407_ENCFF015FXW.txt
#
# Submitted batch job 33197446
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF7_ENCFF018HWM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF7_ENCFF018HWM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF7_ENCFF018HWM.txt
#
# Submitted batch job 33197447
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_PRMT5_ENCFF018TNP
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_PRMT5_ENCFF018TNP.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_PRMT5_ENCFF018TNP.txt
#
# Submitted batch job 33197449
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF253_ENCFF019NGO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF253_ENCFF019NGO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF253_ENCFF019NGO.txt
#
# Submitted batch job 33197450
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_SNIP1_ENCFF020XNM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_SNIP1_ENCFF020XNM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_SNIP1_ENCFF020XNM.txt
#
# Submitted batch job 33197451
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZNF12_ENCFF021JCJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZNF12_ENCFF021JCJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF12_ENCFF021JCJ.txt
#
# Submitted batch job 33197452
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_CEBPB_ENCFF022KBK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_CEBPB_ENCFF022KBK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_CEBPB_ENCFF022KBK.txt
#
# Submitted batch job 33197453
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_NFE2_ENCFF023IFO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# Submitted batch job 33197454
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_HSF4_ENCFF023JGT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_HSF4_ENCFF023JGT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_HSF4_ENCFF023JGT.txt
#
# Submitted batch job 33197455
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_BACH1_ENCFF026BDA
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_BACH1_ENCFF026BDA.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq
bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_THRA_ENCFF992HUS.txt
#
# Submitted batch job 33199084
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_NCOA6_ENCFF996OEL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_NCOA6_ENCFF996OEL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_NCOA6_ENCFF996OEL.txt
#
# Submitted batch job 33199085
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_CEBPG_ENCFF998LIR
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_flagship
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_CEBPG_ENCFF998LIR.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_CEBPG_ENCFF998LIR.txt
#
# Submitted batch job 33199086
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF122CSI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF122CSI.txt
#
# Submitted batch job 33199087
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 33199088
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF148UQI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF148UQI.txt
#
# Submitted batch job 33199089
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF193ERO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF193ERO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF193ERO.txt
#
# Submitted batch job 33199090
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K79me2_ENCFF209OQD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF209OQD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF209OQD.txt
#
# Submitted batch job 33199091
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H2AFZ_ENCFF213OTI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF213OTI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF213OTI.txt
#
# Submitted batch job 33199093
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 33199094
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me1_ENCFF462AVD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF462AVD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF462AVD.txt
#
# Submitted batch job 33199095
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF540NGG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF540NGG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF540NGG.txt
#
# Submitted batch job 33199096
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 33199097
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF561OUZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF561OUZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF561OUZ.txt
#
# Submitted batch job 33199098
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF689QIJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF689QIJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF689QIJ.txt
#
# Submitted batch job 33199099
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF706WUF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF706WUF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF706WUF.txt
#
# Submitted batch job 33199100
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 33199101
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF801AHF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF801AHF.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF801AHF.txt
#
# Submitted batch job 33199102
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 33199103
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF891CHI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF891CHI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF891CHI.txt
#
# Submitted batch job 33199104
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H4K20me1_ENCFF909RKY
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF909RKY.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF909RKY.txt
#
# Submitted batch job 33199106
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me3_ENCFF963GZJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF963GZJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF963GZJ.txt
#
# Submitted batch job 33199107

# %% [markdown]
# ## Review

# %%
ls /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
# Out:
# fcc_astarr_macs_input_overlap  fcc_astarr_macs_input_union

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region
ls ${FDIRY}/encode_chipseq_histone/K562* | wc -l
# Out:
# 19

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region
ls ${FDIRY}/encode_chipseq_encode4/*bed.gz | wc -l
# Out:
# 237

# %% [markdown]
# ```
# FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region
# ls ${FDIRY}/encode_chipseq_flagship/K562* | wc -l
# > 734
# ```

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF885FQN.txt
# Out:
# Hostname:           x2-03-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         06-18-24+13:13:35
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/K562.hg38.ENCSR668LDD.ENCFF885FQN.ChIPseq.H3K4me3.bed.gz
#
# show first few lines of input
# chr1	137611	138186	Peak_11639	868	.	17.17918	86.81271	84.40081	199
# chr1	138333	139668	Peak_13836	392	.	10.05165	39.23344	36.98688	859
# chr1	777481	780024	Peak_8178	1000	.	35.08939	233.59062	230.75691	1621
# chr1	825575	826429	Peak_16217	190	.	4.61296	19.01589	16.87489	277
data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
FDIRY=${FDIRY}/fcc_astarr_macs_input_overlap/encode_chipseq_histone
ls ${FDIRY} | wc -l
# Out:
# 19

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
FDIRY=${FDIRY}/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
ls ${FDIRY} | wc -l
# Out:
# 734

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF885FQN.txt
# Out:
# Hostname:           x2-05-2
# Slurm Array Index:
# Time Stamp:         05-14-24+17:31:21
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/K562.hg38.ENCSR668LDD.ENCFF885FQN.ChIPseq.H3K4me3.bed.gz
#
# show first few lines of input
# chr1	137611	138186	Peak_11639	868	.	17.17918	86.81271	84.40081	199
# chr1	138333	139668	Peak_13836	392	.	10.05165	39.23344	36.98688	859
# chr1	777481	780024	Peak_8178	1000	.	35.08939	233.59062	230.75691	1621
# chr1	825575	826429	Peak_16217	190	.	4.61296	19.01589	16.87489	277
# chr1	826512	827941	Peak_8944	1000	.	31.25149	199.79292	197.06018	919
# chr1	869712	870217	Peak_18688	107	.	4.56893	10.78949	8.71444	293
# chr1	903896	905665	Peak_11513	901	.	16.12678	90.18884	87.76704	640
# chr1	923534	925374	Peak_12257	698	.	13.72073	69.85411	67.49615	545
# chr1	940322	940993	Peak_14764	287	.	7.35176	28.77467	26.57727	202
# chr1	941346	942471	Peak_15181	253	.	6.71822	25.39972	23.22058	548
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone/fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF885FQN.bed.gz
#
# show first few lines of output:
# chr1	137737	139544	chr1	137611	138186	Peak_11639	868	.	17.17918	86.81271	84.40081	199	449
# chr1	137737	139544	chr1	138333	139668	Peak_13836	392	.	10.05165	39.23344	36.98688	859	1211
# chr1	777949	779437	chr1	777481	780024	Peak_8178	1000	.	35.08939	233.59062	230.75691	1621	1488
# chr1	826754	828040	chr1	826512	827941	Peak_8944	1000	.	31.25149	199.79292	197.06018	919	1187
# chr1	869623	870250	chr1	869712	870217	Peak_18688	107	.	4.56893	10.78949	8.71444	293	505
# chr1	903633	905556	chr1	903896	905665	Peak_11513	901	.	16.12678	90.18884	87.76704	640	1660
# chr1	923417	925194	chr1	923534	925374	Peak_12257	698	.	13.72073	69.85411	67.49615	545	1660
# chr1	940325	943460	chr1	940322	940993	Peak_14764	287	.	7.35176	28.77467	26.57727	202	668
# chr1	940325	943460	chr1	941346	942471	Peak_15181	253	.	6.71822	25.39972	23.22058	548	1125
# chr1	958685	959974	chr1	957389	959874	Peak_382	1000	.	43.73086	597.80499	592.98694	1640	1189
#
#
# Done!
# Run Time: 1 seconds
