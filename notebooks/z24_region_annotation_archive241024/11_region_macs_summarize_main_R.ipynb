# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# **Set global variables**

# %%
txt_fdiry = file.path(FD_RES, "region", "summary")
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
TXT_FDIRY_REGION_LABEL   = file.path(FD_RES, "region", "summary")
TXT_FNAME_REGION_LABEL_A = "metadata.label.astarr_macs.tsv"
TXT_FNAME_REGION_LABEL_B = "metadata.label.main.tsv"

# %% [markdown]
# ## Import data

# %%
txt_fdiry = TXT_FDIRY_REGION_LABEL
txt_fname = TXT_FNAME_REGION_LABEL_A
txt_fpath = file.path(txt_fdiry, txt_fname)

dat_region_label_A = read_tsv(txt_fpath, show_col_types = FALSE)
dat_region_label_A
# Out:
#   Folder
# 1 fcc_astarr_macs
# 2 fcc_astarr_macs
#   FName
# 1 K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# 2 K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#   Label
# 1 fcc_astarr_macs_input_overlap
# 2 fcc_astarr_macs_input_union

# %%
txt_fdiry = TXT_FDIRY_REGION_LABEL
txt_fname = TXT_FNAME_REGION_LABEL_B
txt_fpath = file.path(txt_fdiry, txt_fname)

dat_region_label_B = read_tsv(txt_fpath, show_col_types = FALSE)
dat_region_label_B
# Out:
#    Folder
# 1  encode_chromatin_states
# 2  encode_chromatin_states
# 3  encode_chromatin_states
# 4  encode_chromatin_states
# 5  fcc_astarr_csaw
# 6  fcc_astarr_csaw
# 7  fcc_crispri_growth
# 8  fcc_crispri_growth
# 9  fcc_crispri_hcrff
# 10 fcc_mpra_agarwal2023
# 11 fcc_starrmpra_junke
# 12 fcc_starrmpra_junke
# 13 fcc_starrmpra_junke
# 14 fcc_starrmpra_junke
# 15 fcc_starrmpra_junke
# 16 genome_tss
# 17 genome_tss
# 18 hic_insitu_K562_ENCSR545YBD
# 19 hic_insitu_K562_ENCSR545YBD
# 20 hic_insitu_K562_ENCSR545YBD
# 21 hic_intact_K562_deep
# 22 hic_intact_K562_deep
# 23 hic_intact_K562_ENCSR479XDG
# 24 hic_intact_K562_ENCSR479XDG
# 25 hic_intact_K562_ENCSR479XDG
# 26 module_tf_shannon
#    FName
# 1  K562.hg38.cCREs.silencer_rest.bed.gz
# 2  K562.hg38.cCREs.silencer_starr.bed.gz
# 3  K562.hg38.ENCSR365YNI.ENCFF106BGJ.ChromHMM.simplified.bed.gz
# 4  K562.hg38.ENCSR913HQX.ENCFF286VQG.cCREs.simplified.bed.gz
# 5  K562.hg38.ASTARR.csaw.KS91.bed.gz
# 6  K562.hg38.ASTARR.csaw.KSMerge.bed.gz
# 7  K562.hg38.CRISPRi_Growth.signif.bed.gz
# 8  K562.hg38.CRISPRi_Growth.total.bed.gz
# 9  K562.hg38.CRISPRi_HCRFF.CASA.bed.gz
# 10 K562.hg38.LMPRA.lib_design.bed.gz
# 11 K562.hg38.ASTARR.junke.bed.gz
# 12 K562.hg38.eSTARR.junke.bed.gz
# 13 K562.hg38.LMPRA.junke.bed.gz
# 14 K562.hg38.TMPRA.junke.bed.gz
# 15 K562.hg38.WSTARR.junke.bed.gz
# 16 K562.hg38.TSS.selected_by_highest_Pol2_signal.bed.gz
# 17 K562.hg38.TSS.selected_by_highest_Pol2_signal.filtered_by_RNAseq_TPM.bed.gz
# 18 K562.hg38.hic_insitu.Loop_A.bed.gz
# 19 K562.hg38.hic_insitu.Loop_B.bed.gz
# 20 K562.hg38.hic_insitu.TAD.bedpe.gz
# 21 K562.hg38.hic_intact.Loop_A.bed.gz
# 22 K562.hg38.hic_intact.Loop_B.bed.gz
# 23 K562.hg38.hic_intact.Loop_A.bed.gz
# 24 K562.hg38.hic_intact.Loop_B.bed.gz
# 25 K562.hg38.hic_intact.TAD.bedpe.gz
# 26 K562.hg38.TF_Module.bed.gz
#    Label
# 1  encode_ccres_silencer_rest
# 2  encode_ccres_silencer_starr
# 3  encode_chromhmm_ENCFF106BGJ
# 4  encode_ccres_ENCFF286VQG
# 5  fcc_astarr_csaw_KS91
# 6  fcc_astarr_csaw_KSMerge
# 7  fcc_crispri_growth_signif
# 8  fcc_crispri_growth_total
# 9  fcc_crispri_hcrff_casa
# 10 fcc_mpra_agarwal2023
# 11 fcc_starrmpra_junke_astarr
# 12 fcc_starrmpra_junke_estarr
# 13 fcc_starrmpra_junke_lmpra
# 14 fcc_starrmpra_junke_tmpra
# 15 fcc_starrmpra_junke_wstarr
# 16 genome_tss_pol2
# 17 genome_tss_pol2_rnaseq
# 18 hic_insitu_Loop_A_ENCSR545YBD
# 19 hic_insitu_Loop_B_ENCSR545YBD
# 20 hic_insitu_TAD_ENCSR545YBD
# 21 hic_intact_Loop_A_deep
# 22 hic_intact_Loop_B_deep
# 23 hic_intact_Loop_A_ENCSR479XDG
# 24 hic_intact_Loop_B_ENCSR479XDG
# 25 hic_intact_TAD_ENCSR479XDG
# 26 module_tf_shannon

# %% [markdown]
# **Check colnumn names**

# %%
dat = dat_region_label_A
vec = unique(dat$Folder)
vec_txt_region_folder_A = vec

for (txt_region_folder_A in vec_txt_region_folder_A){
    ### get column names for region A
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_A, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_A = dat_cname$Name

    ### show results
    cat(txt_region_folder_A, "\n")
    print(vec_txt_cname_A)
    cat("\n")
}
# Out:
# fcc_astarr_macs
# [1] "Chrom"      "ChromStart" "ChromEnd"

# %%
dat = dat_region_label_B
vec = unique(dat$Folder)
vec_txt_region_folder_B = vec

for (txt_region_folder_B in vec_txt_region_folder_B){
    ### get column names for region B
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_B, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_B = dat_cname$Name

    ### show results
    cat(txt_region_folder_B, "\n")
    print(vec_txt_cname_B)
    cat("\n")
}
# Out:
# encode_chromatin_states
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Group"
# [6] "Label"
#
# fcc_astarr_csaw
#  [1] "Chrom"            "ChromStart"       "ChromEnd"         "Name"
#  [5] "Score"            "Strand"           "Log2FC"           "Input_CPM"
#  [9] "Output_CPM"       "MinusLog10PValue" "MinusLog10QValue" "Group"
# [13] "Label"
#
# fcc_crispri_growth
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Region"     "Guide_ID"
# [6] "Log2FC"     "Padj"       "Group"      "Label"
#
# fcc_crispri_hcrff
#  [1] "Chrom"        "ChromStart"   "ChromEnd"     "Name"         "Score"
#  [6] "Strand"       "Gene_Symbol"  "Gene_Ensembl" "Group"        "Label"
#
# fcc_mpra_agarwal2023
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Score"
# [6] "Strand"     "Group"      "Label"
#
# fcc_starrmpra_junke
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Score"
# [6] "Strand"     "Group"      "Label"      "Dataset"
#
# genome_tss
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Score"
# [6] "Group"      "Label"
#
# hic_insitu_K562_ENCSR545YBD
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Group"
# [6] "Label"
#
# hic_intact_K562_deep
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Group"
# [6] "Label"
#
# hic_intact_K562_ENCSR479XDG
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Group"
# [6] "Label"      "Note"
#
# module_tf_shannon
# [1] "Chrom"      "ChromStart" "ChromEnd"   "Name"       "Group"
# [6] "Label"

# %% [markdown]
# ## Main

# %% [markdown]
# **init**

# %%
dat = dat_region_label_A
lst = split(dat, 1:nrow(dat))
lst = lapply(lst, as.list)
lst_region_label_A = lst[1]
lst
# Out:
# $`1`
# $`1`$Folder
# [1] "fcc_astarr_macs"
#
# $`1`$FName
# [1] "K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz"
#
# $`1`$Label
# [1] "fcc_astarr_macs_input_overlap"
#
#
# $`2`
# $`2`$Folder
# [1] "fcc_astarr_macs"
#
# $`2`$FName
# [1] "K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz"
#
# $`2`$Label
# [1] "fcc_astarr_macs_input_union"

# %%
dat = dat_region_label_B
vec = unique(dat$Folder)
idx = str_detect(vec, "hic")
vec = vec[!idx]
vec_txt_region_folder_B = vec
vec
# Out:
# [1] "encode_chromatin_states" "fcc_astarr_csaw"
# [3] "fcc_crispri_growth"      "fcc_crispri_hcrff"
# [5] "fcc_mpra_agarwal2023"    "fcc_starrmpra_junke"
# [7] "genome_tss"              "module_tf_shannon"

# %% [markdown]
# **Loop**

# %%
### loop through region A
for (idx in seq_along(lst_region_label_A)){
    ### get region A
    lst = lst_region_label_A[[idx]]
    txt_region_folder_A = lst$Folder
    txt_region_label_A  = lst$Label

    ### get column names for region A
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_A, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_A = dat_cname$Name

    ### loop through region B
    for (txt_region_folder_B in vec_txt_region_folder_B){
        ### get column names for region B
        txt_fdiry = file.path(FD_RES, "region", txt_region_folder_B, "summary")
        txt_fname = "description.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
        dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
        vec_txt_cname_B = dat_cname$Name

        ### get total column names for annotation table
        vec_txt_cname = c(
            paste0(vec_txt_cname_A, "_A"),
            paste0(vec_txt_cname_B, "_B"),
            "Overlap"
        )
        
        ### get directory of annotation table
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A, 
            txt_region_folder_B
        )
        txt_fname = "*bed.gz"
        txt_fglob = file.path(txt_fdiry, txt_fname)

        ### get annotation table files
        vec_txt_fpath = Sys.glob(txt_fglob)
        vec_txt_fname = basename(vec_txt_fpath)

        ### show progress
        cat("===========================================\n")
        cat("Read annotation...", "\n")
        cat("Region A:", txt_region_folder_A, "|", txt_region_label_A, "\n")
        cat("Region B:", txt_region_folder_B, "\n")
        cat("FDiry:   ", "\n")
        print(txt_fdiry)
        cat("FName:   ", "\n")
        print(vec_txt_fname)
        cat("\n")
        flush.console()
        
        ### import annotation tables
        lst = lapply(vec_txt_fname, function(txt_fname){
            ### set directory
            txt_fpath = file.path(txt_fdiry, txt_fname)
            
            ### get annotation of region A and region B
            vec = str_split(txt_fname, "\\.")[[1]]
            txt_annot_A = vec[1]
            txt_annot_B = vec[2]

            ### read table and add annotation labels
            dat = read_tsv(txt_fpath, col_names = vec_txt_cname, show_col_types = FALSE)
            dat = dat %>% 
                dplyr::mutate(
                    Region_A = fun_gen_region(Chrom_A, ChromStart_A, ChromEnd_A),
                    Region_B = fun_gen_region(Chrom_B, ChromStart_B, ChromEnd_B),
                    Annotation_A = txt_annot_A,
                    Annotation_B = txt_annot_B
                )
            return(dat)
        }) 

        ### concatenate tables
        dat = bind_rows(lst)
        dat_region_annot_pair = dat
        
        ### summarize annotation tables
        dat = dat_region_annot_pair
        dat = dat %>%
            dplyr::group_by(
                Chrom_A, ChromStart_A, ChromEnd_A, Region_A,
                Annotation_A,
                Annotation_B,
                Group_B,
                Label_B
            ) %>%
            dplyr::summarise(
                Region_B = paste(Region_B, collapse=";"),
                Count_B  = n(),
                .groups = "drop")
        dat_region_annot_summary = dat


        ### set directory
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A,
            "summary"
        )
        txt_fname1 = paste("region", "annotation", txt_region_folder_B, "tsv", sep = ".")
        txt_fpath1 = file.path(txt_fdiry, txt_fname1)
        txt_fname2 = paste("region", "summary",    txt_region_folder_B, "tsv", sep = ".")
        txt_fpath2 = file.path(txt_fdiry, txt_fname2)
        
        ### show progress
        cat("Save annotation...",  "\n")
        cat("FDiry: ", txt_fdiry, "\n")
        cat("FName1:", txt_fname1, "\n")
        cat("FName2:", txt_fname2, "\n")
        cat("\n")
        flush.console()

        ### write tables
        dir.create(txt_fdiry, showWarnings = FALSE)
        write_tsv(dat_region_annot_pair,    txt_fpath1)
        write_tsv(dat_region_annot_summary, txt_fpath2)
    } ### end loop region B
} ### end loop region A
# Out:
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: encode_chromatin_states
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states"
# FName:
# [1] "fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.bed.gz"
# [2] "fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.bed.gz"
# [3] "fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.bed.gz"
# [4] "fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.encode_chromatin_states.tsv
# FName2: region.summary.encode_chromatin_states.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: fcc_astarr_csaw
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_astarr_csaw"
# FName:
# [1] "fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.bed.gz"
# [2] "fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.fcc_astarr_csaw.tsv
# FName2: region.summary.fcc_astarr_csaw.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: fcc_crispri_growth
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_growth"
# FName:
# [1] "fcc_astarr_macs_input_overlap.fcc_crispri_growth_signif.bed.gz"
# [2] "fcc_astarr_macs_input_overlap.fcc_crispri_growth_total.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.fcc_crispri_growth.tsv
# FName2: region.summary.fcc_crispri_growth.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: fcc_crispri_hcrff
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_hcrff"
# FName:
# [1] "fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.fcc_crispri_hcrff.tsv
# FName2: region.summary.fcc_crispri_hcrff.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: fcc_mpra_agarwal2023
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_mpra_agarwal2023"
# FName:
# [1] "fcc_astarr_macs_input_overlap.fcc_mpra_agarwal2023.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.fcc_mpra_agarwal2023.tsv
# FName2: region.summary.fcc_mpra_agarwal2023.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: fcc_starrmpra_junke
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke"
# FName:
# [1] "fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_astarr.bed.gz"
# [2] "fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_estarr.bed.gz"
# [3] "fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_lmpra.bed.gz"
# [4] "fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_tmpra.bed.gz"
# [5] "fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_wstarr.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.fcc_starrmpra_junke.tsv
# FName2: region.summary.fcc_starrmpra_junke.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: genome_tss
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/genome_tss"
# FName:
# [1] "fcc_astarr_macs_input_overlap.genome_tss_pol2.bed.gz"
# [2] "fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.genome_tss.tsv
# FName2: region.summary.genome_tss.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: module_tf_shannon
# FDiry:
# [1] "/mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/module_tf_shannon"
# FName:
# [1] "fcc_astarr_macs_input_overlap.module_tf_shannon.bed.gz"
#
# Save annotation...
# FDiry:  /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName1: region.annotation.module_tf_shannon.tsv
# FName2: region.summary.module_tf_shannon.tsv

# %% [markdown]
# ## Review

# %%
head(dat_region_annot_pair)
# Out:
#   Chrom_A ChromStart_A ChromEnd_A Chrom_B ChromStart_B ChromEnd_B
# 1 chr1    115429       115969     chr1    115702       115751
# 2 chr1    115429       115969     chr1    115702       115751
# 3 chr1    115429       115969     chr1    115702       115751
# 4 chr1    115429       115969     chr1    115702       115751
# 5 chr1    136201       137353     chr1    136446       136510
# 6 chr1    138321       139517     chr1    139031       139110
#   Name_B             Group_B   Label_B   Overlap Region_A
# 1 chr1:115702-115751 TF_Module Module_02 49      chr1:115429-115969
# 2 chr1:115702-115751 TF_Module Module_05 49      chr1:115429-115969
# 3 chr1:115702-115751 TF_Module Module_10 49      chr1:115429-115969
# 4 chr1:115702-115751 TF_Module Module_44 49      chr1:115429-115969
# 5 chr1:136446-136510 TF_Module Module_27 64      chr1:136201-137353
# 6 chr1:139031-139110 TF_Module Module_02 79      chr1:138321-139517
#   Region_B           Annotation_A                  Annotation_B
# 1 chr1:115702-115751 fcc_astarr_macs_input_overlap module_tf_shannon
# 2 chr1:115702-115751 fcc_astarr_macs_input_overlap module_tf_shannon
# 3 chr1:115702-115751 fcc_astarr_macs_input_overlap module_tf_shannon
# 4 chr1:115702-115751 fcc_astarr_macs_input_overlap module_tf_shannon
# 5 chr1:136446-136510 fcc_astarr_macs_input_overlap module_tf_shannon
# 6 chr1:139031-139110 fcc_astarr_macs_input_overlap module_tf_shannon

# %%
head(dat_region_annot_summary)
# Out:
#   Chrom_A ChromStart_A ChromEnd_A Region_A
# 1 chr1    115429       115969     chr1:115429-115969
# 2 chr1    115429       115969     chr1:115429-115969
# 3 chr1    115429       115969     chr1:115429-115969
# 4 chr1    115429       115969     chr1:115429-115969
# 5 chr1    136201       137353     chr1:136201-137353
# 6 chr1    138321       139517     chr1:138321-139517
#   Annotation_A                  Annotation_B      Group_B   Label_B
# 1 fcc_astarr_macs_input_overlap module_tf_shannon TF_Module Module_02
# 2 fcc_astarr_macs_input_overlap module_tf_shannon TF_Module Module_05
# 3 fcc_astarr_macs_input_overlap module_tf_shannon TF_Module Module_10
# 4 fcc_astarr_macs_input_overlap module_tf_shannon TF_Module Module_44
# 5 fcc_astarr_macs_input_overlap module_tf_shannon TF_Module Module_27
# 6 fcc_astarr_macs_input_overlap module_tf_shannon TF_Module Module_02
#   Region_B           Count_B
# 1 chr1:115702-115751 1
# 2 chr1:115702-115751 1
# 3 chr1:115702-115751 1
# 4 chr1:115702-115751 1
# 5 chr1:136446-136510 1
# 6 chr1:139031-139110 1
