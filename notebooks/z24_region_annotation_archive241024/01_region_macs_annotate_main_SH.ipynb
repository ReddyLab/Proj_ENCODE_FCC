# %% [raw]
# ---
# title: Region annotation 01 (ASTARR MACS peaks)
# subtitle: Annotate peaks (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_flagship
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chromatin_states
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs
# fcc_crispri_growth
# fcc_crispri_hcrff
# fcc_mpra_agarwal2023
# fcc_screened
# fcc_starrmpra_junke
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/metadata.label.main.tsv

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs.tsv
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.main.tsv
# Folder	FName	Label
# encode_chromatin_states	K562.hg38.cCREs.silencer_rest.bed.gz	encode_ccres_silencer_rest
# encode_chromatin_states	K562.hg38.cCREs.silencer_starr.bed.gz	encode_ccres_silencer_starr
# encode_chromatin_states	K562.hg38.ENCSR365YNI.ENCFF106BGJ.ChromHMM.simplified.bed.gz	encode_chromhmm_ENCFF106BGJ
# encode_chromatin_states	K562.hg38.ENCSR913HQX.ENCFF286VQG.cCREs.simplified.bed.gz	encode_ccres_ENCFF286VQG
# fcc_astarr_csaw	K562.hg38.ASTARR.csaw.KS91.bed.gz	fcc_astarr_csaw_KS91
# fcc_astarr_csaw	K562.hg38.ASTARR.csaw.KSMerge.bed.gz	fcc_astarr_csaw_KSMerge
# fcc_crispri_growth	K562.hg38.CRISPRi_Growth.signif.bed.gz	fcc_crispri_growth_signif
# fcc_crispri_growth	K562.hg38.CRISPRi_Growth.total.bed.gz	fcc_crispri_growth_total
# fcc_crispri_hcrff	K562.hg38.CRISPRi_HCRFF.CASA.bed.gz	fcc_crispri_hcrff_casa
# fcc_mpra_agarwal2023	K562.hg38.LMPRA.lib_design.bed.gz	fcc_mpra_agarwal2023
# fcc_starrmpra_junke	K562.hg38.ASTARR.junke.bed.gz	fcc_starrmpra_junke_astarr
# fcc_starrmpra_junke	K562.hg38.eSTARR.junke.bed.gz	fcc_starrmpra_junke_estarr
# fcc_starrmpra_junke	K562.hg38.LMPRA.junke.bed.gz	fcc_starrmpra_junke_lmpra
# fcc_starrmpra_junke	K562.hg38.TMPRA.junke.bed.gz	fcc_starrmpra_junke_tmpra
# fcc_starrmpra_junke	K562.hg38.WSTARR.junke.bed.gz	fcc_starrmpra_junke_wstarr
# genome_tss	K562.hg38.TSS.selected_by_highest_Pol2_signal.bed.gz	genome_tss_pol2
# genome_tss	K562.hg38.TSS.selected_by_highest_Pol2_signal.filtered_by_RNAseq_TPM.bed.gz	genome_tss_pol2_rnaseq
# hic_insitu_K562_ENCSR545YBD	K562.hg38.hic_insitu.Loop_A.bed.gz	hic_insitu_Loop_A_ENCSR545YBD
# hic_insitu_K562_ENCSR545YBD	K562.hg38.hic_insitu.Loop_B.bed.gz	hic_insitu_Loop_B_ENCSR545YBD
# hic_insitu_K562_ENCSR545YBD	K562.hg38.hic_insitu.TAD.bedpe.gz	hic_insitu_TAD_ENCSR545YBD
# hic_intact_K562_deep	K562.hg38.hic_intact.Loop_A.bed.gz	hic_intact_Loop_A_deep
# hic_intact_K562_deep	K562.hg38.hic_intact.Loop_B.bed.gz	hic_intact_Loop_B_deep
# hic_intact_K562_ENCSR479XDG	K562.hg38.hic_intact.Loop_A.bed.gz	hic_intact_Loop_A_ENCSR479XDG
# hic_intact_K562_ENCSR479XDG	K562.hg38.hic_intact.Loop_B.bed.gz	hic_intact_Loop_B_ENCSR479XDG
# hic_intact_K562_ENCSR479XDG	K562.hg38.hic_intact.TAD.bedpe.gz	hic_intact_TAD_ENCSR479XDG
# module_tf_shannon	K562.hg38.TF_Module.bed.gz	module_tf_shannon

# %% [markdown]
# ## Preview

# %% [markdown]
# **Check loop**

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_growth_signif
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_growth_signif.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_growth_signif.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_growth_total
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_growth_total.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_growth_total.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_hcrff
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_mpra_agarwal2023
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_mpra_agarwal2023
# Output FName:   fcc_astarr_macs_input_overlap.fcc_mpra_agarwal2023.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_mpra_agarwal2023.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_astarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_astarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_astarr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_estarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_estarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_estarr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_lmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_lmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_lmpra.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_tmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_tmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_tmpra.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_wstarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_wstarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_wstarr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/genome_tss
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/genome_tss
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: module_tf_shannon
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/module_tf_shannon
# Output FName:   fcc_astarr_macs_input_overlap.module_tf_shannon.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.module_tf_shannon.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_rest.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_starr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_growth_signif
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_growth_signif.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_growth_signif.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_growth_total
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_growth_total.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_growth_total.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_crispri_hcrff
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_mpra_agarwal2023
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_mpra_agarwal2023
# Output FName:   fcc_astarr_macs_input_union.fcc_mpra_agarwal2023.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_mpra_agarwal2023.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_astarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_astarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_astarr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_estarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_estarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_estarr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_lmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_lmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_lmpra.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_tmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_tmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_tmpra.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_wstarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_wstarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_wstarr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/genome_tss
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/genome_tss
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: module_tf_shannon
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/module_tf_shannon
# Output FName:   fcc_astarr_macs_input_union.module_tf_shannon.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.module_tf_shannon.txt

# %% [markdown]
# ## Execute

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir  -p ${FD_OUT}
        sbatch -p ${NODE} \
            --exclude=dl-01 \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FD_PRJ} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.txt
#
# Submitted batch job 33275398
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.txt
#
# Submitted batch job 33275399
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.txt
#
# Submitted batch job 33275400
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.txt
#
# Submitted batch job 33275401
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.txt
#
# Submitted batch job 33275402
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.txt
#
# Submitted batch job 33275403
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_growth_signif
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_growth_signif.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_growth_signif.txt
#
# Submitted batch job 33275404
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_growth_total
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_growth_total.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_growth_total.txt
#
# Submitted batch job 33275405
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_crispri_hcrff
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.txt
#
# Submitted batch job 33275407
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_mpra_agarwal2023
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_mpra_agarwal2023
# Output FName:   fcc_astarr_macs_input_overlap.fcc_mpra_agarwal2023.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_mpra_agarwal2023.txt
#
# Submitted batch job 33275408
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_astarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_astarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_astarr.txt
#
# Submitted batch job 33275409
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_estarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_estarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_estarr.txt
#
# Submitted batch job 33275410
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_lmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_lmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_lmpra.txt
#
# Submitted batch job 33275411
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_tmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_tmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_tmpra.txt
#
# Submitted batch job 33275412
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_starrmpra_junke_wstarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_wstarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_starrmpra_junke_wstarr.txt
#
# Submitted batch job 33275413
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/genome_tss
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2.txt
#
# Submitted batch job 33275415
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/genome_tss
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.txt
#
# Submitted batch job 33275416
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# Submitted batch job 33275417
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# Submitted batch job 33275418
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.txt
#
# Submitted batch job 33275419
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.txt
#
# Submitted batch job 33275420
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.txt
#
# Submitted batch job 33275421
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.txt
#
# Submitted batch job 33275422
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.txt
#
# Submitted batch job 33275423
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.txt
#
# Submitted batch job 33275424
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: module_tf_shannon
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/module_tf_shannon
# Output FName:   fcc_astarr_macs_input_overlap.module_tf_shannon.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.module_tf_shannon.txt
#
# Submitted batch job 33275425
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_rest.txt
#
# Submitted batch job 33275426
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_starr.txt
#
# Submitted batch job 33275427
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.txt
#
# Submitted batch job 33275428
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chromatin_states
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.txt
#
# Submitted batch job 33275429
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.txt
#
# Submitted batch job 33275430
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_astarr_csaw
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.txt
#
# Submitted batch job 33275431
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_growth_signif
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_growth_signif.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_growth_signif.txt
#
# Submitted batch job 33275432
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_growth_total
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_crispri_growth
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_growth_total.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_growth_total.txt
#
# Submitted batch job 33275433
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_crispri_hcrff
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.txt
#
# Submitted batch job 33275434
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_mpra_agarwal2023
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_mpra_agarwal2023
# Output FName:   fcc_astarr_macs_input_union.fcc_mpra_agarwal2023.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_mpra_agarwal2023.txt
#
# Submitted batch job 33275435
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_astarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_astarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_astarr.txt
#
# Submitted batch job 33275436
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_estarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_estarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_estarr.txt
#
# Submitted batch job 33275437
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_lmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_lmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_lmpra.txt
#
# Submitted batch job 33275438
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_tmpra
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_tmpra.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_tmpra.txt
#
# Submitted batch job 33275439
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_starrmpra_junke_wstarr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/fcc_starrmpra_junke
# Output FName:   fcc_astarr_macs_input_union.fcc_starrmpra_junke_wstarr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_starrmpra_junke_wstarr.txt
#
# Submitted batch job 33275440
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/genome_tss
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2.txt
#
# Submitted batch job 33275441
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/genome_tss
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.txt
#
# Submitted batch job 33275442
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# Submitted batch job 33275443
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# Submitted batch job 33275444
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_insitu_K562_ENCSR545YBD
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.txt
#
# Submitted batch job 33275445
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.txt
#
# Submitted batch job 33275446
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_deep
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.txt
#
# Submitted batch job 33275447
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.txt
#
# Submitted batch job 33275448
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.txt
#
# Submitted batch job 33275449
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_ENCSR479XDG
# Output FName:   fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.txt
#
# Submitted batch job 33275450
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: module_tf_shannon
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/module_tf_shannon
# Output FName:   fcc_astarr_macs_input_union.module_tf_shannon.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.module_tf_shannon.txt
#
# Submitted batch job 33275451

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.module_tf_shannon.txt
# Out:
# Hostname:           x1-01-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         07-10-24+13:11:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/module_tf_shannon/K562.hg38.TF_Module.bed.gz
#
# show first few lines of input
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_02
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_05
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_10
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_44
# chr1	118585	118665	chr1:118585-118665	TF_Module	Module_47
# chr1	136446	136510	chr1:136446-136510	TF_Module	Module_27
# chr1	139031	139110	chr1:139031-139110	TF_Module	Module_02
# chr1	139031	139110	chr1:139031-139110	TF_Module	Module_42
# chr1	268005	268051	chr1:268005-268051	TF_Module	Module_02
# chr1	268005	268051	chr1:268005-268051	TF_Module	Module_10
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/module_tf_shannon/fcc_astarr_macs_input_union.module_tf_shannon.bed.gz
#
# show first few lines of output:
# chr1	115411	115986	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_02	49
# chr1	115411	115986	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_05	49
# chr1	115411	115986	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_10	49
# chr1	115411	115986	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_44	49
# chr1	118518	118743	chr1	118585	118665	chr1:118585-118665	TF_Module	Module_47	80
# chr1	136071	137429	chr1	136446	136510	chr1:136446-136510	TF_Module	Module_27	64
# chr1	137737	139544	chr1	139031	139110	chr1:139031-139110	TF_Module	Module_02	79
# chr1	137737	139544	chr1	139031	139110	chr1:139031-139110	TF_Module	Module_42	79
# chr1	267853	268603	chr1	268005	268051	chr1:268005-268051	TF_Module	Module_02	46
# chr1	267853	268603	chr1	268005	268051	chr1:268005-268051	TF_Module	Module_10	46
#
#
# Done!
# Run Time: 5 seconds

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.txt
# Out:
# Hostname:           x1-01-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         07-10-24+13:11:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/hic_intact_K562_ENCSR479XDG/K562.hg38.hic_intact.TAD.bedpe.gz
#
# show first few lines of input
# chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD
# chr1	1940000	2040000	chr1:1940000-2040000	hic_intact	TAD
# chr1	2205000	2310000	chr1:2205000-2310000	hic_intact	TAD
# chr1	2410000	2525000	chr1:2410000-2525000	hic_intact	TAD
# chr1	2820000	3430000	chr1:2820000-3430000	hic_intact	TAD
# chr1	3490000	3620000	chr1:3490000-3620000	hic_intact	TAD
# chr1	6040000	6205000	chr1:6040000-6205000	hic_intact	TAD
# chr1	6245000	6340000	chr1:6245000-6340000	hic_intact	TAD
# chr1	6550000	6645000	chr1:6550000-6645000	hic_intact	TAD
# chr1	6710000	6785000	chr1:6710000-6785000	hic_intact	TAD
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/hic_intact_K562_ENCSR479XDG/fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.bed.gz
#
# show first few lines of output:
# chr1	1121788	1122529	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	741
# chr1	1122893	1123442	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	549
# chr1	1124347	1125709	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1362
# chr1	1127455	1129027	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1572
# chr1	1134673	1136326	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1653
# chr1	1136833	1138125	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1292
# chr1	1141732	1143168	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1436
# chr1	1143425	1143844	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	419
# chr1	1144125	1145439	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1314
# chr1	1148300	1148832	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	532
#
#
# Done!
# Run Time: 4 seconds

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.module_tf_shannon.txt
# Out:
# Hostname:           x2-07-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         07-10-24+13:11:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405
# chr1	14282	14614
# chr1	16025	16338
# chr1	17288	17689
# chr1	28934	29499
# chr1	115429	115969
# chr1	136201	137353
# chr1	137748	138049
# chr1	138321	139517
# chr1	181005	181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/module_tf_shannon/K562.hg38.TF_Module.bed.gz
#
# show first few lines of input
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_02
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_05
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_10
# chr1	115702	115751	chr1:115702-115751	TF_Module	Module_44
# chr1	118585	118665	chr1:118585-118665	TF_Module	Module_47
# chr1	136446	136510	chr1:136446-136510	TF_Module	Module_27
# chr1	139031	139110	chr1:139031-139110	TF_Module	Module_02
# chr1	139031	139110	chr1:139031-139110	TF_Module	Module_42
# chr1	268005	268051	chr1:268005-268051	TF_Module	Module_02
# chr1	268005	268051	chr1:268005-268051	TF_Module	Module_10
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/module_tf_shannon/fcc_astarr_macs_input_overlap.module_tf_shannon.bed.gz
#
# show first few lines of output:
# chr1	115429	115969	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_02	49
# chr1	115429	115969	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_05	49
# chr1	115429	115969	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_10	49
# chr1	115429	115969	chr1	115702	115751	chr1:115702-115751	TF_Module	Module_44	49
# chr1	136201	137353	chr1	136446	136510	chr1:136446-136510	TF_Module	Module_27	64
# chr1	138321	139517	chr1	139031	139110	chr1:139031-139110	TF_Module	Module_02	79
# chr1	138321	139517	chr1	139031	139110	chr1:139031-139110	TF_Module	Module_42	79
# chr1	267910	268557	chr1	268005	268051	chr1:268005-268051	TF_Module	Module_02	46
# chr1	267910	268557	chr1	268005	268051	chr1:268005-268051	TF_Module	Module_10	46
# chr1	267910	268557	chr1	268005	268051	chr1:268005-268051	TF_Module	Module_46	46
#
#
# Done!
# Run Time: 4 seconds

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.txt
# Out:
# Hostname:           x2-07-2.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         07-10-24+13:11:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405
# chr1	14282	14614
# chr1	16025	16338
# chr1	17288	17689
# chr1	28934	29499
# chr1	115429	115969
# chr1	136201	137353
# chr1	137748	138049
# chr1	138321	139517
# chr1	181005	181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/hic_intact_K562_ENCSR479XDG/K562.hg38.hic_intact.TAD.bedpe.gz
#
# show first few lines of input
# chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD
# chr1	1940000	2040000	chr1:1940000-2040000	hic_intact	TAD
# chr1	2205000	2310000	chr1:2205000-2310000	hic_intact	TAD
# chr1	2410000	2525000	chr1:2410000-2525000	hic_intact	TAD
# chr1	2820000	3430000	chr1:2820000-3430000	hic_intact	TAD
# chr1	3490000	3620000	chr1:3490000-3620000	hic_intact	TAD
# chr1	6040000	6205000	chr1:6040000-6205000	hic_intact	TAD
# chr1	6245000	6340000	chr1:6245000-6340000	hic_intact	TAD
# chr1	6550000	6645000	chr1:6550000-6645000	hic_intact	TAD
# chr1	6710000	6785000	chr1:6710000-6785000	hic_intact	TAD
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/hic_intact_K562_ENCSR479XDG/fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.bed.gz
#
# show first few lines of output:
# chr1	1121812	1122517	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	705
# chr1	1123051	1123418	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	367
# chr1	1124365	1124875	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	510
# chr1	1125359	1125597	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	238
# chr1	1127573	1128245	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	672
# chr1	1128708	1128988	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	280
# chr1	1135065	1136296	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1231
# chr1	1136909	1138088	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	1179
# chr1	1141805	1142527	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	722
# chr1	1142885	1143143	chr1	1120000	1240000	chr1:1120000-1240000	hic_intact	TAD	258
#
#
# Done!
# Run Time: 3 seconds
