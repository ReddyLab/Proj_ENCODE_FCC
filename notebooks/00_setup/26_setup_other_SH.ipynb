# %% [raw]
# ---
# title: Setup Scripts 06
# subtitle: Others
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env

# %% [markdown]
# ## Get additional data for scripts

# %% [markdown]
# ### Get chromosome size information

# %%
ls ${FD_WORK}/proj_encode_fcc
# Out:
# data  Readme.md  results_v1.tar.gz  results_v3.tar.gz  source
# log   results    results_v2.tar.gz  results_v4

# %%
ls ${FD_WORK}/proj_encode_fcc/source
# Out:
# A001_K562_wstarrseq_fragments
# A001_K562_wstarrseq_fragments_wgs
# annotation_cCREs
# annotation_chipseq_histone
# annotation_chipseq_tf
# annotation_chromHMM
# annotation_enhancer_junke
# annotation_enhancer_junke_zscore
# annotation_enhancer_junke_zscore_prev
# annotation_gencode
# annotation_gene
# annotation_remap2022
# annotation_starrseq_negative_control_junke
# chrom.sizes.hg19
# chrom.sizes.hg38
# CRISPRi_FlowFISH
# CRISPRi_growth
# ENCODE_E2G
# hic_intact_K562_ENCSR479XDG
# KS91_K562_astarrseq_fragments_220510
# KS91_K562_astarrseq_fragments_wgs
# KS91_K562_astarrseq_peak_macs
# MPRA
# Readme.md
# RNAseq
# TF_modules
# tmp

# %% [markdown]
# ```
# cp ${FD_WORK}/proj_combeffect_encode_fcc/source/chrom.sizes.hg* ${FD_DAT}/external/
# ls ${FD_DAT}/external
# ```

# %%
ls ${FD_DAT}/external
# Out:
# chrom.list.auto          encode_chipseq_histone   genome_tss
# chrom.list.main          encode_chipseq_subset    hic_insitu_GM12878
# chrom.list.sex           encode_chromatin_states  hic_insitu_K562_ENCSR545YBD
# chrom.sizes.hg19         encode_crispri_hcrff     hic_intact_K562_deep
# chrom.sizes.hg38         encode_open_chromatin    hic_intact_K562_ENCSR479XDG
# encode_chipseq_flagship  encode_rnaseq            RNAseq

# %%
cat ${FD_DAT}/external/chrom.sizes.hg38
# Out:
# chr1	248956422
# chr2	242193529
# chr3	198295559
# chr4	190214555
# chr5	181538259
# chr6	170805979
# chr7	159345973
# chrX	156040895
# chr8	145138636
# chr9	138394717
# chr11	135086622
# chr10	133797422
# chr12	133275309
# chr13	114364328
# chr14	107043718
# chr15	101991189
# chr16	90338345
# chr17	83257441
# chr18	80373285
# chr20	64444167
# chr19	58617616
# chrY	57227415
# chr22	50818468
# chr21	46709983
# chr15_KI270905v1_alt	5161414
# chr6_GL000256v2_alt	4929269
# chr6_GL000254v2_alt	4827813
# chr6_GL000251v2_alt	4795265
# chr6_GL000253v2_alt	4677643
# chr6_GL000250v2_alt	4672374
# chr6_GL000255v2_alt	4606388
# chr6_GL000252v2_alt	4604811
# chr17_KI270857v1_alt	2877074
# chr16_KI270853v1_alt	2659700
# chr16_KI270728v1_random	1872759
# chr17_GL000258v2_alt	1821992
# chr5_GL339449v2_alt	1612928
# chr14_KI270847v1_alt	1511111
# chr17_KI270908v1_alt	1423190
# chr14_KI270846v1_alt	1351393
# chr5_KI270897v1_alt	1144418
# chr7_KI270803v1_alt	1111570
# chr19_GL949749v2_alt	1091841
# ...

# %%
FP_INP=${FD_DAT}/external/chrom.sizes.hg38
FP_OUT=${FD_DAT}/external/chrom.sizes.hg38.bed
cat ${FP_INP} | awk '{print $1"\t"0"\t"$2}' > ${FP_OUT}

# %%
FP_OUT=${FD_DAT}/external/chrom.list.main
echo -e "chr1\nchr2\nchr3\nchr4\nchr5\nchr6\nchr7\nchr8\nchr9\nchr10\nchr11\nchr12\nchr13\nchr14\nchr15\nchr16\nchr17\nchr18\nchr19\nchr20\nchr21\nchr22\nchrX\nchrY" > ${FP_OUT}
cat ${FP_OUT}
# Out:
# chr1
# chr2
# chr3
# chr4
# chr5
# chr6
# chr7
# chr8
# chr9
# chr10
# chr11
# chr12
# chr13
# chr14
# chr15
# chr16
# chr17
# chr18
# chr19
# chr20
# chr21
# chr22
# chrX
# chrY

# %%
FP_OUT=${FD_DAT}/external/chrom.list.auto
echo -e "chr1\nchr2\nchr3\nchr4\nchr5\nchr6\nchr7\nchr8\nchr9\nchr10\nchr11\nchr12\nchr13\nchr14\nchr15\nchr16\nchr17\nchr18\nchr19\nchr20\nchr21\nchr22" > ${FP_OUT}
cat ${FP_OUT}
# Out:
# chr1
# chr2
# chr3
# chr4
# chr5
# chr6
# chr7
# chr8
# chr9
# chr10
# chr11
# chr12
# chr13
# chr14
# chr15
# chr16
# chr17
# chr18
# chr19
# chr20
# chr21
# chr22

# %%
FP_OUT=${FD_DAT}/external/chrom.list.sex
echo -e "chrX\nchrY" > ${FP_OUT}
cat ${FP_OUT}
# Out:
# chrX
# chrY

# %%
ls ${FD_DAT}/external/chrom*
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/chrom.list.auto
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/chrom.list.main
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/chrom.list.sex
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/chrom.sizes.hg19
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/chrom.sizes.hg38
