# %% [raw]
# ---
# title: Prepare TF Modules 01
# subtitle: Explore the data
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
library(biomaRt)
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# **Set global variables**

# %%
txt_fdiry = file.path(FD_DAT, "processed", "TF_modules_Shannon")
vec = dir(txt_fdiry)
vec
# Out:
# [1] "K562.full.region.assignments.txt" "K562.TFzscore.txt"

# %%
txt_fdiry = file.path(FD_DAT, "processed", "TF_modules_Shannon")
txt_fname = "K562.TFzscore.txt"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath)
dat_module_tfs = dat
print(dim(dat_module_tfs))
head(dat)
# Out:
# Rows: 2503 Columns: 2
# ── Column specification ────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): TF
# dbl (1): module
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 2503    2
#   module TF
# 1 1      ZNF589
# 2 1      JUNB
# 3 1      FOSL1
# 4 1      MEIS2
# 5 1      EGR1
# 6 1      MEF2D

# %%
ensembl = useEnsembl(
    biomart = "genes", 
    dataset = "hsapiens_gene_ensembl",
    mirror  = "useast"
)
ensembl
# Out:
# Object of class 'Mart':
#   Using the ENSEMBL_MART_ENSEMBL BioMart database
#   Using the hsapiens_gene_ensembl dataset

# %%
dat = dat_module_tfs
vec = unique(dat$TF)
vec = head(vec)

vec_txt_gene = vec
print(length(vec))
print(vec)
# Out:
# [1] 6
# [1] "ZNF589" "JUNB"   "FOSL1"  "MEIS2"  "EGR1"   "MEF2D"

# %%
vec_txt_attr = c(
    'chromosome_name',
    'ensembl_gene_id', 
    'uniprot_gn_id', 
    'uniprot_gn_symbol', 
    'interpro', 
    'interpro_short_description', 
    'interpro_description'
)

# %%
dat = getBM(
    attributes = vec_txt_attr,
    filters    = 'uniprot_gn_symbol',
    values     = vec_gene, 
    mart       = ensembl)

# %%
dat
# Out:
#     chromosome_name ensembl_gene_id uniprot_gn_id uniprot_gn_symbol interpro
# 1   HG2515_PATCH    ENSG00000291761 Q14814        MEF2D             IPR002100
# 2   HG2515_PATCH    ENSG00000291761 Q05BX2        MEF2D             IPR002100
# 3   HG2515_PATCH    ENSG00000291761 Q14814        MEF2D             IPR022102
# 4   HG2515_PATCH    ENSG00000291761 Q05BX2        MEF2D             IPR022102
# 5   HG2515_PATCH    ENSG00000291761 Q14814        MEF2D             IPR033896
# 6   HG2515_PATCH    ENSG00000291761 Q05BX2        MEF2D             IPR033896
# 7   HG2515_PATCH    ENSG00000291761 Q14814        MEF2D             IPR036879
# 8   HG2515_PATCH    ENSG00000291761 Q05BX2        MEF2D             IPR036879
# 9   HG2515_PATCH    ENSG00000291761 Q14814        MEF2D
# 10  HG2515_PATCH    ENSG00000291761 Q05BX2        MEF2D
# 11  11              ENSG00000175592 A0A0S2Z595    FOSL1             IPR000837
# 12  11              ENSG00000175592 E9PPX2        FOSL1             IPR000837
# ...
