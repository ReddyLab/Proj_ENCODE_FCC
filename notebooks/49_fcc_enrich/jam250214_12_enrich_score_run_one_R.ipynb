# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
suppressMessages(suppressWarnings(library("nullranges")))
suppressMessages(suppressWarnings(library("plyranges")))
suppressMessages(suppressWarnings(library("boot")))
suppressMessages(suppressWarnings(library("coin")))
suppressMessages(suppressWarnings(library("pheatmap")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Import data

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_enrichment_v2"
)
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# List_MatchedRanges.rds
# region.prepare.annotation.tsv
# region.prepare.covariate.tsv
# region.prepare.group.tsv
# region.prepare.score.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_enrichment_v2"
)
txt_fname = "List_MatchedRanges.rds"
txt_fpath = file.path(txt_fdiry, txt_fname)

obj = readRDS(txt_fpath)

lst_mgr_region = obj
print(names(obj))
# Out:
# [1] "Background"   "Enhancer"     "Silencer"     "TSS:Enhancer" "TSS:Silencer"

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_integration",
    "fcc_astarr_macs_input_overlap",
    "analysis_enrichment_v2"
)
txt_fname = "region.prepare.score.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

mat_region_score_import = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 150041    531
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID3B </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ASH1L </th>
#    <th style="text-align:right;"> ATF1 </th>
#    <th style="text-align:right;"> ATF2 </th>
#    <th style="text-align:right;"> ATF3 </th>
#    <th style="text-align:right;"> ATF4 </th>
#    <th style="text-align:right;"> ATF6 </th>
#    <th style="text-align:right;"> ATF7 </th>
#    <th style="text-align:right;"> BACH1 </th>
#    <th style="text-align:right;"> BCL6 </th>
#    <th style="text-align:right;"> BCLAF1 </th>
#    <th style="text-align:right;"> BCOR </th>
#    <th style="text-align:right;"> BDP1 </th>
#    <th style="text-align:right;"> BHLHE40 </th>
#    <th style="text-align:right;"> BMI1 </th>
#    <th style="text-align:right;"> BRCA1 </th>
#    <th style="text-align:right;"> BRD4 </th>
#    <th style="text-align:right;"> BRD9 </th>
#    <th style="text-align:right;"> BRF2 </th>
#    <th style="text-align:right;"> C11orf30 </th>
#    <th style="text-align:right;"> CAMTA2 </th>
#    <th style="text-align:right;"> CBFA2T2 </th>
#    <th style="text-align:right;"> CBFA2T3 </th>
#    <th style="text-align:right;"> CBFB </th>
#    <th style="text-align:right;"> CBX1 </th>
#    <th style="text-align:right;"> CBX2 </th>
#    <th style="text-align:right;"> CBX3 </th>
#    <th style="text-align:right;"> CBX5 </th>
#    <th style="text-align:right;"> CC2D1A </th>
#    <th style="text-align:right;"> CCAR2 </th>
#    <th style="text-align:right;"> CDC5L </th>
#    <th style="text-align:right;"> CEBPB </th>
#    <th style="text-align:right;"> CEBPG </th>
#    <th style="text-align:right;"> CEBPZ </th>
#    <th style="text-align:right;"> CGGBP1 </th>
#    <th style="text-align:right;"> CHAMP1 </th>
#    <th style="text-align:right;"> CHCHD3 </th>
#    <th style="text-align:right;"> CHD1 </th>
#    <th style="text-align:right;"> CHD2 </th>
#    <th style="text-align:right;"> CHD4 </th>
#    <th style="text-align:right;"> CHD7 </th>
#    <th style="text-align:right;"> CLOCK </th>
#    <th style="text-align:right;"> COPS2 </th>
#    <th style="text-align:right;"> CREB1 </th>
#    <th style="text-align:right;"> CREB3 </th>
#    <th style="text-align:right;"> CREB3L1 </th>
#    <th style="text-align:right;"> CREB5 </th>
#    <th style="text-align:right;"> CREBBP </th>
#    <th style="text-align:right;"> CREM </th>
#    <th style="text-align:right;"> CSDE1 </th>
#    <th style="text-align:right;"> CTBP1 </th>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> CTCFL </th>
#    <th style="text-align:right;"> CUX1 </th>
#    <th style="text-align:right;"> CXXC5 </th>
#    <th style="text-align:right;"> DACH1 </th>
#    <th style="text-align:right;"> DDIT3 </th>
#    <th style="text-align:right;"> DDX20 </th>
#    <th style="text-align:right;"> DEAF1 </th>
#    <th style="text-align:right;"> DIDO1 </th>
#    <th style="text-align:right;"> DLX4 </th>
#    <th style="text-align:right;"> DMBX1 </th>
#    <th style="text-align:right;"> DMTF1 </th>
#    <th style="text-align:right;"> DNMT1 </th>
#    <th style="text-align:right;"> DPF2 </th>
#    <th style="text-align:right;"> E2F1 </th>
#    <th style="text-align:right;"> E2F3 </th>
#    <th style="text-align:right;"> E2F4 </th>
#    <th style="text-align:right;"> E2F5 </th>
#    <th style="text-align:right;"> E2F6 </th>
#    <th style="text-align:right;"> E2F7 </th>
#    <th style="text-align:right;"> E2F8 </th>
#    <th style="text-align:right;"> E4F1 </th>
#    <th style="text-align:right;"> EGR1 </th>
#    <th style="text-align:right;"> EHMT2 </th>
#    <th style="text-align:right;"> ELF1 </th>
#    <th style="text-align:right;"> ELF2 </th>
#    <th style="text-align:right;"> ELF4 </th>
#    <th style="text-align:right;"> ELK1 </th>
#    <th style="text-align:right;"> ELK3 </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> EP400 </th>
#    <th style="text-align:right;"> ERF </th>
#    <th style="text-align:right;"> ESRRA </th>
#    <th style="text-align:right;"> ESRRB </th>
#    <th style="text-align:right;"> ETS1 </th>
#    <th style="text-align:right;"> ETS2 </th>
#    <th style="text-align:right;"> ETV1 </th>
#    <th style="text-align:right;"> ETV5 </th>
#    <th style="text-align:right;"> ETV6 </th>
#    <th style="text-align:right;"> EWSR1 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> FIP1L1 </th>
#    <th style="text-align:right;"> FOSL1 </th>
#    <th style="text-align:right;"> FOXA1 </th>
#    <th style="text-align:right;"> FOXA3 </th>
#    <th style="text-align:right;"> FOXJ2 </th>
#    <th style="text-align:right;"> FOXJ3 </th>
#    <th style="text-align:right;"> FOXK1 </th>
#    <th style="text-align:right;"> FOXK2 </th>
#    <th style="text-align:right;"> FOXM1 </th>
#    <th style="text-align:right;"> FOXO4 </th>
#    <th style="text-align:right;"> FOXP1 </th>
#    <th style="text-align:right;"> FOXP4 </th>
#    <th style="text-align:right;"> FUS </th>
#    <th style="text-align:right;"> GABPA </th>
#    <th style="text-align:right;"> GABPB1 </th>
#    <th style="text-align:right;"> GABPB2 </th>
#    <th style="text-align:right;"> GATA1 </th>
#    <th style="text-align:right;"> GATA2 </th>
#    <th style="text-align:right;"> GATAD2A </th>
#    <th style="text-align:right;"> GATAD2B </th>
#    <th style="text-align:right;"> GMEB1 </th>
#    <th style="text-align:right;"> GTF2A2 </th>
#    <th style="text-align:right;"> GTF2E2 </th>
#    <th style="text-align:right;"> GTF2F1 </th>
#    <th style="text-align:right;"> GTF2I </th>
#    <th style="text-align:right;"> HBP1 </th>
#    <th style="text-align:right;"> HCFC1 </th>
#    <th style="text-align:right;"> HDAC1 </th>
#    <th style="text-align:right;"> HDAC2 </th>
#    <th style="text-align:right;"> HDAC3 </th>
#    <th style="text-align:right;"> HDAC6 </th>
#    <th style="text-align:right;"> HDAC8 </th>
#    <th style="text-align:right;"> HDGF </th>
#    <th style="text-align:right;"> HES1 </th>
#    <th style="text-align:right;"> HEY1 </th>
#    <th style="text-align:right;"> HINFP </th>
#    <th style="text-align:right;"> HIVEP1 </th>
#    <th style="text-align:right;"> HLTF </th>
#    <th style="text-align:right;"> HMBOX1 </th>
#    <th style="text-align:right;"> HMG20A </th>
#    <th style="text-align:right;"> HMG20B </th>
#    <th style="text-align:right;"> HMGXB4 </th>
#    <th style="text-align:right;"> HNRNPH1 </th>
#    <th style="text-align:right;"> HNRNPK </th>
#    <th style="text-align:right;"> HNRNPL </th>
#    <th style="text-align:right;"> HNRNPLL </th>
#    <th style="text-align:right;"> HNRNPUL1 </th>
#    <th style="text-align:right;"> HOMEZ </th>
#    <th style="text-align:right;"> HOXB6 </th>
#    <th style="text-align:right;"> HSF4 </th>
#    <th style="text-align:right;"> ID3 </th>
#    <th style="text-align:right;"> IFI16 </th>
#    <th style="text-align:right;"> IKZF1 </th>
#    <th style="text-align:right;"> ILF3 </th>
#    <th style="text-align:right;"> ILK </th>
#    <

# %% [markdown]
# ## Arrange matrix

# %%
dat = mat_region_score_import
dat = dat %>% dplyr::select(-Chrom, -ChromStart, -ChromEnd) %>% column_to_rownames("Region")
mat_region_score = dat
head(dat, 3)
# Out:
#                          H2AFZ      H3K27ac  H3K27me3  H3K36me3  H3K4me1
# chr1:100028014-100029653 0.93242936 1.202217 0.3674175 1.1781314 1.510638
# chr1:100036895-100039189 2.89957396 3.910099 0.4091536 1.1978119 1.069881
# chr1:100046252-100046533 0.04290946 1.091537 0.4388560 0.5386822 2.148905
#                          H3K4me2   H3K4me3   H3K79me2  H3K9ac   H3K9me1   ⋯
# chr1:100028014-100029653 0.6818927 0.5918414 0.3212089 1.029037 0.8262739 ⋯
# chr1:100036895-100039189 4.9478111 5.5219678 4.1772959 4.663171 0.9431997 ⋯
# chr1:100046252-100046533 1.2418524 1.1294906 3.5795422 1.101003 1.6372764 ⋯
#                          ZNF84     ZSCAN29   ZSCAN32   ZZZ3     ASTARR
# chr1:100028014-100029653 1.0330670 0.9713258 0.8083307 1.123223 -0.2125505
# chr1:100036895-100039189 1.1498056 1.2491389 1.0451144 1.033166  1.7130117
# chr1:100046252-100046533 0.7301539 1.1432014 1.1482769 1.394350 -1.6867521
#                          CRISPRi-Growth CRISPRi-HCRFF LMPRA    TMPRA WSTARR
# chr1:100028014-100029653 -0.21446960    0             0.000000 0     -0.7757209
# chr1:100036895-100039189 -0.05130039    0             1.832751 0      2.2235590
# chr1:100046252-100046533  0.00000000    0             0.000000 0     -1.2221295

# %%
TXT_REGION = "Enhancer"
lst = lst_mgr_region
mgr = lst[[TXT_REGION]]

# %%
###
dat  = mat_region_score
vec1 = focal(mgr)$Region
vec2 = matched(mgr)$Region
dat1 = dat[vec1,]
dat2 = dat[vec2,]

###
dat1$Group = "1"
dat2$Group = "0"
dat = bind_rows(dat1, dat2)

###
dat_region_test = dat

# %% [markdown]
# **Check**

# %%
print(length(vec1))
head(vec1)
# Out:
# [1] 11623
# [1] "chr1:778233-779389"   "chr1:1005094-1005553" "chr1:1059012-1060137"
# [4] "chr1:1063762-1064534" "chr1:1068587-1070616" "chr1:1074035-1074340"

# %%
print(length(vec2))
head(vec2)
# Out:
# [1] 11623
# [1] "chr1:146376367-146377638" "chr10:21527109-21527648"
# [3] "chr3:156558321-156558682" "chr22:21886332-21886665"
# [5] "chr16:20763457-20764787"  "chr5:36301966-36302190"

# %%
head(dat1, 3)
# Out:
#                      H2AFZ    H3K27ac  H3K27me3  H3K36me3  H3K4me1  H3K4me2
# chr1:778233-779389   3.119901 3.174314 0.3924389 0.8656374 1.147726 3.991318
# chr1:1005094-1005553 3.438144 2.732050 0.7029624 0.8834022 4.350516 3.552869
# chr1:1059012-1060137 3.412964 2.001709 0.5427736 0.5882644 3.544633 4.583453
#                      H3K4me3  H3K79me2  H3K9ac   H3K9me1   ⋯ ZSCAN29   ZSCAN32
# chr1:778233-779389   4.828437 2.3029331 3.739369 0.2727375 ⋯ 1.1128336 1.107500
# chr1:1005094-1005553 2.151709 1.0138052 3.428329 1.6947420 ⋯ 0.9898965 1.163557
# chr1:1059012-1060137 4.541304 0.5914832 3.482864 0.8757203 ⋯ 1.1985727 1.107239
#                      ZZZ3      ASTARR     CRISPRi-Growth CRISPRi-HCRFF
# chr1:778233-779389   0.9739852  2.4204654  0.4510784     0
# chr1:1005094-1005553 1.0055365  0.5628854 -0.8168504     0
# chr1:1059012-1060137 0.8638441 -1.3703678  1.9579930     0
#                      LMPRA      TMPRA WSTARR    Group
# chr1:778233-779389    2.3941532 0     2.8731011 1
# chr1:1005094-1005553 -1.0360586 0     0.7210513 1
# chr1:1059012-1060137  0.1040286 0     1.3035854 1

# %%
head(dat2, 3)
# Out:
#                          H2AFZ    H3K27ac  H3K27me3  H3K36me3  H3K4me1
# chr1:146376367-146377638 1.377113 1.771163 0.2598532 0.1757564 0.6468336
# chr10:21527109-21527648  2.081537 4.020511 0.2693953 0.4927367 2.0919334
# chr3:156558321-156558682 2.486163 2.066957 0.5363727 0.5584420 1.7250715
#                          H3K4me2  H3K4me3  H3K79me2   H3K9ac   H3K9me1   ⋯
# chr1:146376367-146377638 2.302070 1.569201 0.07678236 1.601435 0.2587661 ⋯
# chr10:21527109-21527648  3.411396 4.343417 1.88516434 4.162242 0.4562857 ⋯
# chr3:156558321-156558682 2.725761 1.289639 0.85525700 1.423748 0.6986443 ⋯
#                          ZSCAN29  ZSCAN32  ZZZ3     ASTARR     CRISPRi-Growth
# chr1:146376367-146377638 1.946551 2.664826 1.107922  0.1166369  0.0000000
# chr10:21527109-21527648  1.284399 1.632059 0.720837 -1.3812972 -1.1686188
# chr3:156558321-156558682 1.193586 1.510972 1.058123  0.5976030 -0.5075313
#                          CRISPRi-HCRFF LMPRA      TMPRA WSTARR     Group
# chr1:146376367-146377638 0              0.3349787 0     -0.9020080 0
# chr10:21527109-21527648  0              0.0000000 0     -0.4351921 0
# chr3:156558321-156558682 0             -0.6893715 0     -0.2003839 0

# %% [markdown]
# ## Test 02: permutation

# %% [markdown]
# **Test single feature**

# %%
txt_feature = "H3K27ac"

dat = dat_region_test
vec = c(txt_feature, "Group")
dat = dat[, vec]
colnames(dat) = c("Score", "Group")
head(dat, 3)
# Out:
#                      Score    Group
# chr1:778233-779389   3.174314 1
# chr1:1005094-1005553 2.732050 1
# chr1:1059012-1060137 2.001709 1

# %%
table(dat$Group)
# Out:
#     0     1
# 11623 11623

# %%
boxplot(Score ~ Group, data = dat, main = "Group Comparison")
# Out:
# Plot with title “Group Comparison”

# %%
txt_feature = "H3K27ac"

dat = dat_region_test
vec = c(txt_feature, "Group")
dat = dat[, vec]
colnames(dat) = c("Score", "Group")

dat = dat %>% 
    dplyr::group_by(Group) %>% 
    dplyr::summarise(
        Mean   = mean(Score, na.rm = TRUE),
        Median = median(Score, na.rm = TRUE),
        SD     = sd(Score, na.rm = TRUE),
        Min    = min(Score, na.rm = TRUE),
        Max    = max(Score, na.rm = TRUE),
        N      = dplyr::n()
    ) %>%
    dplyr::ungroup()
dat
# Out:
#   Group Mean     Median   SD        Min        Max      N
# 1 0     1.527164 1.199317 0.9801431 0.00000000 4.995055 11623
# 2 1     1.915533 1.766116 1.0567417 0.04174945 5.198148 11623

# %%
txt_feature = "H3K27ac"

dat = dat_region_test
vec = c(txt_feature, "Group")
dat = dat[, vec]
colnames(dat) = c("Score", "Group")

# Perform a permutation test
num_iter = 10000
dat = dat %>% dplyr::mutate(Group = factor(Group, levels = c("1", "0")))
res_perm = coin::oneway_test(
    Score ~ Group, 
    data = dat, 
    #distribution = "asymptotic"
    distribution = approximate(nresample = num_iter)
)

# Print results
print(res_perm)
# Out:
# 	Approximative Two-Sample Fisher-Pitman Permutation Test
#
# data:  Score by Group (1, 0)
# Z = 28.537, p-value < 1e-04
# alternative hypothesis: true mu is not equal to 0

# %%
slotNames(res_perm)
# Out:
# [1] "parameter"    "nullvalue"    "distribution" "statistic"    "estimates"
# [6] "method"       "call"

# %%
res_perm@parameter
# Out:
# [1] "mu"

# %%
res_perm@nullvalue
# Out:
# [1] 0

# %%
coin::statistic(res_perm)
# Out:
# [1] 28.53716

# %%
coin::pvalue(res_perm)
# Out:
# [1] <1e-04
# 99 percent confidence interval:
#  0.0000000000 0.0005296914

# %% [markdown]
# **Test multiple features**

# %%
vec_txt_feature = c("CTCF", "SMC3", "RAD21", "POLR2A", "EP300", "EZH2", "REST", "SIN3A",
        'H3K27ac', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K27me3')
vec = c(vec_txt_feature, "Group")

###
dat = dat_region_test
dat = dat[, vec]

head(dat, 3)
# Out:
#                      CTCF     SMC3     RAD21    POLR2A   EP300    EZH2
# chr1:778233-779389   4.309758 2.598127 3.221405 3.330303 2.371818 0.9039206
# chr1:1005094-1005553 1.371173 1.723502 1.391699 2.181314 3.111601 0.8988608
# chr1:1059012-1060137 3.294059 2.553102 2.415877 2.548222 2.160388 1.0704168
#                      REST     SIN3A    H3K27ac  H3K4me1  H3K4me2  H3K4me3
# chr1:778233-779389   1.735252 2.434528 3.174314 1.147726 3.991318 4.828437
# chr1:1005094-1005553 1.580308 1.285878 2.732050 4.350516 3.552869 2.151709
# chr1:1059012-1060137 1.486999 2.647620 2.001709 3.544633 4.583453 4.541304
#                      H3K27me3  Group
# chr1:778233-779389   0.3924389 1
# chr1:1005094-1005553 0.7029624 1
# chr1:1059012-1060137 0.5427736 1

# %%
num_iter = 10000

lst = lapply(vec_txt_feature, function(txt_feature){
    ### select the feature and group lable
    dat = dat_region_test
    vec = c(txt_feature, "Group")
    dat = dat[, vec]
    colnames(dat) = c("Score", "Group")

    ### perform a permutation test
    dat = dat %>% dplyr::mutate(Group = factor(Group, levels = c("1", "0")))
    res = coin::oneway_test(
        Score ~ Group, 
        data = dat, 
        distribution = approximate(nresample = num_iter)
    )

    return(res)
})
names(lst) = vec_txt_feature

lst_fit_object = lst

# %%
lst = lst_fit_object
lst = lapply(lst, function(fit){
    res = c(
        coin::statistic(fit), 
        coin::pvalue(fit) 
    )
    names(res) = c("Stat", "Pval")
    return(res)
})
dat = bind_rows(lst, .id = "Feature")
dat = dat %>% dplyr::mutate(Group = "Enhancer")

dat_fit_summary = dat
dat
# Out:
#    Feature  Stat       Pval   Group
# 1  CTCF     -21.421628 0.0000 Enhancer
# 2  SMC3     -17.135447 0.0000 Enhancer
# 3  RAD21    -15.721149 0.0000 Enhancer
# 4  POLR2A     7.558232 0.0000 Enhancer
# 5  EP300     39.380426 0.0000 Enhancer
# 6  EZH2       6.965439 0.0000 Enhancer
# 7  REST       9.473358 0.0000 Enhancer
# 8  SIN3A    -13.953094 0.0000 Enhancer
# 9  H3K27ac   28.537164 0.0000 Enhancer
# 10 H3K4me1   22.520019 0.0000 Enhancer
# 11 H3K4me2   28.681501 0.0000 Enhancer
# 12 H3K4me3    0.752021 0.4602 Enhancer
# 13 H3K27me3  -2.765306 0.0064 Enhancer

# %%
vec_num_breaks = seq(-40, 40, by = 0.1)

vec = brewer.pal(n = 7, name = "RdBu")
vec = colorRampPalette(rev(vec))(length(vec_num_breaks))
vec_txt_colors = vec

# %%
dat = dat_fit_summary
dat = dat %>% 
    dplyr::select(Group, Feature, Stat) %>% 
    tidyr::spread(Feature, Stat) %>%
    column_to_rownames("Group")
dat
# Out:
#          CTCF      EP300    EZH2     H3K27ac  H3K27me3  H3K4me1  H3K4me2
# Enhancer -21.42163 39.38043 6.965439 28.53716 -2.765306 22.52002 28.6815
#          H3K4me3  POLR2A   RAD21     REST     SIN3A     SMC3
# Enhancer 0.752021 7.558232 -15.72115 9.473358 -13.95309 -17.13545

# %%
options(repr.plot.height = 3, repr.plot.width=10)
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %% [markdown]
# **Test all features**

# %%
dat = mat_region_score
fun_display_table(head(dat, 3))
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;">   </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID3B </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ASH1L </th>
#    <th style="text-align:right;"> ATF1 </th>
#    <th style="text-align:right;"> ATF2 </th>
#    <th style="text-align:right;"> ATF3 </th>
#    <th style="text-align:right;"> ATF4 </th>
#    <th style="text-align:right;"> ATF6 </th>
#    <th style="text-align:right;"> ATF7 </th>
#    <th style="text-align:right;"> BACH1 </th>
#    <th style="text-align:right;"> BCL6 </th>
#    <th style="text-align:right;"> BCLAF1 </th>
#    <th style="text-align:right;"> BCOR </th>
#    <th style="text-align:right;"> BDP1 </th>
#    <th style="text-align:right;"> BHLHE40 </th>
#    <th style="text-align:right;"> BMI1 </th>
#    <th style="text-align:right;"> BRCA1 </th>
#    <th style="text-align:right;"> BRD4 </th>
#    <th style="text-align:right;"> BRD9 </th>
#    <th style="text-align:right;"> BRF2 </th>
#    <th style="text-align:right;"> C11orf30 </th>
#    <th style="text-align:right;"> CAMTA2 </th>
#    <th style="text-align:right;"> CBFA2T2 </th>
#    <th style="text-align:right;"> CBFA2T3 </th>
#    <th style="text-align:right;"> CBFB </th>
#    <th style="text-align:right;"> CBX1 </th>
#    <th style="text-align:right;"> CBX2 </th>
#    <th style="text-align:right;"> CBX3 </th>
#    <th style="text-align:right;"> CBX5 </th>
#    <th style="text-align:right;"> CC2D1A </th>
#    <th style="text-align:right;"> CCAR2 </th>
#    <th style="text-align:right;"> CDC5L </th>
#    <th style="text-align:right;"> CEBPB </th>
#    <th style="text-align:right;"> CEBPG </th>
#    <th style="text-align:right;"> CEBPZ </th>
#    <th style="text-align:right;"> CGGBP1 </th>
#    <th style="text-align:right;"> CHAMP1 </th>
#    <th style="text-align:right;"> CHCHD3 </th>
#    <th style="text-align:right;"> CHD1 </th>
#    <th style="text-align:right;"> CHD2 </th>
#    <th style="text-align:right;"> CHD4 </th>
#    <th style="text-align:right;"> CHD7 </th>
#    <th style="text-align:right;"> CLOCK </th>
#    <th style="text-align:right;"> COPS2 </th>
#    <th style="text-align:right;"> CREB1 </th>
#    <th style="text-align:right;"> CREB3 </th>
#    <th style="text-align:right;"> CREB3L1 </th>
#    <th style="text-align:right;"> CREB5 </th>
#    <th style="text-align:right;"> CREBBP </th>
#    <th style="text-align:right;"> CREM </th>
#    <th style="text-align:right;"> CSDE1 </th>
#    <th style="text-align:right;"> CTBP1 </th>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> CTCFL </th>
#    <th style="text-align:right;"> CUX1 </th>
#    <th style="text-align:right;"> CXXC5 </th>
#    <th style="text-align:right;"> DACH1 </th>
#    <th style="text-align:right;"> DDIT3 </th>
#    <th style="text-align:right;"> DDX20 </th>
#    <th style="text-align:right;"> DEAF1 </th>
#    <th style="text-align:right;"> DIDO1 </th>
#    <th style="text-align:right;"> DLX4 </th>
#    <th style="text-align:right;"> DMBX1 </th>
#    <th style="text-align:right;"> DMTF1 </th>
#    <th style="text-align:right;"> DNMT1 </th>
#    <th style="text-align:right;"> DPF2 </th>
#    <th style="text-align:right;"> E2F1 </th>
#    <th style="text-align:right;"> E2F3 </th>
#    <th style="text-align:right;"> E2F4 </th>
#    <th style="text-align:right;"> E2F5 </th>
#    <th style="text-align:right;"> E2F6 </th>
#    <th style="text-align:right;"> E2F7 </th>
#    <th style="text-align:right;"> E2F8 </th>
#    <th style="text-align:right;"> E4F1 </th>
#    <th style="text-align:right;"> EGR1 </th>
#    <th style="text-align:right;"> EHMT2 </th>
#    <th style="text-align:right;"> ELF1 </th>
#    <th style="text-align:right;"> ELF2 </th>
#    <th style="text-align:right;"> ELF4 </th>
#    <th style="text-align:right;"> ELK1 </th>
#    <th style="text-align:right;"> ELK3 </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> EP400 </th>
#    <th style="text-align:right;"> ERF </th>
#    <th style="text-align:right;"> ESRRA </th>
#    <th style="text-align:right;"> ESRRB </th>
#    <th style="text-align:right;"> ETS1 </th>
#    <th style="text-align:right;"> ETS2 </th>
#    <th style="text-align:right;"> ETV1 </th>
#    <th style="text-align:right;"> ETV5 </th>
#    <th style="text-align:right;"> ETV6 </th>
#    <th style="text-align:right;"> EWSR1 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> FIP1L1 </th>
#    <th style="text-align:right;"> FOSL1 </th>
#    <th style="text-align:right;"> FOXA1 </th>
#    <th style="text-align:right;"> FOXA3 </th>
#    <th style="text-align:right;"> FOXJ2 </th>
#    <th style="text-align:right;"> FOXJ3 </th>
#    <th style="text-align:right;"> FOXK1 </th>
#    <th style="text-align:right;"> FOXK2 </th>
#    <th style="text-align:right;"> FOXM1 </th>
#    <th style="text-align:right;"> FOXO4 </th>
#    <th style="text-align:right;"> FOXP1 </th>
#    <th style="text-align:right;"> FOXP4 </th>
#    <th style="text-align:right;"> FUS </th>
#    <th style="text-align:right;"> GABPA </th>
#    <th style="text-align:right;"> GABPB1 </th>
#    <th style="text-align:right;"> GABPB2 </th>
#    <th style="text-align:right;"> GATA1 </th>
#    <th style="text-align:right;"> GATA2 </th>
#    <th style="text-align:right;"> GATAD2A </th>
#    <th style="text-align:right;"> GATAD2B </th>
#    <th style="text-align:right;"> GMEB1 </th>
#    <th style="text-align:right;"> GTF2A2 </th>
#    <th style="text-align:right;"> GTF2E2 </th>
#    <th style="text-align:right;"> GTF2F1 </th>
#    <th style="text-align:right;"> GTF2I </th>
#    <th style="text-align:right;"> HBP1 </th>
#    <th style="text-align:right;"> HCFC1 </th>
#    <th style="text-align:right;"> HDAC1 </th>
#    <th style="text-align:right;"> HDAC2 </th>
#    <th style="text-align:right;"> HDAC3 </th>
#    <th style="text-align:right;"> HDAC6 </th>
#    <th style="text-align:right;"> HDAC8 </th>
#    <th style="text-align:right;"> HDGF </th>
#    <th style="text-align:right;"> HES1 </th>
#    <th style="text-align:right;"> HEY1 </th>
#    <th style="text-align:right;"> HINFP </th>
#    <th style="text-align:right;"> HIVEP1 </th>
#    <th style="text-align:right;"> HLTF </th>
#    <th style="text-align:right;"> HMBOX1 </th>
#    <th style="text-align:right;"> HMG20A </th>
#    <th style="text-align:right;"> HMG20B </th>
#    <th style="text-align:right;"> HMGXB4 </th>
#    <th style="text-align:right;"> HNRNPH1 </th>
#    <th style="text-align:right;"> HNRNPK </th>
#    <th style="text-align:right;"> HNRNPL </th>
#    <th style="text-align:right;"> HNRNPLL </th>
#    <th style="text-align:right;"> HNRNPUL1 </th>
#    <th style="text-align:right;"> HOMEZ </th>
#    <th style="text-align:right;"> HOXB6 </th>
#    <th style="text-align:right;"> HSF4 </th>
#    <th style="text-align:right;"> ID3 </th>
#    <th style="text-align:right;"> IFI16 </th>
#    <th style="text-align:right;"> IKZF1 </th>
#    <th style="text-align:right;"> ILF3 </th>
#    <th style="text-align:right;"> ILK </th>
#    <th style="text-align:right;"> IRF1 </th>
#    <th style="text-align:right;"> IRF2 </th>
#    <th style="text-align:right;"> IRF9 </th>
#    <th style="text-

# %%
dat = dat_region_test
fun_display_table(head(dat, 3))
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;">   </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID3B </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ASH1L </th>
#    <th style="text-align:right;"> ATF1 </th>
#    <th style="text-align:right;"> ATF2 </th>
#    <th style="text-align:right;"> ATF3 </th>
#    <th style="text-align:right;"> ATF4 </th>
#    <th style="text-align:right;"> ATF6 </th>
#    <th style="text-align:right;"> ATF7 </th>
#    <th style="text-align:right;"> BACH1 </th>
#    <th style="text-align:right;"> BCL6 </th>
#    <th style="text-align:right;"> BCLAF1 </th>
#    <th style="text-align:right;"> BCOR </th>
#    <th style="text-align:right;"> BDP1 </th>
#    <th style="text-align:right;"> BHLHE40 </th>
#    <th style="text-align:right;"> BMI1 </th>
#    <th style="text-align:right;"> BRCA1 </th>
#    <th style="text-align:right;"> BRD4 </th>
#    <th style="text-align:right;"> BRD9 </th>
#    <th style="text-align:right;"> BRF2 </th>
#    <th style="text-align:right;"> C11orf30 </th>
#    <th style="text-align:right;"> CAMTA2 </th>
#    <th style="text-align:right;"> CBFA2T2 </th>
#    <th style="text-align:right;"> CBFA2T3 </th>
#    <th style="text-align:right;"> CBFB </th>
#    <th style="text-align:right;"> CBX1 </th>
#    <th style="text-align:right;"> CBX2 </th>
#    <th style="text-align:right;"> CBX3 </th>
#    <th style="text-align:right;"> CBX5 </th>
#    <th style="text-align:right;"> CC2D1A </th>
#    <th style="text-align:right;"> CCAR2 </th>
#    <th style="text-align:right;"> CDC5L </th>
#    <th style="text-align:right;"> CEBPB </th>
#    <th style="text-align:right;"> CEBPG </th>
#    <th style="text-align:right;"> CEBPZ </th>
#    <th style="text-align:right;"> CGGBP1 </th>
#    <th style="text-align:right;"> CHAMP1 </th>
#    <th style="text-align:right;"> CHCHD3 </th>
#    <th style="text-align:right;"> CHD1 </th>
#    <th style="text-align:right;"> CHD2 </th>
#    <th style="text-align:right;"> CHD4 </th>
#    <th style="text-align:right;"> CHD7 </th>
#    <th style="text-align:right;"> CLOCK </th>
#    <th style="text-align:right;"> COPS2 </th>
#    <th style="text-align:right;"> CREB1 </th>
#    <th style="text-align:right;"> CREB3 </th>
#    <th style="text-align:right;"> CREB3L1 </th>
#    <th style="text-align:right;"> CREB5 </th>
#    <th style="text-align:right;"> CREBBP </th>
#    <th style="text-align:right;"> CREM </th>
#    <th style="text-align:right;"> CSDE1 </th>
#    <th style="text-align:right;"> CTBP1 </th>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> CTCFL </th>
#    <th style="text-align:right;"> CUX1 </th>
#    <th style="text-align:right;"> CXXC5 </th>
#    <th style="text-align:right;"> DACH1 </th>
#    <th style="text-align:right;"> DDIT3 </th>
#    <th style="text-align:right;"> DDX20 </th>
#    <th style="text-align:right;"> DEAF1 </th>
#    <th style="text-align:right;"> DIDO1 </th>
#    <th style="text-align:right;"> DLX4 </th>
#    <th style="text-align:right;"> DMBX1 </th>
#    <th style="text-align:right;"> DMTF1 </th>
#    <th style="text-align:right;"> DNMT1 </th>
#    <th style="text-align:right;"> DPF2 </th>
#    <th style="text-align:right;"> E2F1 </th>
#    <th style="text-align:right;"> E2F3 </th>
#    <th style="text-align:right;"> E2F4 </th>
#    <th style="text-align:right;"> E2F5 </th>
#    <th style="text-align:right;"> E2F6 </th>
#    <th style="text-align:right;"> E2F7 </th>
#    <th style="text-align:right;"> E2F8 </th>
#    <th style="text-align:right;"> E4F1 </th>
#    <th style="text-align:right;"> EGR1 </th>
#    <th style="text-align:right;"> EHMT2 </th>
#    <th style="text-align:right;"> ELF1 </th>
#    <th style="text-align:right;"> ELF2 </th>
#    <th style="text-align:right;"> ELF4 </th>
#    <th style="text-align:right;"> ELK1 </th>
#    <th style="text-align:right;"> ELK3 </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> EP400 </th>
#    <th style="text-align:right;"> ERF </th>
#    <th style="text-align:right;"> ESRRA </th>
#    <th style="text-align:right;"> ESRRB </th>
#    <th style="text-align:right;"> ETS1 </th>
#    <th style="text-align:right;"> ETS2 </th>
#    <th style="text-align:right;"> ETV1 </th>
#    <th style="text-align:right;"> ETV5 </th>
#    <th style="text-align:right;"> ETV6 </th>
#    <th style="text-align:right;"> EWSR1 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> FIP1L1 </th>
#    <th style="text-align:right;"> FOSL1 </th>
#    <th style="text-align:right;"> FOXA1 </th>
#    <th style="text-align:right;"> FOXA3 </th>
#    <th style="text-align:right;"> FOXJ2 </th>
#    <th style="text-align:right;"> FOXJ3 </th>
#    <th style="text-align:right;"> FOXK1 </th>
#    <th style="text-align:right;"> FOXK2 </th>
#    <th style="text-align:right;"> FOXM1 </th>
#    <th style="text-align:right;"> FOXO4 </th>
#    <th style="text-align:right;"> FOXP1 </th>
#    <th style="text-align:right;"> FOXP4 </th>
#    <th style="text-align:right;"> FUS </th>
#    <th style="text-align:right;"> GABPA </th>
#    <th style="text-align:right;"> GABPB1 </th>
#    <th style="text-align:right;"> GABPB2 </th>
#    <th style="text-align:right;"> GATA1 </th>
#    <th style="text-align:right;"> GATA2 </th>
#    <th style="text-align:right;"> GATAD2A </th>
#    <th style="text-align:right;"> GATAD2B </th>
#    <th style="text-align:right;"> GMEB1 </th>
#    <th style="text-align:right;"> GTF2A2 </th>
#    <th style="text-align:right;"> GTF2E2 </th>
#    <th style="text-align:right;"> GTF2F1 </th>
#    <th style="text-align:right;"> GTF2I </th>
#    <th style="text-align:right;"> HBP1 </th>
#    <th style="text-align:right;"> HCFC1 </th>
#    <th style="text-align:right;"> HDAC1 </th>
#    <th style="text-align:right;"> HDAC2 </th>
#    <th style="text-align:right;"> HDAC3 </th>
#    <th style="text-align:right;"> HDAC6 </th>
#    <th style="text-align:right;"> HDAC8 </th>
#    <th style="text-align:right;"> HDGF </th>
#    <th style="text-align:right;"> HES1 </th>
#    <th style="text-align:right;"> HEY1 </th>
#    <th style="text-align:right;"> HINFP </th>
#    <th style="text-align:right;"> HIVEP1 </th>
#    <th style="text-align:right;"> HLTF </th>
#    <th style="text-align:right;"> HMBOX1 </th>
#    <th style="text-align:right;"> HMG20A </th>
#    <th style="text-align:right;"> HMG20B </th>
#    <th style="text-align:right;"> HMGXB4 </th>
#    <th style="text-align:right;"> HNRNPH1 </th>
#    <th style="text-align:right;"> HNRNPK </th>
#    <th style="text-align:right;"> HNRNPL </th>
#    <th style="text-align:right;"> HNRNPLL </th>
#    <th style="text-align:right;"> HNRNPUL1 </th>
#    <th style="text-align:right;"> HOMEZ </th>
#    <th style="text-align:right;"> HOXB6 </th>
#    <th style="text-align:right;"> HSF4 </th>
#    <th style="text-align:right;"> ID3 </th>
#    <th style="text-align:right;"> IFI16 </th>
#    <th style="text-align:right;"> IKZF1 </th>
#    <th style="text-align:right;"> ILF3 </th>
#    <th style="text-align:right;"> ILK </th>
#    <th style="text-align:right;"> IRF1 </th>
#    <th style="text-align:right;"> IRF2 </th>
#    <th style="text-align:right;"> IRF9 </th>
#    <th style="text-

# %%
dat = mat_region_score
vec = colnames(dat)

vec_txt_feature = vec

# %%
num_iter = 10000

lst = lapply(vec_txt_feature, function(txt_feature){
    ### select the feature and group lable
    dat = dat_region_test
    vec = c(txt_feature, "Group")
    dat = dat[, vec]
    colnames(dat) = c("Score", "Group")

    ### perform a permutation test
    dat = dat %>% dplyr::mutate(Group = factor(Group, levels = c("1", "0")))
    res = coin::oneway_test(
        Score ~ Group, 
        data = dat, 
        distribution = approximate(nresample = num_iter)
    )

    return(res)
})
names(lst) = vec_txt_feature

lst_fit_object = lst

# %%
TXT_REGION
# Out:
# [1] "Enhancer"

# %%
lst = lst_fit_object
lst = lapply(lst, function(fit){
    res = c(
        coin::statistic(fit), 
        coin::pvalue(fit) 
    )
    names(res) = c("Stat", "Pval")
    return(res)
})
dat = bind_rows(lst, .id = "Feature")
dat = dat %>% dplyr::mutate(Group = "Enhancer")
dat = dat %>% 
    dplyr::mutate(Score = as.numeric(scale(Stat))) %>%
    dplyr::mutate(Padj  = p.adjust(Pval, method = "BH"))

dat_fit_summary = dat
print(dim(dat))
fun_display_table(head(dat))
# Out:
# [1] 527   6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Feature </th>
#    <th style="text-align:right;"> Stat </th>
#    <th style="text-align:right;"> Pval </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:right;"> Padj </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> H2AFZ </td>
#    <td style="text-align:right;"> 35.764202 </td>
#    <td style="text-align:right;"> 0.0000 </td>
#    <td style="text-align:left;"> Enhancer </td>
#    <td style="text-align:right;"> 1.5151301 </td>
#    <td style="text-align:right;"> 0.0000000 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K27ac </td>
#    <td style="text-align:right;"> 28.537164 </td>
#    <td style="text-align:right;"> 0.0000 </td>
#    <td style="text-align:left;"> Enhancer </td>
#    <td style="text-align:right;"> 1.0337711 </td>
#    <td style="text-align:right;"> 0.0000000 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K27me3 </td>
#    <td style="text-align:right;"> -2.765306 </td>
#    <td style="text-align:right;"> 0.0052 </td>
#    <td style="text-align:left;"> Enhancer </td>
#    <td style="text-align:right;"> -1.0511393 </td>
#    <td style="text-align:right;"> 0.0059188 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K36me3 </td>
#    <td style="text-align:right;"> -14.052677 </td>
#    <td style="text-align:right;"> 0.0000 </td>
#    <td style="text-align:left;"> Enhancer </td>
#    <td style="text-align:right;"> -1.8029380 </td>
#    <td style="text-align:right;"> 0.0000000 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K4me1 </td>
#    <td style="text-align:right;"> 22.520019 </td>
#    <td style="text-align:right;"> 0.0000 </td>
#    <td style="text-align:left;"> Enhancer </td>
#    <td style="text-align:right;"> 0.6329974 </td>
#    <td style="text-align:right;"> 0.0000000 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> H3K4me2 </td>
#    <td style="text-align:right;"> 28.681501 </td>
#    <td style="text-align:right;"> 0.0000 </td>
#    <td style="text-align:left;"> Enhancer </td>
#    <td style="text-align:right;"> 1.0433847 </td>
#    <td style="text-align:right;"> 0.0000000 </td>
#   </tr>
# </tbody>
# </table>

# %%
dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Stat)) + 
    geom_histogram(binwidth = 1) +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Stat)) + 
    geom_density() +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Score)) + 
    geom_histogram(binwidth = 0.1) +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)
# Out:
# plot without title

# %%
dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Score)) + 
    geom_density() +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)
# Out:
# plot without title

# %%
vec_txt_feature_subset = c(
    "CTCF", "SMC3", "RAD21", "POLR2A", "EP300", "EZH2", "REST", "SIN3A",
    'H3K27ac', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K27me3')

# %%
dat = dat_fit_summary
dat = dat %>% dplyr::filter(Feature %in% vec_txt_feature_subset)

dat = dat %>% 
    dplyr::select(Group, Feature, Score) %>% 
    tidyr::spread(Feature, Score) %>%
    column_to_rownames("Group")
dat
# Out:
#          CTCF      EP300   EZH2       H3K27ac  H3K27me3  H3K4me1   H3K4me2
# Enhancer -2.293749 1.75599 -0.4030201 1.033771 -1.051139 0.6329974 1.043385
#          H3K4me3    POLR2A    RAD21     REST       SIN3A     SMC3
# Enhancer -0.8168667 -0.363537 -1.914067 -0.2359795 -1.796305 -2.008267

# %%
vec_num_breaks = seq(-2.5, 2.5, by = 0.1)

vec = brewer.pal(n = 7, name = "RdBu")
vec = colorRampPalette(rev(vec))(length(vec_num_breaks))
vec_txt_colors = vec

# %%
options(repr.plot.height = 3, repr.plot.width=10)
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %%
vec_txt_feature_subset = c(
    "CTCF", "SMC3", "POLR2A", "EP300", "REST", "SIN3A",
    'H3K27ac', 'H3K4me3', 'H3K27me3')

# %%
dat = dat_fit_summary
tmp = dat %>% dplyr::filter(Feature %in% vec_txt_feature_subset)
vec = tmp$Score

dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Score)) + 
    geom_density() +
    geom_vline(xintercept = vec) +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)
# Out:
# plot without title

# %%
txt_feature = "SMC3"

dat = dat_fit_summary
tmp = dat %>% dplyr::filter(Feature == txt_feature)
vec = tmp$Score

dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Score)) + 
    geom_density() +
    geom_vline(xintercept = vec) +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)

# %%
txt_feature = "EP300"

dat = dat_fit_summary
tmp = dat %>% dplyr::filter(Feature == txt_feature)
vec = tmp$Score

dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Score)) + 
    geom_density() +
    geom_vline(xintercept = vec) +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)
# Out:
# plot without title

# %%
txt_feature = "REST"

dat = dat_fit_summary
tmp = dat %>% dplyr::filter(Feature == txt_feature)
vec = tmp$Score

dat = dat_fit_summary
gpt = ggplot(dat, aes(x=Score)) + 
    geom_density() +
    geom_vline(xintercept = vec) +
    theme_cowplot()

options(repr.plot.height = 3, repr.plot.width=10)
print(gpt)
# Out:
# plot without title

# %%
options(repr.plot.height = 3, repr.plot.width=10)
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %%
options(repr.plot.height = 3, repr.plot.width=10)
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %%
options(repr.plot.height = 7, repr.plot.width=10)
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %%
options(repr.plot.height = 7, repr.plot.width=10)
pheatmap(
    dat,
    color  = vec_txt_colors,
    breaks = vec_num_breaks,
    cluster_rows = FALSE,
    cluster_cols = FALSE
)
# Out:
# plot without title

# %% [markdown]
# **Test multiple groups**

# %% [markdown]
# **Test all features**

# %% [markdown]
# ## Test 01: wilcoxon

# %%
dat = mat_region_score
vec = colnames(dat)
vec_txt_feature = vec
print(length(vec))
head(vec)
# Out:
# [1] 527
# [1] "H2AFZ"    "H3K27ac"  "H3K27me3" "H3K36me3" "H3K4me1"  "H3K4me2"

# %%
dat = dat_region_test
head(dat)
# Out:
#                      H2AFZ    H3K27ac   H3K27me3  H3K36me3  H3K4me1  H3K4me2
# chr1:778233-779389   3.119901 3.1743137 0.3924389 0.8656374 1.147726 3.991318
# chr1:1005094-1005553 3.438144 2.7320499 0.7029624 0.8834022 4.350516 3.552869
# chr1:1059012-1060137 3.412964 2.0017086 0.5427736 0.5882644 3.544633 4.583453
# chr1:1063762-1064534 3.447951 2.8408016 0.6292573 0.6806340 5.056598 4.521692
# chr1:1068587-1070616 2.709948 1.4134804 0.7641916 0.3919453 4.037739 3.249180
# chr1:1074035-1074340 1.809431 0.7191773 1.3117705 0.2573269 3.537305 1.518505
#                      H3K4me3  H3K79me2  H3K9ac   H3K9me1   ⋯ ZSCAN29
# chr1:778233-779389   4.828437 2.3029331 3.739369 0.2727375 ⋯ 1.1128336
# chr1:1005094-1005553 2.151709 1.0138052 3.428329 1.6947420 ⋯ 0.9898965
# chr1:1059012-1060137 4.541304 0.5914832 3.482864 0.8757203 ⋯ 1.1985727
# chr1:1063762-1064534 2.977221 1.0200861 3.322137 1.5649195 ⋯ 1.2727906
# chr1:1068587-1070616 3.563758 0.6067776 2.561677 1.0973411 ⋯ 0.9900378
# chr1:1074035-1074340 1.114998 0.4370924 1.743834 1.3883108 ⋯ 1.4825411
#                      ZSCAN32   ZZZ3      ASTARR     CRISPRi-Growth
# chr1:778233-779389   1.1075004 0.9739852  2.4204654  0.4510784
# chr1:1005094-1005553 1.1635567 1.0055365  0.5628854 -0.8168504
# chr1:1059012-1060137 1.1072393 0.8638441 -1.3703678  1.9579930
# chr1:1063762-1064534 1.1492984 0.7674039  1.7621120 -0.3972930
# chr1:1068587-1070616 1.1439027 0.5928746 -0.9119512  0.9917410
# chr1:1074035-1074340 0.6770057 0.5781707 -1.2686317  0.0000000
#                      CRISPRi-HCRFF LMPRA      TMPRA WSTARR    Label_Group
# chr1:778233-779389   0              2.3941532 0     2.8731011 1
# chr1:1005094-1005553 0             -1.0360586 0     0.7210513 1
# chr1:1059012-1060137 0              0.1040286 0     1.3035854 1
# chr1:1063762-1064534 0              0.2360001 0     2.5947463 1
# chr1:1068587-1070616 0              1.7929497 0     0.8088649 1
# chr1:1074035-1074340 0              1.1027177 0     1.0730384 1

# %%
txt_feature = vec_txt_feature[1]

dat = dat_region_test
vec = c(txt_feature, "Label_Group")
head(dat)
# Out:
#                      H2AFZ    H3K27ac   H3K27me3  H3K36me3  H3K4me1  H3K4me2
# chr1:778233-779389   3.119901 3.1743137 0.3924389 0.8656374 1.147726 3.991318
# chr1:1005094-1005553 3.438144 2.7320499 0.7029624 0.8834022 4.350516 3.552869
# chr1:1059012-1060137 3.412964 2.0017086 0.5427736 0.5882644 3.544633 4.583453
# chr1:1063762-1064534 3.447951 2.8408016 0.6292573 0.6806340 5.056598 4.521692
# chr1:1068587-1070616 2.709948 1.4134804 0.7641916 0.3919453 4.037739 3.249180
# chr1:1074035-1074340 1.809431 0.7191773 1.3117705 0.2573269 3.537305 1.518505
#                      H3K4me3  H3K79me2  H3K9ac   H3K9me1   ⋯ ZSCAN29
# chr1:778233-779389   4.828437 2.3029331 3.739369 0.2727375 ⋯ 1.1128336
# chr1:1005094-1005553 2.151709 1.0138052 3.428329 1.6947420 ⋯ 0.9898965
# chr1:1059012-1060137 4.541304 0.5914832 3.482864 0.8757203 ⋯ 1.1985727
# chr1:1063762-1064534 2.977221 1.0200861 3.322137 1.5649195 ⋯ 1.2727906
# chr1:1068587-1070616 3.563758 0.6067776 2.561677 1.0973411 ⋯ 0.9900378
# chr1:1074035-1074340 1.114998 0.4370924 1.743834 1.3883108 ⋯ 1.4825411
#                      ZSCAN32   ZZZ3      ASTARR     CRISPRi-Growth
# chr1:778233-779389   1.1075004 0.9739852  2.4204654  0.4510784
# chr1:1005094-1005553 1.1635567 1.0055365  0.5628854 -0.8168504
# chr1:1059012-1060137 1.1072393 0.8638441 -1.3703678  1.9579930
# chr1:1063762-1064534 1.1492984 0.7674039  1.7621120 -0.3972930
# chr1:1068587-1070616 1.1439027 0.5928746 -0.9119512  0.9917410
# chr1:1074035-1074340 0.6770057 0.5781707 -1.2686317  0.0000000
#                      CRISPRi-HCRFF LMPRA      TMPRA WSTARR    Label_Group
# chr1:778233-779389   0              2.3941532 0     2.8731011 1
# chr1:1005094-1005553 0             -1.0360586 0     0.7210513 1
# chr1:1059012-1060137 0              0.1040286 0     1.3035854 1
# chr1:1063762-1064534 0              0.2360001 0     2.5947463 1
# chr1:1068587-1070616 0              1.7929497 0     0.8088649 1
# chr1:1074035-1074340 0              1.1027177 0     1.0730384 1

# %%
wilcox.test(H2AFZ ~ Label_Group, data=dat)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  H2AFZ by Label_Group
# W = 49129796, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0

# %%
wilcox.test(as.formula("H2AFZ ~ Label_Group"), data=dat)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  H2AFZ by Label_Group
# W = 49129796, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0

# %%
wilcox.test(as.formula("`H2AFZ` ~ Label_Group"), data=dat)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  H2AFZ by Label_Group
# W = 49129796, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0

# %%
wilcox.test(`CRISPRi-Growth` ~ Label_Group, data = dat)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  CRISPRi-Growth by Label_Group
# W = 69395767, p-value = 0.000257
# alternative hypothesis: true location shift is not equal to 0

# %%
wilcox.test(as.formula("`CRISPRi-Growth` ~ Label_Group"), data=dat)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  CRISPRi-Growth by Label_Group
# W = 69395767, p-value = 0.000257
# alternative hypothesis: true location shift is not equal to 0

# %%
txt_feature = vec_txt_feature[1]

dat = dat_region_test
lst = split(dat[,txt_feature], dat$Label_Group)

print(head(lst[['0']]))
print(head(lst[['1']]))
# Out:
# [1] 1.377113 2.081537 2.486163 1.646688 2.806421 1.456428
# [1] 3.119901 3.438144 3.412964 3.447951 2.709948 1.809431

# %%
wilcox.test(lst[['1']], lst[['0']])
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  lst[["1"]] and lst[["0"]]
# W = 85964332, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0

# %%
txt_feature = vec_txt_feature[1]

dat = dat_region_test
txt = paste(txt_feature, "~", "Label_Group")
wilcox.test(as.formula(txt), data=dat)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  H2AFZ by Label_Group
# W = 49129796, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0

# %%
lst = lapply(vec_txt_feature, function(txt_feature){
    dat = dat_region_test
    txt = paste0("`", txt_feature, "`")
    txt = paste0(txt, "~", "Label_Group")
    fit = wilcox.test(as.formula(txt), data=dat)
    return(fit)
})
names(lst) = vec_txt_feature
lst_fit = lst

# %%
lst[[1]]
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  H2AFZ by Label_Group
# W = 49129796, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0

# %%
lst[["H2AFZ"]]
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  H2AFZ by Label_Group
# W = 49129796, p-value < 2.2e-16
# alternative hypothesis: true location shift is not equal to 0

# %%
lst[["CRISPRi-Growth"]]
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  CRISPRi-Growth by Label_Group
# W = 69395767, p-value = 0.000257
# alternative hypothesis: true location shift is not equal to 0

# %%
fit = lst[[1]]
names(fit)
# Out:
# [1] "statistic"   "parameter"   "p.value"     "null.value"  "alternative"
# [6] "method"      "data.name"

# %%
fit$p.value
# Out:
# [1] 8.079187e-284

# %%
lst = lst_fit
lst = lapply(lst, function(fit){
    vec = c(fit$statistic, fit$p.value)
    names(vec) = c("Stat", "Pval")
    return(vec)
})

dat = bind_rows(lst, .id = "Feature")
dat = dat %>% 
    dplyr::mutate(Padj = p.adjust(Pval, method="BH")) %>%
    dplyr::mutate(nLog10Padj = -log10(Padj))
head(dat)
# Out:
#   Feature  Stat     Pval          Padj          nLog10Padj
# 1 H2AFZ    49129796 8.079187e-284 1.216495e-282 281.9148898
# 2 H3K27ac  52473950 8.327434e-191 5.851410e-190 189.2327394
# 3 H3K27me3 68340320  1.209957e-01  1.298670e-01   0.8865011
# 4 H3K36me3 73381800  3.930210e-30  6.432362e-30  29.1916295
# 5 H3K4me1  55243888 8.447857e-128 3.157461e-127 126.5006619
# 6 H3K4me2  51611297 5.020381e-213 4.133970e-212 211.3836327

# %%
vec = c("CTCF", "SMC3", "RAD21", "POLR2A", "EP300", "EZH2", "REST", "SIN3A",
        'H3K27ac', 'H3K4me1', 'H3K4me2', 'H3K4me3', 'H3K27me3')

dat %>% dplyr::filter(Feature %in% vec)
# Out:
#    Feature  Stat     Pval          Padj          nLog10Padj
# 1  H3K27ac  52473950 8.327434e-191 5.851410e-190 189.2327394
# 2  H3K27me3 68340320  1.209957e-01  1.298670e-01   0.8865011
# 3  H3K4me1  55243888 8.447857e-128 3.157461e-127 126.5006619
# 4  H3K4me2  51611297 5.020381e-213 4.133970e-212 211.3836327
# 5  H3K4me3  54346600 8.106466e-147 3.620430e-146 145.4412398
# 6  CTCF     73176023  3.690221e-28  5.947237e-28  27.2256847
# 7  EP300    47919459  0.000000e+00  0.000000e+00         Inf
# 8  EZH2     62244674  3.585372e-25  5.492707e-25  24.2602136
# 9  POLR2A   59454955  2.339267e-56  4.892039e-56  55.3105101
# 10 RAD21    68943158  6.352721e-03  7.215267e-03   2.1417476
# 11 REST     59634348  5.767596e-54  1.169047e-53  52.9321679
# 12 SIN3A    70825447  1.470707e-10  1.918472e-10   9.7170445
# 13 SMC3     73538976  1.098246e-31  1.825790e-31  30.7385491

# %%
dat = dat_region_test
dat = dat[,c(vec, "Label_Group")]
dat = dat %>% 
    tidyr::gather(Feature, Score, -Label_Group) %>% 
    dplyr::mutate(Label_Group = as.character(Label_Group))
head(dat)
# Out:
#   Label_Group Feature Score
# 1 1           CTCF    4.309758
# 2 1           CTCF    1.371173
# 3 1           CTCF    3.294059
# 4 1           CTCF    5.096117
# 5 1           CTCF    1.373199
# 6 1           CTCF    1.091008

# %%
gpt = ggplot(dat, aes(x=Feature, y=Score, fill=Label_Group)) + 
    geom_violin() + 
    theme_cowplot()
options(repr.plot.height=5, repr.plot.width=15)
print(gpt)
# Out:
# plot without title

# %% [markdown]
# ## Test: bootstrap to estimate ratio

# %%
library(boot)

# %%
coin::independence_test
# Out:
# Error in loadNamespace(x): there is no package called ‘coin’
# Traceback:
#
# 1. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 2. withOneRestart(expr, restarts[[1L]])
# 3. doWithOneRestart(return(expr), restart)
# 4. stop(cond)
