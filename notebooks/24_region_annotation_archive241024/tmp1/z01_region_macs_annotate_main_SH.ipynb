# %% [raw]
# ---
# title: Region annotation 01
# subtitle: Annotate ASTARR input MACS peaks
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif

# %%
ls ${FD_RES}/region
# Out:
# encode_chipseq_flagship  fcc_astarr_csaw    hic_insitu_K562_ENCSR545YBD
# encode_chipseq_histone   fcc_astarr_macs    hic_intact_K562_deep
# encode_chipseq_subset    fcc_crispri_hcrff  hic_intact_K562_ENCSR479XDG
# encode_chromatin_states  fcc_screened       summary
# encode_open_chromatin    genome_tss

# %%
ls ${FD_RES}/region/summary
# Out:
# annotation.macs.label.region_A.tsv
# annotation.macs.label.region_B.chipseq.tsv
# annotation.macs.label.region_B.subset.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/annotation.macs.label.region_A.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/annotation.macs.label.region_B.subset.tsv

# %%
cat ${FP_REGION_LABEL_A}
# Out:
# Folder	FName	Label
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
cat ${FP_REGION_LABEL_B}
# Out:
# Folder	FName	Label
# encode_chipseq_subset	K562.hg38.ENCSR000AKP.ENCFF544LXB.ChIPseq.H3K27ac.bed.gz	encode_chipseq_H3K27ac_ENCFF544LXB
# encode_chipseq_subset	K562.hg38.ENCSR000AKQ.ENCFF323WOT.ChIPseq.H3K27me3.bed.gz	encode_chipseq_H3K27me3_ENCFF323WOT
# encode_chipseq_subset	K562.hg38.ENCSR000AKS.ENCFF135ZLM.ChIPseq.H3K4me1.bed.gz	encode_chipseq_H3K4me1_ENCFF135ZLM
# encode_chipseq_subset	K562.hg38.ENCSR000AKT.ENCFF749KLQ.ChIPseq.H3K4me2.bed.gz	encode_chipseq_H3K4me2_ENCFF749KLQ
# encode_chipseq_subset	K562.hg38.ENCSR000BMH.ENCFF398UQZ.ChIPseq.YY1.bed.gz	encode_chipseq_YY1_ENCFF398UQZ
# encode_chipseq_subset	K562.hg38.ENCSR000BMW.ENCFF707MDI.ChIPseq.REST.bed.gz	encode_chipseq_REST_ENCFF707MDI
# encode_chipseq_subset	K562.hg38.ENCSR000EFS.ENCFF190CGV.ChIPseq.JUN.bed.gz	encode_chipseq_JUN_ENCFF190CGV
# encode_chipseq_subset	K562.hg38.ENCSR000EFT.ENCFF657CTC.ChIPseq.GATA1.bed.gz	encode_chipseq_GATA1_ENCFF657CTC
# encode_chipseq_subset	K562.hg38.ENCSR000EFU.ENCFF715WGN.ChIPseq.ELK1.bed.gz	encode_chipseq_ELK1_ENCFF715WGN
# encode_chipseq_subset	K562.hg38.ENCSR000EGE.ENCFF702XPO.ChIPseq.EP300.bed.gz	encode_chipseq_EP300_ENCFF702XPO
# encode_chipseq_subset	K562.hg38.ENCSR000EGM.ENCFF660GHM.ChIPseq.CTCF.bed.gz	encode_chipseq_CTCF_ENCFF660GHM
# encode_chipseq_subset	K562.hg38.ENCSR000EHB.ENCFF852ZRK.ChIPseq.TAL1.bed.gz	encode_chipseq_TAL1_ENCFF852ZRK
# encode_chipseq_subset	K562.hg38.ENCSR004GKA.ENCFF242AOL.ChIPseq.ZEB2.bed.gz	encode_chipseq_ZEB2_ENCFF242AOL
# encode_chipseq_subset	K562.hg38.ENCSR091GVJ.ENCFF627RSK.ChIPseq.ATF1.bed.gz	encode_chipseq_ATF1_ENCFF627RSK
# encode_chipseq_subset	K562.hg38.ENCSR121SPB.ENCFF142ZTD.ChIPseq.KLF10.bed.gz	encode_chipseq_KLF10_ENCFF142ZTD
# encode_chipseq_subset	K562.hg38.ENCSR388QZF.ENCFF355MNE.ChIPseq.POLR2A.bed.gz	encode_chipseq_POLR2A_ENCFF355MNE
# encode_chipseq_subset	K562.hg38.ENCSR552YGL.ENCFF023IFO.ChIPseq.NFE2.bed.gz	encode_chipseq_NFE2_ENCFF023IFO
# encode_chipseq_subset	K562.hg38.ENCSR668LDD.ENCFF885FQN.ChIPseq.H3K4me3.bed.gz	encode_chipseq_H3K4me3_ENCFF885FQN
# encode_chipseq_subset	K562.hg38.ENCSR760UVO.ENCFF488OTN.ChIPseq.KLF16.bed.gz	encode_chipseq_KLF16_ENCFF488OTN
# encode_chipseq_subset	K562.hg38.ENCSR991ELG.ENCFF553GPK.ChIPseq.SP1.bed.gz	encode_chipseq_SP1_ENCFF553GPK
# encode_chipseq_subset	K562.hg38.ENCSR998AJK.ENCFF777PKJ.ChIPseq.NRF1.bed.gz	encode_chipseq_NRF1_ENCFF777PKJ
# encode_chromatin_states	K562.hg38.cCREs.silencer_rest.bed.gz	encode_ccres_silencer_rest
# encode_chromatin_states	K562.hg38.cCREs.silencer_starr.bed.gz	encode_ccres_silencer_starr
# encode_chromatin_states	K562.hg38.ENCSR365YNI.ENCFF106BGJ.ChromHMM.simplified.bed.gz	encode_chromhmm_ENCFF106BGJ
# encode_chromatin_states	K562.hg38.ENCSR913HQX.ENCFF286VQG.cCREs.simplified.bed.gz	encode_ccres_ENCFF286VQG
# fcc_astarr_csaw	K562.hg38.ASTARR.KS91.csaw.bed.gz	fcc_astarr_csaw_KS91
# fcc_astarr_csaw	K562.hg38.ASTARR.KSMerge.csaw.bed.gz	fcc_astarr_csaw_KSMerge
# fcc_crispri_hcrff	K562.hg38.CRISPRi_HCRFF.CASA.bed.gz	fcc_crispri_hcrff_casa
# genome_tss	K562.hg38.TSS.selected_by_highest_Pol2_signal.bed.gz	genome_tss_pol2
# genome_tss	K562.hg38.TSS.selected_by_highest_Pol2_signal.filtered_by_RNAseq_TPM.bed.gz	genome_tss_pol2_rnaseq
# hic_insitu_K562_ENCSR545YBD	K562.hg38.hic_insitu.Loop_A.bed.gz	hic_insitu_Loop_A_ENCSR545YBD
# hic_insitu_K562_ENCSR545YBD	K562.hg38.hic_insitu.Loop_B.bed.gz	hic_insitu_Loop_B_ENCSR545YBD
# hic_insitu_K562_ENCSR545YBD	K562.hg38.hic_insitu.TAD.bedpe.gz	hic_insitu_TAD_ENCSR545YBD
# hic_intact_K562_deep	K562.hg38.hic_intact.Loop_A.bed.gz	hic_intact_Loop_A_deep
# hic_intact_K562_deep	K562.hg38.hic_intact.Loop_B.bed.gz	hic_intact_Loop_B_deep
# hic_intact_K562_ENCSR479XDG	K562.hg38.hic_intact.Loop_A.bed.gz	hic_intact_Loop_A_ENCSR479XDG
# hic_intact_K562_ENCSR479XDG	K562.hg38.hic_intact.Loop_B.bed.gz	hic_intact_Loop_B_ENCSR479XDG
# hic_intact_K562_ENCSR479XDG	K562.hg38.hic_intact.TAD.bedpe.gz	hic_intact_TAD_ENCSR479XDG

# %%
FOLDER_A=fcc_astarr_macs
FOLDER_B=encode_chromatin_states

# %%
### set directory
FOLDR=${FOLDER_A}
FDIRY=${FD_RES}/region/${FOLDR}/summary
FNAME=metadata.label.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL_A=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
### set directory
FOLDR=${FOLDER_B}
FDIRY=${FD_RES}/region/${FOLDR}/summary
FNAME=metadata.label.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL_B=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label
# encode_chromatin_states	K562.hg38.cCREs.silencer_rest.bed.gz	encode_ccres_silencer_rest
# encode_chromatin_states	K562.hg38.cCREs.silencer_starr.bed.gz	encode_ccres_silencer_starr
# encode_chromatin_states	K562.hg38.ENCSR365YNI.ENCFF106BGJ.ChromHMM.simplified.bed.gz	encode_chromhmm_ENCFF106BGJ
# encode_chromatin_states	K562.hg38.ENCSR913HQX.ENCFF286VQG.cCREs.simplified.bed.gz	encode_ccres_ENCFF286VQG

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}

        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${LABEL_REG_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_YY1_ENCFF398UQZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_YY1_ENCFF398UQZ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_REST_ENCFF707MDI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_REST_ENCFF707MDI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_REST_ENCFF707MDI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_JUN_ENCFF190CGV
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_JUN_ENCFF190CGV.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_GATA1_ENCFF657CTC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_GATA1_ENCFF657CTC.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ELK1_ENCFF715WGN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ELK1_ENCFF715WGN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_EP300_ENCFF702XPO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_EP300_ENCFF702XPO.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_CTCF_ENCFF660GHM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_CTCF_ENCFF660GHM.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_TAL1_ENCFF852ZRK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_TAL1_ENCFF852ZRK.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZEB2_ENCFF242AOL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZEB2_ENCFF242AOL.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ATF1_ENCFF627RSK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_KLF10_ENCFF142ZTD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_KLF10_ENCFF142ZTD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_POLR2A_ENCFF355MNE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_POLR2A_ENCFF355MNE.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_NFE2_ENCFF023IFO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_KLF16_ENCFF488OTN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_KLF16_ENCFF488OTN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_SP1_ENCFF553GPK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_SP1_ENCFF553GPK.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_NRF1_ENCFF777PKJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_NRF1_ENCFF777PKJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_YY1_ENCFF398UQZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_YY1_ENCFF398UQZ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_REST_ENCFF707MDI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_JUN_ENCFF190CGV
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_JUN_ENCFF190CGV.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_GATA1_ENCFF657CTC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_ELK1_ENCFF715WGN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_EP300_ENCFF702XPO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_CTCF_ENCFF660GHM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_TAL1_ENCFF852ZRK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_ZEB2_ENCFF242AOL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ZEB2_ENCFF242AOL.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_ATF1_ENCFF627RSK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_KLF10_ENCFF142ZTD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_KLF10_ENCFF142ZTD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_POLR2A_ENCFF355MNE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_POLR2A_ENCFF355MNE.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_NFE2_ENCFF023IFO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_KLF16_ENCFF488OTN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_KLF16_ENCFF488OTN.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_SP1_ENCFF553GPK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_SP1_ENCFF553GPK.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_NRF1_ENCFF777PKJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_rest.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_starr.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.txt
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.txt

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}

        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${LABEL_REG_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### Set log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir  -p ${FD_OUT}
        sbatch -p ${NODE} \
            --exclude=dl-01 \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FD_PRJ} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 30785083
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 30785084
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 30785085
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 30785086
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_YY1_ENCFF398UQZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_YY1_ENCFF398UQZ.txt
#
# Submitted batch job 30785087
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_REST_ENCFF707MDI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_REST_ENCFF707MDI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_REST_ENCFF707MDI.txt
#
# Submitted batch job 30785088
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_JUN_ENCFF190CGV
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_JUN_ENCFF190CGV.txt
#
# Submitted batch job 30785089
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_GATA1_ENCFF657CTC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_GATA1_ENCFF657CTC.txt
#
# Submitted batch job 30785090
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ELK1_ENCFF715WGN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ELK1_ENCFF715WGN.txt
#
# Submitted batch job 30785091
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_EP300_ENCFF702XPO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_EP300_ENCFF702XPO.txt
#
# Submitted batch job 30785092
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_CTCF_ENCFF660GHM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_CTCF_ENCFF660GHM.txt
#
# Submitted batch job 30785093
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_TAL1_ENCFF852ZRK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_TAL1_ENCFF852ZRK.txt
#
# Submitted batch job 30785094
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ZEB2_ENCFF242AOL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ZEB2_ENCFF242AOL.txt
#
# Submitted batch job 30785095
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_ATF1_ENCFF627RSK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.txt
#
# Submitted batch job 30785096
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_KLF10_ENCFF142ZTD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_KLF10_ENCFF142ZTD.txt
#
# Submitted batch job 30785097
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_POLR2A_ENCFF355MNE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_POLR2A_ENCFF355MNE.txt
#
# Submitted batch job 30785098
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_NFE2_ENCFF023IFO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# Submitted batch job 30785099
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 30785100
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_KLF16_ENCFF488OTN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_KLF16_ENCFF488OTN.txt
#
# Submitted batch job 30785101
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_SP1_ENCFF553GPK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_SP1_ENCFF553GPK.txt
#
# Submitted batch job 30785102
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_NRF1_ENCFF777PKJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_NRF1_ENCFF777PKJ.txt
#
# Submitted batch job 30785103
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_rest.txt
#
# Submitted batch job 30785104
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_silencer_starr.txt
#
# Submitted batch job 30785105
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chromhmm_ENCFF106BGJ.txt
#
# Submitted batch job 30785106
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_ccres_ENCFF286VQG.txt
#
# Submitted batch job 30785107
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KS91.txt
#
# Submitted batch job 30785108
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_astarr_csaw_KSMerge.txt
#
# Submitted batch job 30785109
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.fcc_crispri_hcrff_casa.txt
#
# Submitted batch job 30785110
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2.txt
#
# Submitted batch job 30785111
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.genome_tss_pol2_rnaseq.txt
#
# Submitted batch job 30785112
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# Submitted batch job 30785113
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# Submitted batch job 30785114
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_insitu_TAD_ENCSR545YBD.txt
#
# Submitted batch job 30785115
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_deep.txt
#
# Submitted batch job 30785116
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_deep.txt
#
# Submitted batch job 30785117
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_A_ENCSR479XDG.txt
#
# Submitted batch job 30785118
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_Loop_B_ENCSR479XDG.txt
#
# Submitted batch job 30785119
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/
# Output FName:   fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.hic_intact_TAD_ENCSR479XDG.txt
#
# Submitted batch job 30785120
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27ac_ENCFF544LXB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 30785121
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF323WOT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 30785122
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 30785123
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 30785124
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_YY1_ENCFF398UQZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_YY1_ENCFF398UQZ.txt
#
# Submitted batch job 30785125
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_REST_ENCFF707MDI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.txt
#
# Submitted batch job 30785126
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_JUN_ENCFF190CGV
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_JUN_ENCFF190CGV.txt
#
# Submitted batch job 30785127
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_GATA1_ENCFF657CTC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.txt
#
# Submitted batch job 30785128
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_ELK1_ENCFF715WGN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.txt
#
# Submitted batch job 30785129
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_EP300_ENCFF702XPO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.txt
#
# Submitted batch job 30785130
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_CTCF_ENCFF660GHM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.txt
#
# Submitted batch job 30785131
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_TAL1_ENCFF852ZRK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.txt
#
# Submitted batch job 30785132
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_ZEB2_ENCFF242AOL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ZEB2_ENCFF242AOL.txt
#
# Submitted batch job 30785133
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_ATF1_ENCFF627RSK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.txt
#
# Submitted batch job 30785134
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_KLF10_ENCFF142ZTD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_KLF10_ENCFF142ZTD.txt
#
# Submitted batch job 30785135
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_POLR2A_ENCFF355MNE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_POLR2A_ENCFF355MNE.txt
#
# Submitted batch job 30785136
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_NFE2_ENCFF023IFO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# Submitted batch job 30785137
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF885FQN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 30785138
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_KLF16_ENCFF488OTN
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_KLF16_ENCFF488OTN.txt
#
# Submitted batch job 30785139
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_SP1_ENCFF553GPK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_SP1_ENCFF553GPK.txt
#
# Submitted batch job 30785140
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_NRF1_ENCFF777PKJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.txt
#
# Submitted batch job 30785141
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_rest
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_rest.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_rest.txt
#
# Submitted batch job 30785142
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_silencer_starr
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_silencer_starr.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_silencer_starr.txt
#
# Submitted batch job 30785143
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chromhmm_ENCFF106BGJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chromhmm_ENCFF106BGJ.txt
#
# Submitted batch job 30785144
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_ccres_ENCFF286VQG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_ccres_ENCFF286VQG.txt
#
# Submitted batch job 30785145
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KS91
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KS91.txt
#
# Submitted batch job 30785146
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_astarr_csaw_KSMerge
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_astarr_csaw_KSMerge.txt
#
# Submitted batch job 30785147
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: fcc_crispri_hcrff_casa
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.fcc_crispri_hcrff_casa.txt
#
# Submitted batch job 30785148
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2.txt
#
# Submitted batch job 30785149
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: genome_tss_pol2_rnaseq
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.genome_tss_pol2_rnaseq.txt
#
# Submitted batch job 30785150
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_A_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_A_ENCSR545YBD.txt
#
# Submitted batch job 30785151
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_Loop_B_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_Loop_B_ENCSR545YBD.txt
#
# Submitted batch job 30785152
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_insitu_TAD_ENCSR545YBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_insitu_TAD_ENCSR545YBD.txt
#
# Submitted batch job 30785153
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_deep.txt
#
# Submitted batch job 30785154
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_deep
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_deep.txt
#
# Submitted batch job 30785155
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_A_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_A_ENCSR479XDG.txt
#
# Submitted batch job 30785156
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_Loop_B_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_Loop_B_ENCSR479XDG.txt
#
# Submitted batch job 30785157
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: hic_intact_TAD_ENCSR479XDG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/
# Output FName:   fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.hic_intact_TAD_ENCSR479XDG.txt
#
# Submitted batch job 30785158
