# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)

vec = dir(txt_fdiry)
for(txt in vec){cat(txt, "\n")}
# Out:
# matrix.annotation.chipseq.tsv
# matrix.annotation.subset.tsv
# region.annotation.encode_chromatin_states.tsv
# region.annotation.fcc_astarr_csaw.tsv
# region.annotation.fcc_crispri_hcrff.tsv
# region.annotation.genome_tss.tsv
# region.annotation.hic_insitu_K562_ENCSR545YBD.tsv
# region.annotation.hic_intact_K562_deep.tsv
# region.annotation.hic_intact_K562_ENCSR479XDG.tsv
# region.summary.encode_chipseq_encode4.tsv
# region.summary.encode_chipseq_flagship.tsv
# region.summary.encode_chipseq_histone.tsv
# region.summary.encode_chipseq_subset.tsv
# region.summary.encode_chromatin_states.tsv
# region.summary.fcc_astarr_csaw.tsv
# region.summary.fcc_crispri_hcrff.tsv
# region.summary.genome_tss.tsv
# region.summary.hic_insitu_K562_ENCSR545YBD.tsv
# region.summary.hic_intact_K562_deep.tsv
# region.summary.hic_intact_K562_ENCSR479XDG.tsv
# umap.annotation.chipseq.tsv

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.genome_tss.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

###
dat = read_tsv(txt_fpath, show_col_types = FALSE)
dat = dat %>% dplyr::mutate(Label = Label_B)
dat = dat %>% dplyr::filter(Label == "TSS_Pol2_RNAseq")

###
dat = dat %>% 
    dplyr::select(Region_A, Label) %>% 
    dplyr::distinct()

### assign and show
dat_region_annot_tss = dat
print(dim(dat))
head(dat)
# Out:
# [1] 9651    2
#   Region_A            Label
# 1 chr1:28934-29499    TSS_Pol2_RNAseq
# 2 chr1:826796-828040  TSS_Pol2_RNAseq
# 3 chr1:876493-877795  TSS_Pol2_RNAseq
# 4 chr1:958722-959968  TSS_Pol2_RNAseq
# 5 chr1:960468-961615  TSS_Pol2_RNAseq
# 6 chr1:998960-1001192 TSS_Pol2_RNAseq

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.encode_chipseq_subset.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

###
dat = read_tsv(txt_fpath, show_col_types = FALSE)

###
dat = dat %>% dplyr::mutate(Label = paste("chipseq", Label_B, sep="_"))

###
dat = dat %>% 
    dplyr::select(Region_A, Label) %>% 
    dplyr::distinct()

### assign and show
dat_region_annot_chipseq_subset = dat
print(dim(dat))
head(dat)
# Out:
# [1] 428514      2
#   Region_A           Label
# 1 chr1:16025-16338   chipseq_CTCF
# 2 chr1:17288-17689   chipseq_POLR2A
# 3 chr1:115429-115969 chipseq_EP300
# 4 chr1:115429-115969 chipseq_NFE2
# 5 chr1:115429-115969 chipseq_NRF1
# 6 chr1:115429-115969 chipseq_POLR2A

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.encode_chipseq_histone.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

###
dat = read_tsv(txt_fpath, show_col_types = FALSE)

###
dat = dat %>% dplyr::mutate(Label = paste("chipseq", Label_B, sep="_"))

###
dat = dat %>% 
    dplyr::select(Region_A, Label) %>% 
    dplyr::distinct()

### assign and show
dat_region_annot_chipseq_histone = dat
print(dim(dat))
head(dat)
# Out:
# [1] 384749      2
#   Region_A           Label
# 1 chr1:16025-16338   chipseq_H3K36me3
# 2 chr1:137748-138049 chipseq_H3K27ac
# 3 chr1:137748-138049 chipseq_H3K4me2
# 4 chr1:137748-138049 chipseq_H3K4me3
# 5 chr1:137748-138049 chipseq_H3K79me2
# 6 chr1:137748-138049 chipseq_H3K9ac

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.encode_chipseq_encode4.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

###
dat = read_tsv(txt_fpath, show_col_types = FALSE)

###
dat = dat %>% dplyr::mutate(Label = paste("chipseq", Label_B, sep="_"))

###
dat = dat %>% 
    dplyr::select(Region_A, Label) %>% 
    dplyr::distinct()

### assign and show
dat_region_annot_chipseq_encode4 = dat
print(dim(dat))
head(dat)
# Out:
# [1] 1081512       2
#   Region_A           Label
# 1 chr1:115429-115969 chipseq_CGGBP1
# 2 chr1:115429-115969 chipseq_CXXC5
# 3 chr1:115429-115969 chipseq_DMBX1
# 4 chr1:115429-115969 chipseq_SMAD4
# 5 chr1:115429-115969 chipseq_TCF3
# 6 chr1:115429-115969 chipseq_TEAD1

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.hic_intact_K562_deep.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

###
dat = read_tsv(txt_fpath, show_col_types = FALSE)

###
dat = dat %>% 
    dplyr::mutate(Label = paste("hic_loop", Name_B, sep="_")) %>%
    dplyr::filter(Label_B == "Loop_A|Loop_B") %>%
    dplyr::filter(Count > 1)

###
dat = dat %>% 
    dplyr::select(Region_A, Label) %>% 
    dplyr::distinct()

### assign and show
dat_region_hic_loop = dat
print(dim(dat))
head(dat)
# Out:
# [1] 194830      2
#   Region_A           Label
# 1 chr1:778233-779389 hic_loop_chr1:778000-779000|chr1:827000-828000
# 2 chr1:869637-870233 hic_loop_chr1:870000-872000|chr1:974000-976000
# 3 chr1:869637-870233 hic_loop_chr1:870000-872000|chr1:1062000-1064000
# 4 chr1:869637-870233 hic_loop_chr1:870000-875000|chr1:935000-940000
# 5 chr1:869637-870233 hic_loop_chr1:868000-870000|chr1:1290000-1292000
# 6 chr1:903783-905204 hic_loop_chr1:904000-905000|chr1:976000-977000

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "region.summary.hic_intact_K562_ENCSR479XDG.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

###
dat = read_tsv(txt_fpath, show_col_types = FALSE)

###
dat = dat %>% 
    dplyr::mutate(Label = paste("hic_tad", Name_B, sep="_"))  %>%
    dplyr::filter(Label_B == "TAD") %>%
    dplyr::filter(Count > 1)

###
dat = dat %>% 
    dplyr::select(Region_A, Label) %>% 
    dplyr::distinct()

### assign and show
dat_region_hic_tad = dat
print(dim(dat))
head(dat)
# Out:
# [1] 66821     2
#   Region_A             Label
# 1 chr1:1121812-1122517 hic_tad_chr1:1120000-1240000
# 2 chr1:1123051-1123418 hic_tad_chr1:1120000-1240000
# 3 chr1:1124365-1124875 hic_tad_chr1:1120000-1240000
# 4 chr1:1125359-1125597 hic_tad_chr1:1120000-1240000
# 5 chr1:1127573-1128245 hic_tad_chr1:1120000-1240000
# 6 chr1:1128708-1128988 hic_tad_chr1:1120000-1240000

# %%
###
lst = list(
    "TSS"             = dat_region_annot_tss,
    "ChIPseq;Subset"  = dat_region_annot_chipseq_subset,
    "ChIPseq;Histone" = dat_region_annot_chipseq_histone,
    "ChIPseq;TF"      = dat_region_annot_chipseq_encode4,
    "HiC;Loop"        = dat_region_hic_loop,
    "HiC;TAD"         = dat_region_hic_tad
)

lst = lapply(lst, function(dat){
    vec = unique(dat$Label)
    return(vec)
})

lapply(lst, length)
# Out:
# $TSS
# [1] 1
#
# $`ChIPseq;Subset`
# [1] 21
#
# $`ChIPseq;Histone`
# [1] 12
#
# $`ChIPseq;TF`
# [1] 224
#
# $`HiC;Loop`
# [1] 87824
#
# $`HiC;TAD`
# [1] 4255

# %%
###
lst = list(
    "TSS"             = dat_region_annot_tss,
    "ChIPseq;Subset"  = dat_region_annot_chipseq_subset,
    "ChIPseq;Histone" = dat_region_annot_chipseq_histone
)

###
dat  = bind_rows(lst) %>% dplyr::distinct()
vec1 = unique(dat$Region_A)
vec2 = unique(dat$Label)
cat("ATAC: ", length(vec1), "\n")
cat("Label:", length(vec2), "\n")
cat("\n")

###
tmp = dat %>% 
    dplyr::group_by(Region_A) %>% 
    dplyr::summarize(Count = n()) %>%
    dplyr::filter(Count > 1)
vec = tmp$Region_A

###
dat = dat %>% dplyr::filter(Region_A %in% vec)
vec1 = unique(dat$Region_A)
vec2 = unique(dat$Label)
cat("ATAC: ", length(vec1), "\n")
cat("Label:", length(vec2), "\n")
cat("\n")

###
dat_region_annot_merge_subset = dat
print(dim(dat))
head(dat, 3)
# Out:
# ATAC:  129866
# Label: 29
#
# ATAC:  98306
# Label: 29
#
# [1] 630103      2
#   Region_A           Label
# 1 chr1:826796-828040 TSS_Pol2_RNAseq
# 2 chr1:958722-959968 TSS_Pol2_RNAseq
# 3 chr1:960468-961615 TSS_Pol2_RNAseq

# %%
###
lst = list(
    "TSS"             = dat_region_annot_tss,
    "ChIPseq;Subset"  = dat_region_annot_chipseq_subset,
    "ChIPseq;Histone" = dat_region_annot_chipseq_histone,
    "ChIPseq;TF"      = dat_region_annot_chipseq_encode4
)

###
dat  = bind_rows(lst) %>% dplyr::distinct()
vec1 = unique(dat$Region_A)
vec2 = unique(dat$Label)
cat("ATAC: ", length(vec1), "\n")
cat("Label:", length(vec2), "\n")
cat("\n")

###
tmp = dat %>% 
    dplyr::group_by(Label) %>% 
    dplyr::summarize(Count = n()) %>%
    dplyr::filter(Count > 1)
vec = tmp$Label

dat = dat %>% dplyr::filter(Label %in% vec)
vec1 = unique(dat$Region_A)
vec2 = unique(dat$Label)
cat("ATAC: ", length(vec1), "\n")
cat("Label:", length(vec2), "\n")
cat("\n")

###
tmp = dat %>% 
    dplyr::group_by(Region_A) %>% 
    dplyr::summarize(Count = n()) %>%
    dplyr::filter(Count > 1)
vec = tmp$Region_A

dat = dat %>% dplyr::filter(Region_A %in% vec)
vec1 = unique(dat$Region_A)
vec2 = unique(dat$Label)
cat("ATAC: ", length(vec1), "\n")
cat("Label:", length(vec2), "\n")
cat("\n")

###
dat_region_annot_merge_chipseq_tss = dat
print(dim(dat))
head(dat, 3)
# Out:
# ATAC:  133428
# Label: 247
#
# ATAC:  133428
# Label: 247
#
# ATAC:  110648
# Label: 247
#
# [1] 1702569       2
#   Region_A           Label
# 1 chr1:826796-828040 TSS_Pol2_RNAseq
# 2 chr1:958722-959968 TSS_Pol2_RNAseq
# 3 chr1:960468-961615 TSS_Pol2_RNAseq

# %%
dat =  dat_region_annot_merge_chipseq_tss
print(table(dat$Label))
head(dat)
# Out:
#     chipseq_AFF4   chipseq_ARID3B   chipseq_ARID4B     chipseq_ATF1
#             8089             2001            12461            25158
#     chipseq_ATF2     chipseq_ATF3     chipseq_ATF4     chipseq_ATF6
#             1798             8046             7139             5590
#     chipseq_BCL6    chipseq_BRCA1   chipseq_CAMTA2     chipseq_CBFB
#             2038             1564             1831             5479
#    chipseq_CEBPG   chipseq_CGGBP1   chipseq_CHCHD3    chipseq_CLOCK
#             9975             2737             1750             1535
#    chipseq_CREB1    chipseq_CREB5     chipseq_CTCF    chipseq_CXXC5
#            13191             1313            34445            28939
#    chipseq_DDIT3    chipseq_DEAF1     chipseq_DLX4    chipseq_DMBX1
#             2324            15740              297            12112
#    chipseq_DMTF1     chipseq_E2F1     chipseq_E2F3     chipseq_E2F4
#             3663             6968             6600             4112
#     chipseq_E2F5     chipseq_E4F1     chipseq_ELF1     chipseq_ELF2
#             3829             1374             8868             6658
#     chipseq_ELF4     chipseq_ELK1     chipseq_ELK3    chipseq_EP300
#             7999             3441             1066            22329
#      chipseq_ERF    chipseq_ESRRB     chipseq_ETV5     chipseq_ETV6
#             8157              719            12269             2396
#    chipseq_FOXA3    chipseq_FOXJ3    chipseq_FOXK1    chipseq_FOXM1
#            12453              980             5323             4412
#    chipseq_FOXO4    chipseq_FOXP1    chipseq_FOXP4   chipseq_GABPB1
#             2064             8523             4818            15269
#   chipseq_GABPB2    chipseq_GATA1    chipseq_GATA2    chipseq_GMEB1
#              946            11580            11873             8233
#    chipseq_GTF2I    chipseq_H2AFZ  chipseq_H3K27ac chipseq_H3K27me3
#             8013            50973            35863            19836
# chipseq_H3K36me3  chipseq_H3K4me1  chipseq_H3K4me2  chipseq_H3K4me3
#            16507            71804            44736            33664
# chipseq_H3K79me2   chipseq_H3K9ac  chipseq_H3K9me1  chipseq_H3K9me3
#            23359            51596             3520             1617
# chipseq_H4K20me1     chipseq_HEY1   chipseq_HIVEP1   chipseq_HMG20A
#            12941             2157             3348            10338
#   chipseq_HMG20B   chipseq_HMGXB4    chipseq_HOMEZ    chipseq_HOXB6
#              810             5723             1808              946
#     chipseq_HSF4      chipseq_ID3    chipseq_IFI16     chipseq_IRF1
#             2054              641             1117             1470
#     chipseq_IRF2      chipseq_JUN     chipseq_JUNB     chipseq_KAT7
#             1179            17732             3059             8355
#    chipseq_KDM2B    chipseq_KLF10    chipseq_KLF16     chipseq_KLF6
#             4175              722            15389             5572
#     chipseq_LCOR      chipseq_MAX      chipseq_MAZ     chipseq_MBD1
#            12522            19159            27683             2206
#    chipseq_MECOM     chipseq_MED1      chipseq_MLX     chipseq_MTF1
#             6926              873             3199             1059
#     chipseq_MXD1    chipseq_MYBL2      chipseq_MYC     chipseq_MYNN
#             2620              487             6668             1139
#     chipseq_NFE2     chipseq_NFIX    chipseq_NFXL1     chipseq_NFYA
#            14141             1671             2000             7320
#    chipseq_NR1H2    chipseq_NR2C2    chipseq_NR2F6    chipseq_NR3C1
#             3292             7108             4260             2849
#    chipseq_NR4A1     chipseq_NRF1     chipseq_OTX1    chipseq_PATZ1
#             3730            22201             6532             1723
#      chipseq_PHB    chipseq_PHTF2   chipseq_POLR2A    chipseq_PPARD
#             2589             1109            17783              329
#     chipseq_PREB    chipseq_PRMT5     chipseq_PURB    chipseq_RAD21
#             3006             1456              205            35715
#     chipseq_RBPJ     chipseq_RERE     chipseq_REST     chipseq_RFX7
#             1410             2127            16794             1140
#  chipseq_RHOXF2B   chipseq_RNF219    chipseq_RREB1  chipseq_SLC30A9
#             2046              904             6414              303
#    chipseq_SMAD3    chipseq_SMAD4   chipseq_SNAPC5      chipseq_SP1
#             6792            24711              375            16859
#   chipseq_SREBF2      chipseq_SRF    chipseq_STAG1   chipseq_STAT5B
#             1221            11588             9388              320
#    chipseq_STAT6     chipseq_TAL1    chipseq_TBPL1    chipseq_TBX18
#             4010            21572             4708             4496
#    chipseq_TCF15     chipseq_TCF3    chipseq_TCFL5    chipseq_TEAD1
#             2199            24489             1417            17595
#    chipseq_TEAD4     chipseq_TFAM    chipseq_TFAP4    chipseq_TFCP2
#             2592               22            27630             6656
#    chipseq_TFDP1     chipseq_TFE3    chipseq_TGIF2   chipseq_THAP12
#            13950             5874             2965             7620
#    chipseq_THAP7     chipseq_TOE1    chipseq_TSHZ1     chipseq_USF1
#             2715             2995             1717            13057
#     chipseq_USF2      chipseq_YY1    chipseq_ZBTB1   chipseq_ZBTB11
#             9487            20568             5885             3107
#   chipseq_ZBTB12   chipseq_ZBTB17   chipseq_ZBTB33   chipseq_ZBTB34
#             7072            10123            15677             1127
#   chipseq_ZBTB40   chipseq_ZBTB43   chipseq_ZBTB49    chipseq_ZBTB9
#             1952             3299             2018            10300
#    chipseq_ZC3H4     chipseq_ZEB2     chipseq_ZFP1    chipseq_ZFP30
#             2936            17270             1659              374
#    chipseq_ZFP91    chipseq_ZFPM2      chipseq_ZFX  chipseq_ZKSCAN3
#             3665             1780            19105              543
#  chipseq_ZKSCAN8    chipseq_ZNF12   chipseq_ZNF121   chipseq_ZNF124
#             2778             4864             4456              804
#   chipseq_ZNF133   chipseq_ZNF134   chipseq_ZNF140   chipseq_ZNF143
#             1148             3834              534             5060
#   chipseq_ZNF165   chipseq_ZNF174   chipseq_ZNF184   chipseq_ZNF212
#             2480              780              468             1890
#   chipseq_ZNF215   chipseq_ZNF217   chipseq_ZNF224    chipseq_ZNF23
#             4091              384             1849             1327
#   chipseq_ZNF232   chipseq_ZNF239   chipseq_ZNF253   chipseq_ZNF257
#             3248             4017              711             2927
#   chipseq_ZNF263   chipseq_ZNF277  chipseq_ZNF280B   chipseq_ZNF281
#            11350              272              605            25312
#   chipseq_ZNF282     chipseq_ZNF3   chipseq_ZNF311   chipseq_ZNF317
#             2301              843             4270             6228
#   chipseq_ZNF319   chipseq_ZNF324   chipseq_ZNF347  chipseq_ZNF354B
#             3569             2175              629             1483
#  chipseq_ZNF354C   chipseq_ZNF397   chipseq_ZNF398   chipseq_ZNF408
#              822             2165              554              230
#    chipseq_ZNF41   chipseq_ZNF431   chipseq_ZNF436   chipseq_ZNF444
#             3407             5376             1423             2198
#   chipseq_ZNF445   chipseq_ZNF449   chipseq_ZNF507   chipseq_ZNF511
#             1825             3180             4096             8285
#   chipseq_ZNF512  chipseq_ZNF518B   chipseq_ZNF551   chipseq_ZNF561
#              961              429              511             1058
#    chipseq_ZNF57   chipseq_ZNF583   chipseq_ZNF586   chipseq_ZNF609
#             1608             6623             1117             3753
#   chipseq_ZNF639   chipseq_ZNF655   chipseq_ZNF668   chipseq_ZNF695
#              611              480             3027             1290
#   chipseq_ZNF696   chipseq_ZNF699     chipseq_ZNF7   chipseq_ZNF700
#              569              320            10735             1454
#   chipseq_ZNF707   chipseq_ZNF717   chipseq_ZNF740   chipseq_ZNF75A
#             1476             1018             8720             2231
#    chipseq_ZNF76   chipseq_ZNF764    chipseq_ZNF77   chipseq_ZNF778
#             4305             2148              546              128
#  chipseq_ZNF780A   chipseq_ZNF785    chipseq_ZNF79   chipseq_ZNF830
#              665              337             1967             3059
#    chipseq_ZNF84  chipseq_ZSCAN32  TSS_Pol2_RNAseq
#             3127             2737             9635
#   Region_A             Label
# 1 chr1:826796-828040   TSS_Pol2_RNAseq
# 2 chr1:958722-959968   TSS_Pol2_RNAseq
# 3 chr1:960468-961615   TSS_Pol2_RNAseq
# 4 chr1:998960-1001192  TSS_Pol2_RNAseq
# 5 chr1:1013154-1014482 TSS_Pol2_RNAseq
# 6 chr1:1019190-1021734 TSS_Pol2_RNAseq

# %%
dat = dat_region_annot_merge_chipseq_tss
dat = dat %>% dplyr::mutate(Count = 1)
mat = dat %>% tidyr::spread(Label, Count) %>% replace(is.na(.), 0)
fun_display_table(head(mat))
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region_A </th>
#    <th style="text-align:right;"> chipseq_AFF4 </th>
#    <th style="text-align:right;"> chipseq_ARID3B </th>
#    <th style="text-align:right;"> chipseq_ARID4B </th>
#    <th style="text-align:right;"> chipseq_ATF1 </th>
#    <th style="text-align:right;"> chipseq_ATF2 </th>
#    <th style="text-align:right;"> chipseq_ATF3 </th>
#    <th style="text-align:right;"> chipseq_ATF4 </th>
#    <th style="text-align:right;"> chipseq_ATF6 </th>
#    <th style="text-align:right;"> chipseq_BCL6 </th>
#    <th style="text-align:right;"> chipseq_BRCA1 </th>
#    <th style="text-align:right;"> chipseq_CAMTA2 </th>
#    <th style="text-align:right;"> chipseq_CBFB </th>
#    <th style="text-align:right;"> chipseq_CEBPG </th>
#    <th style="text-align:right;"> chipseq_CGGBP1 </th>
#    <th style="text-align:right;"> chipseq_CHCHD3 </th>
#    <th style="text-align:right;"> chipseq_CLOCK </th>
#    <th style="text-align:right;"> chipseq_CREB1 </th>
#    <th style="text-align:right;"> chipseq_CREB5 </th>
#    <th style="text-align:right;"> chipseq_CTCF </th>
#    <th style="text-align:right;"> chipseq_CXXC5 </th>
#    <th style="text-align:right;"> chipseq_DDIT3 </th>
#    <th style="text-align:right;"> chipseq_DEAF1 </th>
#    <th style="text-align:right;"> chipseq_DLX4 </th>
#    <th style="text-align:right;"> chipseq_DMBX1 </th>
#    <th style="text-align:right;"> chipseq_DMTF1 </th>
#    <th style="text-align:right;"> chipseq_E2F1 </th>
#    <th style="text-align:right;"> chipseq_E2F3 </th>
#    <th style="text-align:right;"> chipseq_E2F4 </th>
#    <th style="text-align:right;"> chipseq_E2F5 </th>
#    <th style="text-align:right;"> chipseq_E4F1 </th>
#    <th style="text-align:right;"> chipseq_ELF1 </th>
#    <th style="text-align:right;"> chipseq_ELF2 </th>
#    <th style="text-align:right;"> chipseq_ELF4 </th>
#    <th style="text-align:right;"> chipseq_ELK1 </th>
#    <th style="text-align:right;"> chipseq_ELK3 </th>
#    <th style="text-align:right;"> chipseq_EP300 </th>
#    <th style="text-align:right;"> chipseq_ERF </th>
#    <th style="text-align:right;"> chipseq_ESRRB </th>
#    <th style="text-align:right;"> chipseq_ETV5 </th>
#    <th style="text-align:right;"> chipseq_ETV6 </th>
#    <th style="text-align:right;"> chipseq_FOXA3 </th>
#    <th style="text-align:right;"> chipseq_FOXJ3 </th>
#    <th style="text-align:right;"> chipseq_FOXK1 </th>
#    <th style="text-align:right;"> chipseq_FOXM1 </th>
#    <th style="text-align:right;"> chipseq_FOXO4 </th>
#    <th style="text-align:right;"> chipseq_FOXP1 </th>
#    <th style="text-align:right;"> chipseq_FOXP4 </th>
#    <th style="text-align:right;"> chipseq_GABPB1 </th>
#    <th style="text-align:right;"> chipseq_GABPB2 </th>
#    <th style="text-align:right;"> chipseq_GATA1 </th>
#    <th style="text-align:right;"> chipseq_GATA2 </th>
#    <th style="text-align:right;"> chipseq_GMEB1 </th>
#    <th style="text-align:right;"> chipseq_GTF2I </th>
#    <th style="text-align:right;"> chipseq_H2AFZ </th>
#    <th style="text-align:right;"> chipseq_H3K27ac </th>
#    <th style="text-align:right;"> chipseq_H3K27me3 </th>
#    <th style="text-align:right;"> chipseq_H3K36me3 </th>
#    <th style="text-align:right;"> chipseq_H3K4me1 </th>
#    <th style="text-align:right;"> chipseq_H3K4me2 </th>
#    <th style="text-align:right;"> chipseq_H3K4me3 </th>
#    <th style="text-align:right;"> chipseq_H3K79me2 </th>
#    <th style="text-align:right;"> chipseq_H3K9ac </th>
#    <th style="text-align:right;"> chipseq_H3K9me1 </th>
#    <th style="text-align:right;"> chipseq_H3K9me3 </th>
#    <th style="text-align:right;"> chipseq_H4K20me1 </th>
#    <th style="text-align:right;"> chipseq_HEY1 </th>
#    <th style="text-align:right;"> chipseq_HIVEP1 </th>
#    <th style="text-align:right;"> chipseq_HMG20A </th>
#    <th style="text-align:right;"> chipseq_HMG20B </th>
#    <th style="text-align:right;"> chipseq_HMGXB4 </th>
#    <th style="text-align:right;"> chipseq_HOMEZ </th>
#    <th style="text-align:right;"> chipseq_HOXB6 </th>
#    <th style="text-align:right;"> chipseq_HSF4 </th>
#    <th style="text-align:right;"> chipseq_ID3 </th>
#    <th style="text-align:right;"> chipseq_IFI16 </th>
#    <th style="text-align:right;"> chipseq_IRF1 </th>
#    <th style="text-align:right;"> chipseq_IRF2 </th>
#    <th style="text-align:right;"> chipseq_JUN </th>
#    <th style="text-align:right;"> chipseq_JUNB </th>
#    <th style="text-align:right;"> chipseq_KAT7 </th>
#    <th style="text-align:right;"> chipseq_KDM2B </th>
#    <th style="text-align:right;"> chipseq_KLF10 </th>
#    <th style="text-align:right;"> chipseq_KLF16 </th>
#    <th style="text-align:right;"> chipseq_KLF6 </th>
#    <th style="text-align:right;"> chipseq_LCOR </th>
#    <th style="text-align:right;"> chipseq_MAX </th>
#    <th style="text-align:right;"> chipseq_MAZ </th>
#    <th style="text-align:right;"> chipseq_MBD1 </th>
#    <th style="text-align:right;"> chipseq_MECOM </th>
#    <th style="text-align:right;"> chipseq_MED1 </th>
#    <th style="text-align:right;"> chipseq_MLX </th>
#    <th style="text-align:right;"> chipseq_MTF1 </th>
#    <th style="text-align:right;"> chipseq_MXD1 </th>
#    <th style="text-align:right;"> chipseq_MYBL2 </th>
#    <th style="text-align:right;"> chipseq_MYC </th>
#    <th style="text-align:right;"> chipseq_MYNN </th>
#    <th style="text-align:right;"> chipseq_NFE2 </th>
#    <th style="text-align:right;"> chipseq_NFIX </th>
#    <th style="text-align:right;"> chipseq_NFXL1 </th>
#    <th style="text-align:right;"> chipseq_NFYA </th>
#    <th style="text-align:right;"> chipseq_NR1H2 </th>
#    <th style="text-align:right;"> chipseq_NR2C2 </th>
#    <th style="text-align:right;"> chipseq_NR2F6 </th>
#    <th style="text-align:right;"> chipseq_NR3C1 </th>
#    <th style="text-align:right;"> chipseq_NR4A1 </th>
#    <th style="text-align:right;"> chipseq_NRF1 </th>
#    <th style="text-align:right;"> chipseq_OTX1 </th>
#    <th style="text-align:right;"> chipseq_PATZ1 </th>
#    <th style="text-align:right;"> chipseq_PHB </th>
#    <th style="text-align:right;"> chipseq_PHTF2 </th>
#    <th style="text-align:right;"> chipseq_POLR2A </th>
#    <th style="text-align:right;"> chipseq_PPARD </th>
#    <th style="text-align:right;"> chipseq_PREB </th>
#    <th style="text-align:right;"> chipseq_PRMT5 </th>
#    <th style="text-align:right;"> chipseq_PURB </th>
#    <th style="text-align:right;"> chipseq_RAD21 </th>
#    <th style="text-align:right;"> chipseq_RBPJ </th>
#    <th style="text-align:right;"> chipseq_RERE </th>
#    <th style="text-align:right;"> chipseq_REST </th>
#    <th style="text-align:right;"> chipseq_RFX7 </th>
#    <th style="text-align:right;"> chipseq_RHOXF2B </th>
#    <th style="text-align:right;"> chipseq_RNF219 </th>
#    <th style="text-align:right;"> chipseq_RREB1 </th>
#    <th style="text-align:right;"> chipseq_SLC30A9 </th>
#    <th style="text-align:right;"> chipseq_SMAD3 </th>
#    <th style="text-align:right;"> chipseq_SMAD4 </th>
#    <th style="text-align:right;"> chipseq_SNAPC5 </th>
#    <th style="text-align:right;"> chipseq_SP1 </th>
#    <th style="text-align:right;"> chipseq_SREBF2 </th>
#    <th style="text-align:right;"> chipseq_SRF </th>
#    <th style="text-align:right;"> chipseq_STAG1 </th>
#    <th style="text-align:right;"> chipseq_STAT5B </th>
#    <th style="text-align:right;"> chipseq_STAT6 </th>
#    <th style="text-align:right;"> chipseq_TAL1 </th>
#    <th style="text-align:right;"> chipseq_TBPL1 </th>
#    <th style="text-align:right;"> chipseq_TBX18 </th>
#    <th style="text-align:right;"> chipseq_TCF15 </th>
#    <th style="text-align:right;"> chipseq_TCF3 </th>
#    <th style="text-align:right;"> chipseq_TCFL5 </th>
#    <th style="text-align:right;"> chipseq_TEAD1 </th>
#    <th style="text-align:right;"> chipseq_TEAD4 </th>
#    <th style="text-align:right;"> chipseq_TFAM </th>
#    <th style="text-align:right;"> chipseq_TFAP4 </th>
#    <th style="text-align:right;"> chipseq_TFCP2 </th>
#    <th style="text-align:right;"> chipseq_TFDP1 </th>
#    <th style="text-align:right;"> chipseq_TFE3 </th>
#    <th style="text-align:right;"> chipseq_TGIF2 </th>
#    <th style="t

# %%
print(dim(mat))
# Out:
# [1] 110648    248

# %%
mat_region_annot_merge_chipseq_tss = mat

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "matrix.annotation.tss.chipseq_histone.chipseq_encode4.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

mat = mat_region_annot_merge_chipseq_tss
write_tsv(mat, txt_fpath)

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "matrix.annotation.subset.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

mat = mat_region_annot_merge_subset
write_tsv(mat, txt_fpath)

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "matrix.annotation.tss.chipseq_histone.chipseq_encode4.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

mat = dat_region_annot_merge_chipseq_tss
write_tsv(mat, txt_fpath)

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "matrix.annotation.full.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

mat = mat_region_annot_merge_subset
write_tsv(mat, txt_fpath)
