# %% [raw]
# ---
# title: Region annotation 023 (ASTARR MACS peaks)
# subtitle: Summarize annotations (ChIP-seq; histone)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# **Set global variables**

# %%
txt_fdiry = file.path(FD_RES, "region", "summary")
vec = dir(txt_fdiry)
for (txt in vec){cat(txt, "\n")}
# Out:
# annotation.macs.label.region_A.tsv
# annotation.macs.label.region_B.chipseq_full.tsv
# annotation.macs.label.region_B.chipseq_subset.tsv
# annotation.macs.label.region_B.main.tsv

# %%
TXT_FDIRY_REGION_LABEL   = file.path(FD_RES, "region", "summary")
TXT_FNAME_REGION_LABEL_A = "annotation.macs.label.region_A.tsv"
TXT_FNAME_REGION_LABEL_B = "annotation.macs.label.region_B.chipseq_full.tsv"

# %% [markdown]
# ## Import data

# %%
txt_fdiry = TXT_FDIRY_REGION_LABEL
txt_fname = TXT_FNAME_REGION_LABEL_A
txt_fpath = file.path(txt_fdiry, txt_fname)

dat_region_label_A = read_tsv(txt_fpath, show_col_types = FALSE)
dat_region_label_A
# Out:
#   Folder          FName
# 1 fcc_astarr_macs ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz
# 2 fcc_astarr_macs ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#   Label
# 1 fcc_astarr_macs_input_overlap
# 2 fcc_astarr_macs_input_union

# %%
txt_fdiry = TXT_FDIRY_REGION_LABEL
txt_fname = TXT_FNAME_REGION_LABEL_B
txt_fpath = file.path(txt_fdiry, txt_fname)

dat_region_label_B = read_tsv(txt_fpath, show_col_types = FALSE)
dat_region_label_B
# Out:
#     Folder
# 1   encode_chipseq_flagship
# 2   encode_chipseq_flagship
# 3   encode_chipseq_flagship
# 4   encode_chipseq_flagship
# 5   encode_chipseq_flagship
# 6   encode_chipseq_flagship
# 7   encode_chipseq_flagship
# 8   encode_chipseq_flagship
# 9   encode_chipseq_flagship
# 10  encode_chipseq_flagship
# 11  encode_chipseq_flagship
# 12  encode_chipseq_flagship
# 13  encode_chipseq_flagship
# 14  encode_chipseq_flagship
# 15  encode_chipseq_flagship
# 16  encode_chipseq_flagship
# 17  encode_chipseq_flagship
# 18  encode_chipseq_flagship
# 19  encode_chipseq_flagship
# 20  encode_chipseq_flagship
# 21  encode_chipseq_flagship
# 22  encode_chipseq_flagship
# 23  encode_chipseq_flagship
# 24  encode_chipseq_flagship
# 25  encode_chipseq_flagship
# 26  encode_chipseq_flagship
# 27  encode_chipseq_flagship
# 28  encode_chipseq_flagship
# 29  encode_chipseq_flagship
# 30  encode_chipseq_flagship
# ⋮   ⋮
# 724 encode_chipseq_flagship
# 725 encode_chipseq_flagship
# 726 encode_chipseq_flagship
# 727 encode_chipseq_flagship
# 728 encode_chipseq_flagship
# 729 encode_chipseq_flagship
# 730 encode_chipseq_flagship
# 731 encode_chipseq_flagship
# 732 encode_chipseq_flagship
# 733 encode_chipseq_flagship
# 734 encode_chipseq_flagship
# 735 encode_chipseq_histone
# 736 encode_chipseq_histone
# 737 encode_chipseq_histone
# 738 encode_chipseq_histone
# 739 encode_chipseq_histone
# 740 encode_chipseq_histone
# 741 encode_chipseq_histone
# 742 encode_chipseq_histone
# 743 encode_chipseq_histone
# 744 encode_chipseq_histone
# 745 encode_chipseq_histone
# 746 encode_chipseq_histone
# 747 encode_chipseq_histone
# 748 encode_chipseq_histone
# 749 encode_chipseq_histone
# 750 encode_chipseq_histone
# 751 encode_chipseq_histone
# 752 encode_chipseq_histone
# 753 encode_chipseq_histone
#     FName
# 1   K562.hg38.ENCSR000AKO.ENCFF769AUF.ChIPseq.CTCF.bed.gz
# 2   K562.hg38.ENCSR000AQA.ENCFF807FNB.ChIPseq.KDM5B.bed.gz
# 3   K562.hg38.ENCSR000AQD.ENCFF408NUX.ChIPseq.CHD1.bed.gz
# 4   K562.hg38.ENCSR000AQE.ENCFF804RVA.ChIPseq.EZH2.bed.gz
# 5   K562.hg38.ENCSR000AQF.ENCFF669MJX.ChIPseq.HDAC1.bed.gz
# 6   K562.hg38.ENCSR000AQG.ENCFF182MPT.ChIPseq.HDAC2.bed.gz
# 7   K562.hg38.ENCSR000AQH.ENCFF981ISM.ChIPseq.PHF8.bed.gz
# 8   K562.hg38.ENCSR000AQI.ENCFF942VGF.ChIPseq.RBBP5.bed.gz
# 9   K562.hg38.ENCSR000AQJ.ENCFF383IEP.ChIPseq.SAP30.bed.gz
# 10  K562.hg38.ENCSR000ATJ.ENCFF736FGN.ChIPseq.HDAC6.bed.gz
# 11  K562.hg38.ENCSR000ATL.ENCFF985QBS.ChIPseq.CHD4.bed.gz
# 12  K562.hg38.ENCSR000ATM.ENCFF539MIO.ChIPseq.REST.bed.gz
# 13  K562.hg38.ENCSR000ATT.ENCFF532VPN.ChIPseq.CREBBP.bed.gz
# 14  K562.hg38.ENCSR000ATU.ENCFF258XBJ.ChIPseq.CBX2.bed.gz
# 15  K562.hg38.ENCSR000ATV.ENCFF068OEJ.ChIPseq.CBX3.bed.gz
# 16  K562.hg38.ENCSR000ATW.ENCFF522HZT.ChIPseq.CBX8.bed.gz
# 17  K562.hg38.ENCSR000ATX.ENCFF054XCG.ChIPseq.KDM1A.bed.gz
# 18  K562.hg38.ENCSR000ATY.ENCFF816AEF.ChIPseq.NCOR1.bed.gz
# 19  K562.hg38.ENCSR000ATZ.ENCFF349VSP.ChIPseq.KAT2B.bed.gz
# 20  K562.hg38.ENCSR000AUA.ENCFF923GDR.ChIPseq.RNF2.bed.gz
# 21  K562.hg38.ENCSR000AUB.ENCFF821XJU.ChIPseq.SIRT6.bed.gz
# 22  K562.hg38.ENCSR000AUC.ENCFF647TBC.ChIPseq.SUZ12.bed.gz
# 23  K562.hg38.ENCSR000AUT.ENCFF267QRI.ChIPseq.SETDB1.bed.gz
# 24  K562.hg38.ENCSR000AVD.ENCFF722UJW.ChIPseq.CHD7.bed.gz
# 25  K562.hg38.ENCSR000AVE.ENCFF862UUR.ChIPseq.WHSC1.bed.gz
# 26  K562.hg38.ENCSR000BGW.ENCFF888CKG.ChIPseq.SPI1.bed.gz
# 27  K562.hg38.ENCSR000BGX.ENCFF742ZHT.ChIPseq.SIX5.bed.gz
# 28  K562.hg38.ENCSR000BKF.ENCFF146GZZ.ChIPseq.ZBTB33.bed.gz
# 29  K562.hg38.ENCSR000BKH.ENCFF070ZTX.ChIPseq.BCLAF1.bed.gz
# 30  K562.hg38.ENCSR000BKM.ENCFF242YZU.ChIPseq.GATA2.bed.gz
# ⋮   ⋮
# 724 K562.hg38.ENCSR987KYK.ENCFF159END.ChIPseq.ZNF717.bed.gz
# 725 K562.hg38.ENCSR987PBI.ENCFF412WOK.ChIPseq.DNMT1.bed.gz
# 726 K562.hg38.ENCSR990AZC.ENCFF583XAW.ChIPseq.MCM3.bed.gz
# 727 K562.hg38.ENCSR991ELG.ENCFF553GPK.ChIPseq.SP1.bed.gz
# 728 K562.hg38.ENCSR992KLV.ENCFF749GMT.ChIPseq.MYNN.bed.gz
# 729 K562.hg38.ENCSR995FUM.ENCFF670RLH.ChIPseq.ZNF79.bed.gz
# 730 K562.hg38.ENCSR996ESX.ENCFF321LMQ.ChIPseq.NFRKB.bed.gz
# 731 K562.hg38.ENCSR996SKD.ENCFF798LLI.ChIPseq.CXXC5.bed.gz
# 732 K562.hg38.ENCSR997NGQ.ENCFF137OGC.ChIPseq.XRCC3.bed.gz
# 733 K562.hg38.ENCSR998AJK.ENCFF777PKJ.ChIPseq.NRF1.bed.gz
# 734 K562.hg38.ENCSR998OMC.ENCFF392MAR.ChIPseq.TFCP2.bed.gz
# 735 K562.hg38.ENCSR000AKP.ENCFF544LXB.ChIPseq.H3K27ac.bed.gz
# 736 K562.hg38.ENCSR000AKQ.ENCFF323WOT.ChIPseq.H3K27me3.bed.gz
# 737 K562.hg38.ENCSR000AKR.ENCFF193ERO.ChIPseq.H3K36me3.bed.gz
# 738 K562.hg38.ENCSR000AKS.ENCFF135ZLM.ChIPseq.H3K4me1.bed.gz
# 739 K562.hg38.ENCSR000AKT.ENCFF749KLQ.ChIPseq.H3K4me2.bed.gz
# 740 K562.hg38.ENCSR000AKU.ENCFF689QIJ.ChIPseq.H3K4me3.bed.gz
# 741 K562.hg38.ENCSR000AKV.ENCFF891CHI.ChIPseq.H3K9ac.bed.gz
# 742 K562.hg38.ENCSR000AKW.ENCFF462AVD.ChIPseq.H3K9me1.bed.gz
# 743 K562.hg38.ENCSR000AKX.ENCFF909RKY.ChIPseq.H4K20me1.bed.gz
# 744 K562.hg38.ENCSR000APC.ENCFF213OTI.ChIPseq.H2AFZ.bed.gz
# 745 K562.hg38.ENCSR000APD.ENCFF209OQD.ChIPseq.H3K79me2.bed.gz
# 746 K562.hg38.ENCSR000APE.ENCFF963GZJ.ChIPseq.H3K9me3.bed.gz
# 747 K562.hg38.ENCSR000DWB.ENCFF561OUZ.ChIPseq.H3K36me3.bed.gz
# 748 K562.hg38.ENCSR000DWD.ENCFF706WUF.ChIPseq.H3K4me3.bed.gz
# 749 K562.hg38.ENCSR000EVZ.ENCFF148UQI.ChIPseq.H3K9ac.bed.gz
# 750 K562.hg38.ENCSR000EWA.ENCFF122CSI.ChIPseq.H3K4me3.bed.gz
# 751 K562.hg38.ENCSR000EWB.ENCFF801AHF.ChIPseq.H3K27me3.bed.gz
# 752 K562.hg38.ENCSR000EWC.ENCFF540NGG.ChIPseq.H3K4me1.bed.gz
# 753 K562.hg38.ENCSR668LDD.ENCFF885FQN.ChIPseq.H3K4me3.bed.gz
#     Label
# 1   chipseq_CTCF_ENCFF769AUF
# 2   chipseq_KDM5B_ENCFF807FNB
# 3   chipseq_CHD1_ENCFF408NUX
# 4   chipseq_EZH2_ENCFF804RVA
# 5   chipseq_HDAC1_ENCFF669MJX
# 6   chipseq_HDAC2_ENCFF182MPT
# 7   chipseq_PHF8_ENCFF981ISM
# 8   chipseq_RBBP5_ENCFF942VGF
# 9   chipseq_SAP30_ENCFF383IEP
# 10  chipseq_HDAC6_ENCFF736FGN
# 11  chipseq_CHD4_ENCFF985QBS
# 12  chipseq_REST_ENCFF539MIO
# 13  chipseq_CREBBP_ENCFF532VPN
# 14  chipseq_CBX2_ENCFF258XBJ
# 15  chipseq_CBX3_ENCFF068OEJ
# 16  chipseq_CBX8_ENCFF522HZT
# 17  chipseq_KDM1A_ENCFF054XCG
# 18  chipseq_NCOR1_ENCFF816AEF
# 19  chipseq_KAT2B_ENCFF349VSP
# 20  chipseq_RNF2_ENCFF923GDR
# 21  chipseq_SIRT6_ENCFF821XJU
# 22  chipseq_SUZ12_ENCFF647TBC
# 23  chipseq_SETDB1_ENCFF267QRI
# 24  chipseq_CHD7_ENCFF722UJW
# 25  chipseq_WHSC1_ENCFF862UUR
# 26  chipseq_SPI1_ENCFF888CKG
# 27  chipseq_SIX5_ENCFF742ZHT
# 28  chipseq_ZBTB33_ENCFF146GZZ
# 29  chipseq_BCLAF1_ENCFF070ZTX
# 30  chipseq_GATA2_ENCFF242YZU
# ⋮   ⋮
# 724 chipseq_ZNF717_ENCFF159END
# 725 chipseq_DNMT1_ENCFF412WOK
# 726 chipseq_MCM3_ENCFF583XAW
# 727 chipseq_SP1_ENCFF553GPK
# 728 chipseq_MYNN_ENCFF749GMT
# 729 chipseq_ZNF79_ENCFF670RLH
# 730 chipseq_NFRKB_ENCFF321LMQ
# 731 chipseq_CXXC5_ENCFF798LLI
# 732 chipseq_XRCC3_ENCFF137OGC
# 733 chipseq_NRF1_ENCFF777PKJ
# 734 chipseq_TFCP2_ENCFF392MAR
# 735 chipseq_H3K27ac_ENCFF544LXB
# 736 chipseq_H3K27me3_ENCFF323WOT
# 737 chipseq_H3K36me3_ENCFF193ERO
# 738 chipseq_H3K4me1_ENCFF135ZLM
# 739 chipseq_H3K4me2_ENCFF749KLQ
# 740 chipseq_H3K4me3_ENCFF689QIJ
# 741 chipseq_H3K9ac_ENCFF891CHI
# 742 chipseq_H3K9me1_ENCFF462AVD
# 743 chipseq_H4K20me1_ENCFF909RKY
# 744 chipseq_H2AFZ_ENCFF213OTI
# 745 chipseq_H3K79me2_ENCFF209OQD
# 746 chipseq_H3K9me3_ENCFF963GZJ
# 747 chipseq_H3K36me3_ENCFF561OUZ
# 748 chipseq_H3K4me3_ENCFF706WUF
# 749 chipseq_H3K9ac_ENCFF148UQI
# 750 chipseq_H3K4me3_ENCFF122CSI
# 751 chipseq_H3K27me3_ENCFF801AHF
# 752 chipseq_H3K4me1_ENCFF540NGG
# 753 chipseq_H3K4me3_ENCFF885FQN

# %% [markdown]
# **Check colnumn names**

# %%
dat = dat_region_label_B
vec = unique(dat$Folder)
vec_txt_region_folder_B = vec

for (txt_region_folder_B in vec_txt_region_folder_B){
    ###
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_B, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_B = dat_cname$Name

    ###
    cat(txt_region_folder_B, "\n")
    print(vec_txt_cname_B)
    cat("\n")
}
# Out:
# encode_chipseq_flagship
#  [1] "Chrom"       "ChromStart"  "ChromEnd"    "Name"        "Score"
#  [6] "Strand"      "SignalValue" "PValue"      "QValue"      "Peak"
#
# encode_chipseq_histone
#  [1] "Chrom"       "ChromStart"  "ChromEnd"    "Name"        "Score"
#  [6] "Strand"      "SignalValue" "PValue"      "QValue"      "Peak"

# %% [markdown]
# ## Main

# %%
dat = dat_region_label_A
lst = split(dat, 1:nrow(dat))
lst = lapply(lst, as.list)
lst_region_label_A = lst
lst
# Out:
# $`1`
# $`1`$Folder
# [1] "fcc_astarr_macs"
#
# $`1`$FName
# [1] "ASTARRseq_K562_KS91.hg38.Input.rep_all.max_overlaps.q5.bed.gz"
#
# $`1`$Label
# [1] "fcc_astarr_macs_input_overlap"
#
#
# $`2`
# $`2`$Folder
# [1] "fcc_astarr_macs"
#
# $`2`$FName
# [1] "ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz"
#
# $`2`$Label
# [1] "fcc_astarr_macs_input_union"

# %%
dat = dat_region_label_B
vec = unique(dat$Folder)
vec_txt_region_folder_B = vec
vec
# Out:
# [1] "encode_chipseq_flagship" "encode_chipseq_histone"

# %%
### init
dat = dat_region_label_A
lst = split(dat, 1:nrow(dat))
lst = lapply(lst, as.list)
lst_region_label_A = lst

dat = dat_region_label_B
vec = unique(dat$Folder)
vec_txt_region_folder_B = c("encode_chipseq_histone")

###
for (idx in seq_along(lst_region_label_A)){
    ###
    lst = lst_region_label_A[[idx]]
    txt_region_folder_A = lst$Folder
    txt_region_label_A  = lst$Label

    ###
    txt_fdiry = file.path(FD_RES, "region", txt_region_folder_A, "summary")
    txt_fname = "description.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
    vec_txt_cname_A = dat_cname$Name

    for (txt_region_folder_B in vec_txt_region_folder_B){
        ###
        txt_fdiry = file.path(FD_RES, "region", txt_region_folder_B, "summary")
        txt_fname = "description.tsv"
        txt_fpath = file.path(txt_fdiry, txt_fname)
        dat_cname = read_tsv(txt_fpath, show_col_types = FALSE)
        vec_txt_cname_B = dat_cname$Name

        ###
        vec_txt_cname = c(
            paste0(vec_txt_cname_A, "_A"),
            paste0(vec_txt_cname_B, "_B"),
            "Overlap"
        )
        
        ###
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A, 
            txt_region_folder_B
        )
        txt_fname = "*bed.gz"
        txt_fglob = file.path(txt_fdiry, txt_fname)
        
        vec_txt_fpath = Sys.glob(txt_fglob)
        vec_txt_fname = basename(vec_txt_fpath)

        ### show progress
        cat("===========================================\n")
        cat("Read annotation...", "\n")
        cat("Region A:", txt_region_folder_A, "|", txt_region_label_A, "\n")
        cat("Region B:", txt_region_folder_B, "\n")
        cat("FDiry:   ", txt_fdiry, "\n")
        cat("FName:   ", "\n")
        print(vec_txt_fname)
        cat("\n")
        flush.console()
        
        ###
        lst = lapply(vec_txt_fname, function(txt_fname){
            ###
            txt_fpath = file.path(txt_fdiry, txt_fname)
            
            ###
            vec = str_split(txt_fname, "\\.")[[1]]
            txt_annot_A = vec[1]
            txt_annot_B = vec[2]

            ###
            vec = str_split(txt_annot_B, "_")[[1]]
            txt_group_B = "ChIP-seq; Histone"
            txt_label_B = vec[2]
            
            ###
            dat = read_tsv(txt_fpath, col_names = vec_txt_cname, show_col_types = FALSE)
            dat = dat %>% 
                dplyr::mutate(
                    Region_A = paste0(Chrom_A, ":", ChromStart_A, "-", ChromEnd_A),
                    Region_B = paste0(Chrom_B, ":", ChromStart_B, "-", ChromEnd_B),
                    Annotation_A = txt_annot_A,
                    Annotation_B = txt_annot_B,
                    Group_B      = txt_group_B,
                    Label_B      = txt_label_B
                )
            return(dat)
        }) 

        ###
        dat = bind_rows(lst)
        dat = dat %>%
            dplyr::group_by(
                Chrom_A, ChromStart_A, ChromEnd_A, Region_A,
                Annotation_A,
                Annotation_B,
                Group_B, 
                Label_B
            ) %>%
            dplyr::summarise(
                Region_B = paste(Region_B, collapse="|"),
                Count  = n(),
                .groups = "drop")

        ###
        txt_fdiry = file.path(
            FD_RES, 
            "region_annotation",
            txt_region_label_A,
            "summary"
        )
        txt_fname = paste("region", "summary", txt_region_folder_B, "tsv", sep = ".")
        txt_fpath = file.path(txt_fdiry, txt_fname)

        dir.create(txt_fdiry, showWarnings = FALSE)
        write_tsv(dat, txt_fpath)
        
        ### show progress
        cat("Save annotation...",  "\n")
        cat("FDiry:", txt_fdiry, "\n")
        cat("FName:", txt_fname, "\n")
        cat("\n")
        flush.console()
    } ### end loop region B
} ### end loop region A
# Out:
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_overlap
# Region B: encode_chipseq_histone
# FDiry:    /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# FName:
#  [1] "fcc_astarr_macs_input_overlap.chipseq_H2AFZ_ENCFF213OTI.bed.gz"
#  [2] "fcc_astarr_macs_input_overlap.chipseq_H3K27ac_ENCFF544LXB.bed.gz"
#  [3] "fcc_astarr_macs_input_overlap.chipseq_H3K27me3_ENCFF323WOT.bed.gz"
#  [4] "fcc_astarr_macs_input_overlap.chipseq_H3K27me3_ENCFF801AHF.bed.gz"
#  [5] "fcc_astarr_macs_input_overlap.chipseq_H3K36me3_ENCFF193ERO.bed.gz"
#  [6] "fcc_astarr_macs_input_overlap.chipseq_H3K36me3_ENCFF561OUZ.bed.gz"
#  [7] "fcc_astarr_macs_input_overlap.chipseq_H3K4me1_ENCFF135ZLM.bed.gz"
#  [8] "fcc_astarr_macs_input_overlap.chipseq_H3K4me1_ENCFF540NGG.bed.gz"
#  [9] "fcc_astarr_macs_input_overlap.chipseq_H3K4me2_ENCFF749KLQ.bed.gz"
# [10] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF122CSI.bed.gz"
# [11] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF689QIJ.bed.gz"
# [12] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF706WUF.bed.gz"
# [13] "fcc_astarr_macs_input_overlap.chipseq_H3K4me3_ENCFF885FQN.bed.gz"
# [14] "fcc_astarr_macs_input_overlap.chipseq_H3K79me2_ENCFF209OQD.bed.gz"
# [15] "fcc_astarr_macs_input_overlap.chipseq_H3K9ac_ENCFF148UQI.bed.gz"
# [16] "fcc_astarr_macs_input_overlap.chipseq_H3K9ac_ENCFF891CHI.bed.gz"
# [17] "fcc_astarr_macs_input_overlap.chipseq_H3K9me1_ENCFF462AVD.bed.gz"
# [18] "fcc_astarr_macs_input_overlap.chipseq_H3K9me3_ENCFF963GZJ.bed.gz"
# [19] "fcc_astarr_macs_input_overlap.chipseq_H4K20me1_ENCFF909RKY.bed.gz"
#
# Save annotation...
# FDiry: /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary
# FName: region.summary.encode_chipseq_histone.tsv
#
# ===========================================
# Read annotation...
# Region A: fcc_astarr_macs | fcc_astarr_macs_input_union
# Region B: encode_chipseq_histone
# FDiry:    /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_histone
# FName:
#  [1] "fcc_astarr_macs_input_union.chipseq_H2AFZ_ENCFF213OTI.bed.gz"
#  [2] "fcc_astarr_macs_input_union.chipseq_H3K27ac_ENCFF544LXB.bed.gz"
#  [3] "fcc_astarr_macs_input_union.chipseq_H3K27me3_ENCFF323WOT.bed.gz"
#  [4] "fcc_astarr_macs_input_union.chipseq_H3K27me3_ENCFF801AHF.bed.gz"
#  [5] "fcc_astarr_macs_input_union.chipseq_H3K36me3_ENCFF193ERO.bed.gz"
#  [6] "fcc_astarr_macs_input_union.chipseq_H3K36me3_ENCFF561OUZ.bed.gz"
#  [7] "fcc_astarr_macs_input_union.chipseq_H3K4me1_ENCFF135ZLM.bed.gz"
#  [8] "fcc_astarr_macs_input_union.chipseq_H3K4me1_ENCFF540NGG.bed.gz"
#  [9] "fcc_astarr_macs_input_union.chipseq_H3K4me2_ENCFF749KLQ.bed.gz"
# [10] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF122CSI.bed.gz"
# [11] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF689QIJ.bed.gz"
# [12] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF706WUF.bed.gz"
# [13] "fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF885FQN.bed.gz"
# [14] "fcc_astarr_macs_input_union.chipseq_H3K79me2_ENCFF209OQD.bed.gz"
# [15] "fcc_astarr_macs_input_union.chipseq_H3K9ac_ENCFF148UQI.bed.gz"
# [16] "fcc_astarr_macs_input_union.chipseq_H3K9ac_ENCFF891CHI.bed.gz"
# [17] "fcc_astarr_macs_input_union.chipseq_H3K9me1_ENCFF462AVD.bed.gz"
# [18] "fcc_astarr_macs_input_union.chipseq_H3K9me3_ENCFF963GZJ.bed.gz"
# [19] "fcc_astarr_macs_input_union.chipseq_H4K20me1_ENCFF909RKY.bed.gz"
#
# Save annotation...
# FDiry: /mount/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/summary
# FName: region.summary.encode_chipseq_histone.tsv

# %%
head(dat)
# Out:
#   Chrom_A ChromStart_A ChromEnd_A Region_A
# 1 chr1     16015        16477     chr1:16015-16477
# 2 chr1     16015        16477     chr1:16015-16477
# 3 chr1    118518       118743     chr1:118518-118743
# 4 chr1    118518       118743     chr1:118518-118743
# 5 chr1    137737       139544     chr1:137737-139544
# 6 chr1    137737       139544     chr1:137737-139544
#   Annotation_A                Annotation_B                 Group_B
# 1 fcc_astarr_macs_input_union chipseq_H3K36me3_ENCFF193ERO ChIP-seq; Histone
# 2 fcc_astarr_macs_input_union chipseq_H3K36me3_ENCFF561OUZ ChIP-seq; Histone
# 3 fcc_astarr_macs_input_union chipseq_H3K4me3_ENCFF689QIJ  ChIP-seq; Histone
# 4 fcc_astarr_macs_input_union chipseq_H3K9ac_ENCFF891CHI   ChIP-seq; Histone
# 5 fcc_astarr_macs_input_union chipseq_H3K27ac_ENCFF544LXB  ChIP-seq; Histone
# 6 fcc_astarr_macs_input_union chipseq_H3K36me3_ENCFF193ERO ChIP-seq; Histone
#   Label_B  Region_B                                                 Count
# 1 H3K36me3 chr1:16092-16380                                         1
# 2 H3K36me3 chr1:16209-16339                                         1
# 3 H3K4me3  chr1:118439-118645                                       1
# 4 H3K9ac   chr1:118435-119129                                       1
# 5 H3K27ac  chr1:137650-138169|chr1:138356-139236|chr1:139285-139490 3
# 6 H3K36me3 chr1:139300-139473                                       1
