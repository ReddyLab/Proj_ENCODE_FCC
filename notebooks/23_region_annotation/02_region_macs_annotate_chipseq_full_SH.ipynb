# %% [raw]
# ---
# title: Region annotation 013 (ASTARR MACS peaks)
# subtitle: Annotate peaks (ChIP-seq; full)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: HARDAC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP):
# ...

# %% [markdown]
# **Set global variables**

# %%
ls ${FD_RES}/region
# Out:
# encode_chipseq_encode4   encode_open_chromatin  genome_tss
# encode_chipseq_flagship  fcc_astarr_csaw        hic_insitu_K562_ENCSR545YBD
# encode_chipseq_histone   fcc_astarr_macs        hic_intact_K562_deep
# encode_chipseq_subset    fcc_crispri_hcrff      hic_intact_K562_ENCSR479XDG
# encode_chromatin_states  fcc_screened           summary

# %%
ls ${FD_RES}/region/summary
# Out:
# annotation.macs.label.region_A.tsv
# annotation.macs.label.region_B.chipseq_full.tsv
# annotation.macs.label.region_B.chipseq_subset.tsv
# annotation.macs.label.region_B.main.tsv
# metadata.label.astarr_macs.tsv
# metadata.label.chipseq_full.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
#FP_REGION_LABEL_A=${FD_RES}/region/summary/annotation.macs.label.region_A.tsv
#FP_REGION_LABEL_B=${FD_RES}/region/summary/annotation.macs.label.region_B.chipseq_full.tsv
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/metadata.label.chipseq_full.tsv

# %%
cat ${FP_REGION_LABEL_A}
# Out:
# Folder	FName	Label
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# fcc_astarr_macs	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union

# %%
cat ${FP_REGION_LABEL_B}
# Out:
# Folder	FName	Label
# encode_chipseq_encode4	ENCFF124KCE.bed.gz	chipseq_ZBTB43_ENCFF124KCE
# encode_chipseq_encode4	ENCFF173QUY.bed.gz	chipseq_E2F5_ENCFF173QUY
# encode_chipseq_encode4	ENCFF442RYH.bed.gz	chipseq_ZNF431_ENCFF442RYH
# encode_chipseq_encode4	ENCFF817EJA.bed.gz	chipseq_ZNF512_ENCFF817EJA
# encode_chipseq_encode4	ENCFF430YXJ.bed.gz	chipseq_IRF2_ENCFF430YXJ
# encode_chipseq_encode4	ENCFF881MMD.bed.gz	chipseq_ZNF124_ENCFF881MMD
# encode_chipseq_encode4	ENCFF786CRW.bed.gz	chipseq_NFYA_ENCFF786CRW
# encode_chipseq_encode4	ENCFF586MZX.bed.gz	chipseq_ELK1_ENCFF586MZX
# encode_chipseq_encode4	ENCFF382QUI.bed.gz	chipseq_ZNF277_ENCFF382QUI
# encode_chipseq_encode4	ENCFF122FTW.bed.gz	chipseq_STAT5B_ENCFF122FTW
# encode_chipseq_encode4	ENCFF794SCQ.bed.gz	chipseq_ID3_ENCFF794SCQ
# encode_chipseq_encode4	ENCFF596HNP.bed.gz	chipseq_ZNF143_ENCFF596HNP
# encode_chipseq_encode4	ENCFF086FAZ.bed.gz	chipseq_ARID4B_ENCFF086FAZ
# ...

# %% [markdown]
# ## Preview

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}' | head -n 3)
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# awk: cmd. line:1: (FILENAME=- FNR=182) fatal: print to "standard output" failed (Broken pipe)
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: chipseq_ZBTB43_ENCFF124KCE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_encode4
# Output FName:   fcc_astarr_macs_input_overlap.chipseq_ZBTB43_ENCFF124KCE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.chipseq_ZBTB43_ENCFF124KCE.txt
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: chipseq_E2F5_ENCFF173QUY
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_encode4
# Output FName:   fcc_astarr_macs_input_overlap.chipseq_E2F5_ENCFF173QUY.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.chipseq_E2F5_ENCFF173QUY.txt
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# ...

# %% [markdown]
# ## Execute

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/region/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_annotation/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bedtools_intersect.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir  -p ${FD_OUT}
        sbatch -p ${NODE} \
            --exclude=dl-01 \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FD_PRJ} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: chipseq_ZBTB43_ENCFF124KCE
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_encode4
# Output FName:   fcc_astarr_macs_input_overlap.chipseq_ZBTB43_ENCFF124KCE.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.chipseq_ZBTB43_ENCFF124KCE.txt
#
# Submitted batch job 30858060
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: chipseq_E2F5_ENCFF173QUY
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_encode4
# Output FName:   fcc_astarr_macs_input_overlap.chipseq_E2F5_ENCFF173QUY.bed.gz
# Log    FPath:   ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.chipseq_E2F5_ENCFF173QUY.txt
#
# Submitted batch job 30858061
#
# ...
# Output Label A: fcc_astarr_macs_input_overlap
# ...

# %% [markdown]
# ## Review

# %%
ls /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
# Out:
# fcc_astarr_macs_input_overlap  fcc_astarr_macs_input_union

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region
ls ${FDIRY}/encode_chipseq_histone/K562* | wc -l
# Out:
# 19

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region
ls ${FDIRY}/encode_chipseq_encode4/*bed.gz | wc -l
# Out:
# 237

# %% [markdown]
# ```
# FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region
# ls ${FDIRY}/encode_chipseq_flagship/K562* | wc -l
# > 734
# ```

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF885FQN.txt
# Out:
# Hostname:           x2-03-3.genome.duke.edu
# Slurm Array Index:
# Time Stamp:         06-18-24+13:13:35
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/K562.hg38.ENCSR668LDD.ENCFF885FQN.ChIPseq.H3K4me3.bed.gz
#
# show first few lines of input
# chr1	137611	138186	Peak_11639	868	.	17.17918	86.81271	84.40081	199
# chr1	138333	139668	Peak_13836	392	.	10.05165	39.23344	36.98688	859
# chr1	777481	780024	Peak_8178	1000	.	35.08939	233.59062	230.75691	1621
# chr1	825575	826429	Peak_16217	190	.	4.61296	19.01589	16.87489	277
# ...

# %%
ls /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/encode* | wc -l
# Out:
# K562.hg38.ENCSR000AKP.ENCFF544LXB.ChIPseq.H3K27ac.bed.gz
# K562.hg38.ENCSR000AKQ.ENCFF323WOT.ChIPseq.H3K27me3.bed.gz
# K562.hg38.ENCSR000AKR.ENCFF193ERO.ChIPseq.H3K36me3.bed.gz
# K562.hg38.ENCSR000AKS.ENCFF135ZLM.ChIPseq.H3K4me1.bed.gz
# K562.hg38.ENCSR000AKT.ENCFF749KLQ.ChIPseq.H3K4me2.bed.gz
# K562.hg38.ENCSR000AKU.ENCFF689QIJ.ChIPseq.H3K4me3.bed.gz
# K562.hg38.ENCSR000AKV.ENCFF891CHI.ChIPseq.H3K9ac.bed.gz
# K562.hg38.ENCSR000AKW.ENCFF462AVD.ChIPseq.H3K9me1.bed.gz
# K562.hg38.ENCSR000AKX.ENCFF909RKY.ChIPseq.H4K20me1.bed.gz
# K562.hg38.ENCSR000APC.ENCFF213OTI.ChIPseq.H2AFZ.bed.gz
# K562.hg38.ENCSR000APD.ENCFF209OQD.ChIPseq.H3K79me2.bed.gz
# K562.hg38.ENCSR000APE.ENCFF963GZJ.ChIPseq.H3K9me3.bed.gz
# K562.hg38.ENCSR000DWB.ENCFF561OUZ.ChIPseq.H3K36me3.bed.gz
# K562.hg38.ENCSR000DWD.ENCFF706WUF.ChIPseq.H3K4me3.bed.gz
# K562.hg38.ENCSR000EVZ.ENCFF148UQI.ChIPseq.H3K9ac.bed.gz
# K562.hg38.ENCSR000EWA.ENCFF122CSI.ChIPseq.H3K4me3.bed.gz
# ...

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
FDIRY=${FDIRY}/fcc_astarr_macs_input_overlap/encode_chipseq_histone
ls ${FDIRY} | wc -l
# Out:
# 19

# %%
FDIRY=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation
FDIRY=${FDIRY}/fcc_astarr_macs_input_overlap/encode_chipseq_flagship
ls ${FDIRY} | wc -l
# Out:
# 734

# %%
cat ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.chipseq_H3K4me3_ENCFF885FQN.txt
# Out:
# Hostname:           x2-05-2
# Slurm Array Index:
# Time Stamp:         05-14-24+17:31:21
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/ASTARRseq_K562_KS91.hg38.Input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442
# chr1	14253	14645
# chr1	16015	16477
# chr1	17237	17772
# chr1	28903	29613
# chr1	30803	31072
# chr1	101603	101849
# chr1	115411	115986
# chr1	118518	118743
# chr1	136071	137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_histone/K562.hg38.ENCSR668LDD.ENCFF885FQN.ChIPseq.H3K4me3.bed.gz
#
# show first few lines of input
# chr1	137611	138186	Peak_11639	868	.	17.17918	86.81271	84.40081	199
# chr1	138333	139668	Peak_13836	392	.	10.05165	39.23344	36.98688	859
# chr1	777481	780024	Peak_8178	1000	.	35.08939	233.59062	230.75691	1621
# chr1	825575	826429	Peak_16217	190	.	4.61296	19.01589	16.87489	277
# chr1	826512	827941	Peak_8944	1000	.	31.25149	199.79292	197.06018	919
# ...
