# %% [raw]
# ---
# title: Prepare TF Modules 01
# subtitle: Explore the data
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity
# BASE DIRECTORY (FD_BASE): /mount
# REPO DIRECTORY (FD_REPO): /mount/repo
# WORK DIRECTORY (FD_WORK): /mount/work
# DATA DIRECTORY (FD_DATA): /mount/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /mount/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /mount/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /mount/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /mount/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /mount/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /mount/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /mount/repo/Proj_ENCODE_FCC/log
# PROJECT APP     (FD_APP): /mount/repo/Proj_ENCODE_FCC/app
# PROJECT REF     (FD_REF): /mount/repo/Proj_ENCODE_FCC/references

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
vec = dir(txt_fdiry)
vec = head(vec)
for (txt in vec){cat(txt, "\n")}
# Out:
# hclust.col.annotation.prepare.chipseq_full.fcc.tss.rds
# hclust.col.annotation.prepare.chipseq_full.only.rds
# hclust.col.annotation.test_chrX.chipseq_full.only.rds
# hclust.row.annotation.prepare.chipseq_full.fcc.tss.rds
# hclust.row.annotation.prepare.chipseq_full.only.rds
# hclust.row.annotation.test_chrX.chipseq_full.only.rds

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "result.summary.tfmodule.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_region_annot_module = dat
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Region             Group     Label
# 1 chr1  115429     115969   chr1:115429-115969 TF_Module Module_02
# 2 chr1  115429     115969   chr1:115429-115969 TF_Module Module_05
# 3 chr1  115429     115969   chr1:115429-115969 TF_Module Module_10
# 4 chr1  115429     115969   chr1:115429-115969 TF_Module Module_44
# 5 chr1  136201     137353   chr1:136201-137353 TF_Module Module_27
# 6 chr1  138321     139517   chr1:138321-139517 TF_Module Module_02

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region_annotation", 
    "fcc_astarr_macs_input_overlap",
    "summary"
)
txt_fname = "result.summary.fcc_peak_call.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)

dat_region_annot_fcc = dat
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Region             Group  Label    Label2
# 1 chr1   10038      10405   chr1:10038-10405   ASTARR ASTARR_R ASTARR_R
# 2 chr1   16025      16338   chr1:16025-16338   ASTARR ASTARR_R ASTARR_R
# 3 chr1   17288      17689   chr1:17288-17689   ASTARR ASTARR_R ASTARR_R
# 4 chr1   28934      29499   chr1:28934-29499   ASTARR ASTARR_R ASTARR_R
# 5 chr1  115429     115969   chr1:115429-115969 ASTARR ASTARR_A ASTARR_A
# 6 chr1  136201     137353   chr1:136201-137353 ASTARR ASTARR_R ASTARR_R
#   Label3
# 1 Repress (R)
# 2 Repress (R)
# 3 Repress (R)
# 4 Repress (R)
# 5 Active (A)
# 6 Repress (R)

# %%
txt_region = "fcc_astarr_macs_input_overlap"
txt_fdiry  = file.path(FD_RES, "region_coverage_fcc", txt_region, "summary")
txt_fname  = "result.coverage.zscore.final.tsv"
txt_fpath  = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)
dat_region_score = dat

print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 432505      9
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:left;"> Assay_Name </th>
#    <th style="text-align:left;"> Assay_Type </th>
#    <th style="text-align:left;"> Assay_Group </th>
#    <th style="text-align:left;"> Assay_Label </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr10 </td>
#    <td style="text-align:right;"> 100729094 </td>
#    <td style="text-align:right;"> 100729750 </td>
#    <td style="text-align:left;"> chr10:100729094-100729750 </td>
#    <td style="text-align:right;"> -0.3065107 </td>
#    <td style="text-align:left;"> CRISPRi_FlowFISH_K562_Riley_JinWoo </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCR FlowFISH </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr10 </td>
#    <td style="text-align:right;"> 100743501 </td>
#    <td style="text-align:right;"> 100744571 </td>
#    <td style="text-align:left;"> chr10:100743501-100744571 </td>
#    <td style="text-align:right;"> -0.2702473 </td>
#    <td style="text-align:left;"> CRISPRi_FlowFISH_K562_Riley_JinWoo </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCR FlowFISH </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr10 </td>
#    <td style="text-align:right;"> 100745413 </td>
#    <td style="text-align:right;"> 100745741 </td>
#    <td style="text-align:left;"> chr10:100745413-100745741 </td>
#    <td style="text-align:right;"> 0.1130381 </td>
#    <td style="text-align:left;"> CRISPRi_FlowFISH_K562_Riley_JinWoo </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCR FlowFISH </td>
#   </tr>
# </tbody>
# </table>

# %%
txt_fdiry = file.path(
    FD_RES, 
    "region", 
    "module_tf_shannon",
    "summary"
)
txt_fname = "matrix.TF_Module.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

dat = read_tsv(txt_fpath, show_col_types = FALSE)
dat = dat %>% tibble::column_to_rownames("TF") %>% t

mat_region_tfmodule = dat
fun_display_table(head(dat, 3))
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;">   </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ATF1 </th>
#    <th style="text-align:right;"> ATF2 </th>
#    <th style="text-align:right;"> ATF3 </th>
#    <th style="text-align:right;"> ATF4 </th>
#    <th style="text-align:right;"> ATF6 </th>
#    <th style="text-align:right;"> ATF7 </th>
#    <th style="text-align:right;"> BCL6 </th>
#    <th style="text-align:right;"> BHLHE40 </th>
#    <th style="text-align:right;"> BRD4 </th>
#    <th style="text-align:right;"> CBFB </th>
#    <th style="text-align:right;"> CBX1 </th>
#    <th style="text-align:right;"> CBX2 </th>
#    <th style="text-align:right;"> CBX5 </th>
#    <th style="text-align:right;"> CEBPB </th>
#    <th style="text-align:right;"> CEBPG </th>
#    <th style="text-align:right;"> CEBPZ </th>
#    <th style="text-align:right;"> CHCHD3 </th>
#    <th style="text-align:right;"> CHD2 </th>
#    <th style="text-align:right;"> CHD4 </th>
#    <th style="text-align:right;"> CREB1 </th>
#    <th style="text-align:right;"> CREB3 </th>
#    <th style="text-align:right;"> CREM </th>
#    <th style="text-align:right;"> CTCF </th>
#    <th style="text-align:right;"> DDIT3 </th>
#    <th style="text-align:right;"> DPF2 </th>
#    <th style="text-align:right;"> E2F1 </th>
#    <th style="text-align:right;"> E2F4 </th>
#    <th style="text-align:right;"> E2F5 </th>
#    <th style="text-align:right;"> E2F8 </th>
#    <th style="text-align:right;"> EGR1 </th>
#    <th style="text-align:right;"> EHMT2 </th>
#    <th style="text-align:right;"> ELF1 </th>
#    <th style="text-align:right;"> ELF4 </th>
#    <th style="text-align:right;"> ELK1 </th>
#    <th style="text-align:right;"> EP300 </th>
#    <th style="text-align:right;"> ESRRA </th>
#    <th style="text-align:right;"> ETS1 </th>
#    <th style="text-align:right;"> ETV5 </th>
#    <th style="text-align:right;"> ETV6 </th>
#    <th style="text-align:right;"> EZH2 </th>
#    <th style="text-align:right;"> FIP1L1 </th>
#    <th style="text-align:right;"> FOSL1 </th>
#    <th style="text-align:right;"> FOXA3 </th>
#    <th style="text-align:right;"> FOXJ3 </th>
#    <th style="text-align:right;"> FOXK1 </th>
#    <th style="text-align:right;"> FOXK2 </th>
#    <th style="text-align:right;"> FOXM1 </th>
#    <th style="text-align:right;"> FOXP1 </th>
#    <th style="text-align:right;"> FOXP4 </th>
#    <th style="text-align:right;"> FUS </th>
#    <th style="text-align:right;"> GABPA </th>
#    <th style="text-align:right;"> GABPB1 </th>
#    <th style="text-align:right;"> GATA2 </th>
#    <th style="text-align:right;"> GATAD2A </th>
#    <th style="text-align:right;"> GMEB1 </th>
#    <th style="text-align:right;"> GTF2F1 </th>
#    <th style="text-align:right;"> HBP1 </th>
#    <th style="text-align:right;"> HCFC1 </th>
#    <th style="text-align:right;"> HDAC1 </th>
#    <th style="text-align:right;"> HDAC2 </th>
#    <th style="text-align:right;"> HDAC6 </th>
#    <th style="text-align:right;"> HINFP </th>
#    <th style="text-align:right;"> HIVEP1 </th>
#    <th style="text-align:right;"> HMG20A </th>
#    <th style="text-align:right;"> HNRNPK </th>
#    <th style="text-align:right;"> HNRNPL </th>
#    <th style="text-align:right;"> HNRNPLL </th>
#    <th style="text-align:right;"> HOMEZ </th>
#    <th style="text-align:right;"> IKZF1 </th>
#    <th style="text-align:right;"> IRF1 </th>
#    <th style="text-align:right;"> IRF2 </th>
#    <th style="text-align:right;"> IRF9 </th>
#    <th style="text-align:right;"> JUN </th>
#    <th style="text-align:right;"> JUNB </th>
#    <th style="text-align:right;"> JUND </th>
#    <th style="text-align:right;"> KAT2B </th>
#    <th style="text-align:right;"> KAT7 </th>
#    <th style="text-align:right;"> KAT8 </th>
#    <th style="text-align:right;"> KDM1A </th>
#    <th style="text-align:right;"> KDM5B </th>
#    <th style="text-align:right;"> KLF13 </th>
#    <th style="text-align:right;"> KLF16 </th>
#    <th style="text-align:right;"> KLF6 </th>
#    <th style="text-align:right;"> LCOR </th>
#    <th style="text-align:right;"> MAFF </th>
#    <th style="text-align:right;"> MAFG </th>
#    <th style="text-align:right;"> MAFK </th>
#    <th style="text-align:right;"> MAX </th>
#    <th style="text-align:right;"> MAZ </th>
#    <th style="text-align:right;"> MEF2A </th>
#    <th style="text-align:right;"> MEF2D </th>
#    <th style="text-align:right;"> MEIS2 </th>
#    <th style="text-align:right;"> MGA </th>
#    <th style="text-align:right;"> MLX </th>
#    <th style="text-align:right;"> MNT </th>
#    <th style="text-align:right;"> MTA1 </th>
#    <th style="text-align:right;"> MTA3 </th>
#    <th style="text-align:right;"> MTF1 </th>
#    <th style="text-align:right;"> MXD1 </th>
#    <th style="text-align:right;"> MXI1 </th>
#    <th style="text-align:right;"> MYBL2 </th>
#    <th style="text-align:right;"> MYC </th>
#    <th style="text-align:right;"> MYNN </th>
#    <th style="text-align:right;"> NBN </th>
#    <th style="text-align:right;"> NCOA1 </th>
#    <th style="text-align:right;"> NCOR1 </th>
#    <th style="text-align:right;"> NFATC3 </th>
#    <th style="text-align:right;"> NFE2 </th>
#    <th style="text-align:right;"> NFE2L1 </th>
#    <th style="text-align:right;"> NFIC </th>
#    <th style="text-align:right;"> NFRKB </th>
#    <th style="text-align:right;"> NFYA </th>
#    <th style="text-align:right;"> NONO </th>
#    <th style="text-align:right;"> NR1H2 </th>
#    <th style="text-align:right;"> NR2C2 </th>
#    <th style="text-align:right;"> NR2F1 </th>
#    <th style="text-align:right;"> NR2F2 </th>
#    <th style="text-align:right;"> NR2F6 </th>
#    <th style="text-align:right;"> NR3C1 </th>
#    <th style="text-align:right;"> NRF1 </th>
#    <th style="text-align:right;"> PATZ1 </th>
#    <th style="text-align:right;"> PBX2 </th>
#    <th style="text-align:right;"> PCBP1 </th>
#    <th style="text-align:right;"> PCBP2 </th>
#    <th style="text-align:right;"> PHB2 </th>
#    <th style="text-align:right;"> PHF20 </th>
#    <th style="text-align:right;"> PHF21A </th>
#    <th style="text-align:right;"> PHF8 </th>
#    <th style="text-align:right;"> POLR2A </th>
#    <th style="text-align:right;"> POLR2AphosphoS2 </th>
#    <th style="text-align:right;"> POLR2AphosphoS5 </th>
#    <th style="text-align:right;"> POLR2G </th>
#    <th style="text-align:right;"> PRDM10 </th>
#    <th style="text-align:right;"> PRPF4 </th>
#    <th style="text-align:right;"> PTBP1 </th>
#    <th style="text-align:right;"> RAD21 </th>
#    <th style="text-align:right;"> RAD51 </th>
#    <th style="text-align:right;"> RBFOX2 </th>
#    <th style="text-align:right;"> RBM22 </th>
#    <th style="text-align:right;"> RBM39 </th>
#    <th style="text-align:right;"> RCOR1 </th>
#    <th style="text-align:right;"> RELA </th>
#    <th style="text-align:right;"> REST </th>
#    <th style="text-align:right;"> RFX1 </th>
#    <th style="text-align:right;"> RFX5 </th>
#    <th style="text-align:right;"> RNF2 </th>
#    <th style="text-align:right;"> RNF219 </th>
#    <th style="text-align:right;"> RREB1 </th>
#    <th style="text-align:right;"> SETDB1 </th>
#    <th style="text-align:right;"> SIN3A </th>
#    <th style="text-align:right;"> SIN3B </th>
#    <th style="text-align:right;"> SKIL </th>
#    <th style="text-align:right;"> SMAD1 </th>
#    <th style="text-align:right;"> SMAD4 </th>
#    <th style="text-align:right;"> SMARCC2 </th>
#    <th style="text-align:right;"> SMARCE1 </th>
#    <th style="text-align:right;"> SMC3 </th>
#    <th style="text-align:right;"> SOX6 </th>
#    <th style="text-align:right;"> SP1 </th>
#    <th style="text-align:right;"> SRF </th>
#    <th style="text-align:right;"> STAG1 </th>
#    <th style="text-align:right;"> STAT5B </th>
#    <th style="text-align:right;"> SUZ12 </th>
#    <th style="text-align:right;"> TAF15 </th>
#    <th style="text-align:right;"> TARDBP </th>
#    <th style="text-align:right;"> TBL1XR1 </th>
#    <th sty

# %%
dat = dplyr::left_join(
    dat_region_score,
    dat_region_annot_module, 
    by = c("Chrom", "ChromStart", "ChromEnd", "Region"),
    relationship = "many-to-many"
)

dat = dat %>% na.omit

dat_region_merge = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 939140     11
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:left;"> Assay_Name </th>
#    <th style="text-align:left;"> Assay_Type </th>
#    <th style="text-align:left;"> Assay_Group </th>
#    <th style="text-align:left;"> Assay_Label </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr10 </td>
#    <td style="text-align:right;"> 100743501 </td>
#    <td style="text-align:right;"> 100744571 </td>
#    <td style="text-align:left;"> chr10:100743501-100744571 </td>
#    <td style="text-align:right;"> -0.2702473 </td>
#    <td style="text-align:left;"> CRISPRi_FlowFISH_K562_Riley_JinWoo </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCR FlowFISH </td>
#    <td style="text-align:left;"> TF_Module </td>
#    <td style="text-align:left;"> Module_02 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 4092109 </td>
#    <td style="text-align:right;"> 4092511 </td>
#    <td style="text-align:left;"> chr11:4092109-4092511 </td>
#    <td style="text-align:right;"> -0.4462995 </td>
#    <td style="text-align:left;"> CRISPRi_FlowFISH_K562_Riley_JinWoo </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCR FlowFISH </td>
#    <td style="text-align:left;"> TF_Module </td>
#    <td style="text-align:left;"> Module_22 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 4094223 </td>
#    <td style="text-align:right;"> 4095304 </td>
#    <td style="text-align:left;"> chr11:4094223-4095304 </td>
#    <td style="text-align:right;"> -0.2301690 </td>
#    <td style="text-align:left;"> CRISPRi_FlowFISH_K562_Riley_JinWoo </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCRFF </td>
#    <td style="text-align:left;"> CRISPRi-HCR FlowFISH </td>
#    <td style="text-align:left;"> TF_Module </td>
#    <td style="text-align:left;"> Module_11 </td>
#   </tr>
# </tbody>
# </table>

# %%
dat = dat_region_merge
dat = dat %>% 
    dplyr::group_by(Assay_Type, Assay_Group, Assay_Label, Label) %>%
    dplyr::summarise(
        Score   = mean(Score),
        .groups = "drop"
    )
dat = dat %>% dplyr::mutate(Assay = Assay_Label)

dat_region_summary = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 420   6
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Assay_Type </th>
#    <th style="text-align:left;"> Assay_Group </th>
#    <th style="text-align:left;"> Assay_Label </th>
#    <th style="text-align:left;"> Label </th>
#    <th style="text-align:right;"> Score </th>
#    <th style="text-align:left;"> Assay </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_KS91 </td>
#    <td style="text-align:left;"> ATAC-STARR </td>
#    <td style="text-align:left;"> Module_01 </td>
#    <td style="text-align:right;"> 0.6821597 </td>
#    <td style="text-align:left;"> ATAC-STARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_KS91 </td>
#    <td style="text-align:left;"> ATAC-STARR </td>
#    <td style="text-align:left;"> Module_02 </td>
#    <td style="text-align:right;"> 0.0652575 </td>
#    <td style="text-align:left;"> ATAC-STARR </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_KS91 </td>
#    <td style="text-align:left;"> ATAC-STARR </td>
#    <td style="text-align:left;"> Module_03 </td>
#    <td style="text-align:right;"> 0.4990355 </td>
#    <td style="text-align:left;"> ATAC-STARR </td>
#   </tr>
# </tbody>
# </table>

# %%
mat = mat_region_tfmodule
mat = dist(mat, method = "manhattan")
res = hclust(mat, method = "ward.D2")

res_hclust_module = res
print(res)
# Out:
# Call:
# hclust(d = mat, method = "ward.D2")
#
# Cluster method   : ward.D2
# Distance         : manhattan
# Number of objects: 70

# %%
res = res_hclust_module
idx = res$order
vec = res$label[idx]

vec_txt_module = vec

# %%
vec_txt_assay= c(
    "Tiling-MPRA", "WHG-STARR", "ATAC-STARR", "Lenti-MPRA", 
    "CRISPRi-Growth", 
    "CRISPRi-HCR FlowFISH"
)

# %%
vec_txt_color = colorRampPalette(rev(brewer.pal(10, "RdBu")))
theme_color   = scale_fill_gradientn(colours = vec_txt_color(50), limits=c(-1.0, 1.0))
theme_text    = theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1, size=20))

# %%
dat = dat_region_summary
dat = dat %>% 
    dplyr::mutate(Assay = factor(Assay, levels=rev(vec_txt_assay))) %>%
    dplyr::mutate(Label = factor(Label, levels=rev(vec_txt_module)))
                
gpt = ggplot(dat, aes(x=Assay, y=Label, fill=Score)) + 
    geom_tile() + 
    labs(x="", y="") +
    theme_cowplot() + 
    background_grid() +
    theme_color +
    theme_text

gpt_module_score = gpt

# %%
options(repr.plot.height=20, repr.plot.width=10)
gpt = gpt_module_score
print(gpt)
# Out:
# plot without title

# %%
dat = dat_region_merge
dat = dat %>% 
    dplyr::filter(Label == "Module_36") %>%
    dplyr::filter(Assay_Type == "LMPRA") %>%
    dplyr::distinct()
head(dat)
# Out:
#   Chrom ChromStart ChromEnd Region               Assay_Type Peak_Call
# 1 chr1  1013154    1014482  chr1:1013154-1014482 LMPRA      Active (A)
# 2 chr1  2801325    2802251  chr1:2801325-2802251 LMPRA      Active (A)
# 3 chr1  3795662    3797054  chr1:3795662-3797054 LMPRA      Active (A)
# 4 chr1  5885475    5886502  chr1:5885475-5886502 LMPRA      Active (A)
# 5 chr1  6600854    6604169  chr1:6600854-6604169 LMPRA      Active (A)
# 6 chr1  8789343    8789802  chr1:8789343-8789802 LMPRA      Active (A)
#   Score     Assay_Name                   Assay_Group Assay_Label Group
# 1 0.5224621 MPRA_Lenti_K562_Nadav_Vikram LMPRA       Lenti-MPRA  TF_Module
# 2 1.1488030 MPRA_Lenti_K562_Nadav_Vikram LMPRA       Lenti-MPRA  TF_Module
# 3 1.9783382 MPRA_Lenti_K562_Nadav_Vikram LMPRA       Lenti-MPRA  TF_Module
# 4 0.7099454 MPRA_Lenti_K562_Nadav_Vikram LMPRA       Lenti-MPRA  TF_Module
# 5 1.6515516 MPRA_Lenti_K562_Nadav_Vikram LMPRA       Lenti-MPRA  TF_Module
# 6 2.4915607 MPRA_Lenti_K562_Nadav_Vikram LMPRA       Lenti-MPRA  TF_Module
#   Label
# 1 Module_36
# 2 Module_36
# 3 Module_36
# 4 Module_36
# 5 Module_36
# 6 Module_36

# %%
gpt = ggplot(dat, aes(x = Score)) +
    geom_histogram(binwidth = 0.1) +
    theme_cowplot()

options(repr.plot.height=5, repr.plot.width=7)
print(gpt)
# Out:
# plot without title

# %%
gpt = ggplot(dat, aes(x = Score)) +
    geom_histogram(binwidth = 0.1) +
    theme_cowplot()

options(repr.plot.height=5, repr.plot.width=7)
print(gpt)

# %%
dat = dat_region_annot_fcc
dat = dat %>% 
    dplyr::mutate(
        Assay_Type = Group,
        Peak_Call  = Label3
    ) %>%
    dplyr::select(Chrom, ChromStart, ChromEnd, Region, Assay_Type, Peak_Call)

dat = dat %>% 
    dplyr::inner_join(
    dat_region_score,
    by = c("Chrom", "ChromStart", "ChromEnd", "Region", "Assay_Type"),
    relationship = "many-to-many"
)

dat = dat %>% 
    dplyr::inner_join(
    dat_region_annot_module,
    by = c("Chrom", "ChromStart", "ChromEnd", "Region"),
    relationship = "many-to-many"
)

dat_region_merge2 = dat
print(dim(dat))
head(dat, 3)
# Out:
# [1] 634547     12
#   Chrom ChromStart ChromEnd Region             Assay_Type Peak_Call  Score
# 1 chr1  115429     115969   chr1:115429-115969 ASTARR     Active (A) 1.895046
# 2 chr1  115429     115969   chr1:115429-115969 ASTARR     Active (A) 1.895046
# 3 chr1  115429     115969   chr1:115429-115969 ASTARR     Active (A) 1.895046
#   Assay_Name                 Assay_Group Assay_Label Group     Label
# 1 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module Module_02
# 2 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module Module_05
# 3 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module Module_10

# %%
print(table(dat$Peak_Call))
# Out:
#  Active (A) Repress (R)
#        2204        1947

# %%
dat = dat_region_merge2
dat = dat %>% 
    dplyr::filter(Label == "Module_34") %>%
    dplyr::filter(Assay_Type == "ASTARR")

lst = split(dat, dat$Peak_Call)

gpt = ggplot(dat, aes(x = Score)) +
    geom_histogram(binwidth = 0.1) +
    theme_cowplot()

options(repr.plot.height=5, repr.plot.width=7)
print(gpt)
# Out:
# plot without title

# %%
lst[["Active (A)"]]
# Out:
#      Chrom ChromStart ChromEnd  Region                   Assay_Type Peak_Call
# 1    chr1   1304794    1306428  chr1:1304794-1306428     ASTARR     Active (A)
# 2    chr1   1504730    1506050  chr1:1504730-1506050     ASTARR     Active (A)
# 3    chr1   1658648    1659623  chr1:1658648-1659623     ASTARR     Active (A)
# 4    chr1   1906919    1907264  chr1:1906919-1907264     ASTARR     Active (A)
# 5    chr1   3319551    3320953  chr1:3319551-3320953     ASTARR     Active (A)
# 6    chr1   3803955    3806146  chr1:3803955-3806146     ASTARR     Active (A)
# 7    chr1   6784286    6785583  chr1:6784286-6785583     ASTARR     Active (A)
# 8    chr1   7608243    7609460  chr1:7608243-7609460     ASTARR     Active (A)
# 9    chr1   9150323    9151391  chr1:9150323-9151391     ASTARR     Active (A)
# 10   chr1   9444108    9444839  chr1:9444108-9444839     ASTARR     Active (A)
# 11   chr1  10555802   10556945  chr1:10555802-10556945   ASTARR     Active (A)
# 12   chr1  11448073   11448607  chr1:11448073-11448607   ASTARR     Active (A)
# 13   chr1  12229544   12231346  chr1:12229544-12231346   ASTARR     Active (A)
# 14   chr1  12548818   12550141  chr1:12548818-12550141   ASTARR     Active (A)
# 15   chr1  12665164   12666514  chr1:12665164-12666514   ASTARR     Active (A)
# 16   chr1  12744951   12745584  chr1:12744951-12745584   ASTARR     Active (A)
# 17   chr1  15523931   15525377  chr1:15523931-15525377   ASTARR     Active (A)
# 18   chr1  15702919   15703967  chr1:15702919-15703967   ASTARR     Active (A)
# 19   chr1  15834376   15836370  chr1:15834376-15836370   ASTARR     Active (A)
# 20   chr1  15893327   15893908  chr1:15893327-15893908   ASTARR     Active (A)
# 21   chr1  16519213   16519898  chr1:16519213-16519898   ASTARR     Active (A)
# 22   chr1  19508798   19509217  chr1:19508798-19509217   ASTARR     Active (A)
# 23   chr1  21022175   21022830  chr1:21022175-21022830   ASTARR     Active (A)
# 24   chr1  21261572   21262936  chr1:21261572-21262936   ASTARR     Active (A)
# 25   chr1  21468552   21468910  chr1:21468552-21468910   ASTARR     Active (A)
# 26   chr1  21638421   21639977  chr1:21638421-21639977   ASTARR     Active (A)
# 27   chr1  21768085   21768914  chr1:21768085-21768914   ASTARR     Active (A)
# 28   chr1  21916778   21917307  chr1:21916778-21917307   ASTARR     Active (A)
# 29   chr1  22365496   22365777  chr1:22365496-22365777   ASTARR     Active (A)
# 30   chr1  23167385   23170223  chr1:23167385-23170223   ASTARR     Active (A)
# ⋮    ⋮     ⋮          ⋮         ⋮                        ⋮          ⋮
# 2175 chrX   74290674   74293073 chrX:74290674-74293073   ASTARR     Active (A)
# 2176 chrX   77785519   77786643 chrX:77785519-77786643   ASTARR     Active (A)
# 2177 chrX  101931385  101932304 chrX:101931385-101932304 ASTARR     Active (A)
# 2178 chrX  103398443  103398928 chrX:103398443-103398928 ASTARR     Active (A)
# 2179 chrX  107718041  107718664 chrX:107718041-107718664 ASTARR     Active (A)
# 2180 chrX  108088567  108088819 chrX:108088567-108088819 ASTARR     Active (A)
# 2181 chrX  110341535  110341939 chrX:110341535-110341939 ASTARR     Active (A)
# 2182 chrX  119041242  119041482 chrX:119041242-119041482 ASTARR     Active (A)
# 2183 chrX  119206132  119206494 chrX:119206132-119206494 ASTARR     Active (A)
# 2184 chrX  120603659  120604763 chrX:120603659-120604763 ASTARR     Active (A)
# 2185 chrX  124763854  124765584 chrX:124763854-124765584 ASTARR     Active (A)
# 2186 chrX  125439123  125439965 chrX:125439123-125439965 ASTARR     Active (A)
# 2187 chrX  130173100  130174764 chrX:130173100-130174764 ASTARR     Active (A)
# 2188 chrX  130594165  130595239 chrX:130594165-130595239 ASTARR     Active (A)
# 2189 chrX  131840920  131842116 chrX:131840920-131842116 ASTARR     Active (A)
# 2190 chrX  135051481  135052586 chrX:135051481-135052586 ASTARR     Active (A)
# 2191 chrX  135740489  135742288 chrX:135740489-135742288 ASTARR     Active (A)
# 2192 chrX  136130852  136131485 chrX:136130852-136131485 ASTARR     Active (A)
# 2193 chrX  136908803  136910479 chrX:136908803-136910479 ASTARR     Active (A)
# 2194 chrX  138925190  138925903 chrX:138925190-138925903 ASTARR     Active (A)
# 2195 chrX  138990284  138991164 chrX:138990284-138991164 ASTARR     Active (A)
# 2196 chrX  139213042  139214072 chrX:139213042-139214072 ASTARR     Active (A)
# 2197 chrX  141903372  141904853 chrX:141903372-141904853 ASTARR     Active (A)
# 2198 chrX  149539064  149541942 chrX:149539064-149541942 ASTARR     Active (A)
# 2199 chrX  151633016  151633616 chrX:151633016-151633616 ASTARR     Active (A)
# 2200 chrX  151988511  151989513 chrX:151988511-151989513 ASTARR     Active (A)
# 2201 chrX  154368733  154369983 chrX:154368733-154369983 ASTARR     Active (A)
# 2202 chrX  154411175  154412358 chrX:154411175-154412358 ASTARR     Active (A)
# 2203 chrX  154829703  154830460 chrX:154829703-154830460 ASTARR     Active (A)
# 2204 chrX  155026613  155027534 chrX:155026613-155027534 ASTARR     Active (A)
#      Score       Assay_Name                 Assay_Group Assay_Label Group
# 1     0.62421811 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2     0.60601017 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 3     2.84081034 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 4     0.74644054 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 5     1.14601736 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 6     0.81714042 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 7    -0.34921424 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 8     1.62940435 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 9     0.04932699 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 10    1.48094948 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 11    0.90827911 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 12    0.55327028 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 13    1.02295249 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 14    0.17845256 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 15    1.52292967 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 16    4.50854305 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 17   -0.55840762 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 18    0.43010093 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 19    2.22605642 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 20    3.00300907 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 21    1.02896530 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 22    1.78522020 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 23    3.37984737 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 24    1.93352220 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 25    1.57795198 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 26    1.74220391 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 27    2.15074211 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 28    1.33656230 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 29    1.35076669 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 30   -0.72339817 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# ⋮    ⋮           ⋮                          ⋮           ⋮           ⋮
# 2175  1.40919491 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2176  2.49332221 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2177  0.83798237 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2178  2.57304594 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2179  2.46970167 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2180  2.88299392 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2181  1.75441896 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2182  3.82500991 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2183  4.40465733 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2184  2.11589284 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2185  1.48466964 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2186  2.18844597 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2187  2.38265072 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2188  2.46420944 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2189  0.75529130 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2190  0.17504324 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2191  0.04583914 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2192  1.42422662 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2193  0.08900645 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2194  2.80828961 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2195  1.41671330 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2196  1.43349960 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2197  1.72600557 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2198 -0.32252851 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2199  0.86977797 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2200  1.42770996 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2201  0.85023495 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2202  0.28527592 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2203  0.77888750 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
# 2204  1.03685906 STARR_ATAC_K562_Reddy_KS91 ASTARR_KS91 ATAC-STARR  TF_Module
#      Label
# 1    Module_34
# 2    Module_34
# 3    Module_34
# 4    Module_34
# 5    Module_34
# 6    Module_34
# 7    Module_34
# 8    Module_34
# 9    Module_34
# 10   Module_34
# 11   Module_34
# 12   Module_34
# 13   Module_34
# 14   Module_34
# 15   Module_34
# 16   Module_34
# 17   Module_34
# 18   Module_34
# 19   Module_34
# 20   Module_34
# 21   Module_34
# 22   Module_34
# 23   Module_34
# 24   Module_34
# 25   Module_34
# 26   Module_34
# 27   Module_34
# 28   Module_34
# 29   Module_34
# 30   Module_34
# ⋮    ⋮
# 2175 Module_34
# 2176 Module_34
# 2177 Module_34
# 2178 Module_34
# 2179 Module_34
# 2180 Module_34
# 2181 Module_34
# 2182 Module_34
# 2183 Module_34
# 2184 Module_34
# 2185 Module_34
# 2186 Module_34
# 2187 Module_34
# 2188 Module_34
# 2189 Module_34
# 2190 Module_34
# 2191 Module_34
# 2192 Module_34
# 2193 Module_34
# 2194 Module_34
# 2195 Module_34
# 2196 Module_34
# 2197 Module_34
# 2198 Module_34
# 2199 Module_34
# 2200 Module_34
# 2201 Module_34
# 2202 Module_34
# 2203 Module_34
# 2204 Module_34
