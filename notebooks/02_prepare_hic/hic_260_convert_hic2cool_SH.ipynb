# %% [raw]
# ---
# title: Region annotation 01 (ASTARR MACS peaks)
# subtitle: Annotate peaks (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ...

# %% [markdown]
# ## Input data

# %%
ls ${FD_RES}
# Out:
# analysis_umap_cluster_by_coverage_score  region_converage_hic
# annotation                               region_coverage_chipseq
# assay_fcc                                region_coverage_fcc
# assay_hic                                region_integration
# region                                   region_nuc
# region_annotation                        summary

# %%
ls -1 ${FD_DAT}/external
# Out:
# chrom.hg38.main.bed
# chrom.hg38.total.bed
# chrom.sizes.hg19
# chrom.sizes.hg38
# encode_chipseq_agarwal2023
# encode_chipseq_flagship
# encode_chipseq_histone
# encode_chipseq_histone_241223
# encode_chipseq_histone_250120
# encode_chipseq_subset
# encode_chipseq_tf_250108
# encode_chipseq_tf_250120
# encode_chromatin_states
# encode_crispri_hcrff
# encode_open_chromatin
# encode_rnaseq
# genome_tss
# hic_insitu_GM12878
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# protein_interpro
# RNAseq
# z_encode_chipseq_encode4
# z_encode_chipseq_flagship
# z_encode_chipseq_histone
# z_encode_chipseq_subset

# %%
ls -1 ${FD_DAT}/external/hic_intact_K562_deep
# Out:
# inter.hic
# localizedList_primary_10.bedpe
# processed

# %% [markdown]
# ## Convert hic to cool format

# %%
hicConvertFormat --help
# Out:
# usage: hicConvertFormat --matrices MATRICES [MATRICES ...] --outFileName
#                         OUTFILENAME [OUTFILENAME ...] --inputFormat
#                         {h5,cool,hic,homer,hicpro,2D-text} --outputFormat
#                         {cool,h5,homer,ginteractions,mcool,hicpro}
#                         [--correction_name CORRECTION_NAME]
#                         [--correction_division] [--store_applied_correction]
#                         [--chromosome CHROMOSOME] [--enforce_integer]
#                         [--load_raw_values]
#                         [--resolutions RESOLUTIONS [RESOLUTIONS ...]] [--help]
#                         [--chromosomeSizes txt file] [--version]
#                         [--bedFileHicpro BEDFILEHICPRO [BEDFILEHICPRO ...]]
#
# Conversion of Hi-C matrices of different file formats. We support the
# conversion of hic to cool format via hic2cool, and homer, HicPro, h5 and cool
# ...

# %% [markdown]
# ```
# hicConvertFormat -m matrix.hic --inputFormat hic --outputFormat cool -o matrix.cool --resolutions 10000
# ```

# %%
hictk --help
# Out:
# Blazing fast tools to work with .hic and .cool files.
# Usage: /usr/local/bin/hictk [OPTIONS] SUBCOMMAND
#
# Options:
#   -h,--help                   Print this help message and exit
#   -V,--version                Display program version information and exit
#
# Subcommands:
#   balance                     Balance Hi-C files using ICE, SCALE, or VC.
#   convert                     Convert Hi-C files between different formats.
#   dump                        Read interactions and other kinds of data from .hic and Cooler files and write them to stdout.
#   fix-mcool                   Fix corrupted .mcool files.
#   load                        Build .cool and .hic files from interactions in various text formats.
#   merge                       Merge multiple Cooler or .hic files into a single file.
#   metadata                    Print file metadata to stdout.
#   rename-chromosomes, rename-chroms
#                               Rename chromosomes found in Cooler files.
# ...

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res10k.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

# %%
hicConvertFormat -m ${FP_INP} --inputFormat hic --outputFormat cool -o ${FP_OUT} --resolutions 10000
# Out:
# INFO:hicexplorer.hicConvertFormat:Converting with hic2cool.
# Traceback (most recent call last):
#   File "/usr/local/bin/hicConvertFormat", line 7, in <module>
#     main()
#   File "/usr/local/lib/python3.12/site-packages/hicexplorer/hicConvertFormat.py", line 138, in main
#     hic2cool_convert(matrix, out_name, resolution)
#   File "/usr/local/lib/python3.12/site-packages/hic2cool/hic2cool_utils.py", line 859, in hic2cool_convert
#     used_chrs, resolutions, masteridx, genome, metadata = read_header(req)
#                                                           ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/hic2cool/hic2cool_utils.py", line 96, in read_header
#     value = readcstr(req)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/hic2cool/hic2cool_utils.py", line 58, in readcstr
#     return buf.decode("utf-8")
#            ^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ```
# $ hicConvertFormat -m ${FP_INP} --inputFormat hic --outputFormat cool -o ${FP_OUT} --resolutions 10000
#
# INFO:hicexplorer.hicConvertFormat:Converting with hic2cool.
# Traceback (most recent call last):
#   File "/usr/local/bin/hicConvertFormat", line 7, in <module>
#     main()
#   File "/usr/local/lib/python3.12/site-packages/hicexplorer/hicConvertFormat.py", line 138, in main
#     hic2cool_convert(matrix, out_name, resolution)
#   File "/usr/local/lib/python3.12/site-packages/hic2cool/hic2cool_utils.py", line 859, in hic2cool_convert
#     used_chrs, resolutions, masteridx, genome, metadata = read_header(req)
#                                                           ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/hic2cool/hic2cool_utils.py", line 96, in read_header
#     value = readcstr(req)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/hic2cool/hic2cool_utils.py", line 58, in readcstr
#     return buf.decode("utf-8")
#            ^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x9e in position 0: invalid start byte
# ```

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res10k.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

# %%
hictk convert ${FP_INP} ${FP_OUT} --resolutions 10000
# Out:
# [2025-03-17 20:35:04.102] [info]: Running hictk v2.0.0-bioconda
# [2025-03-17 20:35:04.104] [info]: Converting /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic to /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/processed/inter.res10k.cool (hic -> cool)...
# [2025-03-17 20:35:30.046] [info]: [10000] begin processing 10000bp matrix...
# [2025-03-17 20:35:39.000] [info]: [10000] processing chr1:3900000-3910000 at 1116944 pixels/s (cache hit rate 18.35%)...
# [2025-03-17 20:35:41.830] [info]: [10000] processing chr1:6920000-6930000 at 3533569 pixels/s (cache hit rate 100.00%)...
# [2025-03-17 20:35:44.704] [info]: [10000] processing chr1:9530000-9540000 at 3480682 pixels/s (cache hit rate 93.75%)...
# [2025-03-17 20:35:51.805] [info]: [10000] processing chr1:12030000-12040000 at 1408252 pixels/s (cache hit rate 14.12%)...
# ...

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res5k.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

hictk convert ${FP_INP} ${FP_OUT} --resolutions 5000
# Out:
# [2025-03-17 21:26:19.064] [info]: Running hictk v2.0.0-bioconda
# [2025-03-17 21:26:19.066] [info]: Converting /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic to /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/processed/inter.res5k.cool (hic -> cool)...
# [2025-03-17 21:26:28.393] [info]: [5000] begin processing 5000bp matrix...
# [2025-03-17 21:26:34.884] [info]: [5000] processing chr1:3645000-3650000 at 1540595 pixels/s (cache hit rate 11.58%)...
# [2025-03-17 21:26:42.523] [info]: [5000] processing chr1:6470000-6475000 at 1309243 pixels/s (cache hit rate 16.98%)...
# [2025-03-17 21:26:45.329] [info]: [5000] processing chr1:8740000-8745000 at 3563792 pixels/s (cache hit rate 96.10%)...
# [2025-03-17 21:26:49.804] [info]: [5000] processing chr1:10930000-10935000 at 2234637 pixels/s (cache hit rate 6.47%)...
# ...

# %%
ls -l ${FD_DAT}/external/hic_intact_K562_deep/processed
# Out:
# total 10542728
# -rw-r--r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab 4735754386 Mar 17 20:59 inter.res10k.cool
# -rw-r--r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab 6059992453 Mar 17 21:53 inter.res5k.cool

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res2k.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

hictk convert ${FP_INP} ${FP_OUT} --resolutions 2000
# Out:
# [2025-03-17 22:11:14.944] [info]: Running hictk v2.0.0-bioconda
# [2025-03-17 22:11:14.946] [info]: Converting /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic to /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/processed/inter.res2k.cool (hic -> cool)...
# [2025-03-17 22:11:24.919] [info]: [2000] begin processing 2000bp matrix...
# [2025-03-17 22:11:29.226] [info]: [2000] processing chr1:3392000-3394000 at 2322880 pixels/s (cache hit rate 19.93%)...
# [2025-03-17 22:11:37.799] [info]: [2000] processing chr1:6082000-6084000 at 1166453 pixels/s (cache hit rate 22.07%)...
# [2025-03-17 22:11:40.460] [info]: [2000] processing chr1:8216000-8218000 at 3757986 pixels/s (cache hit rate 95.76%)...
# [2025-03-17 22:11:45.353] [info]: [2000] processing chr1:10190000-10192000 at 2044154 pixels/s (cache hit rate 21.81%)...
# ...

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res1k.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

hictk convert ${FP_INP} ${FP_OUT} --resolutions 1000
# Out:
# [2025-03-17 22:43:03.569] [info]: Running hictk v2.0.0-bioconda
# [2025-03-17 22:43:03.571] [info]: Converting /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic to /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/processed/inter.res1k.cool (hic -> cool)...
# [2025-03-17 22:43:13.091] [info]: [1000] begin processing 1000bp matrix...
# [2025-03-17 22:43:21.131] [info]: [1000] processing chr1:3198000-3199000 at 1244091 pixels/s (cache hit rate 37.92%)...
# [2025-03-17 22:43:29.250] [info]: [1000] processing chr1:5746000-5747000 at 1231679 pixels/s (cache hit rate 33.98%)...
# [2025-03-17 22:43:31.988] [info]: [1000] processing chr1:7784000-7785000 at 3652301 pixels/s (cache hit rate 95.16%)...
# [2025-03-17 22:43:34.696] [info]: [1000] processing chr1:9664000-9665000 at 3692762 pixels/s (cache hit rate 95.13%)...
# ...

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res5h.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

hictk convert ${FP_INP} ${FP_OUT} --resolutions 500
# Out:
# [2025-03-17 23:19:29.941] [info]: Running hictk v2.0.0-bioconda
# [2025-03-17 23:19:29.943] [info]: Converting /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic to /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/processed/inter.res5h.cool (hic -> cool)...
# [2025-03-17 23:19:39.197] [info]: [500] begin processing 500bp matrix...
# [2025-03-17 23:19:48.030] [info]: [500] processing chr1:2998000-2998500 at 1132503 pixels/s (cache hit rate 61.04%)...
# [2025-03-17 23:19:56.055] [info]: [500] processing chr1:5355000-5355500 at 1245951 pixels/s (cache hit rate 69.38%)...
# [2025-03-17 23:19:58.669] [info]: [500] processing chr1:7248500-7249000 at 3827019 pixels/s (cache hit rate 96.97%)...
# [2025-03-17 23:20:01.433] [info]: [500] processing chr1:9056000-9056500 at 3617945 pixels/s (cache hit rate 96.95%)...
# ...

# %%
ls -l ${FD_OUT}
# Out:
# total 42193172
# -rw-r--r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab  4735754386 Mar 17 20:59 inter.res10k.cool
# -rw-r--r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab 10813444172 Mar 17 23:19 inter.res1k.cool
# -rw-r--r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab  8444768885 Mar 17 22:42 inter.res2k.cool
# -rw-r--r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab 13151823207 Mar 17 23:59 inter.res5h.cool
# -rw-r--r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab  6059992453 Mar 17 21:53 inter.res5k.cool
