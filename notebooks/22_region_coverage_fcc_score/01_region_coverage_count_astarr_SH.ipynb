# %% [raw]
# ---
# title: Region Coverage (FCC) 01
# subtitle: Count fragment/oligo across regions (ASTARR)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# ## Prepare

# %% [markdown]
# **Region sets for calculating FCC effect size**

# %%
### set directory
FDIRY=${FD_RES}/region/summary
FNAME=metadata.label.region_for_analysis.tsv
FPATH=${FDIRY}/${FNAME}

### get table
FP_REGION_LABEL=${FPATH}
cat ${FPATH}
# Out:
# Folder	FName	Label	FPath
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz

# %%
cat ${FP_REGION_LABEL} | cut -f 1-3
# Out:
# Folder	FName	Label
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM

# %% [markdown]
# **Assays**

# %%
### Assay
ASSAY_TYPE=assay_fcc
ASSAY_NAMES=(
    STARR_ATAC_K562_Reddy_KS91
    STARR_ATAC_K562_Reddy_KS274
    STARR_ATAC_K562_Reddy_KSMerge
)

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loop: Region**

# %%
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### show progress
    echo ==============================
    echo "Region folder:" ${FOLDER_A}
    echo "Region label: " ${LABEL_A}
    
    ### Set directory
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF274YGF
# ==============================
# Region folder: region_for_analysis
# Region label:  dnase_ENCFF185XRG
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF558BLC
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF925CYR
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF333TAT
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM

# %%
cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}'
# Out:
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# region_for_analysis	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz	dnase_ENCFF274YGF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz	dnase_ENCFF185XRG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz	atac_ENCFF558BLC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF558BLC.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz	atac_ENCFF925CYR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR483RKN.ENCFF925CYR.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz	atac_ENCFF333TAT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
# region_for_analysis	K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz	atac_ENCFF948AFM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz

# %% [markdown]
# **Test loop: Assay**

# %%
for ASSAY_NAME in ${ASSAY_NAMES[@]}; do
    
    ### show progress
    echo ==============================
    echo "Assay name: " ${ASSAY_NAME}
    
    ### Set directory
    FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
    FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
    
    ### loop through each sample
    for FP_INP_B in ${FP_INPS[@]}; do
        FN_INP_B=$(basename ${FP_INP_B})
        echo ${FN_INP_B}
    done
    echo
done
# Out:
# ==============================
# Assay name:  STARR_ATAC_K562_Reddy_KS91
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# ==============================
# Assay name:  STARR_ATAC_K562_Reddy_KS274
# ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# ==============================
# Assay name:  STARR_ATAC_K562_Reddy_KSMerge
# ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
# ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz

# %% [markdown]
# **Test loop: Region + Assay**

# %%
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### set input file
    FD_INP_A=$(dirname ${FPATH_A})
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        #FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep1*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
        
            ### set input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc_score/${LABEL_A}/${ASSAY_NAME}
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_A}.${ASSAY_NAME}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_A}
            echo "Region label: " ${LABEL_A}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Input fdiry:  " ${FD_INP_A/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_A}
            echo "Input fdiry:  " ${FD_INP_B/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_B}
            echo
            echo "Output fdiry: " ${FD_OUT/${FD_RES}/'${FD_RES}'}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo
        done
    done
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)    
#done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt

# %% [markdown]
# ## Execute

# %% [markdown]
# **Check**

# %%
echo ${FP_CNF}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **RUN**

# %%
### init: set executable
FN_EXE="run_bedtools_coverage.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### Execute
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### set input file
    FD_INP_A=$(dirname ${FPATH_A})
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
        #FP_INPS=($(ls ${FD_INP_B}/*hg38*rep1*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
        
            ### set input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc_score/${LABEL_A}/${ASSAY_NAME}
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_A}.${ASSAY_NAME}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo ==============================
            echo "Region folder:" ${FOLDER_A}
            echo "Region label: " ${LABEL_A}
            echo "Assay  name:  " ${ASSAY_NAME}
            echo
            echo "Input fdiry:  " ${FD_INP_A/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_A}
            echo "Input fdiry:  " ${FD_INP_B/${FD_RES}/'${FD_RES}'}
            echo "Input fname:  " ${FN_INP_B}
            echo
            echo "Output fdiry: " ${FD_OUT/${FD_RES}/'${FD_RES}'}
            echo "Output fname: " ${FN_OUT}
            echo
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo

            ### execute
            mkdir -p ${FD_OUT}
            sbatch \
                --cpus-per-task 4 \
                --mem 10G \
                --output ${FP_LOG} \
                ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
            echo
        done
    done
#done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301082
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301083
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301084
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301085
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301086
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301087
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301088
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301089
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301090
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301091
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301092
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301093
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301094
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301095
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301096
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301097
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301098
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301099
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301100
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301101
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301102
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301103
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301104
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301105
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301106
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301107
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301108
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301109
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301110
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301111
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301112
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_overlap
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301113
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301114
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301115
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301116
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301117
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301118
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301119
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301120
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301121
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301122
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS91
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301123
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301124
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301125
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301126
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301127
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301128
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301129
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301130
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301131
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301132
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301133
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301134
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301135
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301136
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301137
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301138
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301139
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301140
#
# ==============================
# Region folder: region_for_analysis
# Region label:  fcc_astarr_macs_input_union
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# ...
#
# Submitted batch job 301316
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301317
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301318
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301319
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301320
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301321
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301322
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301323
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KS274
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KS274
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301324
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301325
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301326
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301327
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301328
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301329
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301330
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301331
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep5.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301332
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep6.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301333
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301334
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301335
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301336
#
# ==============================
# Region folder: region_for_analysis
# Region label:  atac_ENCFF948AFM
# Assay  name:   STARR_ATAC_K562_Reddy_KSMerge
#
# Input fdiry:   ${FD_RES}/region/region_for_analysis
# Input fname:   K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
# Input fdiry:   ${FD_RES}/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts
# Input fname:   ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Output fdiry:  ${FD_RES}/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge
# Output fname:  ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep4.WGS.unstranded.bed.gz.txt
#
# Submitted batch job 301337

# %% [markdown]
# ## Review

# %%
### Execute
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do
    
    ### set input file
    FD_INP_A=$(dirname ${FPATH_A})
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### loop through each assay
    for ASSAY_NAME in ${ASSAY_NAMES[@]}; do

        ### Set directory
        FD_INP_B=${FD_RES}/${ASSAY_TYPE}/${ASSAY_NAME}/fragment_counts
        #FP_INPS=($(ls ${FD_INP_B}/*hg38*rep*bed.gz))
        FP_INPS=($(ls ${FD_INP_B}/*hg38*rep1*bed.gz))

        ### loop through each sample
        for FP_INP_B in ${FP_INPS[@]}; do
        
            ### set input file
            FD_INP_B=$(dirname  ${FP_INP_B})
            FN_INP_B=$(basename ${FP_INP_B})
            
            ### setup output file
            FD_OUT=${FD_RES}/region_coverage_fcc/${LABEL_A}/${ASSAY_NAME}/overlap_count
            FN_OUT=${FN_INP_B}
            FP_OUT=${FD_OUT}/${FN_OUT}
            
            ### setup log file
            FN_LOG=region.coverage.${LABEL_A}.${ASSAY_NAME}.${FN_OUT}.txt
            FP_LOG=${FD_LOG}/${FN_LOG}
            
            ### show progress
            echo "Log file:" '${FD_LOG}/'${FN_LOG}
            echo
        done
    done
#done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}' | head -n 1)    
done < <(cat ${FP_REGION_LABEL} | awk 'NR >=2 {print}')
# Out:
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF558BLC.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF925CYR.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
#
# Log file: ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt

# %%
cat ${FD_LOG}/region.coverage.fcc_astarr_macs_input_overlap.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-24
# Slurm Array Index:
# Time Stamp:         07-14-25+21:17:03
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc_score/fcc_astarr_macs_input_overlap/STARR_ATAC_K562_Reddy_KS91/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10038	10405	chr1:10038-10405	145
# chr1	14282	14614	chr1:14282-14614	106
# chr1	16025	16338	chr1:16025-16338	124
# chr1	17288	17689	chr1:17288-17689	259
# chr1	28934	29499	chr1:28934-29499	258
# chr1	115429	115969	chr1:115429-115969	950
# chr1	136201	137353	chr1:136201-137353	1441
# chr1	137748	138049	chr1:137748-138049	111
# chr1	138321	139517	chr1:138321-139517	484
# chr1	181005	181854	chr1:181005-181854	397
#
#
# Done!
# Run Time: 2 minutes and 47 seconds

# %%
cat ${FD_LOG}/region.coverage.fcc_astarr_macs_input_union.STARR_ATAC_K562_Reddy_KS91.ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-20
# Slurm Array Index:
# Time Stamp:         07-14-25+21:17:03
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442	chr1:10015-10442
# chr1	14253	14645	chr1:14253-14645
# chr1	16015	16477	chr1:16015-16477
# chr1	17237	17772	chr1:17237-17772
# chr1	28903	29613	chr1:28903-29613
# chr1	30803	31072	chr1:30803-31072
# chr1	101603	101849	chr1:101603-101849
# chr1	115411	115986	chr1:115411-115986
# chr1	118518	118743	chr1:118518-118743
# chr1	136071	137429	chr1:136071-137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS91/fragment_counts/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10001	10143	chr1_10001_10143	1	.
# chr1	10002	10118	chr1_10002_10118	1	.
# chr1	10002	10131	chr1_10002_10131	1	.
# chr1	10002	10203	chr1_10002_10203	1	.
# chr1	10002	10209	chr1_10002_10209	1	.
# chr1	10002	10227	chr1_10002_10227	1	.
# chr1	10002	10436	chr1_10002_10436	1	.
# chr1	10003	10113	chr1_10003_10113	1	.
# chr1	10003	10118	chr1_10003_10118	1	.
# chr1	10003	10119	chr1_10003_10119	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc_score/fcc_astarr_macs_input_union/STARR_ATAC_K562_Reddy_KS91/ASTARRseq_K562_KS91.hg38.Input.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	10015	10442	chr1:10015-10442	155
# chr1	14253	14645	chr1:14253-14645	110
# chr1	16015	16477	chr1:16015-16477	141
# chr1	17237	17772	chr1:17237-17772	259
# chr1	28903	29613	chr1:28903-29613	263
# chr1	30803	31072	chr1:30803-31072	82
# chr1	101603	101849	chr1:101603-101849	73
# chr1	115411	115986	chr1:115411-115986	951
# chr1	118518	118743	chr1:118518-118743	85
# chr1	136071	137429	chr1:136071-137429	1465
#
#
# Done!
# Run Time: 2 minutes and 33 seconds

# %%
cat ${FD_LOG}/region.coverage.dnase_ENCFF274YGF.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-15
# Slurm Array Index:
# Time Stamp:         07-14-25+21:17:05
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EKS.ENCFF274YGF.DNase.bed.gz
#
# show first few lines of input
# chr1	181400	181530	chr1:181400-181530
# chr1	778660	778800	chr1:778660-778800
# chr1	779137	779200	chr1:779137-779200
# chr1	827460	827554	chr1:827460-827554
# chr1	842880	843060	chr1:842880-843060
# chr1	869800	869980	chr1:869800-869980
# chr1	875760	875920	chr1:875760-875920
# chr1	898828	899004	chr1:898828-899004
# chr1	900030	900100	chr1:900030-900100
# chr1	901580	901645	chr1:901580-901645
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	14145	14485	chr1:14145-14485	2	.
# chr1	14243	14498	chr1:14243-14498	1	.
# chr1	14454	14729	chr1:14454-14729	1	.
# chr1	14522	14725	chr1:14522-14725	1	.
# chr1	14599	14850	chr1:14599-14850	1	.
# chr1	14659	14864	chr1:14659-14864	2	.
# chr1	14781	15268	chr1:14781-15268	1	.
# chr1	15172	15659	chr1:15172-15659	1	.
# chr1	15503	15729	chr1:15503-15729	3	.
# chr1	15508	15711	chr1:15508-15711	4	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc_score/dnase_ENCFF274YGF/STARR_ATAC_K562_Reddy_KS274/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	181400	181530	chr1:181400-181530	17
# chr1	778660	778800	chr1:778660-778800	2392
# chr1	779137	779200	chr1:779137-779200	28
# chr1	827460	827554	chr1:827460-827554	463
# chr1	842880	843060	chr1:842880-843060	187
# chr1	869800	869980	chr1:869800-869980	88
# chr1	875760	875920	chr1:875760-875920	3
# chr1	898828	899004	chr1:898828-899004	42
# chr1	900030	900100	chr1:900030-900100	4
# chr1	901580	901645	chr1:901580-901645	29
#
#
# Done!
# Run Time: 19 seconds

# %%
cat ${FD_LOG}/region.coverage.dnase_ENCFF185XRG.STARR_ATAC_K562_Reddy_KS274.ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-01
# Slurm Array Index:
# Time Stamp:         07-14-25+21:17:06
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR000EOT.ENCFF185XRG.DNase.bed.gz
#
# show first few lines of input
# chr1	139369	139421	chr1:139369-139421
# chr1	180800	180871	chr1:180800-180871
# chr1	181108	181200	chr1:181108-181200
# chr1	181400	181560	chr1:181400-181560
# chr1	186785	186839	chr1:186785-186839
# chr1	186980	187129	chr1:186980-187129
# chr1	268011	268080	chr1:268011-268080
# chr1	777860	778036	chr1:777860-778036
# chr1	778740	778860	chr1:778740-778860
# chr1	779086	779320	chr1:779086-779320
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KS274/fragment_counts/ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10421	10570	chr1:10421-10570	1	.
# chr1	13044	13243	chr1:13044-13243	2	.
# chr1	13303	13459	chr1:13303-13459	1	.
# chr1	13483	13661	chr1:13483-13661	1	.
# chr1	14091	14513	chr1:14091-14513	1	.
# chr1	14129	14468	chr1:14129-14468	1	.
# chr1	14191	14755	chr1:14191-14755	1	.
# chr1	14231	14498	chr1:14231-14498	1	.
# chr1	14449	14971	chr1:14449-14971	1	.
# chr1	14452	14620	chr1:14452-14620	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc_score/dnase_ENCFF185XRG/STARR_ATAC_K562_Reddy_KS274/ASTARRseq_K562_KS274.hg38.Output.rep3.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	139369	139421	chr1:139369-139421	7
# chr1	180800	180871	chr1:180800-180871	.
# chr1	181108	181200	chr1:181108-181200	1
# chr1	181400	181560	chr1:181400-181560	9
# chr1	186785	186839	chr1:186785-186839	1
# chr1	186980	187129	chr1:186980-187129	3
# chr1	268011	268080	chr1:268011-268080	23
# chr1	777860	778036	chr1:777860-778036	19
# chr1	778740	778860	chr1:778740-778860	1917
# chr1	779086	779320	chr1:779086-779320	51
#
#
# Done!
# Run Time: 20 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-11
# Slurm Array Index:
# Time Stamp:         07-14-25+21:17:06
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
#
# show first few lines of input
# chr1	42030	42399	chr1:42030-42399
# chr1	68963	70035	chr1:68963-70035
# chr1	79151	79653	chr1:79151-79653
# chr1	778339	779268	chr1:778339-779268
# chr1	804424	805054	chr1:804424-805054
# chr1	811420	811854	chr1:811420-811854
# chr1	812328	812983	chr1:812328-812983
# chr1	817227	818384	chr1:817227-818384
# chr1	826581	828166	chr1:826581-828166
# chr1	842062	843249	chr1:842062-843249
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts/ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	10057	10233	chr1_10057_10233	2	.
# chr1	10188	10442	chr1_10188_10442	1	.
# chr1	10285	10349	chr1_10285_10349	1	.
# chr1	10287	10332	chr1_10287_10332	1	.
# chr1	10365	10449	chr1_10365_10449	1	.
# chr1	10389	10442	chr1_10389_10442	1	.
# chr1	13471	13708	chr1_13471_13708	1	.
# chr1	14098	14507	chr1_14098_14507	1	.
# chr1	14132	14498	chr1_14132_14498	1	.
# chr1	14134	14498	chr1_14134_14498	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge/ASTARRseq_K562_KS91.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	42030	42399	chr1:42030-42399	.
# chr1	68963	70035	chr1:68963-70035	.
# chr1	79151	79653	chr1:79151-79653	.
# chr1	778339	779268	chr1:778339-779268	2569
# chr1	804424	805054	chr1:804424-805054	12
# chr1	811420	811854	chr1:811420-811854	10
# chr1	812328	812983	chr1:812328-812983	23
# chr1	817227	818384	chr1:817227-818384	37
# chr1	826581	828166	chr1:826581-828166	766
# chr1	842062	843249	chr1:842062-843249	162
#
#
# Done!
# Run Time: 17 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF948AFM.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-10
# Slurm Array Index:
# Time Stamp:         07-14-25+21:17:06
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF948AFM.ATAC.bed.gz
#
# show first few lines of input
# chr1	42030	42399	chr1:42030-42399
# chr1	68963	70035	chr1:68963-70035
# chr1	79151	79653	chr1:79151-79653
# chr1	778339	779268	chr1:778339-779268
# chr1	804424	805054	chr1:804424-805054
# chr1	811420	811854	chr1:811420-811854
# chr1	812328	812983	chr1:812328-812983
# chr1	817227	818384	chr1:817227-818384
# chr1	826581	828166	chr1:826581-828166
# chr1	842062	843249	chr1:842062-843249
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	14145	14485	chr1:14145-14485	2	.
# chr1	14243	14498	chr1:14243-14498	1	.
# chr1	14454	14729	chr1:14454-14729	1	.
# chr1	14522	14725	chr1:14522-14725	1	.
# chr1	14599	14850	chr1:14599-14850	1	.
# chr1	14659	14864	chr1:14659-14864	2	.
# chr1	14781	15268	chr1:14781-15268	1	.
# chr1	15172	15659	chr1:15172-15659	1	.
# chr1	15503	15729	chr1:15503-15729	3	.
# chr1	15508	15711	chr1:15508-15711	4	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc_score/atac_ENCFF948AFM/STARR_ATAC_K562_Reddy_KSMerge/ASTARRseq_K562_KS274.hg38.Output.rep1.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	42030	42399	chr1:42030-42399	.
# chr1	68963	70035	chr1:68963-70035	.
# chr1	79151	79653	chr1:79151-79653	.
# chr1	778339	779268	chr1:778339-779268	3333
# chr1	804424	805054	chr1:804424-805054	12
# chr1	811420	811854	chr1:811420-811854	9
# chr1	812328	812983	chr1:812328-812983	43
# chr1	817227	818384	chr1:817227-818384	53
# chr1	826581	828166	chr1:826581-828166	639
# chr1	842062	843249	chr1:842062-843249	299
#
#
# Done!
# Run Time: 18 seconds

# %%
cat ${FD_LOG}/region.coverage.atac_ENCFF333TAT.STARR_ATAC_K562_Reddy_KSMerge.ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz.txt
# Out:
# Hostname:           plp-rcc-node-08
# Slurm Array Index:
# Time Stamp:         07-14-25+21:17:06
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/region_for_analysis/K562.hg38.ENCSR868FGK.ENCFF333TAT.ATAC.bed.gz
#
# show first few lines of input
# chr1	40649	41403	chr1:40649-41403
# chr1	41475	41713	chr1:41475-41713
# chr1	42030	42399	chr1:42030-42399
# chr1	46255	47025	chr1:46255-47025
# chr1	67629	67864	chr1:67629-67864
# chr1	68056	68341	chr1:68056-68341
# chr1	68963	70035	chr1:68963-70035
# chr1	79151	79653	chr1:79151-79653
# chr1	87574	88453	chr1:87574-88453
# chr1	267975	268142	chr1:267975-268142
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_fcc/STARR_ATAC_K562_Reddy_KSMerge/fragment_counts/ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# show first few lines of input
# chr1	13055	13163	chr1:13055-13163	1	.
# chr1	13236	13481	chr1:13236-13481	1	.
# chr1	13253	13495	chr1:13253-13495	1	.
# chr1	13261	13479	chr1:13261-13479	1	.
# chr1	13314	13500	chr1:13314-13500	1	.
# chr1	14449	14642	chr1:14449-14642	1	.
# chr1	14449	14645	chr1:14449-14645	2	.
# chr1	14452	14620	chr1:14452-14620	1	.
# chr1	14452	14679	chr1:14452-14679	1	.
# chr1	14482	14709	chr1:14482-14709	1	.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_fcc_score/atac_ENCFF333TAT/STARR_ATAC_K562_Reddy_KSMerge/ASTARRseq_K562_KS274.hg38.Output.rep2.WGS.unstranded.bed.gz
#
# show first few lines of output:
# chr1	40649	41403	chr1:40649-41403	.
# chr1	41475	41713	chr1:41475-41713	.
# chr1	42030	42399	chr1:42030-42399	.
# chr1	46255	47025	chr1:46255-47025	.
# chr1	67629	67864	chr1:67629-67864	.
# chr1	68056	68341	chr1:68056-68341	.
# chr1	68963	70035	chr1:68963-70035	.
# chr1	79151	79653	chr1:79151-79653	3
# chr1	87574	88453	chr1:87574-88453	9
# chr1	267975	268142	chr1:267975-268142	35
#
#
# Done!
# Run Time: 16 seconds
