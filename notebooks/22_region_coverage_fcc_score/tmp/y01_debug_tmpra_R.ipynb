# %% [raw]
# ---
# title: Region Coverage 32
# subtitle: Summarize coverage for Tiling MPRA
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
#suppressMessages(suppressWarnings(library("DESeq2")))
#suppressMessages(suppressWarnings(library("edgeR")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# **Set global variable**

# %%
txt_fdiry = file.path(FD_RES, "assay_fcc")
vec = dir(txt_fdiry)
for (txt in vec) {cat(txt, "\n")}
# Out:
# CRISPRi_FlowFISH_K562_Riley_JinWoo
# CRISPRi_Growth_K562_Gersbach_JinWoo
# MPRA_Lenti_K562_Nadav_Vikram
# MPRA_Tiling_K562_Tewhey_Hannah
# STARR_ATAC_K562_Reddy_KS274
# STARR_ATAC_K562_Reddy_KS91
# STARR_ATAC_K562_Reddy_KSMerge
# STARR_WHG_K562_Reddy_A001

# %%
#VEC_TXT_ASSAY = c(
#    "STARR_ATAC_K562_Reddy_KS91",
#    "STARR_ATAC_K562_Reddy_KS274",
#    "STARR_ATAC_K562_Reddy_KSMerge",
#    "STARR_WHG_K562_Reddy_A001"
#)
TXT_ASSAY = "MPRA_Tiling_K562_Tewhey_Hannah"
VEC_TXT_PREFIX = c("OL13", "OL43", "OL45")

# %% [markdown]
# ## View the directory

# %%
txt_region = "fcc_astarr_macs_input_overlap"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")
for (txt in dir(txt_fdiry)){cat(txt, "\n")}
# Out:
# data.count_column.norm.OL13.rds
# data.count_column.norm.OL43.rds
# data.count_column.norm.OL45.rds
# data.count_column.raw.OL13.rds
# data.count_column.raw.OL43.rds
# data.count_column.raw.OL45.rds
# data.deseq2.OL13.rds
# data.deseq2.OL43.rds
# data.deseq2.OL45.rds
# data.edger.OL13.rds
# data.edger.OL43.rds
# data.edger.OL45.rds
# matrix.count.deseq.OL13.tsv
# matrix.count.deseq.OL43.tsv
# matrix.count.deseq.OL45.tsv
# matrix.count.FPKM.OL13.tsv
# matrix.count.FPKM.OL43.tsv
# matrix.count.FPKM.OL45.tsv
# matrix.count.norm.OL13.tsv
# matrix.count.norm.OL43.tsv
# matrix.count.norm.OL45.tsv
# matrix.count.raw.OL13.tsv
# matrix.count.raw.OL43.tsv
# matrix.count.raw.OL45.tsv
# matrix.count.TPM.OL13.tsv
# matrix.count.TPM.OL43.tsv
# matrix.count.TPM.OL45.tsv
# result.coverage.Log2FC.deseq.OL13.tsv
# result.coverage.Log2FC.deseq.OL43.tsv
# result.coverage.Log2FC.deseq.OL45.tsv
# result.coverage.Log2FC.deseq.tsv
# result.coverage.screened.OL13.tsv
# result.coverage.screened.OL43.tsv
# ...

# %%
txt_region = "fcc_astarr_macs_input_union"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")
for (txt in dir(txt_fdiry)){cat(txt, "\n")}
# Out:
# data.count_column.norm.OL13.rds
# data.count_column.norm.OL43.rds
# data.count_column.norm.OL45.rds
# data.count_column.raw.OL13.rds
# data.count_column.raw.OL43.rds
# data.count_column.raw.OL45.rds
# data.deseq2.OL13.rds
# data.deseq2.OL43.rds
# data.deseq2.OL45.rds
# data.edger.OL13.rds
# data.edger.OL43.rds
# data.edger.OL45.rds
# matrix.count.deseq.OL13.tsv
# matrix.count.deseq.OL43.tsv
# matrix.count.deseq.OL45.tsv
# matrix.count.FPKM.OL13.tsv
# matrix.count.FPKM.OL43.tsv
# matrix.count.FPKM.OL45.tsv
# matrix.count.norm.OL13.tsv
# matrix.count.norm.OL43.tsv
# matrix.count.norm.OL45.tsv
# matrix.count.raw.OL13.tsv
# matrix.count.raw.OL43.tsv
# matrix.count.raw.OL45.tsv
# matrix.count.TPM.OL13.tsv
# matrix.count.TPM.OL43.tsv
# matrix.count.TPM.OL45.tsv
# result.coverage.Log2FC.deseq.OL13.tsv
# result.coverage.Log2FC.deseq.OL43.tsv
# result.coverage.Log2FC.deseq.OL45.tsv
# result.coverage.Log2FC.deseq.tsv
# result.coverage.screened.OL13.tsv
# result.coverage.screened.OL43.tsv
# ...

# %%
txt_region = "fcc_astarr_macs_input_union"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")

vec_txt_fname = c(
    "result.coverage.Log2FC.deseq.OL13.tsv", 
    "result.coverage.Log2FC.deseq.OL43.tsv", 
    "result.coverage.Log2FC.deseq.OL45.tsv" 
)

lst = lapply(vec_txt_fname, function(txt_fname){
    ### set file directory
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})

lst_dat_region_score_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# [[1]]
# [1] 22 10
#
# [[2]]
# [1] 394  10
#
# [[3]]
# [1] 1306   10
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> baseMean </th>
#    <th style="text-align:right;"> log2FoldChange </th>
#    <th style="text-align:right;"> lfcSE </th>
#    <th style="text-align:right;"> stat </th>
#    <th style="text-align:right;"> pvalue </th>
#    <th style="text-align:right;"> padj </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 61792068 </td>
#    <td style="text-align:right;"> 61793464 </td>
#    <td style="text-align:left;"> chr11:61792068-61793464 </td>
#    <td style="text-align:right;"> 260242.12 </td>
#    <td style="text-align:right;"> 1.666570 </td>
# ...

# %%
txt_region = "fcc_astarr_macs_input_union"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")
txt_fname = "result.coverage.Log2FC.deseq.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

### read table
dat = read_tsv(txt_fpath, show_col_types = FALSE)


dat_region_score_import = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 1722   11
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Batch </th>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> baseMean </th>
#    <th style="text-align:right;"> log2FoldChange </th>
#    <th style="text-align:right;"> lfcSE </th>
#    <th style="text-align:right;"> stat </th>
#    <th style="text-align:right;"> pvalue </th>
#    <th style="text-align:right;"> padj </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> OL13 </td>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 61792068 </td>
#    <td style="text-align:right;"> 61793464 </td>
#    <td style="text-align:left;"> chr11:61792068-61793464 </td>
#    <td style="text-align:right;"> 260242.12 </td>
#    <td style="text-align:right;"> 1.666570 </td>
# ...

# %%
txt_region = "fcc_astarr_macs_input_union"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")

vec_txt_fname = c(
    "result.coverage.summary.OL13.tsv", 
    "result.coverage.summary.OL43.tsv", 
    "result.coverage.summary.OL45.tsv" 
)

lst = lapply(vec_txt_fname, function(txt_fname){
    ### set file directory
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})

lst_dat_region_summary_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# [[1]]
# [1] 22 10
#
# [[2]]
# [1] 394  10
#
# [[3]]
# [1] 1306   10
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input_DESeq </th>
#    <th style="text-align:right;"> Input_FPKM </th>
#    <th style="text-align:right;"> Input_TPM </th>
#    <th style="text-align:right;"> Output_DESeq </th>
#    <th style="text-align:right;"> Output_FPKM </th>
#    <th style="text-align:right;"> Output_TPM </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 61792068 </td>
#    <td style="text-align:right;"> 61793464 </td>
#    <td style="text-align:left;"> chr11:61792068-61793464 </td>
#    <td style="text-align:right;"> 124677.80 </td>
#    <td style="text-align:right;"> 39.97229 </td>
# ...

# %%
txt_region = "fcc_astarr_macs_input_union"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")
txt_fname = "result.coverage.summary.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

### read table
dat = read_tsv(txt_fpath, show_col_types = FALSE)


dat_region_summary_import = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 1722   11
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Batch </th>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> Input_DESeq </th>
#    <th style="text-align:right;"> Input_FPKM </th>
#    <th style="text-align:right;"> Input_TPM </th>
#    <th style="text-align:right;"> Output_DESeq </th>
#    <th style="text-align:right;"> Output_FPKM </th>
#    <th style="text-align:right;"> Output_TPM </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> OL13 </td>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 61792068 </td>
#    <td style="text-align:right;"> 61793464 </td>
#    <td style="text-align:left;"> chr11:61792068-61793464 </td>
#    <td style="text-align:right;"> 124677.80 </td>
# ...

# %%
txt_region = "fcc_astarr_macs_input_union"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")

vec_txt_fname = c(
    "result.coverage.screened.OL13.tsv", 
    "result.coverage.screened.OL43.tsv", 
    "result.coverage.screened.OL45.tsv" 
)

lst = lapply(vec_txt_fname, function(txt_fname){
    ### set file directory
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})

lst_dat_region_screened_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# [[1]]
# [1] 22  7
#
# [[2]]
# [1] 394   7
#
# [[3]]
# [1] 1306    7
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Input </th>
#    <th style="text-align:left;"> Output </th>
#    <th style="text-align:left;"> Total </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 61792068 </td>
#    <td style="text-align:right;"> 61793464 </td>
#    <td style="text-align:left;"> chr11:61792068-61793464 </td>
#    <td style="text-align:left;"> TRUE </td>
#    <td style="text-align:left;"> TRUE </td>
#    <td style="text-align:left;"> TRUE </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 61800085 </td>
# ...

# %%
txt_region = "fcc_astarr_macs_input_union"
txt_assay  = TXT_ASSAY
txt_fdiry = file.path(
    FD_RES, 
    "region_coverage_fcc",
    txt_region,
    txt_assay, 
    "overlap_score", 
    "summary")
txt_fname = "result.coverage.screened.tsv"
txt_fpath = file.path(txt_fdiry, txt_fname)

### read table
dat = read_tsv(txt_fpath, show_col_types = FALSE)


dat_region_summary_import = dat
print(dim(dat))
fun_display_table(head(dat, 3))
# Out:
# [1] 1722    8
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Batch </th>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Input </th>
#    <th style="text-align:left;"> Output </th>
#    <th style="text-align:left;"> Total </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> OL13 </td>
#    <td style="text-align:left;"> chr11 </td>
#    <td style="text-align:right;"> 61792068 </td>
#    <td style="text-align:right;"> 61793464 </td>
#    <td style="text-align:left;"> chr11:61792068-61793464 </td>
#    <td style="text-align:left;"> TRUE </td>
#    <td style="text-align:left;"> TRUE </td>
#    <td style="text-align:left;"> TRUE </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> OL13 </td>
#    <td style="text-align:left;"> chr11 </td>
# ...
