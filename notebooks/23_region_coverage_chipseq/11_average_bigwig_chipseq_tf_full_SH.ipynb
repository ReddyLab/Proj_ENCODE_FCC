# %% [raw]
# ---
# title: Region annotation 02 (ASTARR MACS peaks)
# subtitle: Annotate peaks (ChIP-seq; subset)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ...

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}
# Out:
# annotation
# assay_chipseq
# assay_fcc
# assay_hic
# region
# region_annotation
# region_closest
# region_converage_hic
# region_coverage_chipseq
# region_coverage_fcc
# region_integration
# region_nuc
# site

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs_merge.tsv
# metadata.label.chipseq_histone.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.chipseq_tf_full.tsv
# metadata.label.hic.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
ls -1 ${FD_RES}/assay_chipseq
# Out:
# encode_chipseq_histone
# encode_chipseq_tf_full

# %%
ls -1 ${FD_RES}/assay_chipseq/encode_chipseq_tf_full/summary
# Out:
# metadata.label.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs_merge.tsv
FP_REGION_LABEL_B=${FD_RES}/assay_chipseq/encode_chipseq_tf_full/summary/metadata.label.tsv

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs_merge.tsv
# Folder	FName	Label	FPath
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B} | head
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_tf_full/summary/metadata.label.tsv
# Folder	FName	Label	FPath
# encode_chipseq_tf_full	ENCFF465ZAR.bigWig	encode_chipseq_ZNF347_ENCFF465ZAR	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_tf_full/signal_fold_change/ENCFF465ZAR.bigWig
# encode_chipseq_tf_full	ENCFF178FEN.bigWig	encode_chipseq_ZBTB9_ENCFF178FEN	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_tf_full/signal_fold_change/ENCFF178FEN.bigWig
# encode_chipseq_tf_full	ENCFF040PTP.bigWig	encode_chipseq_AFF4_ENCFF040PTP	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_tf_full/signal_fold_change/ENCFF040PTP.bigWig
# encode_chipseq_tf_full	ENCFF193LUC.bigWig	encode_chipseq_ZFX_ENCFF193LUC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_tf_full/signal_fold_change/ENCFF193LUC.bigWig
# ...

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loop**

# %%
### Loop region A
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do

    ### Set input A
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### Loop region B
    while read FOLDER_B FNAME_B LABEL_B FPATH_B; do
    
        ### Set input B
        FN_INP_B=${FNAME_B}
        FP_INP_B=${FPATH_B}
        
        ### Set output
        FOLDER=region_coverage_chipseq/${LABEL_A}/${FOLDER_B}
        FD_OUT=${FD_RES}/${FOLDER}
        FN_OUT=${LABEL_A}.${LABEL_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_A}.${LABEL_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Input:"
        echo "- Label A:" ${LABEL_A}
        echo "- Label B:" ${LABEL_B}
        echo "Output:"
        echo "- FDiry:" '${FD_RES}'/${FOLDER}
        echo "- FName:" ${FN_OUT}
        echo "Log:" 
        echo "- FPath:" '${FD_LOG}'/${FN_LOG}
        echo  
        
    done < <(cat ${FP_REGION_LABEL_B} | head -n 3 | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ...
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_ZNF347_ENCFF465ZAR
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf_full
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.txt
#
# ...
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_ZBTB9_ENCFF178FEN
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf_full
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_ZBTB9_ENCFF178FEN.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZBTB9_ENCFF178FEN.txt
#
# ...
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_ZNF347_ENCFF465ZAR
# Output:
# ...

# %% [markdown]
# **Execute: init**

# %%
### init: check results and log folder
echo "- FD_RES:" ${FD_RES}
echo "- FD_LOG:" ${FD_LOG}
echo "- FP_CNF:" ${FP_CNF}
# Out:
# - FD_RES: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# - FD_LOG: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# - FP_CNF: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %%
### init: set executable
FN_EXE="run_bigWigAverageOverBed.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

# %% [markdown]
# **Execute: fcc_astarr_macs_input_overlap**

# %%
### init: set Input_A
FOLDER_A=fcc_astarr_macs_merge
FNAME_A=K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
LABEL_A=fcc_astarr_macs_input_overlap
FDIRY_A=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge
FPATH_A=${FDIRY_A}/${FNAME_A}

### check file existence
ls -hs ${FPATH_A}

### Execute: Set input A
FN_INP_A=${FNAME_A}
FP_INP_A=${FPATH_A}

### Execute: Loop region B
while read FOLDER_B FNAME_B LABEL_B FPATH_B; do

    ### Set input B
    FN_INP_B=${FNAME_B}
    FP_INP_B=${FPATH_B}
    
    ### Set output
    FOLDER=region_coverage_chipseq/${LABEL_A}/${FOLDER_B}
    FD_OUT=${FD_RES}/${FOLDER}
    FN_OUT=${LABEL_A}.${LABEL_B}.tsv
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    ### setup log file
    FN_LOG=coverage.average_bigwig_over_bed.${LABEL_A}.${LABEL_B}.txt
    FP_LOG=${FD_LOG}/${FN_LOG}
    
    ### show progress
    echo ==============================
    echo "Input:"
    echo "- Label A:" ${LABEL_A}
    echo "- Label B:" ${LABEL_B}
    echo "Output:"
    echo "- FDiry:" '${FD_RES}'/${FOLDER}
    echo "- FName:" ${FN_OUT}
    echo "Log:" 
    echo "- FPath:" '${FD_LOG}'/${FN_LOG}
    echo 
    
    ### execute
    mkdir -p ${FD_OUT}
    sbatch \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FP_LOG} \
        ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
    echo
done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
# Out:
# 1.8M /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# ...
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_ZNF347_ENCFF465ZAR
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf_full
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.txt
#
# Submitted batch job 281371
#
# ...
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_ZBTB9_ENCFF178FEN
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_tf_full
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_ZBTB9_ENCFF178FEN.tsv
# Log:
# ...

# %% [markdown]
# **Execute: fcc_astarr_macs_input_union**

# %%
### init: set Input_A
FOLDER_A=fcc_astarr_macs_merge
FNAME_A=K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
LABEL_A=fcc_astarr_macs_input_union
FDIRY_A=/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge
FPATH_A=${FDIRY_A}/${FNAME_A}

### check file existence
ls -hs ${FPATH_A}

### Execute: Set input A
FN_INP_A=${FNAME_A}
FP_INP_A=${FPATH_A}

### Execute: Loop region B
while read FOLDER_B FNAME_B LABEL_B FPATH_B; do

    ### Set input B
    FN_INP_B=${FNAME_B}
    FP_INP_B=${FPATH_B}
    
    ### Set output
    FOLDER=region_coverage_chipseq/${LABEL_A}/${FOLDER_B}
    FD_OUT=${FD_RES}/${FOLDER}
    FN_OUT=${LABEL_A}.${LABEL_B}.tsv
    FP_OUT=${FD_OUT}/${FN_OUT}
    
    ### setup log file
    FN_LOG=coverage.average_bigwig_over_bed.${LABEL_A}.${LABEL_B}.txt
    FP_LOG=${FD_LOG}/${FN_LOG}
    
    ### show progress
    echo ==============================
    echo "Input:"
    echo "- Label A:" ${LABEL_A}
    echo "- Label B:" ${LABEL_B}
    echo "Output:"
    echo "- FDiry:" '${FD_RES}'/${FOLDER}
    echo "- FName:" ${FN_OUT}
    echo "Log:" 
    echo "- FPath:" '${FD_LOG}'/${FN_LOG}
    echo 
    
    ### execute
    mkdir -p ${FD_OUT}
    sbatch \
        --cpus-per-task 4 \
        --mem 4G \
        --output ${FP_LOG} \
        ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
    echo
done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
# Out:
# 2.9M /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
# ...
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_ZNF347_ENCFF465ZAR
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_tf_full
# - FName: fcc_astarr_macs_input_union.encode_chipseq_ZNF347_ENCFF465ZAR.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_ZNF347_ENCFF465ZAR.txt
#
# Submitted batch job 282091
#
# ...
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_ZBTB9_ENCFF178FEN
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_tf_full
# - FName: fcc_astarr_macs_input_union.encode_chipseq_ZBTB9_ENCFF178FEN.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_ZBTB9_ENCFF178FEN.txt
#
# ...

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_ZNF347_ENCFF465ZAR.txt
# Out:
# Hostname:           plp-rcc-node-01
# Slurm Array Index:
# Time Stamp:         06-11-25+14:30:31
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_tf_full/signal_fold_change/ENCFF465ZAR.bigWig
#
# processing chromosomes
#
# ...

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_POLR2AphosphoS5_ENCFF907FLD.txt
# Out:
# Hostname:           plp-rcc-node-01
# Slurm Array Index:
# Time Stamp:         06-11-25+14:37:00
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_tf_full/signal_fold_change/ENCFF907FLD.bigWig
#
# processing chromosomes
#
# ...

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_ZNF347_ENCFF465ZAR.txt
# Out:
# Hostname:           plp-rcc-node-06
# Slurm Array Index:
# Time Stamp:         06-10-25+15:04:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442	chr1:10015-10442
# chr1	14253	14645	chr1:14253-14645
# chr1	16015	16477	chr1:16015-16477
# chr1	17237	17772	chr1:17237-17772
# chr1	28903	29613	chr1:28903-29613
# chr1	30803	31072	chr1:30803-31072
# chr1	101603	101849	chr1:101603-101849
# chr1	115411	115986	chr1:115411-115986
# chr1	118518	118743	chr1:118518-118743
# chr1	136071	137429	chr1:136071-137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF253TOF.bigWig
#
# processing chromosomes
#
# ...

# %%
cat ${FD_LOG}/${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_POLR2AphosphoS5_ENCFF907FLD.txt
# Out:
# scancel: error: Kill job error on job id 281066: Access/permission denied
# scancel: error: Kill job error on job id 281183: Access/permission denied
# : 210
