# %% [raw]
# ---
# title: Region annotation 11 (ASTARR MACS peaks)
# subtitle: Summarize annotations (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %%
### get annotated region folder
vec = c(
    "fcc_astarr_macs_input_overlap",
    "fcc_astarr_macs_input_union"
)
names(vec) = vec

### assign and show
vec_txt_folder = vec
for(txt in vec){cat(txt, "\n")}
# Out:
# fcc_astarr_macs_input_overlap
# fcc_astarr_macs_input_union

# %%
txt_fdiry = file.path(FD_RES, "region_coverage_chipseq", "*", "summary")
txt_fname = "matrix.coverage.encode_chipseq_histone.by_target.mean0.tsv"
txt_fglob = file.path(txt_fdiry, txt_fname)

vec = Sys.glob(txt_fglob)
for(txt in vec){cat(txt, "\n")}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/summary/matrix.coverage.encode_chipseq_histone.by_target.mean0.tsv
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/summary/matrix.coverage.encode_chipseq_histone.by_target.mean0.tsv

# %%
txt_fdiry = file.path(FD_RES, "region_coverage_chipseq", "*", "summary")
txt_fname = "matrix.coverage.encode_chipseq_tf_full.by_target.mean0.tsv"
txt_fglob = file.path(txt_fdiry, txt_fname)

vec = Sys.glob(txt_fglob)
for(txt in vec){cat(txt, "\n")}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/summary/matrix.coverage.encode_chipseq_tf_full.by_target.mean0.tsv
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/summary/matrix.coverage.encode_chipseq_tf_full.by_target.mean0.tsv

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_coverage_chipseq", txt_folder, "summary")
    txt_fname = "matrix.coverage.encode_chipseq_histone.by_target.mean0.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})


### assign and show
lst_mat_region_score_mean0_chipseq_histone = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 150042     16
#
# $fcc_astarr_macs_input_union
# [1] 246852     16
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
# ...

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_coverage_chipseq", txt_folder, "summary")
    txt_fname = "matrix.coverage.encode_chipseq_histone.by_target.log2p.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})


### assign and show
lst_mat_region_score_log2p_chipseq_histone = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 150042     16
#
# $fcc_astarr_macs_input_union
# [1] 246852     16
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
# ...

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_coverage_chipseq", txt_folder, "summary")
    txt_fname = "matrix.coverage.encode_chipseq_tf_full.by_target.mean0.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})


### assign and show
lst_mat_region_score_mean0_chipseq_tf_full = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 150042    514
#
# $fcc_astarr_macs_input_union
# [1] 246852    514
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID3B </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ASH1L </th>
#    <th style="text-align:right;"> ATF1 </th>
# ...

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_coverage_chipseq", txt_folder, "summary")
    txt_fname = "matrix.coverage.encode_chipseq_tf_full.by_target.log2p.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})


### assign and show
lst_mat_region_score_log2p_chipseq_tf_full = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 150042    514
#
# $fcc_astarr_macs_input_union
# [1] 246852    514
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> ADNP </th>
#    <th style="text-align:right;"> AFF1 </th>
#    <th style="text-align:right;"> AFF4 </th>
#    <th style="text-align:right;"> AGO1 </th>
#    <th style="text-align:right;"> ARHGAP35 </th>
#    <th style="text-align:right;"> ARID1B </th>
#    <th style="text-align:right;"> ARID2 </th>
#    <th style="text-align:right;"> ARID3A </th>
#    <th style="text-align:right;"> ARID3B </th>
#    <th style="text-align:right;"> ARID4B </th>
#    <th style="text-align:right;"> ARNT </th>
#    <th style="text-align:right;"> ASH1L </th>
#    <th style="text-align:right;"> ATF1 </th>
# ...

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ### get table
    dat1 = lst_mat_region_score_mean0_chipseq_histone[[txt_folder]]
    dat2 = lst_mat_region_score_mean0_chipseq_tf_full[[txt_folder]]

    ### merge
    vec = c("Chrom", "ChromStart", "ChromEnd", "Region")
    dat = dplyr::full_join(dat1, dat2, by = vec)
    return(dat)
})


### assign and show
lst_mat_region_score_mean0_chipseq_merge = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 150042    526
#
# $fcc_astarr_macs_input_union
# [1] 246852    526
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
# ...

# %%
lst = lapply(vec_txt_folder, function(txt_folder){
    ### get table
    dat1 = lst_mat_region_score_log2p_chipseq_histone[[txt_folder]]
    dat2 = lst_mat_region_score_log2p_chipseq_tf_full[[txt_folder]]

    ### merge
    vec = c("Chrom", "ChromStart", "ChromEnd", "Region")
    dat = dplyr::full_join(dat1, dat2, by = vec)
    return(dat)
})


### assign and show
lst_mat_region_score_log2p_chipseq_merge = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 150042    526
#
# $fcc_astarr_macs_input_union
# [1] 246852    526
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> H2AFZ </th>
#    <th style="text-align:right;"> H3K27ac </th>
#    <th style="text-align:right;"> H3K27me3 </th>
#    <th style="text-align:right;"> H3K36me3 </th>
#    <th style="text-align:right;"> H3K4me1 </th>
#    <th style="text-align:right;"> H3K4me2 </th>
#    <th style="text-align:right;"> H3K4me3 </th>
#    <th style="text-align:right;"> H3K79me2 </th>
#    <th style="text-align:right;"> H3K9ac </th>
#    <th style="text-align:right;"> H3K9me1 </th>
#    <th style="text-align:right;"> H3K9me3 </th>
#    <th style="text-align:right;"> H4K20me1 </th>
#    <th style="text-align:right;"> ADNP </th>
# ...

# %%
for (txt_folder in vec_txt_folder){
    ### set file directory
    txt_fdiry  = file.path(FD_RES, "region_coverage_chipseq", txt_folder, "summary")
    txt_fname  = "matrix.coverage.encode_chipseq_merge.by_target.mean0.tsv"
    txt_fpath  = file.path(txt_fdiry, txt_fname)

    ### write data
    lst = lst_mat_region_score_mean0_chipseq_merge
    dat = lst[[txt_folder]]
    write_tsv(dat, txt_fpath)
}

# %%
for (txt_folder in vec_txt_folder){
    ### set file directory
    txt_fdiry  = file.path(FD_RES, "region_coverage_chipseq", txt_folder, "summary")
    txt_fname  = "matrix.coverage.encode_chipseq_merge.by_target.log2p.tsv"
    txt_fpath  = file.path(txt_fdiry, txt_fname)

    ### write data
    lst = lst_mat_region_score_log2p_chipseq_merge
    dat = lst[[txt_folder]]
    write_tsv(dat, txt_fpath)
}
