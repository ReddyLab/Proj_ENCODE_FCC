# %% [raw]
# ---
# title: Region annotation 02 (ASTARR MACS peaks)
# subtitle: Annotate peaks (ChIP-seq; subset)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **Set global variables**

# %%
ls -1 ${FD_RES}
# Out:
# annotation
# assay_chipseq
# assay_fcc
# assay_hic
# region
# region_annotation
# region_closest
# region_converage_hic
# region_coverage_chipseq
# region_coverage_fcc
# region_integration
# region_nuc
# site

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs_merge.tsv
# metadata.label.chipseq_histone.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.chipseq_tf_full.tsv
# metadata.label.hic.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %%
ls -1 ${FD_RES}/assay_chipseq
# Out:
# encode_chipseq_histone
# encode_chipseq_tf_full

# %%
ls -1 ${FD_RES}/assay_chipseq/encode_chipseq_histone/summary
# Out:
# metadata.label.tsv

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs_merge.tsv
FP_REGION_LABEL_B=${FD_RES}/assay_chipseq/encode_chipseq_histone/summary/metadata.label.tsv

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs_merge.tsv
# Folder	FName	Label	FPath
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/summary/metadata.label.tsv
# Folder	FName	Label	FPath
# encode_chipseq_histone	ENCFF544AVW.bigWig	encode_chipseq_H3K79me2_ENCFF544AVW	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF544AVW.bigWig
# encode_chipseq_histone	ENCFF286WRJ.bigWig	encode_chipseq_H3K9ac_ENCFF286WRJ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF286WRJ.bigWig
# encode_chipseq_histone	ENCFF621DJP.bigWig	encode_chipseq_H2AFZ_ENCFF621DJP	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF621DJP.bigWig
# encode_chipseq_histone	ENCFF959YJV.bigWig	encode_chipseq_H3K4me2_ENCFF959YJV	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF959YJV.bigWig
# encode_chipseq_histone	ENCFF911JVK.bigWig	encode_chipseq_H3K4me3_ENCFF911JVK	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF911JVK.bigWig
# encode_chipseq_histone	ENCFF242ENK.bigWig	encode_chipseq_H3K27me3_ENCFF242ENK	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF242ENK.bigWig
# encode_chipseq_histone	ENCFF806YEZ.bigWig	encode_chipseq_H3K4me3_ENCFF806YEZ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF806YEZ.bigWig
# encode_chipseq_histone	ENCFF583BKU.bigWig	encode_chipseq_H3K9ac_ENCFF583BKU	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF583BKU.bigWig
# encode_chipseq_histone	ENCFF660WUG.bigWig	encode_chipseq_H3K4me3_ENCFF660WUG	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF660WUG.bigWig
# encode_chipseq_histone	ENCFF605FAF.bigWig	encode_chipseq_H4K20me1_ENCFF605FAF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF605FAF.bigWig
# encode_chipseq_histone	ENCFF654SLZ.bigWig	encode_chipseq_H3K9me1_ENCFF654SLZ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF654SLZ.bigWig
# encode_chipseq_histone	ENCFF317VHO.bigWig	encode_chipseq_H3K36me3_ENCFF317VHO	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF317VHO.bigWig
# encode_chipseq_histone	ENCFF139KZL.bigWig	encode_chipseq_H3K27me3_ENCFF139KZL	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF139KZL.bigWig
# encode_chipseq_histone	ENCFF399SGM.bigWig	encode_chipseq_H3K4me1_ENCFF399SGM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF399SGM.bigWig
# encode_chipseq_histone	ENCFF347YYH.bigWig	encode_chipseq_H3K36me3_ENCFF347YYH	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF347YYH.bigWig
# encode_chipseq_histone	ENCFF381NDD.bigWig	encode_chipseq_H3K27ac_ENCFF381NDD	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF381NDD.bigWig
# encode_chipseq_histone	ENCFF607SUJ.bigWig	encode_chipseq_H3K4me1_ENCFF607SUJ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF607SUJ.bigWig
# encode_chipseq_histone	ENCFF601JGK.bigWig	encode_chipseq_H3K9me3_ENCFF601JGK	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF601JGK.bigWig
# encode_chipseq_histone	ENCFF253TOF.bigWig	encode_chipseq_H3K4me3_ENCFF253TOF	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF253TOF.bigWig

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loop**

# %%
### Loop region A
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do

    ### Set input A
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### Loop region B
    while read FOLDER_B FNAME_B LABEL_B FPATH_B; do
    
        ### Set input B
        FN_INP_B=${FNAME_B}
        FP_INP_B=${FPATH_B}
        
        ### Set output
        FOLDER=region_coverage_chipseq/${LABEL_A}/${FOLDER_B}
        FD_OUT=${FD_RES}/${FOLDER}
        FN_OUT=${LABEL_A}.${LABEL_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_A}.${LABEL_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Input:"
        echo "- Label A:" ${LABEL_A}
        echo "- Label B:" ${LABEL_B}
        echo "Output:"
        echo "- FDiry:" '${FD_RES}'/${FOLDER}
        echo "- FName:" ${FN_OUT}
        echo "Log:" 
        echo "- FPath:" '${FD_LOG}'/${FN_LOG}
        echo  
        
    done < <(cat ${FP_REGION_LABEL_B} | head -n 3 | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K79me2_ENCFF544AVW
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9ac_ENCFF286WRJ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF286WRJ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF286WRJ.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K79me2_ENCFF544AVW
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF544AVW.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF544AVW.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K9ac_ENCFF286WRJ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF286WRJ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF286WRJ.txt

# %% [markdown]
# **Execute**

# %%
### init: check results and log folder
echo "- FD_RES:" ${FD_RES}
echo "- FD_LOG:" ${FD_LOG}
echo "- FP_CNF:" ${FP_CNF}
# Out:
# - FD_RES: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# - FD_LOG: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# - FP_CNF: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %%
### init: set executable
FN_EXE="run_bigWigAverageOverBed.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### Loop region A
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do

    ### Set input A
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### Loop region B
    while read FOLDER_B FNAME_B LABEL_B FPATH_B; do
    
        ### Set input B
        FN_INP_B=${FNAME_B}
        FP_INP_B=${FPATH_B}
        
        ### Set output
        FOLDER=region_coverage_chipseq/${LABEL_A}/${FOLDER_B}
        FD_OUT=${FD_RES}/${FOLDER}
        FN_OUT=${LABEL_A}.${LABEL_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_A}.${LABEL_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Input:"
        echo "- Label A:" ${LABEL_A}
        echo "- Label B:" ${LABEL_B}
        echo "Output:"
        echo "- FDiry:" '${FD_RES}'/${FOLDER}
        echo "- FName:" ${FN_OUT}
        echo "Log:" 
        echo "- FPath:" '${FD_LOG}'/${FN_LOG}
        echo 
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K79me2_ENCFF544AVW
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.txt
#
# Submitted batch job 279967
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9ac_ENCFF286WRJ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF286WRJ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF286WRJ.txt
#
# Submitted batch job 279968
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H2AFZ_ENCFF621DJP
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF621DJP.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF621DJP.txt
#
# Submitted batch job 279969
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me2_ENCFF959YJV
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF959YJV.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF959YJV.txt
#
# Submitted batch job 279970
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF911JVK
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF911JVK.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF911JVK.txt
#
# Submitted batch job 279971
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27me3_ENCFF242ENK
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF242ENK.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF242ENK.txt
#
# Submitted batch job 279972
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF806YEZ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF806YEZ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF806YEZ.txt
#
# Submitted batch job 279973
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9ac_ENCFF583BKU
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF583BKU.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF583BKU.txt
#
# Submitted batch job 279974
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF660WUG
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF660WUG.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF660WUG.txt
#
# Submitted batch job 279975
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H4K20me1_ENCFF605FAF
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF605FAF.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF605FAF.txt
#
# Submitted batch job 279976
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9me1_ENCFF654SLZ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF654SLZ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF654SLZ.txt
#
# Submitted batch job 279977
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K36me3_ENCFF317VHO
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF317VHO.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF317VHO.txt
#
# Submitted batch job 279978
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27me3_ENCFF139KZL
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF139KZL.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF139KZL.txt
#
# Submitted batch job 279979
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me1_ENCFF399SGM
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF399SGM.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF399SGM.txt
#
# Submitted batch job 279980
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K36me3_ENCFF347YYH
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF347YYH.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF347YYH.txt
#
# Submitted batch job 279981
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27ac_ENCFF381NDD
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF381NDD.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF381NDD.txt
#
# Submitted batch job 279982
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me1_ENCFF607SUJ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF607SUJ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF607SUJ.txt
#
# Submitted batch job 279983
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K9me3_ENCFF601JGK
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF601JGK.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF601JGK.txt
#
# Submitted batch job 279984
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF253TOF
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF253TOF.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF253TOF.txt
#
# Submitted batch job 279985
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K79me2_ENCFF544AVW
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF544AVW.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF544AVW.txt
#
# Submitted batch job 279986
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K9ac_ENCFF286WRJ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF286WRJ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF286WRJ.txt
#
# Submitted batch job 279987
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H2AFZ_ENCFF621DJP
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF621DJP.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF621DJP.txt
#
# Submitted batch job 279988
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me2_ENCFF959YJV
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF959YJV.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF959YJV.txt
#
# Submitted batch job 279989
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me3_ENCFF911JVK
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF911JVK.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF911JVK.txt
#
# Submitted batch job 279990
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K27me3_ENCFF242ENK
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF242ENK.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF242ENK.txt
#
# Submitted batch job 279991
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me3_ENCFF806YEZ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF806YEZ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF806YEZ.txt
#
# Submitted batch job 279992
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K9ac_ENCFF583BKU
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF583BKU.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF583BKU.txt
#
# Submitted batch job 279993
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me3_ENCFF660WUG
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF660WUG.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF660WUG.txt
#
# Submitted batch job 279994
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H4K20me1_ENCFF605FAF
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF605FAF.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF605FAF.txt
#
# Submitted batch job 279995
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K9me1_ENCFF654SLZ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF654SLZ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF654SLZ.txt
#
# Submitted batch job 279996
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K36me3_ENCFF317VHO
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF317VHO.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF317VHO.txt
#
# Submitted batch job 279997
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K27me3_ENCFF139KZL
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF139KZL.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF139KZL.txt
#
# Submitted batch job 279998
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me1_ENCFF399SGM
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF399SGM.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF399SGM.txt
#
# Submitted batch job 279999
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K36me3_ENCFF347YYH
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF347YYH.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF347YYH.txt
#
# Submitted batch job 280000
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K27ac_ENCFF381NDD
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF381NDD.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF381NDD.txt
#
# Submitted batch job 280001
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me1_ENCFF607SUJ
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF607SUJ.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF607SUJ.txt
#
# Submitted batch job 280002
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K9me3_ENCFF601JGK
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF601JGK.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF601JGK.txt
#
# Submitted batch job 280003
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me3_ENCFF253TOF
# Output:
# - FDiry: ${FD_RES}/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF253TOF.tsv
# Log:
# - FPath: ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF253TOF.txt
#
# Submitted batch job 280004

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.txt
# Out:
# Hostname:           plp-rcc-node-01
# Slurm Array Index:
# Time Stamp:         06-10-25+15:04:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
#
# show first few lines of input
# chr1	10038	10405	chr1:10038-10405
# chr1	14282	14614	chr1:14282-14614
# chr1	16025	16338	chr1:16025-16338
# chr1	17288	17689	chr1:17288-17689
# chr1	28934	29499	chr1:28934-29499
# chr1	115429	115969	chr1:115429-115969
# chr1	136201	137353	chr1:136201-137353
# chr1	137748	138049	chr1:137748-138049
# chr1	138321	139517	chr1:138321-139517
# chr1	181005	181854	chr1:181005-181854
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF544AVW.bigWig
#
# processing chromosomes
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone/fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.tsv
#
# show first few lines of output:
# chr1:10038-10405	367	367	121.71	0.331634	0.331634	0	0.7606
# chr1:14282-14614	332	332	0	0	0	0	0
# chr1:16025-16338	313	313	151.934	0.485412	0.485412	0	1.0608
# chr1:17288-17689	401	401	102.697	0.256101	0.256101	0	0.7606
# chr1:28934-29499	565	565	0	0	0	0	0
# chr1:115429-115969	540	540	205.383	0.380338	0.380338	0	1.5212
# chr1:136201-137353	1152	1152	154.051	0.133725	0.133725	0	0.7606
# chr1:137748-138049	301	301	2107.85	7.00283	7.00283	3.44722	10.6484
# chr1:138321-139517	1196	1196	16192.8	13.5392	13.5392	0	29.6634
# chr1:181005-181854	849	849	0	0	0	0	0
#
#
# Done!
# Run Time: 19 seconds

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF253TOF.txt
# Out:
# Hostname:           plp-rcc-node-06
# Slurm Array Index:
# Time Stamp:         06-10-25+15:04:38
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442	chr1:10015-10442
# chr1	14253	14645	chr1:14253-14645
# chr1	16015	16477	chr1:16015-16477
# chr1	17237	17772	chr1:17237-17772
# chr1	28903	29613	chr1:28903-29613
# chr1	30803	31072	chr1:30803-31072
# chr1	101603	101849	chr1:101603-101849
# chr1	115411	115986	chr1:115411-115986
# chr1	118518	118743	chr1:118518-118743
# chr1	136071	137429	chr1:136071-137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/assay_chipseq/encode_chipseq_histone/signal_fold_change/ENCFF253TOF.bigWig
#
# processing chromosomes
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone/fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF253TOF.tsv
#
# show first few lines of output:
# chr1:10015-10442	427	427	0	0	0	0	0
# chr1:14253-14645	392	392	0	0	0	0	0
# chr1:16015-16477	462	462	46.6098	0.100887	0.100887	0	0.22361
# chr1:17237-17772	535	535	49.1942	0.0919518	0.0919518	0	0.22361
# chr1:28903-29613	710	710	0	0	0	0	0
# chr1:30803-31072	269	269	94.3655	0.350801	0.350801	0	0.44723
# chr1:101603-101849	246	246	56.127	0.228159	0.228159	0	0.44723
# chr1:115411-115986	575	575	147.585	0.256669	0.256669	0	0.67084
# chr1:118518-118743	225	225	464.261	2.06338	2.06338	1.3418	3.57806
# chr1:136071-137429	1358	1358	101.519	0.0747563	0.0747563	0	0.44723
#
#
# Done!
# Run Time: 23 seconds

# %%
### Set script
        FP_EXE=${FD_EXE}/run_bigWigAverageOverBed.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B LABEL_REG_B FPATH_REG_B; do

        ### Set input B
        FP_INP_B=${FPATH_REG_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_coverage_chipseq/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bigWigAverageOverBed.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K79me2_ENCFF544AVW
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF544AVW.txt
#
# Submitted batch job 68384
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF286WRJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF286WRJ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF286WRJ.txt
#
# Submitted batch job 68385
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H2AFZ_ENCFF621DJP
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF621DJP.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF621DJP.txt
#
# Submitted batch job 68386
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me2_ENCFF959YJV
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF959YJV.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF959YJV.txt
#
# Submitted batch job 68387
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF911JVK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF911JVK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF911JVK.txt
#
# Submitted batch job 68388
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF242ENK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF242ENK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF242ENK.txt
#
# Submitted batch job 68389
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF806YEZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF806YEZ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF806YEZ.txt
#
# Submitted batch job 68390
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF583BKU
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF583BKU.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF583BKU.txt
#
# Submitted batch job 68391
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF660WUG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF660WUG.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF660WUG.txt
#
# Submitted batch job 68392
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H4K20me1_ENCFF605FAF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF605FAF.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF605FAF.txt
#
# Submitted batch job 68393
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me1_ENCFF654SLZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF654SLZ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF654SLZ.txt
#
# Submitted batch job 68394
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF317VHO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF317VHO.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF317VHO.txt
#
# Submitted batch job 68395
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF139KZL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF139KZL.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF139KZL.txt
#
# Submitted batch job 68396
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF399SGM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF399SGM.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF399SGM.txt
#
# Submitted batch job 68397
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF347YYH
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF347YYH.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF347YYH.txt
#
# Submitted batch job 68398
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27ac_ENCFF381NDD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF381NDD.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF381NDD.txt
#
# Submitted batch job 68399
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF607SUJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF607SUJ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF607SUJ.txt
#
# Submitted batch job 68400
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me3_ENCFF601JGK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF601JGK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF601JGK.txt
#
# Submitted batch job 68401
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF253TOF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF253TOF.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF253TOF.txt
#
# Submitted batch job 68402
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K79me2_ENCFF544AVW
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF544AVW.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF544AVW.txt
#
# Submitted batch job 68403
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF286WRJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF286WRJ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF286WRJ.txt
#
# Submitted batch job 68404
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H2AFZ_ENCFF621DJP
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF621DJP.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF621DJP.txt
#
# Submitted batch job 68405
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF959YJV
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF959YJV.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF959YJV.txt
#
# Submitted batch job 68406
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF911JVK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF911JVK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF911JVK.txt
#
# Submitted batch job 68407
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF242ENK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF242ENK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF242ENK.txt
#
# Submitted batch job 68408
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF806YEZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF806YEZ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF806YEZ.txt
#
# Submitted batch job 68409
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF583BKU
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF583BKU.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF583BKU.txt
#
# Submitted batch job 68410
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF660WUG
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF660WUG.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF660WUG.txt
#
# Submitted batch job 68411
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H4K20me1_ENCFF605FAF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF605FAF.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF605FAF.txt
#
# Submitted batch job 68412
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me1_ENCFF654SLZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF654SLZ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF654SLZ.txt
#
# Submitted batch job 68413
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF317VHO
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF317VHO.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF317VHO.txt
#
# Submitted batch job 68414
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF139KZL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF139KZL.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF139KZL.txt
#
# Submitted batch job 68415
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF399SGM
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF399SGM.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF399SGM.txt
#
# Submitted batch job 68416
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF347YYH
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF347YYH.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF347YYH.txt
#
# Submitted batch job 68417
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27ac_ENCFF381NDD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF381NDD.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF381NDD.txt
#
# Submitted batch job 68418
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF607SUJ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF607SUJ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF607SUJ.txt
#
# Submitted batch job 68419
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me3_ENCFF601JGK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF601JGK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF601JGK.txt
#
# Submitted batch job 68420
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF253TOF
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF253TOF.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF253TOF.txt
#
# Submitted batch job 68421

# %%
### Loop region A
while read FOLDER_REG_A FNAME_REG_A LABEL_REG_A; do
    
    ### Set input A
    FD_INP_A=${FD_RES}/region/${FOLDER_REG_A}
    FN_INP_A=${FNAME_REG_A}
    FP_INP_A=${FD_INP_A}/${FN_INP_A}
    FOLDER_A=${LABEL_REG_A}
    
    ### Loop region B
    while read FOLDER_REG_B FNAME_REG_B LABEL_REG_B; do

        ### Set input B
        FD_INP_B=${FD_RES}/annotation/${FOLDER_REG_B}
        FN_INP_B=${FNAME_REG_B}
        FP_INP_B=${FD_INP_B}/${FN_INP_B}
        FOLDER_B=${FOLDER_REG_B}
        
        ### Set output
        FD_OUT=${FD_RES}/region_coverage_chipseq/${FOLDER_A}/${FOLDER_B}
        FN_OUT=${LABEL_REG_A}.${LABEL_REG_B}.tsv
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=coverage.average_bigwig_over_bed.${LABEL_REG_A}.${LABEL_REG_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### Set script
        FP_EXE=${FD_EXE}/run_bigWigAverageOverBed.sh
        
        ### show progress
        echo ==============================
        echo "Output Label A:" ${LABEL_REG_A}
        echo "Output Label B:" ${LABEL_REG_B}
        echo 
        echo "Output FDiry:  " ${FD_OUT}
        echo "Output FName:  " ${FN_OUT}
        echo "Log    FPath:  " '${FD_LOG}/'${FN_LOG}
        echo 
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me2_ENCFF054RSU
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF054RSU.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF054RSU.txt
#
# Submitted batch job 65457
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF071GML
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF071GML.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF071GML.txt
#
# Submitted batch job 65458
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF178QDA
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF178QDA.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF178QDA.txt
#
# Submitted batch job 65459
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H2AFZ_ENCFF202EVH
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF202EVH.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H2AFZ_ENCFF202EVH.txt
#
# Submitted batch job 65460
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me1_ENCFF220RGS
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF220RGS.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me1_ENCFF220RGS.txt
#
# Submitted batch job 65461
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9ac_ENCFF239EBH
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF239EBH.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9ac_ENCFF239EBH.txt
#
# Submitted batch job 65462
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF287LBI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF287LBI.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF287LBI.txt
#
# Submitted batch job 65463
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K79me2_ENCFF334HSS
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF334HSS.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K79me2_ENCFF334HSS.txt
#
# Submitted batch job 65464
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF405ZDL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF405ZDL.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF405ZDL.txt
#
# Submitted batch job 65465
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me1_ENCFF457URZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF457URZ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF457URZ.txt
#
# Submitted batch job 65466
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF461RKK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF461RKK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF461RKK.txt
#
# Submitted batch job 65467
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27ac_ENCFF465GBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF465GBD.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF465GBD.txt
#
# Submitted batch job 65468
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF582IMB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF582IMB.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF582IMB.txt
#
# Submitted batch job 65469
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF605EVL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF605EVL.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF605EVL.txt
#
# Submitted batch job 65470
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K9me3_ENCFF632NQA
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF632NQA.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K9me3_ENCFF632NQA.txt
#
# Submitted batch job 65471
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K36me3_ENCFF633OZC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF633OZC.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K36me3_ENCFF633OZC.txt
#
# Submitted batch job 65472
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H4K20me1_ENCFF694ODT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF694ODT.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H4K20me1_ENCFF694ODT.txt
#
# Submitted batch job 65473
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K4me3_ENCFF767UON
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF767UON.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF767UON.txt
#
# Submitted batch job 65474
#
# ==============================
# Output Label A: fcc_astarr_macs_input_overlap
# Output Label B: encode_chipseq_H3K27me3_ENCFF847BFA
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_overlap/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF847BFA.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF847BFA.txt
#
# Submitted batch job 65475
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me2_ENCFF054RSU
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF054RSU.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF054RSU.txt
#
# Submitted batch job 65476
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF071GML
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF071GML.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF071GML.txt
#
# Submitted batch job 65477
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF178QDA
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF178QDA.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF178QDA.txt
#
# Submitted batch job 65478
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H2AFZ_ENCFF202EVH
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF202EVH.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H2AFZ_ENCFF202EVH.txt
#
# Submitted batch job 65479
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me1_ENCFF220RGS
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF220RGS.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9me1_ENCFF220RGS.txt
#
# Submitted batch job 65480
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9ac_ENCFF239EBH
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF239EBH.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9ac_ENCFF239EBH.txt
#
# Submitted batch job 65481
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF287LBI
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF287LBI.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF287LBI.txt
#
# Submitted batch job 65482
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K79me2_ENCFF334HSS
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF334HSS.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K79me2_ENCFF334HSS.txt
#
# Submitted batch job 65483
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF405ZDL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF405ZDL.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF405ZDL.txt
#
# Submitted batch job 65484
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me1_ENCFF457URZ
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF457URZ.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF457URZ.txt
#
# Submitted batch job 65485
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF461RKK
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF461RKK.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF461RKK.txt
#
# Submitted batch job 65486
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27ac_ENCFF465GBD
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF465GBD.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF465GBD.txt
#
# Submitted batch job 65487
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF582IMB
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF582IMB.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF582IMB.txt
#
# Submitted batch job 65488
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF605EVL
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF605EVL.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF605EVL.txt
#
# Submitted batch job 65489
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K9me3_ENCFF632NQA
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF632NQA.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K9me3_ENCFF632NQA.txt
#
# Submitted batch job 65490
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K36me3_ENCFF633OZC
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF633OZC.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K36me3_ENCFF633OZC.txt
#
# Submitted batch job 65491
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H4K20me1_ENCFF694ODT
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF694ODT.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H4K20me1_ENCFF694ODT.txt
#
# Submitted batch job 65492
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K4me3_ENCFF767UON
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF767UON.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF767UON.txt
#
# Submitted batch job 65493
#
# ==============================
# Output Label A: fcc_astarr_macs_input_union
# Output Label B: encode_chipseq_H3K27me3_ENCFF847BFA
#
# Output FDiry:   /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone
# Output FName:   fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF847BFA.tsv
# Log    FPath:   ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF847BFA.txt
#
# Submitted batch job 65494

# %%
cat ${FD_LOG}/coverage.average_bigwig_over_bed.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF847BFA.txt
# Out:
# Hostname:           plp-rcc-node-19
# Slurm Array Index:
# Time Stamp:         01-09-25+11:21:04
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz
#
# show first few lines of input
# chr1	10015	10442	chr1:10015-10442
# chr1	14253	14645	chr1:14253-14645
# chr1	16015	16477	chr1:16015-16477
# chr1	17237	17772	chr1:17237-17772
# chr1	28903	29613	chr1:28903-29613
# chr1	30803	31072	chr1:30803-31072
# chr1	101603	101849	chr1:101603-101849
# chr1	115411	115986	chr1:115411-115986
# chr1	118518	118743	chr1:118518-118743
# chr1	136071	137429	chr1:136071-137429
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/annotation/encode_chipseq_histone/ENCFF847BFA.bigWig
#
# bigWigAverageOverBed v2 - Compute average score of big wig over each bed, which may have introns.
# usage:
#    bigWigAverageOverBed in.bw in.bed out.tab
# The output columns are:
#    name - name field from bed, which should be unique
#    size - size of bed (sum of exon sizes
#    covered - # bases within exons covered by bigWig
#    sum - sum of values over all bases covered
#    mean0 - average over bases with non-covered bases counting as zeroes
#    mean - average over just covered bases
# Options:
#    -stats=stats.ra - Output a collection of overall statistics to stat.ra file
#    -bedOut=out.bed - Make output bed that is echo of input bed but with mean column appended
#    -sampleAroundCenter=N - Take sample at region N bases wide centered around bed item, rather
#                      than the usual sample in the bed item.
#    -minMax - include two additional columns containing the min and max observed in the area.
#
#
# Output:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone/fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF847BFA.tsv
#
# show first few lines of output:
# cat: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_coverage_chipseq/fcc_astarr_macs_input_union/encode_chipseq_histone/fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF847BFA.tsv: No such file or directory
#
#
# Done!
# Run Time: 0 seconds
