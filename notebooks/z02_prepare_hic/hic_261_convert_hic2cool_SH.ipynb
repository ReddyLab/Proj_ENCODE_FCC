# %% [raw]
# ---
# title: Region annotation 01 (ASTARR MACS peaks)
# subtitle: Annotate peaks (Main)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ...

# %% [markdown]
# ## Input data

# %%
ls ${FD_RES}
# Out:
# analysis_umap_cluster_by_coverage_score  region_converage_hic
# annotation                               region_coverage_chipseq
# assay_fcc                                region_coverage_fcc
# assay_hic                                region_integration
# region                                   region_nuc
# region_annotation                        summary

# %%
ls -lh ${FD_DAT}/external/hic_intact_K562_deep
# Out:
# total 346G
# -rw-rw-r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab 346G Aug 18  2022 inter.hic
# -rw-rw-r-- 1 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab  39M May 23  2023 localizedList_primary_10.bedpe
# drwxr-sr-x 2 kk319 grouper-duke-policies-oasis-res-compute-cluster-reddylab  151 Mar 17 23:19 processed

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FN_INP=inter.hic
FP_INP=${FD_INP}/${FN_INP}

ls ${FP_INP}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FN_INP=inter.hic
FP_INP=${FD_INP}/${FN_INP}

hictk dump --table normalizations ${FP_INP}
# Out:
# RU
# VC
# VC_SQRT

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res10k.RU.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

hictk convert ${FP_INP} ${FP_OUT} --resolutions 10000 --normalization-methods RU
# Out:
# [2025-03-19 14:46:24.122] [info]: Running hictk v2.0.0-bioconda
# [2025-03-19 14:46:24.147] [info]: Converting /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic to /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/processed/inter.res10k.RU.cool (hic -> cool)...
# [2025-03-19 14:46:33.337] [info]: [10000] begin processing 10000bp matrix...
# [2025-03-19 14:46:41.736] [info]: [10000] processing chr1:3900000-3910000 at 1190902 pixels/s (cache hit rate 18.35%)...
# [2025-03-19 14:46:44.396] [info]: [10000] processing chr1:6920000-6930000 at 3760812 pixels/s (cache hit rate 100.00%)...
# [2025-03-19 14:46:47.112] [info]: [10000] processing chr1:9530000-9540000 at 3681885 pixels/s (cache hit rate 93.75%)...
# [2025-03-19 14:46:54.108] [info]: [10000] processing chr1:12030000-12040000 at 1429593 pixels/s (cache hit rate 14.12%)...
# ...

# %%
FD_INP=${FD_DAT}/external/hic_intact_K562_deep
FD_OUT=${FD_DAT}/external/hic_intact_K562_deep/processed
FN_INP=inter.hic
FN_OUT=inter.res2k.RU.cool
FP_INP=${FD_INP}/${FN_INP}
FP_OUT=${FD_OUT}/${FN_OUT}

hictk convert ${FP_INP} ${FP_OUT} --resolutions 2000 --normalization-methods RU
# Out:
# [2025-03-19 15:10:23.421] [info]: Running hictk v2.0.0-bioconda
# [2025-03-19 15:10:23.453] [info]: Converting /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/inter.hic to /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data/external/hic_intact_K562_deep/processed/inter.res2k.RU.cool (hic -> cool)...
# [2025-03-19 15:10:33.741] [info]: [2000] begin processing 2000bp matrix...
# [2025-03-19 15:10:41.081] [info]: [2000] processing chr1:3392000-3394000 at 1362583 pixels/s (cache hit rate 19.93%)...
# [2025-03-19 15:10:49.554] [info]: [2000] processing chr1:6082000-6084000 at 1180359 pixels/s (cache hit rate 22.07%)...
# [2025-03-19 15:10:52.186] [info]: [2000] processing chr1:8216000-8218000 at 3799392 pixels/s (cache hit rate 95.76%)...
# [2025-03-19 15:10:57.031] [info]: [2000] processing chr1:10190000-10192000 at 2064410 pixels/s (cache hit rate 21.81%)...
# ...
