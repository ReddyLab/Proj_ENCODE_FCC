# %% [raw]
# ---
# title: Annotation of ATAC (ASTARR Input) 03
# subtitle: Intersection (ChIP-seq Subset)
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
source ../run_config_project.sh
show_env
# Out:
# You are working on             Duke Server: RCC
# BASE DIRECTORY (FD_BASE):      /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO):      /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK):      /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA):      /data/reddylab/Kuei/data
# CONTAINER DIR. (FD_SING):      /data/reddylab/Kuei/container
#
# You are working with           ENCODE FCC
# PATH OF PROJECT (FD_PRJ):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references
# PROJECT IMAGE   (FP_PRJ_SIF):  /data/reddylab/Kuei/container/project/singularity_proj_encode_fcc.sif
# PROJECT CONF.   (FP_CNF):      /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts/config_project.sh

# %% [markdown]
# **Set global variables**

# %%
FP_REGION_LABEL_A=${FD_RES}/region/summary/metadata.label.astarr_macs_merge.tsv
FP_REGION_LABEL_B=${FD_RES}/region/summary/metadata.label.chipseq_subset.tsv

# %% [markdown]
# ## Prepare

# %% [markdown]
# **View files**

# %%
ls -1 ${FD_RES}/region
# Out:
# encode_chipseq_histone
# encode_chipseq_subset
# encode_chipseq_tf_full
# encode_chromatin_states
# encode_e2g_benchmark
# encode_open_chromatin
# fcc_astarr_csaw
# fcc_astarr_macs_merge
# fcc_astarr_macs_narrowpeak
# fcc_crispri_growth
# fcc_crispri_hcrff
# fcc_screened
# fcc_starrmpra_junke
# fcc_table
# fcc_table_cluster
# genome_tss
# hic_insitu_K562_ENCSR545YBD
# hic_intact_K562_deep
# hic_intact_K562_ENCSR479XDG
# module_tf_shannon
# summary
# tmp

# %%
ls -1 ${FD_RES}/region/summary
# Out:
# metadata.label.astarr_macs_merge.tsv
# metadata.label.chipseq_histone.tsv
# metadata.label.chipseq_subset.tsv
# metadata.label.chipseq_tf_full.tsv
# metadata.label.hic.tsv
# metadata.label.main.tsv
# metadata.label.ocr.tsv

# %% [markdown]
# **View: Metatable label A**

# %%
ls  ${FP_REGION_LABEL_A}
cat ${FP_REGION_LABEL_A}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.astarr_macs_merge.tsv
# Folder	FName	Label	FPath
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz	fcc_astarr_macs_input_overlap	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.max_overlaps.q5.bed.gz
# fcc_astarr_macs_merge	K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz	fcc_astarr_macs_input_union	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all.union.q5.bed.gz

# %%
cat ${FP_REGION_LABEL_A} | cut -f 1,3
# Out:
# Folder	Label
# fcc_astarr_macs_merge	fcc_astarr_macs_input_overlap
# fcc_astarr_macs_merge	fcc_astarr_macs_input_union

# %% [markdown]
# **View: Metatable label B**

# %%
ls  ${FP_REGION_LABEL_B}
cat ${FP_REGION_LABEL_B}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/summary/metadata.label.chipseq_subset.tsv
# Folder	FName	Label	FPath
# encode_chipseq_subset	ENCFF023IFO.bed.gz	encode_chipseq_NFE2_ENCFF023IFO	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF023IFO.bed.gz
# encode_chipseq_subset	ENCFF135ZLM.bed.gz	encode_chipseq_H3K4me1_ENCFF135ZLM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF135ZLM.bed.gz
# encode_chipseq_subset	ENCFF142ZTD.bed.gz	encode_chipseq_KLF10_ENCFF142ZTD	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF142ZTD.bed.gz
# encode_chipseq_subset	ENCFF190CGV.bed.gz	encode_chipseq_JUN_ENCFF190CGV	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF190CGV.bed.gz
# encode_chipseq_subset	ENCFF242AOL.bed.gz	encode_chipseq_ZEB2_ENCFF242AOL	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF242AOL.bed.gz
# encode_chipseq_subset	ENCFF323WOT.bed.gz	encode_chipseq_H3K27me3_ENCFF323WOT	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF323WOT.bed.gz
# encode_chipseq_subset	ENCFF355MNE.bed.gz	encode_chipseq_POLR2A_ENCFF355MNE	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF355MNE.bed.gz
# encode_chipseq_subset	ENCFF398UQZ.bed.gz	encode_chipseq_YY1_ENCFF398UQZ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF398UQZ.bed.gz
# encode_chipseq_subset	ENCFF488OTN.bed.gz	encode_chipseq_KLF16_ENCFF488OTN	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF488OTN.bed.gz
# encode_chipseq_subset	ENCFF544LXB.bed.gz	encode_chipseq_H3K27ac_ENCFF544LXB	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF544LXB.bed.gz
# encode_chipseq_subset	ENCFF553GPK.bed.gz	encode_chipseq_SP1_ENCFF553GPK	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF553GPK.bed.gz
# encode_chipseq_subset	ENCFF627RSK.bed.gz	encode_chipseq_ATF1_ENCFF627RSK	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF627RSK.bed.gz
# encode_chipseq_subset	ENCFF657CTC.bed.gz	encode_chipseq_GATA1_ENCFF657CTC	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF657CTC.bed.gz
# encode_chipseq_subset	ENCFF660GHM.bed.gz	encode_chipseq_CTCF_ENCFF660GHM	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF660GHM.bed.gz
# encode_chipseq_subset	ENCFF702XPO.bed.gz	encode_chipseq_EP300_ENCFF702XPO	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF702XPO.bed.gz
# encode_chipseq_subset	ENCFF707MDI.bed.gz	encode_chipseq_REST_ENCFF707MDI	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF707MDI.bed.gz
# encode_chipseq_subset	ENCFF715WGN.bed.gz	encode_chipseq_ELK1_ENCFF715WGN	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF715WGN.bed.gz
# encode_chipseq_subset	ENCFF749KLQ.bed.gz	encode_chipseq_H3K4me2_ENCFF749KLQ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF749KLQ.bed.gz
# encode_chipseq_subset	ENCFF777PKJ.bed.gz	encode_chipseq_NRF1_ENCFF777PKJ	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF777PKJ.bed.gz
# encode_chipseq_subset	ENCFF852ZRK.bed.gz	encode_chipseq_TAL1_ENCFF852ZRK	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF852ZRK.bed.gz
# encode_chipseq_subset	ENCFF885FQN.bed.gz	encode_chipseq_H3K4me3_ENCFF885FQN	/data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/encode_chipseq_subset/ENCFF885FQN.bed.gz

# %%
cat ${FP_REGION_LABEL_B} | cut -f 1,3
# Out:
# Folder	Label
# encode_chipseq_subset	encode_chipseq_NFE2_ENCFF023IFO
# encode_chipseq_subset	encode_chipseq_H3K4me1_ENCFF135ZLM
# encode_chipseq_subset	encode_chipseq_KLF10_ENCFF142ZTD
# encode_chipseq_subset	encode_chipseq_JUN_ENCFF190CGV
# encode_chipseq_subset	encode_chipseq_ZEB2_ENCFF242AOL
# encode_chipseq_subset	encode_chipseq_H3K27me3_ENCFF323WOT
# encode_chipseq_subset	encode_chipseq_POLR2A_ENCFF355MNE
# encode_chipseq_subset	encode_chipseq_YY1_ENCFF398UQZ
# encode_chipseq_subset	encode_chipseq_KLF16_ENCFF488OTN
# encode_chipseq_subset	encode_chipseq_H3K27ac_ENCFF544LXB
# encode_chipseq_subset	encode_chipseq_SP1_ENCFF553GPK
# encode_chipseq_subset	encode_chipseq_ATF1_ENCFF627RSK
# encode_chipseq_subset	encode_chipseq_GATA1_ENCFF657CTC
# encode_chipseq_subset	encode_chipseq_CTCF_ENCFF660GHM
# encode_chipseq_subset	encode_chipseq_EP300_ENCFF702XPO
# encode_chipseq_subset	encode_chipseq_REST_ENCFF707MDI
# encode_chipseq_subset	encode_chipseq_ELK1_ENCFF715WGN
# encode_chipseq_subset	encode_chipseq_H3K4me2_ENCFF749KLQ
# encode_chipseq_subset	encode_chipseq_NRF1_ENCFF777PKJ
# encode_chipseq_subset	encode_chipseq_TAL1_ENCFF852ZRK
# encode_chipseq_subset	encode_chipseq_H3K4me3_ENCFF885FQN

# %% [markdown]
# ## Execute

# %% [markdown]
# **Test loop**

# %%
### init: set executable
FN_EXE="run_bedtools_intersect.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### init: check results and log folder
echo "- FD_RES:" ${FD_RES}
echo "- FD_LOG:" ${FD_LOG}

### Loop region A
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do

    ### Set input A
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### Loop region B
    while read FOLDER_B FNAME_B LABEL_B FPATH_B; do
    
        ### Set input B
        FN_INP_B=${FNAME_B}
        FP_INP_B=${FPATH_B}
        
        ### Set output
        FOLDER=region_annotation/${LABEL_A}/${FOLDER_B}
        FD_OUT=${FD_RES}/${FOLDER}
        FN_OUT=${LABEL_A}.${LABEL_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.annotation.${LABEL_A}.${LABEL_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Input:"
        echo "- Label A:" ${LABEL_A}
        echo "- Label B:" ${LABEL_B}
        echo "Output:"
        echo "- FDiry:" '${FD_RES}'/${FOLDER}
        echo "- FName:" ${FN_OUT}
        echo "Log:" 
        echo "- FPath:" '${FD_LOG}'/${FN_LOG}
        echo  
        
    done < <(cat ${FP_REGION_LABEL_B} | head -n 3 | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# - FD_RES: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# - FD_LOG: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_NFE2_ENCFF023IFO
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_NFE2_ENCFF023IFO
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.annotation.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt

# %% [markdown]
# **Execute**

# %%
### init: set executable
FN_EXE="run_bedtools_intersect.sh"
FP_EXE=${FD_EXE}/${FN_EXE}

### init: check results and log folder
echo "- FD_RES:" ${FD_RES}
echo "- FD_LOG:" ${FD_LOG}

### Loop region A
while read FOLDER_A FNAME_A LABEL_A FPATH_A; do

    ### Set input A
    FN_INP_A=${FNAME_A}
    FP_INP_A=${FPATH_A}
    
    ### Loop region B
    while read FOLDER_B FNAME_B LABEL_B FPATH_B; do
    
        ### Set input B
        FN_INP_B=${FNAME_B}
        FP_INP_B=${FPATH_B}
        
        ### Set output
        FOLDER=region_annotation/${LABEL_A}/${FOLDER_B}
        FD_OUT=${FD_RES}/${FOLDER}
        FN_OUT=${LABEL_A}.${LABEL_B}.bed.gz
        FP_OUT=${FD_OUT}/${FN_OUT}
        
        ### setup log file
        FN_LOG=region.intersect.${LABEL_A}.${LABEL_B}.txt
        FP_LOG=${FD_LOG}/${FN_LOG}
        
        ### show progress
        echo ==============================
        echo "Input:"
        echo "- Label A:" ${LABEL_A}
        echo "- Label B:" ${LABEL_B}
        echo "Output:"
        echo "- FDiry:" '${FD_RES}'/${FOLDER}
        echo "- FName:" ${FN_OUT}
        echo "Log:" 
        echo "- FPath:" '${FD_LOG}'/${FN_LOG}
        echo  
        
        ### execute
        mkdir -p ${FD_OUT}
        sbatch \
            --cpus-per-task 4 \
            --mem 4G \
            --output ${FP_LOG} \
            ${FP_EXE} ${FP_CNF} ${FP_INP_A} ${FP_INP_B} ${FP_OUT}
        echo
    done < <(cat ${FP_REGION_LABEL_B} | awk 'NR >=2 {print}')
done < <(cat ${FP_REGION_LABEL_A} | awk 'NR >=2 {print}')
# Out:
# - FD_RES: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# - FD_LOG: /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_NFE2_ENCFF023IFO
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# Submitted batch job 277511
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 277512
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_KLF10_ENCFF142ZTD
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_KLF10_ENCFF142ZTD.txt
#
# Submitted batch job 277513
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_JUN_ENCFF190CGV
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_JUN_ENCFF190CGV.txt
#
# Submitted batch job 277514
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_ZEB2_ENCFF242AOL
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_ZEB2_ENCFF242AOL.txt
#
# Submitted batch job 277515
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27me3_ENCFF323WOT
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 277516
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_POLR2A_ENCFF355MNE
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_POLR2A_ENCFF355MNE.txt
#
# Submitted batch job 277517
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_YY1_ENCFF398UQZ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_YY1_ENCFF398UQZ.txt
#
# Submitted batch job 277518
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_KLF16_ENCFF488OTN
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_KLF16_ENCFF488OTN.txt
#
# Submitted batch job 277519
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K27ac_ENCFF544LXB
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 277520
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_SP1_ENCFF553GPK
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_SP1_ENCFF553GPK.txt
#
# Submitted batch job 277521
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_ATF1_ENCFF627RSK
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_ATF1_ENCFF627RSK.txt
#
# Submitted batch job 277522
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_GATA1_ENCFF657CTC
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_GATA1_ENCFF657CTC.txt
#
# Submitted batch job 277523
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_CTCF_ENCFF660GHM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_CTCF_ENCFF660GHM.txt
#
# Submitted batch job 277524
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_EP300_ENCFF702XPO
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_EP300_ENCFF702XPO.txt
#
# Submitted batch job 277525
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_REST_ENCFF707MDI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_REST_ENCFF707MDI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_REST_ENCFF707MDI.txt
#
# Submitted batch job 277526
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_ELK1_ENCFF715WGN
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_ELK1_ENCFF715WGN.txt
#
# Submitted batch job 277527
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 277528
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_NRF1_ENCFF777PKJ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_NRF1_ENCFF777PKJ.txt
#
# Submitted batch job 277529
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_TAL1_ENCFF852ZRK
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_TAL1_ENCFF852ZRK.txt
#
# Submitted batch job 277530
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_overlap
# - Label B: encode_chipseq_H3K4me3_ENCFF885FQN
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_overlap/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_overlap.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 277531
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_NFE2_ENCFF023IFO
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_NFE2_ENCFF023IFO.txt
#
# Submitted batch job 277532
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me1_ENCFF135ZLM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K4me1_ENCFF135ZLM.txt
#
# Submitted batch job 277533
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_KLF10_ENCFF142ZTD
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_KLF10_ENCFF142ZTD.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_KLF10_ENCFF142ZTD.txt
#
# Submitted batch job 277534
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_JUN_ENCFF190CGV
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_JUN_ENCFF190CGV.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_JUN_ENCFF190CGV.txt
#
# Submitted batch job 277535
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_ZEB2_ENCFF242AOL
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_ZEB2_ENCFF242AOL.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_ZEB2_ENCFF242AOL.txt
#
# Submitted batch job 277536
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K27me3_ENCFF323WOT
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K27me3_ENCFF323WOT.txt
#
# Submitted batch job 277537
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_POLR2A_ENCFF355MNE
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_POLR2A_ENCFF355MNE.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_POLR2A_ENCFF355MNE.txt
#
# Submitted batch job 277538
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_YY1_ENCFF398UQZ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_YY1_ENCFF398UQZ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_YY1_ENCFF398UQZ.txt
#
# Submitted batch job 277539
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_KLF16_ENCFF488OTN
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_KLF16_ENCFF488OTN.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_KLF16_ENCFF488OTN.txt
#
# Submitted batch job 277540
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K27ac_ENCFF544LXB
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K27ac_ENCFF544LXB.txt
#
# Submitted batch job 277541
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_SP1_ENCFF553GPK
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_SP1_ENCFF553GPK.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_SP1_ENCFF553GPK.txt
#
# Submitted batch job 277542
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_ATF1_ENCFF627RSK
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_ATF1_ENCFF627RSK.txt
#
# Submitted batch job 277543
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_GATA1_ENCFF657CTC
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_GATA1_ENCFF657CTC.txt
#
# Submitted batch job 277544
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_CTCF_ENCFF660GHM
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_CTCF_ENCFF660GHM.txt
#
# Submitted batch job 277545
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_EP300_ENCFF702XPO
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_EP300_ENCFF702XPO.txt
#
# Submitted batch job 277546
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_REST_ENCFF707MDI
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_REST_ENCFF707MDI.txt
#
# Submitted batch job 277547
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_ELK1_ENCFF715WGN
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_ELK1_ENCFF715WGN.txt
#
# Submitted batch job 277548
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me2_ENCFF749KLQ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K4me2_ENCFF749KLQ.txt
#
# Submitted batch job 277549
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_NRF1_ENCFF777PKJ
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_NRF1_ENCFF777PKJ.txt
#
# Submitted batch job 277550
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_TAL1_ENCFF852ZRK
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_TAL1_ENCFF852ZRK.txt
#
# Submitted batch job 277551
#
# ==============================
# Input:
# - Label A: fcc_astarr_macs_input_union
# - Label B: encode_chipseq_H3K4me3_ENCFF885FQN
# Output:
# - FDiry: ${FD_RES}/region_annotation/fcc_astarr_macs_input_union/encode_chipseq_subset
# - FName: fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.bed.gz
# Log:
# - FPath: ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
#
# Submitted batch job 277552

# %% [markdown]
# ## Review

# %%
cat ${FD_LOG}/region.intersect.fcc_astarr_macs_input_union.encode_chipseq_H3K4me3_ENCFF885FQN.txt
# Out:
# Hostname:           plp-rcc-node-07
# Slurm Array Index:
# Time Stamp:         05-29-25+16:41:24
#
# Input:  /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region/fcc_astarr_macs_merge/K562.hg38.ASTARR.macs.KS91.input.rep_all