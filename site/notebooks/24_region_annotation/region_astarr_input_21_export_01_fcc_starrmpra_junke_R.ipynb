# %% [raw]
# ---
# title: Annotation of ATAC (ASTARR Input) 21
# subtitle: 01 Summarize ATAC w/ STARR/MRPA peaks
# format:
#     html:
#         code-fold:  true
#         code-tools: true
# ---

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("../run_config_project_sing.R")))
show_env()
# Out:
# You are working on        Singularity: singularity_proj_encode_fcc
# BASE DIRECTORY (FD_BASE): /data/reddylab/Kuei
# REPO DIRECTORY (FD_REPO): /data/reddylab/Kuei/repo
# WORK DIRECTORY (FD_WORK): /data/reddylab/Kuei/work
# DATA DIRECTORY (FD_DATA): /data/reddylab/Kuei/data
#
# You are working with      ENCODE FCC
# PATH OF PROJECT (FD_PRJ): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC
# PROJECT RESULTS (FD_RES): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results
# PROJECT SCRIPTS (FD_EXE): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/scripts
# PROJECT DATA    (FD_DAT): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/data
# PROJECT NOTE    (FD_NBK): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/notebooks
# PROJECT DOCS    (FD_DOC): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/docs
# PROJECT LOG     (FD_LOG): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/log
# PROJECT REF     (FD_REF): /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/references

# %% [markdown]
# ## Prepare

# %% [markdown]
# **Set global variable**

# %%
vec = c(
    "fcc_astarr_macs_input_overlap",
    "fcc_astarr_macs_input_union"
)
names(vec) = vec

VEC_TXT_FOLDER = vec
for(txt in vec){cat(txt, "\n")}
# Out:
# fcc_astarr_macs_input_overlap
# fcc_astarr_macs_input_union

# %%
TXT_FNAME_ANNOT = "region.intersect.summary.fcc_starrmpra_junke.tsv"

# %% [markdown]
# **View files**

# %%
txt_fdiry = file.path(FD_RES, "region_annotation", "*", "summary")
txt_fname = TXT_FNAME_ANNOT
txt_fglob = file.path(txt_fdiry, txt_fname)

vec = Sys.glob(txt_fglob)
for(txt in vec){cat(txt, "\n")}
# Out:
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_overlap/summary/region.intersect.summary.fcc_starrmpra_junke.tsv
# /data/reddylab/Kuei/repo/Proj_ENCODE_FCC/results/region_annotation/fcc_astarr_macs_input_union/summary/region.intersect.summary.fcc_starrmpra_junke.tsv

# %% [markdown]
# ## Import data

# %% [markdown]
# **Import region pairs**

# %%
### loop to import data
lst = lapply(VEC_TXT_FOLDER, function(txt_folder){
    ### set file directory
    txt_fdiry = file.path(FD_RES, "region_annotation", txt_folder, "summary")
    txt_fname = TXT_FNAME_ANNOT
    txt_fpath = file.path(txt_fdiry, txt_fname)

    ### read table
    dat = read_tsv(txt_fpath, show_col_types = FALSE)
    return(dat)
})

### assign and show
lst_dat_region_annot_import = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 208167     10
#
# $fcc_astarr_macs_input_union
# [1] 259439     10
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Annotation_A </th>
#    <th style="text-align:left;"> Annotation_B </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#    <th style="text-align:left;"> Region_Annot </th>
#    <th style="text-align:right;"> Region_Count </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> fcc_starrmpra_junke_astarr </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> chr1:10010-10430 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
#    <td style="text-align:right;"> 16338 </td>
#    <td style="text-align:left;"> chr1:16025-16338 </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> fcc_starrmpra_junke_astarr </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> chr1:16220-16340 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 17288 </td>
#    <td style="text-align:right;"> 17689 </td>
#    <td style="text-align:left;"> chr1:17288-17689 </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> fcc_starrmpra_junke_astarr </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> chr1:17230-17440;chr1:17610-17720 </td>
#    <td style="text-align:right;"> 2 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# **Explore: Group**

# %%
lst = lst_dat_region_annot_import
lst = lapply(lst, function(dat){
    res = table(dat$Group, dnn = "Group")
    dat = as.data.frame(res)
    return(dat)
})

dat = bind_rows(lst, .id = "Region")
dat = dat %>% tidyr::spread(Group, Freq)
fun_display_table(dat)
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> ASTARR </th>
#    <th style="text-align:right;"> eSTARR </th>
#    <th style="text-align:right;"> LMPRA </th>
#    <th style="text-align:right;"> TMPRA </th>
#    <th style="text-align:right;"> WSTARR </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:right;"> 129285 </td>
#    <td style="text-align:right;"> 489 </td>
#    <td style="text-align:right;"> 34929 </td>
#    <td style="text-align:right;"> 873 </td>
#    <td style="text-align:right;"> 42591 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:right;"> 167104 </td>
#    <td style="text-align:right;"> 515 </td>
#    <td style="text-align:right;"> 37052 </td>
#    <td style="text-align:right;"> 1143 </td>
#    <td style="text-align:right;"> 53625 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# **Explore: Group x Label**

# %%
lst = lst_dat_region_annot_import
lst = lapply(lst, function(dat){
    res = table(dat$Group, dat$Label, dnn = c("Group", "Label"))
    dat = as.data.frame(res)
    return(dat)
})

dat = bind_rows(lst, .id = "Region")
dat = dat %>% tidyr::spread(Label, Freq)
fun_display_table(dat)
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:right;"> ASTARR_A </th>
#    <th style="text-align:right;"> ASTARR_AB </th>
#    <th style="text-align:right;"> ASTARR_R </th>
#    <th style="text-align:right;"> ASTARR_RB </th>
#    <th style="text-align:right;"> eSTARR_A </th>
#    <th style="text-align:right;"> eSTARR_AB </th>
#    <th style="text-align:right;"> eSTARR_R </th>
#    <th style="text-align:right;"> eSTARR_RB </th>
#    <th style="text-align:right;"> LMPRA_A </th>
#    <th style="text-align:right;"> LMPRA_AB </th>
#    <th style="text-align:right;"> LMPRA_R </th>
#    <th style="text-align:right;"> LMPRA_RB </th>
#    <th style="text-align:right;"> TMPRA_A </th>
#    <th style="text-align:right;"> TMPRA_AB </th>
#    <th style="text-align:right;"> TMPRA_R </th>
#    <th style="text-align:right;"> WSTARR_A </th>
#    <th style="text-align:right;"> WSTARR_AB </th>
#    <th style="text-align:right;"> WSTARR_R </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 26161 </td>
#    <td style="text-align:right;"> 10347 </td>
#    <td style="text-align:right;"> 73723 </td>
#    <td style="text-align:right;"> 19054 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> eSTARR </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 145 </td>
#    <td style="text-align:right;"> 30 </td>
#    <td style="text-align:right;"> 262 </td>
#    <td style="text-align:right;"> 52 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 20692 </td>
#    <td style="text-align:right;"> 13931 </td>
#    <td style="text-align:right;"> 245 </td>
#    <td style="text-align:right;"> 61 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> TMPRA </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 847 </td>
#    <td style="text-align:right;"> 13 </td>
#    <td style="text-align:right;"> 13 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> WSTARR </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 26992 </td>
#    <td style="text-align:right;"> 12410 </td>
#    <td style="text-align:right;"> 3189 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 29626 </td>
#    <td style="text-align:right;"> 10926 </td>
#    <td style="text-align:right;"> 103577 </td>
#    <td style="text-align:right;"> 22975 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> eSTARR </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 149 </td>
#    <td style="text-align:right;"> 31 </td>
#    <td style="text-align:right;"> 279 </td>
#    <td style="text-align:right;"> 56 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 22022 </td>
#    <td style="text-align:right;"> 14663 </td>
#    <td style="text-align:right;"> 289 </td>
#    <td style="text-align:right;"> 78 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;">

# %% [markdown]
# **Explore: Group x Region Count**

# %%
lst = lst_dat_region_annot_import
lst = lapply(lst, function(dat){
    res = table(dat$Group, dat$Region_Count, dnn = c("Group", "Region_Count"))
    dat = as.data.frame(res)
    return(dat)
})

dat = bind_rows(lst, .id = "Region")
dat = dat %>% tidyr::spread(Region_Count, Freq)
fun_display_table(dat)
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:right;"> 1 </th>
#    <th style="text-align:right;"> 2 </th>
#    <th style="text-align:right;"> 3 </th>
#    <th style="text-align:right;"> 4 </th>
#    <th style="text-align:right;"> 5 </th>
#    <th style="text-align:right;"> 6 </th>
#    <th style="text-align:right;"> 7 </th>
#    <th style="text-align:right;"> 8 </th>
#    <th style="text-align:right;"> 9 </th>
#    <th style="text-align:right;"> 10 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 96966 </td>
#    <td style="text-align:right;"> 24722 </td>
#    <td style="text-align:right;"> 5777 </td>
#    <td style="text-align:right;"> 1391 </td>
#    <td style="text-align:right;"> 322 </td>
#    <td style="text-align:right;"> 79 </td>
#    <td style="text-align:right;"> 20 </td>
#    <td style="text-align:right;"> 8 </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> NA </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> eSTARR </td>
#    <td style="text-align:right;"> 487 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> NA </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 33573 </td>
#    <td style="text-align:right;"> 1284 </td>
#    <td style="text-align:right;"> 62 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> NA </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> TMPRA </td>
#    <td style="text-align:right;"> 599 </td>
#    <td style="text-align:right;"> 214 </td>
#    <td style="text-align:right;"> 43 </td>
#    <td style="text-align:right;"> 12 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 3 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> NA </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> WSTARR </td>
#    <td style="text-align:right;"> 35125 </td>
#    <td style="text-align:right;"> 6185 </td>
#    <td style="text-align:right;"> 1087 </td>
#    <td style="text-align:right;"> 174 </td>
#    <td style="text-align:right;"> 15 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> NA </td>
#    <td style="text-align:right;"> NA </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 122668 </td>
#    <td style="text-align:right;"> 32281 </td>
#    <td style="text-align:right;"> 8687 </td>
#    <td style="text-align:right;"> 2440 </td>
#    <td style="text-align:right;"> 708 </td>
#    <td style="text-align:right;"> 213 </td>
#    <td style="text-align:right;"> 66 </td>
#    <td style="text-align:right;"> 33 </td>
#    <td style="text-align:right;"> 5 </td>
#    <td style="text-align:right;"> 3 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> eSTARR </td>
#    <td style="text-align:right;"> 513 </td>
#    <td style="text-align:right;"> 2 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 35609 </td>
#    <td style="text-align:right;"> 1365 </td>
#    <td style="text-align:right;"> 67 </td>
#    <td style="text-align:right;"> 7 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> TMPRA </td>
#    <td style="text-align:right;"> 770 </td>
#    <td style="text-align:right;"> 281 </td>
#    <td style="text-align:right;"> 65 </td>
#    <td style="text-align:right;"> 19 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 4 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> WSTARR </td>
#    <td style="text-align:right;"> 44580 </td>
#    <td style="text-align:right;"> 7510 </td>
#    <td style="text-align:right;"> 1295 </td>
#    <td style="text-align:right;"> 210 </td>
#    <td style="text-align:right;"> 24 </td>
#    <td style="text-align:right;"> 6 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Arrange table

# %%
### init
vec = c("ASTARR", "WSTARR", "LMPRA", "TMPRA")
vec = c(
    paste(vec, "A", sep = "_"),
    paste(vec, "R", sep = "_")
)
vec_txt_label = vec
cat("Label:", vec_txt_label, "\n\n")

### arrange tables
lst = lst_dat_region_annot_import
lst = lapply(lst, function(dat){
    dat = dat %>% 
        dplyr::filter(Label %in% vec_txt_label) %>%
        dplyr::distinct()

    ###
    dat = dat %>% tidyr::separate(Label, into=c("X", "Direction_Label"), remove=FALSE)

    ### sanity check
    cat("Check:", all(dat$Group == dat$X), "\n")

    ###
    dat = dat %>% dplyr::mutate(
        Direction_Assay = dplyr::recode(
            Direction_Label, 
            "A" = "Active",
            "R" = "Repressive"
        )
    ) 

    ### reorder columns
    dat = dat %>%
        dplyr::select(
            Chrom, ChromStart, ChromEnd, Region,
            Annotation_A, Annotation_B,
            Group, Label,
            Direction_Assay,
            Direction_Label,
            Region_Annot,
            Region_Count
        )
    return(dat)
})

### assign and show
lst_dat_region_annot_arrange = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# Label: ASTARR_A WSTARR_A LMPRA_A TMPRA_A ASTARR_R WSTARR_R LMPRA_R TMPRA_R
#
# Check: TRUE
# Check: TRUE
# $fcc_astarr_macs_input_overlap
# [1] 151862     12
#
# $fcc_astarr_macs_input_union
# [1] 196065     12
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Annotation_A </th>
#    <th style="text-align:left;"> Annotation_B </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:left;"> Label </th>
#    <th style="text-align:left;"> Direction_Assay </th>
#    <th style="text-align:left;"> Direction_Label </th>
#    <th style="text-align:left;"> Region_Annot </th>
#    <th style="text-align:right;"> Region_Count </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> fcc_starrmpra_junke_astarr </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> Repressive </td>
#    <td style="text-align:left;"> R </td>
#    <td style="text-align:left;"> chr1:10010-10430 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
#    <td style="text-align:right;"> 16338 </td>
#    <td style="text-align:left;"> chr1:16025-16338 </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> fcc_starrmpra_junke_astarr </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> Repressive </td>
#    <td style="text-align:left;"> R </td>
#    <td style="text-align:left;"> chr1:16220-16340 </td>
#    <td style="text-align:right;"> 1 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 17288 </td>
#    <td style="text-align:right;"> 17689 </td>
#    <td style="text-align:left;"> chr1:17288-17689 </td>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> fcc_starrmpra_junke_astarr </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:left;"> ASTARR_R </td>
#    <td style="text-align:left;"> Repressive </td>
#    <td style="text-align:left;"> R </td>
#    <td style="text-align:left;"> chr1:17230-17440;chr1:17610-17720 </td>
#    <td style="text-align:right;"> 2 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# **Explore: Group x Label**

# %%
lst = lst_dat_region_annot_arrange
lst = lapply(lst, function(dat){
    res = table(dat$Group, dat$Label, dnn = c("Group", "Label"))
    dat = as.data.frame(res)
    return(dat)
})

dat = bind_rows(lst, .id = "Region")
dat = dat %>% tidyr::spread(Label, Freq)
fun_display_table(dat)
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:right;"> ASTARR_A </th>
#    <th style="text-align:right;"> ASTARR_R </th>
#    <th style="text-align:right;"> LMPRA_A </th>
#    <th style="text-align:right;"> LMPRA_R </th>
#    <th style="text-align:right;"> TMPRA_A </th>
#    <th style="text-align:right;"> TMPRA_R </th>
#    <th style="text-align:right;"> WSTARR_A </th>
#    <th style="text-align:right;"> WSTARR_R </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 26161 </td>
#    <td style="text-align:right;"> 73723 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 20692 </td>
#    <td style="text-align:right;"> 245 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> TMPRA </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 847 </td>
#    <td style="text-align:right;"> 13 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> WSTARR </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 26992 </td>
#    <td style="text-align:right;"> 3189 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 29626 </td>
#    <td style="text-align:right;"> 103577 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 22022 </td>
#    <td style="text-align:right;"> 289 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> TMPRA </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1103 </td>
#    <td style="text-align:right;"> 24 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> WSTARR </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 33350 </td>
#    <td style="text-align:right;"> 6074 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# **Explore: Group x Direction**

# %%
lst = lst_dat_region_annot_arrange
lst = lapply(lst, function(dat){
    res = table(dat$Group, dat$Direction_Assay, dnn = c("Group", "Direction"))
    dat = as.data.frame(res)
    return(dat)
})

dat = bind_rows(lst, .id = "Region")
dat = dat %>% tidyr::spread(Direction, Freq)
fun_display_table(dat)
# Out:
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:left;"> Group </th>
#    <th style="text-align:right;"> Active </th>
#    <th style="text-align:right;"> Repressive </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 26161 </td>
#    <td style="text-align:right;"> 73723 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 20692 </td>
#    <td style="text-align:right;"> 245 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> TMPRA </td>
#    <td style="text-align:right;"> 847 </td>
#    <td style="text-align:right;"> 13 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_overlap </td>
#    <td style="text-align:left;"> WSTARR </td>
#    <td style="text-align:right;"> 26992 </td>
#    <td style="text-align:right;"> 3189 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> ASTARR </td>
#    <td style="text-align:right;"> 29626 </td>
#    <td style="text-align:right;"> 103577 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> LMPRA </td>
#    <td style="text-align:right;"> 22022 </td>
#    <td style="text-align:right;"> 289 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> TMPRA </td>
#    <td style="text-align:right;"> 1103 </td>
#    <td style="text-align:right;"> 24 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> fcc_astarr_macs_input_union </td>
#    <td style="text-align:left;"> WSTARR </td>
#    <td style="text-align:right;"> 33350 </td>
#    <td style="text-align:right;"> 6074 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Matrix

# %%
### convert long to wide format
lst = lst_dat_region_annot_arrange
lst = lapply(lst, function(dat){
    dat = dat %>%
        dplyr::select(Chrom, ChromStart, ChromEnd, Region, Label) %>%
        dplyr::mutate(Value = 1) %>%
        dplyr::distinct() 

    dat = dat %>% 
        tidyr::spread(Label, Value) %>%
        replace(is.na(.), 0)
    return(dat)
})

### assign and show
lst_dat_region_annot_matrix = lst

res = lapply(lst, dim)
print(res)

dat = lst[[1]]
fun_display_table(head(dat, 3))
# Out:
# $fcc_astarr_macs_input_overlap
# [1] 99749    12
#
# $fcc_astarr_macs_input_union
# [1] 135016     12
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Chrom </th>
#    <th style="text-align:right;"> ChromStart </th>
#    <th style="text-align:right;"> ChromEnd </th>
#    <th style="text-align:left;"> Region </th>
#    <th style="text-align:right;"> ASTARR_A </th>
#    <th style="text-align:right;"> ASTARR_R </th>
#    <th style="text-align:right;"> LMPRA_A </th>
#    <th style="text-align:right;"> LMPRA_R </th>
#    <th style="text-align:right;"> TMPRA_A </th>
#    <th style="text-align:right;"> TMPRA_R </th>
#    <th style="text-align:right;"> WSTARR_A </th>
#    <th style="text-align:right;"> WSTARR_R </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 10038 </td>
#    <td style="text-align:right;"> 10405 </td>
#    <td style="text-align:left;"> chr1:10038-10405 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 16025 </td>
#    <td style="text-align:right;"> 16338 </td>
#    <td style="text-align:left;"> chr1:16025-16338 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> chr1 </td>
#    <td style="text-align:right;"> 17288 </td>
#    <td style="text-align:right;"> 17689 </td>
#    <td style="text-align:left;"> chr1:17288-17689 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 1 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#    <td style="text-align:right;"> 0 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Save results

# %%
for (txt_folder in VEC_TXT_FOLDER){

    ### get tables
    dat_region_annot_result = lst_dat_region_annot_arrange[[txt_folder]]
    dat_region_annot_matrix = lst_dat_region_annot_matrix[[txt_folder]]
    
    ### set file directory
    txt_fdiry = file.path(
        FD_RES, 
        "region_annotation", 
        txt_folder,
        "summary"
    )
    
    ### write region annotation (long format)
    txt_fname = "region.annotation.fcc_starrmpra_junke.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    
    dat = dat_region_annot_result
    dat = dat %>% dplyr::arrange(Chrom, ChromStart, ChromEnd)
    write_tsv(dat, txt_fpath)

    ### write region annotation (wide format)
    txt_fname = "matrix.annotation.fcc_starrmpra_junke.tsv"
    txt_fpath = file.path(txt_fdiry, txt_fname)
    
    dat = dat_region_annot_matrix
    dat = dat %>% dplyr::arrange(Chrom, ChromStart, ChromEnd)
    write_tsv(dat, txt_fpath)
}
